-- %% [markdown]
-- # [dbo].[Branch]

-- %%
USE [trstfy]
GO

-- %%
/****** Object:  Table [dbo].[Branch]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Branch](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](20) NULL,
	[Name] [varchar](50) NOT NULL,
	[CourseId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Branch_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConfigurationDtl]

-- %%
/****** Object:  Table [dbo].[ConfigurationDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConfigurationDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ConfigurationHdrId] [int] NULL,
	[BranchId] [int] NOT NULL,
	[YearId] [int] NOT NULL,
	[SubjectId] [int] NOT NULL,
	[TypeId] [int] NOT NULL,
	[AssessmentsId] [int] NOT NULL,
	[LabsId] [int] NOT NULL,
	[ProjectsId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_ConfigurationDtl_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ConfigurationHdr]

-- %%
/****** Object:  Table [dbo].[ConfigurationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ConfigurationHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UniversityId] [int] NULL,
	[RegulationCodeId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_ConfigurationHdr_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Course]

-- %%
/****** Object:  Table [dbo].[Course]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Course](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](20) NULL,
	[Description] [varchar](50) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Courses_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Institutions]

-- %%
/****** Object:  Table [dbo].[Institutions]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Institutions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NameofInstitiute] [varchar](255) NULL,
	[AffiliatedUniversity] [varchar](100) NOT NULL,
	[Location] [varchar](55) NULL,
	[Pincode] [int] NULL,
	[GSTNumber] [varchar](50) NULL,
	[Picture] [varchar](255) NULL,
	[ContactNumber] [bigint] NULL,
	[ContactName] [varchar](50) NULL,
	[Designation] [varchar](50) NULL,
	[EmailId] [varchar](55) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[InstitutePermanentId] [varchar](20) NULL,
 CONSTRAINT [PK_Institutions_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Instructor]

-- %%
/****** Object:  Table [dbo].[Instructor]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Instructor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](20) NULL,
	[Name] [varchar](100) NOT NULL,
	[Gender] [varchar](10) NOT NULL,
	[Age] [int] NULL,
	[Email] [varchar](55) NULL,
	[PhoneNo] [bigint] NULL,
	[Qualification] [varchar](50) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Instructor_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupDtl]

-- %%
/****** Object:  Table [dbo].[LookupDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LookupHdrId] [int] NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Remarks] [varchar](100) NULL,
	[Ord] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupHdr]

-- %%
/****** Object:  Table [dbo].[LookupHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MarksFileHDR]

-- %%
/****** Object:  Table [dbo].[MarksFileHDR]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MarksFileHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FileId] [varchar](255) NOT NULL,
	[FileName] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RegulationDtl]

-- %%
/****** Object:  Table [dbo].[RegulationDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RegulationDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RegulationHdrId] [int] NOT NULL,
	[RegulationCode] [varchar](55) NOT NULL,
	[Regulationyear] [int] NOT NULL,
	[Year] [int] NOT NULL,
	[Semester] [varchar](55) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RegulationHdr]

-- %%
/****** Object:  Table [dbo].[RegulationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RegulationHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RegulationCode] [varchar](55) NOT NULL,
	[Regulationyear] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StudentMarks]

-- %%
/****** Object:  Table [dbo].[StudentMarks]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StudentMarks](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[StudentId] [int] NOT NULL,
	[SemesterId] [varchar](20) NULL,
	[ModeOfExam] [varchar](50) NOT NULL,
	[SubjectCode] [varchar](50) NOT NULL,
	[Marks] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_StudentMarks_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StudentProfile]

-- %%
/****** Object:  Table [dbo].[StudentProfile]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StudentProfile](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FirstName] [varchar](100) NOT NULL,
	[SecondName] [varchar](100) NOT NULL,
	[FatherName] [varchar](100) NOT NULL,
	[AadharNo] [varchar](12) NOT NULL,
	[Gender] [int] NULL,
	[PhoneNo] [bigint] NULL,
	[Email] [varchar](55) NULL,
	[HouseNumber] [varchar](50) NULL,
	[StreetName] [varchar](50) NULL,
	[Address] [varchar](255) NULL,
	[City] [varchar](50) NULL,
	[State] [varchar](50) NULL,
	[Pincode] [varchar](10) NULL,
	[RollNo] [varchar](50) NULL,
	[BranchId] [int] NULL,
	[InstituteId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[DateOfBirth] [date] NULL,
	[UniqueId] [varchar](255) NULL,
	[Picture] [varchar](255) NULL,
 CONSTRAINT [PK_StudentProfile_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Subjects]

-- %%
/****** Object:  Table [dbo].[Subjects]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Subjects](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Subject] [varchar](55) NULL,
	[SubCode] [varchar](55) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Subjects_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[University]

-- %%
/****** Object:  Table [dbo].[University]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[University](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UniversityName] [varchar](50) NOT NULL,
	[UniversityId] [varchar](50) NOT NULL,
	[Location] [varchar](55) NULL,
	[Pincode] [int] NULL,
	[EmailId] [varchar](55) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_University_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](30) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[MiddileName] [varchar](50) NULL,
	[LastName] [varchar](50) NOT NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[RoleId] [int] NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Branch__IsActive__5C37ACAD]

-- %%
ALTER TABLE [dbo].[Branch] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Branch__CreatedD__5D2BD0E6]

-- %%
ALTER TABLE [dbo].[Branch] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Branch__UpdatedD__5F141958]

-- %%
ALTER TABLE [dbo].[Branch] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Configura__IsAct__43F60EC8]

-- %%
ALTER TABLE [dbo].[ConfigurationDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Configura__Creat__44EA3301]

-- %%
ALTER TABLE [dbo].[ConfigurationDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Configura__Updat__45DE573A]

-- %%
ALTER TABLE [dbo].[ConfigurationDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Configura__IsAct__5B0E7E4A]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Configura__Creat__5C02A283]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Configura__Updat__5CF6C6BC]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Course__IsActive__40C49C62]

-- %%
ALTER TABLE [dbo].[Course] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Course__CreatedD__41B8C09B]

-- %%
ALTER TABLE [dbo].[Course] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Course__UpdatedD__42ACE4D4]

-- %%
ALTER TABLE [dbo].[Course] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Instituti__IsAct__627A95E8]

-- %%
ALTER TABLE [dbo].[Institutions] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Instituti__Creat__636EBA21]

-- %%
ALTER TABLE [dbo].[Institutions] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Instituti__Updat__6462DE5A]

-- %%
ALTER TABLE [dbo].[Institutions] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Instructo__IsAct__793DFFAF]

-- %%
ALTER TABLE [dbo].[Instructor] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Instructo__Creat__7A3223E8]

-- %%
ALTER TABLE [dbo].[Instructor] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Instructo__Updat__7B264821]

-- %%
ALTER TABLE [dbo].[Instructor] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__IsAct__4AD81681]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Creat__4BCC3ABA]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Updat__4CC05EF3]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__IsAct__4EA8A765]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Creat__4F9CCB9E]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Updat__5090EFD7]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__1DB06A4F]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__1EA48E88]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__1F98B2C1]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__208CD6FA]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__2180FB33]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__22751F6C]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__Regulatio__IsAct__1BB31344]

-- %%
ALTER TABLE [dbo].[RegulationDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Regulatio__Creat__1CA7377D]

-- %%
ALTER TABLE [dbo].[RegulationDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Regulatio__Updat__1D9B5BB6]

-- %%
ALTER TABLE [dbo].[RegulationDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Regulatio__IsAct__16EE5E27]

-- %%
ALTER TABLE [dbo].[RegulationHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Regulatio__Creat__17E28260]

-- %%
ALTER TABLE [dbo].[RegulationHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Regulatio__Updat__18D6A699]

-- %%
ALTER TABLE [dbo].[RegulationHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__2B0A656D]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__2BFE89A6]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__2CF2ADDF]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__2DE6D218]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__2EDAF651]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__2FCF1A8A]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__123EB7A3]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__1332DBDC]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__14270015]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__StudentMa__IsAct__1CDC41A7]

-- %%
ALTER TABLE [dbo].[StudentMarks] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__StudentMa__Creat__1DD065E0]

-- %%
ALTER TABLE [dbo].[StudentMarks] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__StudentMa__Updat__1EC48A19]

-- %%
ALTER TABLE [dbo].[StudentMarks] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__StudentPr__IsAct__69279377]

-- %%
ALTER TABLE [dbo].[StudentProfile] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__StudentPr__Creat__6A1BB7B0]

-- %%
ALTER TABLE [dbo].[StudentProfile] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__StudentPr__Updat__6B0FDBE9]

-- %%
ALTER TABLE [dbo].[StudentProfile] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Subjects__IsActi__78D3EB5B]

-- %%
ALTER TABLE [dbo].[Subjects] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Subjects__Create__79C80F94]

-- %%
ALTER TABLE [dbo].[Subjects] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Subjects__Update__7ABC33CD]

-- %%
ALTER TABLE [dbo].[Subjects] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Universit__IsAct__09FE775D]

-- %%
ALTER TABLE [dbo].[University] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Universit__Creat__0AF29B96]

-- %%
ALTER TABLE [dbo].[University] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Universit__Updat__0BE6BFCF]

-- %%
ALTER TABLE [dbo].[University] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__60A75C0F]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__619B8048]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__628FA481]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK__Branch__CourseId__61F08603]

-- %%
ALTER TABLE [dbo].[Branch]  WITH CHECK ADD FOREIGN KEY([CourseId])
REFERENCES [dbo].[Course] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Creat__46D27B73]

-- %%
ALTER TABLE [dbo].[ConfigurationDtl]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Updat__47C69FAC]

-- %%
ALTER TABLE [dbo].[ConfigurationDtl]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Creat__2B2A60FE]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Creat__5DEAEAF5]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Unive__2D12A970]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr]  WITH CHECK ADD FOREIGN KEY([UniversityId])
REFERENCES [dbo].[University] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Unive__5FD33367]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr]  WITH CHECK ADD FOREIGN KEY([UniversityId])
REFERENCES [dbo].[University] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Updat__2E06CDA9]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Configura__Updat__60C757A0]

-- %%
ALTER TABLE [dbo].[ConfigurationHdr]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Instituti__Creat__65570293]

-- %%
ALTER TABLE [dbo].[Institutions]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Instituti__Updat__664B26CC]

-- %%
ALTER TABLE [dbo].[Institutions]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Instructo__Creat__7D0E9093]

-- %%
ALTER TABLE [dbo].[Instructor]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Instructo__Updat__7C1A6C5A]

-- %%
ALTER TABLE [dbo].[Instructor]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK_Menu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Menu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK__Roles__CreatedBy__40058253]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK_Roles_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Roles_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK__StudentMa__Creat__1FB8AE52]

-- %%
ALTER TABLE [dbo].[StudentMarks]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__StudentMa__Updat__20ACD28B]

-- %%
ALTER TABLE [dbo].[StudentMarks]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__StudentPr__Branc__6C040022]

-- %%
ALTER TABLE [dbo].[StudentProfile]  WITH CHECK ADD FOREIGN KEY([BranchId])
REFERENCES [dbo].[Branch] ([Id])
GO

-- %% [markdown]
-- # [FK__StudentPr__Creat__6CF8245B]

-- %%
ALTER TABLE [dbo].[StudentProfile]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__StudentPr__Insti__6DEC4894]

-- %%
ALTER TABLE [dbo].[StudentProfile]  WITH CHECK ADD FOREIGN KEY([InstituteId])
REFERENCES [dbo].[Institutions] ([Id])
GO

-- %% [markdown]
-- # [FK__StudentPr__Updat__6EE06CCD]

-- %%
ALTER TABLE [dbo].[StudentProfile]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Subjects__Create__7BB05806]

-- %%
ALTER TABLE [dbo].[Subjects]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Subjects__Update__7CA47C3F]

-- %%
ALTER TABLE [dbo].[Subjects]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Universit__Creat__0CDAE408]

-- %%
ALTER TABLE [dbo].[University]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__Universit__Updat__0DCF0841]

-- %%
ALTER TABLE [dbo].[University]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [dbo].[LookupDtlByCodeandYear]

-- %%
/****** Object:  StoredProcedure [dbo].[LookupDtlByCodeandYear]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[LookupDtlByCodeandYear](@RegulationCode varchar(255),@Year int)
as
begin
select * from RegulationDtl where RegulationCode = @RegulationCode AND Year =@Year
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddBranch]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBranch]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddBranch] 
(
@Id int
,@CourseId int
,@Code varchar(20)
,@Name varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@branchOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].Branch (
				 CourseId
				,[Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @CourseId
				,@Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @branchOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].Branch
			SET  [CourseId] = @CourseId
			,[Code] = @Code
				,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @branchOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddConfiguration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddConfiguration]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddConfiguration] 
(
 @Id int
,@Institution varchar(50)
,@Regulation varchar(100)
,@Semister varchar(50)
,@Course varchar(55)
,@Description varchar(55)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)

	as BEGIN 
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].ConfigurationScreen(
				 Institution
				,Regulation
				,Semister
				,Course
				,Description
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Institution
				,@Regulation
				,@Semister
                ,@Course
				,@Description
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				END
		ELSE
		Begin
			UPDATE [dbo].ConfigurationScreen
			SET  Institution = @Institution
				,Regulation = @Regulation
				,Semister=@Semister
				,Course=@Course
				,Description=@Description
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END 
	END
GO

-- %% [markdown]
-- # [dbo].[SP_AddConfigurationDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddConfigurationDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddConfigurationDtl] 
(
 @Id int
,@ConfigurationHdrId int
,@BranchId int
,@YearId int
,@SubjectId int
,@TypeId int
,@AssessmentsId int
,@LabsId int
,@ProjectsId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@configdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].ConfigurationDtl (
				 ConfigurationHdrId
				,BranchId
				,YearId
				,SubjectId
				,TypeId
				,AssessmentsId
				,LabsId
				,ProjectsId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ConfigurationHdrId
				,@BranchId
				,@YearId
				,@SubjectId
				,@TypeId
				,@AssessmentsId
				,@LabsId
				,@ProjectsId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @configdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[ConfigurationDtl]
			SET  ConfigurationHdrId = @ConfigurationHdrId
			,BranchId = @BranchId
			,YearId=@YearId
				,SubjectId = @SubjectId
				,TypeId = @TypeId
				,AssessmentsId=@AssessmentsId
				,LabsId=@LabsId
				,ProjectsId=@ProjectsId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @configdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddConfigurationHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddConfigurationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddConfigurationHdr] 
(
 @Id int,
 @UniversityId Varchar(55)
,@RegulationCodeId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@configOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[ConfigurationHdr] (
				 [UniversityId]
				,[RegulationCodeId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @UniversityId
				,@RegulationCodeId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @configOUT  = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[ConfigurationHdr]
			SET  
				[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @configOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCourse]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCourse]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddCourse] 
(
 @Id int
,@Code varchar(20)
,@Description varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@CourseOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].Course (
				 [Code]
				,Description
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Description
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @CourseOUT = @@IDENTITY
				END
		ELSE
		Begin
			UPDATE [dbo].Course
			SET Code = @Code
				,Description=@Description
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @CourseOUT = @Id
	end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddInstitutions]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddInstitutions]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddInstitutions] 
(
 @Id int
,@NameofInstitiute varchar(50)
,@AffiliatedUniversity varchar(100)
,@InstitutePermanentId varchar(50)
,@Location varchar(55)
,@Pincode int
,@GSTNumber varchar(50)
,@Picture varchar(255)
,@ContactNumber bigint
,@ContactName varchar(50)
,@Designation varchar(50)
,@EmailId varchar(55)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)

	as BEGIN 
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].Institutions(
				 NameofInstitiute
				,AffiliatedUniversity
				,InstitutePermanentId
				,Location
				,Pincode
				,GSTNumber
				,Picture
				,ContactNumber
				,ContactName
				,Designation
				,EmailId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @NameofInstitiute
				,@AffiliatedUniversity
				,@InstitutePermanentId
                ,@Location
				,@Pincode
				,@GSTNumber
				,@Picture
				,@ContactNumber
				,@ContactName
				,@Designation
				,@EmailId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				END
		ELSE
		Begin
			UPDATE [dbo].Institutions
			SET  NameofInstitiute = @NameofInstitiute
				,AffiliatedUniversity = @AffiliatedUniversity
				,InstitutePermanentId=@InstitutePermanentId
				,Location=@Location
				,Pincode=@Pincode
				,GSTNumber=@GSTNumber
				,Picture=@Picture
				,ContactNumber=@ContactNumber
				,ContactName=@ContactName
				,Designation=@Designation
				,EmailId=@EmailId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END 
	END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddLookupDtl] 
(
 @Id int
,@LookupHdrId int
,@Code varchar(255)
,@Name varchar(100)
,@Remarks varchar(100)
,@Ord int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookupdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupDtl] (
				  [LookupHdrId]
				,[Code]
				,[Name]
				,[Remarks]
				,[Ord]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @LookupHdrId
				,@Code
				,@Name
				,@Remarks
				,@Ord
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookupdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[LookupDtl]
			SET  [LookupHdrId] = @LookupHdrId
			,[Code] = @Code
				,[Name] = @Name
				,[Remarks] = @Remarks
				,[Ord] = @Ord
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookupdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddLookupHdr] 
(
 @Id int,
 @Code Varchar(255)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookuphdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupHdr] (
					 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 	 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookuphdrOUT = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[LookupHdr]
			SET  
				[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookuphdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRegulationDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRegulationDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRegulationDtl] 
(
 @Id int
,@RegulationHdrId int
,@RegulationCode varchar(55)
,@Regulationyear int
,@Year int
,@Semester varchar(55)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@regulationdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[RegulationDtl] (
				 [RegulationHdrId]
				,[RegulationCode]
				,Regulationyear
				,[Year]
				,[Semester]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RegulationHdrId
				,@RegulationCode
				,@Regulationyear
				,@Year
				,@Semester
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @regulationdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[RegulationDtl]
			SET  [RegulationHdrId] = @RegulationHdrId
			,[RegulationCode] = @RegulationCode
			,Regulationyear=@Regulationyear
				,[Year] = @Year
				,[Semester] = @Semester
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @regulationdtlOUT = @@IDENTITY
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRegulationHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRegulationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddRegulationHdr] 
(
 @Id int,
 @RegulationCode Varchar(55)
,@Regulationyear int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@regulationhdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[RegulationHdr] (
				 [RegulationCode]
				,[Regulationyear]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RegulationCode
				,@Regulationyear
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @regulationhdrOUT = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[RegulationHdr]
			SET  
				[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @regulationhdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Code]
				,[Name]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Code] = @Code
				,[Name] = @Name
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStudentMarks]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStudentMarks]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddStudentMarks] 
(
 @Id int
,@StudentId int
,@SemesterId varchar(20)
,@ModeOfExam varchar(50)
,@SubjectCode varchar(50)
,@Marks int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)
	as BEGIN 
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].StudentMarks(
				 StudentId
				 ,SemesterId
				 ,ModeOfExam
				 ,SubjectCode
				 ,Marks 
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@StudentId
				,@SemesterId
				,@ModeOfExam
				,@SubjectCode
				,@Marks
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())  AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())  AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				)
				END
		--ELSE
		--Begin
			--UPDATE [dbo].StudentProfile
			--SET [FirstName] = @FirstName
			--     ,SecondName=@SecondName
			--	 ,FatherName=@FatherName
			--	 ,AadharNo=@AadharNo
			--	 ,DateOfBirth=@DateOfBirth
			--	 ,Gender=@Gender
			--	 ,PhoneNo=@PhoneNo
			--	,Email=@Email
			--	,HouseNumber=@HouseNumber
			--	,StreetName=@StreetName
			--	,[Address]=@Address
			--	,City=@City
			--	,[State]=@State
			--	,Pincode=@Pincode
			--	,RollNo=@RollNo
			--	,BranchId=@BranchCode
			--	,InstituteId=@InstituteCode
			--	,[IsActive] = ISNULL(@IsActive, 1)
			--	,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
			--	,[UpdatedByUserId] = @UpdatedByUserId
			--WHERE Id = @Id
	--END 
	END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStudentProfile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStudentProfile]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddStudentProfile] 
(
 @Id int
,@FirstName varchar(100)
,@SecondName varchar(100)
,@FatherName varchar(100)
,@AadharNo varchar(12)
,@DateOfBirth date
,@Gender int
,@PhoneNo bigint
,@Email varchar(55)
,@HouseNumber varchar(50)
,@StreetName  varchar(50)
,@Address varchar(255)
,@City varchar(50)
,@State varchar(50)
,@Pincode varchar(10)
,@RollNo varchar(50)
,@BranchCode varchar(50)
,@InstituteCode varchar(50)
,@Picture varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@StudentId int output
)
 
	as BEGIN 
		IF ISNULL(@Id,0)=0
		begin
		DECLARE @BranchId int
		set @BranchId =(select Id from Branch where Code=@BranchCode) 
		DECLARE @InstituteId int
		set @InstituteId =(select Id from Institutions where InstitutePermanentId=@InstituteCode) 
			INSERT INTO [dbo].StudentProfile(
				 FirstName
				 ,SecondName
				 ,FatherName
				 ,AadharNo
				 ,DateOfBirth 
				 ,Gender
				 ,PhoneNo
				 ,Email
				 ,HouseNumber
				 ,StreetName
				 ,[Address]
				 ,City
				 ,[State]
				 ,Pincode
				 ,RollNo
				 ,BranchId
				,InstituteId
				,Picture
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@FirstName
				,@SecondName
				,@FatherName
				,@AadharNo
				,@DateOfBirth
				,@Gender
				,@PhoneNo
				,@Email
				,@HouseNumber
				,@StreetName
				,@Address
				,@City
				,@State
				,@Pincode
				,@RollNo
			    ,@BranchId
				,@InstituteId
				,@Picture
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @StudentId  = @@IDENTITY
				declare @GID varchar(255)
                set @GID =('U'+RIGHT('0000000'+CAST(@StudentId AS VARCHAR(7)),7))
                update StudentProfile set UniqueId=@GID where Id=@StudentId
				END
		--ELSE
		--Begin
			--UPDATE [dbo].StudentProfile
			--SET [FirstName] = @FirstName
			--     ,SecondName=@SecondName
			--	 ,FatherName=@FatherName
			--	 ,AadharNo=@AadharNo
			--	 ,DateOfBirth=@DateOfBirth
			--	 ,Gender=@Gender
			--	 ,PhoneNo=@PhoneNo
			--	,Email=@Email
			--	,HouseNumber=@HouseNumber
			--	,StreetName=@StreetName
			--	,[Address]=@Address
			--	,City=@City
			--	,[State]=@State
			--	,Pincode=@Pincode
			--	,RollNo=@RollNo
			--	,BranchId=@BranchCode
			--	,InstituteId=@InstituteCode
			--	,[IsActive] = ISNULL(@IsActive, 1)
			--	,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
			--	,[UpdatedByUserId] = @UpdatedByUserId
			--WHERE Id = @Id
	--END 
	END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSubjects]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSubjects]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddSubjects] 
(
 @Id int
,@Subject varchar(55)
,@SubCode varchar(55)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)

	as BEGIN 
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].Subjects(
				 Subject
				,SubCode
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			 @Subject
				,@SubCode
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				END
		ELSE
		Begin
			UPDATE [dbo].Subjects
			SET  Subject = @Subject
				,SubCode = @SubCode
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END 
	END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUniversity]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUniversity]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddUniversity] 
(
 @Id int
,@UniversityName varchar(50)
,@UniversityId varchar(100)
,@Location varchar(55)
,@Pincode int
,@EmailId varchar(55)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)

	as BEGIN 
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].University(
				 UniversityName
				,UniversityId
				,Location
				,Pincode
				,EmailId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @UniversityName
				,@UniversityId
                ,@Location
				,@Pincode
				,@EmailId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				END
		ELSE
		Begin
			UPDATE [dbo].University
			SET  UniversityName = @UniversityName
				,UniversityId = @UniversityId
				,Location=@Location
				,Pincode=@Pincode
				,EmailId=@EmailId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END 
	END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
 @Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@MiddileName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber bigint
,@RoleId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Users] (
				 [UserName]
				,[Password]
				,[FirstName]
				,[MiddileName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,[RoleId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@UserName
				,@Password
				,@FirstName
				,@MiddileName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@RoleId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Users]
			SET  
				[UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName
				,[MiddileName] = @MiddileName
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[MobileNumber] = @MobileNumber
				,[RoleId] = @RoleId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckConfigurationHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckConfigurationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_CheckConfigurationHdr] (@P_UniversityId INT,@RegualtionCodeId int)
as
begin
select * from ConfigurationHdr where UniversityId=@P_UniversityId and RegulationCodeId=@RegualtionCodeId
END

GO

-- %% [markdown]
-- # [dbo].[SP_CheckStudent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckStudent]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_CheckStudent](@StudentName varchar(50),@BranchCode varchar(50),@InstituteCode varchar(50))
as
begin
DECLARE @BranchId int
set @BranchId =(select Id from Branch where Code=@BranchCode) 
DECLARE @InstituteId int
set @InstituteId =(select Id from Institutions where InstitutePermanentId=@InstituteCode)
select count(*) count from 
StudentProfile where FirstName=@StudentName and BranchId=@BranchId
and InstituteId=@InstituteId
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetBranch]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBranch]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetBranch] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[CourseId]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Branch]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBranchByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBranchByHdrCode]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetBranchByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[CourseId]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Branch] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Code = ISNULL(@P_Code, t.Code) 
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBranchByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBranchByHdrId]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetBranchByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[CourseId]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Branch] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.CourseId = ISNULL(@P_Id, t.CourseId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBranchDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBranchDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




Create PROCEDURE [dbo].[SP_GetBranchDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[CourseId] as CourseId
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Branch] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetConfigurationDetails] (@P_Id INT)
AS
BEGIN
	SELECT * from ConfigurationScreen WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetConfigurationDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[ConfigurationHdrId]
		,[BranchId]
		,YearId
		,SubjectId
		,TypeId
		,AssessmentsId
		,LabsId
		,ProjectsId
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[ConfigurationDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDtlByBranchYear]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDtlByBranchYear]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetConfigurationDtlByBranchYear] (@P_ConfigHdrId int,@P_BranchId INT,@P_YearId INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ConfigurationHdrId]
		,t.[BranchId]
		,t.YearId
		,t.SubjectId
		,t.TypeId
		,t.AssessmentsId
		,t.LabsId
		,t.ProjectsId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].ConfigurationDtl t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.ConfigurationHdrId = @P_ConfigHdrId and t.BranchId = @P_BranchId and t.YearId=@P_YearId
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDtlByConfigHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDtlByConfigHdrId]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetConfigurationDtlByConfigHdrId](@P_ConfigurationHdrId int)
as
begin
select * from
(select u.UniversityName,b.Name BranchName,lud.Year,cast(cast(lud.Year as varchar(10))+'-'+cast(lud.Semester as varchar(10)) as varchar(255)) YearSem,x.Subjects from
(SELECT ConfigurationHdrId,BranchId,YearId ,(select STRING_AGG(Subject, '***') from Subjects where Id in (select Item from [SplitString]((STRING_AGG(SubjectId, ', ')),',') )  
) Subjects
FROM ConfigurationDtl where ConfigurationHdrId =@P_ConfigurationHdrId
GROUP BY ConfigurationHdrId,BranchId,YearId)x
inner join Branch b on b.Id = x.BranchId
inner join RegulationDtl lud on lud.Id = x.YearId
inner join ConfigurationHdr chd on chd.Id = x.ConfigurationHdrId
inner join University u on u.Id = chd.UniversityId)y
order by y.BranchName,y.YearSem
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDtlByHdrCode]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetConfigurationDtlByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ConfigurationHdrId]
		,t.[BranchId]
		,t.[YearId]
		,t.SubjectId
		,t.TypeId
		,t.AssessmentsId
		,t.LabsId
		,t.ProjectsId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[ConfigurationDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDtlByHdrId]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetConfigurationDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ConfigurationHdrId]
		,t.[BranchId]
		,t.[YearId]
		,t.SubjectId
		,t.TypeId
		,t.AssessmentsId
		,t.LabsId
		,t.ProjectsId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[ConfigurationDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.ConfigurationHdrId = ISNULL(@P_Id, t.ConfigurationHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationDtlDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetConfigurationDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ConfigurationHdrId] 
		,t.[BranchId]
		,t.YearId
		,t.SubjectId
		,t.TypeId
		,t.AssessmentsId
		,t.LabsId
		,t.ProjectsId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].ConfigurationDtl t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetConfigurationHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[UniversityId]
		,[RegulationCodeId]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[ConfigurationHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetConfigurationHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetConfigurationHdrDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetConfigurationHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id] 
		,t.[UniversityId]
		,uni.UniversityName
		,t.[RegulationCodeId]
		,l.RegulationCode
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].ConfigurationHdr t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	Inner join University uni ON uni.Id=t.UniversityId
	Inner join RegulationDtl l ON l.Id=t.RegulationCodeId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCourse]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCourse]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetCourse] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Description]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Course]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCourseDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCourseDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetCourseDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Description]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Course] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInstitutionDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInstitutionDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetInstitutionDetails] (@P_Id INT)
AS
BEGIN
SELECT
	    i.[Id]
		,i.[NameofInstitiute]
		,cast(i.AffiliatedUniversity as int) AffiliatedUniversity
		,u.UniversityName as AffiliatedUniversityName
		,i.InstitutePermanentId
		,i.Location
		,i.Pincode
	    ,i.GSTNumber
		,i.ContactNumber
		,i.ContactName
		,i.Designation
		,i.EmailId
		,i.[IsActive]
		,i.[CreatedDate]
		,i.[CreatedByUserId]
		,i.[UpdatedDate]
		,i.[UpdatedByUserId]
	FROM [dbo].[Institutions] i
	INNER JOIN dbo.University u ON u.Id = i.AffiliatedUniversity
	WHERE i.Id = ISNULL(@P_Id, i.Id)
		AND i.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[LookupHdrId]
		,[Code]
		,[Name]
		,[Remarks]
		,[Ord]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrCode]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Code = ISNULL(@P_Code, t.Code) 
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrId]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.LookupHdrId = ISNULL(@P_Id, t.LookupHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId] as LookupMstId
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		  [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdrDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetLookupHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		  t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id) and  m.ViewYN = 1
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@P_UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegulationDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegulationDtl]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetRegulationDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RegulationHdrId]
		,[RegulationCode]
		,Regulationyear
		,[Year]
		,[Semester]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RegulationDtl]
	WHERE Id = ISNULL(@P_Id, Id) 
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegulationDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegulationDtlByHdrCode]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetRegulationDtlByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[RegulationHdrId]
		,t.[RegulationCode]
		,t.[Regulationyear]
		,t.[Semester]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[RegulationDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.RegulationCode = ISNULL(@P_Code, t.RegulationCode) 
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegulationDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegulationDtlByHdrId]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetRegulationDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[RegulationHdrId]
		,t.[RegulationCode]
		,t.[Regulationyear]
		,t.[Year]
		,t.[Semester]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[RegulationDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.RegulationHdrId = ISNULL(@P_Id, t.RegulationHdrId)
		AND t.IsActive = 1 order by [Year],[Semester] asc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegulationDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegulationDtlDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetRegulationDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[RegulationHdrId] as RegulationHdrId
		,t.[RegulationCode]
		,t.Regulationyear
		,t.[Year]
		,t.[Semester]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[RegulationDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id) AND t.IsActive = 1 
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegulationHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegulationHdr]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetRegulationHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RegulationCode]
		,[Regulationyear]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RegulationHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegulationHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegulationHdrDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetRegulationHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[RegulationCode]
		,t.[Regulationyear]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[RegulationHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.ViewYN = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRolesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Roles] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStudentDataForBlockchain]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStudentDataForBlockchain]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetStudentDataForBlockchain 2
CREATE Proc [dbo].[SP_GetStudentDataForBlockchain](@StudentId int)
as
begin
declare @UID varchar(255)
set @UID =(select UniqueId from StudentProfile where Id = @StudentId)
select 
(SELECT 	
	(
		select sm.SemesterId,sm.ModeOfExam,sm.SubjectCode,sm.Marks from StudentMarks sm
        where sm.StudentId=sp.Id and sm.ModeOfExam like '%sem%' FOR JSON AUTO
	) studentmarks
	,sp.FirstName+' '+sp.SecondName as Name,sp.FatherName,sp.AadharNo,sp.Address,sp.Pincode,sp.Gender,
c.Description CourseName,i.NameofInstitiute,InstitutePermanentId,u.UniversityName,u.Location,rud.RegulationCode,
i.Picture InstituteImage,sp.Picture StudentImage,sp.Email,sp.PhoneNo
from StudentProfile sp
inner join Branch b on b.Id = sp.BranchId
inner join Course c on c.Id = b.CourseId
inner join Institutions i on i.Id = sp.InstituteId
inner join University u on u.Id = i.AffiliatedUniversity
inner join ConfigurationHdr ch on ch.UniversityId = u.Id
inner join RegulationDtl rud on rud.Id = ch.RegulationCodeId
where sp.Id=@StudentId
FOR JSON PATH)JsonObject,@UID as UId,'P0iZHIMRG8EVGm6jYA9LFx8wt81nzoQSNUvj3r2bYIxIwuGLvBjTNY1msrsg1Ud4' payload,'KSRM' Form
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStudentDetailsByMobileNoorAadharNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStudentDetailsByMobileNoorAadharNo]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_GetStudentDetailsByMobileNoorAadharNo](@MobileNo bigint,@AadharNo varchar(20))
as
begin
select Id,UniqueId from StudentProfile sp where 
sp.PhoneNo=case when @MobileNo is null then sp.PhoneNo else @MobileNo end
and 
AadharNo=case when @AadharNo is null then sp.AadharNo else @AadharNo end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStudentProfile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStudentProfile]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetStudentProfile] (@P_Id INT)
AS
BEGIN
SELECT
	    s.[Id]
		,s.[FirstName]
		,s.[SecondName]
		,s.FatherName
		,s.AadharNo
		,s.[DateOfBirth]
	    ,s.[PhoneNo]
		,s.[Email]
		,s.[HouseNumber]
		,s.[StreetName]
		,s.[Address]
		,s.City
		,s.[State]
		,s.Pincode
	    ,s.[RollNo]
		,b.Name as BranchCode
		,i.NameofInstitiute as InstituteCode
		,s.UniqueId
		,s.[IsActive]
		,s.[CreatedDate]
		,s.[CreatedByUserId]
		,s.[UpdatedDate]
		,s.[UpdatedByUserId]
	FROM [dbo].[StudentProfile] s
	INNER JOIN dbo.Branch b ON b.Id = s.BranchId
	INNER JOIN dbo.Institutions i ON i.Id = s.InstituteId
	WHERE s.Id = ISNULL(@P_Id, s.Id)
		AND s.IsActive = 1 
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetSubjectDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSubjectDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetSubjectDetails] (@P_Id INT)
AS
BEGIN


	SELECT s.Id, 
s.Subject, s.SubCode,s.IsActive,s.CreatedByUserId,s.CreatedDate,s.UpdatedDate,s.UpdatedByUserId from Subjects s 
	
	
	
	WHERE s.Id = ISNULL(@P_Id, s.Id)
		AND s.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUniversityDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUniversityDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetUniversityDetails] (@P_Id INT)
AS
BEGIN
	SELECT * from University WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsers] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[UserName]
		,[Password]
		,[FirstName]
		,[MiddileName]
		,[LastName]
		,[EmailId]
		,[MobileNumber]
		,[RoleId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Users]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsersDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[MiddileName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,c.RoleName
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Users] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:16:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNumber,
			u.Password
		FROM Users u 
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END
GO
