-- %% [markdown]
-- # [dbo].[appVersion]

-- %%
USE [ovo]
GO

-- %%
/****** Object:  Table [dbo].[appVersion]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[appVersion](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[AppName] [varchar](100) NOT NULL,
	[AppVersion] [float] NOT NULL,
	[DBVersion] [float] NULL,
	[Environment] [varchar](50) NULL,
	[AppURL] [varchar](500) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Banner]

-- %%
/****** Object:  Table [dbo].[Banner]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Banner](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](255) NULL,
	[BannerUrl] [varchar](255) NULL,
	[width] [varchar](100) NULL,
	[height] [varchar](100) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cart]

-- %%
/****** Object:  Table [dbo].[Cart]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cart](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [int] NULL,
	[ProductId] [int] NULL,
	[Qty] [int] NULL,
	[Price] [decimal](18, 2) NULL,
	[Discount] [decimal](18, 2) NULL,
	[ItemValue] [decimal](18, 2) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Category]

-- %%
/****** Object:  Table [dbo].[Category]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Category](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[Picture] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Coupons]

-- %%
/****** Object:  Table [dbo].[Coupons]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Coupons](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](10) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[Description] [varchar](1000) NULL,
	[ValidFrom] [datetime] NOT NULL,
	[ValidTo] [datetime] NOT NULL,
	[CouponType] [int] NULL,
	[TransactionType] [int] NULL,
	[MinCartValue] [float] NULL,
	[MaxDiscountUpto] [float] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CouponTransaction]

-- %%
/****** Object:  Table [dbo].[CouponTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CouponTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CouponId] [int] NOT NULL,
	[UserId] [int] NOT NULL,
	[OrderNo] [varchar](50) NOT NULL,
	[RedeemedAmount] [float] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UPdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customer]

-- %%
/****** Object:  Table [dbo].[Customer]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[MobileNo] [bigint] NOT NULL,
	[EmailId] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[FCMtoken] [varchar](3000) NULL,
	[ImgURL] [varchar](500) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[MobileNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CustomerAddress]

-- %%
/****** Object:  Table [dbo].[CustomerAddress]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CustomerAddress](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CustId] [int] NOT NULL,
	[AddressName] [varchar](100) NOT NULL,
	[Address] [varchar](4000) NOT NULL,
	[FlatNo] [varchar](255) NULL,
	[Area] [varchar](255) NULL,
	[IsDefault] [bit] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[PinCode] [varchar](10) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[CustId] ASC,
	[Address] ASC,
	[FlatNo] ASC,
	[Area] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DeliveryCharges]

-- %%
/****** Object:  Table [dbo].[DeliveryCharges]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DeliveryCharges](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Type] [varchar](255) NULL,
	[StartRange] [int] NULL,
	[EndRange] [int] NULL,
	[Charges] [decimal](18, 2) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Districts]

-- %%
/****** Object:  Table [dbo].[Districts]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Districts](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[StateId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FAQ]

-- %%
/****** Object:  Table [dbo].[FAQ]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FAQ](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Question] [varchar](3000) NULL,
	[Answer] [varchar](3000) NULL,
	[Ord] [int] NULL,
	[Category] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mandal]

-- %%
/****** Object:  Table [dbo].[Mandal]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mandal](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[DistrictId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OfferNotification]

-- %%
/****** Object:  Table [dbo].[OfferNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OfferNotification](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Description] [varchar](3000) NULL,
	[NotificationImage] [varchar](3000) NULL,
	[CreatedDate] [datetime] NULL,
	[CustomerId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderDtl]

-- %%
/****** Object:  Table [dbo].[OrderDtl]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderNo] [varchar](50) NOT NULL,
	[ProductId] [int] NOT NULL,
	[Qty] [int] NOT NULL,
	[Price] [float] NOT NULL,
	[Discount] [float] NOT NULL,
	[ItemValue] [float] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[DiscountedAmt] [float] NOT NULL,
	[Deliverycharges] [float] NULL,
 CONSTRAINT [PK_OrderDtl_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderHdr]

-- %%
/****** Object:  Table [dbo].[OrderHdr]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderNo] [varchar](50) NOT NULL,
	[OrdDate] [datetime] NOT NULL,
	[OrdValue] [float] NOT NULL,
	[Discount] [float] NOT NULL,
	[DeliveryAddressId] [int] NULL,
	[SlotId] [int] NULL,
	[Status] [varchar](50) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[IsSubscription] [bit] NULL,
	[CouponId] [int] NULL,
	[WareHouseId] [int] NULL,
	[ReasonForCancel] [varchar](255) NULL,
	[DeliveryAmount] [float] NULL,
 CONSTRAINT [PK_OrderHdr_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ__OrderHdr__C3907C7574391C71] UNIQUE NONCLUSTERED 
(
	[OrderNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ__OrderHdr__C3907C7596E6D5F2] UNIQUE NONCLUSTERED 
(
	[OrderNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderHistory]

-- %%
/****** Object:  Table [dbo].[OrderHistory]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderHistory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderId] [int] NOT NULL,
	[UserId] [int] NOT NULL,
	[OrderDate] [datetime] NOT NULL,
	[OrderList] [varchar](max) NOT NULL,
	[OrderStatus] [varchar](100) NOT NULL,
	[OrderAddressId] [int] NOT NULL,
	[CancelReason] [varchar](255) NULL,
	[UpdatedDate] [datetime] NOT NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderNotification]

-- %%
/****** Object:  Table [dbo].[OrderNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderNotification](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderNo] [varchar](255) NULL,
	[Status] [varchar](255) NULL,
	[CreatedDate] [datetime] NULL,
	[CustomerId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrderPayment]

-- %%
/****** Object:  Table [dbo].[OrderPayment]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrderPayment](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderNo] [varchar](255) NOT NULL,
	[UserId] [int] NOT NULL,
	[PaymentTypeId] [int] NOT NULL,
	[PaymentDate] [datetime] NOT NULL,
	[Amount] [decimal](18, 2) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[PaymentTransactionId] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Orders]

-- %%
/****** Object:  Table [dbo].[Orders]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Orders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [int] NOT NULL,
	[OrderDate] [datetime] NOT NULL,
	[OrderList] [varchar](max) NOT NULL,
	[OrderStatus] [varchar](100) NOT NULL,
	[OrderAddressId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[CancelReason] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PaymentMethod]

-- %%
/****** Object:  Table [dbo].[PaymentMethod]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PaymentMethod](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](255) NULL,
	[ImageURL] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Paymenttransaction]

-- %%
/****** Object:  Table [dbo].[Paymenttransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Paymenttransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PaymentId] [int] NULL,
	[TransactionId] [int] NULL,
	[Description] [varchar](255) NULL,
	[Status] [varchar](255) NULL,
	[Amount] [decimal](18, 2) NOT NULL,
	[PaymentType] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PriceList]

-- %%
/****** Object:  Table [dbo].[PriceList]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PriceList](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NULL,
	[ProductPrice] [decimal](18, 0) NULL,
	[PriceCategory] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[ProductId] ASC,
	[PriceCategory] ASC,
	[StartDate] ASC,
	[ProductPrice] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CategoryId] [int] NULL,
	[ProductName] [varchar](255) NULL,
	[Description] [varchar](255) NULL,
	[Brand] [varchar](255) NULL,
	[ProductCode] [varchar](255) NULL,
	[UomId] [int] NULL,
	[Qty] [int] NULL,
	[Picture] [varchar](255) NULL,
	[Discount] [decimal](18, 0) NULL,
	[DetailedDescription] [varchar](255) NULL,
	[OpeningStock] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Price] [decimal](18, 3) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sales]

-- %%
/****** Object:  Table [dbo].[Sales]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sales](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserId] [int] NULL,
	[OrderId] [int] NULL,
	[DateofPurchase] [datetime] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdateDate] [datetime] NULL,
	[UpdateByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Slot]

-- %%
/****** Object:  Table [dbo].[Slot]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Slot](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[StartTime] [varchar](255) NULL,
	[EndTime] [varchar](255) NULL,
	[NoOfOrders] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[Diff] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SlotDTL]

-- %%
/****** Object:  Table [dbo].[SlotDTL]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SlotDTL](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SlotHDRId] [int] NULL,
	[SlotId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SlotHDR]

-- %%
/****** Object:  Table [dbo].[SlotHDR]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SlotHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SlotDate] [date] NULL,
	[SlotRange] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[States]

-- %%
/****** Object:  Table [dbo].[States]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[States](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Stock]

-- %%
/****** Object:  Table [dbo].[Stock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Stock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NOT NULL,
	[AvailableStocks] [int] NULL,
	[TotalStocks] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StockTransaction]

-- %%
/****** Object:  Table [dbo].[StockTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StockTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NOT NULL,
	[TotalStocks] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Subscription]

-- %%
/****** Object:  Table [dbo].[Subscription]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Subscription](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CustomerId] [int] NOT NULL,
	[CustomerAddressId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[StartDate] [datetime] NOT NULL,
	[SubscribeObject] [varchar](max) NOT NULL,
	[IsPause] [bit] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[WareHouseId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UOM]

-- %%
/****** Object:  Table [dbo].[UOM]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UOM](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserAppVersions]

-- %%
/****** Object:  Table [dbo].[UserAppVersions]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserAppVersions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserID] [int] NOT NULL,
	[AppVersion] [int] NOT NULL,
	[DBVersion] [int] NULL,
	[Environment] [varchar](10) NULL,
	[ForceUpdate] [bit] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](255) NULL,
	[Password] [varchar](255) NULL,
	[RoleId] [int] NULL,
	[EmpId] [varchar](255) NULL,
	[FirstName] [varchar](255) NULL,
	[MiddleName] [varchar](255) NULL,
	[LastName] [varchar](255) NULL,
	[Email] [varchar](255) NULL,
	[MobileNo] [bigint] NULL,
	[DOJ] [datetime] NULL,
	[ViewYN] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[WareHouseId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Village]

-- %%
/****** Object:  Table [dbo].[Village]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Village](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[MandalId] [int] NULL,
	[PinCode] [varchar](100) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WalletTransaction]

-- %%
/****** Object:  Table [dbo].[WalletTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WalletTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CustomerId] [int] NULL,
	[Amount] [decimal](18, 2) NOT NULL,
	[TransactionDate] [datetime] NULL,
	[TransactionType] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[TransactionId] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouse]

-- %%
/****** Object:  Table [dbo].[WareHouse]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouse](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ContactName] [varchar](100) NULL,
	[ContactNo] [bigint] NULL,
	[Address] [varchar](1000) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouseServiceLocation]

-- %%
/****** Object:  Table [dbo].[WareHouseServiceLocation]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouseServiceLocation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[PinCode] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[PinCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouseStock]

-- %%
/****** Object:  Table [dbo].[WareHouseStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouseStock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[AvailableStock] [int] NULL,
	[TotalStock] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouseStockTranaction]

-- %%
/****** Object:  Table [dbo].[WareHouseStockTranaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouseStockTranaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[TotalStock] [int] NULL,
	[TransactionDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WebhookTransactions]

-- %%
/****** Object:  Table [dbo].[WebhookTransactions]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WebhookTransactions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[JsonObject] [varchar](3000) NOT NULL,
	[CreatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__appVersio__IsAct__0A537D18]

-- %%
ALTER TABLE [dbo].[appVersion] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__appVersio__Creat__0B47A151]

-- %%
ALTER TABLE [dbo].[appVersion] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__appVersio__Updat__0C3BC58A]

-- %%
ALTER TABLE [dbo].[appVersion] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Banner__IsActive__367C1819]

-- %%
ALTER TABLE [dbo].[Banner] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Banner__CreatedD__37703C52]

-- %%
ALTER TABLE [dbo].[Banner] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Banner__UpdatedD__3864608B]

-- %%
ALTER TABLE [dbo].[Banner] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Coupons__IsActiv__6ADAD1BF]

-- %%
ALTER TABLE [dbo].[Coupons] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Coupons__Created__6BCEF5F8]

-- %%
ALTER TABLE [dbo].[Coupons] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Coupons__Updated__6CC31A31]

-- %%
ALTER TABLE [dbo].[Coupons] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__CouponTra__IsAct__7740A8A4]

-- %%
ALTER TABLE [dbo].[CouponTransaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__CouponTra__Creat__7834CCDD]

-- %%
ALTER TABLE [dbo].[CouponTransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__CouponTra__UPdat__7928F116]

-- %%
ALTER TABLE [dbo].[CouponTransaction] ADD  DEFAULT (getdate()) FOR [UPdatedDate]
GO

-- %% [markdown]
-- # [DF__Customer__IsActi__68D28DBC]

-- %%
ALTER TABLE [dbo].[Customer] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Customer__Create__69C6B1F5]

-- %%
ALTER TABLE [dbo].[Customer] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Customer__Update__6ABAD62E]

-- %%
ALTER TABLE [dbo].[Customer] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__CustomerA__IsAct__725BF7F6]

-- %%
ALTER TABLE [dbo].[CustomerAddress] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__CustomerA__Creat__73501C2F]

-- %%
ALTER TABLE [dbo].[CustomerAddress] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__CustomerA__Updat__74444068]

-- %%
ALTER TABLE [dbo].[CustomerAddress] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__DeliveryC__IsAct__2116E6DF]

-- %%
ALTER TABLE [dbo].[DeliveryCharges] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__DeliveryC__Creat__220B0B18]

-- %%
ALTER TABLE [dbo].[DeliveryCharges] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__DeliveryC__Updat__22FF2F51]

-- %%
ALTER TABLE [dbo].[DeliveryCharges] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__FAQ__IsActive__69279377]

-- %%
ALTER TABLE [dbo].[FAQ] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__FAQ__CreatedDate__6A1BB7B0]

-- %%
ALTER TABLE [dbo].[FAQ] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__FAQ__UpdatedDate__6B0FDBE9]

-- %%
ALTER TABLE [dbo].[FAQ] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__18EBB532]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__ViewYN__19DFD96B]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__1AD3FDA4]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__1BC821DD]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__1CBC4616]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__1DB06A4F]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__OrderDtl__Qty__5A5A5133]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__Qty__5A5A5133]  DEFAULT ((0)) FOR [Qty]
GO

-- %% [markdown]
-- # [DF__OrderDtl__Price__5B4E756C]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__Price__5B4E756C]  DEFAULT ((0)) FOR [Price]
GO

-- %% [markdown]
-- # [DF__OrderDtl__Discou__5C4299A5]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__Discou__5C4299A5]  DEFAULT ((0)) FOR [Discount]
GO

-- %% [markdown]
-- # [DF__OrderDtl__ItemVa__5D36BDDE]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__ItemVa__5D36BDDE]  DEFAULT ((0)) FOR [ItemValue]
GO

-- %% [markdown]
-- # [DF__OrderDtl__IsActi__5E2AE217]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__IsActi__5E2AE217]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__OrderDtl__Create__5F1F0650]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__Create__5F1F0650]  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__OrderDtl__Update__60132A89]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__Update__60132A89]  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__OrderDtl__Discou__68C86C1B]

-- %%
ALTER TABLE [dbo].[OrderDtl] ADD  CONSTRAINT [DF__OrderDtl__Discou__68C86C1B]  DEFAULT ((0)) FOR [DiscountedAmt]
GO

-- %% [markdown]
-- # [DF__OrderHdr__OrdVal__455F344D]

-- %%
ALTER TABLE [dbo].[OrderHdr] ADD  CONSTRAINT [DF__OrderHdr__OrdVal__455F344D]  DEFAULT ((0)) FOR [OrdValue]
GO

-- %% [markdown]
-- # [DF__OrderHdr__IsActi__46535886]

-- %%
ALTER TABLE [dbo].[OrderHdr] ADD  CONSTRAINT [DF__OrderHdr__IsActi__46535886]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__OrderHdr__Create__47477CBF]

-- %%
ALTER TABLE [dbo].[OrderHdr] ADD  CONSTRAINT [DF__OrderHdr__Create__47477CBF]  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__OrderHdr__Update__483BA0F8]

-- %%
ALTER TABLE [dbo].[OrderHdr] ADD  CONSTRAINT [DF__OrderHdr__Update__483BA0F8]  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__OrderPaym__IsAct__1FEDB87C]

-- %%
ALTER TABLE [dbo].[OrderPayment] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__OrderPaym__Creat__20E1DCB5]

-- %%
ALTER TABLE [dbo].[OrderPayment] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PaymentMe__IsAct__54CB950F]

-- %%
ALTER TABLE [dbo].[PaymentMethod] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PaymentMe__Creat__55BFB948]

-- %%
ALTER TABLE [dbo].[PaymentMethod] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PaymentMe__Updat__56B3DD81]

-- %%
ALTER TABLE [dbo].[PaymentMethod] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Paymenttr__IsAct__40257DE4]

-- %%
ALTER TABLE [dbo].[Paymenttransaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Paymenttr__Creat__4119A21D]

-- %%
ALTER TABLE [dbo].[Paymenttransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Paymenttr__Updat__420DC656]

-- %%
ALTER TABLE [dbo].[Paymenttransaction] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PriceList__IsAct__7B7B4DDC]

-- %%
ALTER TABLE [dbo].[PriceList] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PriceList__Creat__7C6F7215]

-- %%
ALTER TABLE [dbo].[PriceList] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PriceList__Updat__7D63964E]

-- %%
ALTER TABLE [dbo].[PriceList] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__22751F6C]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__236943A5]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__245D67DE]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__ViewYN__25518C17]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__2645B050]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__2739D489]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__ViewYN__0E6E26BF]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__0F624AF8]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__10566F31]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Sales__IsActive__793DFFAF]

-- %%
ALTER TABLE [dbo].[Sales] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Sales__CreatedDa__7A3223E8]

-- %%
ALTER TABLE [dbo].[Sales] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Sales__UpdateDat__7B264821]

-- %%
ALTER TABLE [dbo].[Sales] ADD  DEFAULT (getdate()) FOR [UpdateDate]
GO

-- %% [markdown]
-- # [DF__Slot__IsActive__3BCADD1B]

-- %%
ALTER TABLE [dbo].[Slot] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Slot__CreatedDat__3CBF0154]

-- %%
ALTER TABLE [dbo].[Slot] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Slot__UpdatedDat__3DB3258D]

-- %%
ALTER TABLE [dbo].[Slot] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SlotDTL__IsActiv__7E8CC4B1]

-- %%
ALTER TABLE [dbo].[SlotDTL] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SlotHDR__IsActiv__78D3EB5B]

-- %%
ALTER TABLE [dbo].[SlotHDR] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Stock__IsActive__1BE81D6E]

-- %%
ALTER TABLE [dbo].[Stock] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Stock__CreatedDa__1CDC41A7]

-- %%
ALTER TABLE [dbo].[Stock] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Stock__UpdatedDa__1DD065E0]

-- %%
ALTER TABLE [dbo].[Stock] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__StockTran__IsAct__2759D01A]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__StockTran__Creat__284DF453]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__StockTran__Updat__2942188C]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Subscript__IsAct__2D12A970]

-- %%
ALTER TABLE [dbo].[Subscription] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Subscript__Creat__2E06CDA9]

-- %%
ALTER TABLE [dbo].[Subscription] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Subscript__Updat__2EFAF1E2]

-- %%
ALTER TABLE [dbo].[Subscription] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__UOM__IsActive__3B75D760]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__UOM__CreatedDate__3C69FB99]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__UOM__UpdatedDate__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__UserAppVe__IsAct__02E7657A]

-- %%
ALTER TABLE [dbo].[UserAppVersions] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__UserAppVe__Creat__03DB89B3]

-- %%
ALTER TABLE [dbo].[UserAppVersions] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__UserAppVe__Updat__04CFADEC]

-- %%
ALTER TABLE [dbo].[UserAppVersions] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WalletTra__IsAct__59E54FE7]

-- %%
ALTER TABLE [dbo].[WalletTransaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WalletTra__Creat__5AD97420]

-- %%
ALTER TABLE [dbo].[WalletTransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WalletTra__Updat__5BCD9859]

-- %%
ALTER TABLE [dbo].[WalletTransaction] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__IsAct__4D4A6ED8]

-- %%
ALTER TABLE [dbo].[WareHouse] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WareHouse__Creat__4E3E9311]

-- %%
ALTER TABLE [dbo].[WareHouse] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Updat__4F32B74A]

-- %%
ALTER TABLE [dbo].[WareHouse] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__IsAct__469D7149]

-- %%
ALTER TABLE [dbo].[WareHouseServiceLocation] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WareHouse__Creat__47919582]

-- %%
ALTER TABLE [dbo].[WareHouseServiceLocation] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Updat__4885B9BB]

-- %%
ALTER TABLE [dbo].[WareHouseServiceLocation] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__IsAct__57C7FD4B]

-- %%
ALTER TABLE [dbo].[WareHouseStock] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WareHouse__Creat__58BC2184]

-- %%
ALTER TABLE [dbo].[WareHouseStock] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Updat__59B045BD]

-- %%
ALTER TABLE [dbo].[WareHouseStock] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__IsAct__5B988E2F]

-- %%
ALTER TABLE [dbo].[WareHouseStockTranaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WareHouse__Creat__5C8CB268]

-- %%
ALTER TABLE [dbo].[WareHouseStockTranaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Updat__5D80D6A1]

-- %%
ALTER TABLE [dbo].[WareHouseStockTranaction] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WebhookTr__Creat__2354350C]

-- %%
ALTER TABLE [dbo].[WebhookTransactions] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [FK_Menu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Menu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK_OrderDtl_ProductId]

-- %%
ALTER TABLE [dbo].[OrderDtl]  WITH CHECK ADD  CONSTRAINT [FK_OrderDtl_ProductId] FOREIGN KEY([ProductId])
REFERENCES [dbo].[Product] ([Id])
GO
ALTER TABLE [dbo].[OrderDtl] CHECK CONSTRAINT [FK_OrderDtl_ProductId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK__Roles__CreatedBy__114A936A]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK_Roles_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Roles_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_UpdatedByUserId]
GO

-- %% [markdown]
-- # [CK__WareHouse__PinCo__4979DDF4]

-- %%
ALTER TABLE [dbo].[WareHouseServiceLocation]  WITH CHECK ADD CHECK  (([PinCode]>=(6)))
GO

-- %% [markdown]
-- # [dbo].[SlotDetailsByTime]

-- %%
/****** Object:  StoredProcedure [dbo].[SlotDetailsByTime]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SlotDetailsByTime '10:47'
CREATE Proc [dbo].[SlotDetailsByTime](@time varchar(255))
as
begin
--select s.Id,s.StartTime,s.EndTime,s.StartTime+'-'+s.EndTime Slot,s.NoOfOrders,s.IsActive,s.CreatedDate,s.CreatedByUserId,
--s.UpdatedDate,s.UpdatedByUserId,(s.NoOfOrders-isnull(od.cnt,0)) AvailableSlots from Slot s
--left join (Select SlotId,COUNT(SlotId) cnt from OrderHdr group by SlotId) od on od.SlotId = s.Id
--where cast(s.StartTime as time)>=@time

--select sd.SlotHDRId,sd.SlotId,sh.SlotDate,s.StartTime+'-'+s.EndTime Slot,s.NoOfOrders,(s.NoOfOrders - isnull(oh.SlotCount,0)) Available 
--from SlotDTL sd
--inner join SlotHDR sh on sh.Id = sd.SlotHDRId
--inner join Slot s on s.Id = sd.SlotId
--left join 
--(select count(*) SlotCount,SlotId from  OrderHdr where 
--cast(OrdDate as date) = cast(getdate() as date) group by SlotId) oh on oh.SlotId = sd.SlotId
--where sh.SlotDate =cast(getdate() as date) and cast(s.StartTime as time)>=@time and sd.IsActive=1
--order by s.StartTime

select sd.SlotHDRId,sd.SlotId,sh.SlotDate,s.StartTime+'-'+s.EndTime Slot,s.NoOfOrders,(s.NoOfOrders - isnull(oh.SlotCount,0)) Available 
from SlotDTL sd
inner join SlotHDR sh on sh.Id = sd.SlotHDRId
inner join Slot s on s.Id = sd.SlotId
left join 
(select count(*) SlotCount,SlotId from  OrderHdr where 
cast(OrdDate as date) = cast(getdate() as date) group by SlotId) oh on oh.SlotId = sd.SlotId
where  cast(s.StartTime as time)>=@time and sd.IsActive=1 and sh.SlotDate >=cast(getdate() as date) and
sh.SlotDate <=cast(getdate()+1 as date)
order by sh.SlotDate,sd.SlotId,s.StartTime

end

--exec SlotDetailsByTime '02:11 PM'
GO

-- %% [markdown]
-- # [dbo].[SP_AddAutoOrderDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddAutoOrderDtl]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddAutoOrderDtl] (
	@Id INT = NULL
	,@OrderNo varchar(50)
	,@ProductId int
	,@Qty int
	,@Price float
	,@Discount float
	,@ItemValue float
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@DiscountedAmt float
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
	)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].[OrderDtl] (
				 OrderNo
			    ,[ProductId]
			    ,[Qty]
			    ,[Price]
			    ,[Discount]
			    ,[ItemValue]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[DiscountedAmt]
				)
			VALUES (
				 @OrderNo
				,@ProductId
				,@Qty
				,@Price
				,@Discount
				,@ItemValue
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@DiscountedAmt
				)
			    --update Stock set AvailableStocks=AvailableStocks-@Qty where ProductId=@ProductId
				 declare @WarehouseId int
			   set @WarehouseId = (select WareHouseId from OrderHdr where OrderNo =@OrderNo)
			   update WareHouseStock set AvailableStock=AvailableStock-@Qty where ProductId=@ProductId and WareHouseId = @WarehouseId
				 --Removed in Cart Items after Ordered Placed
				 delete from Cart where ProductId=@ProductId and CreatedByUserId=@CreatedByUserId
				end
		ELSE
			UPDATE [dbo].[OrderDtl]
			SET  OrderNo = @OrderNo
			    ,[ProductId] = @ProductId
			    ,[Qty] = @Qty
			    ,[Price] = @Price
			    ,[Discount] = @Discount
			    ,[ItemValue] = @ItemValue
				,[IsActive] = @IsActive
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
				,[DiscountedAmt] =@DiscountedAmt
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddAutoOrderHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddAutoOrderHdr]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddAutoOrderHdr] (
	@Id INT = NULL
	,@OrdDate datetime
	,@OrdValue float
	,@Discount float
	,@DeliveryAddressId int
	,@SlotId int
	,@WareHouseId Int
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@IsSubscription bit
	,@OrderNo varchar(255) output
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
	)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[OrderHdr] (
			[OrderNo],
				 [OrdDate] 
			    ,[OrdValue]
				,Discount
				,[DeliveryAddressId]
				,[SlotId]
				,WareHouseId
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,IsSubscription
				)
			VALUES (
				'1',
				 @OrdDate
				,@OrdValue
				,@Discount
				,@DeliveryAddressId
				,@SlotId
				,@WareHouseId
				,'Placed'
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@IsSubscription
				)

				declare @Out int
				set @Out = @@IDENTITY

				update OrderHdr set 
				OrderNo =(REPLACE(CONVERT(CHAR(10), getdate(), 103), '/', '')+''+format(@Out,'0000'))
				where Id = @Out
				set @OrderNo = (REPLACE(CONVERT(CHAR(10), getdate(), 103), '/', '')+''+format(@Out,'0000'))
				end
		ELSE
		begin
			UPDATE [dbo].[OrderHdr]
			SET  
			     [OrdDate] = @OrdDate
			    ,[OrdValue] = @OrdValue
				,Discount=@Discount
				,DeliveryAddressId = @DeliveryAddressId
				,SlotId = @SlotId
				,[IsActive] = @IsActive
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @OrderNo = ''
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddAutoOrderPayment]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddAutoOrderPayment]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_AddAutoOrderPayment]
(
@Id int,
@OrderNo varchar(255),
@UserId int,
@PaymentTypeId int,
@PaymentDate datetime,
@Amount decimal(18,2),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@PaymentTransactionId varchar(255)
) 
as
begin
    if ISNULL(@Id,0) = 0
	begin
	   insert into OrderPayment
	   (OrderNo
	   ,UserId
	   ,PaymentTypeId
	   ,PaymentDate
	   ,Amount
	   ,IsActive
	   ,CreatedDate
	   ,CreatedByUserId
	   ,UpdatedDate
	   ,UpdatedByUserId 
	   ,PaymentTransactionId
	   )
	   values
	   (
	   @OrderNo
	   ,@UserId
	   ,@PaymentTypeId
	   ,@PaymentDate
	   ,@Amount
	   ,@IsActive
	   ,@CreatedDate
	   ,@CreatedByUserId
	   ,@UpdatedDate
	   ,@UpdatedByUserId
	   ,@PaymentTransactionId
	   )
	  --Removed in Cart Items after Ordered Placed
	  --delete from Cart where ProductId in 
	  --(select ProductId from OrderDtl where OrderNo = @OrderNo) and CreatedByUserId=@UserId
	end
end


GO

-- %% [markdown]
-- # [dbo].[SP_AddAutoWalletTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddAutoWalletTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddAutoWalletTransaction]
(@Id int
,@CustomerId int
,@Amount decimal(18,2)
,@TransactionDate datetime
,@TransactionType int
,@TransactionId varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorMessage varchar(3000) output
)
as
begin
If isnull(@Id,0)=0
begin
If @TransactionType = 1
begin
  If @TransactionId != 'Id'
  begin
insert into WalletTransaction(
    CustomerId
	,Amount
	,TransactionDate
	,TransactionType
	,TransactionId
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId

)
values(
	@CustomerId
	,@Amount
	,@TransactionDate 
	,@TransactionType
	,@TransactionId
	,@IsActive
	,@CreatedDate 
	,@CreatedByUserId
	,@UpdatedDate 
	,@UpdatedByUserId
)
  end
set @ErrorMessage = ''
end
else If @TransactionType = -1
begin
 declare @Credit float,@Debit float,@RemainingAmount float 
set @Credit =(select sum(Amount) from WalletTransaction where CustomerId=@CustomerId and TransactionType=1)
set @Debit =(select isnull(sum(Amount),0) from WalletTransaction where CustomerId=@CustomerId and TransactionType=-1)
set @RemainingAmount = @Credit - @Debit
If @RemainingAmount >0
begin
insert into WalletTransaction(
    CustomerId
	,Amount
	,TransactionDate 
	,TransactionType
	,TransactionId
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId

)
values(
	@CustomerId
	,@Amount
	,@TransactionDate
	,@TransactionType
	,@TransactionId
	,@IsActive
	,@CreatedDate 
	,@CreatedByUserId
	,@UpdatedDate 
	,@UpdatedByUserId
)
set @ErrorMessage = ''
end
else
begin
set @ErrorMessage = 'negative balance'
end
end
end
--else
--begin
--update WalletTransaction Set CustomerId=@CustomerId,
--Amount=@Amount,TransactionDate=@TransactionDate,TransactionType=@TransactionType,TransactionId=@TransactionId
--,@IsActive=@IsActive where Id=@Id end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddBanner]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBanner]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddBanner]
(@Id int,
 @Code varchar(50),
 @Name varchar(255),
 @BannerUrl varchar(255),
 @width varchar(100),
 @height varchar (100),
 @IsActive bit,
 @CreatedByUserId int,
 @CreatedDate datetime,
 @UpdatedByUserId int,
 @UpdatedDate datetime
 
)
as
begin
	If isnull(@Id,0)=0
	begin
	insert into Banner(
	Code,
	Name,
	BannerUrl ,
    width ,
    height,
	IsActive,
	CreatedByUserId,
	CreatedDate,
	UpdatedByUserId,
	UpdatedDate
	)
	values(
	@Code,
	@Name,
	@BannerUrl ,
    @width,
    @height ,
	@IsActive,
	@CreatedByUserId,
	@CreatedDate,
	@UpdatedByUserId,
	@UpdatedDate
	)
	
	end
	else
	begin
	update Banner Set Code=@Code,Name=@Name,BannerUrl=@BannerUrl,width=@width,height=@height,IsActive=@IsActive,UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
	
	end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddCart]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCart]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_AddCart @UserId=1,@ProductId=1,@Qty=5,@Price=1,@Discount=0.1,@ItemValue=9.9,@Flag='plus',@IsActive=1,@CreatedByUserId=1,@CreatedDate='2022-11-08',@UpdatedByUserId=1,@UpdatedDate='2022-11-08'
CREATE Procedure [dbo].[SP_AddCart]
(
 @UserId Int,
 @ProductId Int,
 @Qty Int,
 @Price float,
 @Discount float,
 @ItemValue float,
 @Flag varchar(50),
 @IsActive bit,
 @CreatedByUserId int,
 @CreatedDate datetime,
 @UpdatedByUserId int,
 @UpdatedDate datetime
 
)
as
begin

IF not EXISTS (select * from Cart where IsActive=1 and UserId=@UserId and ProductId=@ProductId)
begin
insert into Cart(
	UserId,
	ProductId,
	Qty,
    Price ,
	Discount,
	ItemValue,
    IsActive,
	CreatedByUserId,
	CreatedDate,
	UpdatedByUserId,
	UpdatedDate
	)
	values(
	@UserId,
	@ProductId,
	@Qty,
    @Price ,
	@Discount,
	@ItemValue,
    isnull(@IsActive,1),
	@CreatedByUserId,
	--isnull(@CreatedDate,getdate()),
	isnull(@CreatedDate,GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
	@UpdatedByUserId,
	isnull(@UpdatedDate,GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	)
end
else
begin
    if @Flag = 'plus'
	begin
	update Cart Set Qty=Qty+1,ItemValue=@ItemValue where ProductId=@ProductId and UserId = @UserId
	end
	else if @Flag = 'minus'
	begin
	update Cart Set Qty =(case when Qty = 0 then 0 else Qty-1 end),ItemValue=@ItemValue
	where ProductId=@ProductId and UserId = @UserId
	end
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCategory]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddCategory]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@Picture varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into Category(
Code,
Name,
Picture,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@Picture,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update Category Set Code=@Code,Name=@Name,Picture=@Picture,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddCoupons]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCoupons]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddCoupons]
(
@Id int,
@Code varchar(10),
@Name varchar(255),
@Description varchar(1000),
@ValidFrom datetime,
@ValidTo datetime,
@CouponType int,
@TransactionType int,
@MinCartValue float,
@MaxDiscountUpto float,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into Coupons(
Code,
Name,
Description,
ValidFrom,
ValidTo,
CouponType,
TransactionType,
MinCartValue,
MaxDiscountUpto,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@Description,
ISNULL(@ValidFrom, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
ISNULL(@ValidTo, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
@CouponType,
@TransactionType,
@MinCartValue,
@MaxDiscountUpto,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update Coupons Set Code=@Code,Name=@Name,Description=@Description,ValidFrom=@ValidFrom,ValidTo=@ValidTo,
CouponType=@CouponType,TransactionType=@TransactionType,MinCartValue=@MinCartValue,MaxDiscountUpto=@MaxDiscountUpto,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddCouponTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCouponTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddCouponTransaction]
(@Id int,
@CouponId int,
@UserId int,
@OrderNo varchar(50),
@RedeemedAmount float,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into CouponTransaction(
CouponId,
UserId,
OrderNo,
RedeemedAmount,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@CouponId,
@UserId,
@OrderNo,
@RedeemedAmount,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update CouponTransaction Set CouponId=@CouponId,UserId=@UserId,OrderNo=@OrderNo,RedeemedAmount=@RedeemedAmount
,@IsActive=@IsActive,UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddCustomer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCustomer]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddCustomer]
(@Id int,
@Name varchar(255),
@EmailId varchar(255),
@MobileNo bigInt,
@FCMtoken varchar(3000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into Customer(
Name,
MobileNo,
EmailId,
FCMtoken,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Name,
@MobileNo,
@EmailId,
@FCMtoken,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update Customer Set Name=@Name,EmailId=@EmailId,FCMtoken=@FCMtoken,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddCustomerAddress]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCustomerAddress]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_AddCustomerAddress]
(
  @Id int
 ,@CustId int
 ,@AddressName varchar(100)
 ,@Address varchar(4000)
 ,@FlatNo varchar(255)
 ,@Area varchar(255)
 ,@PinCode varchar(10)
 ,@IsDefault bit
 ,@IsActive bit
 ,@CreatedDate datetime
 ,@CreatedByUserId int
 ,@UpdatedDate datetime
 ,@UpdatedByUserId int
)
as 
begin
if isnull(@Id,0) = 0
begin
if @IsDefault =1
begin
 update CustomerAddress set IsDefault=0 where CustId=@CustId
end
insert into CustomerAddress
(
  CustId
 ,AddressName
 ,Address
 ,FlatNo
 ,Area
 ,PinCode
 ,IsDefault
 ,IsActive
 ,CreatedDate
 ,CreatedByUserId
 ,UpdatedDate
 ,UpdatedByUserId
)
values
(
 @CustId
,@AddressName
,@Address
,@FlatNo
,@Area
,@PinCode
,@IsDefault
,@IsActive
,@CreatedDate
,@CreatedByUserId
,@UpdatedDate
,@UpdatedByUserId
)
end
else
begin
if @IsDefault =1
begin
 update CustomerAddress set IsDefault=0 where CustId=@CustId
end
update CustomerAddress set 
 AddressName=@AddressName
,Address = @Address
,FlatNo = @FlatNo
,Area=@Area
,PinCode = @PinCode
,IsDefault = @IsDefault
,IsActive = @IsActive
,UpdatedByUserId=@UpdatedByUserId
where Id = @Id
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddDeliveryCharges]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDeliveryCharges]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddDeliveryCharges]
(@Id int,
 @Code varchar(255),
 @Type varchar(255),
 @StartRange int,
 @EndRange int,
 @Charges varchar(255),
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as begin
	If isnull(@Id,0)=0
	begin
	insert into DeliveryCharges(
	Code,
	Type,
	StartRange,
	EndRange,
	Charges,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	values(
	@Code,
	@Type,
	@StartRange,
	@EndRange,
	@Charges,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId
	)
	end

else
begin
update DeliveryCharges Set Type=@Type,StartRange=@StartRange,EndRange=@EndRange,
Charges=@Charges,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddDistricts]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDistricts]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 CREATE Procedure [dbo].[SP_AddDistricts]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@StateId Int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime

)
as
begin
If isnull(@Id,0)=0
begin
insert into Districts(
Code,
Name,
StateId,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@StateId,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)

end

begin
update Districts Set Code=@Code,Name=@Name,StateId=@StateId,@IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddFAQ]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFAQ]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddFAQ]
(@Id int
,@Question varchar(3000)
,@Answer varchar(3000)
,@Ord int
,@Category varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)
as
begin
If isnull(@Id,0)=0
begin
insert into FAQ(
    Question
	,Answer
	,Ord
	,Category
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId

)
values(
	@Question
	,@Answer
	,@Ord
	,@Category
	,@IsActive
	,@CreatedDate
	,@CreatedByUserId
	,@UpdatedDate
	,@UpdatedByUserId
)
end
else
begin
update FAQ Set Question=@Question,
Answer =@Answer ,
Ord = @Ord,
Category=@Category,
@IsActive=@IsActive where Id=@Id end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddMandals]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMandals]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Procedure [dbo].[SP_AddMandals]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@DistrictId Int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@MandalOutId int output
)
as
begin
If isnull(@Id,0)=0
begin
insert into Mandal(
Code,
Name,
DistrictId,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@DistrictId,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @MandalOutId=@@IDENTITY
end
else
begin
update Mandal Set Code=@Code,Name=@Name,DistrictId=@DistrictId,@IsActive=@IsActive where Id=@Id
end
end


GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddOfferNotification]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOfferNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddOfferNotification]
(@Id int
,@Description varchar(3000)
,@NotificationImage varchar(3000)
,@CreatedDate datetime
,@CustomerId int
)
as
begin
If isnull(@Id,0)=0
begin
insert into OfferNotification(
	Description
	,NotificationImage
	,CreatedDate
	,CustomerId
)
values(
	@Description
	,@NotificationImage
	,@CreatedDate
	,@CustomerId
)
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddOrderDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrderDtl]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddOrderDtl] (
	@Id INT = NULL
	,@OrderNo varchar(50)
	,@ProductId int
	,@Qty int
	,@Price float
	,@Discount float
	,@ItemValue float
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@DiscountedAmt float
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
	)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].[OrderDtl] (
				 OrderNo
			    ,[ProductId]
			    ,[Qty]
			    ,[Price]
			    ,[Discount]
			    ,[ItemValue]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[DiscountedAmt]
				)
			VALUES (
				 @OrderNo
				,@ProductId
				,@Qty
				,@Price
				,@Discount
				,@ItemValue
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,@DiscountedAmt
				)
			   -- update Stock set AvailableStocks=AvailableStocks-@Qty where ProductId=@ProductId
			   declare @WarehouseId int
			   set @WarehouseId = (select WareHouseId from OrderHdr where OrderNo =@OrderNo)
			   update WareHouseStock set AvailableStock=AvailableStock-@Qty where ProductId=@ProductId and WareHouseId = @WarehouseId 
				 --Removed in Cart Items after Ordered Placed
				delete from Cart where ProductId=@ProductId and CreatedByUserId=@CreatedByUserId
				end
		ELSE
			UPDATE [dbo].[OrderDtl]
			SET  OrderNo = @OrderNo
			    ,[ProductId] = @ProductId
			    ,[Qty] = @Qty
			    ,[Price] = @Price
			    ,[Discount] = @Discount
			    ,[ItemValue] = @ItemValue
				,[IsActive] = @IsActive
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
				,[DiscountedAmt] =@DiscountedAmt
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddOrderHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrderHdr]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddOrderHdr] (
	@Id INT = NULL
	,@OrdDate datetime
	,@OrdValue float
	,@Discount float
	,@DeliveryAddressId int
	,@SlotId int
	,@WareHouseId Int
	,@CouponId int
	,@IsActive BIT = 1
	,@DeliveryAmount float
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@IsSubscription bit
	,@OrderNo varchar(255) output
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
	)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[OrderHdr] (
			[OrderNo],
				 [OrdDate] 
			    ,[OrdValue]
				,Discount
				,[DeliveryAddressId]
				,[SlotId]
				,WareHouseId
				,[CouponId]
				,[Status]
				,[IsActive]
				,[ReasonForCancel]
				,DeliveryAmount
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,IsSubscription
				)
			VALUES (
				'1',
				 @OrdDate 
				,@OrdValue
				,@Discount
				,@DeliveryAddressId
				,@SlotId
				,@WareHouseId
				,@CouponId
				,'Placed'
				,ISNULL(@IsActive, 1)
				,'NA'
				,@DeliveryAmount
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				--,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				--,ISNULL(@UpdatedDate, GETDATE()) 
				,@UpdatedByUserId
				,@IsSubscription
				)

				declare @Out int
				set @Out = @@IDENTITY

				update OrderHdr set 
				OrderNo =(REPLACE(CONVERT(CHAR(10), getdate(), 103), '/', '')+''+format(@Out,'0000'))
				where Id = @Out
				set @OrderNo = (REPLACE(CONVERT(CHAR(10), getdate(), 103), '/', '')+''+format(@Out,'0000'))
				end
		ELSE
		begin
			UPDATE [dbo].[OrderHdr]
			SET  
			     [OrdDate] = @OrdDate
			    ,[OrdValue] = @OrdValue
				,Discount=@Discount
				,DeliveryAddressId = @DeliveryAddressId
				,SlotId = @SlotId
				,WareHouseId = @WareHouseId
				,CouponId = @CouponId
				,[IsActive] = @IsActive
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @OrderNo = ''
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddOrderNotification]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrderNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddOrderNotification]
(@Id int
,@OrderNo varchar(255)
,@Status varchar(255)
,@CreatedDate datetime
,@CustomerId int
)
as
begin
If isnull(@Id,0)=0
begin
insert into OrderNotification(
	OrderNo
	,Status
	,CreatedDate
	,CustomerId
)
values(
	@OrderNo
	,@Status
	,@CreatedDate
	,@CustomerId
)
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddOrderPayment]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrderPayment]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_AddOrderPayment]
(
@Id int,
@OrderNo varchar(255),
@UserId int,
@PaymentTypeId int,
@PaymentDate datetime,
@Amount decimal(18,2),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@PaymentTransactionId varchar(255)
) 
as
begin
    if ISNULL(@Id,0) = 0
	begin
	   insert into OrderPayment
	   (OrderNo
	   ,UserId
	   ,PaymentTypeId
	   ,PaymentDate
	   ,Amount
	   ,IsActive
	   ,CreatedDate
	   ,CreatedByUserId
	   ,UpdatedDate
	   ,UpdatedByUserId 
	   ,PaymentTransactionId
	   )
	   values
	   (
	   @OrderNo
	   ,@UserId
	   ,@PaymentTypeId
	   ,@PaymentDate
	   ,@Amount
	   ,@IsActive
	   ,@CreatedDate
	   ,@CreatedByUserId
	   ,@UpdatedDate
	   ,@UpdatedByUserId
	   ,@PaymentTransactionId
	   )
	  --Removed in Cart Items after Ordered Placed
	  --delete from Cart where ProductId in 
	  --(select ProductId from OrderDtl where OrderNo = @OrderNo) and CreatedByUserId=@UserId
	end
end


GO

-- %% [markdown]
-- # [dbo].[SP_AddOrders]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrders]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[SP_AddOrders]
(
 @Id int
 ,@UserId int
 ,@OrderDate datetime
 ,@OrderList varchar(max)
 ,@OrderStatus varchar(255)
 ,@OrderAddressId int
 ,@IsActive bit
 ,@CreatedDate datetime
 ,@CreatedByUserId int
 ,@UpdatedDate datetime
 ,@UpdatedByUserId int
 ,@CancelReason varchar(255)
)
as 
begin
if isnull(@Id,0) = 0
begin
insert into Orders
(
 UserId
 ,OrderDate
 ,OrderList
 ,OrderStatus
 ,OrderAddressId
 ,IsActive
 ,CreatedDate
 ,CreatedByUserId
 ,UpdatedDate
 ,UpdatedByUserId
 ,CancelReason
)
values
(
@UserId
,@OrderDate
,@OrderList
,@OrderStatus
,@OrderAddressId
,@IsActive
,@CreatedDate
,@CreatedByUserId
,@UpdatedDate
,@UpdatedByUserId
,@CancelReason
)
end
else
begin
update Orders set 
 OrderList=@OrderList
,OrderStatus = @OrderStatus
,OrderAddressId = @OrderAddressId
,UpdatedDate=@UpdatedDate
,UpdatedByUserId=@UpdatedByUserId
,CancelReason = @CancelReason
where Id = @id
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddPaymentMethod]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPaymentMethod]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--select * from PaymentMethod

CREATE proc [dbo].[SP_AddPaymentMethod]
(
@Id int
,@Code varchar(255)
,@Name varchar(255)
,@ImageURL varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)
as
begin
 if ISNULL(@Id,0) = 0
 begin
   insert into PaymentMethod
   (
    Code
	,Name
	,ImageURL
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId
    )
	values
	(
	@Code
	,@Name
	,@ImageURL
	,@IsActive
	,@CreatedDate
	,@CreatedByUserId
	,@UpdatedDate
	,@UpdatedByUserId
	)

 end
 else
	begin
	if SUBSTRING(@ImageURL, 1, 5) = 'https'
	begin
	update PaymentMethod
	Set Code=@Code,
Name =@Name ,
ImageURL = @ImageURL,
IsActive=@IsActive where Id=@Id
	end
	else
	begin
	update 
	PaymentMethod
	Set Code=@Code,
Name =@Name,
IsActive=@IsActive where Id=@Id
	end
	end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddPaymenttransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPaymenttransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddPaymenttransaction]
(@Id int
,@PaymentId int
,@TransactionId int
,@Description varchar(255)
,@Status varchar(255)
,@Amount decimal(18,2)
,@PaymentType varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)
as
begin
If isnull(@Id,0)=0
begin
insert into Paymenttransaction(
    PaymentId
	,TransactionId
	,Description
	,Status
	,Amount
	,PaymentType
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId

)
values(
	@PaymentId
	,@TransactionId
	,@Description
	,@Status
	,@Amount
	,@PaymentType
	,@IsActive
	,@CreatedDate
	,@CreatedByUserId
	,@UpdatedDate
	,@UpdatedByUserId
)
end
else
begin
update Paymenttransaction Set PaymentId=@PaymentId,
TransactionId =@TransactionId ,
Description = @Description,
Status=@Status,
Amount=@Amount,
PaymentType=@PaymentType,@IsActive=@IsActive where Id=@Id end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddPriceList]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPriceList]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddPriceList]
(@Id int,
@ProductId Int,
@ProductPrice Decimal,
@StartDate datetime,
@EndDate datetime,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime

)
as
begin
If isnull(@Id,0)=0
begin
insert into PriceList(
ProductId ,
ProductPrice ,
PriceCategory ,
StartDate,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProductId ,
@ProductPrice ,
'Regular' ,
@StartDate,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
	begin
	--update PriceList Set ProductId=@ProductId,ProductPrice=@ProductPrice,
	--PriceCategory='Regular',StartDate=@StartDate,EndDate=@EndDate,@IsActive=@IsActive 
	--where Id=@Id

    update PriceList Set EndDate=@EndDate
	where Id=@Id
	insert into PriceList(
ProductId ,
ProductPrice ,
PriceCategory ,
StartDate,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProductId ,
@ProductPrice ,
'Regular' ,
@StartDate,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
	end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProduct]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddProduct]
(@Id int ,
@CategoryId Int,
@ProductName varchar(255),
@Description varchar(255),
@Brand varchar (255),
@ProductCode varchar(255),
@UomId Int,
@Qty int,
@Price Decimal (18,3),
@Picture varchar(255),
@Discount decimal,
@DetailedDescription varchar(255),
@OpeningStock int,
@IsActive bit ,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into Product(
CategoryId,
ProductName ,
Description,
Brand ,
ProductCode,
UomId ,
Qty ,
Price,
Picture ,
Discount ,
DetailedDescription,
OpeningStock,
IsActive ,
CreatedByUserId ,
CreatedDate ,
UpdatedByUserId ,
UpdatedDate
)
values(
@CategoryId,
@ProductName ,
@Description,
@Brand ,
@ProductCode,
@UomId ,
@Qty ,
@Price,
@Picture ,
@Discount ,
@DetailedDescription,
@OpeningStock,
@IsActive ,
@CreatedByUserId ,
@CreatedDate ,
@UpdatedByUserId ,
@UpdatedDate
)
declare @OutId int
set @OutId =@@IDENTITY
insert into Stock (ProductId,AvailableStocks,TotalStocks,IsActive,CreatedByUserId,CreatedDate,
UpdatedByUserId,UpdatedDate) values(@OutId,@OpeningStock,@OpeningStock,@IsActive,@CreatedByUserId,@CreatedDate,@UpdatedByUserId,@UpdatedDate)

insert into StockTransaction (ProductId,TotalStocks,IsActive,CreatedByUserId,CreatedDate,
UpdatedByUserId,UpdatedDate) values(@OutId,@OpeningStock,@IsActive,@CreatedByUserId,@CreatedDate,@UpdatedByUserId,@UpdatedDate)
end
else
	begin
	if SUBSTRING(@Picture, 1, 5) = 'https'
	begin
	update Product Set CategoryId=@CategoryId,
ProductName =@ProductName ,
Description=@Description,
Brand=@Brand ,
ProductCode=@ProductCode,
UomId=@UomId ,
Qty=@Qty ,
Price =@Price,
Picture=@Picture ,
Discount=@Discount ,
DetailedDescription=@DetailedDescription,
IsActive=@IsActive where Id=@Id
	end
	else
	begin
	update Product Set CategoryId=@CategoryId,
ProductName =@ProductName ,
Description=@Description,
Brand=@Brand ,
ProductCode=@ProductCode,
UomId=@UomId ,
Qty=@Qty ,
Price = @Price,
Discount=@Discount ,
DetailedDescription=@DetailedDescription,
IsActive=@IsActive where Id=@Id
	end
	end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddRoles]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@ViewYN bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@RolesOutId int output
)
as
begin
If isnull(@Id,0)=0
begin
insert into Roles(
Code,
Name,
ViewYN,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@ViewYN,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @RolesOutId=@@IDENTITY
end
else
begin
update Roles Set Code=@Code,Name=@Name,ViewYN=@ViewYN where Id=@Id



end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddSales]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSales]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_AddSales]
(@Id int
,@UserId int
,@ProductId int
,@DateofPurchase datetime
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdateDate datetime
,@UpdateByUserId int
)
as
begin
if isnull(@Id,0) = 0
begin
insert into Sales
(
  UserId
  ,ProductId
  ,DateofPurchase
  ,IsActive
  ,CreatedDate
  ,CreatedByUserId
  ,UpdateDate
  ,UpdateByUserId
)
values
(
@UserId
,@ProductId
,@DateofPurchase
,@IsActive
,@CreatedDate
,@CreatedByUserId
,@UpdateDate
,@UpdateByUserId
)
end
else
begin
  update Sales 
  set 
   UserId = @UserId
  ,ProductId=@ProductId
  ,DateofPurchase = @DateofPurchase
  ,IsActive = @IsActive
  ,UpdateDate = @UpdateDate
  ,UpdateByUserId = @UpdateByUserId
  where Id = @Id
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddSlot]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSlot]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_AddSlot]
(
 @Id int
 ,@StartTime varchar(255)
 ,@EndTime varchar(255)
 ,@NoOfOrders int
 ,@IsActive bit
 ,@CreatedDate datetime
 ,@CreatedByUserId int
 ,@UpdatedDate datetime
 ,@UpdatedByUserId int
)
as
begin
  if isnull(@Id,0) = 0
  begin
  insert into Slot
  (
    StartTime
   ,EndTime
   ,NoOfOrders
   ,IsActive
   ,CreatedDate
   ,CreatedByUserId
   ,UpdatedDate
   ,UpdatedByUserId
  )
  values
  (
    @StartTime
   ,@EndTime
   ,@NoOfOrders
   ,@IsActive
   ,@CreatedDate
   ,@CreatedByUserId
   ,@UpdatedDate
   ,@UpdatedByUserId
  )

   declare @out int
  set @out = @@IDENTITY
  update Slot set Diff = DATEDIFF(MINUTE, StartTime, EndTime) where Id=@out
  end
 
  else
  begin
   update Slot set 
   StartTime = @StartTime,
   EndTime = @EndTime,
   NoOfOrders = @NoOfOrders,
   IsActive =@IsActive,
   UpdatedDate = @UpdatedDate,
   UpdatedByUserId =@UpdatedByUserId
   where Id = @Id
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddSlotDTL]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSlotDTL]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_AddSlotDTL] (
	 @Id INT = NULL
	,@SlotHDRId int
	,@SlotId int
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
	)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[SlotDTL] (
			     [SlotHDRId]
				,[SlotId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SlotHDRId
				,@SlotId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				
	       end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSlotHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSlotHDR]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddSlotHDR] (
	 @Id INT = NULL
	,@SlotDate date
	,@SlotRange varchar(50)
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@SlotHDRId int output
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
	)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[SlotHDR] (
			     [SlotDate]
				,[SlotRange]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SlotDate
				,@SlotRange
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @SlotHDRId = @@IDENTITY
	       end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStates]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStates]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddStates]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@StatesOutId int output
)
as
begin
If isnull(@Id,0)=0
begin
insert into States(
Code,
Name,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @StatesOutId=@@IDENTITY
end
else
begin
update States Set Code=@Code,Name=@Name,@IsActive=@IsActive where Id=@Id end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddStock]
(@Id int,
 @ProductId int,
 @TotalStocks int,
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as begin
	If isnull(@Id,0)=0
	begin
	insert into Stock(
	ProductId,
	AvailableStocks,
	TotalStocks,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	values(
	@ProductId,
	@TotalStocks,
	@TotalStocks,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId
	)
	end

else
begin
update Stock Set TotalStocks= TotalStocks+@TotalStocks,AvailableStocks= AvailableStocks+@TotalStocks,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId where ProductId=@ProductId

insert into StockTransaction (ProductId,TotalStocks,IsActive,CreatedByUserId,CreatedDate,
UpdatedByUserId,UpdatedDate) 
values(@ProductId,@TotalStocks,@IsActive,@CreatedByUserId,@CreatedDate,@UpdatedByUserId,@UpdatedDate)
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddStockTranaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStockTranaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create Procedure [dbo].[SP_AddStockTranaction]
(@Id int,
 @ProductId int,
 @TotalStocks int,
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as begin
	If isnull(@Id,0)=0
	begin
	insert into StockTransaction(
	ProductId,
	TotalStocks,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	values(
	@ProductId,
	@TotalStocks,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId
	)
	end

end
GO

-- %% [markdown]
-- # [dbo].[SP_AddSubscriptionDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSubscriptionDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddSubscriptionDetails]
(@Id int,
@CustomerId int,
@CustomerAddressId int,
 @ProductId int,
 @StartDate datetime,
 @SubscribeObject varchar(max),
 @WareHouseId int,
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as begin
	If isnull(@Id,0)=0
	begin
	insert into Subscription(
	CustomerId,
	CustomerAddressId,
	ProductId,
	StartDate,
	SubscribeObject,
	WareHouseId,
	IsPause, 
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	values(
	@CustomerId,
	@CustomerAddressId,
	@ProductId,
	@StartDate,
	@SubscribeObject,
	@WareHouseId,
	0, 
	@IsActive,
	--ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
	getdate(),
	@CreatedByUserId,
	--ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
	getdate(),
	@UpdatedByUserId
	)
	end

else
begin
update Subscription Set CustomerId=@CustomerId,CustomerAddressId=@CustomerAddressId,ProductId=@ProductId,StartDate=@StartDate,SubscribeObject=@SubscribeObject,
WareHouseId=@WareHouseId,IsActive=@IsActive,
--UpdatedDate=@UpdatedDate,
UpdatedDate = getdate(),
UpdatedByUserId=@UpdatedByUserId
where ID=@ID
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddUOM]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUOM]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddUOM]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime



)
as
begin
If isnull(@Id,0)=0
begin
insert into UOM(
Code,
Name,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)

end
else
begin
update UOM Set Code=@Code,Name=@Name,IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddUserAppVersions]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUserAppVersions]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddUserAppVersions]
(@Id int,
@UserID int,
@AppVersion int,
@DBVersion int,
@Environment varchar(10),
@ForceUpdate bit,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime



)
as
begin
If isnull(@Id,0)=0
begin
insert into UserAppVersions(
UserID,
AppVersion,
DBVersion,
Environment,
ForceUpdate,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@UserID,
@AppVersion,
@DBVersion,
@Environment,
@ForceUpdate,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)

end
else
begin
update UserAppVersions Set UserID=@UserID,AppVersion=@AppVersion,DBVersion=@DBVersion,Environment=@Environment,ForceUpdate=@ForceUpdate,@IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddUsers]
(@Id int
,@UserName varchar(255)
,@Password varchar(255)
,@RoleId Int
--,@EmpId varchar(255)
,@FirstName varchar(255)
,@MiddleName varchar(255)
,@LastName varchar(255)
,@Email varchar(255)
,@MobileNo BigInt
--,@DOJ datetime
,@WareHouseId Int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int


)
as
begin

If isnull(@Id,0)=0
begin
insert into Users(
UserName ,
Password ,
RoleId ,
--EmpId ,
FirstName ,
MiddleName ,
LastName ,
Email ,
MobileNo,
WareHouseId,
--DOJ,
ViewYN ,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId
)
values(
@UserName ,
@Password,
@RoleId,
--@EmpId,
@FirstName,
@MiddleName,
@LastName ,
@Email ,
@MobileNo,
@WareHouseId,
--@DOJ,
@ViewYN,
@CreatedDate,
@CreatedByUserId ,
@UpdatedDate ,
@UpdatedByUserId
)
end
else
begin
update Users Set
UserName = @UserName ,
Password = @Password,
RoleId = @RoleId,
FirstName = @FirstName,
MiddleName = @MiddleName,
LastName = @LastName ,
Email = @Email ,
MobileNo = @MobileNo,
WareHouseId = @WareHouseId,
ViewYN = @ViewYN where Id=@Id

end
	
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddVillage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVillage]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddVillage]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@MandalId Int,
@PinCode varchar(100),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@VillageOutId int output
)
as
begin
If isnull(@Id,0)=0
begin
insert into Village(
Code,
Name,
MandalId,
PinCode,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@MandalId,
@PinCode,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @VillageOutId=@@IDENTITY
end
else
begin
update Village Set Code=@Code,Name=@Name,MandalId=@MandalId,PinCode=@PinCode,@IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWalletTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWalletTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWalletTransaction]
(@Id int
,@CustomerId int
,@Amount decimal(18,2)
,@TransactionDate datetime
,@TransactionType int
,@TransactionId varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorMessage varchar(3000) output
)
as
begin
If isnull(@Id,0)=0
begin
If @TransactionType = 1
begin
  If @TransactionId != 'Id'
  begin
insert into WalletTransaction(
    CustomerId
	,Amount
	,TransactionDate
	,TransactionType
	,TransactionId
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId

)
values(
	@CustomerId
	,@Amount
	,@TransactionDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,@TransactionType
	,@TransactionId
	,@IsActive
	,@CreatedDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,@CreatedByUserId
	,@UpdatedDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,@UpdatedByUserId
)
  end
set @ErrorMessage = ''
end
else If @TransactionType = -1
begin
 declare @Credit float,@Debit float,@RemainingAmount float 
set @Credit =(select sum(Amount) from WalletTransaction where CustomerId=@CustomerId and TransactionType=1)
set @Debit =(select isnull(sum(Amount),0) from WalletTransaction where CustomerId=@CustomerId and TransactionType=-1)
set @RemainingAmount = @Credit - @Debit
If @RemainingAmount >0
begin
insert into WalletTransaction(
    CustomerId
	,Amount
	,TransactionDate 
	,TransactionType
	,TransactionId
	,IsActive
	,CreatedDate
	,CreatedByUserId
	,UpdatedDate
	,UpdatedByUserId

)
values(
	@CustomerId
	,@Amount
	,@TransactionDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,@TransactionType
	,@TransactionId
	,@IsActive
	,@CreatedDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,@CreatedByUserId
	,@UpdatedDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,@UpdatedByUserId
)
set @ErrorMessage = ''
end
else
begin
set @ErrorMessage = 'negative balance'
end
end
end
--else
--begin
--update WalletTransaction Set CustomerId=@CustomerId,
--Amount=@Amount,TransactionDate=@TransactionDate,TransactionType=@TransactionType,TransactionId=@TransactionId
--,@IsActive=@IsActive where Id=@Id end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddWareHouse]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWareHouse]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWareHouse]
(@Id int,
@Name varchar(100),
@ContactName varchar(100),
@ContactNo bigint,
@Address varchar(1000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into WareHouse(
Name,
ContactName,
ContactNo,
Address,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Name,
@ContactName,
@ContactNo,
@Address,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update WareHouse Set Name=@Name,ContactName=@ContactName,ContactNo=@ContactNo,Address=@Address,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWareHouseServiceLocation]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWareHouseServiceLocation]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWareHouseServiceLocation]
(
@Id int,
@WareHouseId int,
@PinCode int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into WareHouseServiceLocation(
WareHouseId,
PinCode,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@WareHouseId,
@PinCode,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update WareHouseServiceLocation Set WareHouseId=@WareHouseId,PinCode=@PinCode,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWareHouseStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWareHouseStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWareHouseStock]
(@Id int,
@WareHouseId int,
@ProductId int,
@AvailableStock int,
@TotalStock int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into WareHouseStock(
WareHouseId,
ProductId,
AvailableStock,
TotalStock,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@WareHouseId,
@ProductId,
@TotalStock,
@TotalStock,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)

insert into WareHouseStockTranaction (WareHouseId,ProductId,TotalStock,TransactionDate,
IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate) 
values(@WareHouseId,@ProductId,@TotalStock,getdate(),@IsActive,@CreatedByUserId,getdate(),@UpdatedByUserId,getdate())

end
else
begin
update WareHouseStock Set WareHouseId=@WareHouseId,ProductId=@ProductId,
AvailableStock=AvailableStock+@TotalStock,TotalStock=TotalStock+@TotalStock,
@IsActive=@IsActive,UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate 
where Id=@Id

insert into WareHouseStockTranaction (WareHouseId,ProductId,TotalStock,TransactionDate,
IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate) 
values(@WareHouseId,@ProductId,@TotalStock,getdate(),@IsActive,@CreatedByUserId,getdate(),@UpdatedByUserId,getdate())

end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWebhookTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWebhookTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Proc [dbo].[SP_AddWebhookTransaction]
(
@Id int,
@JsonObject varchar(3000)
)
as
begin
  if ISNULL(@Id,0) = 0
  begin
 insert into WebhookTransactions(JsonObject) values (@JsonObject)
 end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AllSubscriptionDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AllSubscriptionDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc  [dbo].[SP_AllSubscriptionDetails](@CustId int)
as
begin
select COUNT(*) count from Subscription where CustomerId=@CustId and IsPause=0 and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_AutomationSubscription]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AutomationSubscription]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_AutomationSubscription
CREATE proc [dbo].[SP_AutomationSubscription]
as
begin

select CustomerId, sum(Amount) CreditAmount into #CustCredit from WalletTransaction where TransactionType=1 
group by CustomerId
select CustomerId, isnull(sum(Amount),0) DebitAmount into #CustDebit from WalletTransaction where TransactionType=-1 
group by CustomerId

select cc.CustomerId,cc.CreditAmount - isnull(cd.DebitAmount,0) Balance into #CustBalance from #CustCredit cc
left join #CustDebit cd on cc.CustomerId = cd.CustomerId

select * into #Temp from 
(SELECT  sub.CustomerId,sub.CustomerAddressId,sub.ProductId,sub.SubscribeObject
,JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3)) AS Qty,pl.ProductPrice
,(JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))*pl.ProductPrice) PriceWithOutDiscount
,cast((JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))*pl.ProductPrice)as decimal(18,2))
-((cast((p.Discount/100) as decimal(18,2)))*(pl.ProductPrice*JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3)))) PriceWithDiscount
,((cast((p.Discount/100) as decimal(18,2)))*(pl.ProductPrice*JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))))
as DiscountAmount,p.Discount DiscountPer,cb.Balance,st.AvailableStock as AvailableStocks,sub.WareHouseId
FROM Subscription  sub
inner join Product p on p.Id =sub.ProductId
inner join PriceList pl on pl.ProductId = sub.ProductId
inner join #CustBalance cb on cb.CustomerId = sub.CustomerId
--inner join Stock st on st.ProductId = sub.ProductId
inner join WareHouseStock st on st.ProductId = sub.ProductId and st.WareHouseId = sub.WareHouseId
where sub.IsPause=0 and sub.IsActive=1 and pl.EndDate is null 
and CAST(sub.StartDate as Date)<=CAST(getdate() as date))X
where X.Qty<=AvailableStocks

--SELECT  sub.CustomerId,sub.CustomerAddressId,sub.ProductId,sub.SubscribeObject
--,JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3)) AS Qty,pl.ProductPrice
--,(JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))*pl.ProductPrice) PriceWithOutDiscount
--,cast((JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))*pl.ProductPrice)as decimal(18,2))
---CEILING((cast((p.Discount/100) as decimal(18,2)))*(pl.ProductPrice*JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3)))) PriceWithDiscount
--,CEILING((cast((p.Discount/100) as decimal(18,2)))*(pl.ProductPrice*JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))))
--as DiscountAmount,p.Discount DiscountPer,cb.Balance into #Temp
--FROM Subscription  sub
--inner join Product p on p.Id =sub.ProductId
--inner join PriceList pl on pl.ProductId = sub.ProductId
--inner join #CustBalance cb on cb.CustomerId = sub.CustomerId
--where sub.IsPause=0 and sub.IsActive=1 and pl.EndDate is null 
--and CAST(sub.StartDate as Date)<=CAST(getdate() as date) 

DECLARE @CustId int
DECLARE @NoOfProducts int
DECLARE @PriceWithDiscount float
DECLARE @DiscountAmount float
DECLARE @CustomerAddressId int
DECLARE @WareHouseId int
Declare @myresultset Cursor
Set @myresultset = CURSOR for select CustomerId,COUNT(productId) NoOfProducts,
Sum(PriceWithDiscount)+50 PriceWithDiscount,
sum(DiscountAmount) DiscountAmount,CustomerAddressId,WareHouseId
from #Temp where Qty !=0 and PriceWithDiscount<=Balance group by CustomerId,CustomerAddressId,WareHouseId
OPEN @myresultset 
Fetch NEXT from @myresultset
into @CustId,@NoOfProducts,@PriceWithDiscount,@DiscountAmount,@CustomerAddressId,@WareHouseId
While @@Fetch_Status=0
Begin

   DECLARE @dt datetime;
   DECLARE @OutOrderNo varchar(255)
   DECLARE @OutErrorNumber int
   DECLARE @OutErrorMessage varchar(3000)
   DECLARE @OutWalletMessage varchar(3000)
   set @dt= getdate();
   ---Insert Data to Order HDR
 exec SP_AddAutoOrderHdr @Id=null,@OrdDate=@dt,@OrdValue=@PriceWithDiscount,
 @Discount=@DiscountAmount,@DeliveryAddressId=@CustomerAddressId,@SlotId=0,@WareHouseId=@WareHouseId,@IsActive=1,@CreatedDate=@dt,
 @CreatedByUserId=@CustId,@UpdatedDate=@dt,@UpdatedByUserId=@CustId,@IsSubscription=1,@OrderNo = @OutOrderNo output,
 @ErrorNumber = @OutErrorNumber output,@ErrorMessage = @OutErrorMessage output

 exec SP_AddAutoWalletTransaction @Id=null,@CustomerId=@CustId,@Amount=@PriceWithDiscount,@TransactionDate=@dt
,@TransactionType=-1,@TransactionId='',@IsActive=1,@CreatedDate=@dt,@CreatedByUserId=@CustId,@UpdatedDate=@dt
,@UpdatedByUserId=@CustId,@ErrorMessage=@OutWalletMessage output
 

  exec SP_AddAutoOrderPayment @Id=null,@OrderNo=@OutOrderNo,@UserId=@CustId,@PaymentTypeId=2
,@PaymentDate=@dt,@Amount=@PriceWithDiscount,@IsActive=1,@CreatedDate=@dt,@CreatedByUserId=@CustId,@UpdatedDate=@dt
,@UpdatedByUserId=@CustId,@PaymentTransactionId=''
 ---

 ----Insert Data to Order DTL---
DECLARE @ODProductId int
DECLARE @ODQty int
DECLARE @ODProductPrice int
DECLARE @ODDiscountAmount float
DECLARE @ODPriceWithDiscount float
DECLARE @DiscountPer int
Declare @myresultset1 Cursor
Set @myresultset1 = CURSOR for select ProductId,Qty,ProductPrice,DiscountAmount,PriceWithDiscount,DiscountPer
from #Temp where CustomerId = @CustId and Qty !=0 and PriceWithDiscount<=Balance
OPEN @myresultset1 
Fetch NEXT from @myresultset1
into @ODProductId,@ODQty,@ODProductPrice,@ODDiscountAmount,@ODPriceWithDiscount,@DiscountPer
While @@Fetch_Status=0
Begin
   DECLARE @ODdt datetime;
   DECLARE @ODOutErrorNumber int
   DECLARE @ODOutErrorMessage varchar(3000)
   set @ODdt= getdate();
   declare @IV float
   --set @IV = (@ODQty*@ODProductPrice)-@ODDiscountAmount
   --print @ODDiscountAmount
   --print @ODQty*@ODProductPrice
exec SP_AddAutoOrderDtl @Id=null,@OrderNo=@OutOrderNo,@ProductId=@ODProductId,@Qty=@ODQty,
@Price = @ODProductPrice,@Discount = @DiscountPer,@ItemValue =@ODPriceWithDiscount,
@IsActive=1,@CreatedDate=@ODdt,@CreatedByUserId=@CustId,@UpdatedDate=@ODdt,@UpdatedByUserId=@CustId,
@DiscountedAmt = @ODDiscountAmount,@ErrorNumber = @ODOutErrorNumber output,
@ErrorMessage = @ODOutErrorMessage output


  
 Fetch Next from @myresultset1
 into @ODProductId,@ODQty,@ODProductPrice,@ODDiscountAmount,@ODPriceWithDiscount,@DiscountPer
End
close @myresultset1

 ------------------------

 Fetch Next from @myresultset
 into @CustId,@NoOfProducts,@PriceWithDiscount,@DiscountAmount,@CustomerAddressId,@WareHouseId
End
close @myresultset

drop table #Temp
drop table #CustCredit
drop table #CustDebit
drop table #CustBalance
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckAvailablityStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckAvailablityStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_CheckAvailablityStock](@CustId int)
as
begin
select c.ProductId,c.Qty,s.AvailableStocks from Cart c
inner join Stock s on s.ProductId = c.ProductId
where c.CreatedByUserId=4 and c.IsActive=1 and c.Qty>=1 --and s.AvailableStocks<c.Qty
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckAvailablityStockByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckAvailablityStockByProductId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_CheckAvailablityStockByProductId](@CustId int,@ProductId int)
as
begin
select c.ProductId,c.Qty,s.AvailableStocks from Cart c
inner join Stock s on s.ProductId = c.ProductId
where c.CreatedByUserId=@CustId and c.IsActive=1 and c.Qty>=1 and s.AvailableStocks<c.Qty
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckMobile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckMobile]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_CheckMobile](@MobileNo bigint)
as
begin
select COUNT(*) count from Customer where MobileNo =@MobileNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckMobileNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckMobileNo]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
    
CREATE   PROCEDURE [dbo].[SP_CheckMobileNo] (@MobileNo Varchar(max))    
AS    
BEGIN    
select COUNT(*) Count from Customer where MobileNo= @MobileNo 
END 
GO

-- %% [markdown]
-- # [dbo].[SP_CheckProductAvailStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckProductAvailStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_CheckProductAvailStock](@ProductId int) as 
begin
select Id from Stock where ProductId=@ProductId

end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckProductAvailwarehouseStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckProductAvailwarehouseStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_CheckProductAvailwarehouseStock](@ProductId int,@WareHouseId Int) as 
begin
select Id from WareHouseStock where ProductId=@ProductId and WareHouseId = @WareHouseId

end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckSlotDetailsByTime]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckSlotDetailsByTime]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_CheckSlotDetailsByTime](@time varchar(255))
as
begin
select Id,Code,StartTime,EndTime,StartTime+'-'+EndTime Slot,IsActive,CreatedDate,CreatedByUserId,
UpdatedDate,UpdatedByUserId from Slot  where  cast(StartTime as time)<=@time
end
GO

-- %% [markdown]
-- # [dbo].[SP_ClearCartByCustId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ClearCartByCustId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_ClearCartByCustId](@CustId int)
as
begin
 update Cart set IsActive= 0 where UserId = @CustId
end
GO

-- %% [markdown]
-- # [dbo].[SP_ClearNotification]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ClearNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_ClearNotification] (@Cust_Id int)
as
begin
delete from OrderNotification where CustomerId=@Cust_Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteSubscriptionById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteSubscriptionById]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_DeleteSubscriptionById](@Id int)
as
begin
update Subscription set IsActive=0 where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetAppVersion]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAppVersion]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetAppVersion]
as
begin
select Id,AppName,cast(cast(appVersion as decimal(18,2)) as varchar(50)) AppVersion,DBVersion,Environment,AppURL,
IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId
from appVersion where IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBannerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBannerDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetBannerDetails](@P_Id int)
as
begin
select Id,Code,Name,BannerUrl,width,height,IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate from Banner where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCancelledOrderHdrByOrderDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCancelledOrderHdrByOrderDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetCancelledOrderHdrByOrderDate](@StartDate date,@EndDate date,@WareHouseId Int)
as
begin

SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
      ,h.[OrdValue]
	  ,od.NoOfProducts,
	  od.DiscountedAmt 
	  ,h.Status
	  ,h.ReasonForCancel
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
  FROM [dbo].[OrderHdr] h
  INNER JOIN dbo.Customer U ON h.CreatedByUserId = U.Id
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
  WHERE cast(h.OrdDate as Date)>=@StartDate
and cast(h.OrdDate as Date)<=@EndDate and h.WareHouseId = ISNULL(@WareHouseId, h.WareHouseId)
 and h.Status in ('Cancel') AND h.IsActive = 1 order by h.CreatedDate desc
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCartDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCartDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE   PROCEDURE [dbo].[SP_GetCartDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 c.[Id]
		,c.[UserId]
		,u.UserName as UserName
		,c.[ProductId]
		,p.ProductName as ProductName
		,c.[Qty]
		,c.[Price]
		,c.[Discount]
		,c.[ItemValue]
	    ,c.[IsActive]
		,c.[CreatedDate]
		,c.[CreatedByUserId]
		,c.[UpdatedDate]
		,c.[UpdatedByUserId]
		,p.Picture
	FROM [dbo].[Cart] c

	INNER JOIN dbo.Users u ON u.Id = c.UserId
	INNER JOIN dbo.Product p ON p.Id = c.ProductId 

	Where
	 c.Id = ISNULL(@P_Id, c.Id)
		AND c.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCartDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCartDetailsByUserId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





CREATE   PROCEDURE [dbo].[SP_GetCartDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT 
		 c.[Id]
		,c.[UserId]
		,u.Name as UserName
		,c.[ProductId]
		,p.ProductName as ProductName
		,c.[Qty]
		,c.[Price]
		,p.[Discount]
		,c.[ItemValue]
	    ,c.[IsActive]
		,c.[CreatedDate]
		,c.[CreatedByUserId]
		,c.[UpdatedDate]
		,c.[UpdatedByUserId]
		,p.Picture
		,(c.Qty * c.Price) - (c.[ItemValue]) DiscountAmount
		,s.AvailableStocks
	FROM [dbo].[Cart] c
	
	INNER JOIN dbo.Customer u ON u.Id = c.UserId
	INNER JOIN dbo.Product p ON p.Id = c.ProductId
	inner join dbo.Stock s on s.ProductId = c.ProductId
	Where
	 c.UserId = ISNULL(@P_UserId, c.UserId)
		AND c.IsActive = 1 and c.Qty>=1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCartDetailsByWareHouseIdUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCartDetailsByWareHouseIdUserId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetCartDetailsByWareHouseIdUserId 1

Create PROCEDURE [dbo].[SP_GetCartDetailsByWareHouseIdUserId] (@P_UserId INT,@WareHouseId int)
AS
BEGIN
	SELECT 
		 c.[Id]
		,c.[UserId]
		,u.Name as UserName
		,c.[ProductId]
		,p.ProductName as ProductName
		,c.[Qty]
		,c.[Price]
		,p.[Discount]
		,c.[ItemValue]
	    ,c.[IsActive]
		,c.[CreatedDate]
		,c.[CreatedByUserId]
		,c.[UpdatedDate]
		,c.[UpdatedByUserId]
		,p.Picture
		,(c.Qty * c.Price) - (c.[ItemValue]) DiscountAmount
		,s.AvailableStock AvailableStocks
	FROM [dbo].[Cart] c
	
	INNER JOIN dbo.Customer u ON u.Id = c.UserId
	INNER JOIN dbo.Product p ON p.Id = c.ProductId
	inner join dbo.WareHouseStock s on s.ProductId = c.ProductId and s.WareHouseId = @WareHouseId
	Where
	 c.UserId = ISNULL(@P_UserId, c.UserId)
		AND c.IsActive = 1 and c.Qty>=1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCategoryActiveDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCategoryActiveDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetCategoryActiveDetails](@P_Id Int) 
as
begin
select Id,Code,Name,Picture,IsActive,CreatedByUserId,CreatedDate ,UpdatedDate from Category where IsActive =1 AND  Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCategoryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCategoryDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetCategoryDetails](@P_Id int) 
as
begin
select Id,Code,Name,Picture,IsActive,CreatedByUserId,CreatedDate ,UpdatedDate from Category where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCatogoryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCatogoryDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetCatogoryDetails](@P_Id int) 
as
begin
select Id,Code,Name,IsActive,CreatedByUserId,CreatedDate from Category where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCompletedOrderHdrByOrderDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCompletedOrderHdrByOrderDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetCompletedOrderHdrByOrderDate](@StartDate date,@EndDate date,@WareHouseId Int)
as
begin

SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
      ,h.[OrdValue]
	  ,od.NoOfProducts,
	  od.DiscountedAmt 
	  ,h.Status
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
  FROM [dbo].[OrderHdr] h
  INNER JOIN dbo.Customer U ON h.CreatedByUserId = U.Id
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
  WHERE cast(h.OrdDate as Date)>=@StartDate
and cast(h.OrdDate as Date)<=@EndDate
 and h.Status in ('Delivered') AND  h.WareHouseId = ISNULL(@WareHouseId, h.WareHouseId) and  h.IsActive = 1 order by h.CreatedDate desc
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCouponDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCouponDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetCouponDetails](@Id int)
as
begin
   select * from Coupons c where  c.Id= ISNULL(@Id,c.Id) and ValidTo>getdate()
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCouponTransactionDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCouponTransactionDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetCouponTransactionDetails](@Id int)
as
begin
 select   Ct.CouponId,
 C.Code,
 ct.OrderNo,
 Cu.Name ,
 ct.Id ,
 ct.IsActive,
 ct.RedeemedAmount,
 ct.UPdatedDate

 
 from CouponTransaction ct
 inner Join Coupons C on C.Id = ct.CouponId
 inner Join Customer Cu On Cu.Id = ct.UserId
 where ct.IsActive=1 and ct.Id = ISNULL(@Id,ct.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCouponTransactionDetailsByCustId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCouponTransactionDetailsByCustId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_GetCouponTransactionDetailsByCustId](@CustId int)
as
begin
 select * from CouponTransaction ct where ct.IsActive=1 and ct.UserId = @CustId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCustomerAddress]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCustomerAddress]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_GetCustomerAddress](@Id int)
as
begin
select * from CustomerAddress where CustId=isnull(@id,CustId) and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCustomerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCustomerDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetCustomerDetails](@P_Id int)
as
begin

select 
c.Id,
c.Name,
c.MobileNo,
c.EmailId,
c.IsActive,
c.CreatedByUserId,
c.CreatedDate,
c.UpdatedByUserId,
c.UpdatedDate,
c.FCMtoken
,ca.Address
,ca.AddressName
,ca.Area
,ca.FlatNo
,ca.PinCode
,ca.Id AddressId
from Customer c 
left join (select * from CustomerAddress where IsDefault =1) ca on ca.CustId = c.Id
where c.Id=isnull(@P_Id,c.Id) and c.IsActive=1
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliverManagementDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliverManagementDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDeliverManagementDetails '2022-11-08','2022-11-08'
CREATE PROCEDURE [dbo].[SP_GetDeliverManagementDetails] (@StartDate date,@EndDate date)
AS
BEGIN
select oh.OrderNo,oh.OrdDate,ca.FlatNo,ca.Area,ca.AddressName,(Ca.FlatNo+','+ Ca.Area + ',' +Ca.Address) as Address,
ca.PinCode,sl.StartTime+'-'+sl.EndTime Slot,od.NoOfProducts
,pm.Name Status
from OrderHdr Oh
inner join CustomerAddress ca on ca.Id = oh.DeliveryAddressId
left join Slot sl on sl.Id = oh.SlotId
inner join OrderPayment op on op.OrderNo = oh.OrderNo
--left join Paymenttransaction pt on pt.Id = op.PaymentTransactionId
inner join PaymentMethod pm on pm.Id = op.PaymentTypeId
INNER join (select OrderNo,count(ProductId) NoOfProducts
  from OrderDtl group by OrderNo) od on od.OrderNo = oh.OrderNo
where oh.Status='On the way' and  cast(Oh.OrdDate as Date)>=@StartDate
and cast(Oh.OrdDate as Date)<=@EndDate and Oh.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryChargesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryChargesDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetDeliveryChargesDetails] (@P_Id int)
as
begin
select * from DeliveryCharges where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryChargesDetailsByOrderValue]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryChargesDetailsByOrderValue]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDeliveryChargesDetailsByOrderValue 300
CREATE procedure [dbo].[SP_GetDeliveryChargesDetailsByOrderValue] (@OrderValue float)
as
begin
select  Charges   
from DeliveryCharges where StartRange<= @OrderValue and EndRange >= @OrderValue

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetdeliveryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetdeliveryDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetdeliveryDetails '2022-11-08','2022-11-08'
CREATE proc [dbo].[SP_GetdeliveryDetails](@StartDate date,@EndDate date)
as
begin
SELECT distinct d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,p.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
	  ,U.Name as UpdateByUserName
      ,d.[UpdatedByUserId]	  
	  ,pl.ProductPrice
	  ,o.OrdValue
	  ,pm.Name
	  ,0 as DeliveryCharges
	  ,o.OrdDate
	  ,ca.Address as DeliveryAddress
	  ,ca.PinCode as PinCode
	  ,s.StartTime+'-'+s.EndTime Slot
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  inner join PriceList pl on pl.ProductId =d.ProductId
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
  INNER JOIN dbo.OrderHdr o ON o.OrderNo = d.OrderNo
  inner join CustomerAddress ca on ca.Id = o.DeliveryAddressId
  left join Slot s on s.Id = o.SlotId
  inner join OrderPayment op on op.OrderNo = d.OrderNo
  inner join PaymentMethod pm on pm.Id = op.PaymentTypeId
  INNER JOIN Customer U on U.Id=d.CreatedByUserId
      	WHERE cast(o.OrdDate as Date)>=@StartDate
and cast(o.OrdDate as Date)<=@EndDate and d.IsActive = 1 and o.Status = 'On the way'
		 and pl.EndDate is null
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictsDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE   PROCEDURE [dbo].[SP_GetDistrictsDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[StateId]
		,s.name as StateName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
	FROM [dbo].[Districts] t
	
	INNER JOIN dbo.States s ON s.Id = t.StateId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetEveningSlotDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetEveningSlotDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetEveningSlotDetails](@diff varchar(50))
as
begin
select s.Id,s.StartTime,s.EndTime,
--s.StartTime+'-'+s.EndTime Slot,
SUBSTRING(s.StartTime, 1, 5)+'-'+s.EndTime Slot,
s.NoOfOrders,s.IsActive,s.CreatedDate,s.CreatedByUserId,
s.UpdatedDate,s.UpdatedByUserId,'rgb(253, 216, 129)' Color from Slot s
where cast(s.StartTime as time)>='12:00 PM' and s.IsActive=1 and s.Diff  = @diff
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetEveningSlotDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetEveningSlotDetailsById]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetEveningSlotDetailsById](@Id int,@diff varchar(50))
as
begin
select s.Id,s.StartTime,s.EndTime,
--s.StartTime+'-'+s.EndTime Slot,
SUBSTRING(s.StartTime, 1, 5)+'-'+s.EndTime Slot,
s.NoOfOrders,s.IsActive,s.CreatedDate,s.CreatedByUserId,
s.UpdatedDate,s.UpdatedByUserId,
case when sd.SlotId is null then 'rgb(253, 216, 129)' else 'rgb(252, 183, 19)' end Color from Slot s
left join (select * from SlotDTL where SlotHDRId=@Id and IsActive=1) sd on sd.SlotId = s.Id
where cast(s.StartTime as time)>='12:00 PM' and s.IsActive=1 and s.Diff  = @diff
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFAQ]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFAQ]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_GetFAQ] (@P_Id int)
as
begin
select Id,Question,Answer,Ord,Category,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from FAQ where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetMandalsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMandalsDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE   PROCEDURE [dbo].[SP_GetMandalsDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[DistrictId]
		,d.name as DistrictName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
	FROM [dbo].[Mandal] t
	
	INNER JOIN dbo.Districts d ON d.Id = t.DistrictId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id)
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMorningSlotDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMorningSlotDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetMorningSlotDetails](@diff varchar(50))
as
begin
select s.Id,s.StartTime,s.EndTime,
--s.StartTime+'-'+s.EndTime Slot,
SUBSTRING(s.StartTime, 1, 5)+'-'+s.EndTime Slot,
s.NoOfOrders,s.IsActive,s.CreatedDate,s.CreatedByUserId,
s.UpdatedDate,s.UpdatedByUserId,'rgb(253, 216, 129)' Color from Slot s
where cast(s.StartTime as time)<'12:00 PM' and s.IsActive=1 and s.Diff  = @diff
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetMorningSlotDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMorningSlotDetailsById]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetMorningSlotDetailsById](@Id int,@diff varchar(50))
as
begin
select s.Id,s.StartTime,s.EndTime,
--s.StartTime+'-'+s.EndTime Slot,
SUBSTRING(s.StartTime, 1, 5)+'-'+s.EndTime Slot,
s.NoOfOrders,s.IsActive,s.CreatedDate,s.CreatedByUserId,
s.UpdatedDate,s.UpdatedByUserId,
case when sd.SlotId is null then 'rgb(253, 216, 129)' else 'rgb(252, 183, 19)' end Color from Slot s
left join (select * from SlotDTL where SlotHDRId=@Id and IsActive=1) sd on sd.SlotId = s.Id
where cast(s.StartTime as time)<'12:00 PM' and s.IsActive=1 and s.Diff  = @diff
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetOfferNotification]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOfferNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_GetOfferNotification] (@P_Id int)
as
begin
select Id,Description,NotificationImage,CreatedDate,CustomerId from OfferNotification where CustomerId=isnull(@P_Id,CustomerId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtl]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetOrderDtl] (@P_Id INT)
AS
BEGIN
SELECT d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
      ,d.[Qty]
      ,d.[Price]
      ,d.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
      ,d.[UpdatedByUserId]
  FROM [dbo].[OrderDtl] d
      	WHERE d.Id = ISNULL(@P_Id, d.Id)
		AND d.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtlByOrderDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtlByOrderDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- exec SP_GetOrderDtlByOrderDate '2022-12-05' ,'2022-12-06'
CREATE proc [dbo].[SP_GetOrderDtlByOrderDate](@StartDate date,@EndDate date)
as
begin

SELECT 
	   h.OrderNo
	   
	  ,p.ProductName
	  ,h.Qty
	  ,s.StartTime+'-'+s.EndTime Slot
	  ,U.Name as CustomerName
	  ,U.MobileNo
	 ,(Ca.AddressName+','+Ca.Address+','+Ca.FlatNo+','+Ca.Area) as CustomerAddress
	   ,o.CreatedDate OrderDate
	   ,o.OrdDate DeliveryDate
  FROM [dbo].[OrderDtl] h
  INNER JOIN dbo.Customer U ON h.CreatedByUserId = U.Id
  Join dbo.CustomerAddress Ca on h.CreatedByUserId = Ca.CustId and ca.IsDefault =1
  Inner Join dbo.Product p on h.ProductId=p.Id
   INNER JOIN dbo.OrderHdr o ON o.OrderNo = h.OrderNo
   left join Slot s on s.Id = o.SlotId
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
WHERE cast(h.CreatedDate as Date)>=@StartDate
and cast(h.CreatedDate as Date)<=@EndDate
 AND h.IsActive = 1 and o.Status not in ('Cancel','Delivered') order by h.CreatedDate desc

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtlByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtlByUserId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetOrderDtlByUserId] (@P_Id INT)
AS
BEGIN
SELECT d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]	 
      ,d.[Qty]
      ,d.[Price]
      ,d.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
      ,d.[UpdatedByUserId]
  FROM [dbo].[OrderDtl] d
      	WHERE d.CreatedByUserId = ISNULL(@P_Id, d.CreatedByUserId)
		AND d.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtlDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetOrderDtlDetails] (@P_Id INT)
AS
BEGIN
SELECT d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,d.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
      ,d.[UpdatedByUserId]
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
      	WHERE d.Id = ISNULL(@P_Id, d.Id)
		AND d.IsActive = 1 order by d.CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtlDetailsByOrderId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtlDetailsByOrderId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetOrderDtlDetailsByOrderId] (@P_Id Varchar(50),@UserId Int)
AS
BEGIN
SELECT distinct d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,p.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
	  
	  ,ca.PinCode
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,o.OrdDate [UpdatedDate]
	  ,o.Status
	  ,o.Discount as TotalDiscount
	  ,(o.Discount - ct.RedeemedAmount) as TotalDiscountamt
	  ,o.ReasonForCancel
	  ,U.Name as UpdateByUserName
      ,d.[UpdatedByUserId]	  
	  ,pl.ProductPrice
	  ,o.OrdValue
	  ,pm.Name
	  ,U.Name as Customername
	  ,U.MobileNo
	  ,50 as DeliveryCharges
	  ,o.OrdDate

	  ,ct.RedeemedAmount
	  ,cp.Code as couponcode
	  ,o.OrdValue as Totalvalue
	  ,ca.AddressName + '' + ca.Address  + '' + ca.FlatNo + '' + ca.Area  as DeliveryAddress
	  ,s.StartTime+'-'+s.EndTime Slot
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  inner join PriceList pl on pl.ProductId =d.ProductId
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
  INNER JOIN dbo.OrderHdr o ON o.OrderNo = d.OrderNo
  
  inner join CustomerAddress ca on ca.Id = o.DeliveryAddressId
  left join Slot s on s.Id = o.SlotId
  left join CouponTransaction ct on ct.OrderNo = d.OrderNo
  left join Coupons cp on cp.Id = ct.CouponId
  inner join OrderPayment op on op.OrderNo = d.OrderNo
  inner join PaymentMethod pm on pm.Id = op.PaymentTypeId
  INNER JOIN Customer U on U.Id=d.CreatedByUserId
      	WHERE d.OrderNo = ISNULL(@P_Id, d.OrderNo)
		AND d.IsActive = 1
		AND d.CreatedByUserId=@UserId and pl.EndDate is null
END



--exec SP_GetOrderDtlDetailsByOrderId '040420220001',44



GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtlDetailsByOrderNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtlDetailsByOrderNo]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetOrderDtlDetailsByOrderNo '301120220057'
CREATE PROCEDURE [dbo].[SP_GetOrderDtlDetailsByOrderNo] (@OrderNo Varchar(50))
AS
BEGIN
SELECT distinct d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,p.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
	  ,U.Name as UpdateByUserName
      ,d.[UpdatedByUserId]	  
	  ,pl.ProductPrice
	  ,cast (o.OrdValue - o.[Discount] as decimal(18,2))  OrdValue
	  ,pm.Name
	  ,0 as DeliveryCharges
	  ,o.OrdDate
	  ,ca.Address as DeliveryAddress
	  ,s.StartTime+'-'+s.EndTime Slot
	  ,ct.RedeemedAmount
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  inner Join CouponTransaction ct on ct.OrderNo = d.OrderNo
  inner join PriceList pl on pl.ProductId =d.ProductId
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
  INNER JOIN dbo.OrderHdr o ON o.OrderNo = d.OrderNo
  inner join CustomerAddress ca on ca.Id = o.DeliveryAddressId
  left join Slot s on s.Id = o.SlotId
  inner join OrderPayment op on op.OrderNo = d.OrderNo
  inner join PaymentMethod pm on pm.Id = op.PaymentTypeId
  INNER JOIN Customer U on U.Id=d.CreatedByUserId
      	WHERE d.OrderNo = ISNULL(@OrderNo, d.OrderNo)
		AND d.IsActive = 1 and pl.EndDate is null 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderDtlDetailsByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderDtlDetailsByProductId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetOrderDtlDetailsByProductId] (@P_Id INT)
AS
BEGIN
SELECT d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,d.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
      ,d.[UpdatedByUserId]
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  inner join dbo.OrderHdr o on o.OrderNo = d.OrderNo
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
      	WHERE d.ProductId = ISNULL(@P_Id, d.ProductId)
		AND d.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderHdr]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetOrderHdr] (@P_Id INT,
@FromDate Date,
@ToDate Date)
AS
BEGIN
	SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
      ,h.[OrdValue]
	  ,h.Discount
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
	  ,h.CouponId
  FROM [dbo].[OrderHdr] h
    	WHERE h.Id = ISNULL(@P_Id, h.Id)
		AND h.IsActive = 1 
		AND CAST(h.CreatedDate AS date) BETWEEN isnull(@FromDate,CAST(h.CreatedDate AS date)) AND isnull(@ToDate,CAST(h.CreatedDate AS date))
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderHdrByOrderDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderHdrByOrderDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetOrderHdrByOrderDate '2022-11-28','2022-11-29',1
CREATE proc [dbo].[SP_GetOrderHdrByOrderDate](@StartDate date,@EndDate date,@WareHouseId Int)
as
begin

SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
      ,h.[OrdValue]
	  ,od.NoOfProducts,
	  od.DiscountedAmt 
	  ,h.Status
	  ,h.IsSubscription
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
	  ,h.CouponId
	  ,Ca.PinCode
	,(Ca.FlatNo+','+ Ca.Area + ',' +Ca.Address)  as CustomerAddress
  FROM [dbo].[OrderHdr] h
  INNER JOIN dbo.Customer U ON h.CreatedByUserId = U.Id 
 --Inner Join dbo.CustomerAddress Ca on h.CreatedByUserId = Ca.CustId and ca.IsDefault =1
 Inner Join dbo.CustomerAddress Ca on h.CreatedByUserId = Ca.CustId and h.DeliveryAddressId = ca.Id
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
  WHERE cast(h.OrdDate as Date)>=@StartDate
 and cast(h.OrdDate as Date)<=@EndDate and  h.WareHouseId = ISNULL(@WareHouseId, h.WareHouseId)
 and h.Status not in ('Cancel','Delivered')  and h.IsActive = 1 order by h.CreatedDate desc
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderHdrByOrderDateBySubscription]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderHdrByOrderDateBySubscription]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetOrderHdrByOrderDateBySubscription](@StartDate date,@EndDate date)
as
begin

SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
      ,h.[OrdValue]
	  ,od.NoOfProducts,
	  od.DiscountedAmt 
	  ,h.Status
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
	  ,h.CouponId
  FROM [dbo].[OrderHdr] h
  INNER JOIN dbo.Customer U ON h.CreatedByUserId = U.Id
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
  WHERE cast(h.OrdDate as Date)>=@StartDate
and cast(h.OrdDate as Date)<=@EndDate and h.IsSubscription=1
 and h.Status not in ('Cancel','Delivered') AND h.IsActive = 1 order by h.CreatedDate desc
end


--exec SP_GetOrderHdrByOrderDate '2022-04-03','2022-04-04'
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderHdrDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetOrderHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
      ,h.[OrdValue]
	  ,od.NoOfProducts,
	  od.DiscountedAmt 
	  ,h.Status
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
	  ,h.CouponId
  FROM [dbo].[OrderHdr] h
  INNER JOIN dbo.Users U ON h.CreatedByUserId = U.Id
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
  WHERE h.Id = ISNULL(@P_Id, h.Id) 
  AND h.IsActive = 1 order by h.CreatedDate desc

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderHdrDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderHdrDetailsByUserId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetOrderHdrDetailsByUserId 17
CREATE PROCEDURE [dbo].[SP_GetOrderHdrDetailsByUserId] (@UserId INT)
AS
BEGIN
	SELECT h.[Id]
	  ,h.OrderNo
      ,h.[OrdDate]
	  ,h.Discount
      --,h.[OrdValue]
	  ,cast(h.[OrdValue] - h.Discount  as decimal(18,2)) OrdValue
	  ,od.NoOfProducts,
	  od.DiscountedAmt
	  ,h.Status
	  ,h.IsSubscription
      ,h.[IsActive]
      ,h.[CreatedDate]
      ,h.[CreatedByUserId]
      ,h.[UpdatedDate]
      ,h.[UpdatedByUserId]
	  ,h.CouponId
  FROM [dbo].[OrderHdr] h
  INNER JOIN dbo.Customer U ON h.CreatedByUserId = U.Id
  INNER join (select OrderNo,count(ProductId) NoOfProducts,sum(DiscountedAmt) DiscountedAmt
  from OrderDtl group by OrderNo) od on od.OrderNo = h.OrderNo
  WHERE h.CreatedByUserId = ISNULL(@UserId, h.Id) 
  AND h.IsActive = 1 order by h.CreatedDate desc

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderHistory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderHistory]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetOrderHistory](@Id int)
as
begin
select * from OrderHistory where Id=isnull(@id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderNotification]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderNotification]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetOrderNotification] (@P_Id int)
as
begin
select Id,OrderNo,Status,CreatedDate,CustomerId from OrderNotification where CustomerId=isnull(@P_Id,CustomerId) 
order by CreatedDate desc
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrders]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrders]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetOrders](@Id int)
as
begin
select * from Orders where Id=isnull(@id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrdersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrdersDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetOrdersDetails](@StartDate date,@EndDate date,@WareHouseId Int)
as
begin

select X.Status,sum(X.NoOfOrders) NoOfOrders from
((select oh.Status,count(oh.OrderNo) NoOfOrders from OrderHdr oh

where oh.WareHouseId = ISNULL(@WareHouseId, oh.WareHouseId) and  cast(oh.OrdDate as Date)>=@StartDate 
and  cast(oh.OrdDate as Date)<=@EndDate and oh.Status not in ('Confirmed') group by  GROUPING SETS (
        (oh.Status),
        ()))
        union
select 'Cancel' Status,0 NoOfOrders
union
select null Status,0 NoOfOrders
union
select 'Placed' Status,0 NoOfOrders
union
select 'Delivered' Status,0 NoOfOrders
union
select 'Preparing for Dispatch' Status,0 NoOfOrders
union
select 'On the way' Status,0 NoOfOrders)X group by Status

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderSummaryDetailsByOrderNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderSummaryDetailsByOrderNo]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetOrderSummaryDetailsByOrderNo '301120220057',17
CREATE PROCEDURE [dbo].[SP_GetOrderSummaryDetailsByOrderNo] (@P_Id Varchar(50),@UserId Int)
AS
BEGIN
SELECT distinct d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,p.Picture ProductURL
	  ,p.Description ProductDescription
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,p.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
	  ,U.Name as UpdateByUserName
      ,d.[UpdatedByUserId]	  
	  ,pl.ProductPrice

	  ,o.OrdValue
	  ,pm.Name PaymentName
	  ,0 as DeliveryCharges
	  --,o.OrdDate
	  ,o.CreatedDate OrdDate
	  ,o.Discount HDRDiscount
	  ,ca.Address+','+ca.FlatNo+','+ca.Area as DeliveryAddress
	  ,s.StartTime+'-'+s.EndTime Slot
	  ,cast(cast(o.OrdDate as Date) as varchar(50))+' '+ s.StartTime+'-'+s.EndTime DeliveryDate 
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  inner join PriceList pl on pl.ProductId =d.ProductId
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
  INNER JOIN dbo.OrderHdr o ON o.OrderNo = d.OrderNo
  inner join CustomerAddress ca on ca.Id = o.DeliveryAddressId
  inner join Slot s on s.Id = o.SlotId
  inner join OrderPayment op on op.OrderNo = d.OrderNo
  inner join PaymentMethod pm on pm.Id = op.PaymentTypeId
  INNER JOIN Customer U on U.Id=d.CreatedByUserId
      	WHERE d.OrderNo = ISNULL(@P_Id, d.OrderNo)
		AND d.IsActive = 1 and o.IsSubscription=0
		AND d.CreatedByUserId=@UserId and pl.EndDate is null
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrderSummaryDetailsByOrderNoBySubscription]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrderSummaryDetailsByOrderNoBySubscription]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetOrderSummaryDetailsByOrderNoBySubscription null,1
CREATE PROCEDURE [dbo].[SP_GetOrderSummaryDetailsByOrderNoBySubscription] (@P_Id Varchar(50),@UserId Int)
AS
BEGIN
SELECT distinct d.[Id]
      ,d.[OrderNo]
      ,d.[ProductId]
	  ,p.ProductName Product
	  ,p.Picture ProductURL
	  ,p.Description ProductDescription
	  ,c.Name Category
      ,d.[Qty]
      ,d.[Price]
      ,p.[Discount]
	  ,d.[DiscountedAmt]
      ,d.[ItemValue]
      ,d.[IsActive]
      ,d.[CreatedDate]
      ,d.[CreatedByUserId]
      ,d.[UpdatedDate]
	  ,U.Name as UpdateByUserName
      ,d.[UpdatedByUserId]	  
	  ,pl.ProductPrice

	  ,o.OrdValue
	  --,pm.Name PaymentName
	  ,0 as DeliveryCharges
	  ,o.OrdDate
	  ,o.Discount HDRDiscount
	  ,ca.Address as DeliveryAddress
	 -- ,s.StartTime+'-'+s.EndTime Slot
	--  ,cast(cast(o.OrdDate as Date) as varchar(50))+' '+ s.StartTime+'-'+s.EndTime DeliveryDate 
  FROM [dbo].[OrderDtl] d
  INNER JOIN dbo.Product p ON p.Id = d.ProductId
  inner join PriceList pl on pl.ProductId =d.ProductId
  INNER JOIN dbo.Category c ON c.Id = p.CategoryId
  INNER JOIN dbo.OrderHdr o ON o.OrderNo = d.OrderNo  
  inner join CustomerAddress ca on ca.Id = o.DeliveryAddressId
  --inner join Slot s on s.Id = o.SlotId
  --inner join OrderPayment op on op.OrderNo = d.OrderNo
  --inner join PaymentMethod pm on pm.Id = op.PaymentTypeId
  INNER JOIN Customer U on U.Id=d.CreatedByUserId
      	WHERE d.OrderNo = ISNULL(@P_Id, d.OrderNo)
		AND d.IsActive = 1 and o.IsSubscription=1
		AND d.CreatedByUserId=@UserId and pl.EndDate is null
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPaymentMethodDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPaymentMethodDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_GetPaymentMethodDetails](@Id int)
as
begin
select * from PaymentMethod where Id = ISNULL(@Id,Id) order by Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPaymenttransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPaymenttransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_GetPaymenttransaction] (@P_Id int)
as
begin
select Id,PaymentId,TransactionId,Description,Status,Amount,PaymentType,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from Paymenttransaction where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPriceListByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPriceListByProductId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPriceListByProductId](@P_ProductId Int)
as
begin
select * from PriceList where ProductId=@P_ProductId and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPriceListDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPriceListDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[SP_GetPriceListDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 pl.[Id]
		,pl.[ProductId]
		,p.ProductName as ProductName
		,pl.[ProductPrice]
		,pl.[PriceCategory]
		,pl.[StartDate]
		,pl.[EndDate]
		
		,pl.[IsActive]
		,pl.[CreatedDate]
		,pl.[CreatedByUserId]
		,pl.[UpdatedDate]
		,pl.[UpdatedByUserId]
		,case when pl.EndDate is null then 'false' else 'true' end Status
	FROM [dbo].[PriceList] pl
	
	INNER JOIN dbo.Product p ON p.Id = pl.ProductId
	WHERE pl.Id = ISNULL(@P_Id, pl.Id)
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPriceListDetailsByDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPriceListDetailsByDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[SP_GetPriceListDetailsByDate] (@StartDate date,@EndDate date)
AS
BEGIN
	SELECT 
		 pl.[Id]
		,pl.[ProductId]
		,p.ProductName as ProductName
		,pl.[ProductPrice]
		,pl.[PriceCategory]
		,pl.[StartDate]
		,pl.[EndDate]
		,pl.[IsActive]
		,pl.[CreatedDate]
		,pl.[CreatedByUserId]
		,pl.[UpdatedDate]
		,pl.[UpdatedByUserId]
		,case when pl.EndDate is null then 'false' else 'true' end Status
	FROM [dbo].[PriceList] pl
	
	INNER JOIN dbo.Product p ON p.Id = pl.ProductId
	WHERE cast(pl.StartDate as Date)>=@StartDate
and cast(pl.StartDate as Date)<=@EndDate
and pl.IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductPriceListDropdownDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductPriceListDropdownDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[SP_GetProductPriceListDropdownDetails] (@P_Id INT)
AS
BEGIN
    select p.Id,p.ProductName from Product p where Id not
    in(select distinct ProductId from PriceList where IsActive=1) and IsActive=1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProducts]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetProducts] (@P_Id int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
				,p.[DetailedDescription]
						,p.OpeningStock
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
	FROM [dbo].[Product] p

	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId	

	WHERE p.Id = ISNULL(@P_Id, p.Id)
		 AND pl.EndDate Is null

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailByCategoryId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailByCategoryId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProductsDetailByCategoryId] (@P_CategoryId Int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
	FROM [dbo].[Product] p
	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId
	WHERE p.CategoryId = ISNULL(@P_CategoryId, p.CategoryId)
		AND p.IsActive = 1 AND pl.EndDate Is null

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailByCategoryUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailByCategoryUserId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProductsDetailByCategoryUserId] (@P_CategoryId Int,@UserId int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
		,isnull(ca.Qty,0) CartQty 
 , st.AvailableStocks as AvailableStock
	FROM [dbo].[Product] p
	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId
	left join(select * from dbo.Cart where IsActive=1 and UserId=@UserId) ca on ca.ProductId = p.Id
Inner join Stock st on st.ProductId = p. Id
WHERE p.CategoryId = ISNULL(@P_CategoryId, p.CategoryId)
		AND p.IsActive = 1 AND pl.EndDate Is null 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailByWareHouseIdCategoryUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailByWareHouseIdCategoryUserId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetProductsDetailByWareHouseIdCategoryUserId] (@CategoryId Int,@UserId int,@WareHouseId int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
		,isnull(ca.Qty,0) CartQty 
		, whs.AvailableStock as AvailableStock
	FROM [dbo].[Product] p
	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId
	left join(select * from dbo.Cart where IsActive=1 and UserId=@UserId) ca on ca.ProductId = p.Id
Inner join WareHouseStock whs on whs.ProductId = p. Id and whs.WareHouseId = @WareHouseId
WHERE p.CategoryId = ISNULL(@CategoryId, p.CategoryId)
		AND p.IsActive = 1 AND pl.EndDate Is null 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProductsDetails] (@P_Id int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
				,p.[DetailedDescription]
						,p.OpeningStock
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
	FROM [dbo].[Product] p

	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId	

	WHERE p.Id = ISNULL(@P_Id, p.Id)
		AND p.IsActive = 1 AND pl.EndDate Is null

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailsByCategoryId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailsByCategoryId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetProductsDetailsByCategoryId] (@P_CategoryId Int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
	FROM [dbo].[Product] p
	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId
	WHERE p.CategoryId = ISNULL(@P_CategoryId, p.CategoryId)
		AND p.IsActive = 1 AND pl.EndDate Is null

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailsByCustId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailsByCustId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetProductsDetailsByCustId] (@P_Id int,@CustId int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
				,p.[DetailedDescription]
						,p.OpeningStock
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
		,s.AvailableStock as AvailableStocks
		,isnull(ca.Qty,0) as CartQty
	FROM [dbo].[Product] p

	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId	
	--inner join dbo.Stock s on s.ProductId = p.Id
	inner join dbo.WareHouseStock s on s.ProductId = p.Id
	left join (select * from Cart where UserId=@CustId and IsActive=1) ca on ca.ProductId = p.Id
	WHERE p.Id = ISNULL(@P_Id, p.Id)
		AND p.IsActive = 1 AND pl.EndDate Is null

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailsByProductIdCustIdWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailsByProductIdCustIdWareHouseId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create procedure [dbo].[SP_GetProductsDetailsByProductIdCustIdWareHouseId] (@P_Id int,@CustId int,@WareHouseId int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
				,p.[DetailedDescription]
						,p.OpeningStock
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
		,s.AvailableStock as AvailableStocks
		,isnull(ca.Qty,0) as CartQty
	FROM [dbo].[Product] p

	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId	
	inner join dbo.WareHouseStock s on s.ProductId = p.Id and s.WareHouseId = @WareHouseId
	left join (select * from Cart where UserId=@CustId and IsActive=1) ca on ca.ProductId = p.Id
	WHERE p.Id = ISNULL(@P_Id, p.Id)
		AND p.IsActive = 1 AND pl.EndDate Is null

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailsByWareHouseIdCustId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailsByWareHouseIdCustId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetProductsDetailsByWareHouseIdCustId] (@Id int,@CustId int,@WareHouseId int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,c.Name as CategoryName
		,p.[ProductName]
		,p.[ProductCode]
		,p.[Description]
		,p.[Brand]
		,p.[UomId]
	    ,u.Name as UomName
		,p.[Qty]
		,p.[Picture]
		,p.[Discount]
				,p.[DetailedDescription]
						,p.OpeningStock
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		,isnull(pl.ProductPrice,0) ProductPrice
		,whs.AvailableStock as AvailableStocks
		,isnull(ca.Qty,0) as CartQty
	FROM [dbo].[Product] p

	left join PriceList pl on pl.ProductId = p.Id
	INNER JOIN dbo.Category c ON c.Id = p.CategoryId
	INNER JOIN dbo.UOM u ON u.Id = p.UomId	
	inner join dbo.WareHouseStock whs on whs.ProductId = p.Id and whs.WareHouseId = @WareHouseId
	left join (select * from Cart where UserId=@CustId and IsActive=1) ca on ca.ProductId = p.Id
	WHERE p.Id = ISNULL(@Id, p.Id)
		AND p.IsActive = 1 AND pl.EndDate Is null

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.ViewYN = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetRolesDetails](@P_Id int)
as
begin
select Id,Code,Name,ViewYN,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate from Roles where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSales]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSales]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetSales](@Id int)
as
begin
 select s.*
 ,p.CategoryId
 ,p.ProductName
 ,p.Description
 ,p.Brand
 ,p.ProductCode
 ,p.UomId
 ,p.Qty
 ,p.Picture
 ,p.Discount
 ,c.FirstName+' '+c.LastName CustomerName
 ,c.MobileNumber
 ,c.FlatNo
 ,c.Floor
 ,c.BuildingName
 ,c.RoadNo
 ,c.ColonyName
 ,c.CityName
 ,c.PinCode
 ,c.StateId
 ,cat.Name CategoryName
 ,cat.Picture CategoryURL
 ,uom.Name UOMName
 ,st.Name StateName
 from Sales s
 inner join Product p on p.Id = s.ProductId
 inner join Customer c on c.Id = s.UserId
 inner join Category cat on cat.Id = p.CategoryId
 inner join UOM uom on uom.Id = p.UomId
 inner join States st on st.Id = c.StateId
 where s.Id = ISNULL(@Id,s.Id)
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetSlotDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSlotDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_GetSlotDetails](@Id int)
as
begin
select Id,StartTime,EndTime,StartTime+'-'+EndTime Slot,NoOfOrders,IsActive,CreatedDate,CreatedByUserId,
UpdatedDate,UpdatedByUserId from Slot where Id = isnull(@Id,Id)  --and IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSlotDTLDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSlotDTLDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetSlotDTLDetails](@Id int)
as
begin
  select * from SlotDTL sd where sd.Id =isnull(@Id,sd.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSlotHDRDates]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSlotHDRDates]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetSlotHDRDates]
as
begin
select distinct SlotDate from SlotHDR where 
IsActive=1 and SlotDate>=cast(getdate() as date)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSlotHDRDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSlotHDRDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetSlotHDRDetails](@Id int)
as
begin
  select *,case when SlotDate>=cast(getdate() as Date) then 'false' else 'true' end Status
  from SlotHDR sh where sh.Id =isnull(@Id,sh.Id) and sh.IsActive =1 order by Id desc
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetStatesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStatesDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetStatesDetails](@P_Id int)
as
begin
select Id,Code,Name,IsActive,CreatedByUserId,CreatedDate from States where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStock]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetStock] (@P_Id int)
as
begin
select s.*,p.ProductName,s.AvailableStocks as AvailableStock from Stock s 
inner join Product p on p.Id=s.ProductId
where s.Id = isnull(@P_Id,s.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockByCurrentDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockByCurrentDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetStockByCurrentDate]
as
begin
select s.*,p.ProductName,s.AvailableStocks as AvailableStock from Stock s 
inner join Product p on p.Id=s.ProductId
--where cast (s.UpdatedDate as date) = cast(getdate() as date)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetailsByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetailsByProductId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetStockDetailsByProductId] (@ProductId varchar(200))
as
begin
select s.*,p.ProductName,s.AvailableStocks as AvailableStock from Stock s 
inner join Product p on p.Id=s.ProductId
--where s.ProductId in (select * from dbo.splitstring(@ProductId))
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetailsByWareHouseIdProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetailsByWareHouseIdProductId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetStockDetailsByWareHouseIdProductId 1,1
CREATE procedure [dbo].[SP_GetStockDetailsByWareHouseIdProductId] (@ProductId int,@WareHouseId int)
as
begin
declare @WId int
if @WareHouseId is null
begin
set @WId = 1
end
else
begin
set @WId = @WareHouseId
end

select distinct s.Id,p.ProductName,isnull(s.TotalStock,0) as TotalStocks,wh.Name,
isnull(s.AvailableStock,0) as AvailableStocks,s.WareHouseId from WareHouseStock s 
inner join WareHouse wh on wh.Id = isnull(@WId,wh.Id)
right join Product p on p.Id=s.ProductId and s.WareHouseId = isnull(@WId,s.WareHouseId) where p.IsActive = 1
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetSubscription]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSubscription]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetSubscription] (@P_Id int,@Customer_Id int)
as
begin
select s.*,p.ProductName,p.Picture,p.Qty,p.DetailedDescription,pl.ProductPrice from Subscription s
inner join Product p on p.Id=s.ProductId
inner join PriceList pl on pl.ProductId = p.Id
where s.Id=isnull(@P_Id,s.Id) and s.IsActive=1 and p.IsActive=1 and CustomerId=@Customer_Id and pl.EndDate Is null
order by CreatedDate desc
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetSubscriptionDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSubscriptionDetailsById]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetSubscriptionDetailsById null
CREATE PROCEDURE [dbo].[SP_GetSubscriptionDetailsById] (@P_Id INT)
AS
BEGIN
	SELECT s.[Id]
	,C.Name as CustomerName
	,(Ca.AddressName+','+Ca.Address+','+Ca.FlatNo+','+Ca.Area) as CustomerAddress
	,p.ProductName 
	  ,s.StartDate
	  ,s.SubscribeObject
	  ,s.IsPause
      ,s.[IsActive]
      ,s.[CreatedDate]
      ,s.[CreatedByUserId]
      ,s.[UpdatedDate]
      ,s.[UpdatedByUserId]
  FROM [dbo].[Subscription] s
  Inner Join dbo.Customer C ON s.CustomerId=C.Id
  Inner join dbo.CustomerAddress Ca ON s.CustomerAddressId=Ca.Id
  Inner join dbo.Product p ON s.ProductId=p.Id
  WHERE s.Id = ISNULL(@P_Id, s.Id)
  AND s.IsActive = 1 

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSubscriptionDetailsByWarehouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSubscriptionDetailsByWarehouseId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetSubscriptionDetailsById null
CREATE PROCEDURE [dbo].[SP_GetSubscriptionDetailsByWarehouseId] (@WareHouseId INT)
AS
BEGIN
	SELECT s.[Id]
	,C.Name as CustomerName
	,
	(Ca.FlatNo+','+ Ca.Area + ',' +Ca.Address)  as CustomerAddress
	,p.ProductName 
	  ,s.StartDate
	  ,s.SubscribeObject
	  ,s.IsPause
      ,s.[IsActive]
      ,s.[CreatedDate]
      ,s.[CreatedByUserId]
      ,s.[UpdatedDate]
      ,s.[UpdatedByUserId]
	  ,w.Name
  FROM [dbo].[Subscription] s
  Inner Join dbo.Customer C ON s.CustomerId=C.Id
  Inner join dbo.CustomerAddress Ca ON s.CustomerAddressId=Ca.Id
  Inner join dbo.Product p ON s.ProductId=p.Id
  Inner Join WareHouse w on w.Id = s.WareHouseId
  WHERE s.WareHouseId = ISNULL(@WareHouseId, s.WareHouseId)
  AND s.IsActive = 1 

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUomDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUomDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetUomDetails](@P_Id int)
as
begin
select Id,Code,Name,IsActive,CreatedByUserId,CreatedDate ,UpdatedDate from UOM where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAppVersions]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAppVersions]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetUserAppVersions](@P_Id int)
as
begin
select Id,UserID,AppVersion,DBVersion,Environment,ForceUpdate,IsActive,CreatedByUserId,CreatedDate ,UpdatedDate from UserAppVersions where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserByMobileNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserByMobileNo]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE proc [dbo].[SP_GetUserByMobileNo](@MobileNo bigint)
as
begin
select Id,Name from Customer where MobileNo = @MobileNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetUsersDetails](@P_Id int)
as
begin
select u.Id,u.UserName ,
u.Password ,
u.RoleId ,
u.EmpId ,
u.FirstName ,
u.MiddleName ,
u.LastName ,
u.Email ,
u.MobileNo,
u.DOJ,
u.ViewYN ,
u.CreatedDate,
u.CreatedByUserId,
u.UpdatedDate,
u.UpdatedByUserId,r.Name from Users u
left join Roles r on u.RoleId=r.Id where u.Id=isnull(@P_Id,u.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetVillageDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVillageDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetVillageDetails](@P_Id int)
as
begin
select Id,Code,Name,MandalId,PinCode,IsActive,CreatedByUserId,CreatedDate from Village where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWalletBalance]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWalletBalance]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetWalletBalance 17
CREATE Proc [dbo].[SP_GetWalletBalance](@CustomerId int)
as
begin
declare @Credit float,@Debit float
set @Credit =(select sum(Amount) from WalletTransaction where CustomerId=@CustomerId and TransactionType=1)

set @Debit =(select isnull(sum(Amount),0) from WalletTransaction where CustomerId=@CustomerId and TransactionType=-1)

select cast(@Credit - @Debit as decimal(18,2)) balance
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWalletTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWalletTransaction]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWalletTransaction] (@P_Id int)
as
begin
select Id,CustomerId,Amount,TransactionDate,TransactionType,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from WalletTransaction where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseDetails](@Id int)
as
begin
 select * from WareHouse wh where wh.Id = ISNULL(@Id,wh.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseServiceLocationByPinCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseServiceLocationByPinCode]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseServiceLocationByPinCode](@PinCode int)
as
begin
 select * from WareHouseServiceLocation whsl where whsl.IsActive=1 and whsl.PinCode = ISNULL(@PinCode,whsl.PinCode)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseServiceLocationByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseServiceLocationByWareHouseId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseServiceLocationByWareHouseId](@WareHouseId int)
as
begin
 select
 whsl.WareHouseId,
 whsl.PinCode,
 whsl.Id,
 whsl.IsActive,
 whsl.UpdatedDate,
 whsl.UpdatedByUserId,
 whsl.CreatedDate,
 whsl.CreatedByUserId,
 w.Name as warehouseName
 
 from WareHouseServiceLocation whsl
 
 inner join  WareHouse w on w.Id = whsl.WareHouseId   where  whsl.WareHouseId = ISNULL(@WareHouseId,whsl.WareHouseId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseServiceLocationDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseServiceLocationDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseServiceLocationDetails](@Id int)
as
begin
 select
 whsl.WareHouseId,
 whsl.PinCode,
 whsl.Id,
 whsl.IsActive,
 whsl.UpdatedDate,
 whsl.UpdatedByUserId,
 whsl.CreatedDate,
 whsl.CreatedByUserId,
 w.Name as warehouseName
 
 from WareHouseServiceLocation whsl
 
 inner join  WareHouse w on w.Id = whsl.WareHouseId   where  whsl.Id = ISNULL(@Id,whsl.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseStockDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseStockDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetWareHouseStockDetails](@Id int)
as
begin
select * from WareHouseStock whs where whs.IsActive =1 and whs.Id = ISNULL(@Id,whs.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseStockDetailsByWarehouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseStockDetailsByWarehouseId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetWareHouseStockDetailsByWarehouseId](@WareHouseId int)
as
begin
select whs.AvailableStock,whs.TotalStock,whs.IsActive,whs.ProductId,P.ProductName
from WareHouseStock whs 
right join Product p On P.Id = whs.ProductId
where whs.IsActive =1 and whs.WareHouseId = ISNULL(@WareHouseId,whs.WareHouseId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_PauseSubscriptionByCustomerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_PauseSubscriptionByCustomerId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_PauseSubscriptionByCustomerId](@CustomerId int,@IsPause bit)
as
begin
update Subscription set IsPause=@IsPause where CustomerId=@CustomerId
end
GO

-- %% [markdown]
-- # [dbo].[SP_PauseSubscriptionById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_PauseSubscriptionById]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_PauseSubscriptionById](@Id int,@IsPause bit)
as
begin
update Subscription set IsPause=@IsPause where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_ProductvalidationForPriceList]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ProductvalidationForPriceList]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create  procedure [dbo].[SP_ProductvalidationForPriceList](@ProductId Int)
as
begin
select Count(*) Cnt From PriceList P

where P.ProductId=isnull(@ProductId,ProductId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_PushNotificationForWalletBalace]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_PushNotificationForWalletBalace]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_PushNotificationForWalletBalace
CREATE Proc [dbo].[SP_PushNotificationForWalletBalace]
as
begin
select CustomerId, sum(Amount) CreditAmount into #CustCredit from WalletTransaction where TransactionType=1 
group by CustomerId
select CustomerId, isnull(sum(Amount),0) DebitAmount into #CustDebit from WalletTransaction where TransactionType=-1 
group by CustomerId

select cc.CustomerId,cc.CreditAmount - cd.DebitAmount Balance into #CustBalance from #CustCredit cc
left join #CustDebit cd on cc.CustomerId = cd.CustomerId

SELECT  sub.CustomerId,sub.CustomerAddressId,sub.ProductId,sub.SubscribeObject
,JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3)) AS Qty,pl.ProductPrice
,(JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))*pl.ProductPrice) PriceWithOutDiscount
,cast((JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))*pl.ProductPrice)as decimal(18,2))
-CEILING((cast((p.Discount/100) as decimal(18,2)))*(pl.ProductPrice*JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3)))) PriceWithDiscount
,CEILING((cast((p.Discount/100) as decimal(18,2)))*(pl.ProductPrice*JSON_VALUE(SubscribeObject,'$.'+LEFT(DATENAME(WEEKDAY, getdate()), 3))))
as DiscountAmount,p.Discount DiscountPer,cb.Balance into #Temp
FROM Subscription  sub
inner join Product p on p.Id =sub.ProductId
inner join PriceList pl on pl.ProductId = sub.ProductId
inner join #CustBalance cb on cb.CustomerId = sub.CustomerId
where sub.IsPause=0 and sub.IsActive=1 and pl.EndDate is null 
and CAST(sub.StartDate as Date)<=CAST(getdate() as date) 

DECLARE @CustId int
DECLARE @NoOfRecords int
Declare @myresultset Cursor
Create table #PushNotification(CustomerId int,Message varchar(250),CreatedDate datetime)
Set @myresultset = CURSOR for select CustomerId,COUNT(*) NoOfRecords
from #Temp where Qty !=0 and PriceWithDiscount>Balance group by CustomerId
OPEN @myresultset 
Fetch NEXT from @myresultset
into @CustId,@NoOfRecords
While @@Fetch_Status=0
Begin
  insert into #PushNotification(CustomerId,Message,CreatedDate)
  values(@CustId,'Your Wallet Balance is Low',getdate())
 Fetch Next from @myresultset
 into @CustId,@NoOfRecords
End
close @myresultset
select * from #PushNotification
drop table #Temp
drop table #CustCredit
drop table #CustDebit
drop table #CustBalance
drop table #PushNotification
end
GO

-- %% [markdown]
-- # [dbo].[SP_RemoveCartItems]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_RemoveCartItems]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[SP_RemoveCartItems](@ProductId int,@UserId int)
as
begin
update Cart set IsActive=0 where ProductId=@ProductId and CreatedByUserId=@UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_RemoveSlotDTLByHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_RemoveSlotDTLByHDRId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_RemoveSlotDTLByHDRId](@Id int)
as
begin
 Update SlotDTL set IsActive=0 where SlotHDRId=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_ResetUserPassword]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ResetUserPassword]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_ResetUserPassword] (@Password varchar(255),@Id int)
as
begin
update Users set Password  = @Password where Id = @Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_ResumeOrPauseAllSubscriptionDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ResumeOrPauseAllSubscriptionDetails]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_ResumeOrPauseAllSubscriptionDetails](@CustId int,@Status varchar(255))
as
begin
 if @Status = 'resume'
 begin
  update Subscription set IsPause=0 where CustomerId=@CustId
 end
 else
 begin
 update Subscription set IsPause=1 where CustomerId=@CustId
 end
end
GO

-- %% [markdown]
-- # [dbo].[SP_SlotDTLByHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SlotDTLByHDRId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_SlotDTLByHDRId](@Id int)
as
begin
select SlotId from SlotDTL where SlotHDRId=@Id and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateCustomerFCMToken]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateCustomerFCMToken]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdateCustomerFCMToken](@UserId int,@FCMToken varchar(3000))
as
begin
update Customer set FCMtoken=@FCMToken where Id = @UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateCustomerProfile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateCustomerProfile]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_UpdateCustomerProfile](
@Id int,
@Name varchar(255),
@EmailId varchar(300),
@ImgURL varchar(300),
@FCMtoken varchar(3000),
@UpdatedDate datetime,
@UpdatedByUserId int
)
as
begin
if @ImgURL != null
begin
  update Customer set Name =@Name,EmailId = @EmailId,ImgURL = @ImgURL,UpdatedDate = @UpdatedDate,UpdatedByUserId = @UpdatedByUserId
  where Id = @Id
  end
  else
  begin
   update Customer set Name =@Name,EmailId = @EmailId,UpdatedDate = @UpdatedDate,UpdatedByUserId = @UpdatedByUserId
  where Id = @Id
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateOrderStatus]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateOrderStatus]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_UpdateOrderStatus](@OrderNo varchar(50),@OrderStatus varchar(50),@UserId int,@ReasonForCancel Varchar(255))
as
begin
  Update OrderHdr set Status=@OrderStatus ,ReasonForCancel = @ReasonForCancel  where OrderNo=@OrderNo and CreatedByUserId=@UserId
  insert OrderNotification (OrderNo,Status,CreatedDate,CustomerId) values (@OrderNo,@OrderStatus,GETDATE(),@UserId)

  -- if Order Cancelled then add Order Amount to Wallet 
  if @OrderStatus = 'Cancel'
  begin
    declare @RefundAmount float 
	 DECLARE @dt datetime;
     DECLARE @OutWalletMessage varchar(3000)
     set @dt= getdate();
	set @RefundAmount = (select OrdValue from OrderHdr where OrderNo=@OrderNo and CreatedByUserId=@UserId);
	 exec SP_AddAutoWalletTransaction @Id=null,@CustomerId=@UserId,@Amount=@RefundAmount,@TransactionDate=@dt
,@TransactionType=1,@TransactionId='Refund',@IsActive=1,@CreatedDate=@dt,@CreatedByUserId=@UserId,@UpdatedDate=@dt
,@UpdatedByUserId=@UserId,@ErrorMessage=@OutWalletMessage output

  end

  if @OrderStatus = 'On the way'
  begin
DECLARE @ProductId int
DECLARE @Qty int
Declare @myresultset Cursor
Set @myresultset = CURSOR for select ProductId,Qty from OrderDtl where OrderNo in
(select OrderNo from OrderHdr where Status='On the way' and OrderNo=@OrderNo)
OPEN @myresultset 
Fetch NEXT from @myresultset
into @ProductId,@Qty
While @@Fetch_Status=0
Begin
  update Stock set TotalStocks=TotalStocks-@Qty where ProductId=@ProductId
 Fetch Next from @myresultset
 into @ProductId,@Qty
End
close @myresultset
 end
  else if @OrderStatus = 'Cancel'
  begin
 DECLARE @ProductId1 int
DECLARE @Qty1 int
Declare @myresultset1 Cursor
Set @myresultset1 = CURSOR for select ProductId,Qty from OrderDtl where OrderNo in
(select OrderNo from OrderHdr where Status='Cancel' and OrderNo=@OrderNo)
OPEN @myresultset1 
Fetch NEXT from @myresultset1
into @ProductId1,@Qty1
While @@Fetch_Status=0
Begin
  update Stock set AvailableStocks=AvailableStocks+@Qty1 where ProductId=@ProductId1


 Fetch Next from @myresultset1
 into @ProductId1,@Qty1
End
close @myresultset1
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateOrderStatusByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateOrderStatusByWareHouseId]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_UpdateOrderStatusByWareHouseId](@OrderNo varchar(50),@OrderStatus varchar(50),@UserId int,@WareHouseId int)
as
begin
  Update OrderHdr set Status=@OrderStatus where OrderNo=@OrderNo and CreatedByUserId=@UserId
  insert OrderNotification (OrderNo,Status,CreatedDate,CustomerId) values (@OrderNo,@OrderStatus,GETDATE(),@UserId)

  -- if Order Cancelled then add Order Amount to Wallet 
  if @OrderStatus = 'Cancel'
  begin
    declare @RefundAmount float 
	 DECLARE @dt datetime;
     DECLARE @OutWalletMessage varchar(3000)
     set @dt= getdate();
	set @RefundAmount = (select OrdValue from OrderHdr where OrderNo=@OrderNo and CreatedByUserId=@UserId);
	 exec SP_AddAutoWalletTransaction @Id=null,@CustomerId=@UserId,@Amount=@RefundAmount,@TransactionDate=@dt
,@TransactionType=1,@TransactionId='Refund',@IsActive=1,@CreatedDate=@dt,@CreatedByUserId=@UserId,@UpdatedDate=@dt
,@UpdatedByUserId=@UserId,@ErrorMessage=@OutWalletMessage output

  end

  if @OrderStatus = 'On the way'
  begin
DECLARE @ProductId int
DECLARE @Qty int
Declare @myresultset Cursor
Set @myresultset = CURSOR for select ProductId,Qty from OrderDtl where OrderNo in
(select OrderNo from OrderHdr where Status='On the way' and OrderNo=@OrderNo)
OPEN @myresultset 
Fetch NEXT from @myresultset
into @ProductId,@Qty
While @@Fetch_Status=0
Begin
  --update Stock set TotalStocks=TotalStocks-@Qty where ProductId=@ProductId
  update WareHouseStock set TotalStock=TotalStock-@Qty where ProductId=@ProductId and WareHouseId = @WareHouseId
 Fetch Next from @myresultset
 into @ProductId,@Qty
End
close @myresultset
 end
  else if @OrderStatus = 'Cancel'
  begin
 DECLARE @ProductId1 int
DECLARE @Qty1 int
Declare @myresultset1 Cursor
Set @myresultset1 = CURSOR for select ProductId,Qty from OrderDtl where OrderNo in
(select OrderNo from OrderHdr where Status='Cancel' and OrderNo=@OrderNo)
OPEN @myresultset1 
Fetch NEXT from @myresultset1
into @ProductId1,@Qty1
While @@Fetch_Status=0
Begin
  --update Stock set AvailableStocks=AvailableStocks+@Qty1 where ProductId=@ProductId1
  update WareHouseStock set AvailableStock=AvailableStock+@Qty1 where ProductId=@ProductId1 and WareHouseId = @WareHouseId
 Fetch Next from @myresultset1
 into @ProductId1,@Qty1
End
close @myresultset1
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdatePriceListEndDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdatePriceListEndDate]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdatePriceListEndDate](@PricelistId int,@StartDate datetime)
as
begin 
update PriceList set EndDate= @StartDate where Id =@PricelistId
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNo,
			u.Password
			,u.WareHouseId
			,w.Name as WareHouseName
		FROM Users u 
		left join WareHouse w on w.Id = u.WareHouseId
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END
GO

-- %% [markdown]
-- # [dbo].[SP_WalletTransactionHistory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_WalletTransactionHistory]    Script Date: 27-10-2023 15:01:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_WalletTransactionHistory](@CustomerId int)
as
begin
 select * from WalletTransaction where CustomerId =@CustomerId order by CreatedDate desc
end
GO
