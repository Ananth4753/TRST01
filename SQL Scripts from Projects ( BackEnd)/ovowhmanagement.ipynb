-- %% [markdown]
-- # [dbo].[Flock]

-- %%
USE [ovowhmanagement]
GO

-- %%
/****** Object:  Table [dbo].[Flock]    Script Date: 27-10-2023 15:21:36 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Flock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[Area] [float] NOT NULL,
	[Location] [varchar](255) NULL,
	[IsAcive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdateByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupDtl]

-- %%
/****** Object:  Table [dbo].[LookupDtl]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LookupHdrId] [int] NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[OrdinalPosition] [int] NULL,
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupHdr]

-- %%
/****** Object:  Table [dbo].[LookupHdr]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingMaterialHistory]

-- %%
/****** Object:  Table [dbo].[PackingMaterialHistory]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingMaterialHistory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SummaryDate] [datetime] NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[PackingMaterialId] [int] NOT NULL,
	[OpeningStock] [int] NOT NULL,
	[ClosingStock] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingMaterials]

-- %%
/****** Object:  Table [dbo].[PackingMaterials]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingMaterials](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[Type] [varchar](255) NULL,
	[AvailableStock] [int] NOT NULL,
	[UOMId] [int] NULL,
	[IsAcive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdateByUserId] [int] NOT NULL,
	[WareHouseId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingMaterialTransaction]

-- %%
/****** Object:  Table [dbo].[PackingMaterialTransaction]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingMaterialTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PackingMaterialId] [int] NOT NULL,
	[TransactionTypeId] [int] NOT NULL,
	[Stock] [int] NOT NULL,
	[TransactionDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingSlipDTL]

-- %%
/****** Object:  Table [dbo].[PackingSlipDTL]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingSlipDTL](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PackingSlipHDRId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[Quantity] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[SkuId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingSlipHDR]

-- %%
/****** Object:  Table [dbo].[PackingSlipHDR]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingSlipHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[InTransit] [bit] NOT NULL,
	[IsInHouseTransfer] [bit] NOT NULL,
	[LossInTransit] [bit] NOT NULL,
	[GRNConfirmation] [bit] NOT NULL,
	[DaysInTransit] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[Status] [int] NULL,
	[Type] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingSlipStatus]

-- %%
/****** Object:  Table [dbo].[PackingSlipStatus]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingSlipStatus](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PackingSlipHDRId] [int] NOT NULL,
	[StatusId] [int] NOT NULL,
	[CreatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CategoryId] [int] NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[Description] [varchar](255) NULL,
	[BrandId] [int] NOT NULL,
	[ProductCode] [varchar](255) NOT NULL,
	[Qty] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[Classification] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductBarCode]

-- %%
/****** Object:  Table [dbo].[ProductBarCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductBarCode](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BatchId] [varchar](200) NULL,
	[FlockId] [int] NOT NULL,
	[StackId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[SkuId] [int] NOT NULL,
	[PackedDate] [datetime] NOT NULL,
	[NoOfQuantity] [int] NOT NULL,
	[Url] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UniqueId] [varchar](3000) NULL,
	[IsRepacking] [bit] NULL,
	[RePackingBatchId] [int] NULL,
	[RePackingQty] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [ProductBarCode_BatchId] UNIQUE NONCLUSTERED 
(
	[BatchId] ASC,
	[ProductId] ASC,
	[WareHouseId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [ProductBarCode_UniqueId] UNIQUE NONCLUSTERED 
(
	[UniqueId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SKU]

-- %%
/****** Object:  Table [dbo].[SKU]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SKU](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[code] [varchar](20) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[UOM] [int] NOT NULL,
	[Qty] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[IsAcive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdateByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SKUPackingMaterial]

-- %%
/****** Object:  Table [dbo].[SKUPackingMaterial]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SKUPackingMaterial](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SKUId] [int] NOT NULL,
	[PackingMaterialName] [int] NOT NULL,
	[Qty] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Stack]

-- %%
/****** Object:  Table [dbo].[Stack]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Stack](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[Area] [float] NOT NULL,
	[Location] [varchar](255) NULL,
	[URL] [varchar](500) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdateByUserId] [int] NOT NULL,
	[UniqueId] [varchar](3000) NULL,
	[Printcode] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [Stack_UniqueId] UNIQUE NONCLUSTERED 
(
	[UniqueId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](255) NULL,
	[Password] [varchar](255) NULL,
	[RoleId] [int] NULL,
	[FirstName] [varchar](255) NULL,
	[LastName] [varchar](255) NULL,
	[Email] [varchar](255) NULL,
	[MobileNo] [bigint] NULL,
	[ViewYN] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[WareHouseId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouse]

-- %%
/****** Object:  Table [dbo].[WareHouse]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouse](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NULL,
	[ContactName] [varchar](100) NULL,
	[ContactNo] [bigint] NULL,
	[Address] [varchar](1000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouseServiceLocation]

-- %%
/****** Object:  Table [dbo].[WareHouseServiceLocation]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouseServiceLocation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NULL,
	[PinCode] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[PinCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouseStock]

-- %%
/****** Object:  Table [dbo].[WareHouseStock]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouseStock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[StackId] [int] NULL,
	[BatchId] [int] NULL,
	[Stock] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WarehouseStockHistory]

-- %%
/****** Object:  Table [dbo].[WarehouseStockHistory]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WarehouseStockHistory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SummaryDate] [datetime] NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[StackId] [int] NULL,
	[BatchId] [int] NULL,
	[OpeningStock] [int] NOT NULL,
	[ClosingStock] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WareHouseStockTransaction]

-- %%
/****** Object:  Table [dbo].[WareHouseStockTransaction]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WareHouseStockTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WareHouseId] [int] NOT NULL,
	[TransactionTypeId] [int] NOT NULL,
	[ProductId] [int] NOT NULL,
	[StackId] [int] NULL,
	[BatchId] [int] NULL,
	[Stock] [int] NULL,
	[InTransit] [bit] NOT NULL,
	[IsInHouseTransfer] [bit] NOT NULL,
	[LossInTransit] [bit] NOT NULL,
	[GRNConfirmation] [bit] NOT NULL,
	[DaysInTransit] [int] NULL,
	[TransactionDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Flock__IsAcive__4F47C5E3]

-- %%
ALTER TABLE [dbo].[Flock] ADD  DEFAULT ((1)) FOR [IsAcive]
GO

-- %% [markdown]
-- # [DF__Flock__CreatedDa__503BEA1C]

-- %%
ALTER TABLE [dbo].[Flock] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Flock__UpdatedDa__51300E55]

-- %%
ALTER TABLE [dbo].[Flock] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__440B1D61]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__ViewYN__44FF419A]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__45F365D3]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__46E78A0C]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__47DBAE45]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__48CFD27E]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__PackingMa__IsAct__756D6ECB]

-- %%
ALTER TABLE [dbo].[PackingMaterialHistory] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PackingMa__Creat__76619304]

-- %%
ALTER TABLE [dbo].[PackingMaterialHistory] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PackingMa__Updat__7755B73D]

-- %%
ALTER TABLE [dbo].[PackingMaterialHistory] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PackingMa__IsAci__65F62111]

-- %%
ALTER TABLE [dbo].[PackingMaterials] ADD  DEFAULT ((1)) FOR [IsAcive]
GO

-- %% [markdown]
-- # [DF__PackingMa__Creat__66EA454A]

-- %%
ALTER TABLE [dbo].[PackingMaterials] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PackingMa__Updat__67DE6983]

-- %%
ALTER TABLE [dbo].[PackingMaterials] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PackingMa__Trans__7A3223E8]

-- %%
ALTER TABLE [dbo].[PackingMaterialTransaction] ADD  DEFAULT (getdate()) FOR [TransactionDate]
GO

-- %% [markdown]
-- # [DF__PackingMa__IsAct__7B264821]

-- %%
ALTER TABLE [dbo].[PackingMaterialTransaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PackingMa__Creat__7C1A6C5A]

-- %%
ALTER TABLE [dbo].[PackingMaterialTransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PackingMa__Updat__7D0E9093]

-- %%
ALTER TABLE [dbo].[PackingMaterialTransaction] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PackingSl__IsAct__3552E9B6]

-- %%
ALTER TABLE [dbo].[PackingSlipDTL] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PackingSl__IsAct__39237A9A]

-- %%
ALTER TABLE [dbo].[PackingSlipHDR] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PackingSl__Creat__3A179ED3]

-- %%
ALTER TABLE [dbo].[PackingSlipHDR] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PackingSl__Updat__3B0BC30C]

-- %%
ALTER TABLE [dbo].[PackingSlipHDR] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PackingSl__Creat__589C25F3]

-- %%
ALTER TABLE [dbo].[PackingSlipStatus] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__4D94879B]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__4E88ABD4]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__4F7CD00D]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__ViewYN__5070F446]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__5165187F]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__52593CB8]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__ViewYN__3A81B327]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__3B75D760]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__3C69FB99]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Stack__CreatedDa__13F1F5EB]

-- %%
ALTER TABLE [dbo].[Stack] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Stack__UpdatedDa__14E61A24]

-- %%
ALTER TABLE [dbo].[Stack] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Creat__68487DD7]

-- %%
ALTER TABLE [dbo].[WareHouse] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Updat__693CA210]

-- %%
ALTER TABLE [dbo].[WareHouse] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Creat__6E01572D]

-- %%
ALTER TABLE [dbo].[WareHouseServiceLocation] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WareHouse__Updat__6EF57B66]

-- %%
ALTER TABLE [dbo].[WareHouseServiceLocation] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Warehouse__IsAct__2610A626]

-- %%
ALTER TABLE [dbo].[WarehouseStockHistory] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Warehouse__Creat__2704CA5F]

-- %%
ALTER TABLE [dbo].[WarehouseStockHistory] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Warehouse__Updat__27F8EE98]

-- %%
ALTER TABLE [dbo].[WarehouseStockHistory] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK_Menu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Menu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK__Roles__CreatedBy__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK_Roles_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Roles_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_UpdatedByUserId]
GO

-- %% [markdown]
-- # [dbo].[addFlock]

-- %%
/****** Object:  StoredProcedure [dbo].[addFlock]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[addFlock]
(
@Id as int,
@Name as varchar(255),
@Area as float,
@Location as varchar(255) = Null,
@IsAcive as bit = 1,
@CreatedDate as datetime = getdate,
@CreatedByUserId as int,
@UpdatedDate as datetime = getdate,
@UpdateByUserId as int
)
AS

-- Author: Mohan Krishna
-- Created: 29 Dec 2022
-- Procedure: Inserts a dbo.Flock

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0 begin
insert [dbo].[Flock] (Name,Area,Location,IsAcive,CreatedDate,CreatedByUserId,UpdatedDate,UpdateByUserId)
values (@Name,@Area,@Location,@IsAcive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdateByUserId)


-- Return the new ID
select SCOPE_IDENTITY();

end else begin

update [dbo].[Flock] set
		Name = coalesce(@Name, Name),
		Area = coalesce(@Area, Area),
		Location = coalesce(@Location, Location),
		IsAcive = coalesce(@IsAcive, IsAcive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdateByUserId = coalesce(@UpdateByUserId, UpdateByUserId)
where Id = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;


GO

-- %% [markdown]
-- # [dbo].[addpackingMaterials]

-- %%
/****** Object:  StoredProcedure [dbo].[addpackingMaterials]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[addpackingMaterials]
(
@Id as int,
@Name as varchar(255),
@Type as varchar(255) = Null,
@AvailableStock as int,
@UOMId as int,
@WareHouseId as int,
@IsAcive as bit = 1,
@CreatedDate as datetime = getdate,
@CreatedByUserId as int,
@UpdatedDate as datetime = getdate,
@UpdateByUserId as int
)
AS

-- Author: Mohan Krishna
-- Created: 29 Dec 2022
-- Procedure: Inserts a dbo.packingMaterials

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0 begin
insert [dbo].[packingMaterials] (Name,Type,AvailableStock,UOMId,WareHouseId,IsAcive,CreatedDate,CreatedByUserId,UpdatedDate,UpdateByUserId)
values (@Name,@Type,@AvailableStock,@UOMId,@WareHouseId,@IsAcive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdateByUserId)


-- Return the new ID
select SCOPE_IDENTITY();

end else begin

update [dbo].[packingMaterials] set
		Name = coalesce(@Name, Name),
		Type = coalesce(@Type, Type),
		AvailableStock = coalesce(@AvailableStock, AvailableStock),
		WareHouseId = coalesce(@WareHouseId, WareHouseId),
		UOMId = coalesce(@UOMId, UOMId),
		IsAcive = coalesce(@IsAcive, IsAcive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdateByUserId = coalesce(@UpdateByUserId, UpdateByUserId)
where Id = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;


GO

-- %% [markdown]
-- # [dbo].[addProductBarCode]

-- %%
/****** Object:  StoredProcedure [dbo].[addProductBarCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[addProductBarCode]
(
@Id as int,
@BatchId as Varchar(200),
@FlockId as int,
@StackId as int,
@ProductId as int,
@WareHouseId as int,
@SkuId as int,
@PackedDate as datetime,
@NoOfQuantity as int,
@IsRepacking as bit,
@RePackingBatchId int,
@RePackingQty int,
@IsActive as bit,
@CreatedDate as datetime,
@CreatedByUserId as int,
@UpdatedDate as datetime,
@UpdatedByUserId as int
)
AS

-- Author: Mohan Krishna
-- Created: 29 Dec 2022
-- Procedure: Inserts a dbo.ProductBarCode

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0 begin
  declare @UniqueId varchar(255)
 set @UniqueId = newId()
insert [dbo].[ProductBarCode] (BatchId,FlockId,StackId,ProductId,WareHouseId,SkuId,PackedDate,NoOfQuantity,IsRepacking,RePackingBatchId,RePackingQty,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId,UniqueId)
values (@BatchId,@FlockId,@StackId,@ProductId,@WareHouseId,@SkuId,@PackedDate,@NoOfQuantity,@IsRepacking,@RePackingBatchId,@RePackingQty,@IsActive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdatedByUserId,@UniqueId)


update p set p.AvailableStock =  p.AvailableStock - (@NoOfQuantity*s.qty)
from PackingMaterials p join SkuPackingMaterial s on p.id = s.packingmaterialname
where s.skuid = @SkuId and s.IsActive =1


 declare @url varchar(500),@OutId int
 set @OutId = @@IDENTITY
  update ProductBarCode set URL='https://ovotrace.trst01.in/'+ cast (@WareHouseId as varchar) +'/'+   @UniqueId where Id = @OutId
-- Return the new ID




select SCOPE_IDENTITY();
insert into WareHouseStock(WareHouseId,ProductId,Stock,IsActive,CreatedByUserId,CreatedDate,
      UpdatedByUserId,UpdatedDate,StackId,BatchId)values(@WareHouseId,@ProductId,@NoOfQuantity,@IsActive,@CreatedByUserId,
	  getdate(),@UpdatedByUserId,getdate(),@StackId,@BatchId)
end else begin

update [dbo].[ProductBarCode] set
		BatchId = coalesce(@BatchId, BatchId),
		FlockId = coalesce(@FlockId, FlockId),
		StackId = coalesce(@StackId, StackId),
		ProductId = coalesce(@ProductId, ProductId),
		WareHouseId = coalesce(@WareHouseId, WareHouseId),
		SkuId = coalesce(@SkuId, SkuId),
		PackedDate = coalesce(@PackedDate, PackedDate),
		NoOfQuantity = coalesce(@NoOfQuantity, NoOfQuantity),
		IsRepacking = coalesce(@IsRepacking, IsRepacking),
		RePackingBatchId = coalesce(@RePackingBatchId, RePackingBatchId),
		RePackingQty = coalesce(@RePackingQty, RePackingQty),
		IsActive = coalesce(@IsActive, IsActive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdatedByUserId = coalesce(@UpdatedByUserId, UpdatedByUserId)
where Id = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;






GO

-- %% [markdown]
-- # [dbo].[addSku]

-- %%
/****** Object:  StoredProcedure [dbo].[addSku]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[addSku]
(
@Id as int,
@code as varchar(20),
@Name as varchar(255),
@UOM as int,
@Qty as int,
@ProductId as int,
@IsAcive as bit = 1,
@CreatedDate as datetime = getdate,
@CreatedByUserId as int,
@UpdatedDate as datetime = getdate,
@UpdateByUserId as int,
@SKUId as int output
)
AS

-- Author: Mohan Krishna
-- Created: 29 Dec 2022
-- Procedure: Inserts a dbo.Sku

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0 begin
insert [dbo].[SKU] (code,Name,UOM,Qty,ProductId,IsAcive,CreatedDate,CreatedByUserId,UpdatedDate,UpdateByUserId)
values (@code,@Name,@UOM,@Qty,@ProductId,@IsAcive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdateByUserId)
set @SKUId = @@IDENTITY


-- Return the new ID
select SCOPE_IDENTITY();

end else begin

update [dbo].[SKU] set
		code = coalesce(@code, code),
		Name = coalesce(@Name, Name),
		UOM = coalesce(@UOM, UOM),
		Qty = coalesce(@Qty,Qty),
		ProductId = coalesce(@ProductId, ProductId),
		IsAcive = coalesce(@IsAcive, IsAcive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdateByUserId = coalesce(@UpdateByUserId, UpdateByUserId)
where Id = @Id
set @SKUId = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;


GO

-- %% [markdown]
-- # [dbo].[addStack]

-- %%
/****** Object:  StoredProcedure [dbo].[addStack]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROC [dbo].[addStack]
(
@Id as int,
@WareHouseId as int,
@Printcode as varchar(50),
@Name as varchar(255),
@Area as float,
@Location as varchar(255) = Null,
@IsActive as bit = 1,
@CreatedDate as datetime = getdate,
@CreatedByUserId as int,
@UpdatedDate as datetime = getdate,
@UpdateByUserId as int
)
AS

-- Author: Mohan Krishna
-- Created: 29 Dec 2022
-- Procedure: Inserts a dbo.Stack

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0
 begin
 declare @UniqueId varchar(500)
 set @UniqueId = newId()
insert [dbo].[Stack] (WareHouseId,Printcode,Name,Area,Location,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdateByUserId,UniqueId)
values (@WareHouseId,@Printcode,@Name,@Area,@Location,@IsActive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdateByUserId,@UniqueId)
 declare @url varchar(500),@OutId int
 set @OutId = @@IDENTITY
 update Stack set URL='https://ovotrace.trst01.in/Stack/' + CAST(@WareHouseId as varchar) +'/'  + @UniqueId where Id = @OutId

-- Return the new ID
select SCOPE_IDENTITY();

end else begin

update [dbo].[Stack] set
		WareHouseId = coalesce(@WareHouseId, WareHouseId),
		Printcode = coalesce(@Printcode,Printcode),
		Name = coalesce(@Name, Name),
		Area = coalesce(@Area, Area),
		Location = coalesce(@Location, Location),
		IsActive = coalesce(@IsActive, IsActive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdateByUserId = coalesce(@UpdateByUserId, UpdateByUserId)
where Id = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;


GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupDtl]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddLookupDtl](
@Id int,
@LookupHdrId int,
@Code varchar(50),
@Name varchar(100),
@OrdinalPosition Int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int

)
as
begin
If isnull(@Id,0)=0
begin
insert into LookupDtl(
LookupHdrId,
Code,
Name,
OrdinalPosition,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@LookupHdrId,
@Code,
@Name,
@OrdinalPosition,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update LookupDtl Set LookupHdrId=@LookupHdrId, Code=@Code,Name=@Name,OrdinalPosition=@OrdinalPosition,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupHdr]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddLookupHdr] 
(
@Id int,
@Code Varchar(50)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookuphdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION

 

    BEGIN TRY
        IF ISNULL(@Id,0)=0
        BEGIN
            INSERT INTO [dbo].[LookupHdr] (
                 [Code]
                ,[Name]
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                 @Code
                ,@Name
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
                set @lookuphdrOUT = @@IDENTITY

 

            --update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
                END
        ELSE
        begin
            UPDATE [dbo].[LookupHdr]
            SET  Code=@Code,
                [Name] = @Name
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
            set @lookuphdrOUT = @Id
            end
    END TRY

 

    BEGIN CATCH
        SELECT @ErrorNumber = ERROR_NUMBER()
            ,@ErrorMessage = ERROR_MESSAGE()

 

        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
    END CATCH;

 

    IF @@TRANCOUNT > 0
        COMMIT TRANSACTION;

 

    SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPackingSlipDTL]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPackingSlipDTL]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[SP_AddPackingSlipDTL]
(
@Id as int,
@PackingSlipHDRId as int,
@ProductId as int,
@SkuId as int,
@Quantity as int,
@IsActive as bit = 1,
@CreatedDate as datetime,
@CreatedByUserId as int,
@UpdatedDate as datetime,
@UpdatedByUserId as int
)
AS

-- Author: Mohan Krishna
-- Created: 04 Jan 2023
-- Procedure: Inserts a dbo.PackingSlipDTL

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0 begin
insert [dbo].[PackingSlipDTL] (PackingSlipHDRId,ProductId,SkuId,Quantity,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId)
values (@PackingSlipHDRId,@ProductId,@SkuId,@Quantity,@IsActive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdatedByUserId)


-- Return the new ID
select SCOPE_IDENTITY();

end else begin

update [dbo].[PackingSlipDTL] set
		PackingSlipHDRId = coalesce(@PackingSlipHDRId, PackingSlipHDRId),
		ProductId = coalesce(@ProductId, ProductId),
		SkuId = coalesce(@SkuId, SkuId),
		Quantity = coalesce(@Quantity, Quantity),
		IsActive = coalesce(@IsActive, IsActive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdatedByUserId = coalesce(@UpdatedByUserId, UpdatedByUserId)
where Id = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;


GO

-- %% [markdown]
-- # [dbo].[SP_AddPackingSlipHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPackingSlipHDR]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROC [dbo].[SP_AddPackingSlipHDR]
(
@Id as int,
@WareHouseId as int,
@Code as varchar(50),
@InTransit as bit,
@IsInHouseTransfer as bit,
@LossInTransit as bit,
@Status as int,
@Type as int,
@GRNConfirmation as bit,
@DaysInTransit as int,
@IsActive as bit = 1,
@CreatedDate as datetime = getdate,
@CreatedByUserId as int,
@UpdatedDate as datetime = getdate,
@UpdatedByUserId as int,
@OutHDRId as int output
)
AS

-- Author: Mohan Krishna
-- Created: 04 Jan 2023
-- Procedure: Inserts a dbo.PackingSlipHDR

begin transaction

begin try

-- insert
 IF ISNULL(@Id,0) = 0 begin
insert [dbo].[PackingSlipHDR] 
(WareHouseId,Code,InTransit,IsInHouseTransfer,LossInTransit,GRNConfirmation,
DaysInTransit,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,
UpdatedByUserId,Status,Type)
values (@WareHouseId,@Code,@InTransit,@IsInHouseTransfer,@LossInTransit,
@GRNConfirmation,@DaysInTransit,@IsActive,@CreatedDate,@CreatedByUserId,@UpdatedDate,
@UpdatedByUserId,@Status,@Type)

set @OutHDRId = @@IDENTITY

end
else 
begin

update [dbo].[PackingSlipHDR] set
        WareHouseId = coalesce(@WareHouseId, WareHouseId),
		Code = coalesce(@Code, Code),
		InTransit = coalesce(@InTransit, InTransit),
		IsInHouseTransfer = coalesce(@IsInHouseTransfer, IsInHouseTransfer),
		LossInTransit = coalesce(@LossInTransit, LossInTransit),
		GRNConfirmation = coalesce(@GRNConfirmation, GRNConfirmation),
		DaysInTransit = coalesce(@DaysInTransit, DaysInTransit),
		IsActive = coalesce(@IsActive, IsActive),
		CreatedDate = coalesce(@CreatedDate, CreatedDate),
		CreatedByUserId = coalesce(@CreatedByUserId, CreatedByUserId),
		UpdatedDate = coalesce(@UpdatedDate, UpdatedDate),
		UpdatedByUserId = coalesce(@UpdatedByUserId, UpdatedByUserId),
		Status = coalesce(@Status, Status),
		Type = coalesce(@Status, Type)

where Id = @Id

set @OutHDRId = @Id

 end 
commit transaction

end try

begin catch

 declare @ErrorMessage NVARCHAR(4000);
 declare @ErrorSeverity INT;
 declare @ErrorState INT;

 select @ErrorMessage = ERROR_MESSAGE(), @ErrorSeverity = ERROR_SEVERITY(), @ErrorState = ERROR_STATE();

 raiserror (@ErrorMessage, @ErrorSeverity, @ErrorState);

 rollback transaction

end catch;


GO

-- %% [markdown]
-- # [dbo].[SP_AddPackingSlipStatus]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPackingSlipStatus]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




create procedure [dbo].[SP_AddPackingSlipStatus](
@Id int,
@PackingSlipHDRId int,
@StatusId int,
@CreatedDate datetime
)
as 
begin
If isnull(@Id,0)=0

begin
insert into PackingSlipStatus(
PackingSlipHDRId,
StatusId,
CreatedDate
)
values
(
@PackingSlipHDRId,
@StatusId,
@CreatedDate
)
end
else
begin

update PackingSlipStatus set PackingSlipHDRId=@PackingSlipHDRId,StatusId=@StatusId,CreatedDate=@CreatedDate where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProduct]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddProduct]
(@Id int ,
@CategoryId Int,
@Name varchar(255),
@Description varchar(255),
@BrandId int,

@ProductCode varchar(255),
@Qty int,
@Classification Int,
@IsActive bit ,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@OutProductId int output
)
as
begin
If isnull(@Id,0)=0
begin
insert into Product(
CategoryId,
Name ,
Description,
BrandId ,
ProductCode,
Qty ,
Classification,
IsActive ,
CreatedByUserId ,
CreatedDate ,
UpdatedByUserId ,
UpdatedDate
)
values(
@CategoryId,
@Name ,
@Description,
@BrandId ,
@ProductCode,
@Qty ,
@Classification,
@IsActive ,
@CreatedByUserId ,
@CreatedDate ,
@UpdatedByUserId ,
@UpdatedDate
)
declare @OutId int
set @OutId =@@IDENTITY
set @OutProductId = @OutId
end
else
begin

	update Product Set CategoryId=@CategoryId,
Name =@Name ,
Description=@Description,
BrandId=@BrandId ,
ProductCode=@ProductCode,
Qty=@Qty ,
Classification = @Classification,
IsActive=@IsActive,
UpdatedByUserId = @UpdatedByUserId,
UpdatedDate = @UpdatedDate
where Id=@Id
   
    

--	if SUBSTRING(@Picture, 1, 5) = 'https'
--	begin
--	update Product Set CategoryId=@CategoryId,
--ProductName =@ProductName ,
--Description=@Description,
--Brand=@Brand ,
--ProductCode=@ProductCode,
--UomId=@UomId ,
--Qty=@Qty ,
--Picture=@Picture ,
--Discount=@Discount ,
--DetailedDescription=@DetailedDescription,
--IsActive=@IsActive where Id=@Id

--	update PriceList Set ProductPrice=@Price,StartDate=getdate(),@IsActive=@IsActive 
--	where ProductId=@Id
--	end
--	else
--	begin
--	update Product Set CategoryId=@CategoryId,
--ProductName =@ProductName ,
--Description=@Description,
--Brand=@Brand ,
--ProductCode=@ProductCode,
--UomId=@UomId ,
--Qty=@Qty ,
--Discount=@Discount ,
--DetailedDescription=@DetailedDescription,
--IsActive=@IsActive where Id=@Id

--update PriceList Set ProductPrice=@Price,StartDate=getdate(),@IsActive=@IsActive 
--	where ProductId=@Id
--	end
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddProductLevelStockInOut]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProductLevelStockInOut]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_AddProductLevelStockInOut]
(
@UniqueId varchar(3000),
@BatchId int,
@WareHouseId int,
@StackId int,
@ProductId int,
@TransactionType bit,  -- 1 means Stock In/0 means Stock Out
@Stock int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
)
as
begin

   declare @cnt int
   set @cnt = (select count(*) from WareHouseStock where StackId = @StackId and
   WareHouseId = @WareHouseId and ProductId = @ProductId and BatchId = @BatchId)
  
   if @cnt = 0
   begin
      insert into WareHouseStock(WareHouseId,ProductId,Stock,IsActive,CreatedByUserId,CreatedDate,
      UpdatedByUserId,UpdatedDate,StackId,BatchId)values(@WareHouseId,@ProductId,@Stock,@IsActive,@CreatedByUserId,
	  getdate(),@UpdatedByUserId,getdate(),@StackId,@BatchId)

	  --insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  --,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	  -- IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  --values(@WareHouseId,1,@ProductId,@Stock,1,0,0,0,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  --@UpdatedByUserId,getdate(),@stackid)	  
   end
   else
   begin

     if @TransactionType = 1
	 begin
     update WareHouseStock set Stock = Stock+@Stock,IsActive = @IsActive,
	 UpdatedByUserId = @UpdatedByUserId,UpdatedDate = @UpdatedDate
     where StackId = @stackid and WareHouseId = @WareHouseId 
	 and ProductId = @ProductId and BatchId = @BatchId
	 end
	 else if @TransactionType = 0
	 begin
	  update WareHouseStock set Stock = Stock-@Stock,IsActive = @IsActive,
	 UpdatedByUserId = @UpdatedByUserId,UpdatedDate = @UpdatedDate
     where StackId = @stackid and WareHouseId = @WareHouseId 
	 and ProductId = @ProductId and BatchId = @BatchId
	 end
      -- insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  --,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	  -- IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  --values(@WareHouseId,1,@ProductId,@Stock,1,0,0,0,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  --@UpdatedByUserId,getdate(),@stackid)	
   end

end
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE Procedure [dbo].[SP_AddRoles]
(@Id int,
@Code varchar(50),
@Name varchar(255),
@ViewYN bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@RolesOutId int output
)
as
begin
If isnull(@Id,0)=0
begin
insert into Roles(
Code,
Name,
ViewYN,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@ViewYN,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @RolesOutId=@@IDENTITY
end
else
begin
update Roles Set Code=@Code,Name=@Name,ViewYN=@ViewYN where Id=@Id



end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddSKUPackingMaterial]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSKUPackingMaterial]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddSKUPackingMaterial]
(@Id int,
@SKUId Int,
@PackingMaterialName Int,
@Qty  Int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime

,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into SKUPackingMaterial(
SKUId,
PackingMaterialName,
Qty,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@SKUId,

@PackingMaterialName,
@Qty,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)

end
else
begin
update SKUPackingMaterial Set SKUId = @SKUId, PackingMaterialName=@PackingMaterialName,Qty = @Qty,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id


end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddStackLevelStockIn]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStackLevelStockIn]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_AddStackLevelStockIn]
(
@WareHouseId int,
@ProductId int,
@Stock int,
@UniqueId varchar(3000),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
)
as
begin

   declare @stackid int
   set @stackid = (select Id from ProductBarCode where UniqueId = @UniqueId)
   declare @cnt int
   set @cnt = (select count(*) from WareHouseStock where StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId)
  
   if @cnt = 0
   begin
      insert into WareHouseStock(WareHouseId,ProductId,Stock,IsActive,CreatedByUserId,CreatedDate,
      UpdatedByUserId,UpdatedDate,StackId)values(@WareHouseId,@ProductId,@Stock,@IsActive,@CreatedByUserId,
	  getdate(),@UpdatedByUserId,getdate(),@stackid)

	  insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  ,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	   IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  values(@WareHouseId,1,@ProductId,@Stock,1,0,0,0,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  @UpdatedByUserId,getdate(),@stackid)	  
   end
   else
   begin

     update WareHouseStock set Stock = Stock+@Stock,
	 IsActive = @IsActive,UpdatedByUserId = @UpdatedByUserId,UpdatedDate = @UpdatedDate
     where StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId

     insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  ,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	   IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  values(@WareHouseId,1,@ProductId,@Stock,1,0,0,0,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  @UpdatedByUserId,getdate(),@stackid)	
   end

end

GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddUsers]
(@Id int
,@UserName varchar(255)
,@Password varchar(255)
,@RoleId Int
,@FirstName varchar(255)
,@LastName varchar(255)
,@Email varchar(255)
,@MobileNo BigInt
,@WareHouseId Int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int


)
as
begin

If isnull(@Id,0)=0
begin
insert into Users(
UserName ,
Password ,
RoleId ,
FirstName ,
LastName ,
Email ,
MobileNo,
WareHouseId,
ViewYN ,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId
)
values(
@UserName ,
@Password,
@RoleId,
@FirstName,
@LastName ,
@Email ,
@MobileNo,
@WareHouseId,
@ViewYN,
@CreatedDate,
@CreatedByUserId ,
@UpdatedDate ,
@UpdatedByUserId
)
end
else
begin
update Users Set
UserName = @UserName ,
Password = @Password,
RoleId = @RoleId,
FirstName = @FirstName,
LastName = @LastName ,
Email = @Email ,
MobileNo = @MobileNo,
WareHouseId = @WareHouseId,
ViewYN = @ViewYN where Id=@Id

end
	
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWareHouse]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWareHouse]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWareHouse]
(@Id int,
@Name varchar(100),
@ContactName varchar(100),
@ContactNo bigint,
@Address varchar(1000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@WareHouseId int output
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into WareHouse(
Name,
ContactName,
ContactNo,
Address,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Name,
@ContactName,
@ContactNo,
@Address,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
 set @WareHouseId = @@IDENTITY
end
else
begin
update WareHouse Set Name=@Name,ContactName=@ContactName,ContactNo=@ContactNo,Address=@Address,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id

set @WareHouseId = @Id
end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWareHouseServiceLocation]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWareHouseServiceLocation]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWareHouseServiceLocation]
(
@Id int,
@WareHouseId int,
@PinCode int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into WareHouseServiceLocation(
WareHouseId,
PinCode,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@WareHouseId,
@PinCode,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update WareHouseServiceLocation Set WareHouseId=@WareHouseId,PinCode=@PinCode,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddWareHouseStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWareHouseStock]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddWareHouseStock]
(@Id int,
@WareHouseId int,
@ProductId int,
@StackId int,
@BatchId int,
@Stock int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
BEGIN TRY
If isnull(@Id,0)=0
begin
insert into WareHouseStock(
WareHouseId,
ProductId,
StackId,
BatchId,
Stock,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@WareHouseId,
@ProductId,
@StackId,
@BatchId,
@Stock,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)

--insert into WareHouseStockTransaction (WareHouseId,ProductId,TotalStock,TransactionDate,
--IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate) 
--values(@WareHouseId,@ProductId,@TotalStock,getdate(),@IsActive,@CreatedByUserId,getdate(),@UpdatedByUserId,getdate())

--insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
--,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
--IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate) 
--values(1,1,1,100,1,0,0,0,1,getdate(),1,1,getdate(),1,getdate())

end
else
begin
update WareHouseStock Set Stock=Stock+@Stock,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate 
where Id=@Id

--insert into WareHouseStockTransaction (WareHouseId,ProductId,TotalStock,TransactionDate,
--IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate) 
--values(@WareHouseId,@ProductId,@TotalStock,getdate(),@IsActive,@CreatedByUserId,getdate(),@UpdatedByUserId,getdate())

end
END TRY
BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) ;
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBarCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBarCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetBarCode](@Id int)
as 
begin
select * from BarCode where Id= isnull(@Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFlockDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFlockDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetFlockDetails] (@P_Id Int)
AS
BEGIN
	SELECT 
	F.Id,
	F.Name,
	F.Area,
	F.Location,
	F.IsAcive,
	F.CreatedDate,
	F.CreatedByUserId,
	F.UpdatedDate,
	F.UpdateByUserId
	FROM [dbo].[Flock] F
	
	
	WHERE F.Id = ISNULL(@P_Id, F.Id)

	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetLookupDtlDetails](@Id int)
as 
begin

select * from LookupDtl where Id= isnull(@Id,Id)

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetailsByCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetailsByCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetLookupDtlDetailsByCode](@Code varchar(50))
as 
begin

select * from LookupDtl where Code= isnull(@Code,Code)
and IsActive=1   

order By OrdinalPosition asc
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetailsByLookupHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetailsByLookupHdrId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetLookupDtlDetailsByLookupHdrId](@LookupHdrId int)
as 
begin

select * from LookupDtl where LookupHdrId= isnull(@LookupHdrId,LookupHdrId)

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdrDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetLookupHdrDetails](@Id int)
as 
begin

select * from LookupHdr where Id= isnull(@Id,Id)

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id)
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingDetailsForExcel]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingDetailsForExcel]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPackingDetailsForExcel](@Id int)
as
begin
   select PH.Code, W.Name As WareHouse,PH.CreatedDate,l.Name as PackingSlipType,
  PH.DaysInTransit,sk.Name as skuName,pr.Name as ProductName,P.Quantity,ld.Name as Status
  from PackingSlipHDR  PH

   INNER JOIN WareHouse W on W.Id = PH.WareHouseId
   INNER JOIN PackingSlipDTL p on p.PackingSlipHDRId = PH.Id
   Inner Join Product pr On pr.Id = p.ProductId
   inner Join SKU sk on sk.Id = p.SkuId

   Inner Join LookupDtl ld on ld.Id = PH.Status
    Inner Join LookupDtl l on l.Id = PH.Type
   
   
   where PH.IsActive =1 and PH.Id = ISNULL(@Id,PH.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingMaterials]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingMaterials]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetPackingMaterials] (@P_Id Int)
AS
BEGIN
	SELECT 
	P.Id,
	P.AvailableStock,
	P.Name,
	W.Name as WareHouseName,
	P.WareHouseId,
	P.IsAcive,
	P.Type,
	l.Name as UOM,
	P.UOMId,
	P.CreatedByUserId,
	P.CreatedDate,
	P.UpdateByUserId,
	P.UpdatedDate
	FROM [dbo].[PackingMaterials] P
	inner join WareHouse W on W.Id=P.WareHouseId
	inner Join LookupDtl l on l.Id = P.UOMId
	WHERE P.Id = ISNULL(@P_Id, P.Id)

	
END



  
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingMaterialsByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingMaterialsByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetPackingMaterialsByWareHouseId] (@WareHouseId Int)
AS
BEGIN
	SELECT 
	P.Id,
	P.AvailableStock,
	P.Name,
	W.Name as WareHouseName,
	P.IsAcive,
	P.Type,
	l.Name as UOM,
	P.UOMId,
	P.WareHouseId,
	P.CreatedByUserId,
	P.CreatedDate,
	P.UpdateByUserId,
	P.UpdatedDate
	FROM [dbo].[PackingMaterials] P
	inner join WareHouse W on W.Id=P.WareHouseId
	inner Join LookupDtl l on l.Id = P.UOMId
	WHERE P.Id = ISNULL(@WareHouseId, P.WareHouseId)

	
END



  
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingSlipDTLDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingSlipDTLDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPackingSlipDTLDetails](@Id int)
as
begin
   select p.*,S.Name as SkuName from PackingSlipDTL p
   inner join Sku S on S.Id = p.SkuId
   where p.IsActive =1 and p.Id = ISNULL(@Id,p.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingSlipDTLDetailsByHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingSlipDTLDetailsByHDRId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPackingSlipDTLDetailsByHDRId](@HDRId int)
as
begin
   select pd.*,ph.Code,p.Name as ProductName,sk.Name As skuName from PackingSlipDTL pd
   inner join PackingSlipHDR ph on ph.Id = pd.PackingSlipHDRId
   inner join Product p on p.Id=pd.ProductId
   inner Join sku sk on sk.Id = pd.SkuId
   where pd.IsActive =1 and [PackingSlipHDRId] = @HDRId
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingSlipHDRDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingSlipHDRDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPackingSlipHDRDetails](@Id int)
as
begin
   select Ph.Id,W.Name As WareHouse,PH.Code,PH.InTransit,PH.IsInHouseTransfer,PH.LossInTransit,PH.GRNConfirmation,PH.DaysInTransit,PH.IsActive,PH.CreatedDate,PH.CreatedByUserId,PH.UpdatedDate,PH.UpdatedByUserId,PH.WareHouseId,PH.Status,PH.Type from PackingSlipHDR  PH

   INNER JOIN WareHouse W on W.Id = PH.WareHouseId
   
   
   
   where PH.IsActive =1 and PH.Id = ISNULL(@Id,PH.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingSlipHDRDetailsByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingSlipHDRDetailsByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPackingSlipHDRDetailsByWareHouseId](@WareHouseId int)
as
begin
   select     Ph.Id,LD.Name   as PackingType, l.Name as packingStatus,W.Name As WareHouse,PH.Code,PH.InTransit,PH.IsInHouseTransfer,PH.LossInTransit,PH.GRNConfirmation,PH.DaysInTransit,PH.IsActive,PH.CreatedDate,PH.CreatedByUserId,PH.UpdatedDate,PH.UpdatedByUserId,PH.WareHouseId,PH.Status,PH.Type from PackingSlipHDR  PH
      inner Join LookupDtl LD on LD.Id = PH.Type 
   INNER JOIN WareHouse W on W.Id = PH.WareHouseId
   inner Join LookupDtl l on l.Id = PH.Status 
   

   
   where PH.IsActive =1 and PH.WareHouseId = ISNULL(@WareHouseId,PH.WareHouseId)
   
end






GO

-- %% [markdown]
-- # [dbo].[SP_GetProductBarCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductBarCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetProductBarCode](@Id int)
as 
begin
select P.Id, 
P.BatchId,
P.NoOfQuantity,
P.PackedDate,
P.Url,
P.UniqueId,
P.IsRepacking,
P.RePackingBatchId,
P.RePackingQty,
P.CreatedByUserId,
P.CreatedDate,
P.UpdatedByUserId,
P.UpdatedDate,
P.IsActive,
F.Name As FlockName,
w.Name As WareHouse,
Pd.Name as Product,
sk.Name as Skuname,
st.Name as Stackname,
 format(cast(p.CreatedDate as datetime),'yyyyMMddhhmmss') + cast (P.Id as varchar(10)) as BarcodeLabel
  from ProductBarCode P 
  Inner Join WareHouse w on w.Id = P.WareHouseId
  Inner Join Flock F on F.Id = P.FlockId
  Inner Join Product Pd on Pd.Id = P.ProductId
  inner Join Sku sk On sk.Id = P.SkuId
  inner Join Stack  st On st.Id = P.StackId
  where P.Id = isnull(@Id,P.Id)
end
  
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductBarCodeDetailsByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductBarCodeDetailsByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetProductBarCodeDetailsByWareHouseId](@WareHouseId int)
as 
begin
select P.Id, 
P.BatchId,
P.NoOfQuantity,
P.PackedDate,
P.Url,
P.CreatedByUserId,
P.IsRepacking,
P.RePackingBatchId,
P.RePackingQty,
P.CreatedDate,
P.UpdatedByUserId,
P.UpdatedDate,
P.IsActive,
F.Name As FlockName,
w.Name As WareHouse,
Pd.Name as Product,
sk.Name as Skuname,
st.Name as Stackname
  from ProductBarCode P 
  Inner Join WareHouse w on w.Id = P.WareHouseId
  Inner Join Flock F on F.Id = P.FlockId
  Inner Join Product Pd on Pd.Id = P.ProductId
  inner Join Sku sk On sk.Id = P.SkuId
  inner Join Stack  st On st.Id = P.StackId
  where P.WareHouseId = isnull(@WareHouseId,P.WareHouseId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProducts]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProducts] (@P_Id int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,p.[Name]
		,p.[Description]
		,p.[BrandId],
		l.Name as Brand,
		ld.Name as CategoryName,
		kl.Name as ClassificationName
		,p.[ProductCode]
		,p.[Qty]
		,p.[IsActive]
		,p.[CreatedByUserId]
		,p.[CreatedDate]
		,p.[UpdatedByUserId]
		,p.[UpdatedDate]
		
	FROM [dbo].[Product] p	
	inner join LookupDtl ld on ld.Id =p.CategoryId
	inner join LookupDtl l on l.Id =p.BrandId

	inner join LookupDtl kl on kl.Id =p.Classification
	WHERE p.Id = ISNULL(@P_Id, p.Id)
		
		 end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductsDetailByCategoryId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductsDetailByCategoryId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProductsDetailByCategoryId] (@P_CategoryId Int)
as
begin 
SELECT 
		 p.[Id]
		,p.[CategoryId]
		,p.[Name]
		,p.[ProductCode]
		,p.[Description]
		,p.[BrandId]
		,ld.Name as CategoryName,
		d.Name as ClassificationName
		,p.[Qty]
		,p.[IsActive]
		,p.[CreatedDate]
		,p.[CreatedByUserId]
		,p.[UpdatedDate]
		,p.[UpdatedByUserId]
		
	FROM [dbo].[Product] p
	
	inner join LookupDtl ld on ld.Id =p.CategoryId
		
	inner join LookupDtl d on d.Id =p.Classification

	WHERE p.CategoryId = ISNULL(@P_CategoryId, p.CategoryId)
		AND p.IsActive = 1 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)

	ORDER By r.name, PM.[Order]  ,m.[Order]
END



  
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetRolesDetails](@P_Id int)
as
begin
select Id,Code,Name,ViewYN,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate from Roles where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSKUByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSKUByProductId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetSKUByProductId](@ProductId int)
as
begin
select 
S.code,
S.Id,
S.Name,
S.IsAcive,
S.UpdateByUserId,
S.CreatedByUserId,
S.CreatedDate,
S.UpdatedDate,
S.UOM,
PD.Name As ProductName,
S.ProductId,
S.Qty,
L.Name as UomName
from Sku S



inner Join Product PD On Pd.Id = S.ProductId

inner join LookupDtl L on L.Id = S.UOM

 where S.ProductId = @ProductId
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetSkuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSkuDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetSkuDetails](@P_Id int)
as
begin
select 
S.code,
S.Id,
S.Name,
S.IsAcive,
S.UpdateByUserId,
S.CreatedByUserId,
S.CreatedDate,
S.UpdatedDate,
S.UOM,
PD.Name As ProductName,
S.ProductId,
S.Qty,
L.Name as UomName
from Sku S



inner Join Product PD On Pd.Id = S.ProductId

inner join LookupDtl L on L.Id = S.UOM

 where S.Id=isnull(@P_Id,S.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSKUPackingmaterial]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSKUPackingmaterial]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetSKUPackingmaterial](@Id int)
as 
begin
select * from SKUPackingMaterial SP 

where SP.Id=isnull(@Id,SP.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSKUPackingMaterialBySkuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSKUPackingMaterialBySkuId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetSKUPackingMaterialBySkuId](@SKUId int)
as 
begin
select * from SKUPackingMaterial SP 

where SP.SKUId = @SKUId and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStack]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStack]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetStack]( @Id int)
as 
begin
select 
s.Id,
s.WareHouseId,
s.Printcode,
w.Name as WareHouseName,
s.Name,
s.Area,
s.Location,
s.URL,
s.IsActive,
s.UpdatedDate

from Stack s
inner join WareHouse w  on w.Id=s.WareHouseId
where s.Id= isnull(@Id,s.Id)
end


update Stack set Printcode='20230110' where Id=2
GO

-- %% [markdown]
-- # [dbo].[SP_GetStackByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStackByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetStackByWareHouseId](@WareHouseId int)
as 
begin
select 
s.Id,
s.WareHouseId,
s.Printcode,
w.Name as WareHouseName,
s.Name,
s.Area,
s.Location,
s.URL,
s.IsActive,
s.UpdatedDate

from Stack s
inner join WareHouse w  on w.Id=s.WareHouseId
where s.WareHouseId= isnull(@WareHouseId,s.WareHouseId)
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetStackLevelStockDetailsByBarCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStackLevelStockDetailsByBarCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetStackLevelStockDetailsByBarCode '59E5EE6B-AD99-4C72-B665-FD67E247054D'
CREATE proc [dbo].[SP_GetStackLevelStockDetailsByBarCode](@UniqueId varchar(3000))
as
begin
 declare @StackId int
 declare @StackName varchar(255)
 set @StackId = (select Id from Stack where UniqueId = @UniqueId)
 set @StackName = (select Name from Stack where UniqueId = @UniqueId)

 select @StackId StackId , @StackName StackName

 select X.*,W.Name WareHouseName,P.Name ProdcutName  from
 (select WareHouseId,ProductId,sum(Stock) Stock
 from [dbo].[WareHouseStock] where StackId = @StackId group by WareHouseId,ProductId) X
 inner join WareHouse W on W.Id = X.WareHouseId
 inner join Product P on P.Id = X.ProductId

end


GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetailsByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetailsByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_GetStockDetailsByWareHouseId](@WareHouseId int)
as
begin
select WHS.WareHouseId,WHS.StackId,WHS.ProductId,sum(WHS.Stock) Stock,W.Name WareHouseName,P.Name ProductName,S.Name StackName from WareHouseStock  WHS
 inner join WareHouse W on W.Id = WHS.WareHouseId
 inner join Product P on P.Id = WHS.ProductId
 inner join Stack S on S.Id = WHS.StackId
 where WHS.WareHouseId = @WareHouseId
group by WHS.WareHouseId,WHS.StackId,WHS.ProductId,W.Name,P.Name,S.Name
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetUsersDetails](@P_Id int)
as
begin
select u.Id,u.UserName ,
u.Password ,
u.RoleId ,
u.FirstName ,
u.LastName ,
u.Email ,
u.MobileNo,
u.ViewYN ,
u.CreatedDate,
u.CreatedByUserId,
u.UpdatedDate,
u.UpdatedByUserId,r.Name from Users u
left join Roles r on u.RoleId=r.Id where u.Id=isnull(@P_Id,u.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetWareHouseDetails] (@Id int)
as
begin
 select * from WareHouse wh where wh.Id = ISNULL(@Id,wh.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseServiceLocationByPinCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseServiceLocationByPinCode]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseServiceLocationByPinCode](@PinCode int)
as
begin
 select * from WareHouseServiceLocation whsl where whsl.IsActive=1 and whsl.PinCode = ISNULL(@PinCode,whsl.PinCode)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseServiceLocationByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseServiceLocationByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseServiceLocationByWareHouseId](@WareHouseId int)
as
begin
 select
 whsl.WareHouseId,
 whsl.PinCode,
 whsl.Id,
 whsl.IsActive,
 whsl.UpdatedDate,
 whsl.UpdatedByUserId,
 whsl.CreatedDate,
 whsl.CreatedByUserId,
 w.Name as warehouseName
 
 from WareHouseServiceLocation whsl
 
 inner join  WareHouse w on w.Id = whsl.WareHouseId   where  whsl.WareHouseId = ISNULL(@WareHouseId,whsl.WareHouseId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseServiceLocationDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseServiceLocationDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_GetWareHouseServiceLocationDetails] (@Id int)
as
begin
 select
 whsl.WareHouseId,
 whsl.PinCode,
 whsl.Id,
 whsl.IsActive,
 whsl.UpdatedDate,
 whsl.UpdatedByUserId,
 whsl.CreatedDate,
 whsl.CreatedByUserId,
 w.Name as warehouseName
 
 from WareHouseServiceLocation whsl
 
 inner join  WareHouse w on w.Id = whsl.WareHouseId   where  whsl.Id = ISNULL(@Id,whsl.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseStockDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseStockDetails]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetWareHouseStockDetails](@Id int)
as
begin
select * from WareHouseStock whs where whs.IsActive =1 and whs.Id = ISNULL(@Id,whs.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseStockDetailsByWarehouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseStockDetailsByWarehouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetWareHouseStockDetailsByWarehouseId](@WareHouseId int)
as
begin
select whs.AvailableStock,whs.TotalStock,whs.IsActive,whs.ProductId,P.ProductName
from WareHouseStock whs 
right join Product p On P.Id = whs.ProductId
where whs.IsActive =1 and whs.WareHouseId = ISNULL(@WareHouseId,whs.WareHouseId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWareHouseStockTransactoinDetailsByWarehouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWareHouseStockTransactoinDetailsByWarehouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetWareHouseStockTransactoinDetailsByWarehouseId](@WareHouseId int)
as
begin
select whs.TotalStock, whs.TransactionDate,whs.IsActive,whs.ProductId,P.ProductName
from WareHouseStockTransaction whs 
right join Product p On P.Id = whs.ProductId
where whs.IsActive =1 and whs.WareHouseId = ISNULL(@WareHouseId,whs.WareHouseId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_ProductLevelStockDetailsByPackingSlipHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ProductLevelStockDetailsByPackingSlipHDRId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
   CREATE Proc [dbo].[SP_ProductLevelStockDetailsByPackingSlipHDRId](@PackingSlipHDRId Int)
   As
   
   Begin select S.Name StackName,W.Name WareHouseName,p.Name ProductName,WHS.Stock,cast(PBC.PackedDate as Date) PackedDate,
   WHS.BatchId from WareHouseStock WHS
   Inner Join WareHouse W on W.Id = WHS.WareHouseId
   Inner Join Stack S on S.Id = WHS.StackId
   Inner Join Product P on P.Id = WHS.ProductId
   Inner Join ProductBarCode PBC on PBC.WareHouseId = WHS.WareHouseId and PBC.ProductId = WHS.ProductId and PBC.BatchId = WHS.BatchId
   where WHS.WareHouseId=(select WareHouseId from PackingSlipHDR where Id = @PackingSlipHDRId) 
   And WHS.ProductId in (select ProductId from PackingSlipDTL 
   where PackingSlipHDRId = @PackingSlipHDRId) order by PBC.PackedDate

   End
GO

-- %% [markdown]
-- # [dbo].[SP_ProductLevelStockDetailsByProductIdByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ProductLevelStockDetailsByProductIdByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_ProductLevelStockDetailsByProductIdByWareHouseId 1,2
Create proc [dbo].[SP_ProductLevelStockDetailsByProductIdByWareHouseId](@ProductId Int,@WareHouseId int)
as
begin
 
   select S.Name StackName,W.Name WareHouseName,p.Name ProductName,WHS.Stock,cast(PBC.PackedDate as Date) PackedDate,
   WHS.BatchId from WareHouseStock WHS
   inner join WareHouse W on W.Id = WHS.WareHouseId
   inner join Stack S on S.Id = WHS.StackId
   inner join Product P on P.Id = WHS.ProductId
   inner join ProductBarCode PBC on PBC.WareHouseId = WHS.WareHouseId and PBC.ProductId = WHS.ProductId and PBC.BatchId = WHS.BatchId
   where WHS.WareHouseId=@WareHouseId and WHS.ProductId = @ProductId order by PBC.PackedDate

end
GO

-- %% [markdown]
-- # [dbo].[SP_ProductLevelStockDetailsByStackId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ProductLevelStockDetailsByStackId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_ProductLevelStockDetailsByStackId 1
create proc [dbo].[SP_ProductLevelStockDetailsByStackId](@StackId Int)
as
begin
 
   select S.Name StackName,W.Name WareHouseName,p.Name ProductName,WHS.Stock,cast(PBC.PackedDate as Date) PackedDate,
   WHS.BatchId from WareHouseStock WHS
   inner join WareHouse W on W.Id = WHS.WareHouseId
   inner join Stack S on S.Id = WHS.StackId
   inner join Product P on P.Id = WHS.ProductId
   inner join ProductBarCode PBC on PBC.StackId = WHS.StackId and PBC.BatchId = WHS.BatchId
   where WHS.StackId=@StackId order by PBC.PackedDate

end
GO

-- %% [markdown]
-- # [dbo].[SP_ProductLevelStockDetailsByUniqueId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ProductLevelStockDetailsByUniqueId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_ProductLevelStockDetailsByUniqueId 'A2050414-A05A-47FA-A527-07584C1544A1'
CREATE proc [dbo].[SP_ProductLevelStockDetailsByUniqueId](@UniqueId varchar(3000))
as
begin
   declare @WareHouseId int
   declare @WareHouseName varchar(255)
   declare @StackId int
   declare @StackName varchar(255)
   declare @ProductId int
   declare @ProductName varchar(255)
   declare @BatchId int
   declare @PackedDate date
  
 
   select @WareHouseId=WareHouseId,@StackId=StackId,@BatchId =BatchId,@PackedDate = cast(PackedDate as Date),
   @ProductId = ProductId from ProductBarCode where UniqueId = @UniqueId

   select @WareHouseName = Name from WareHouse where Id = @WareHouseId
   select @StackName = Name from Stack where Id = @StackId
   select @ProductName = Name from Product where Id = @ProductId

   select @WareHouseId WareHouseId,@WareHouseName WareHouseName,@StackId StackId,@StackName StackName ,@ProductId ProductId,@ProductName ProductName,@BatchId BatchId 
   
   select @StackName StackName,@WareHouseName WareHouseName,@ProductName ProductName,WHS.Stock,@PackedDate PackedDate,WHS.BatchId from WareHouseStock WHS
   where WHS.WareHouseId=@WareHouseId and WHS.StackId = @StackId and WHS.BatchId = @BatchId
end

GO

-- %% [markdown]
-- # [dbo].[SP_ProductLevelStockDetailsByWareHouseId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ProductLevelStockDetailsByWareHouseId]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_ProductLevelStockDetailsByWareHouseId 1
CREATE proc [dbo].[SP_ProductLevelStockDetailsByWareHouseId](@WareHouseId Int)
as
begin
 
   select S.Name StackName,W.Name WareHouseName,p.Name ProductName,WHS.Stock,cast(PBC.PackedDate as Date) PackedDate,
   WHS.BatchId from WareHouseStock WHS
   inner join WareHouse W on W.Id = WHS.WareHouseId
   inner join Stack S on S.Id = WHS.StackId
   inner join Product P on P.Id = WHS.ProductId
   inner join ProductBarCode PBC on PBC.WareHouseId = WHS.WareHouseId and PBC.BatchId = WHS.BatchId
   where WHS.WareHouseId=@WareHouseId order by PBC.PackedDate

end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateProductLevelStockIn]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateProductLevelStockIn]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[SP_UpdateProductLevelStockIn]
(
@WareHouseId int,
@ProductId int,
@Stock int,
@IsInHouseTransfer bit,
@LossInTransit bit,
@GRNConfirmation bit,
@UniqueId varchar(3000),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
)
as
begin

   declare @stackid int
   set @stackid = (select StackId from ProductBarCode where UniqueId = @UniqueId)
      declare @cnt int
   set @cnt = (select count(*) from WareHouseStock where StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId)
   if @cnt > 0
   begin
     update WareHouseStock set Stock = Stock + @Stock,
	 IsActive = @IsActive,UpdatedByUserId = @UpdatedByUserId,UpdatedDate = @UpdatedDate
     where  StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId

     insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  ,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	   IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  values(@WareHouseId,0,@ProductId,@Stock,1,@IsInHouseTransfer,@LossInTransit,@GRNConfirmation,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  @UpdatedByUserId,getdate(),@stackid)	
end
end

GO

-- %% [markdown]
-- # [dbo].[SP_UpdateProductLevelStockOut]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateProductLevelStockOut]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_UpdateProductLevelStockOut]
(
@WareHouseId int,
@ProductId int,
@Stock int,
@IsInHouseTransfer bit,
@LossInTransit bit,
@GRNConfirmation bit,
@UniqueId varchar(3000),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
)
as
begin

   declare @stackid int
   set @stackid = (select StackId from ProductBarCode where UniqueId = @UniqueId)
      declare @cnt int
   set @cnt = (select count(*) from WareHouseStock where StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId)
   if @cnt > 0 and @Stock < (Select Stock from WareHouseStock where  StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId)
   begin
    
     update WareHouseStock set Stock = Stock - @Stock,
	 IsActive = @IsActive,UpdatedByUserId = @UpdatedByUserId,UpdatedDate = @UpdatedDate
     where  StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId

     insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  ,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	   IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  values(@WareHouseId,0,@ProductId,@Stock,1,@IsInHouseTransfer,@LossInTransit,@GRNConfirmation,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  @UpdatedByUserId,getdate(),@stackid)	
end
end



GO

-- %% [markdown]
-- # [dbo].[SP_UpdateSKUPackingMaterial]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateSKUPackingMaterial]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_UpdateSKUPackingMaterial](@Id int)
as 
begin
update SKUPackingMaterial set IsActive = 0 where Id = @Id


end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateStackLevelStockOut]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateStackLevelStockOut]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_UpdateStackLevelStockOut]
(
@WareHouseId int,
@ProductId int,
@Stock int,
@IsInHouseTransfer bit,
@LossInTransit bit,
@GRNConfirmation bit,
@UniqueId varchar(3000),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
)
as
begin

   declare @stackid int
   set @stackid = (select Id from Stack where UniqueId = @UniqueId)
      declare @cnt int
   set @cnt = (select count(*) from WareHouseStock where StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId)
   if @cnt > 0
   begin
     update WareHouseStock set Stock = Stock - @Stock,
	 IsActive = @IsActive,UpdatedByUserId = @UpdatedByUserId,UpdatedDate = @UpdatedDate
     where  StackId = @stackid and WareHouseId = @WareHouseId and ProductId = @ProductId

     insert into WareHouseStockTransaction (WareHouseId,TransactionTypeId,ProductId,Stock,InTransit
	  ,IsInHouseTransfer,LossInTransit,GRNConfirmation,DaysInTransit,TransactionDate,
	   IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,StackId) 
	  values(@WareHouseId,0,@ProductId,@Stock,1,@IsInHouseTransfer,@LossInTransit,@GRNConfirmation,1,getdate(),@IsActive,@CreatedByUserId,getdate(),
	  @UpdatedByUserId,getdate(),@stackid)	
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNo,
			u.Password
			,u.WareHouseId
		,w.Name as WareHouseName
		FROM Users u 
		left join WareHouse w on w.Id = u.WareHouseId
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END
GO

-- %% [markdown]
-- # [dbo].[UpdatepackingSlipHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[UpdatepackingSlipHdr]    Script Date: 27-10-2023 15:21:37 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  procedure [dbo].[UpdatepackingSlipHdr] (@Id Int,@WareHouseId Int,@Status Int,@DaysInTransit Int)
as
begin 
Update PackingSlipHDR set Status = @Status ,DaysInTransit = @DaysInTransit
	
	

	WHERE Id = @Id AND IsActive = 1 and WareHouseId=@WareHouseId 

end

GO
