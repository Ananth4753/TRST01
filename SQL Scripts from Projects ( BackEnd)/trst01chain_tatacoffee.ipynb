-- %% [markdown]
-- # [dbo].[BatchGRNDetails]

-- %%
USE [trst01chain_tatacoffee]
GO

-- %%
/****** Object:  Table [dbo].[BatchGRNDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BatchGRNDetails](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BatchHdrId] [int] NOT NULL,
	[GRNId] [int] NOT NULL,
	[ManfacturerId] [int] NULL,
	[DealerId] [int] NULL,
	[FarmerId] [int] NULL,
	[Quantity] [decimal](18, 3) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BatchHdrDetails]

-- %%
/****** Object:  Table [dbo].[BatchHdrDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BatchHdrDetails](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BatchNo] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
/****** Object:  Table [dbo].[Country]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Country](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Customer]

-- %%
/****** Object:  Table [dbo].[Customer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Customer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[EntityName] [varchar](255) NOT NULL,
	[Address] [varchar](255) NULL,
	[Email] [varchar](100) NULL,
	[Phone] [varchar](20) NULL,
	[VillageId] [int] NULL,
	[SubDistrictId] [int] NULL,
	[DistrictorRegencyId] [int] NULL,
	[StateorProvinceId] [int] NULL,
	[CountryId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dealer]

-- %%
/****** Object:  Table [dbo].[Dealer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dealer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[PrimaryContactNo] [bigint] NULL,
	[Address] [varchar](500) NULL,
	[Village] [int] NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitute] [decimal](12, 9) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[ManufacturerId] [int] NULL,
	[IsSubDealer] [bit] NULL,
	[IsMapping] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DistrictorRegency]

-- %%
/****** Object:  Table [dbo].[DistrictorRegency]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DistrictorRegency](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[StateId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DRCDetails]

-- %%
/****** Object:  Table [dbo].[DRCDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DRCDetails](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[DRCHdrId] [int] NOT NULL,
	[GRNId] [int] NOT NULL,
	[DRCValue] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DRCHdrDetails]

-- %%
/****** Object:  Table [dbo].[DRCHdrDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DRCHdrDetails](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[DRCNo] [varchar](255) NULL,
	[DRCDocument] [varchar](5000) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Farmer]

-- %%
/****** Object:  Table [dbo].[Farmer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Farmer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[FirstName] [varchar](255) NOT NULL,
	[LastName] [varchar](255) NULL,
	[FatherName] [varchar](255) NULL,
	[Gender] [varchar](10) NULL,
	[Age] [int] NULL,
	[PrimaryContactNo] [bigint] NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[NationalIdentityCode] [varchar](255) NULL,
	[NationalIdentityCodeDocument] [varchar](255) NULL,
	[NoOfPlots] [int] NULL,
	[Image] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[IsMapping] [bit] NULL,
	[IsHouseholdServy] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[FarmerCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FarmerHouseholdChildrenDetails]

-- %%
/****** Object:  Table [dbo].[FarmerHouseholdChildrenDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FarmerHouseholdChildrenDetails](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerHouseholdSurveyId] [int] NOT NULL,
	[FarmerId] [int] NOT NULL,
	[ChildrenName] [varchar](255) NOT NULL,
	[ChildrenGender] [varchar](20) NOT NULL,
	[ChildrenAge] [int] NOT NULL,
	[ChildrenOccupation] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[FarmerCode] [varchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FarmerHouseholdSurvey]

-- %%
/****** Object:  Table [dbo].[FarmerHouseholdSurvey]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FarmerHouseholdSurvey](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerId] [int] NOT NULL,
	[FamilyCount] [int] NULL,
	[MaritalStatus] [bit] NULL,
	[SpouseName] [varchar](255) NULL,
	[Age] [int] NOT NULL,
	[Gender] [varchar](20) NOT NULL,
	[Occupation] [varchar](255) NOT NULL,
	[NoofChildren] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[FarmerCode] [varchar](100) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GRN]

-- %%
/****** Object:  Table [dbo].[GRN]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GRN](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[GRNnumber] [varchar](255) NULL,
	[ManfacturerId] [int] NULL,
	[DealerId] [int] NULL,
	[FarmerCode] [varchar](255) NULL,
	[Quantity] [decimal](18, 3) NULL,
	[GRNdate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[ModeofTransport] [int] NULL,
	[CurrentQty] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Invoice]

-- %%
/****** Object:  Table [dbo].[Invoice]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Invoice](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[InvoiceNumber] [varchar](255) NULL,
	[ManfacturerId] [int] NULL,
	[Product] [varchar](255) NOT NULL,
	[Quantity] [int] NOT NULL,
	[ShippingTo] [int] NOT NULL,
	[ShippingAddress] [varchar](500) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[DealerId] [int] NULL,
	[Vessel] [varchar](255) NULL,
	[PortofLoading] [varchar](255) NULL,
	[PortofDischarge] [varchar](255) NULL,
	[POLTiming] [datetime] NULL,
	[PODTiming] [datetime] NULL,
	[BatchId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Logistics]

-- %%
/****** Object:  Table [dbo].[Logistics]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Logistics](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[VehicleRegistrationNumber] [varchar](50) NULL,
	[InsuranceExpiryDate] [datetime] NOT NULL,
	[ManufacturingYear] [datetime] NOT NULL,
	[LastMaintenanceDate] [datetime] NOT NULL,
	[VehicleType] [varchar](50) NULL,
	[VehicleLoadCapacity] [varchar](50) NULL,
	[Fueltype] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Manfacturer]

-- %%
/****** Object:  Table [dbo].[Manfacturer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Manfacturer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[EntityName] [varchar](255) NOT NULL,
	[PrimaryContactName] [varchar](255) NOT NULL,
	[PrimaryContactNo] [bigint] NULL,
	[SecondaryContactNo] [bigint] NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitude] [decimal](12, 9) NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ManfacturerProcessingQty]

-- %%
/****** Object:  Table [dbo].[ManfacturerProcessingQty]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ManfacturerProcessingQty](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ManfacturerId] [int] NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[ProcurmentDate] [datetime] NOT NULL,
	[ProcurmentQty] [decimal](18, 3) NULL,
	[IsProcessed] [bit] NOT NULL,
	[ProcessedBatchId] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mapping_DealerFarmer]

-- %%
/****** Object:  Table [dbo].[Mapping_DealerFarmer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mapping_DealerFarmer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[DealerId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mapping_DealerManufacturer]

-- %%
/****** Object:  Table [dbo].[Mapping_DealerManufacturer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mapping_DealerManufacturer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ManufacturerId] [int] NOT NULL,
	[DealerId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UC_Dealer] UNIQUE NONCLUSTERED 
(
	[DealerId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mapping_DealerSubDealer]

-- %%
/****** Object:  Table [dbo].[Mapping_DealerSubDealer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mapping_DealerSubDealer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[DealerId] [int] NOT NULL,
	[SubDealerId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mapping_ManfacturerFarmer]

-- %%
/****** Object:  Table [dbo].[Mapping_ManfacturerFarmer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mapping_ManfacturerFarmer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[ManfacturerId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](255) NOT NULL,
	[Icon] [varchar](255) NOT NULL,
	[Order] [int] NULL,
	[IconType] [varchar](255) NULL,
	[ClassName] [varchar](255) NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Plantation]

-- %%
/****** Object:  Table [dbo].[Plantation]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Plantation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotCode] [varchar](255) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[TypeOfOwnership] [varchar](10) NULL,
	[AreaInHectors] [decimal](12, 3) NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitude] [decimal](12, 9) NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[GeoboundariesArea] [varchar](255) NULL,
	[LabourStatus] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[PlotCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationDocuments]

-- %%
/****** Object:  Table [dbo].[PlantationDocuments]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationDocuments](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotCode] [varchar](255) NOT NULL,
	[DocURL] [varchar](255) NOT NULL,
	[DocType] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[DocUrlValue] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationGeoBoundaries]

-- %%
/****** Object:  Table [dbo].[PlantationGeoBoundaries]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationGeoBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotCode] [varchar](255) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[Latitude] [decimal](12, 8) NULL,
	[Longitude] [decimal](12, 8) NULL,
	[SeqNo] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[PlotCount] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationLabourSurvey]

-- %%
/****** Object:  Table [dbo].[PlantationLabourSurvey]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationLabourSurvey](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlantationId] [int] NOT NULL,
	[NoOfFieldWorkers] [int] NOT NULL,
	[NoOfMaleWorkers] [int] NOT NULL,
	[NoOfFemaleWorkers] [int] NOT NULL,
	[NoOfResident] [int] NOT NULL,
	[NoOfMigrant] [int] NOT NULL,
	[OccupationOfChildren] [varchar](100) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[FarmerCode] [varchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationYeild]

-- %%
/****** Object:  Table [dbo].[PlantationYeild]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationYeild](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotCode] [varchar](255) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[DateOfHarvest] [datetime] NULL,
	[YeildInTons] [decimal](10, 3) NOT NULL,
	[SupplyInTons] [decimal](10, 3) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlotFarmonaut]

-- %%
/****** Object:  Table [dbo].[PlotFarmonaut]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlotFarmonaut](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[PlotCode] [varchar](255) NULL,
	[FieldId] [varchar](255) NULL,
	[SubmitFieldResponse] [varchar](max) NULL,
	[SensedDaysResponse] [varchar](max) NULL,
	[FieldImageResponseForNDVI] [varchar](1000) NULL,
	[FieldImageResponseForNDWI] [varchar](1000) NULL,
	[FieldImageResponseForLULC] [varchar](1000) NULL,
	[FieldImageResponseForNDMI] [varchar](1000) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlotFarmonautSensedDate]

-- %%
/****** Object:  Table [dbo].[PlotFarmonautSensedDate]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlotFarmonautSensedDate](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[PlotCode] [varchar](255) NULL,
	[FieldId] [varchar](255) NULL,
	[SensedDate] [varchar](max) NULL,
	[FieldImageResponseForNDVI] [varchar](1000) NULL,
	[FieldImageResponseForNDWI] [varchar](1000) NULL,
	[FieldImageResponseForLULC] [varchar](1000) NULL,
	[FieldImageResponseForNDMI] [varchar](1000) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlotSatsure]

-- %%
/****** Object:  Table [dbo].[PlotSatsure]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlotSatsure](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[PlotCode] [varchar](255) NULL,
	[RequestId] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[RunDataRequestResponse] [varchar](max) NULL,
	[DatasetResponse] [varchar](max) NULL,
	[DatasetResponseForNDVI] [varchar](1000) NULL,
	[DatasetResponseForNDWI] [varchar](1000) NULL,
	[DatasetResponseForNDMI] [varchar](1000) NULL,
	[DatasetResponseForLULC] [varchar](1000) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductBatch]

-- %%
/****** Object:  Table [dbo].[ProductBatch]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductBatch](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Product] [varchar](255) NOT NULL,
	[Type] [varchar](255) NOT NULL,
	[Quantity] [int] NOT NULL,
	[BatchId] [varchar](255) NOT NULL,
	[URL] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PurchaseOrder]

-- %%
/****** Object:  Table [dbo].[PurchaseOrder]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PurchaseOrder](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Type] [varchar](255) NOT NULL,
	[ManfacturerId] [int] NULL,
	[DealerId] [int] NOT NULL,
	[FarmerId] [int] NOT NULL,
	[GRNnumber] [varchar](255) NOT NULL,
	[LotNumber] [varchar](255) NOT NULL,
	[PODate] [datetime] NOT NULL,
	[ModeOfPayment] [varchar](255) NOT NULL,
	[ModeOfDelivery] [varchar](255) NOT NULL,
	[ShippingAddress] [varchar](500) NOT NULL,
	[BillingAddress] [varchar](500) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RiskAssesmentAnswerDtl]

-- %%
/****** Object:  Table [dbo].[RiskAssesmentAnswerDtl]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RiskAssesmentAnswerDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RiskAssesmentQuestionHdrId] [int] NOT NULL,
	[Answers] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[FarmerCode] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RiskAssesmentQuestionHdr]

-- %%
/****** Object:  Table [dbo].[RiskAssesmentQuestionHdr]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RiskAssesmentQuestionHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[QuestionCategory] [varchar](100) NOT NULL,
	[SerialNo] [int] NOT NULL,
	[Questions] [varchar](500) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StateorProvince]

-- %%
/****** Object:  Table [dbo].[StateorProvince]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StateorProvince](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[CountryId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SubDistrict]

-- %%
/****** Object:  Table [dbo].[SubDistrict]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SubDistrict](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[DistrictId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SupplyOrders]

-- %%
/****** Object:  Table [dbo].[SupplyOrders]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SupplyOrders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Product] [varchar](255) NOT NULL,
	[Type] [varchar](255) NOT NULL,
	[ShippingAddress] [varchar](500) NOT NULL,
	[InvoiceNumber] [varchar](255) NOT NULL,
	[SupplyGRNnumber] [varchar](255) NOT NULL,
	[Amount] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Trader]

-- %%
/****** Object:  Table [dbo].[Trader]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Trader](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TraderName] [varchar](255) NOT NULL,
	[ContactNo] [bigint] NULL,
	[VillageId] [int] NULL,
	[Address] [varchar](500) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitude] [decimal](12, 9) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TypeCompany]

-- %%
/****** Object:  Table [dbo].[TypeCompany]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TypeCompany](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[PrimaryContactName] [varchar](255) NOT NULL,
	[PrimaryContactNo] [bigint] NULL,
	[SecondaryContactNo] [bigint] NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitude] [decimal](12, 9) NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](255) NOT NULL,
	[Password] [nvarchar](255) NOT NULL,
	[FirstName] [varchar](255) NOT NULL,
	[LastName] [varchar](255) NULL,
	[EmailId] [varchar](255) NULL,
	[MobileNumber] [varchar](20) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[RoleId] [int] NULL,
	[IMEINo] [varchar](100) NULL,
	[TraderId] [int] NULL,
	[DealerId] [int] NULL,
	[ManufacturerId] [int] NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Village]

-- %%
/****** Object:  Table [dbo].[Village]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Village](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[SubDistrictId] [int] NOT NULL,
	[PinCode] [varchar](50) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Farmer__IsMappin__05D8E0BE]

-- %%
ALTER TABLE [dbo].[Farmer] ADD  DEFAULT ((0)) FOR [IsMapping]
GO

-- %% [markdown]
-- # [DF__Farmer__IsHouseh__06CD04F7]

-- %%
ALTER TABLE [dbo].[Farmer] ADD  DEFAULT ((0)) FOR [IsHouseholdServy]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__07C12930]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__08B54D69]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__09A971A2]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__0A9D95DB]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__0B91BA14]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__0C85DE4D]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__PlotFarmo__IsAct__0D7A0286]

-- %%
ALTER TABLE [dbo].[PlotFarmonaut] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PlotFarmo__Creat__0E6E26BF]

-- %%
ALTER TABLE [dbo].[PlotFarmonaut] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PlotFarmo__Updat__0F624AF8]

-- %%
ALTER TABLE [dbo].[PlotFarmonaut] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PlotFarmo__IsAct__10566F31]

-- %%
ALTER TABLE [dbo].[PlotFarmonautSensedDate] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PlotFarmo__Creat__114A936A]

-- %%
ALTER TABLE [dbo].[PlotFarmonautSensedDate] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PlotFarmo__Updat__123EB7A3]

-- %%
ALTER TABLE [dbo].[PlotFarmonautSensedDate] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PlotSatsu__IsAct__1332DBDC]

-- %%
ALTER TABLE [dbo].[PlotSatsure] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PlotSatsu__Creat__14270015]

-- %%
ALTER TABLE [dbo].[PlotSatsure] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PlotSatsu__Updat__151B244E]

-- %%
ALTER TABLE [dbo].[PlotSatsure] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__160F4887]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__17036CC0]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__17F790F9]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__ViewYN__18EBB532]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__19DFD96B]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__1AD3FDA4]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__1BC821DD]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__1CBC4616]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__1DB06A4F]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__1EA48E88]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__1F98B2C1]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__208CD6FA]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__2180FB33]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [dbo].[GetFarmerDocumentsDeatilsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[GetFarmerDocumentsDeatilsByFarmerCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[GetFarmerDocumentsDeatilsByFarmerCode](@FarmerCode Varchar(255))
as
begin
select
    pd.DocType,
	pd.DocURL,
	pd.FarmerCode,
	pd.PlotCode,
      pd.IsActive,
      pd.CreatedDate,
      pd.CreatedByUserId,
      pd.UpdatedDate,
      pd.UpdatedByUserId
	    from PlantationDocuments pd
		
		
	  where pd.FarmerCode = ISNULL(@FarmerCode,pd.FarmerCode)


end
GO

-- %% [markdown]
-- # [dbo].[SP_AddBatchDetailsForMobile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBatchDetailsForMobile]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddBatchDetailsForMobile]
(
    @Id INT,
    @BatchHdrId INT,
    @GRNId INT,
    @ManfacturerId INT,
    @DealerId INT,
    @FarmerId INT,
    @Quantity Decimal(18,3),
    @IsActive BIT,
    @CreatedDate DATETIME,
    @CreatedByUserId INT,
    @UpdatedDate DATETIME,
    @UpdatedByUserId INT,
    @ErrorNumber INT OUTPUT,
    @ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION;

    BEGIN TRY
        IF ISNULL(@Id, 0) = 0
        BEGIN
            INSERT INTO [dbo].[BatchGRNDetails] (
                [BatchHdrId],
                [GRNId],
                [ManfacturerId],
                [DealerId],
                [FarmerId],
                [Quantity],
                [IsActive],
                [CreatedDate],
                [CreatedByUserId],
                [UpdatedDate],
                [UpdatedByUserId]
            )
            VALUES (
                @BatchHdrId,
                @GRNId,
                @ManfacturerId,
                @DealerId,
                @FarmerId,
                @Quantity,
                ISNULL(@IsActive, 1),
                ISNULL(@CreatedDate, GETDATE()),
                @CreatedByUserId,
                ISNULL(@UpdatedDate, GETDATE()),
                @UpdatedByUserId
            );

            UPDATE GRN
            SET CurrentQty = CurrentQty - @Quantity
            WHERE Id = @GRNId;
        END
        ELSE
        BEGIN
            UPDATE [dbo].[BatchGRNDetails]
            SET [IsActive] = ISNULL(@IsActive, 1),
                [UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()),
                [UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id;
        END

        COMMIT TRANSACTION;
        SET @ErrorNumber = 0;
        SET @ErrorMessage = 'Success';
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;

        SELECT @ErrorNumber = ERROR_NUMBER(),
               @ErrorMessage = ERROR_MESSAGE();

        
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[SP_AddBatchGRNDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBatchGRNDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddBatchGRNDetails]
(
    @Id INT,
    @BatchHdrId INT,
    @GRNId INT,
    @ManfacturerId INT,
    @DealerId INT,
    @FarmerId INT,
    @Quantity Decimal(18,3),
    @IsActive BIT,
    @CreatedDate DATETIME,
    @CreatedByUserId INT,
    @UpdatedDate DATETIME,
    @UpdatedByUserId INT,
    @ErrorNumber INT OUTPUT,
    @ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION;

    BEGIN TRY
        IF ISNULL(@Id, 0) = 0
        BEGIN
            INSERT INTO [dbo].[BatchGRNDetails] (
                [BatchHdrId],
                [GRNId],
                [ManfacturerId],
                [DealerId],
                [FarmerId],
                [Quantity],
                [IsActive],
                [CreatedDate],
                [CreatedByUserId],
                [UpdatedDate],
                [UpdatedByUserId]
            )
            VALUES (
                @BatchHdrId,
                @GRNId,
                @ManfacturerId,
                @DealerId,
                @FarmerId,
                @Quantity,
                ISNULL(@IsActive, 1),
                ISNULL(@CreatedDate, GETDATE()),
                @CreatedByUserId,
                ISNULL(@UpdatedDate, GETDATE()),
                @UpdatedByUserId
            );

            UPDATE GRN
            SET CurrentQty = CurrentQty - @Quantity
            WHERE Id = @GRNId;
        END
        ELSE
        BEGIN
            UPDATE [dbo].[BatchGRNDetails]
            SET [IsActive] = ISNULL(@IsActive, 1),
                [UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()),
                [UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id;
        END

        COMMIT TRANSACTION;
        SET @ErrorNumber = 0;
        SET @ErrorMessage = 'Success';
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;

        SELECT @ErrorNumber = ERROR_NUMBER(),
               @ErrorMessage = ERROR_MESSAGE();

        
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[SP_AddBatchHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBatchHdrDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddBatchHdrDetails](
@Id Int,
@BatchNo varchar(255),
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
,@BatchHdrOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO [dbo].[BatchHdrDetails] (
                 BatchNo
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                 @BatchNo
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
  set @BatchHdrOUT = @@IDENTITY
                --declare @POId int
                --set @POId  = @@IDENTITY
                --declare @GID varchar(255)
               -- set @GID =('BATCH'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
               -- update [BatchHdrDetails] set BatchNo = @GID,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 

                --where Id=@POId
		 end
	  ELSE
	 BEGIN
	  UPDATE [dbo].[BatchHdrDetails]
            SET  
                
                 BatchNo=@BatchNo
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
            set @BatchHdrOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddBatchHdrDetailsForMobile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBatchHdrDetailsForMobile]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_AddBatchHdrDetailsForMobile](
@Id Int,
@BatchNo varchar(255),
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
,@BatchHdrOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO [dbo].[BatchHdrDetails] (
                 BatchNo
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                 @BatchNo
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
  set @BatchHdrOUT = @@IDENTITY
                --declare @POId int
                --set @POId  = @@IDENTITY
                --declare @GID varchar(255)
               -- set @GID =('BATCH'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
               -- update [BatchHdrDetails] set BatchNo = @GID,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 

                --where Id=@POId
		 end
	  ELSE
	 BEGIN
	  UPDATE [dbo].[BatchHdrDetails]
            SET  
                
                 BatchNo=@BatchNo
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
            set @BatchHdrOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCountry]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCountry]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_AddCountry](
@Id int,
@Code varchar(255),
@Name varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO Country(
  Code,
  [Name],
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @Code,
  @Name,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE Country
   SET Code = @Code,
 [Name] = @Name,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCustomer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCustomer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddCustomer](
@Id int,
@EntityName Varchar(255),
@Address Varchar(255),
@Email VARCHAR(100),
@Phone VARCHAR(20),
@VillageId int,
@SubDistrictId Int,
@DistrictorRegencyId Int,
@StateorProvinceId Int,
@CountryId Int null, 

@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO Customer(
EntityName,
Address,
Email,
Phone,
VillageId,
SubDistrictId,
DistrictorRegencyId,
StateorProvinceId,
CountryId, 

  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
@EntityName,
@Address,
@Email,
@Phone,
@VillageId,
@SubDistrictId,
@DistrictorRegencyId,
@StateorProvinceId,
@CountryId, 

  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE Customer
   SET EntityName = @EntityName,
 Address = @Address,
 Email = @Email,
 [Phone] = @Phone,
 VillageId = @VillageId,
 SubDistrictId = @SubDistrictId,
 [DistrictorRegencyId] = @DistrictorRegencyId,
 [StateorProvinceId] = @StateorProvinceId,
  [CountryId] = @CountryId,

  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDealer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDealer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_AddDealer](
@Id int,
@Name varchar(255),
@PrimaryContactNo bigint,
@Address varchar(500),
@Village int,
@Latitude decimal(12,9),
@Longitute decimal(12,9),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

    BEGIN TRANSACTION

	BEGIN TRY
	   IF ISNULL(@Id,0) = 0
	   INSERT INTO Dealer(
	   Name,
	   PrimaryContactNo,
	   Address,
	   Village,
	   Latitude,
	   Longitute,
	   IsActive,
	   CreatedDate,
	   CreatedByUserId,
	   UpdatedDate,
	   UpdatedByUserId
	   )
	   VALUES(
	    @Name,
	   @PrimaryContactNo,
	   @Address,
	   @Village,
	   @Latitude,
	   @Longitute,
	   @IsActive,
	   @CreatedDate,
	   @CreatedByUserId,
	   @UpdatedDate,
	   @UpdatedByUserId
	   )
      ELSE 
	      UPDATE Dealer 
   SET  Name = @Name,
		PrimaryContactNo = @PrimaryContactNo,
		Address = @Address,
		Village = @Village,
		Latitude = @Latitude,
		Longitute = @Longitute,
		IsActive = @IsActive,
		UpdatedDate = @UpdatedDate,
		UpdatedByUserId = @UpdatedByUserId
		WHERE Id = @Id
	END TRY
	    BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDealerFarmer_Mapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDealerFarmer_Mapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddDealerFarmer_Mapping](
@Id int,
@FarmerCode varchar(255),
@DealerId Int,

@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 
 BEGIN TRY
 IF ISNULL(@Id,0) = 0
 begin
 INSERT INTO Mapping_DealerFarmer(
 FarmerCode,
 DealerId,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
@FarmerCode,
@DealerId,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)

update Farmer set IsMapping = 1 where FarmerCode = @FarmerCode
end
ELSE begin

    update Farmer set IsMapping=0 where FarmerCode=(select FarmerCode from Mapping_DealerFarmer where Id = @Id)
     UPDATE Mapping_DealerFarmer 

	 SET 
		FarmerCode = @FarmerCode,
		DealerId = @DealerId,	
         IsActive = @IsActive,
         UpdatedDate = @UpdatedDate,
         UpdatedByUserId = @UpdatedByUserId
         WHERE Id = @Id
		 update Farmer set IsMapping = 1 where FarmerCode = @FarmerCode
		 end
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END



GO

-- %% [markdown]
-- # [dbo].[SP_AddDealerManufacturer_Mapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDealerManufacturer_Mapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddDealerManufacturer_Mapping](
@Id int,
@DealerId Int,
@ManufacturerId Int,

@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 
 BEGIN TRY
 IF ISNULL(@Id,0) = 0
 begin
 INSERT INTO Mapping_DealerManufacturer(
 ManufacturerId,
 DealerId,
 
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
@ManufacturerId,

@DealerId,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)
update Dealer set IsMapping = 1 where Id = @DealerId
end
ELSE
     UPDATE Mapping_DealerManufacturer 
	 SET 
	 ManufacturerId = @ManufacturerId,
 DealerId = @DealerId,
         IsActive = @IsActive,
         UpdatedDate = @UpdatedDate,
         UpdatedByUserId = @UpdatedByUserId
         WHERE Id = @Id

 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END

GO

-- %% [markdown]
-- # [dbo].[SP_AddDealerSubDealer_Mapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDealerSubDealer_Mapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddDealerSubDealer_Mapping](
@Id int,
@DealerId Int,
@SubDealerId Int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 
 BEGIN TRY
 IF ISNULL(@Id,0) = 0
 begin
 INSERT INTO Mapping_DealerSubDealer(

 DealerId,
 SubDealerId,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
@DealerId,
@SubDealerId,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)

update Dealer set IsSubDealer = 1 , IsMapping=1 where Id = @SubDealerId
End
ELSE
begin
     UPDATE Mapping_DealerSubDealer 
	 SET 

 DealerId = @DealerId,
 SubDealerId=@SubDealerId,
         IsActive = @IsActive,
         UpdatedDate = @UpdatedDate,
         UpdatedByUserId = @UpdatedByUserId
         WHERE Id = @Id
		 end
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDistrictorRegency]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDistrictorRegency]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
create  procedure [dbo].[SP_AddDistrictorRegency](
@Id int,
@Code varchar(255),
@Name varchar(255),
@StateId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO DistrictorRegency(
  Code,
  [Name],
  StateId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @Code,
  @Name,
  @StateId,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE DistrictorRegency
   SET Code = @Code,
 [Name] = @Name,
 StateId=@StateId,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDRCDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDRCDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_AddDRCDetails]
(
    @Id INT,
    @DRCHdrId INT,
    @GRNId INT,
    @DRCValue Int,
    @IsActive BIT,
    @CreatedDate DATETIME,
    @CreatedByUserId INT,
    @UpdatedDate DATETIME,
    @UpdatedByUserId INT,
    @ErrorNumber INT OUTPUT,
    @ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION;

    BEGIN TRY
        IF ISNULL(@Id, 0) = 0
        BEGIN
            INSERT INTO [dbo].[DRCDetails] (
                [DRCHdrId],
                [GRNId],
               [DRCValue],
                [IsActive],
                [CreatedDate],
                [CreatedByUserId],
                [UpdatedDate],
                [UpdatedByUserId]
            )
            VALUES (
                @DRCHdrId,
                @GRNId,
               @DRCValue,
                ISNULL(@IsActive, 1),
                ISNULL(@CreatedDate, GETDATE()),
                @CreatedByUserId,
                ISNULL(@UpdatedDate, GETDATE()),
                @UpdatedByUserId
            );

            UPDATE GRN
            SET CurrentQty = CurrentQty - @DRCValue
            WHERE Id = @GRNId;
        END
        ELSE
        BEGIN
            UPDATE [dbo].[DRCDetails]
            SET [IsActive] = ISNULL(@IsActive, 1),
                [UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()),
                [UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id;
        END

        COMMIT TRANSACTION;
        SET @ErrorNumber = 0;
        SET @ErrorMessage = 'Success';
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;

        SELECT @ErrorNumber = ERROR_NUMBER(),
               @ErrorMessage = ERROR_MESSAGE();

        
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[SP_AddDRCHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDRCHdrDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_AddDRCHdrDetails](
@Id Int,
@DRCNo varchar(255),
@DRCDocument varchar(5000),
@IsActive bit

,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
,@DRCHdrOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO [dbo].[DRCHdrDetails] (
                 [DRCNo],
				 [DRCDocument]
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                 @DRCNo
				 ,@DRCDocument
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
  set @DRCHdrOUT = @@IDENTITY
                --declare @POId int
                --set @POId  = @@IDENTITY
                --declare @GID varchar(255)
               -- set @GID =('BATCH'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
               -- update [BatchHdrDetails] set BatchNo = @GID,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 

                --where Id=@POId
		 end
	  ELSE
	 BEGIN
	  UPDATE [dbo].[DRCHdrDetails]
            SET  
                DRCNo=@DRCNo
				,DRCDocument=@DRCDocument
             
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
            set @DRCHdrOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_AddFarmer](
@Id int,
@FarmerCode varchar(255),
@FirstName varchar(255),
@LastName varchar(255),
@FatherName varchar(255),
@Gender varchar(10),
@Age int,
@PrimaryContactNo bigint,
@Address varchar(500),
@VillageId int,
@NationalIdentityCode varchar(255),
@NationalIdentityCodeDocument varchar(255),
@NoOfPlots int,
@Image varchar(500),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO Farmer(
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  Address,
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  Image,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @FarmerCode,
  @FirstName,
  @LastName,
  @FatherName,
  @Gender,
  @Age,
  @PrimaryContactNo,
  @Address,
  @VillageId,
  @NationalIdentityCode,
  @NationalIdentityCodeDocument,
  @NoOfPlots,
  @Image,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE Farmer
   SET FarmerCode = @FarmerCode,
  FirstName = @FirstName,
  LastName = @LastName,
  FatherName = @FatherName,
  Gender = @Gender,
  Age = @Age,
  PrimaryContactNo = @PrimaryContactNo,
  Address = @Address,
  VillageId = @VillageId,
  NationalIdentityCode = @NationalIdentityCode,
  NationalIdentityCodeDocument = @NationalIdentityCodeDocument,
  NoOfPlots = @NoOfPlots,
  Image = @Image,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmerHouseholdChildrenDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmerHouseholdChildrenDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddFarmerHouseholdChildrenDetails](
@FarmerHouseholdSurveyId int,
@FarmerId int,
@FarmerCode varchar(100),
@ChildrenName varchar(255),
@ChildrenGender varchar(20),
@ChildrenAge int,
@ChildrenOccupation varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
 	  INSERT INTO FarmerHouseholdChildrenDetails (
FarmerHouseholdSurveyId,
FarmerId,
FarmerCode,
ChildrenName,
ChildrenGender,
ChildrenAge,
ChildrenOccupation,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
@FarmerHouseholdSurveyId,
@FarmerId,
@FarmerCode,
@ChildrenName,
@ChildrenGender,
@ChildrenAge,
@ChildrenOccupation,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	     
	 
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmerHouseholdSurvey]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmerHouseholdSurvey]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddFarmerHouseholdSurvey](
@FarmerId int,
@FarmerCode varchar(100),
@FamilyCount int,
@MaritalStatus bit,
@SpouseName varchar(255),
@Age int,
@Gender varchar(20),
@Occupation varchar(255),
@NoofChildren int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@HouseholdSurveyOUT Int output,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
 	  INSERT INTO FarmerHouseholdSurvey (
FarmerId,
FarmerCode,
FamilyCount,
MaritalStatus,
SpouseName,
Age,
Gender,
Occupation,
NoofChildren,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
@FarmerId,
@FarmerCode,
@FamilyCount,
@MaritalStatus,
@SpouseName,
@Age,
@Gender,
@Occupation,
@NoofChildren,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	    set @HouseholdSurveyOUT = @@IDENTITY
	 update Farmer set IsHouseholdServy = 1 where Id = @FarmerId
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddGRNdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGRNdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddGRNdetails](
@Id int,

@ManfacturerId int,
@DealerId int,
@FarmerCode VarChar(255),
@Quantity Decimal(18,3),

@GRNdate datetime,

@ModeofTransport Int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT,
@GRNOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO GRN(
	
      ManfacturerId,
      DealerId,
      FarmerCode,
      Quantity,
	
      GRNdate,

	  ModeofTransport,
      IsActive,
      CreatedDate,
      CreatedByUserId,
      UpdatedDate,
      UpdatedByUserId
	  )
	  VALUES(
	
      @ManfacturerId,
      @DealerId,
      @FarmerCode,
      @Quantity,
	  
      @GRNdate,

	  @ModeofTransport,
      @IsActive,
      @CreatedDate,
      @CreatedByUserId,
      @UpdatedDate,
      @UpdatedByUserId
	  )
	  set @GRNOUT = @@IDENTITY
	  declare @GrnId Int
	  set @GrnId = @@IDENTITY
			declare @GID varchar(255)
			

                set @GID =('GRN'+RIGHT('0000000'+CAST(@GrnId AS VARCHAR(7)),7))
               update GRN set GRNnumber=@GID ,CurrentQty=@Quantity where Id=@GrnId
			 End
		  
	  ELSE
	 BEGIN
	  UPDATE GRN
	    SET 
      ManfacturerId = @ManfacturerId,
      DealerId = @DealerId,
      FarmerCode = @FarmerCode,
      Quantity = @Quantity,
	  CurrentQty= @Quantity,
      GRNdate = @GRNdate,
	
	  ModeofTransport=@ModeofTransport,
      IsActive = @IsActive,
      UpdatedDate = @UpdatedDate,
      UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
	  	set @GRNOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END




GO

-- %% [markdown]
-- # [dbo].[SP_AddInvoiceDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddInvoiceDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddInvoiceDetails](
@Id int,
@ManfacturerId int,
@DealerId int,
@Product varchar(255),
@Quantity int,
@BatchId Int,
@ShippingTo Int,
@ShippingAddress varchar(500),
@Vessel varchar(255),
@PortofLoading varchar(255),
@PortofDischarge varchar(255),
@PODTiming datetime,
@POLTiming datetime,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT,
@InvoiceOUT Int OUTPUT
)
AS
BEGIN
 
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	begin
	  INSERT INTO Invoice(
	 
      ManfacturerId,
	  DealerId,
      Product,
      Quantity,
	  BatchId,
      ShippingTo,
      ShippingAddress,
	  Vessel, 
      PortofLoading,
      PortofDischarge,
      [PODTiming],
      [POLTiming],
      IsActive,
      CreatedDate,
      CreatedByUserId,
      UpdatedDate,
      UpdatedByUserId
	  )
	  VALUES(
	 
      @ManfacturerId,
	  @DealerId,
      @Product,
      @Quantity,
	  @BatchId,
      @ShippingTo,
      @ShippingAddress,
	  @Vessel, 
      @PortofLoading,
      @PortofDischarge,
      @PODTiming,
      @POLTiming,
      @IsActive,
      @CreatedDate,
      @CreatedByUserId,
      @UpdatedDate,
      @UpdatedByUserId
	  )

	  	  set @InvoiceOUT = @@IDENTITY
	  declare @InvoiceId Int
	  set @InvoiceId = @@IDENTITY
			declare @GID varchar(255)
			

                set @GID =('IN'+RIGHT('0000000'+CAST(@InvoiceId AS VARCHAR(7)),7))
               update Invoice set InvoiceNumber=@GID where Id=@InvoiceId
	End
	ELSE
	begin
	  UPDATE Invoice
  SET 
      ManfacturerId = @ManfacturerId,
	 DealerId = @DealerId,
	 	 Vessel=@Vessel, 
      PortofLoading=@PortofLoading,
      PortofDischarge=@PortofDischarge,
      [PODTiming]=@PODTiming,
      [POLTiming]=@POLTiming,
      Quantity = @Quantity,
	  BatchId=@BatchId,
      ShippingTo = @ShippingTo,
      ShippingAddress = @ShippingAddress,
      IsActive = @IsActive,
      UpdatedDate = @UpdatedDate,
      UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
	  set @InvoiceOUT = @Id
	  end
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END

   
GO

-- %% [markdown]
-- # [dbo].[SP_AddLogistics]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLogistics]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddLogistics](
@Id int,
@VehicleRegistrationNumber varchar(50),
@ManufacturingYear datetime,
@LastMaintenanceDate datetime,
@InsuranceExpiryDate  datetime,
@VehicleType varchar(50),
@VehicleLoadCapacity varchar(50),
@Fueltype varchar (50),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO Logistics(
  VehicleRegistrationNumber,
  ManufacturingYear,
  LastMaintenanceDate,
  InsuranceExpiryDate,
  VehicleType,
  VehicleLoadCapacity,
  Fueltype,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @VehicleRegistrationNumber,
  @ManufacturingYear,
  @LastMaintenanceDate,
  @InsuranceExpiryDate,
  @VehicleType,
  @VehicleLoadCapacity,
  @Fueltype,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE Logistics
   SET VehicleRegistrationNumber = @VehicleRegistrationNumber,
   	 InsuranceExpiryDate =@InsuranceExpiryDate
		 ,ManufacturingYear =@ManufacturingYear
		 ,LastMaintenanceDate =@LastMaintenanceDate,
 VehicleType=@VehicleType,VehicleLoadCapacity=@VehicleLoadCapacity,Fueltype=@Fueltype,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddManfacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManfacturer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddManfacturer](
@Id int,
@EntityName varchar(255),
@PrimaryContactName varchar(255),
@PrimaryContactNo bigint,
@SecondaryContactNo bigint,
@Latitude decimal(12,9),
@Longitude decimal(12,9),
@Address varchar(500),
@VillageId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

  BEGIN TRY
  IF ISNULL(@Id,0) = 0
	begin
    INSERT INTO Manfacturer(
	EntityName,
	PrimaryContactName,
	PrimaryContactNo,
	SecondaryContactNo,
	Latitude,
	Longitude,
	Address,
	VillageId,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@EntityName,
	@PrimaryContactName,
	@PrimaryContactNo,
	@SecondaryContactNo,
	@Latitude,
	@Longitude,
	@Address,
	@VillageId,
	@IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	end
	ELSE
	begin
	UPDATE Manfacturer
	SET  EntityName = @EntityName,
	PrimaryContactName = @PrimaryContactName,
	PrimaryContactNo = @PrimaryContactNo,
	SecondaryContactNo = @SecondaryContactNo,
	Latitude = @Latitude,
	Longitude = @Longitude,
	Address = @Address,
	VillageId = @VillageId,
	IsActive = @IsActive,
    UpdatedDate = @UpdatedDate,
    UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
	end
  END TRY
  BEGIN CATCH
   SELECT ErrorMessage = ERROR_MESSAGE(),
          ErrorNumber = ERROR_NUMBER()

		  IF @@TRANCOUNT >0
		  ROLLBACK TRANSACTION;
	      RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
 
  END CATCH
     IF @@TRANCOUNT >0
	 COMMIT TRANSACTION;

	 SET @ErrorNumber = 0
	 SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddManfacturerFarmerMapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManfacturerFarmerMapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddManfacturerFarmerMapping](
@Id int,
@FarmerCode varchar(255),
@ManfacturerId int,

@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 
 BEGIN TRY
 IF ISNULL(@Id,0) = 0
 begin
 INSERT INTO Mapping_ManfacturerFarmer(
 FarmerCode,
 ManfacturerId,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
@FarmerCode,
@ManfacturerId,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)

update Farmer set IsMapping = 1 where FarmerCode = @FarmerCode
end
ELSE begin

   update Farmer set IsMapping = 0 where FarmerCode = (select FarmerCode from Mapping_ManfacturerFarmer where Id=@Id)

     UPDATE Mapping_ManfacturerFarmer
	 SET 
		 FarmerCode = @FarmerCode,
		 ManfacturerId = @ManfacturerId,
         IsActive = @IsActive,
         UpdatedDate = @UpdatedDate,
         UpdatedByUserId = @UpdatedByUserId
         WHERE Id = @Id
		 update Farmer set IsMapping = 1 where FarmerCode = @FarmerCode
		 end
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END



GO

-- %% [markdown]
-- # [dbo].[SP_AddManfacturerProcessingQty]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManfacturerProcessingQty]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_AddManfacturerProcessingQty](
@Id int,
@ManfacturerId int,
@FarmerCode varchar(255),
@ProcurmentDate datetime,
@ProcurmentQty decimal(18,3),
@IsProcessed bit,
@ProcessedBatchId varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
  BEGIN TRANSACTION

  BEGIN TRY
    IF ISNULL(@Id,0) = 0
	INSERT INTO ManfacturerProcessingQty(
	ManfacturerId,
    FarmerCode,
    ProcurmentDate,
    ProcurmentQty,
    IsProcessed,
    ProcessedBatchId,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	VALUES(
	@ManfacturerId,
    @FarmerCode,
    @ProcurmentDate,
    @ProcurmentQty,
    @IsProcessed,
    @ProcessedBatchId,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId

	)
	ELSE
	UPDATE ManfacturerProcessingQty
	SET 
	ManfacturerId = @ManfacturerId,
    FarmerCode = @FarmerCode,
    ProcurmentDate = @ProcurmentDate,
    ProcurmentQty = @ProcurmentQty,
    IsProcessed = @IsProcessed,
    ProcessedBatchId = @ProcessedBatchId,
	IsActive = @IsActive,
	UpdatedDate = @UpdatedDate,
	UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY

  BEGIN CATCH
     SELECT @ErrorNumber = ERROR_NUMBER(),
	        @ErrorMessage = ERROR_MESSAGE();
			
			IF @@TRANCOUNT>0
            ROLLBACK TRANSACTION;
            RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
  END CATCH
      IF @@TRANCOUNT>0
	   COMMIT TRANSACTION;

	   SET @ErrorNumber = 0
	   SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(255)
,@Icon varchar(255)
,@Order int
,@IconType varchar(255)
,@ClassName varchar(255)
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Name]
				,[MenuType]
				,[ParentMenuId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				,IconType
				,ClassName
				)
			VALUES (
				 @Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				,@IconType
				,@ClassName
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
				,IconType=@IconType
				,ClassName=@ClassName
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantation]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantation]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddPlantation](
@Id int,
@PlotCode varchar(255),
@FarmerCode varchar(255),
@TypeOfOwnership varchar(10),
@AreaInHectors decimal(8,3),
@GeoboundariesArea varchar(255),
@Latitude decimal(12,9),
@Longitude decimal(12,9),
@Address varchar(500),
@VillageId int,
@LabourStatus Bit,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
  BEGIN TRANSACTION

  BEGIN TRY
    IF ISNULL(@Id,0) = 0
	INSERT INTO Plantation(
	PlotCode,
	FarmerCode,
	TypeOfOwnership,
	AreaInHectors,
	GeoboundariesArea,
	Latitude,
	Longitude,
	Address,
	VillageId,
	LabourStatus,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	VALUES(
	@PlotCode,
	@FarmerCode,
	@TypeOfOwnership,
	@AreaInHectors,
	@GeoboundariesArea,
	@Latitude,
	@Longitude,
	@Address,
	@VillageId,
	@LabourStatus,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId

	)
	ELSE
	UPDATE Plantation
	SET PlotCode = @PlotCode,
	FarmerCode = @FarmerCode,
	TypeOfOwnership = @TypeOfOwnership,
	AreaInHectors = @AreaInHectors,
	GeoboundariesArea = @GeoboundariesArea,
	Latitude = @Latitude,
	Longitude = @Longitude,
	Address = @Address,
	VillageId = @VillageId,
	LabourStatus=@LabourStatus,
	IsActive = @IsActive,
	UpdatedDate = @UpdatedDate,
	UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY

  BEGIN CATCH
     SELECT @ErrorNumber = ERROR_NUMBER(),
	        @ErrorMessage = ERROR_MESSAGE();
			
			IF @@TRANCOUNT>0
            ROLLBACK TRANSACTION;
            RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
  END CATCH
      IF @@TRANCOUNT>0
	   COMMIT TRANSACTION;

	   SET @ErrorNumber = 0
	   SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationDocuments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationDocuments]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddPlantationDocuments](
@Id int,
@FarmerCode varchar(255),
@PlotCode varchar(255),
@DocURL varchar(255),
@DocType varchar(255),
@DocUrlValue varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
	declare @checkcnt int
	set @checkcnt = (select count(*) from PlantationDocuments where FarmerCode=@FarmerCode
	and DocType=@DocType and IsActive=1)
    IF @checkcnt = 0
	begin
	  INSERT INTO PlantationDocuments(
	  FarmerCode,
	  PlotCode,
	  DocURL,
	  DocType,
	  DocUrlValue,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
	  @FarmerCode,
	  @PlotCode,
	  @DocURL,
	  @DocType,
	  @DocUrlValue,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	  end
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationGeoBoundaries]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_AddPlantationGeoBoundaries](
@Id int,
@PlotCode varchar(255),
@FarmerCode varchar(255),
@Latitude decimal(12,8),
@Longitude decimal(12,8),
@SeqNo int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id, 0) = 0
	  INSERT INTO PlantationGeoBoundaries(
	  PlotCode,
      FarmerCode,
	  Latitude,
	  Longitude,
	  SeqNo,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
	  @PlotCode,
      @FarmerCode,
	  @Latitude,
	  @Longitude,
	  @SeqNo,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	  ELSE
	  UPDATE PlantationGeoBoundaries
	  SET PlotCode = @PlotCode,
	  FarmerCode = @FarmerCode,
	  Latitude = @Latitude,
	  Longitude = @Longitude,
	  SeqNo = @SeqNo,
	  IsActive = @IsActive,
	  UpdatedDate = @UpdatedDate,
	  UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationLabourSurvey]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationLabourSurvey]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddPlantationLabourSurvey](
@PlantationId int,
@FarmerCode varchar (255),
@NoOfFieldWorkers int,
@NoOfMaleWorkers int,
@NoOfFemaleWorkers int,
@NoOfResident int,
@NoOfMigrant int,
@OccupationOfChildren varchar(100),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
 	  INSERT INTO PlantationLabourSurvey (
	  PlantationId,
	  FarmerCode,
      NoOfFieldWorkers,
      NoOfMaleWorkers,
      NoOfFemaleWorkers,
      NoOfResident,
      NoOfMigrant,
      OccupationOfChildren,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
      @PlantationId,
	  @FarmerCode,
      @NoOfFieldWorkers,
      @NoOfMaleWorkers,
      @NoOfFemaleWorkers,
      @NoOfResident,
      @NoOfMigrant,
      @OccupationOfChildren,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	 
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationYeild]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationYeild]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_AddPlantationYeild](
@Id int,
@PlotCode varchar(255),
@FarmerCode varchar(255),
@DateOfHarvest Datetime,
@YeildInTons decimal(10,3),
@SupplyInTons decimal(10,3),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
  BEGIN TRANSACTION

  BEGIN TRY
    IF ISNULL(@Id,0) = 0
	INSERT INTO PlantationYeild(
	PlotCode,
	FarmerCode,
	DateOfHarvest,
	YeildInTons,
	SupplyInTons,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	VALUES(
	@PlotCode,
	@FarmerCode,
	@DateOfHarvest,
	@YeildInTons,
	@SupplyInTons,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId

	)
	ELSE
	UPDATE PlantationYeild
	SET PlotCode = @PlotCode,
	FarmerCode = @FarmerCode,
	DateOfHarvest = @DateOfHarvest,
	YeildInTons = @YeildInTons,
	SupplyInTons = @SupplyInTons,
	IsActive = @IsActive,
	UpdatedDate = @UpdatedDate,
	UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY

  BEGIN CATCH
     SELECT @ErrorNumber = ERROR_NUMBER(),
	        @ErrorMessage = ERROR_MESSAGE();
			
			IF @@TRANCOUNT>0
            ROLLBACK TRANSACTION;
            RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
  END CATCH
      IF @@TRANCOUNT>0
	   COMMIT TRANSACTION;

	   SET @ErrorNumber = 0
	   SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddProductBatch]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProductBatch]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddProductBatch](
@Id int,
@Product varchar(255),
@Type varchar(255),
@Quantity int,
@BatchId varchar(255),
@URL varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
    INSERT INTO ProductBatch(
	Product,
    Type,
    Quantity,
	BatchId,
	URL,
    IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@Product,
    @Type,
    @Quantity,
	@BatchId,
	@URL,
    @IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	ELSE
	UPDATE ProductBatch
	  SET Product = @Product,
          Type = @Type,
          Quantity = @Quantity,
		  BatchId = @BatchId,
		  URL = @URL,
          IsActive = @IsActive,
          UpdatedDate = @UpdatedDate,
          UpdatedByUserId = @UpdatedByUserId
	      WHERE Id = @Id
	  
END TRY
     BEGIN CATCH
         SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'




END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPurchaseOrder]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPurchaseOrder]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddPurchaseOrder](
@Id int,
@Type varchar(255),
@ManfacturerId int,
@DealerId int,
@FarmerId int,
@GRNnumber varchar(255),
@LotNumber varchar(255),
@PODate datetime,
@ModeOfPayment varchar(255),
@ModeOfDelivery varchar(255),
@ShippingAddress varchar(500),
@BillingAddress varchar(500),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
    INSERT INTO PurchaseOrder(
	Type,
    ManfacturerId,
    DealerId,
    FarmerId,
    GRNnumber,
    LotNumber,
    PODate,
    ModeOfPayment,
    ModeOfDelivery,
    ShippingAddress,
    BillingAddress,
    IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@Type,
    @ManfacturerId,
    @DealerId,
    @FarmerId,
    @GRNnumber,
    @LotNumber,
    @PODate,
    @ModeOfPayment,
    @ModeOfDelivery,
    @ShippingAddress,
    @BillingAddress,
    @IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	ELSE
	UPDATE PurchaseOrder
	  SET Type = @Type,
    ManfacturerId = @ManfacturerId,
    DealerId  = @DealerId,
    FarmerId = @FarmerId,
    GRNnumber = @GRNnumber,
    LotNumber = @LotNumber,
    PODate = @PODate,
    ModeOfPayment = @ModeOfPayment,
    ModeOfDelivery = @ModeOfDelivery,
    ShippingAddress = @ShippingAddress,
    BillingAddress = @BillingAddress,
    IsActive = @IsActive,
    UpdatedDate = @UpdatedDate,
    UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
	  
END TRY
     BEGIN CATCH
         SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'




END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRiskAssesmentAnswerDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRiskAssesmentAnswerDtl]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE procedure [dbo].[SP_AddRiskAssesmentAnswerDtl](
@Id int,
@RiskAssesmentQuestionHdrId int,
@FarmerCode varchar(255),
@Answers varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
 IF ISNULL(@Id,0) = 0
   INSERT INTO RiskAssesmentAnswerDtl(
RiskAssesmentQuestionHdrId,
FarmerCode,
Answers,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

   )
   VALUES(
@RiskAssesmentQuestionHdrId,
@FarmerCode,
@Answers,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
ELSE

UPDATE RiskAssesmentAnswerDtl 
   SET RiskAssesmentQuestionHdrId = @RiskAssesmentQuestionHdrId,
       FarmerCode = @FarmerCode,
       Answers = @Answers,
       IsActive = @IsActive,
       UpdatedDate = @UpdatedDate,
       UpdatedByUserId = @UpdatedByUserId
      WHERE Id = @Id

END TRY

BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'


END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRiskAssesmentQuestionHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRiskAssesmentQuestionHdr]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddRiskAssesmentQuestionHdr](
@Id int,
@QuestionCategory Varchar(100),
@SerialNo Int,
@Questions Varchar(100),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@RiskAssesmentHdrOUT int OUTPUT,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
 IF ISNULL(@Id,0) = 0
 BEGIN
   INSERT INTO RiskAssesmentQuestionHdr (
QuestionCategory,
SerialNo,
Questions,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

   )
   VALUES(
@QuestionCategory,
@SerialNo,
@Questions,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
set @RiskAssesmentHdrOUT = @@IDENTITY
END
ELSE
BEGIN
UPDATE RiskAssesmentQuestionHdr 
   SET QuestionCategory = @QuestionCategory,
       SerialNo = @SerialNo,
       Questions = @Questions,
       IsActive = @IsActive,
       UpdatedDate = @UpdatedDate,
       UpdatedByUserId = @UpdatedByUserId
      WHERE Id = @Id
	  set @RiskAssesmentHdrOUT = @Id
	  END
END TRY

BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'


END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRole]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRole]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRole] 
(
 @Id int
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Name]
				,[IsActive]
				,[CreatedDate]
				,[UpdatedDate]
				)
			VALUES (
				 @Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,ISNULL(@UpdatedDate, GETDATE())
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Name]
				,[IsActive]
				,[CreatedDate]
				,[UpdatedDate]
				)
			VALUES (
				 @Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,ISNULL(@UpdatedDate, GETDATE())
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStateorProvince]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStateorProvince]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
create  procedure [dbo].[SP_AddStateorProvince](
@Id int,
@Code varchar(255),
@Name varchar(255),
@CountryId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO StateorProvince(
  Code,
  [Name],
  CountryId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @Code,
  @Name,
  @CountryId,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE StateorProvince
   SET Code = @Code,
 [Name] = @Name,
 CountryId=@CountryId,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSubDistrict]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSubDistrict]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE  procedure [dbo].[SP_AddSubDistrict](
@Id int,
@Code varchar(50),
@Name varchar(100),
@DistrictId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO SubDistrict(
  Code,
  [Name],
  DistrictId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @Code,
  @Name,
  @DistrictId,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE SubDistrict
   SET Code = @Code,
 [Name] = @Name,
 DistrictId=@DistrictId,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSupplyOrders]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSupplyOrders]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddSupplyOrders](
@Id int,
@Product varchar(255),
@Type varchar(255),
@ShippingAddress varchar(500),
@InvoiceNumber varchar(255),
@SupplyGRNnumber varchar(255),
@Amount int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
    INSERT INTO SupplyOrders(
	Product,
    Type,
    ShippingAddress,
    InvoiceNumber,
    SupplyGRNnumber,
    Amount,
    IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@Product,
    @Type,
    @ShippingAddress,
    @InvoiceNumber,
    @SupplyGRNnumber,
    @Amount,
    @IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	ELSE
	UPDATE SupplyOrders
	  SET Product = @Product,
          Type = @Type,
          ShippingAddress = @ShippingAddress,
          InvoiceNumber = @InvoiceNumber,
          SupplyGRNnumber = @SupplyGRNnumber,
          Amount = @Amount,
          IsActive = @IsActive,
          UpdatedDate = @UpdatedDate,
          UpdatedByUserId = @UpdatedByUserId
	      WHERE Id = @Id
	  
END TRY
     BEGIN CATCH
         SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'




END
GO

-- %% [markdown]
-- # [dbo].[SP_AddTrader]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTrader]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddTrader](
@Id int,
@TraderName varchar(255),
@ContactNo bigint,
@VillageId int,
@Address varchar(500),
@Latitude decimal(12,9),
@Longitude decimal(12,9),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 
 BEGIN TRY
 IF ISNULL(@Id,0) = 0
 INSERT INTO Trader(
 TraderName,
 ContactNo,
 VillageId,
 Address,
 Latitude,
 Longitude,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
 @TraderName,
 @ContactNo,
 @VillageId,
 @Address,
 @Latitude,
 @Longitude,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)
ELSE
     UPDATE Trader 
	 SET TraderName = @TraderName,
         ContactNo = @ContactNo,
         VillageId = @VillageId,
         Address = @Address,
		 Latitude = @Latitude,
		 Longitude = @Longitude,
         IsActive = @IsActive,
         UpdatedDate = @UpdatedDate,
         UpdatedByUserId = @UpdatedByUserId
         WHERE Id = @Id

 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END

GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
 @Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber varchar(20)
,@RoleId int
,@TraderId int
,@DealerId int
,@ManufacturerId int
,@IMEINo varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Users] (
				 [UserName]
				,[Password]
				,[FirstName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,[RoleId]
				,[TraderId]
				,[DealerId]
				,[ManufacturerId]
				,[IMEINo]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @UserName
				,@Password
				,@FirstName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@RoleId,
				@TraderId,
				@DealerId,
				@ManufacturerId,
				@IMEINo,
				ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Users]
			SET  
				 [UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[IMEINo] = @IMEINo
				,[MobileNumber] = @MobileNumber
				,[RoleId] = @RoleId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddVillage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVillage]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE  procedure [dbo].[SP_AddVillage](
@Id int,
@Code varchar(50),
@Name varchar(100),
@SubDistrictId int,
@PinCode varchar(50),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO Village(
  Code,
  [Name],
  SubDistrictId,
  PinCode,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @Code,
  @Name,
  @SubDistrictId,
  @PinCode,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE Village
   SET Code = @Code,
 [Name] = @Name,
 SubDistrictId=@SubDistrictId,
 PinCode=@PinCode,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckCountryName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckCountryName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckCountryName](@Name varchar(100))
as
begin
select [Name] from Country where Name=IsNull(@Name,Name)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckDistrictName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckDistrictName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckDistrictName](@Name varchar(100))
as
begin
select [Name] from DistrictorRegency where Name=IsNull(@Name,Name)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckEmailId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckEmailId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckEmailId](@EmailId varchar(255))
as
begin
select EmailId from Users where EmailId=IsNull(@EmailId,EmailId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckFirstName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckFirstName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckFirstName](@FirstName varchar(100))
as
begin
select FirstName from Users where FirstName=IsNull(@FirstName,FirstName)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckMenuName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckMenuName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
create PROCEDURE [dbo].[SP_CheckMenuName] (@Name Varchar(100))
AS
BEGIN
	SELECT Name from Menu
	WHERE Name = ISNULL(@Name, Name)  
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckRoleName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckRoleName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
create PROCEDURE [dbo].[SP_CheckRoleName] (@Name Varchar(100))
AS
BEGIN
	SELECT Name from Roles
	WHERE Name = ISNULL(@Name, Name)  
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckSatetName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckSatetName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckSatetName](@Name varchar(100))
as
begin
select [Name] from StateorProvince where Name=IsNull(@Name,Name)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckSubDistrictName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckSubDistrictName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckSubDistrictName](@Name varchar(100))
as
begin
select [Name] from SubDistrict where Name=IsNull(@Name,Name)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckUserName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckUserName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_CheckUserName](@UserName varchar(100))
as
begin
select UserName from Users where UserName = IsNull (@UserName,UserName)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckVillageName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckVillageName]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckVillageName](@Name varchar(100))
as
begin
select [Name] from Village where Name=IsNull(@Name,Name)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBatchdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBatchdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetBatchdetails](@P_Id int)
as
begin
select
      G.Id,
	  G.BatchNo,

      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from [dbo].[BatchHdrDetails] G
		
	  where G.Id = ISNULL(@P_Id, G.Id)


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBatchGRN_NumberDropdowndetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBatchGRN_NumberDropdowndetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
-- exec SP_GetBatchGRN_NumberDropdowndetails null
CREATE procedure [dbo].[SP_GetBatchGRN_NumberDropdowndetails](@P_Id int)
as
begin
 select
 g.Id,
 g.GRNnumber,
 SUM(n.Quantity) as BatchGRNQuantity,
 g.Quantity as GrnQuantity,
 g.CurrentQty as GRNCurrentqty from BatchGRNDetails n
 right join GRN g on g.Id = n.GRNId where g.CurrentQty > 0 and g.Id=ISNULL(@P_Id, g.Id) and g.IsActive=1
 Group By n.GRNId , g.GRNnumber,g.Quantity,g.CurrentQty,g.Id order by g.GRNnumber
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBatchGRNdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBatchGRNdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetBatchGRNdetails](@BatchHdrId int)
as
begin
select
      G.Id,
	  G.BatchHdrId,
	  G.GRNId,
	  G.Quantity,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId,
	  G.ManfacturerId,
	  G.[DealerId],
	  G.[FarmerId],
	  Gr.GRNnumber ,
	  Gr.GRNdate,
	  m.EntityName as Manufacturer
	    from [dbo].[BatchGRNDetails] G
		left join GRN Gr on G.GRNId = Gr.Id
		left join Manfacturer m on Gr.ManfacturerId = m.Id
	  where G.BatchHdrId = ISNULL(@BatchHdrId, G.BatchHdrId)


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCountOfDealersByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCountOfDealersByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetCountOfDealersByUserId](@P_UserId int)
as
begin
select
   count(1) as NoOfDealers from Dealer


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCountOfManfacturersByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCountOfManfacturersByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetCountOfManfacturersByUserId](@P_UserId int)
as
begin
select
   count(1) as NoOfManfacturers from Manfacturer


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCountryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCountryDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetCountryDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		 ,t.Code
		,t.Name
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[Country] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE   t.Id = ISNULL(@Id, t.Id) order by t.Name asc		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCustomerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCustomerDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetCustomerDetails] (@Id INT)
AS
BEGIN
SELECT 
t.Id,
t.EntityName,
t.Address,
t.Email,
t.Phone,
v.Name as VillageName,
s.Name as SubDistrictname,
d.Name as DistrictorRegencyName,
p.Name as StateorProvinceName,
c.Name as CountryName,

t.[IsActive]
,t.[CreatedDate]
,t.CreatedByUserId
,t.[UpdatedDate]
,t.UpdatedByUserId
	FROM [dbo].[Customer] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	left join Village v On v.Id = t.VillageId
	left join SubDistrict s on s.Id=t.SubDistrictId
	left join DistrictorRegency d on d.Id =t.DistrictorRegencyId
	left join StateorProvince p on p.Id= t.StateorProvinceId
	left join Country y on y.Id = t.CountryId
	WHERE   t.Id = ISNULL(@Id, t.Id)  	 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardForDealerView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardForDealerView]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardForDealerView 10
CREATE proc [dbo].[SP_GetDashboardForDealerView](@DealerId int)
as
begin
declare @NoOfFarmers int,@NoOfPlantations int,@TotalArea decimal(12,3),@NoOfGPSPoints int,@TotalYeildInTons decimal(12,3),@TotalSupplyInTons decimal(12,3)

select @NoOfFarmers= count(Id)  from [dbo].Mapping_DealerFarmer where DealerId = isnull(@DealerId,DealerId)

select  @NoOfPlantations =count(PlotCode),@TotalArea =sum(AreaInHectors)  from [dbo].[Plantation]
where FarmerCode in (select FarmerCode from Farmer where FarmerCode in(select FarmerCode from [dbo].Mapping_DealerFarmer where DealerId = isnull(@DealerId,DealerId)))

select @TotalSupplyInTons= sum(SupplyInTons) from [dbo].[PlantationYeild] where FarmerCode in (select FarmerCode from 
Farmer where FarmerCode in(select FarmerCode from [dbo].Mapping_DealerFarmer  where DealerId = isnull(@DealerId,DealerId)))





select  @NoOfFarmers NoOfFarmers,@NoOfPlantations NoOfPlantations,@TotalArea TotalArea,
@TotalSupplyInTons as TotalSupplyInTons
end









GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardGRNMapDataByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardGRNMapDataByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetDashboardGRNMapDataByDealerId] 1
CREATE proc [dbo].[SP_GetDashboardGRNMapDataByDealerId](@DealerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.Name as EntityName,m.PrimaryContactNo,m.Latitude as M_Latitude,m.Longitute as M_Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_DealerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Dealer m on m.Id = mfm.DealerId
left join GRN G on G.FarmerCode = f.FarmerCode
where mfm.DealerId = @DealerId
order by LastName

end


GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardGRNMapDataByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardGRNMapDataByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetDashboardGRNMapDataByManufacturerId]1
CREATE proc [dbo].[SP_GetDashboardGRNMapDataByManufacturerId](@ManufacturerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.Name as EntityName,m.PrimaryContactNo,m.Latitude as M_Latitude,m.Longitute as M_Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_DealerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Mapping_ManfacturerFarmer fm on fm.FarmerCode = f.FarmerCode
left join Dealer m on m.Id = mfm.DealerId
inner join GRN G on G.FarmerCode = f.FarmerCode
where mfm.DealerId in (select DealerId From [dbo].[Mapping_DealerManufacturer] where ManufacturerId =@ManufacturerId )
order by LastName


end



GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardMapDataByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardMapDataByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetDashboardMapDataByDealerId] 1
CREATE proc [dbo].[SP_GetDashboardMapDataByDealerId](@DealeerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.Name as EntityName,m.PrimaryContactNo,m.Latitude as M_Latitude,m.Longitute as M_Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_DealerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Dealer m on m.Id = mfm.DealerId
where mfm.DealerId = isnull(@DealeerId,mfm.DealerId)
order by LastName


end






GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardMonthlyYeildByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardMonthlyYeildByFarmerCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardMonthlyYeildByFarmerCode 'F_49994952652_1'
CREATE proc [dbo].[SP_GetDashboardMonthlyYeildByFarmerCode](@FarmerCode varchar(255))
as
begin

select py.PlotCode,py.FarmerCode,FORMAT (py.DateOfHarvest, 'MMM-yyyy') as DateOfHarvestMonth,FORMAT (py.DateOfHarvest, 'MM-yyyy') as DateOfHarvestMonthNumber
  ,sum(py.YeildInTons) MonthlyYeildInTons,sum(py.SupplyInTons) MonthlySupplyInTons  into #Temp1 from [dbo].[PlantationYeild] py  where FarmerCode = @FarmerCode
  group by py.PlotCode,py.FarmerCode,FORMAT (py.DateOfHarvest, 'MMM-yyyy'),FORMAT (py.DateOfHarvest, 'MM-yyyy')
 

   select mp.FarmerCode,FORMAT (mp.ProcurmentDate, 'MMM-yyyy') as ProcurmentDateMonth,FORMAT (mp.ProcurmentDate, 'MM-yyyy') as ProcurmentDateMonthNumber
  ,sum(mp.ProcurmentQty) MonthlyProcurmentQty into #Temp2 from [dbo].[ManfacturerProcessingQty] mp  where FarmerCode = @FarmerCode
  group by mp.FarmerCode,FORMAT (mp.ProcurmentDate, 'MMM-yyyy'),FORMAT (mp.ProcurmentDate, 'MM-yyyy')
 
 select t1.*,t2.ProcurmentDateMonth,t2.MonthlyProcurmentQty,f.FirstName+' '+f.LastName as FarmerName,p.Latitude,p.Longitude,p.Address from #Temp1 t1
 left join #Temp2 t2 on t2.FarmerCode = t1.FarmerCode  and t1.DateOfHarvestMonth = t2.ProcurmentDateMonth
 left join Farmer f on f.FarmerCode = t1.FarmerCode
 left join Plantation p on p.FarmerCode = t1.FarmerCode and p.PlotCode = t1.PlotCode
 order by t1.DateOfHarvestMonthNumber
 drop table  #Temp1
  drop table #Temp2

 -- select py.PlotCode,py.FarmerCode,LEFT('0' + CAST(MONTH(py.DateOfHarvest) as varchar(2)),2)  + '-' + CAST(YEAR(py.DateOfHarvest) as char(4)) as DateOfHarvestMonth
 -- ,sum(py.YeildInTons) MonthlyYeildInTons,sum(py.SupplyInTons) MonthlySupplyInTons  into #Temp1 from [dbo].[PlantationYeild] py  where FarmerCode = @FarmerCode
 -- group by py.PlotCode,py.FarmerCode,LEFT('0' + CAST(MONTH(py.DateOfHarvest) as varchar(2)),2)  + '-' + CAST(YEAR(py.DateOfHarvest) as char(4))
 

 --  select mp.FarmerCode,LEFT('0' + CAST(MONTH(mp.ProcurmentDate) as varchar(2)),2)  + '-' + CAST(YEAR(mp.ProcurmentDate) as char(4)) as ProcurmentDateMonth
 -- ,sum(mp.ProcurmentQty) MonthlyProcurmentQty into #Temp2 from [dbo].[ManfacturerProcessingQty] mp  where FarmerCode = @FarmerCode
 -- group by mp.FarmerCode,LEFT('0' + CAST(MONTH(mp.ProcurmentDate) as varchar(2)),2)  + '-' + CAST(YEAR(mp.ProcurmentDate) as char(4))
 
 --select t1.*,t2.ProcurmentDateMonth,t2.MonthlyProcurmentQty,f.FirstName+' '+f.LastName as FarmerName,p.Latitude,p.Longitude from #Temp1 t1
 --left join #Temp2 t2 on t2.FarmerCode = t1.FarmerCode 
 --left join Farmer f on f.FarmerCode = t1.FarmerCode
 --left join Plantation p on p.FarmerCode = t1.FarmerCode and p.PlotCode = t1.PlotCode
 --drop table  #Temp1
 -- drop table #Temp2

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllData]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardOverAllData
CREATE proc [dbo].[SP_GetDashboardOverAllData]
as
begin
declare @NoOfFarmers int,@NoOfPlantations int,@TotalArea decimal(12,3),@NoOfGPSPoints int,@TotalYeildInTons decimal(12,3),@TotalSupplyInTons decimal(12,3)
select @NoOfFarmers =count(FarmerCode)  from [dbo].[Farmer]

select @NoOfPlantations = count(PlotCode),@TotalArea = sum(AreaInHectors) from [dbo].[Plantation]

select @TotalYeildInTons = sum(YeildInTons),@TotalSupplyInTons = sum(SupplyInTons)  from [dbo].[PlantationYeild]

select @NoOfGPSPoints = count(PlotCode)  from [dbo].[Plantation] 
where [Latitude] is not null and [Longitude] is not null

select  @NoOfFarmers NoOfFarmers,@NoOfPlantations NoOfPlantations,@TotalArea TotalArea,@NoOfGPSPoints NoOfGPSPoints
,@TotalYeildInTons as TotalYeild,@TotalSupplyInTons as TotalSupplyInTons
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllDatabymanufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllDatabymanufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 -- exec SP_GetDashboardOverAllDatabymanufacturerId 1
CREATE proc [dbo].[SP_GetDashboardOverAllDatabymanufacturerId] (@ManfacturerId int)
as
begin


select  count(ManufacturerId) as NoofDealers from [dbo].Mapping_DealerManufacturer where ManufacturerId = iSNULL(@ManfacturerId,ManufacturerId)

create table #TempFarmer(FarmerCode varchar(max))
insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_ManfacturerFarmer] where ManfacturerId=iSNULL(@ManfacturerId,ManfacturerId)

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId in (
select DealerId from Mapping_DealerManufacturer where ManufacturerId=iSNULL(@ManfacturerId,ManufacturerId))

select COUNT(F.FarmerCode) as NoOfFarmers
 from Farmer F 
 right join #TempFarmer t on t.FarmerCode=F.FarmerCode
 where f.IsActive=1 and f.FarmerCode in (select FarmerCode from #TempFarmer)

select  
sum(p.AreaInHectors) as TotalArea,COUNT(p.FarmerCode) as  NoOfPlantations 
from Plantation P
 right join #TempFarmer t on t.FarmerCode=P.FarmerCode
 where P.IsActive=1 and P.FarmerCode in (select FarmerCode from #TempFarmer)


select  
isnull(sum(y.YeildInTons),0)  as TotalYeild,
isnull(sum(SupplyInTons),0) as TotalSupplyInTons
from PlantationYeild y
right join #TempFarmer t on t.FarmerCode=y.FarmerCode
 where y.IsActive=1 and y.FarmerCode in (select FarmerCode from #TempFarmer)
 
  
drop table #TempFarmer

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllMapData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllMapData]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardOverAllMapData
CREATE proc [dbo].[SP_GetDashboardOverAllMapData]
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X
left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
order by LastName
-- select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Latitude
-- from
--(select X.PlotCode,X.FarmerCode,'['+string_agg(X.LatLong,',')+']' LatLong from
--(select PlotCode,FarmerCode,'['+cast(Latitude as varchar(255)) +','+cast(Longitude as varchar(255))+']' as LatLong,SeqNo
--from [dbo].[PlantationGeoBoundaries])X
--group by X.PlotCode,X.FarmerCode)X
--left join Farmer f on f.FarmerCode = X.FarmerCode
--left join Plantation p on p.FarmerCode=X.FarmerCode
--order by LastName
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllMapDataByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllMapDataByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardOverAllMapDataByDealerId 1
CREATE proc [dbo].[SP_GetDashboardOverAllMapDataByDealerId](@DealerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.Name as EntityName,m.PrimaryContactNo,m.Latitude as M_Latitude,m.Longitute as M_Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_DealerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Dealer m on m.Id = mfm.DealerId
where mfm.DealerId = @DealerId  and p.IsActive=1
order by LastName


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllMapDataByDealerId_1]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllMapDataByDealerId_1]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardOverAllMapDataByDealerId_1 1
CREATE proc [dbo].[SP_GetDashboardOverAllMapDataByDealerId_1](@DealerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.Name as EntityName,m.PrimaryContactNo,
m.Latitude as M_Latitude,m.Longitute as M_Longitude,'yellow' PolygonColor,
case when grn.FarmerCode is null then 0 else 1 end IsGRN into #Temp2
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_DealerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Dealer m on m.Id = mfm.DealerId
left join (select DealerId,FarmerCode,COUNT(DealerId) as cnt from GRN where (ManfacturerId is null or ManfacturerId=0) group by DealerId,FarmerCode)grn on grn.DealerId = m.Id and grn.FarmerCode=f.FarmerCode
where mfm.DealerId in (select DealerId from Mapping_DealerFarmer where DealerId = isnull(@DealerId,DealerId))
order by LastName

select * from #Temp2 order by PolygonColor

drop table #Temp2
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllMapDataByManfacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllMapDataByManfacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardOverAllMapDataByManfacturerId 2
CREATE proc [dbo].[SP_GetDashboardOverAllMapDataByManfacturerId](@ManfacturerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.EntityName,m.PrimaryContactName,m.PrimaryContactNo,m.Latitude as M_Latitude,m.Longitude as M_Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_ManfacturerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Manfacturer m on m.Id = mfm.ManfacturerId
where mfm.ManfacturerId = @ManfacturerId  and p.IsActive=1
order by LastName


end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardOverAllMapDataByManfacturerId_1]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardOverAllMapDataByManfacturerId_1]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardOverAllMapDataByManfacturerId_1 1
CREATE proc [dbo].[SP_GetDashboardOverAllMapDataByManfacturerId_1](@ManfacturerId int)
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,
p.Latitude,p.Longitude,
m.EntityName,m.PrimaryContactNo,
m.Latitude as M_Latitude,m.Longitude as M_Longitude,'red' PolygonColor,
case when grn.FarmerCode is null then 0 else 1 end IsGRN into #Temp1
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries 
group by PlotCode,FarmerCode) X
left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_ManfacturerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Manfacturer m on m.Id = mfm.ManfacturerId
left join (select ManfacturerId,FarmerCode,COUNT(ManfacturerId) as cnt from GRN where (DealerId is null or DealerId=0) group by ManfacturerId,FarmerCode)grn on grn.ManfacturerId = mfm.ManfacturerId and grn.FarmerCode= f.FarmerCode
where mfm.ManfacturerId = @ManfacturerId  and p.IsActive=1
order by LastName



select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
m.Name as EntityName,m.PrimaryContactNo,
m.Latitude as M_Latitude,m.Longitute as M_Longitude,'yellow' PolygonColor,
case when grn.FarmerCode is null then 0 else 1 end IsGRN into #Temp2
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_DealerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Dealer m on m.Id = mfm.DealerId
left join (select DealerId,FarmerCode,COUNT(DealerId) as cnt from GRN where (ManfacturerId is null or ManfacturerId=0 ) group by DealerId,FarmerCode)grn on grn.DealerId = m.Id and grn.FarmerCode=f.FarmerCode
where mfm.DealerId in (select DealerId from Mapping_DealerManufacturer where ManufacturerId = @ManfacturerId)
order by LastName

select * from
(select * from #Temp1
union all
select * from #Temp2)X order by PolygonColor


drop table #Temp1
drop table #Temp2
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardPlantationMonthlyWiseYeild]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardPlantationMonthlyWiseYeild]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardPlantationMonthlyWiseYeild
create proc [dbo].[SP_GetDashboardPlantationMonthlyWiseYeild]
as
begin

select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Latitude from
(select PlotCode,FarmerCode,sum(YeildInTons) TotalYeildInTons,sum(SupplyInTons) TotalSupplyInTons from PlantationYeild
group by PlotCode,FarmerCode)X
 left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
order by f.FirstName+' '+f.LastName
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalFarmerscardAnalysisByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalFarmerscardAnalysisByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 --- exec SP_GetDashboardTotalFarmerscardAnalysisByDealerId null
 CREATE proc [dbo].[SP_GetDashboardTotalFarmerscardAnalysisByDealerId](@DealerId int)
as
begin
  select  
  COUNT(F.FarmerCode) Farmercount,
  SUM(CASE WHEN F.Gender = 'Male' THEN 1 ELSE 0 END) AS Male_count,
  SUM(CASE WHEN F.Gender = 'Female' THEN 1 ELSE 0 END) AS Female_count,   
  COUNT(CASE WHEN s.FarmerId IS NOT NULL THEN s.FarmerId ELSE NULL END) AS SurveyCompleted,
  COUNT(CASE WHEN F.IsMapping = 1 THEN F.FarmerCode ELSE NULL END) MappedFarmers ,
  count(p.PlotCode) Plotstaken ,
  COUNT(CASE WHEN P.Latitude Is not null And p.Longitude is not null THEN 1 ELSE 0 END) GPSMapped,
  COUNT(P.Latitude) GPSOverall
   from Farmer F 
  right join Mapping_DealerFarmer m on m.FarmerCode = F.FarmerCode
  inner join Plantation p on p.FarmerCode = F.FarmerCode
  left join FarmerHouseholdSurvey s on s.FarmerId = F.Id
  where m.DealerId = ISNULL(@DealerId,m.DealerId)  
  end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalFarmerscardAnalysisByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalFarmerscardAnalysisByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 --- exec [SP_GetDashboardTotalFarmerscardAnalysisByManufacturerId] 1
 CREATE proc [dbo].[SP_GetDashboardTotalFarmerscardAnalysisByManufacturerId](@ManufacturerId int)
as
begin
create table #TempFarmer(FarmerCode varchar(max))
insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_ManfacturerFarmer] where ManfacturerId=iSNULL(@ManufacturerId,ManfacturerId)
insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId in (
select DealerId from Mapping_DealerManufacturer where ManufacturerId=iSNULL(@ManufacturerId,ManufacturerId))
select  COUNT(F.FarmerCode) as Farmercount,
  SUM(CASE WHEN F.Gender = 'Male' THEN 1 ELSE 0 END) AS Male_count,
  SUM(CASE WHEN F.Gender = 'Female' THEN 1 ELSE 0 END) AS Female_count,   
  COUNT(CASE WHEN F.IsMapping = 1 THEN F.FarmerCode ELSE NULL END) MappedFarmers   
   from Farmer F 
  where F.IsActive=1 and F.FarmerCode in (select FarmerCode from #TempFarmer)

  select COUNT(PlotCode) as Plotstaken, COUNT(P.Latitude) as GPSOverall,
  COUNT(CASE WHEN P.Latitude Is not null And p.Longitude is not null THEN 1 ELSE 0 END) as GPSMapped
  from Plantation p 
  where P.IsActive=1 and P.FarmerCode in (select FarmerCode from #TempFarmer)

  select COUNT(CASE WHEN s.FarmerId IS NOT NULL THEN s.FarmerId ELSE NULL END) AS SurveyCompleted from FarmerHouseholdSurvey s
  where S.IsActive=1 and S.FarmerCode in (select FarmerCode from #TempFarmer)

   drop table #TempFarmer
  end 
   

GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalFarmersDetailsByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalFarmersDetailsByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- exec SP_GetDashboardTotalFarmersDetailsByDealerId 1,1
CREATE proc [dbo].[SP_GetDashboardTotalFarmersDetailsByDealerId](@DealerId int,@VillageId Int)
as
begin
select mf.Name,m.DealerId,COUNT(f.FarmerCode)as TotalFarmers,count(p.PlotCode) as ToatlPlantations,
Sum(p.AreaInHectors)as TotalPlantationArea,v.Name AS VillageName
from Farmer f
right join Mapping_DealerFarmer m on m.FarmerCode = f.FarmerCode
left join dealer mf on mf.Id = m.DealerId
left join Village v on v.Id= f.VillageId
left join Plantation p on p.FarmerCode = f.FarmerCode
where 
--CONVERT(DATE, f.CreatedDate) = '2023-06-22 08:42:16.430' and
m.DealerId =ISNULL(@DealerId, m.DealerId)
and f.VillageId = ISNULL(@VillageId, f.VillageId)
group by  mf.Name,m.DealerId,v.Name
end 
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalFarmersDetailsByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalFarmersDetailsByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 -- exec SP_GetDashboardTotalFarmersDetailsByManufacturerId null,1

CREATE proc [dbo].[SP_GetDashboardTotalFarmersDetailsByManufacturerId](@ManufacturerId int,@VillageId Int)
as
begin
select mf.EntityName,m.ManfacturerId,COUNT(f.FarmerCode)as TotalFarmers,count(p.PlotCode) as ToatlPlantations,
Sum(p.AreaInHectors) as TotalPlantationArea ,v.Name AS VillageName 
from Farmer f
right join Mapping_ManfacturerFarmer m on m.FarmerCode = f.FarmerCode
left join Manfacturer mf on mf.Id = m.ManfacturerId
left join Village v on v.Id= f.VillageId
left join Plantation p on p.FarmerCode =f.FarmerCode
where 
--CONVERT(DATE, f.CreatedDate) = '2023-06-22 08:42:16.430' and
m.ManfacturerId =ISNULL(@ManufacturerId , m.ManfacturerId)
and f.VillageId = ISNULL(@VillageId, f.VillageId)
group by  mf.EntityName,m.ManfacturerId,v.Name
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalPlantationMappedwithGPSDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalPlantationMappedwithGPSDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
-- exec SP_GetDashboardTotalPlantationMappedwithGPSDealerId 1,1
CREATE proc [dbo].[SP_GetDashboardTotalPlantationMappedwithGPSDealerId](@DealerId int,@VillageId Int)
as   
begin                                                                                          
select mf.Name,m.DealerId,count(p.PlotCode) as TotalPlantationsMappedwithGPS,Sum(CAST (p.GeoboundariesArea As decimal(12,3)))  As 
TotalPlantationAreaasperGPS,v.Name AS VillageName
from Farmer f
right join Mapping_DealerFarmer m on m.FarmerCode = f.FarmerCode
left join dealer mf on mf.Id = m.DealerId
left join Village v on v.Id= f.VillageId
left join Plantation p on p.FarmerCode = f.FarmerCode
where 
--CONVERT(DATE, f.CreatedDate) = '2023-06-22 08:42:16.430' and
m.DealerId =ISNULL(@DealerId, m.DealerId) and 
 f.VillageId = ISNULL(@VillageId, f.VillageId) 
 and p.Latitude IS NOT NULL and p.Latitude IS NOT NULL
group by  mf.Name,m.DealerId,v.Name
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalPlantationMappedwithGPSManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalPlantationMappedwithGPSManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- exec [SP_GetDashboardTotalPlantationMappedwithGPSManufacturerId] 1,1
 CREATE proc [dbo].[SP_GetDashboardTotalPlantationMappedwithGPSManufacturerId](@ManufacturerId int,@VillageId Int)
as
begin
select mf.EntityName,m.ManfacturerId,count(p.PlotCode) as TotalPlantationsMappedwithGPS,Sum(CAST (p.GeoboundariesArea As decimal(12,3)))  As 
TotalPlantationAreaasperGPS ,v.Name AS VillageName 
from Farmer f
right join Mapping_ManfacturerFarmer m on m.FarmerCode = f.FarmerCode
left join Manfacturer mf on mf.Id = m.ManfacturerId
left join Village v on v.Id= f.VillageId
left join Plantation p on p.FarmerCode =f.FarmerCode
where 
--CONVERT(DATE, f.CreatedDate) = '2023-06-22 08:42:16.430' and
m.ManfacturerId =ISNULL(@ManufacturerId , m.ManfacturerId)
and f.VillageId = ISNULL(@VillageId, f.VillageId)
 and p.Latitude IS NOT NULL and p.Latitude IS NOT NULL
group by  mf.EntityName,m.ManfacturerId,v.Name
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalPlotcardAnalysisByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalPlotcardAnalysisByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 --- exec [SP_GetDashboardTotalPlotcardAnalysisByDealerId] null
 CREATE proc [dbo].[SP_GetDashboardTotalPlotcardAnalysisByDealerId](@DealerId int)
as
begin
  select  
  COUNT(p.PlotCode) PlotCount,
  sum(p.AreaInHectors) TotalPlotArea,
    COUNT(CASE WHEN P.Latitude Is not null And p.Longitude is not null THEN 1 ELSE 0 END) GPSMapped,
  COUNT(P.Latitude) GPSOverall,
  Sum(CAST (p.GeoboundariesArea As decimal(12,3))) TotalPlotAreaGPS
from Plantation P
  right join Mapping_DealerFarmer m on m.FarmerCode = P.FarmerCode
  left join Farmer f on f.FarmerCode = p.FarmerCode
   where m.DealerId = ISNULL(@DealerId,m.DealerId)  
  end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalPlotcardAnalysisByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalPlotcardAnalysisByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 --- exec [SP_GetDashboardTotalPlotcardAnalysisByManufacturerId] 1
 CREATE proc [dbo].[SP_GetDashboardTotalPlotcardAnalysisByManufacturerId](@ManfacturerId int)
as
begin
create table #TempFarmer(FarmerCode varchar(max))
insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_ManfacturerFarmer] where ManfacturerId=iSNULL(@ManfacturerId,ManfacturerId)
insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId in (
select DealerId from Mapping_DealerManufacturer where ManufacturerId=iSNULL(@ManfacturerId,ManufacturerId))

  select  
  COUNT(p.PlotCode) PlotCount,
  sum(p.AreaInHectors) TotalPlotArea,
  COUNT(CASE WHEN P.Latitude Is not null And p.Longitude is not null THEN 1 ELSE 0 END) GPSMapped,
  COUNT(P.Latitude) GPSOverall,
  Sum(CAST (p.GeoboundariesArea As decimal(12,3))) as TotalPlotAreaGPS
  from Plantation P
   where p.IsActive=1 and p.FarmerCode in (select FarmerCode from #TempFarmer) 
    drop table #TempFarmer
  end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalProcurementDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalProcurementDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDashboardTotalProcurementManfacturerId 1,null,'2023-01-01'
CREATE proc [dbo].[SP_GetDashboardTotalProcurementDealerId](@DealerId int,@VillageId int,@CreatedDate varchar(255))
as
begin
select SUM(Quantity) as SumofTotalProcurement,COUNT(GRNnumber) as NumberofTotalProcurement,v.Name as VillageName from GRN G
left join Farmer f on f.FarmerCode = G.FarmerCode
right join Mapping_DealerFarmer m on m.FarmerCode = f.FarmerCode
left join Village v on v.Id = f.VillageId
where f.VillageId = ISNULL(@VillageId, f.VillageId) and  CONVERT(DATE, G.CreatedDate)  BETWEEN @CreatedDate and GETDATE() and G.DealerId = ISNULL(@DealerId, G.DealerId)  group by v.Name
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardTotalProcurementManfacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardTotalProcurementManfacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetDashboardTotalProcurementManfacturerId](@ManfacturerId int,@VillageId int,@CreatedDate varchar(255))
as
begin
select SUM(Quantity) as SumofTotalProcurement,COUNT(GRNnumber) as NumberofTotalProcurement,v.Name as VillageName from GRN G
left join Farmer f on f.FarmerCode = G.FarmerCode
right join Mapping_ManfacturerFarmer m on m.FarmerCode = f.FarmerCode
left join Village v on v.Id = f.VillageId
where f.VillageId = ISNULL(@VillageId, f.VillageId) and  CONVERT(DATE, G.CreatedDate)  BETWEEN @CreatedDate and GETDATE() and G.ManfacturerId = ISNULL(@ManfacturerId, G.ManfacturerId)  group by v.Name
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetDealer](@P_Id int)
AS
BEGIN
SELECT 
       Id,
	   Name,
	   PrimaryContactNo,
	   Address,
	   Village,
	   Latitude,
	   Longitute,
	   IsActive,
	   CreatedDate,
	   CreatedByUserId,
	   UpdatedDate,
	   UpdatedByUserId
	     FROM Dealer
		   WHERE Id = ISNULL(@P_Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerDetailsByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerDetailsByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDealerDetailsByDealerId 1
CREATE proc [dbo].[SP_GetDealerDetailsByDealerId](@DealerId int)
as
begin

select m.EntityName,m.PrimaryContactName,m.PrimaryContactNo,m.Latitude as ManfacturerLatitude,
m.Longitude as ManfacturerLongitude,m.Address as ManfacturerAddress,d.Name as DealerName,
d.PrimaryContactNo as DealerContactNo,d.Latitude as DealerLatitude,
d.Longitute as DealerLogitude,d.Address as DealerAddress,case when grn.cnt=0 then 0 else 1 end IsGRN
from Dealer d
left join Mapping_DealerManufacturer dm on dm.DealerId = d.Id
left join Manfacturer m on m.Id = dm.ManufacturerId
left join (select DealerId,COUNT(DealerId) as cnt from GRN where FarmerCode is null group by DealerId)grn on grn.DealerId = d.Id
where d.Id = isnull(@DealerId,d.Id)
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerDetailsByManfactureId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerDetailsByManfactureId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create procedure [dbo].[SP_GetDealerDetailsByManfactureId](@P_ManufactureId int)
AS
BEGIN
    SELECT
    Id,
    Name,
	PrimaryContactNo,
	Address,
	Village,
	Latitude,
	Longitute,
	ManufacturerId,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId		
	FROM Dealer
		 WHERE ManufacturerId = ISNULL(@P_ManufactureId, ManufacturerId) AND
		 IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerDetailsByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerDetailsByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDealerDetailsByManufacturerId 1
CREATE proc [dbo].[SP_GetDealerDetailsByManufacturerId](@ManufacturerId int)
as
begin

select m.EntityName,m.PrimaryContactName,m.PrimaryContactNo,m.Latitude as ManfacturerLatitude,
m.Longitude as ManfacturerLongitude,m.Address as ManfacturerAddress,d.Name as DealerName,
d.PrimaryContactNo as DealerContactNo,d.Latitude as DealerLatitude,
d.Longitute as DealerLogitude,d.Address as DealerAddress,case when grn.cnt=0 then 0 else 1 end IsGRN
from Manfacturer m
left join Mapping_DealerManufacturer k on k.ManufacturerId = m.Id
left join Dealer d on d.Id = k.DealerId
left join (select DealerId,COUNT(DealerId) as cnt from GRN where FarmerCode is null group by DealerId)grn on grn.DealerId = d.Id
where m.Id = @ManufacturerId

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerDetailsForSubDealerDropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerDetailsForSubDealerDropDown]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetDealerDetailsForSubDealerDropDown](@Id int)
AS
BEGIN
    SELECT
    Id,
    Name,
	
	
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId		
	FROM Dealer
		 WHERE Id = ISNULL(@Id,Id) AND
		 IsActive = 1 AND [IsSubDealer]  = null
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerDetailsGRNCheckByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerDetailsGRNCheckByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetDealerDetailsGRNCheckByDealerId] 1
CREATE proc [dbo].[SP_GetDealerDetailsGRNCheckByDealerId](@DealerId int)
as
begin

select d.Name as DealerName,
d.PrimaryContactNo as DealerContactNo,d.Latitude as DealerLatitude,
d.Longitute as DealerLogitude,d.Address as DealerAddress,case when grn.cnt=0 then 0 else 1 end IsGRN
from Dealer d

left join (select DealerId,COUNT(DealerId) as cnt from GRN where FarmerCode is null group by DealerId)grn on grn.DealerId = d.Id
where d.Id = @DealerId

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerFarmerMappingByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerFarmerMappingByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDealerFarmerMappingByDealerId] (@DealerId INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,r.FarmerCode
		,r.Id as FarmerId
		,D.Name as DealerName
		,t.DealerId
		,r.FirstName + r.LastName as FarmerName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_DealerFarmer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Farmer r on r.FarmerCode = t.FarmerCode
	INNER JOIN Dealer d on d.Id = t.DealerId
	WHERE t.DealerId = ISNULL(@DealerId, t.Id) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerFarmerMappingByDealerIdForDropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerFarmerMappingByDealerIdForDropDown]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_IntelliTrack__GetDealerFarmerMappingByDealerId 1
Create procedure [dbo].[SP_GetDealerFarmerMappingByDealerIdForDropDown](@DealerId int)
AS
BEGIN
    SELECT
    M.Id,

	F.Id As FarmerId,
	M.FarmerCode,
	F.FirstName + F.LastName as FarmerName,
	M.DealerId,
	D.Name  as DealerName,
	M.IsActive,
	M.CreatedDate,
	M.CreatedByUserId,
	M.UpdatedDate,
	M.UpdatedByUserId
		 FROM Mapping_DealerFarmer M
		left join Farmer F on F.FarmerCode = M.FarmerCode
		left join Dealer D on D.Id = M.DealerId
		left join GRN grn on grn.FarmerCode = m.FarmerCode and grn.DealerId=d.Id
		 WHERE M.DealerId = @DealerId and M.IsActive =1 and grn.Id is null
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerFarmerMappingDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerFarmerMappingDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDealerFarmerMappingDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode,
		r.Id as FarmerId
		,t.[DealerId]
		,d.Name as DealerName
		,r.FirstName + r.LastName as FarmerName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_DealerFarmer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Farmer r on r.FarmerCode = t.FarmerCode
	INNER JOIN Dealer d on d.Id = t.DealerId
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerManufacturerMappingDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerManufacturerMappingDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetDealerManufacturerMappingDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ManufacturerId]
		,t.[DealerId]
		,d.Name as DealerName
		,r.EntityName as Manufacturer
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_DealerManufacturer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Manfacturer r on r.Id = t.ManufacturerId
	INNER JOIN Dealer d on d.Id = t.DealerId
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerManufacturerMappingDetailsByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerManufacturerMappingDetailsByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDealerManufacturerMappingDetailsByManufacturerId] (@ManufacturerId INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ManufacturerId]
		,t.[DealerId]
,d.Latitude as Dealer_Latitude
,d.Longitute as Dealer_Longitude
		,d.Name as DealerName
		,r.EntityName as Manufacturer
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_DealerManufacturer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Manfacturer r on r.Id = t.ManufacturerId
	INNER JOIN Dealer d on d.Id = t.DealerId
	WHERE t.ManufacturerId = ISNULL(@ManufacturerId, t.ManufacturerId) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerSubDealerMappingDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerSubDealerMappingDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDealerSubDealerMappingDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.Id,
		t.DealerId,
		d.Name As DealerName
	,t.SubDealerId
	,dd.Name as SubDealerName,
	t.IsActive,
		t.CreatedDate
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.UpdatedDate
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_DealerSubDealer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId

	left JOIN Dealer d on d.Id = t.DealerId
	left JOIN Dealer dd on dd.Id = t.SubDealerId
	WHERE t.Id = ISNULL(@Id, t.Id) AND t.IsActive = 1  order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDeforestrationDetailsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeforestrationDetailsByFarmerCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDeforestrationDetailsByFarmerCode null
CREATE procedure [dbo].[SP_GetDeforestrationDetailsByFarmerCode](@P_FarmerCode varchar(255))
AS
BEGIN
    SELECT
  P.Id,
  P.PlotCode,
  P.FarmerCode,
  f.FirstName + f.LastName  as FarmerName,
  P.TypeOfOwnership,
  P.AreaInHectors,
  P.GeoboundariesArea,
  P.Latitude,
  P.Longitude,
  P.Address,
  P.VillageId,
  P.IsActive,
  P.CreatedDate,
  P.CreatedByUserId,
  P.UpdatedDate,
  P.UpdatedByUserId
  ,pf.FieldId
  ,pf.FieldImageResponseForNDVI
  ,pf.FieldImageResponseForNDWI
  ,pf.FieldImageResponseForLULC
  ,pf.FieldImageResponseForNDMI
  ,'2023-08-15' SensedDate
  ,pgb.Latitude Latitude_1
  ,pgb.Longitude Longitude_1
  ,pgb1.Latitude Latitude_4
  ,pgb1.Longitude Longitude_4
  ,pp.LatLong
  FROM Plantation P
 left join Farmer f on f.FarmerCode = P.FarmerCode
 inner join PlotFarmonaut pf on pf.PlotCode = p.PlotCode
 left join PlantationGeoBoundaries pgb on pgb.PlotCode = p.PlotCode and pgb.SeqNo=1
 left join PlantationGeoBoundaries pgb1 on pgb1.PlotCode = p.PlotCode and pgb1.SeqNo=4
 left join 
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong 
from PlantationGeoBoundaries  group by PlotCode,FarmerCode) pp on pp.PlotCode = p.PlotCode
WHERE P.FarmerCode = ISNULL(@P_FarmerCode, P.FarmerCode)
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictorRegencyDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictorRegencyDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDistrictorRegencyDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		 ,t.Code
		,t.[Name]
		,t.StateId
		,s.[Name] as StateorProvinceName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[DistrictorRegency] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	left join StateorProvince s On s.Id = t.StateId
	WHERE  t.Id = ISNULL(@Id, t.Id) order by t.Name asc		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDRCDetailsByDRCHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDRCDetailsByDRCHdrId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetDRCDetailsByDRCHdrId](@DRCHdrId int)
as
begin
select
      G.Id,
	  G.DRCHdrId,
	  G.GRNId,
	G.DRCValue,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId,
	 Gr.Quantity,
	  Gr.GRNnumber,
	  Gr.CurrentQty,
	  Gr.GRNdate
	 
	    from [dbo].[DRCDetails] G
		left join GRN Gr on G.GRNId = Gr.Id
		
	  where G.DRCHdrId = ISNULL(@DRCHdrId, G.DRCHdrId)


end


GO

-- %% [markdown]
-- # [dbo].[SP_GetDRCDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDRCDetailsById]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetDRCDetailsById](@Id int)
as
begin
select
      G.Id,
	  G.DRCHdrId,
	  G.GRNId,
	G.DRCValue,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId,
	 Gr.Quantity,
	  Gr.GRNnumber,
	  Gr.CurrentQty,
	  Gr.GRNdate
	 
	    from [dbo].[DRCDetails] G
		left join GRN Gr on G.GRNId = Gr.Id
		
	  where G.Id = ISNULL(@Id, G.Id)


end


GO

-- %% [markdown]
-- # [dbo].[SP_GetDRCHdrdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDRCHdrdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetDRCHdrdetails](@P_Id int)
as
begin
select
      G.Id,
	  G.DRCNo,
	  G.DRCDocument,

      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from [dbo].DRCHdrDetails G
		
	  where G.Id = ISNULL(@P_Id, G.Id)


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsBasedOnDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsBasedOnDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetFarmerDetailsBasedOnManfacturerId 1
Create proc [dbo].[SP_GetFarmerDetailsBasedOnDealerId](@DealerId int)
as
begin
create table #TempFarmer(FarmerCode varchar(max))

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId = @DealerId

 select * from Farmer where IsActive=1 and FarmerCode in (select FarmerCode from #TempFarmer)

 drop table #TempFarmer
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsBasedOnManfacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsBasedOnManfacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetFarmerDetailsBasedOnManfacturerId 1
CREATE proc [dbo].[SP_GetFarmerDetailsBasedOnManfacturerId](@ManfacturerId int)
as
begin
if @ManfacturerId is not null
begin
create table #TempFarmer(FarmerCode varchar(max))

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_ManfacturerFarmer] where ManfacturerId=iSNULL(@ManfacturerId,ManfacturerId)

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId in (
 select DealerId from Mapping_DealerManufacturer where ManufacturerId=iSNULL(@ManfacturerId,ManufacturerId))

 select * from Farmer where IsActive=1 and FarmerCode in (select FarmerCode from #TempFarmer)

 drop table #TempFarmer
 end
 else 
 begin
 select * from Farmer where IsActive=1
 end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsByFarmerCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create procedure [dbo].[SP_GetFarmerDetailsByFarmerCode](@P_FarmerCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  Address,
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  Image,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE FarmerCode = ISNULL(@P_FarmerCode, FarmerCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetFarmerDetailsByUserId](@P_CreatedByUserId int)
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  Address,
  IsHouseholdServy,
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  Image,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE CreatedByUserId = ISNULL(@P_CreatedByUserId, CreatedByUserId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsForMapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsForMapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetFarmerDetailsForMapping](@P_Id Int)
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE Id = ISNULL(@P_Id,Id) and IsMapping = 0 and IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsForMappingByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsForMappingByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerDetailsForMappingByDealerId 1,'F_49994952652_1'
CREATE procedure [dbo].[SP_GetFarmerDetailsForMappingByDealerId](@DealerId Int,@FarmerCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE IsMapping = 0 and IsActive = 1

  union

  SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE FarmerCode in (select FarmerCode from Mapping_DealerFarmer
		 where DealerId=@DealerId and FarmerCode=@FarmerCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsForMappingByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsForMappingByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetFarmerDetailsForMappingByManufacturerId] 1,'F_62348037350_1'
Create procedure [dbo].[SP_GetFarmerDetailsForMappingByManufacturerId](@ManufacturerId Int,@FarmerCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE IsMapping = 0 and IsActive = 1

  union

  SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE FarmerCode in (select FarmerCode from Mapping_ManfacturerFarmer
		 where ManfacturerId=@ManufacturerId and FarmerCode=@FarmerCode)
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerHouseholdChildrenDetailsByFarmerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerHouseholdChildrenDetailsByFarmerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetFarmerHouseholdChildrenDetailsByFarmerId](@P_FarmerId int)
AS
BEGIN

SELECT
  Id,
 FarmerHouseholdSurveyId,
FarmerId,
Farmercode,
ChildrenName,
ChildrenGender,
ChildrenAge,
ChildrenOccupation,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId
    FROM FarmerHouseholdChildrenDetails
	    WHERE FarmerId = ISNULL(@P_FarmerId,FarmerId)

END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerHouseholdSurveyDetailsByFarmerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerHouseholdSurveyDetailsByFarmerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetFarmerHouseholdSurveyDetailsByFarmerId](@P_FarmerId int)
AS
BEGIN

SELECT
  fh.Id,
  fh.FarmerId,
  fh.FarmerCode,
  fh.FamilyCount,
 fh.MaritalStatus,
  fh.SpouseName,
  fh.Age,
  f.FirstName + f.LastName as FarmerName,
  fh.Gender,
  fh.Occupation,
  fh.NoofChildren,
  fh.IsActive,
  fh.CreatedDate,
  fh.CreatedByUserId,
  fh.UpdatedDate,
  fh.UpdatedByUserId
    FROM FarmerHouseholdSurvey fh
	inner join Farmer f on f.Id = fh.FarmerId
	    WHERE FarmerId = ISNULL(@P_FarmerId,FarmerId)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGRNdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGRNdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGRNdetails](@P_Id int)
as
begin
select
      G.Id,
	  G.GRNnumber,
	  F.FarmerCode,
	  F.FirstName + F.LastName as FarmerName,
	  F.Address as farmeradress,
      G.ManfacturerId,
	  mf.EntityName as Manufacturer,
      G.DealerId,
	  D.Address as DealerAddress,
      G.Quantity,
	  G.CurrentQty,
      G.GRNdate,
	 
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from GRN G
		left JOIN Farmer F ON G.FarmerCode = F.FarmerCode
		left join Manfacturer mf on mf.Id= G.ManfacturerId
		left join Dealer D on D.Id  = G.DealerId
	  where G.Id = ISNULL(@P_Id, G.Id)


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGRNdetailsByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGRNdetailsByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGRNdetailsByDealerId](@DealerId int)
as
begin
select
      G.Id,
	  G.GRNnumber,
	  F.FarmerCode,
	  F.FirstName + F.LastName as FarmerName,
	  F.Address as farmeradress,
    F.Id as FarmerId,
	G.DealerId,
	  D.Address as DealerAddress,
	  D.Name as DealerName,
      G.Quantity,
	  G.CurrentQty,
      G.GRNdate,
	 G.ModeofTransport,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from GRN G
		left JOIN Farmer F ON G.FarmerCode = F.FarmerCode
		
		left join Dealer D on D.Id  = G.DealerId
	  where G.DealerId = ISNULL(@DealerId, G.DealerId)


end




GO

-- %% [markdown]
-- # [dbo].[SP_GetGRNdetailsByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGRNdetailsByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGRNdetailsByManufacturerId](@ManufacturerId int)
as
begin
select
      G.Id,
	  G.GRNnumber,
	  F.FarmerCode,
	  F.FirstName + F.LastName as FarmerName,
	  F.Id as FarmerId,
	  G.DealerId,
	 D.Name as DealerName,
	G.ManfacturerId,
	M.EntityName as ManufacturerName,
 G.Quantity,
	  G.CurrentQty,
      G.GRNdate,
	 G.ModeofTransport,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from GRN G
		left JOIN Farmer F ON G.FarmerCode = F.FarmerCode
		
		left join Manfacturer M on M.Id  = G.ManfacturerId
		left Join Dealer D on d.Id = G.DealerId
	  where G.ManfacturerId = ISNULL(@ManufacturerId, G.ManfacturerId)


end





GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetInvoiceDetails](@P_Id int)
as
begin
select
      i.Id,
	  InvoiceNumber,
	  Vessel,
      PortofLoading,
      PortofDischarge,
      POLTiming,
      PODTiming,
      ManfacturerId,
	  I.DealerId,
	  d.Name AS DealerName,
      Product,
      Quantity,
      ShippingTo,
      ShippingAddress,
      i.IsActive,
      i.CreatedDate,
	  C.EntityName as ShippingToName,
	  mf.EntityName  as Manufacturer
	    from Invoice i
		left join Manfacturer mf on mf.Id = i.ManfacturerId

		inner join Customer C on C.Id = i.ShippingTo
			left join Dealer d on D.Id = i.DealerId
	  where i.Id = isnull(@P_Id, i.Id)


end


    
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDetailsByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDetailsByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetInvoiceDetailsByDealerId](@DealerId int)
as
begin
select
      i.Id,
	  InvoiceNumber,
	
     
	  I.DealerId,
	  d.Name AS DealerName,
      Product,
      Quantity,
      ShippingTo,
      ShippingAddress,
      i.IsActive,
      i.CreatedDate,
	  C.EntityName as ShippingToName
	
	    from Invoice i
		

		inner join Customer C on C.Id = i.ShippingTo
			inner join Dealer d on D.Id = i.DealerId
	  where i.DealerId = isnull(@DealerId, i.DealerId)


end


   
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDetailsByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDetailsByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetInvoiceDetailsByManufacturerId](@ManufacturerId int)
as
begin
select
      i.Id,
	  InvoiceNumber,
	
     
	  I.ManfacturerId,
	  d.EntityName AS ManufacturerName,
      Product,
      Quantity,
      ShippingTo,
      ShippingAddress,
      i.IsActive,
      i.CreatedDate,
	  C.EntityName as ShippingToName
	
	    from Invoice i
		

		inner join Customer C on C.Id = i.ShippingTo
			left join Manfacturer d on D.Id = i.ManfacturerId
	  where i.ManfacturerId = isnull(@ManufacturerId, i.ManfacturerId)


end


    
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogisticsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogisticsDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetLogisticsDetails] (@Id INT)
AS
BEGIN
 
	SELECT 
		 l.[Id]
		 ,l.VehicleRegistrationNumber
		 ,l.InsuranceExpiryDate
		 ,l.ManufacturingYear
		 ,l.LastMaintenanceDate
		 ,l.VehicleType
		 ,l.VehicleLoadCapacity
		 ,l.Fueltype
		,l.[IsActive]
		,l.[CreatedDate]
		,l.CreatedByUserId
		,l.[UpdatedDate]
		,l.UpdatedByUserId
	FROM [dbo].[Logistics] l
	INNER JOIN VW_UserInfo c ON c.Id=l.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=l.UpdatedByUserId
	WHERE l.IsActive=1 and  l.Id = ISNULL(@Id, l.Id)  	 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetManfacturer](@P_Id int)
AS
BEGIN
    SELECT
    Id,
    EntityName,
	PrimaryContactName,
	PrimaryContactNo,
	SecondaryContactNo,
	Latitude,
	Longitude,
	Address,
	VillageId,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId		
	FROM Manfacturer
		 WHERE Id = ISNULL(@P_Id, Id) AND
		 IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturerDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetManfacturerDetails
 CREATE proc [dbo].[SP_GetManfacturerDetails]
 as
 begin
   select Id,EntityName,PrimaryContactName,PrimaryContactNo,Latitude,Longitude,Address
   from Manfacturer where IsActive = 1
 end
GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturerFarmerMappingDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturerFarmerMappingDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetManfacturerFarmerMappingDetails](@P_Id int)
AS
BEGIN
    SELECT
    Id,
	FarmerCode,
	ManfacturerId,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
		 FROM Mapping_ManfacturerFarmer
		 WHERE Id = ISNULL(@P_Id, Id)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturerProcessingQtyDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturerProcessingQtyDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetManfacturerProcessingQtyDetails](@P_Id int)
AS
BEGIN
    SELECT
    Id,
	ManfacturerId,
    FarmerCode,
    ProcurmentDate,
    ProcurmentQty,
    IsProcessed,
    ProcessedBatchId,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
		 FROM ManfacturerProcessingQty
		 WHERE Id = ISNULL(@P_Id, Id)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetManufacturer-DealerMappingDtlForMobile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManufacturer-DealerMappingDtlForMobile]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetManufacturer-DealerMappingDtlForMobile](@ManufacturerId int)
AS
BEGIN
    SELECT
    M.Id,
	
	M.DealerId,
	D.Name  as DealerName,
	mn.EntityName as ManufacturerName,
	M.ManufacturerId ,
	M.IsActive,
	M.CreatedDate,
	M.CreatedByUserId,
	M.UpdatedDate,
	M.UpdatedByUserId
		 FROM Mapping_DealerManufacturer M

		inner join Dealer D on D.Id = M.DealerId
		inner join Manfacturer Mn on Mn.Id = M.ManufacturerId
		 WHERE M.ManufacturerId = @ManufacturerId and M.IsActive =1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetManufacturerFarmerMappingByManufacturerIdForDropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManufacturerFarmerMappingByManufacturerIdForDropDown]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetManufacturerFarmerMappingByManufacturerIdForDropDown] 1
CREATE procedure [dbo].[SP_GetManufacturerFarmerMappingByManufacturerIdForDropDown](@ManufacturerId int)
AS
BEGIN
    SELECT
    M.Id,

	F.Id As FarmerId,
	M.FarmerCode,
	F.FirstName + F.LastName as FarmerName,
	M.ManfacturerId,
	D.EntityName  as ManufacturerName,
	M.IsActive,
	M.CreatedDate,
	M.CreatedByUserId,
	M.UpdatedDate,
	M.UpdatedByUserId
		 FROM Mapping_ManfacturerFarmer M
		left join Farmer F on F.FarmerCode = M.FarmerCode
		left join Manfacturer D on D.Id = M.ManfacturerId
		left join GRN grn on grn.FarmerCode = m.FarmerCode and grn.ManfacturerId=d.Id
		 WHERE M.ManfacturerId = @ManufacturerId and M.IsActive =1 and grn.Id is null
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetManufacturerFarmerMappingDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManufacturerFarmerMappingDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetManufacturerFarmerMappingDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[ManfacturerId]
		,t.[FarmerCode],
		f.Id as FarmerId
		,f.FirstName + F.LastName as FarmerName
		,r.EntityName as Manufacturer
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_ManfacturerFarmer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Manfacturer r on r.Id = t.ManfacturerId
	INNER JOIN Farmer f on f.FarmerCode = t.FarmerCode
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMapping_DealerMfgbyManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMapping_DealerMfgbyManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMapping_DealerMfgbyManufacturerId] (@ManufacturerId INT)
AS
BEGIN
	SELECT 
	DM.Id,
	D.Name as Dealer,
	DM.DealerId,
	DM.ManufacturerId,
	m.EntityName as ManufacturerName
	from Mapping_DealerManufacturer DM
inner join Manfacturer m on m.Id=DM.ManufacturerId
inner join Dealer D on D.Id = Dm.DealerId

	WHERE  DM.Id = ISNULL(@ManufacturerId, DM.ManufacturerId) order by m.EntityName asc		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMapping_FarmerbyManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMapping_FarmerbyManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMapping_FarmerbyManufacturerId] (@ManufacturerId INT)
AS
BEGIN
	SELECT 
	MF.Id,
	MF.ManfacturerId,
	MF.FarmerCode,
	F.Id as FarmerId,
	m.EntityName as ManufacturerName,
	F.FirstName+' '+F.LastName as FarmerName,
	MF.CreatedDate,
	MF.UpdatedDate,
	MF.IsActive
	from Mapping_ManfacturerFarmer MF
	left join Manfacturer m on m.Id=MF.ManfacturerId
	left join Farmer F on F.FarmerCode = MF.FarmerCode
	WHERE  MF.Id = ISNULL(@ManufacturerId, MF.ManfacturerId) order by m.EntityName asc		 
END





GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM [dbo].[VW_UserRoleMenus] M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M WHERE MenuType='M' AND UserId=@UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Name
		,m.MenuType
		,m.IconType
		,m.ClassName
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuTypes
		--,mm.Name as ParentMenu
		,m.ParentMenuId
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.IsActive
		,m.CreatedDate
		--,u.Name as CreatedByUser
		,m.CreatedByUserId
		,m.UpdatedDate
		--,um.Name as UpdatedByUser
		,m.UpdatedByUserId
	FROM dbo.Menu m 
	inner join VW_UserInfo u on m.CreatedByUserId=u.Id 
	inner join VW_UserInfo Um ON Um.id=m.UpdatedByUserId
	left join menu mm on mm.Id=m.ParentMenuId
	WHERE m.Id = ISNULL(@Id, m.Id)  order by CreatedDate desc 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@UserId INT)
AS
BEGIN
	SELECT RM.Id,
	    RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDetailsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDetailsByFarmerCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetPlantationDetailsByFarmerCode](@P_FarmerCode varchar(255))
AS
BEGIN
    SELECT
  P.Id,
  P.PlotCode,
  P.FarmerCode,
  f.FirstName + f.LastName  as FarmerName,
  P.TypeOfOwnership,
  P.AreaInHectors,
  P.GeoboundariesArea,
  P.Latitude,
  P.Longitude,
  P.Address,
  P.VillageId,
  P.IsActive,
  P.CreatedDate,
  P.CreatedByUserId,
  P.UpdatedDate,
  P.UpdatedByUserId
		 FROM Plantation P
		 left join Farmer f on f.FarmerCode = P.FarmerCode
		 WHERE P.FarmerCode = ISNULL(@P_FarmerCode, P.FarmerCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDetailsByPlotCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDetailsByPlotCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetPlantationDetailsByPlotCode](@P_PlotCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  PlotCode,
  FarmerCode,
  TypeOfOwnership,
  AreaInHectors,
  GeoboundariesArea,
  Latitude,
  Longitude,
  Address,
  VillageId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Plantation
		 WHERE PlotCode = ISNULL(@P_PlotCode, PlotCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDetailsByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetPlantationDetailsByUserId](@P_CreatedByUserId int)
AS
BEGIN
    SELECT
  Id,
  PlotCode,
  FarmerCode,
  TypeOfOwnership,
  AreaInHectors,
  GeoboundariesArea,
  Latitude,
  Longitude,
  Address,
  VillageId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Plantation
		 WHERE CreatedByUserId = ISNULL(@P_CreatedByUserId, CreatedByUserId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDocumentsByPlotCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDocumentsByPlotCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create procedure [dbo].[SP_GetPlantationDocumentsByPlotCode](@P_PlotCode varchar(255))
AS
BEGIN
    SELECT
      Id,
      PlotCode,
	  DocURL,
	  DocType,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
		 FROM PlantationDocuments
		 WHERE PlotCode = ISNULL(@P_PlotCode, PlotCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationGeoBoundariesByPlotCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationGeoBoundariesByPlotCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetPlantationGeoBoundariesByPlotCode 'P_1694154058000_1'
CREATE procedure [dbo].[SP_GetPlantationGeoBoundariesByPlotCode](@P_PlotCode varchar(255))
AS
BEGIN
    SELECT
      Id,
      PlotCode,
      FarmerCode,
	  Latitude,
	  Longitude,
	  SeqNo,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
		 FROM PlantationGeoBoundaries
		 WHERE PlotCode = ISNULL(@P_PlotCode, PlotCode) order by SeqNo
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationGeoBoundariesByPlotCodeForPolygon]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationGeoBoundariesByPlotCodeForPolygon]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetPlantationGeoBoundariesByPlotCodeForPolygon 'P_1694154058000_1'
CREATE proc [dbo].[SP_GetPlantationGeoBoundariesByPlotCodeForPolygon](@P_PlotCode varchar(255))
as
begin
select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude

 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong 
from PlantationGeoBoundaries where PlotCode=@P_PlotCode group by PlotCode,FarmerCode) X
left join Farmer f on f.FarmerCode = X.FarmerCode
inner join Plantation p on p.FarmerCode=X.FarmerCode
left join Mapping_ManfacturerFarmer mfm on mfm.FarmerCode = f.FarmerCode
left join Manfacturer m on m.Id = mfm.ManfacturerId
where p.PlotCode = @P_PlotCode
order by LastName

-- select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude,
-- m.EntityName,m.PrimaryContactName,m.PrimaryContactNo,m.Latitude as M_Latitude,m.Longitude as M_Longitude
-- from
--(select X.PlotCode,X.FarmerCode,'['+string_agg(X.LatLong,',')+']' LatLong from
--(select PlotCode,FarmerCode,'['+cast(Latitude as varchar(255)) +','+cast(Longitude as varchar(255))+']' as LatLong,SeqNo
--from [dbo].[PlantationGeoBoundaries])X
--group by X.PlotCode,X.FarmerCode)X
--left join Farmer f on f.FarmerCode = X.FarmerCode
--left join Plantation p on p.FarmerCode=X.FarmerCode
--left join ManfacturerFarmerMapping mfm on mfm.FarmerCode = X.FarmerCode
--left join Manfacturer m on m.Id = mfm.ManfacturerId
--where mfm.ManfacturerId = @ManfacturerId
--order by LastName
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationLabourSurveyDetailsByPlantationId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationLabourSurveyDetailsByPlantationId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetPlantationLabourSurveyDetailsByPlantationId](@P_PlantationId int)
AS
BEGIN
  SELECT
      Id,
	  PlantationId,
      NoOfFieldWorkers,
      NoOfMaleWorkers,
      NoOfFemaleWorkers,
      NoOfResident,
      NoOfMigrant,
      OccupationOfChildren,
      IsActive,
      CreatedDate,
      CreatedByUserId,
      UpdatedDate,
      UpdatedByUserId
	   FROM PlantationLabourSurvey
	   WHERE PlantationId = ISNULL(@P_PlantationId,PlantationId)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationYeildDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationYeildDetailsByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationYeildDetailsByUserId](@P_CreatedByUserId int)
AS
BEGIN
    SELECT
    Id,
    PlotCode,
	FarmerCode,
	DateOfHarvest,
	YeildInTons,
	SupplyInTons,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
		 FROM PlantationYeild
		 WHERE CreatedByUserId = ISNULL(@P_CreatedByUserId, CreatedByUserId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotFarmonautDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotFarmonautDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetPlotFarmonautDetails
CREATE proc [dbo].[SP_GetPlotFarmonautDetails]
as
begin
  
   SELECT
  P.Id,
  P.PlotCode,
  P.FarmerCode,
  f.FirstName + f.LastName  as FarmerName,
  P.TypeOfOwnership,
  P.AreaInHectors,
  P.GeoboundariesArea,
  P.Latitude,
  P.Longitude,
  P.Address,
  P.VillageId,
  P.IsActive,
  P.CreatedDate,
  P.CreatedByUserId,
  P.UpdatedDate,
  P.UpdatedByUserId
  ,pf.FieldId
  ,pf.FieldImageResponseForNDVI
  ,pf.FieldImageResponseForNDWI
  ,pf.FieldImageResponseForLULC
  ,pf.FieldImageResponseForNDMI
  ,'2023-08-15' SensedDate
  ,pgb.Latitude Latitude_1
  ,pgb.Longitude Longitude_1
  ,pgb1.Latitude Latitude_4
  ,pgb1.Longitude Longitude_4
  ,'15.4888' Deep_Latitude
  ,'78.4865' Deep_Longitude
  ,pp.LatLong
  FROM Plantation P
 left join Farmer f on f.FarmerCode = P.FarmerCode
 inner join PlotFarmonautSensedDate pf on pf.PlotCode = p.PlotCode
 left join PlantationGeoBoundaries pgb on pgb.PlotCode = p.PlotCode and pgb.SeqNo=1
 left join PlantationGeoBoundaries pgb1 on pgb1.PlotCode = p.PlotCode and pgb1.SeqNo=4
 left join 
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong 
from PlantationGeoBoundaries  group by PlotCode,FarmerCode) pp on pp.PlotCode = p.PlotCode
WHERE pf.PlotCode in ('P_210920231028_25','P_210920231028_26','P_210920231028_27',
'P_210920231028_28','P_210920231028_29','P_210920231028_30',
'P_210920231028_31','P_210920231028_32')
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotFarmonautDetailsByPlotCodeAndSensedDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotFarmonautDetailsByPlotCodeAndSensedDate]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetPlotFarmonautDetailsByPlotCodeAndSensedDate 'P_49994952652_1','20230909'
CREATE proc [dbo].[SP_GetPlotFarmonautDetailsByPlotCodeAndSensedDate]
(@PlotCode varchar(255),@SensedDate varchar(255))
as
begin
  
   SELECT
  P.Id,
  P.PlotCode,
  P.FarmerCode,
  f.FirstName + f.LastName  as FarmerName,
  P.TypeOfOwnership,
  P.AreaInHectors,
  P.GeoboundariesArea,
  P.Latitude,
  P.Longitude,
  P.Address,
  P.VillageId,
  P.IsActive,
  P.CreatedDate,
  P.CreatedByUserId,
  P.UpdatedDate,
  P.UpdatedByUserId
  ,pf.FieldId
  ,pf.FieldImageResponseForNDVI
  ,pf.FieldImageResponseForNDWI
  ,pf.FieldImageResponseForLULC
  ,pf.FieldImageResponseForNDMI
  ,'2023-08-15' SensedDate
  ,pgb.Latitude Latitude_1
  ,pgb.Longitude Longitude_1
  ,pgb1.Latitude Latitude_4
  ,pgb1.Longitude Longitude_4
  ,pp.LatLong
  ,case when p.PlotCode= 'P_49994952652_1' then  'Yes'
        when p.PlotCode= 'P_42054288873_1' then  'Yes'
		when p.PlotCode= 'P_22029249515_1' then  'Yes'
		when p.PlotCode= 'P_36077066004_1' then  'Yes'
		when p.PlotCode= 'P_92653372293_1' then  'Yes' else 'No' end DeforestrationFree

  FROM Plantation P
 left join Farmer f on f.FarmerCode = P.FarmerCode
 inner join PlotFarmonautSensedDate pf on pf.PlotCode = p.PlotCode
 left join PlantationGeoBoundaries pgb on pgb.PlotCode = p.PlotCode and pgb.SeqNo=1
 left join PlantationGeoBoundaries pgb1 on pgb1.PlotCode = p.PlotCode and pgb1.SeqNo=4
 left join 
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong 
from PlantationGeoBoundaries  group by PlotCode,FarmerCode) pp on pp.PlotCode = p.PlotCode
WHERE pf.PlotCode = @PlotCode and pf.SensedDate = @SensedDate
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotFarmonautDetailsByYear]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotFarmonautDetailsByYear]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


--exec SP_GetPlotFarmonautDetailsByYear 2020
CREATE proc [dbo].[SP_GetPlotFarmonautDetailsByYear](@Year varchar(255))
as
begin
  
  if(@Year = '2023')
  begin
   SELECT
  P.Id,
  P.PlotCode,
  P.FarmerCode,
  f.FirstName + f.LastName  as FarmerName,
  P.TypeOfOwnership,
  P.AreaInHectors,
  P.GeoboundariesArea,
  P.Latitude,
  P.Longitude,
  P.Address,
  P.VillageId,
  P.IsActive,
  P.CreatedDate,
  P.CreatedByUserId,
  P.UpdatedDate,
  P.UpdatedByUserId
  ,pf.FieldId
  ,pf.FieldImageResponseForNDVI
  ,pf.FieldImageResponseForNDWI
  ,pf.FieldImageResponseForLULC
  ,pf.FieldImageResponseForNDMI
  ,'2023-08-15' SensedDate
  ,pgb.Latitude Latitude_1
  ,pgb.Longitude Longitude_1
  ,pgb1.Latitude Latitude_4
  ,pgb1.Longitude Longitude_4
  ,'15.4888' Deep_Latitude
  ,'78.4865' Deep_Longitude
  ,pp.LatLong
  FROM Plantation P
 left join Farmer f on f.FarmerCode = P.FarmerCode
 inner join PlotFarmonautSensedDate pf on pf.PlotCode = p.PlotCode
 left join PlantationGeoBoundaries pgb on pgb.PlotCode = p.PlotCode and pgb.SeqNo=1
 left join PlantationGeoBoundaries pgb1 on pgb1.PlotCode = p.PlotCode and pgb1.SeqNo=4
 left join 
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong 
from PlantationGeoBoundaries  group by PlotCode,FarmerCode) pp on pp.PlotCode = p.PlotCode
WHERE pf.PlotCode in ('P_210920231028_25','P_210920231028_26','P_210920231028_27',
'P_210920231028_28','P_210920231028_29','P_210920231028_30',
'P_210920231028_31','P_210920231028_32') and pf.Id in (
23,
24,
25,
26,
27,
28,
29,
30)
  end
  else if(@Year = '2020')
   begin
   SELECT
  P.Id,
  P.PlotCode,
  P.FarmerCode,
  f.FirstName + f.LastName  as FarmerName,
  P.TypeOfOwnership,
  P.AreaInHectors,
  P.GeoboundariesArea,
  P.Latitude,
  P.Longitude,
  P.Address,
  P.VillageId,
  P.IsActive,
  P.CreatedDate,
  P.CreatedByUserId,
  P.UpdatedDate,
  P.UpdatedByUserId
  ,pf.FieldId
  ,pf.FieldImageResponseForNDVI
  ,pf.FieldImageResponseForNDWI
  ,pf.FieldImageResponseForLULC
  ,pf.FieldImageResponseForNDMI
  ,'2020-01-01' SensedDate
  ,pgb.Latitude Latitude_1
  ,pgb.Longitude Longitude_1
  ,pgb1.Latitude Latitude_4
  ,pgb1.Longitude Longitude_4
  ,'15.4888' Deep_Latitude
  ,'78.4865' Deep_Longitude
  ,pp.LatLong
  FROM Plantation P
 left join Farmer f on f.FarmerCode = P.FarmerCode
 inner join PlotFarmonautSensedDate pf on pf.PlotCode = p.PlotCode
 left join PlantationGeoBoundaries pgb on pgb.PlotCode = p.PlotCode and pgb.SeqNo=1
 left join PlantationGeoBoundaries pgb1 on pgb1.PlotCode = p.PlotCode and pgb1.SeqNo=4
 left join 
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong 
from PlantationGeoBoundaries  group by PlotCode,FarmerCode) pp on pp.PlotCode = p.PlotCode
WHERE pf.PlotCode in ('P_210920231028_25','P_210920231028_26','P_210920231028_27',
'P_210920231028_28','P_210920231028_29','P_210920231028_30',
'P_210920231028_31','P_210920231028_32') and pf.Id in (
31,
32,
33,
34,
35,
36,
37,
38
)
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotsDetailsBasedOnDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotsDetailsBasedOnDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec [SP_GetPlotsDetailsBasedOnDealerId] 1
Create proc [dbo].[SP_GetPlotsDetailsBasedOnDealerId](@DealerId int)
as
begin
create table #TempFarmer(FarmerCode varchar(max))

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId = @DealerId

 select * from Plantation where IsActive=1 and FarmerCode in (select FarmerCode from #TempFarmer)

 drop table #TempFarmer
end
GO

-- %% [markdown]
-- # [dbo].[SP_GeTPlotsDetailsBasedOnManfacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GeTPlotsDetailsBasedOnManfacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GeTPlotsDetailsBasedOnManfacturerId NULL
CREATE proc [dbo].[SP_GeTPlotsDetailsBasedOnManfacturerId](@ManfacturerId int)
as
begin
if @ManfacturerId is not null
begin
create table #TempFarmer(FarmerCode varchar(max))

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_ManfacturerFarmer] where ManfacturerId=iSNULL(@ManfacturerId,ManfacturerId)

insert into #TempFarmer(FarmerCode)
select FarmerCode from [dbo].[Mapping_DealerFarmer] where DealerId in (
 select DealerId from Mapping_DealerManufacturer where ManufacturerId=iSNULL(@ManfacturerId,ManufacturerId))

 select * from Plantation where IsActive=1 and FarmerCode in (select FarmerCode from #TempFarmer)

 drop table #TempFarmer
 end
  else 
 begin
 select * from Plantation where IsActive=1
 end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductBatchDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductBatchDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetProductBatchDetails](@P_Id int)
AS
BEGIN
SELECT 
    Id,
    Product,
    Type,
    Quantity,
	BatchId,
	URL,
    IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	 FROM ProductBatch
	 WHERE Id = ISNULL(@P_Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPurchaseOrderDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPurchaseOrderDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetPurchaseOrderDetails](@P_Id int)
AS
BEGIN
SELECT 
    Id,
    Type,
    ManfacturerId,
    DealerId,
    FarmerId,
    GRNnumber,
    LotNumber,
    PODate,
    ModeOfPayment,
    ModeOfDelivery,
    ShippingAddress,
    BillingAddress,
    IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	 FROM PurchaseOrder
	 WHERE Id = ISNULL(@P_Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRiskAssesmentAnswerDtlByFarmerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRiskAssesmentAnswerDtlByFarmerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetRiskAssesmentAnswerDtlByFarmerId](@FarmerCode VarChar(255))
AS
BEGIN

SELECT
  Id,
 RiskAssesmentQuestionHdrId,
FarmerCode,
Answers,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId
    FROM RiskAssesmentAnswerDtl
	    WHERE FarmerCode = ISNULL(@FarmerCode,FarmerCode)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRiskAssesmentQuestionHdrById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRiskAssesmentQuestionHdrById]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetRiskAssesmentQuestionHdrById](@P_Id int)
AS
BEGIN

SELECT
  Id,
  QuestionCategory,
SerialNo,
Questions,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
    FROM RiskAssesmentQuestionHdr
	    WHERE Id = ISNULL(@P_Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetRoleDetails null
CREATE PROCEDURE [dbo].[SP_GetRoleDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[UpdatedDate]
	FROM [dbo].[Roles] t
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
END

--- End Procedure : SP_GetRoleDetails

--- Start Procedure : SP_AddMenu
SET ANSI_NULLS ON
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.IsActive
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as CreatedByUser
		,Um.Name as UpdatedByUser
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN VW_UserInfo U ON U.Id=RM.CreatedByUserId
	inner join VW_UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@Id, RM.RoleId)
		  
	ORDER By r.name, PM.[Order]  ,m.[Order],UpdatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSensedDatesByPlotCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSensedDatesByPlotCode]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetSensedDatesByPlotCode 'P_49994952652_1'
CREATE proc [dbo].[SP_GetSensedDatesByPlotCode](@PlotCode varchar(255))
as
begin
select * from 
(select SensedDate,CONVERT(DATE, SensedDate, 112) AS ConvertedDate
from PlotFarmonautSensedDate where PlotCode=@PlotCode)X order by X.ConvertedDate desc
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetSideMenuByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSideMenuByUserId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetSideMenuByUserId 1
CREATE proc [dbo].[SP_GetSideMenuByUserId](@UserId int)
as
begin
select m.Path as path,m.MenuName as title,isnull(m.IconType,'') as iconType,m.Icon as icon,
isnull(m.ClassName,'') as class,'false' as groupTitle,'' as badge,'' as badgeClass,'All' role,m.[Order] as orderPosition,
dbo.FN_JsonArrayToString(m.MenuId,@UserId) AS submenu
from VW_UserRoleMenus m where m.UserId = @UserId and m.MenuType = 'M' 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStateorProvinceDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStateorProvinceDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetStateorProvinceDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		 ,t.Code
		,t.Name
		,t.CountryId
		,c.Name as CountryName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
	FROM [dbo].[StateorProvince] t
	INNER JOIN VW_UserInfo d ON d.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	Left Join Country c on c.Id=t.CountryId
	WHERE   t.Id = ISNULL(@Id, t.Id) order by t.Name asc		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSubDistrictDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSubDistrictDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetSubDistrictDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		 ,t.Code
		,t.[Name]
		,t.DistrictId
		,s.[Name] as DistrictorRegencyName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[SubDistrict] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	left join DistrictorRegency s On s.Id = t.DistrictId
	WHERE  t.Id = ISNULL(@Id, t.Id) order by t.Name asc		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSupplyOrdersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSupplyOrdersDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetSupplyOrdersDetails](@P_Id int)
AS
BEGIN
SELECT 
    Id,
    Product,
    Type,
    ShippingAddress,
    InvoiceNumber,
    SupplyGRNnumber,
    Amount,
    IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	 FROM SupplyOrders
	 WHERE Id = ISNULL(@P_Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTrader]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTrader]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetTrader](@P_Id int)
AS
BEGIN
SELECT 
 Id,
 TraderName,
 ContactNo,
 VillageId,
 Address,
 Latitude,
 Longitude,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
   FROM Trader
   WHERE Id =ISNULL (@P_Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTransactionDetailsByIMEINO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTransactionDetailsByIMEINO]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetTransactionDetailsByIMEINO 'abc'
CREATE PROCEDURE [dbo].[SP_GetTransactionDetailsByIMEINO](@IMEINO varchar(100))
as
    
begin

 --- 0=Farmer -----
 select  * from Farmer where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
 ------------------

 --- 1=Plantation -----
 select * from Plantation where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
 ------------------

 --- 2=PlantationDocuments -----
 select * from PlantationDocuments where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
 ------------------

  --- 3=PlantationGeoBoundaries -----
 select * from PlantationGeoBoundaries where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
 ------------------
   ---4=PlantationLabourSurvey
  Select * from PlantationLabourSurvey where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

  ---5=FarmerHouseholdParentSurvey----
select * from FarmerHouseholdSurvey where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
  -------------------
  ---6=FarmerHouseholdChildrenSurvey
  Select * from FarmerHouseholdChildrenDetails where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
  -----------------------------------------

   ---7=RiskAssesmentAnswerDtl
  Select * from RiskAssesmentAnswerDtl where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
  -----------------------------------------

  
   ---8=Mapping_DealerFarmer
  Select * from Mapping_DealerFarmer where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
  ----------------------------------------

    
   ---9=Mapping_ManfacturerFarmer
  Select * from Mapping_ManfacturerFarmer where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)
  ----------------------------------------

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserByIMEINo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserByIMEINo]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetUserByIMEINo](@IMEINo varchar(50))
as
begin
select * from Users where IMEINo=@IMEINo and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUserDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,t.TraderId
		,t.DealerId
		,t.IMEINo
		,t.ManufacturerId
		,r.Name AS RoleName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Users] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Roles r on r.Id = t.RoleId
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersBasedOnId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersBasedOnId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


--exec SP_GetUsersBasedOnId 17
CREATE proc [dbo].[SP_GetUsersBasedOnId](@Id int)
as
begin
declare @ManufacturerId int
declare @DealerId int
declare @role varchar(255)

select @ManufacturerId = u.ManufacturerId,@DealerId =u.DealerId,@role=r.Name from Users u
left join Roles r on r.Id = u.RoleId
where u.Id=@Id and u.IsActive=1

if @role = 'Developer' or @role = 'SuperAdmin'
begin
select * from Users where IsActive=1 
end
else if @role = 'Manufacturer'
begin
select * from Users where IsActive=1 
and ManufacturerId = case when @ManufacturerId is null then null else @ManufacturerId end
end
else if @role = 'Dealer'
begin
select * from Users where IsActive=1 
and DealerId = case when @DealerId is null then null else @DealerId end
end
end



GO

-- %% [markdown]
-- # [dbo].[SP_GetVillageDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVillageDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetVillageDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		 ,t.Code
		,t.[Name]
		,t.SubDistrictId
		,s.[Name] as SubDistrictName
		,t.PinCode
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[Village] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	left join SubDistrict s On s.Id = t.SubDistrictId
	WHERE   t.Id = ISNULL(@Id, t.Id) order by t.Name asc		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack__GetDealerFarmerMappingByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack__GetDealerFarmerMappingByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_IntelliTrack__GetDealerFarmerMappingByDealerId 1
CREATE procedure [dbo].[SP_IntelliTrack__GetDealerFarmerMappingByDealerId](@DealerId int)
AS
BEGIN
    SELECT
    M.Id,

	F.Id As FarmerId,
	M.FarmerCode,
	F.FirstName + F.LastName as FarmerName,
	M.DealerId,
	D.Name  as DealerName,
	M.IsActive,
	M.CreatedDate,
	M.CreatedByUserId,
	M.UpdatedDate,
	M.UpdatedByUserId
		 FROM Mapping_DealerFarmer M
		left join Farmer F on F.FarmerCode = M.FarmerCode
		left join Dealer D on D.Id = M.DealerId
		left join GRN grn on grn.FarmerCode = m.FarmerCode and grn.DealerId=d.Id
		 WHERE M.DealerId = @DealerId and M.IsActive =1 and grn.Id is null
END


GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_AddBatchDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_AddBatchDtl]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_IntelliTrack_AddBatchDtl]
(
    @Id INT,
    @BatchHdrId INT,
    @GRNId INT,
    @ManfacturerId INT,
    @DealerId INT,
    @FarmerId INT,
    @Quantity Decimal(18,3),
    @IsActive BIT,
    @CreatedDate DATETIME,
    @CreatedByUserId INT,
    @UpdatedDate DATETIME,
    @UpdatedByUserId INT,
    @ErrorNumber INT OUTPUT,
    @ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION;

    BEGIN TRY
        IF ISNULL(@Id, 0) = 0
        BEGIN
            INSERT INTO [dbo].[BatchGRNDetails] (
                [BatchHdrId],
                [GRNId],
                [ManfacturerId],
                [DealerId],
                [FarmerId],
                [Quantity],
                [IsActive],
                [CreatedDate],
                [CreatedByUserId],
                [UpdatedDate],
                [UpdatedByUserId]
            )
            VALUES (
                @BatchHdrId,
                @GRNId,
                @ManfacturerId,
                @DealerId,
                @FarmerId,
                @Quantity,
                ISNULL(@IsActive, 1),
                ISNULL(@CreatedDate, GETDATE()),
                @CreatedByUserId,
                ISNULL(@UpdatedDate, GETDATE()),
                @UpdatedByUserId
            );

            UPDATE GRN
            SET CurrentQty = CurrentQty - @Quantity
            WHERE Id = @GRNId;
        END
        ELSE
        BEGIN
            UPDATE [dbo].[BatchGRNDetails]
            SET [IsActive] = ISNULL(@IsActive, 1),
                [UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()),
                [UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id;
        END

        COMMIT TRANSACTION;
        SET @ErrorNumber = 0;
        SET @ErrorMessage = 'Success';
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;

        SELECT @ErrorNumber = ERROR_NUMBER(),
               @ErrorMessage = ERROR_MESSAGE();

        
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_AddBatchHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_AddBatchHdrDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_AddBatchHdrDetails](
@Id Int,
@BatchNo varchar(255),
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
,@BatchHdrOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO [dbo].[BatchHdrDetails] (
                 BatchNo
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                 @BatchNo
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
  set @BatchHdrOUT = @@IDENTITY
                --declare @POId int
                --set @POId  = @@IDENTITY
                --declare @GID varchar(255)
               -- set @GID =('BATCH'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
               -- update [BatchHdrDetails] set BatchNo = @GID,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 

                --where Id=@POId
		 end
	  ELSE
	 BEGIN
	  UPDATE [dbo].[BatchHdrDetails]
            SET  
                
                 BatchNo=@BatchNo
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
            set @BatchHdrOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_AddDRCDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_AddDRCDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_IntelliTrack_AddDRCDetails]
(
    @Id INT,
    @DRCHdrId INT,
    @GRNId INT,
    @DRCValue Int,
    @IsActive BIT,
    @CreatedDate DATETIME,
    @CreatedByUserId INT,
    @UpdatedDate DATETIME,
    @UpdatedByUserId INT,
    @ErrorNumber INT OUTPUT,
    @ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION;

    BEGIN TRY
        IF ISNULL(@Id, 0) = 0
        BEGIN
            INSERT INTO [dbo].[DRCDetails] (
                [DRCHdrId],
                [GRNId],
               [DRCValue],
                [IsActive],
                [CreatedDate],
                [CreatedByUserId],
                [UpdatedDate],
                [UpdatedByUserId]
            )
            VALUES (
                @DRCHdrId,
                @GRNId,
               @DRCValue,
                ISNULL(@IsActive, 1),
                ISNULL(@CreatedDate, GETDATE()),
                @CreatedByUserId,
                ISNULL(@UpdatedDate, GETDATE()),
                @UpdatedByUserId
            );

            UPDATE GRN
            SET CurrentQty = CurrentQty - @DRCValue
            WHERE Id = @GRNId;
        END
        ELSE
        BEGIN
            UPDATE [dbo].[DRCDetails]
            SET [IsActive] = ISNULL(@IsActive, 1),
                [UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()),
                [UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id;
        END

        COMMIT TRANSACTION;
        SET @ErrorNumber = 0;
        SET @ErrorMessage = 'Success';
    END TRY
    BEGIN CATCH
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;

        SELECT @ErrorNumber = ERROR_NUMBER(),
               @ErrorMessage = ERROR_MESSAGE();

        
    END CATCH;
END;
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_AddDRCHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_AddDRCHdrDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create  procedure [dbo].[SP_IntelliTrack_AddDRCHdrDetails](
@Id Int,
@DRCNo varchar(255),
@DRCDocument varchar(5000),
@IsActive bit

,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
,@DRCHdrOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO [dbo].[DRCHdrDetails] (
                 [DRCNo],
				 [DRCDocument]
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                 @DRCNo
				 ,@DRCDocument
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
  set @DRCHdrOUT = @@IDENTITY
                --declare @POId int
                --set @POId  = @@IDENTITY
                --declare @GID varchar(255)
               -- set @GID =('BATCH'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
               -- update [BatchHdrDetails] set BatchNo = @GID,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 

                --where Id=@POId
		 end
	  ELSE
	 BEGIN
	  UPDATE [dbo].[DRCHdrDetails]
            SET  
                DRCNo=@DRCNo
				,DRCDocument=@DRCDocument
             
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
            set @DRCHdrOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_AddGRN]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_AddGRN]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_IntelliTrack_AddGRN](
@Id int,

@ManfacturerId int,
@DealerId int,
@FarmerCode VarChar(255),
@Quantity Decimal(18,3),

@GRNdate datetime,

@ModeofTransport Int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT,
@GRNOUT Int OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	Begin
	  INSERT INTO GRN(
	
      ManfacturerId,
      DealerId,
      FarmerCode,
      Quantity,
	
      GRNdate,

	  ModeofTransport,
      IsActive,
      CreatedDate,
      CreatedByUserId,
      UpdatedDate,
      UpdatedByUserId
	  )
	  VALUES(
	
      @ManfacturerId,
      @DealerId,
      @FarmerCode,
      @Quantity,
	  
      @GRNdate,

	  @ModeofTransport,
      @IsActive,
      @CreatedDate,
      @CreatedByUserId,
      @UpdatedDate,
      @UpdatedByUserId
	  )
	  set @GRNOUT = @@IDENTITY
	  declare @GrnId Int
	  set @GrnId = @@IDENTITY
			declare @GID varchar(255)
			

                set @GID =('GRN'+RIGHT('0000000'+CAST(@GrnId AS VARCHAR(7)),7))
               update GRN set GRNnumber=@GID ,CurrentQty=@Quantity where Id=@GrnId
			 End
		  
	  ELSE
	 BEGIN
	  UPDATE GRN
	    SET 
      ManfacturerId = @ManfacturerId,
      DealerId = @DealerId,
      FarmerCode = @FarmerCode,
      Quantity = @Quantity,
	  CurrentQty= @Quantity,
      GRNdate = @GRNdate,
	
	  ModeofTransport=@ModeofTransport,
      IsActive = @IsActive,
      UpdatedDate = @UpdatedDate,
      UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
	  	set @GRNOUT = @Id
 End
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH
		
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END






GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_AddInvoiceDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_AddInvoiceDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_AddInvoiceDetails](
@Id int,
@ManfacturerId int,
@DealerId int,
@Product varchar(255),
@Quantity int,
@BatchId Int,
@ShippingTo Int,
@ShippingAddress varchar(500),
@Vessel varchar(255),
@PortofLoading varchar(255),
@PortofDischarge varchar(255),
@PODTiming datetime,
@POLTiming datetime,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT,
@InvoiceOUT Int OUTPUT
)
AS
BEGIN
 
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id,0) = 0
	begin
	  INSERT INTO Invoice(
	 
      ManfacturerId,
	  DealerId,
      Product,
      Quantity,
	  BatchId,
      ShippingTo,
      ShippingAddress,
	  Vessel, 
      PortofLoading,
      PortofDischarge,
      [PODTiming],
      [POLTiming],
      IsActive,
      CreatedDate,
      CreatedByUserId,
      UpdatedDate,
      UpdatedByUserId
	  )
	  VALUES(
	 
      @ManfacturerId,
	  @DealerId,
      @Product,
      @Quantity,
	  @BatchId,
      @ShippingTo,
      @ShippingAddress,
	  @Vessel, 
      @PortofLoading,
      @PortofDischarge,
      @PODTiming,
      @POLTiming,
      @IsActive,
      @CreatedDate,
      @CreatedByUserId,
      @UpdatedDate,
      @UpdatedByUserId
	  )

	  	  set @InvoiceOUT = @@IDENTITY
	  declare @InvoiceId Int
	  set @InvoiceId = @@IDENTITY
			declare @GID varchar(255)
			

                set @GID =('IN'+RIGHT('0000000'+CAST(@InvoiceId AS VARCHAR(7)),7))
               update Invoice set InvoiceNumber=@GID where Id=@InvoiceId
	End
	ELSE
	begin
	  UPDATE Invoice
  SET 
      ManfacturerId = @ManfacturerId,
	 DealerId = @DealerId,
	 	 Vessel=@Vessel, 
      PortofLoading=@PortofLoading,
      PortofDischarge=@PortofDischarge,
      [PODTiming]=@PODTiming,
      [POLTiming]=@POLTiming,
      Quantity = @Quantity,
	  BatchId=@BatchId,
      ShippingTo = @ShippingTo,
      ShippingAddress = @ShippingAddress,
      IsActive = @IsActive,
      UpdatedDate = @UpdatedDate,
      UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
	  set @InvoiceOUT = @Id
	  end
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END

   
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetBatchdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetBatchdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_GetBatchdetails](@P_Id int)
as
begin
select
      G.Id,
	  G.BatchNo,

      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from [dbo].[BatchHdrDetails] G
		
	  where G.Id = ISNULL(@P_Id, G.Id)


end
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetBatchGRNdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetBatchGRNdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_GetBatchGRNdetails](@BatchHdrId int)
as
begin
select
      G.Id,
	  G.BatchHdrId,
	  G.GRNId,
	  G.Quantity,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId,
	  G.ManfacturerId,
	  G.[DealerId],
	  G.[FarmerId],
	  Gr.GRNnumber ,
	  Gr.GRNdate,
	  m.EntityName as Manufacturer
	    from [dbo].[BatchGRNDetails] G
		left join GRN Gr on G.GRNId = Gr.Id
		left join Manfacturer m on Gr.ManfacturerId = m.Id
	  where G.BatchHdrId = ISNULL(@BatchHdrId, G.BatchHdrId)


end
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetCustomerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetCustomerDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_IntelliTrack_GetCustomerDetails] (@Id INT)
AS
BEGIN
SELECT 
t.Id,
t.EntityName,
t.Address,
t.Email,
t.Phone,
v.Name as VillageName,
s.Name as SubDistrictname,
d.Name as DistrictorRegencyName,
p.Name as StateorProvinceName,
c.Name as CountryName,

t.[IsActive]
,t.[CreatedDate]
,t.CreatedByUserId
,t.[UpdatedDate]
,t.UpdatedByUserId
	FROM [dbo].[Customer] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	left join Village v On v.Id = t.VillageId
	left join SubDistrict s on s.Id=t.SubDistrictId
	left join DistrictorRegency d on d.Id =t.DistrictorRegencyId
	left join StateorProvince p on p.Id= t.StateorProvinceId
	left join Country y on y.Id = t.CountryId
	WHERE   t.Id = ISNULL(@Id, t.Id)  	 
END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetDealerById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetDealerById]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_IntelliTrack_GetDealerById](@Id int)
AS
BEGIN
SELECT 
       Id,
	   Name,
	   PrimaryContactNo,
	   Address,
	   Village,
	   Latitude,
	   Longitute,
	   IsActive,
	   CreatedDate,
	   CreatedByUserId,
	   UpdatedDate,
	   UpdatedByUserId
	     FROM Dealer
		   WHERE Id = ISNULL(@Id,Id)

END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetDealerByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetDealerByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
cREATE procedure [dbo].[SP_IntelliTrack_GetDealerByManufacturerId](@ManufacturerId int)
AS
BEGIN
SELECT 
      md.Id,
	 md.DealerId,
	 md.ManufacturerId,
	 D.Name as DealerName,
	 M.EntityName as ManufacturerName,
	   md.IsActive
	   
	     FROM Mapping_DealerManufacturer md

		 Inner Join Dealer D on D.Id = md.DealerId
		 Inner Join Manfacturer M on M.Id = md.ManufacturerId
		   WHERE md.ManufacturerId =  md.ManufacturerId

END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetDRCDetailByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetDRCDetailByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_IntelliTrack_GetDRCDetailByDealerId] 1

Create proc [dbo].[SP_IntelliTrack_GetDRCDetailByDealerId](@DealerId int)
as
begin

select 
D.Id,
D.DRCValue,
G.CurrentQty,
G.Quantity,
D.GRNId,
G.GRNnumber

from DRCDetails D

left join GRN G on G.Id = D.DRCHdrId where G.DealerId = @DealerId

end



GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetDRCDetailsByDRCHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetDRCDetailsByDRCHdrId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_GetDRCDetailsByDRCHdrId](@DRCHdrId int)
as
begin
select
      G.Id,
	  G.DRCHdrId,
	  G.GRNId,
	G.DRCValue,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId,
	 Gr.Quantity,
	  Gr.GRNnumber,
	  Gr.CurrentQty,
	  Gr.GRNdate
	 
	    from [dbo].[DRCDetails] G
		left join GRN Gr on G.GRNId = Gr.Id
		
	  where G.DRCHdrId = ISNULL(@DRCHdrId, G.DRCHdrId)


end


GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetDRCDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetDRCDetailsById]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_GetDRCDetailsById](@Id int)
as
begin
select
      G.Id,
	  G.DRCHdrId,
	  G.GRNId,
	G.DRCValue,
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId,
	 Gr.Quantity,
	  Gr.GRNnumber,
	  Gr.CurrentQty,
	  Gr.GRNdate
	 
	    from [dbo].[DRCDetails] G
		left join GRN Gr on G.GRNId = Gr.Id
		
	  where G.Id = ISNULL(@Id, G.Id)


end


GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetDRCHdrdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetDRCHdrdetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_GetDRCHdrdetails](@P_Id int)
as
begin
select
      G.Id,
	  G.DRCNo,
	  G.DRCDocument,

      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from [dbo].DRCHdrDetails G
		
	  where G.Id = ISNULL(@P_Id, G.Id)


end
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetGRNdetailsByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetGRNdetailsByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_IntelliTrack_GetGRNdetailsByDealerId](@DealerId int)
as
begin
select
      G.Id,
	  G.GRNnumber,
	  F.FarmerCode,
	  F.FirstName + F.LastName as FarmerName,
	  F.Address as farmeradress,
      G.ManfacturerId,
	  mf.Name as Dealer,
      G.DealerId,
	
      F.Id as FarmerId,
      G.Quantity,
	  G.CurrentQty,
      G.GRNdate,
	 
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from GRN G
		left JOIN Farmer F ON G.FarmerCode = F.FarmerCode
		left join Dealer mf on mf.Id= G.DealerId
	
	  where G.DealerId = @DealerId and G.IsActive = 1


end


GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetGRNdetailsByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetGRNdetailsByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_IntelliTrack_GetGRNdetailsByManufacturerId](@ManufacturerId int)
as
begin
select
      G.Id,
	  G.GRNnumber,
	  F.FarmerCode,
	  F.FirstName + F.LastName as FarmerName,
	  F.Address as farmeradress,
      G.ManfacturerId,
	  mf.EntityName as Manufacturer,
    
      F.Id as FarmerId,
      G.Quantity,
	  G.CurrentQty,
      G.GRNdate,
	 
      G.IsActive,
      G.CreatedDate,
      G.CreatedByUserId,
      G.UpdatedDate,
      G.UpdatedByUserId
	    from GRN G
		left JOIN Farmer F ON G.FarmerCode = F.FarmerCode
		left join Manfacturer mf on mf.Id= G.ManfacturerId
	
	  where G.ManfacturerId = @ManufacturerId and G.IsActive = 1


end
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetInvoiceDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetInvoiceDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_IntelliTrack_GetInvoiceDetails](@P_Id int)
as
begin
select
      i.Id,
	  InvoiceNumber,
	  Vessel,
      PortofLoading,
      PortofDischarge,
      POLTiming,
      PODTiming,
      ManfacturerId,
	  I.DealerId,
	  d.Name AS DealerName,
      Product,
      Quantity,
      ShippingTo,
      ShippingAddress,
      i.IsActive,
      i.CreatedDate,
	  C.EntityName as ShippingToName,
	  mf.EntityName  as Manufacturer
	    from Invoice i
		left join Manfacturer mf on mf.Id = i.ManfacturerId

		inner join Customer C on C.Id = i.ShippingTo
			left join Dealer d on D.Id = i.DealerId
	  where i.Id = isnull(@P_Id, i.Id)


end


    
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetLogisticsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetLogisticsDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_IntelliTrack_GetLogisticsDetails] (@Id INT)
AS
BEGIN
 
	SELECT 
		 l.[Id]
		 ,l.VehicleRegistrationNumber
		 ,l.InsuranceExpiryDate
		 ,l.ManufacturingYear
		 ,l.LastMaintenanceDate
		 ,l.VehicleType
		 ,l.VehicleLoadCapacity
		 ,l.Fueltype
		,l.[IsActive]
		,l.[CreatedDate]
		,l.CreatedByUserId
		,l.[UpdatedDate]
		,l.UpdatedByUserId
	FROM [dbo].[Logistics] l
	INNER JOIN VW_UserInfo c ON c.Id=l.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=l.UpdatedByUserId
	WHERE l.IsActive=1 and  l.Id = ISNULL(@Id, l.Id)  	 
END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetManfacturerById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetManfacturerById]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create procedure [dbo].[SP_IntelliTrack_GetManfacturerById](@Id int)
AS
BEGIN
    SELECT
    Id,
    EntityName,
	PrimaryContactName,
	PrimaryContactNo,
	SecondaryContactNo,
	Latitude,
	Longitude,
	Address,
	VillageId,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId		
	FROM Manfacturer
		 WHERE Id = ISNULL(@Id, Id) AND
		 IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetManfacturerFarmerMappingByManufacturerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetManfacturerFarmerMappingByManufacturerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_IntelliTrack_GetManfacturerFarmerMappingByManufacturerId](@ManufacturerId int)
AS
BEGIN
    SELECT
    M.Id,
	F.Id as FarmerId,
	M.FarmerCode,
	F.FirstName + F.LastName as FarmerName,
	M.ManfacturerId,
	M.IsActive,
	M.CreatedDate,
	M.CreatedByUserId,
	M.UpdatedDate,
	M.UpdatedByUserId
		 FROM Mapping_ManfacturerFarmer M
		left join Farmer F on F.FarmerCode= M.FarmerCode
		 WHERE M.ManfacturerId = @ManufacturerId
END

GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_GetSubDealerByDealerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_GetSubDealerByDealerId]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_IntelliTrack_GetSubDealerByDealerId](@DealerId INT)
AS
BEGIN
	SELECT 
		 t.Id,
		t.DealerId,
		d.Name As DealerName
	,t.SubDealerId
	,dd.Name as SubDealerName
		,t.CreatedDate
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.UpdatedDate
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Mapping_DealerSubDealer] t

	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId

	left JOIN Dealer d on d.Id = t.DealerId
	left JOIN Dealer dd on dd.Id = t.SubDealerId
	WHERE t.DealerId = ISNULL(@DealerId, t.DealerId) AND t.IsActive = 1  order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_IntelliTrack_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_IntelliTrack_ValidateUser]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_IntelliTrack_ValidateUser 'DeveloperUser','b56e0b4ea4962283bee762525c2d490f'
CREATE PROCEDURE [dbo].[SP_IntelliTrack_ValidateUser]
	@UserName VARCHAR(255),
	@Password VARCHAR(255)    
AS

BEGIN
	
		SELECT 
		 t.[Id]
		,[UserName]
		,[Password]
		,[FirstName]
		,[LastName]
		,[EmailId]
		,[MobileNumber]
		,[RoleId]
		,isnull([DealerId],0) DealerId
		,isnull([ManufacturerId],0) ManufacturerId
		,isnull([TraderId],0) TraderId
		,t.[IsActive]
		,t.[CreatedDate]
		,[CreatedByUserId]
		,t.[UpdatedDate]
		,[UpdatedByUserId]
		,r.Name as RoleName
	FROM [dbo].[Users] t
	inner join [dbo].[Roles] r on r.Id = t.RoleId
	WHERE t.UserName=@UserName AND t.Password=@Password AND t.IsActive=1
END
GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddDealerFarmer_Mapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddDealerFarmer_Mapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_Mobile_AddDealerFarmer_Mapping](
@FarmerCode varchar(255),
@DealerId Int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 BEGIN TRY
 INSERT INTO Mapping_DealerFarmer(
 FarmerCode,
 DealerId,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
@FarmerCode,
@DealerId,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)

update Farmer set IsMapping = 1 where FarmerCode = @FarmerCode
 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END



GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddFarmer]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_Mobile_AddFarmer](
@FarmerCode varchar(255),
@FirstName varchar(255),
@LastName varchar(255),
@FatherName varchar(255),
@Gender varchar(10),
@Age int,
@PrimaryContactNo bigint,
@Address varchar(500),
@VillageId int,
@NationalIdentityCode varchar(255),
@NationalIdentityCodeDocument varchar(255),
@NoOfPlots int,
@Image varchar(500),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
   DECLARE @cnt int
   SET @cnt =(select COUNT(FarmerCode) from Farmer where FarmerCode = @FarmerCode and IsActive=1)
  IF @cnt = 0
  INSERT INTO Farmer(
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  [Address],
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  [Image],
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @FarmerCode,
  @FirstName,
  @LastName,
  @FatherName,
  @Gender,
  @Age,
  @PrimaryContactNo,
  @Address,
  @VillageId,
  @NationalIdentityCode,
  @NationalIdentityCodeDocument,
  @NoOfPlots,
  @Image,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )  
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddManfacturerFarmer_Mapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddManfacturerFarmer_Mapping]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_Mobile_AddManfacturerFarmer_Mapping](
@FarmerCode varchar(255),
@ManfacturerId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
BEGIN TRANSACTION
 
 BEGIN TRY

 INSERT INTO Mapping_ManfacturerFarmer(
 FarmerCode,
 ManfacturerId,
 IsActive,
 CreatedDate,
 CreatedByUserId,
 UpdatedDate,
 UpdatedByUserId
 )
VALUES(
@FarmerCode,
@ManfacturerId,
 @IsActive,
 @CreatedDate,
 @CreatedByUserId,
 @UpdatedDate,
 @UpdatedByUserId
)
 update Farmer set IsMapping = 1 where FarmerCode = @FarmerCode

 END TRY
 BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END



GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddPlantation]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddPlantation]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_Mobile_AddPlantation](
@PlotCode varchar(255),
@FarmerCode varchar(255),
@TypeOfOwnership varchar(10),
@AreaInHectors decimal(8,3),
@GeoboundariesArea  varchar(255),
@Latitude decimal(12,9),
@Longitude decimal(12,9),
@Address varchar(500),
@VillageId int,
@LabourStatus bit,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
  BEGIN TRANSACTION

  BEGIN TRY
    DECLARE @cnt int
   SET @cnt =(select COUNT(PlotCode) from Plantation where PlotCode = @PlotCode and IsActive=1)
   IF @cnt = 0
   begin
	INSERT INTO Plantation(
	PlotCode,
	FarmerCode,
	TypeOfOwnership,
	AreaInHectors,
	GeoboundariesArea,
	Latitude,
	Longitude,
	Address,
	VillageId,
	LabourStatus,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	VALUES(
	@PlotCode,
	@FarmerCode,
	@TypeOfOwnership,
	@AreaInHectors,
	@GeoboundariesArea,
	@Latitude,
	@Longitude,
	@Address,
	@VillageId,
	@LabourStatus,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId

	)
	end
	  ELSE
	  begin
	 if @LabourStatus = 1
	 begin
   UPDATE Plantation
   SET LabourStatus = @LabourStatus,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE PlotCode = @PlotCode
  end
  if @GeoboundariesArea >0.0
  begin
  UPDATE Plantation
   SET GeoboundariesArea = @GeoboundariesArea,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE PlotCode = @PlotCode
  end
  end

  END TRY

  BEGIN CATCH
     SELECT @ErrorNumber = ERROR_NUMBER(),
	        @ErrorMessage = ERROR_MESSAGE();
			
			IF @@TRANCOUNT>0
            ROLLBACK TRANSACTION;
            RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
  END CATCH
      IF @@TRANCOUNT>0
	   COMMIT TRANSACTION;

	   SET @ErrorNumber = 0
	   SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddPlantationDocuments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddPlantationDocuments]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_Mobile_AddPlantationDocuments](
@FarmerCode varchar(255),
@PlotCode varchar(255),
@DocURL varchar(255),
@DocType varchar(255),
@DocUrlValue varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
 declare @checkcnt int
	set @checkcnt = (select count(*) from PlantationDocuments where FarmerCode=@FarmerCode
	and DocType=@DocType and IsActive=1)
    IF @checkcnt = 0
	  INSERT INTO PlantationDocuments(
	  FarmerCode,
	  PlotCode,
	  DocURL,
	  DocType,
	  DocUrlValue,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
	  @FarmerCode,
	  @PlotCode,
	  @DocURL,
	  @DocType,
	  @DocUrlValue,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	 
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddPlantationGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddPlantationGeoBoundaries]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_Mobile_AddPlantationGeoBoundaries](
@PlotCode varchar(255),
@FarmerCode varchar(255),
@Latitude decimal(12,8),
@Longitude decimal(12,8),
@PlotCount int,
@SeqNo int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
   
	  INSERT INTO PlantationGeoBoundaries(
	  PlotCode,
      FarmerCode,
	  Latitude,
	  Longitude,
	  PlotCount,
	  SeqNo,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
	  @PlotCode,
      @FarmerCode,
	  @Latitude,
	  @Longitude,
	  @PlotCount,
	  @SeqNo,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	 
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_AddRiskAssesmentAnswerDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_AddRiskAssesmentAnswerDtl]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_Mobile_AddRiskAssesmentAnswerDtl]
(
@RiskAssesmentQuestionHdrId int,
@FarmerCode varchar(255),
@Answers varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY

   INSERT INTO RiskAssesmentAnswerDtl(
RiskAssesmentQuestionHdrId,
Farmercode,
Answers,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

   )
   VALUES(
@RiskAssesmentQuestionHdrId,
@FarmerCode,
@Answers,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
	     
	 
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_Mobile_GetMasterDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Mobile_GetMasterDetails]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_Mobile_GetMasterDetails]
as
begin

--- 0 = Country ---
 select * from Country where IsActive =1

 --- 1 = StateorProvince ---
 select * from StateorProvince where IsActive =1

 --- 2 = DistrictorRegency ---
 select * from DistrictorRegency where IsActive =1

  --- 3 = SubDistrict ---
 select * from SubDistrict where IsActive =1

 ---  4 = Village ----
  select * from Village where IsActive =1

 ---  5 = RiskAssesmentQuestionHdr ----
  select * from RiskAssesmentQuestionHdr where IsActive =1

 --- 6 = Dealer -----
	select * from Dealer where IsActive=1

	--- 7 = Manfacturer -----
	select * from Manfacturer where IsActive=1

end
GO

-- %% [markdown]
-- # [dbo].[SP_TestMobileMap]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TestMobileMap]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_TestMobileMap]
as
begin
select X.*,f.FirstName+' '+f.LastName as FarmerName,p.Address as PlotAddress,p.AreaInHectors,p.Latitude,p.Longitude
 from
(select PlotCode,FarmerCode,dbo.FN_MapArray(PlotCode,FarmerCode) as LatLong from PlantationGeoBoundaries group by PlotCode,FarmerCode) X

left join Farmer f on f.FarmerCode = X.FarmerCode
left join Plantation p on p.FarmerCode=X.FarmerCode
where p.IsActive=1
order by LastName
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:14:13 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_ValidateUser 'DeveloperUser','b56e0b4ea4962283bee762525c2d490f'
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(255),
	@Password VARCHAR(255)    
AS

BEGIN
	
		SELECT 
		 t.[Id]
		,[UserName]
		,[Password]
		,[FirstName]
		,[LastName]
		,[EmailId]
		,[MobileNumber]
		,[RoleId]
		,[DealerId]
		,[ManufacturerId]
		,[TraderId]
		,t.[IsActive]
		,t.[CreatedDate]
		,[CreatedByUserId]
		,t.[UpdatedDate]
		,[UpdatedByUserId]
		,r.Name as RoleName
	FROM [dbo].[Users] t
	inner join [dbo].[Roles] r on r.Id = t.RoleId
	WHERE t.UserName=@UserName AND t.Password=@Password AND t.IsActive=1
END
GO
