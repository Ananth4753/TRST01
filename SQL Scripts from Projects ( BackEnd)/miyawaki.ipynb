-- %% [markdown]
-- # [dbo].[addinfo]

-- %%
USE [miyawaki]
GO

-- %%
/****** Object:  Table [dbo].[addinfo]    Script Date: 27-10-2023 15:09:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[addinfo](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrgId] [int] NULL,
	[ProjectId] [int] NOT NULL,
	[Presence] [bit] NOT NULL,
	[GPS] [varchar](100) NULL,
	[Longitude] [varchar](100) NULL,
	[Latitude] [varchar](100) NULL,
	[Area] [decimal](5, 2) NULL,
	[capacity] [decimal](5, 2) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[City]

-- %%
/****** Object:  Table [dbo].[City]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[City](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_City_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_City_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Country]

-- %%
/****** Object:  Table [dbo].[Country]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Country](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Country_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Country_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExcelFileHdr]

-- %%
/****** Object:  Table [dbo].[ExcelFileHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExcelFileHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NULL,
	[PlotId] [int] NULL,
	[FileId] [bigint] NULL,
	[FileName] [varchar](50) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExcelPLOT]

-- %%
/****** Object:  Table [dbo].[ExcelPLOT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExcelPLOT](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FileId] [int] NULL,
	[HdrId] [int] NULL,
	[SNO] [varchar](50) NULL,
	[ExcelSheetType] [varchar](20) NULL,
	[PLANT_NAME] [varchar](50) NULL,
	[COMMON_NAME] [varchar](50) NULL,
	[BOTANICAL_NAME] [varchar](50) NULL,
	[DIAMETER_INCHES] [varchar](50) NULL,
	[HEIGHT_FEETS] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExcelPLOTS]

-- %%
/****** Object:  Table [dbo].[ExcelPLOTS]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExcelPLOTS](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FileId] [int] NULL,
	[HdrId] [int] NULL,
	[SNO] [varchar](50) NULL,
	[ExcelSheetType] [varchar](20) NULL,
	[PLANT_NAME] [varchar](50) NULL,
	[COMMON_NAME] [varchar](50) NULL,
	[BOTANICAL_NAME] [varchar](50) NULL,
	[DIAMETER_INCHES] [varchar](50) NULL,
	[HEIGHT_FEETS] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Flag]

-- %%
/****** Object:  Table [dbo].[Flag]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Flag](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NameId] [int] NULL,
	[Name] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GeoBoundaries]

-- %%
/****** Object:  Table [dbo].[GeoBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GeoBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NULL,
	[Latitude] [float] NULL,
	[Longitude] [float] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[seqorder] [int] NULL,
 CONSTRAINT [PK_GeoBoundaries_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[grid]

-- %%
/****** Object:  Table [dbo].[grid]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[grid](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NOT NULL,
	[Name] [varchar](100) NULL,
	[Description] [varchar](100) NULL,
	[GPS] [varchar](100) NULL,
	[Longitude] [varchar](100) NULL,
	[Latitude] [varchar](100) NULL,
	[Area] [decimal](5, 2) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GridBoundaries]

-- %%
/****** Object:  Table [dbo].[GridBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GridBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[projectId] [varchar](50) NOT NULL,
	[PolygonId] [int] NOT NULL,
	[Latitude] [decimal](11, 9) NULL,
	[Longitude] [decimal](11, 9) NULL,
	[MeasuredArea] [float] NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GridGeoBoundaries]

-- %%
/****** Object:  Table [dbo].[GridGeoBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GridGeoBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[GridId] [int] NULL,
	[Latitude] [float] NULL,
	[Longitude] [float] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[seqorder] [int] NULL,
 CONSTRAINT [PK_GridGeoBoundaries_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GRIDSMERGE]

-- %%
/****** Object:  Table [dbo].[GRIDSMERGE]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GRIDSMERGE](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrgId] [int] NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Location] [varchar](255) NULL,
	[Type] [int] NULL,
	[GPS] [varchar](255) NOT NULL,
	[Latitude] [varchar](100) NOT NULL,
	[Longitude] [varchar](100) NOT NULL,
	[Areaofplantation] [decimal](18, 3) NOT NULL,
	[StartDate] [datetime] NOT NULL,
	[EndDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GRIDSMERGE1]

-- %%
/****** Object:  Table [dbo].[GRIDSMERGE1]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GRIDSMERGE1](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrgId] [int] NOT NULL,
	[projectId] [varchar](50) NOT NULL,
	[Latitude] [varchar](100) NOT NULL,
	[Longitude] [varchar](100) NOT NULL,
	[GridId] [int] NULL,
	[StartDate] [datetime] NOT NULL,
	[EndDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UserId] [int] NULL,
	[seqorder] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LogbookHdr]

-- %%
/****** Object:  Table [dbo].[LogbookHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LogbookHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrgId] [int] NOT NULL,
	[ProjectId] [int] NULL,
	[forestdistance] [decimal](5, 2) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[SoilComposition] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupDtl]

-- %%
/****** Object:  Table [dbo].[LookupDtl]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LookupHdrId] [int] NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Remarks] [varchar](100) NULL,
	[Ord] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupHdr]

-- %%
/****** Object:  Table [dbo].[LookupHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[MobileUsers]

-- %%
/****** Object:  Table [dbo].[MobileUsers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[MobileUsers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrganizationId] [int] NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[JobTitle] [varchar](100) NOT NULL,
	[Email] [varchar](255) NOT NULL,
	[DeviceNumber] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Organization]

-- %%
/****** Object:  Table [dbo].[Organization]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Organization](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BusinessName] [varchar](55) NOT NULL,
	[GST] [varchar](55) NOT NULL,
	[FirstName] [varchar](100) NOT NULL,
	[LastName] [varchar](100) NOT NULL,
	[ContactNumber] [bigint] NULL,
	[Email] [varchar](255) NOT NULL,
	[Typeofbusiness] [int] NOT NULL,
	[StreetName] [varchar](255) NOT NULL,
	[CountryId] [int] NOT NULL,
	[StateId] [int] NOT NULL,
	[CityId] [int] NOT NULL,
	[Pin] [varchar](20) NOT NULL,
	[BuildingName] [varchar](55) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UNQ_BusinessName] UNIQUE NONCLUSTERED 
(
	[BusinessName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PLOT1BACK]

-- %%
/****** Object:  Table [dbo].[PLOT1BACK]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PLOT1BACK](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FileId] [int] NULL,
	[SNO] [varchar](50) NULL,
	[PLANT_NAME] [varchar](50) NULL,
	[COMMON_NAME] [varchar](50) NULL,
	[BOTANICAL_NAME] [varchar](50) NULL,
	[CIRCUMFERENCE_INCHES] [varchar](50) NULL,
	[HEIGHT_FEETS] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PLOT1FRONT]

-- %%
/****** Object:  Table [dbo].[PLOT1FRONT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PLOT1FRONT](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FileId] [int] NULL,
	[SNO] [int] NULL,
	[PLANT_NAME] [varchar](50) NULL,
	[COMMON_NAME] [varchar](50) NULL,
	[BOTANICAL_NAME] [varchar](50) NULL,
	[DIAMETER_INCHES] [varchar](50) NULL,
	[HEIGHT_FEETS] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlotAminities]

-- %%
/****** Object:  Table [dbo].[PlotAminities]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlotAminities](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SNO] [int] NULL,
	[PLANTNAME] [varchar](50) NULL,
	[COMMONNAME] [varchar](50) NULL,
	[BOTANICALNAME] [varchar](50) NULL,
	[DIAMETER] [varchar](50) NULL,
	[HEIGHT] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ExcelHdrId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlotExcelDtl]

-- %%
/****** Object:  Table [dbo].[PlotExcelDtl]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlotExcelDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[HdrId] [int] NULL,
	[ExcelSheetType] [varchar](50) NULL,
	[SNO] [int] NULL,
	[PLANT_NAME] [varchar](50) NULL,
	[COMMON_NAME] [varchar](50) NULL,
	[BOTANICAL_NAME] [varchar](50) NULL,
	[DIAMETER_INCHES] [varchar](50) NULL,
	[HEIGHT_FEETS] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Project]

-- %%
/****** Object:  Table [dbo].[Project]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Project](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrgId] [int] NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Location] [varchar](255) NULL,
	[Type] [int] NULL,
	[GPS] [varchar](255) NOT NULL,
	[Latitude] [varchar](100) NOT NULL,
	[Longitude] [varchar](100) NOT NULL,
	[Areaofplantation] [decimal](18, 3) NOT NULL,
	[StartDate] [datetime] NOT NULL,
	[EndDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectAdditionalInfo]

-- %%
/****** Object:  Table [dbo].[ProjectAdditionalInfo]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectAdditionalInfo](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NOT NULL,
	[OrgId] [int] NOT NULL,
	[waterbodyLocation] [varchar](100) NOT NULL,
	[Latitude] [decimal](11, 9) NOT NULL,
	[Longitude] [decimal](11, 9) NOT NULL,
	[waterbodyArea] [decimal](8, 3) NOT NULL,
	[waterbodyCapacity] [decimal](8, 3) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectCurrentDTL]

-- %%
/****** Object:  Table [dbo].[ProjectCurrentDTL]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectCurrentDTL](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectCurrentHDRId] [int] NOT NULL,
	[MachineryCurrentlyId] [int] NOT NULL,
	[FuelUsageCurrent] [decimal](10, 5) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectCurrentHDR]

-- %%
/****** Object:  Table [dbo].[ProjectCurrentHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectCurrentHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NOT NULL,
	[OrgId] [int] NOT NULL,
	[NoofMachinery] [int] NOT NULL,
	[TransplantaionPlantsLocation] [varchar](100) NOT NULL,
	[LatitudePlant] [decimal](11, 9) NOT NULL,
	[LongitudePlant] [decimal](11, 9) NOT NULL,
	[NoofPlantstransported] [int] NOT NULL,
	[ModeTransportDevelpmentId] [int] NOT NULL,
	[NoofTransportationsforsoil] [int] NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectDevDTL]

-- %%
/****** Object:  Table [dbo].[ProjectDevDTL]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectDevDTL](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectDevHDRId] [int] NOT NULL,
	[EquipmentNameId] [int] NOT NULL,
	[EquipmentNo] [varchar](50) NULL,
	[Noofhoursusedday] [varchar](50) NULL,
	[Fuelusage] [decimal](9, 5) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectDevHDR]

-- %%
/****** Object:  Table [dbo].[ProjectDevHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectDevHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NOT NULL,
	[OrgId] [int] NOT NULL,
	[NoofEquipments] [int] NOT NULL,
	[TransportationSoilAmount] [decimal](11, 6) NOT NULL,
	[TransportationSoillocation] [varchar](100) NOT NULL,
	[LatitudeSoil] [decimal](11, 9) NOT NULL,
	[LongitudeSoil] [decimal](11, 9) NOT NULL,
	[ModeTransportDevelpmentId] [int] NOT NULL,
	[NoofTransportationsoil] [int] NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectDocument]

-- %%
/****** Object:  Table [dbo].[ProjectDocument]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectDocument](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NOT NULL,
	[OrgId] [int] NOT NULL,
	[DocURL] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[DocumentName] [varchar](255) NULL,
	[SNo] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProjectLeakage]

-- %%
/****** Object:  Table [dbo].[ProjectLeakage]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProjectLeakage](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectId] [int] NOT NULL,
	[OrgId] [int] NOT NULL,
	[NoofEquipments] [int] NOT NULL,
	[EquipmentdeviceId] [int] NOT NULL,
	[EquipmentNameId] [int] NOT NULL,
	[EquipmentNo] [varchar](100) NOT NULL,
	[NoofHoursUsedEquipments] [varchar](50) NOT NULL,
	[FuelUsageDevelopment] [decimal](10, 5) NOT NULL,
	[TransportationSoilAmount] [decimal](11, 6) NOT NULL,
	[TransportationSoillocation] [varchar](100) NOT NULL,
	[LatitudeSoil] [decimal](11, 9) NOT NULL,
	[LongitudeSoil] [decimal](11, 9) NOT NULL,
	[ModeTransportDevelpmentId] [int] NOT NULL,
	[NoofTransportationsoil] [int] NOT NULL,
	[NoofMachineryinuse] [int] NOT NULL,
	[MachineryCurrentlyId] [int] NOT NULL,
	[FuelUsageCurrent] [decimal](10, 5) NOT NULL,
	[TransplantaionPlantsLocation] [varchar](100) NOT NULL,
	[LatitudePlant] [decimal](11, 9) NOT NULL,
	[LongitudePlant] [decimal](11, 9) NOT NULL,
	[NoofPlantstransported] [int] NOT NULL,
	[ModeoftransportcurrentId] [int] NOT NULL,
	[Nooftransportationscurrent] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Projectusers]

-- %%
/****** Object:  Table [dbo].[Projectusers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Projectusers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProjectOUTId] [int] NULL,
	[OrgId] [int] NOT NULL,
	[UserId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[States]

-- %%
/****** Object:  Table [dbo].[States]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[States](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_State_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_State_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](30) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[LastName] [varchar](50) NOT NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[RoleId] [int] NULL,
	[OrgId] [int] NULL,
	[JobTitle] [int] NULL,
	[Flag] [int] NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[waterbodyBoundaries]

-- %%
/****** Object:  Table [dbo].[waterbodyBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[waterbodyBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PolygonId] [int] NOT NULL,
	[Latitude] [decimal](11, 9) NULL,
	[Longitude] [decimal](11, 9) NULL,
	[seqorder] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__addinfo__IsActiv__43F60EC8]

-- %%
ALTER TABLE [dbo].[addinfo] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__addinfo__Created__44EA3301]

-- %%
ALTER TABLE [dbo].[addinfo] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__addinfo__Updated__47C69FAC]

-- %%
ALTER TABLE [dbo].[addinfo] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__City__IsActive__19AACF41]

-- %%
ALTER TABLE [dbo].[City] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__City__CreatedDat__1A9EF37A]

-- %%
ALTER TABLE [dbo].[City] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__City__UpdatedDat__1B9317B3]

-- %%
ALTER TABLE [dbo].[City] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Country__IsActiv__1209AD79]

-- %%
ALTER TABLE [dbo].[Country] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Country__Created__12FDD1B2]

-- %%
ALTER TABLE [dbo].[Country] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Country__Updated__13F1F5EB]

-- %%
ALTER TABLE [dbo].[Country] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ExcelFile__IsAct__12E8C319]

-- %%
ALTER TABLE [dbo].[ExcelFileHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ExcelFile__Creat__13DCE752]

-- %%
ALTER TABLE [dbo].[ExcelFileHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ExcelFile__Updat__14D10B8B]

-- %%
ALTER TABLE [dbo].[ExcelFileHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ExcelPLOT__IsAct__3631FF56]

-- %%
ALTER TABLE [dbo].[ExcelPLOT] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ExcelPLOT__Creat__3726238F]

-- %%
ALTER TABLE [dbo].[ExcelPLOT] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ExcelPLOT__Updat__381A47C8]

-- %%
ALTER TABLE [dbo].[ExcelPLOT] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ExcelPLOT__IsAct__3BEAD8AC]

-- %%
ALTER TABLE [dbo].[ExcelPLOTS] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ExcelPLOT__Creat__3CDEFCE5]

-- %%
ALTER TABLE [dbo].[ExcelPLOTS] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ExcelPLOT__Updat__3DD3211E]

-- %%
ALTER TABLE [dbo].[ExcelPLOTS] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__GeoBounda__IsAct__16644E42]

-- %%
ALTER TABLE [dbo].[GeoBoundaries] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__GeoBounda__Creat__1758727B]

-- %%
ALTER TABLE [dbo].[GeoBoundaries] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__GeoBounda__Updat__184C96B4]

-- %%
ALTER TABLE [dbo].[GeoBoundaries] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__grid__IsActive__52793849]

-- %%
ALTER TABLE [dbo].[grid] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__grid__CreatedDat__536D5C82]

-- %%
ALTER TABLE [dbo].[grid] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__grid__UpdatedDat__546180BB]

-- %%
ALTER TABLE [dbo].[grid] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__GridBound__IsAct__62AFA012]

-- %%
ALTER TABLE [dbo].[GridBoundaries] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__GridBound__Creat__63A3C44B]

-- %%
ALTER TABLE [dbo].[GridBoundaries] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__GridBound__Updat__6497E884]

-- %%
ALTER TABLE [dbo].[GridBoundaries] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__GridGeoBo__IsAct__6F1576F7]

-- %%
ALTER TABLE [dbo].[GridGeoBoundaries] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__GridGeoBo__Creat__70099B30]

-- %%
ALTER TABLE [dbo].[GridGeoBoundaries] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__GridGeoBo__Updat__70FDBF69]

-- %%
ALTER TABLE [dbo].[GridGeoBoundaries] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LogbookHd__IsAct__618671AF]

-- %%
ALTER TABLE [dbo].[LogbookHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LogbookHd__Creat__627A95E8]

-- %%
ALTER TABLE [dbo].[LogbookHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LogbookHd__Updat__636EBA21]

-- %%
ALTER TABLE [dbo].[LogbookHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__IsAct__336AA144]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Creat__345EC57D]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Updat__3552E9B6]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__IsAct__2EA5EC27]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Creat__2F9A1060]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Updat__308E3499]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__1DB06A4F]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__1EA48E88]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__1F98B2C1]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__208CD6FA]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__2180FB33]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__22751F6C]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__MobileUse__IsAct__74794A92]

-- %%
ALTER TABLE [dbo].[MobileUsers] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__MobileUse__Creat__756D6ECB]

-- %%
ALTER TABLE [dbo].[MobileUsers] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__MobileUse__Updat__76619304]

-- %%
ALTER TABLE [dbo].[MobileUsers] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Organizat__IsAct__29E1370A]

-- %%
ALTER TABLE [dbo].[Organization] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Organizat__Creat__2AD55B43]

-- %%
ALTER TABLE [dbo].[Organization] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Organizat__Updat__2BC97F7C]

-- %%
ALTER TABLE [dbo].[Organization] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PLOT1BACK__IsAct__642DD430]

-- %%
ALTER TABLE [dbo].[PLOT1BACK] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PLOT1BACK__Creat__6521F869]

-- %%
ALTER TABLE [dbo].[PLOT1BACK] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PLOT1BACK__Updat__66161CA2]

-- %%
ALTER TABLE [dbo].[PLOT1BACK] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PLOT1FRON__IsAct__67FE6514]

-- %%
ALTER TABLE [dbo].[PLOT1FRONT] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PLOT1FRON__Creat__68F2894D]

-- %%
ALTER TABLE [dbo].[PLOT1FRONT] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PLOT1FRON__Updat__69E6AD86]

-- %%
ALTER TABLE [dbo].[PLOT1FRONT] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PlotAmini__IsAct__09946309]

-- %%
ALTER TABLE [dbo].[PlotAminities] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PlotAmini__Creat__0A888742]

-- %%
ALTER TABLE [dbo].[PlotAminities] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PlotAmini__Updat__0B7CAB7B]

-- %%
ALTER TABLE [dbo].[PlotAminities] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PlotExcel__IsAct__2CA8951C]

-- %%
ALTER TABLE [dbo].[PlotExcelDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PlotExcel__Creat__2D9CB955]

-- %%
ALTER TABLE [dbo].[PlotExcelDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Project__IsActiv__7AF13DF7]

-- %%
ALTER TABLE [dbo].[Project] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Project__Created__7BE56230]

-- %%
ALTER TABLE [dbo].[Project] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Project__Updated__7CD98669]

-- %%
ALTER TABLE [dbo].[Project] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectAd__IsAct__5E1FF51F]

-- %%
ALTER TABLE [dbo].[ProjectAdditionalInfo] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectAd__Creat__5F141958]

-- %%
ALTER TABLE [dbo].[ProjectAdditionalInfo] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectAd__Updat__60083D91]

-- %%
ALTER TABLE [dbo].[ProjectAdditionalInfo] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectCu__IsAct__324172E1]

-- %%
ALTER TABLE [dbo].[ProjectCurrentDTL] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectCu__Creat__3335971A]

-- %%
ALTER TABLE [dbo].[ProjectCurrentDTL] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectCu__Updat__3429BB53]

-- %%
ALTER TABLE [dbo].[ProjectCurrentDTL] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectCu__IsAct__2D7CBDC4]

-- %%
ALTER TABLE [dbo].[ProjectCurrentHDR] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectCu__Creat__2E70E1FD]

-- %%
ALTER TABLE [dbo].[ProjectCurrentHDR] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectCu__Updat__2F650636]

-- %%
ALTER TABLE [dbo].[ProjectCurrentHDR] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectDe__IsAct__4183B671]

-- %%
ALTER TABLE [dbo].[ProjectDevDTL] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectDe__Creat__4277DAAA]

-- %%
ALTER TABLE [dbo].[ProjectDevDTL] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectDe__Updat__436BFEE3]

-- %%
ALTER TABLE [dbo].[ProjectDevDTL] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectDe__IsAct__4CF5691D]

-- %%
ALTER TABLE [dbo].[ProjectDevHDR] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectDe__Creat__4DE98D56]

-- %%
ALTER TABLE [dbo].[ProjectDevHDR] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectDe__Updat__4EDDB18F]

-- %%
ALTER TABLE [dbo].[ProjectDevHDR] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectDo__IsAct__664B26CC]

-- %%
ALTER TABLE [dbo].[ProjectDocument] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectDo__Creat__673F4B05]

-- %%
ALTER TABLE [dbo].[ProjectDocument] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectDo__Updat__68336F3E]

-- %%
ALTER TABLE [dbo].[ProjectDocument] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectLe__IsAct__13BCEBC1]

-- %%
ALTER TABLE [dbo].[ProjectLeakage] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ProjectLe__Creat__14B10FFA]

-- %%
ALTER TABLE [dbo].[ProjectLeakage] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ProjectLe__Updat__15A53433]

-- %%
ALTER TABLE [dbo].[ProjectLeakage] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Projectus__IsAct__041093DD]

-- %%
ALTER TABLE [dbo].[Projectusers] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Projectus__Creat__0504B816]

-- %%
ALTER TABLE [dbo].[Projectusers] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Projectus__Updat__05F8DC4F]

-- %%
ALTER TABLE [dbo].[Projectusers] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__2B0A656D]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__2BFE89A6]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__2CF2ADDF]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__2DE6D218]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__2EDAF651]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__2FCF1A8A]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__123EB7A3]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__1332DBDC]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__14270015]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__States__IsActive__0A688BB1]

-- %%
ALTER TABLE [dbo].[States] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__States__CreatedD__0B5CAFEA]

-- %%
ALTER TABLE [dbo].[States] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__States__UpdatedD__0C50D423]

-- %%
ALTER TABLE [dbo].[States] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__60A75C0F]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__619B8048]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__628FA481]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__waterbody__IsAct__3B60C8C7]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__waterbody__Creat__3C54ED00]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__waterbody__Updat__3D491139]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK__addinfo__Created__45DE573A]

-- %%
ALTER TABLE [dbo].[addinfo]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__addinfo__Updated__46D27B73]

-- %%
ALTER TABLE [dbo].[addinfo]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__GridBound__Creat__658C0CBD]

-- %%
ALTER TABLE [dbo].[GridBoundaries]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__GridBound__Creat__68687968]

-- %%
ALTER TABLE [dbo].[GridBoundaries]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__GridBound__Updat__668030F6]

-- %%
ALTER TABLE [dbo].[GridBoundaries]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__GridBound__Updat__695C9DA1]

-- %%
ALTER TABLE [dbo].[GridBoundaries]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK__waterbody__Creat__3E3D3572]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__waterbody__Creat__3F3159AB]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__waterbody__Updat__40257DE4]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK__waterbody__Updat__4119A21D]

-- %%
ALTER TABLE [dbo].[waterbodyBoundaries]  WITH CHECK ADD FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [dbo].[SP_AddCity]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCity]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_AddCity] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[City] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[City]
			SET  [Code] = @Code
				,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCountry]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCountry]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_AddCountry] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Country] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Country]
			SET  [Code] = @Code
				,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDocsForProject]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDocsForProject]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddDocsForProject]
(@Id int,
@ProjectId Int,
@OrgId Int,
@DocURL varchar(255),
@DocumentName  varchar(255), 
--@DocExtension varchar(255),
@SNo Int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into ProjectDocument(
ProjectId,
OrgId,
DocURL,
DocumentName,
--DocExtension,
SNo,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate

)
values(
@ProjectId,
@OrgId,
@DocURL,
@DocumentName,
--@DocExtension,
@SNo,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update ProjectDocument Set OrgId=@OrgId,ProjectId = @ProjectId,DocURL = @DocURL,DocumentName=@DocumentName,@IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddExcelDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddExcelDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddExcelDetails]
(@Id int,
@ExcelFileHDRId int,
@SNOFront varchar(50),
@PLANTNAMEFront varchar(100),
@COMMONNAMEFront varchar(100),
@BOTANICALNAMEFront varchar(100),
@DIAFront decimal(6,3),
@HEIGHTfront [decimal](6,3),
@SNOBack varchar(50),
@PLANTNAMEBack varchar(100),
@COMMONNAMEBack varchar(100),
@BOTANICALNAMEBack varchar(100),
@CircumferenceBack decimal(6, 3),
@HEIGHTBack [decimal](6, 3),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into ExcelDetails(
ExcelFileHDRId ,
SNOFront,
PLANTNAMEFront,
COMMONNAMEFront,
BOTANICALNAMEFront,
DIAFront,
HEIGHTfront,
SNOBack,
PLANTNAMEBack,
COMMONNAMEBack,
BOTANICALNAMEBack,
CircumferenceBack,
HEIGHTBack,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ExcelFileHDRId ,
@SNOFront,
@PLANTNAMEFront,
@COMMONNAMEFront,
@BOTANICALNAMEFront,
@DIAFront,
@HEIGHTfront,
@SNOBack,
@PLANTNAMEBack,
@COMMONNAMEBack,
@BOTANICALNAMEBack,
@CircumferenceBack,
@HEIGHTBack,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
 
end
else
begin
update ExcelDetails Set  
IsActive=@IsActive where Id=@Id

end
end




 
GO

-- %% [markdown]
-- # [dbo].[SP_AddExcelFileHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddExcelFileHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddExcelFileHdr] 
(
 @Id int 
 ,@PlotId int
 ,@ProjectId int
,@FileId BigInt
,@FileName varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@HdrId int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin

			INSERT INTO [dbo].[ExcelFileHdr] (
				 ProjectId
				 ,PlotId
				 ,FileId
				 ,FileName
				,IsActive
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			     @ProjectId
				 ,@PlotId
				 ,@FileId
				 ,@FileName
				,ISNULL(@IsActive, 1)
				,--GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				GETDATE()
				,@CreatedByUserId
				,--GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				GETDATE()
				,@UpdatedByUserId
				)
				set @HdrId=@@IDENTITY
				end
		ELSE
		begin
			UPDATE [dbo].ExcelFileHdr
			SET   [ProjectId]=@ProjectId
			     ,[FileId] = @FileId
				 ,[PlotId] = @PlotId
				,[FileName]=@FileName
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = GETDATE()-- AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @HdrId=@Id
			End
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddExcelPLOT]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddExcelPLOT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddExcelPLOT] 
(
 @Id int = NULL
,@FileId Int
,@SNO VARCHAR(50)
,@ExcelSheetType varchar(20)
,@PLANT_NAME varchar(50)
,@COMMON_NAME varchar(50)
,@BOTANICAL_NAME varchar(50)
,@DIAMETER_INCHES varchar(50)
,@HEIGHT_FEETS varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		--declare @PId int
		--set @PId = (select Id from Product where ProductName=@ProductName)
			INSERT INTO [dbo].[ExcelPLOT] (
				 FileId
				 ,SNO
				 ,ExcelSheetType
				,[PLANT_NAME]
				,[COMMON_NAME]
				,[BOTANICAL_NAME]
				,[DIAMETER_INCHES]
				,[HEIGHT_FEETS]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				
				)
			VALUES (
				 @FileId
				,@SNO
				,@ExcelSheetType
				,@PLANT_NAME
				,@COMMON_NAME
				,@BOTANICAL_NAME
				,@DIAMETER_INCHES
				,@HEIGHT_FEETS
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[ExcelPLOT]
			SET  [FileId] = @FileId
				,[SNO] = @SNO
				,[ExcelSheetType] = @ExcelSheetType
				,[PLANT_NAME] = @PLANT_NAME
				,COMMON_NAME=@COMMON_NAME
				,BOTANICAL_NAME=@BOTANICAL_NAME
				,[DIAMETER_INCHES] = @DIAMETER_INCHES
				,HEIGHT_FEETS=@HEIGHT_FEETS
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGeoBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddGeoBoundaries]
(@Id int = null,
@ProjectId Int,
@Latitude FLOAT,
@Longitude FLOAT,
@seqorder int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime


)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into GeoBoundaries(
 ProjectId,
Latitude,
Longitude,
seqorder,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProjectId,
 @Latitude,
@Longitude,
@seqorder,
  @IsActive,
  @CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate

)
 
end
else
begin
update GeoBoundaries Set ProjectId=@ProjectId, Latitude=@Latitude,Longitude=@Longitude,seqorder=@seqorder,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddGrid]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGrid]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddGrid]
(@Id int,
@ProjectId int,
@Name Varchar(100),
@Description varchar(100),
--@Size varchar(100),
@GPS varchar(100),
@Longitude varchar(100),
@Latitude varchar(100),
@Area decimal(5,2),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@GridOUT int OUTPUT
)
as
begin
If isnull(@Id,0)=0
begin
insert into grid(
ProjectId,
[Name],
[Description],
--Size,
GPS,
Latitude,
Longitude,
Area,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProjectId,
@Name,
@Description,
--@Size,
@GPS,
@Latitude,
@Longitude,
@Area,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @GridOUT = @@IDENTITY
update GridGeoBoundaries set GridId = @GridOUT where GridId = 10000000
 end
else
begin
update grid Set ProjectId=@ProjectId,Name=@Name,Description=@Description,GPS=@GPS,Latitude=@Latitude,Longitude = @Longitude,
Area=@Area,IsActive=@IsActive where Id=@Id
 
end
end




GO

-- %% [markdown]
-- # [dbo].[SP_AddGridBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGridBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddGridBoundaries]
(@Id int = null,
@ProjectId Int,
@Latitude decimal(11, 9),
@Longitude decimal(11, 9),
@MeasuredArea Float,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime


)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into GridBoundaries(
 ProjectId,
Latitude,
Longitude,
MeasuredArea,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProjectId,
 @Latitude,
@Longitude,
@MeasuredArea,
  @IsActive,
  @CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate

)
 
end
else
begin
update GridBoundaries Set ProjectId=@ProjectId, Latitude=@Latitude,Longitude=@Longitude,
MeasuredArea=@MeasuredArea,IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddGridGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGridGeoBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddGridGeoBoundaries]
(@Id int = null,
@GridId Int,
@seqorder Int,
@Latitude FLOAT,
@Longitude FLOAT,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime


)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into GridGeoBoundaries(
 GridId,
 seqorder,
Latitude,
Longitude,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@GridId,
@seqorder,
 @Latitude,
@Longitude,
  @IsActive,
  @CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate

)
 
end
else
begin
update GridGeoBoundaries Set GridId=@GridId,seqorder=@seqorder, Latitude=@Latitude,Longitude=@Longitude,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_Addinfo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Addinfo]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_Addinfo]
(@Id int,
@OrgId int,
@ProjectId int,
@Presence bit,
@GPS varchar(100),
@Longitude varchar(100),
@Latitude varchar(100),
@Area decimal(5,2),
@capacity decimal(5,2),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@PolygonOUT int OUTPUT
)
as
begin
If isnull(@Id,0)=0
begin
insert into addinfo(
OrgId,
ProjectId,
Presence,
GPS,
Latitude,
Longitude,
Area,
capacity,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@OrgId,
@ProjectId,
@Presence,
@GPS,
@Latitude,
@Longitude,
@Area,
@capacity,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
set @PolygonOUT = @@IDENTITY
update waterbodyBoundaries set PolygonId = @PolygonOUT where PolygonId = 10000000
 end
else
begin
update addinfo Set ProjectId=@ProjectId,Presence=@Presence,GPS=@GPS,Latitude=@Latitude,Longitude = @Longitude,
Area=@Area,capacity=@capacity,IsActive=@IsActive where Id=@Id
 
end
end




 
GO

-- %% [markdown]
-- # [dbo].[SP_AddLeakageForProject]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLeakageForProject]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddLeakageForProject]
(@Id int,
@ProjectId Int,
@OrgId Int,
@EquipmentNameId Int,
@EquipmentNo Int,
@NoofHoursUsedEquipments Int,	 
@IsMcCurrentlyinUse bit,
@FuelUsage [decimal](10, 6),
@TransportationSoilAmount[decimal](11, 6),
@TransportationSoillocation [varchar](100),
@LatitudeSoil [decimal](11, 9),
@LongitudeSoil [decimal](11, 9),
@ModeTransportId Int,
@TransplantaionPlantsLocation  [varchar](100),
@LatitudePlant [decimal](11, 9),
@LongitudePlant [decimal](11, 9),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as
begin
If isnull(@Id,0)=0
begin
insert into ProjectLeakage(
ProjectId,
OrgId,
EquipmentNameId,
EquipmentNo,
NoofHoursUsedEquipments,
IsMcCurrentlyinUse,
FuelUsage,
TransportationSoilAmount,
TransportationSoillocation,
LatitudeSoil,
LongitudeSoil,
ModeTransportId,
TransplantaionPlantsLocation,
LatitudePlant,
LongitudePlant,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId
 
)
values(
@ProjectId,
@OrgId,
@EquipmentNameId,
@EquipmentNo,
@NoofHoursUsedEquipments,
@IsMcCurrentlyinUse,
@FuelUsage,
@TransportationSoilAmount,
@TransportationSoillocation,
@LatitudeSoil,
@LongitudeSoil,
@ModeTransportId,
@TransplantaionPlantsLocation,
@LatitudePlant,
@LongitudePlant,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
  
				declare @POId int
                set @POId  = @@IDENTITY
				declare @GID varchar(255)
                set @GID =('EQ'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
                update ProjectLeakage set EquipmentNo = @GID where Id=@POId
end
else
begin
update ProjectLeakage Set OrgId=@OrgId,ProjectId = @ProjectId,EquipmentNameId = @EquipmentNameId,EquipmentNo=@EquipmentNo,
NoofHoursUsedEquipments=@NoofHoursUsedEquipments,IsMcCurrentlyinUse=@IsMcCurrentlyinUse,FuelUsage=@FuelUsage,TransportationSoilAmount=@TransportationSoilAmount,
TransportationSoillocation=@TransportationSoillocation,LatitudeSoil=@LatitudeSoil,LongitudeSoil=@LongitudeSoil,ModeTransportId=@ModeTransportId,
TransplantaionPlantsLocation=@TransplantaionPlantsLocation,LatitudePlant=@LatitudePlant,LongitudePlant=@LongitudePlant,@IsActive=@IsActive where Id=@Id
end
end


GO

-- %% [markdown]
-- # [dbo].[SP_AddLogbookHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLogbookHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddLogbookHDR] 
(
@Id int,
@OrgId int,
@ProjectId int,
@forestdistance [decimal](5,2) 
,@SoilComposition [varchar](255),
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@LogbookhdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LogbookHdr] (
			     OrgId,
				 ProjectId
				 ,forestdistance
				 ,SoilComposition
				,IsActive
				,CreatedDate
				,CreatedByUserId
				,UpdatedDate
				,UpdatedByUserId
				)
			VALUES (
			@OrgId,
				 @ProjectId
				,@forestdistance
				,@SoilComposition
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @LogbookhdrOUT = @@IDENTITY
				END
		ELSE
		begin
			UPDATE [dbo].[LogbookHdr]

			SET  OrgId=@OrgId,ProjectId=@ProjectId,
		forestdistance=@forestdistance,SoilComposition=@SoilComposition, 
				[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @LogbookhdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END         
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupDtl]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddLookupDtl] 
(
 @Id int
,@LookupHdrId int
,@Code varchar(255)
,@Name varchar(100)
,@Remarks varchar(100)
,@Ord int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookupdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupDtl] (
				  [LookupHdrId]
				,[Code]
				,[Name]
				,[Remarks]
				,[Ord]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @LookupHdrId
				,@Code
				,@Name
				,@Remarks
				,@Ord
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookupdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[LookupDtl]
			SET  [LookupHdrId] = @LookupHdrId
			,[Code] = @Code
				,[Name] = @Name
				,[Remarks] = @Remarks
				,[Ord] = @Ord
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookupdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddLookupHdr] 
(
 @Id int,
 @Code Varchar(255)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookuphdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupHdr] (
					 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 	 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookuphdrOUT = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[LookupHdr]
			SET  
				[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookuphdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMobileUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMobileUsers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddMobileUsers]
(@Id int,
@OrganizationId int,
@Name varchar(100),
@JobTitle varchar(100),
@Email varchar(255),
@DeviceNumber varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into MobileUsers(
OrganizationId,
Name,
JobTitle,
Email,
DeviceNumber,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@OrganizationId,
@Name,
@JobTitle,
@Email,
@DeviceNumber,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update MobileUsers Set OrganizationId=@OrganizationId,Name=@Name,JobTitle=@JobTitle,Email=@Email,DeviceNumber=@DeviceNumber,@IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddOrganization]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrganization]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddOrganization]
(@Id int,
@BusinessName varchar(55),
@GST varchar(55),
@FirstName varchar(100),
@LastName varchar(100),
@ContactNumber bigint,
@Email varchar(255),
@Typeofbusiness int,
@StreetName varchar(255),
@CountryId int,
@StateId int,
@CityId int,
@Pin varchar(20),
@BuildingName varchar(55),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into Organization(
BusinessName,
GST,
FirstName,
LastName,
ContactNumber,
Email,
Typeofbusiness,
StreetName,
CountryId,
StateId,
CityId,
Pin,
BuildingName,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@BusinessName,
@GST,
@FirstName,
@LastName,
@ContactNumber,
@Email,
@Typeofbusiness,
@StreetName,
@CountryId,
@StateId,
@CityId,
@Pin,
@BuildingName,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
declare @OrgId int
set @OrgId = @@IDENTITY
 insert into Users(UserName,
Password ,
RoleId ,
FirstName ,
Flag,
LastName ,
EmailId ,
MobileNumber,
ViewYN ,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId,
OrgId
)
Values(
@Email,
'b56e0b4ea4962283bee762525c2d490f',
1,
@BusinessName,
0,---web zero
'',
@Email,
@ContactNumber,
1,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId,
@OrgId
)
end
else
begin
update Organization Set BusinessName=@BusinessName,GST=@GST,FirstName=@FirstName,LastName=@LastName,ContactNumber=@ContactNumber,Email=@Email,Typeofbusiness=@Typeofbusiness,StreetName=@StreetName,CountryId=@CountryId,StateId=@StateId,CityId=@CityId,Pin=@Pin,BuildingName=@BuildingName,@IsActive=@IsActive where Id=@Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT1BACK]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT1BACK]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPLOT1BACK] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@Circumference varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT1BACK] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[Circumference]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@Circumference
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT1BACK]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[Circumference] = @Circumference
				,HEIGHT=@HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT1FRONT]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT1FRONT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPLOT1FRONT] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@DIAMETER varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT1FRONT] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[DIAMETER]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@DIAMETER
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT1FRONT]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[DIAMETER] = @DIAMETER
				,HEIGHT=@HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT2BACK]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT2BACK]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPLOT2BACK] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@Circumference varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT2BACK] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[Circumference]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@Circumference
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT2BACK]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[Circumference] = @Circumference
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT2FRONT]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT2FRONT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPLOT2FRONT] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@DIAMETER varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT1FRONT] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[DIAMETER]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@DIAMETER
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT1FRONT]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[DIAMETER] = @DIAMETER
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT3BACK]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT3BACK]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPLOT3BACK] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@Circumference varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT3BACK] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[Circumference]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@Circumference
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT3BACK]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[Circumference] = @Circumference
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT3FRONT]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT3FRONT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPLOT3FRONT] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@DIAMETER varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT1FRONT] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[DIAMETER]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@DIAMETER
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT1FRONT]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[DIAMETER] = @DIAMETER
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT4FRONT]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT4FRONT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPLOT4FRONT] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@DIAMETER varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT1FRONT] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[DIAMETER]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@DIAMETER
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT1FRONT]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[DIAMETER] = @DIAMETER
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPLOT5FRONT]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPLOT5FRONT]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPLOT5FRONT] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@DIAMETER varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PLOT1FRONT] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[DIAMETER]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@DIAMETER
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PLOT1FRONT]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[DIAMETER] = @DIAMETER
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlotAminities]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlotAminities]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPlotAminities] 
(
 @Id int = NULL
,@SNO varchar(50)
,@PLANTNAME varchar(50)
,@COMMONNAME bit,
@BOTANICALNAME varchar(50)
,@DIAMETER varchar(50)
,@HEIGHT varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PlotAminities] (
				 [SNO]
				,[PLANTNAME]
				,[COMMONNAME]
				,[BOTANICALNAME]
				,[DIAMETER]
				,[HEIGHT]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				,@PLANTNAME
				,@COMMONNAME
				,@BOTANICALNAME
				,@DIAMETER
				,@HEIGHT
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PlotAminities]
			SET  [SNO] = @SNO
				,[PLANTNAME] = @PLANTNAME
				,[COMMONNAME] = @COMMONNAME
				,[BOTANICALNAME] = @BOTANICALNAME
				,[DIAMETER] = @DIAMETER
				,HEIGHT=HEIGHT
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlotExcelDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlotExcelDtl]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_AddPlotExcelDtl] 
(
 @Id int = NULL,
 @HdrId int = Null,
 @ExcelSheetType varchar(50)
,@SNO varchar(50)
,@PLANT_NAME varchar(50)
,@COMMON_NAME varchar(50),
@BOTANICAL_NAME varchar(50)
,@DIAMETER_INCHES varchar(50)
,@HEIGHT_FEETS varchar(50)
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PlotExcelDtl] (
				 [SNO]
				,[HdrId]
				,[ExcelSheetType]
				,[PLANT_NAME]
				,[COMMON_NAME]
				,[BOTANICAL_NAME]
				,[DIAMETER_INCHES]
				,[HEIGHT_FEETS]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @SNO
				 ,@HdrId
				,@ExcelSheetType
				,@PLANT_NAME
				,@COMMON_NAME
				,@BOTANICAL_NAME
				,@DIAMETER_INCHES
				,@HEIGHT_FEETS
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PlotExcelDtl]
			SET  [SNO] = @SNO
			    ,[ExcelSheetType] = @ExcelSheetType
				,[PLANT_NAME] = @PLANT_NAME
				,[COMMON_NAME] = @COMMON_NAME
				,[BOTANICAL_NAME] = @BOTANICAL_NAME
				,[DIAMETER_INCHES] = @DIAMETER_INCHES
				,[HEIGHT_FEETS]=@HEIGHT_FEETS
				,[HdrId] = @HdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlotExcelSummary]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlotExcelSummary]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddPlotExcelSummary] 
(
 @Id int = NULL
,@Plots varchar(50)
,@FrontSide bit
,@Backside bit,
@FrontGrid varchar(50)
,@Backgrid varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		 
			INSERT INTO [dbo].[PlotExcelSummary] (
				 [Plots]
				,[FrontSide]
				,[Backside]
				,[FrontGrid]
				,[Backgrid]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				 @Plots
				,@FrontSide
				,@Backside
				,@FrontGrid
				,@Backgrid
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[PlotExcelSummary]
			SET  [Plots] = @Plots
				,[FrontSide] = @FrontSide
				,[Backside] = @Backside
				,[FrontGrid] = @FrontGrid
				
				,[Backgrid] = @Backgrid
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectCurrentDTL]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectCurrentDTL]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddProjectCurrentDTL] 
(
 @Id int
,@ProjectCurrentHDRId int,
@MachineryCurrentlyId [int],
@FuelUsageCurrent decimal (10, 5),
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ProjectCurrenthdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[ProjectCurrentDTL] (
				 ProjectCurrentHDRId,
                 MachineryCurrentlyId,
                 FuelUsageCurrent
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ProjectCurrentHDRId
				,@MachineryCurrentlyId
				,@FuelUsageCurrent
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
			
				)
				set @ProjectCurrenthdrOUT = @@IDENTITY

			 
				END
		ELSE
			UPDATE [dbo].[ProjectCurrentDTL]
			SET  [ProjectCurrentHDRId] = @ProjectCurrentHDRId
			,[MachineryCurrentlyId] = @MachineryCurrentlyId
				,FuelUsageCurrent = @FuelUsageCurrent
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId

			WHERE Id = @Id
			set @ProjectCurrenthdrOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectCurrentHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectCurrentHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddProjectCurrentHDR] 
(
@Id int,
@ProjectId int,
@OrgId int,
@NoofMachinery int,
@TransplantaionPlantsLocation varchar (100),
@LatitudePlant decimal(11, 9),
@LongitudePlant decimal(11, 9),
@NoofPlantstransported int,
@ModeTransportDevelpmentId int,
@NoofTransportationsforsoil int,
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ProjectCurrenthdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[ProjectCurrentHDR] (
				 ProjectId
				 ,OrgId
				 ,NoofMachinery
				 ,TransplantaionPlantsLocation
				 ,LatitudePlant
				,LongitudePlant
                ,NoofPlantstransported,
                ModeTransportDevelpmentId,
                NoofTransportationsforsoil
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ProjectId
				,@OrgId
				,@NoofMachinery
				 ,@TransplantaionPlantsLocation
				 ,@LatitudePlant
				,@LongitudePlant
                ,@NoofPlantstransported,
                @ModeTransportDevelpmentId,
                @NoofTransportationsforsoil
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @ProjectCurrenthdrOUT = @@IDENTITY

		 
				END
		ELSE
		begin
			UPDATE [dbo].[ProjectCurrentHDR]
			SET  ProjectId=@ProjectId,
			OrgId=@OrgId,NoofMachinery=@NoofMachinery,TransplantaionPlantsLocation=@TransplantaionPlantsLocation,
			LatitudePlant=@LatitudePlant,LongitudePlant=@LongitudePlant,NoofPlantstransported=@NoofPlantstransported,
			ModeTransportDevelpmentId=@ModeTransportDevelpmentId
				,NoofTransportationsforsoil=@NoofTransportationsforsoil
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @ProjectCurrenthdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectDevDTL]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectDevDTL]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddProjectDevDTL] 
(
 @Id int
,@ProjectDevHDRId int,
@EquipmentNameId int,
@EquipmentNo varchar (50),
@Noofhoursusedday varchar (50),
@Fuelusage decimal(9,5),
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ProjectDevhdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[ProjectDevDTL] (
				 ProjectDevHDRId,
				 EquipmentNameId,
                 EquipmentNo,
                 Noofhoursusedday,
                 Fuelusage
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ProjectDevHDRId
				,@EquipmentNameId,
                 @EquipmentNo,
                 @Noofhoursusedday,
                 @Fuelusage
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
			
				)
				set @ProjectDevhdrOUT = @@IDENTITY

			 
				END
		ELSE
			UPDATE [dbo].[ProjectDevDTL]
			SET  [ProjectDevHDRId] = @ProjectDevHDRId
			, EquipmentNameId=@EquipmentNameId,
                 EquipmentNo=@EquipmentNo,
                 Noofhoursusedday=@Noofhoursusedday,
                 Fuelusage=@Fuelusage
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId

			WHERE Id = @Id
			set @ProjectDevhdrOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectDevHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectDevHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddProjectDevHDR] 
(
@Id int,
@ProjectId int,
@OrgId int,
@NoofEquipments int ,
@TransportationSoilAmount decimal(11, 6),
@TransportationSoillocation varchar (100),
@LatitudeSoil decimal (11, 9),
@LongitudeSoil decimal (11, 9),
@ModeTransportDevelpmentId int,
@NoofTransportationsoil int,
@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ProjectDevhdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[ProjectDevHDR] (
				 ProjectId
				 ,OrgId
				 ,NoofEquipments
				 ,TransportationSoilAmount
				 ,TransportationSoillocation
				 ,LatitudeSoil
				 ,LongitudeSoil
				 ,ModeTransportDevelpmentId
				 ,NoofTransportationsoil
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ProjectId
				,@OrgId
				,@NoofEquipments
				,@TransportationSoilAmount
				,@TransportationSoillocation
				,@LatitudeSoil
				,@LongitudeSoil
				,@ModeTransportDevelpmentId
				,@NoofTransportationsoil
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @ProjectDevhdrOUT = @@IDENTITY

		 
				END
		ELSE
		begin
			UPDATE [dbo].[ProjectDevHDR]
			SET  ProjectId=@ProjectId,
			OrgId=@OrgId,NoofEquipments=@NoofEquipments,TransportationSoilAmount=@TransportationSoilAmount,
			TransportationSoillocation=@TransportationSoillocation,LatitudeSoil=@LatitudeSoil,LongitudeSoil=@LongitudeSoil,
			ModeTransportDevelpmentId=@ModeTransportDevelpmentId
				,NoofTransportationsoil = @NoofTransportationsoil
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @ProjectDevhdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectLeakage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectLeakage]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Procedure [dbo].[SP_AddProjectLeakage]
(@Id int,
@ProjectId [int]  ,
@OrgId Int,
	@NoofEquipments int,
	@EquipmentdeviceId  int,
	@EquipmentNameId [int] ,
	@EquipmentNo [varchar](100) ,
	@NoofHoursUsedEquipments varchar(50),
	@FuelUsageDevelopment [decimal](10, 5),
	@TransportationSoilAmount [decimal](11, 6),
	@TransportationSoillocation [varchar](100),
	@LatitudeSoil [decimal](11, 9),
	@LongitudeSoil [decimal](11, 9),
	@ModeTransportDevelpmentId [int],
    @NoofTransportationsoil int,
	@NoofMachineryinuse int,
	@MachineryCurrentlyId int,
	@FuelUsageCurrent [decimal](10, 5),
	@TransplantaionPlantsLocation [varchar](100),
	@LatitudePlant [decimal](11, 9),
	@LongitudePlant [decimal](11, 9),
	@NoofPlantstransported int,
	@ModeoftransportcurrentId int,
	@Nooftransportationscurrent Int,
	@IsActive [bit],
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into ProjectLeakage(
ProjectId,
OrgId,
NoofEquipments,
EquipmentdeviceId,
EquipmentNameId,
EquipmentNo,
NoofHoursUsedEquipments,
FuelUsageDevelopment,
TransportationSoilAmount,
TransportationSoillocation,
LatitudeSoil,
LongitudeSoil,
ModeTransportDevelpmentId,
NoofTransportationsoil,
NoofMachineryinuse,
MachineryCurrentlyId,
FuelUsageCurrent,
TransplantaionPlantsLocation,
LatitudePlant,
LongitudePlant,
NoofPlantstransported,
ModeoftransportcurrentId,
Nooftransportationscurrent,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProjectId,
@OrgId,
@NoofEquipments,
@EquipmentdeviceId,
@EquipmentNameId,
@EquipmentNo,
@NoofHoursUsedEquipments,
@FuelUsageDevelopment,
@TransportationSoilAmount,
@TransportationSoillocation,
@LatitudeSoil,
@LongitudeSoil,
@ModeTransportDevelpmentId,
@NoofTransportationsoil,
@NoofMachineryinuse,
@MachineryCurrentlyId,
@FuelUsageCurrent,
@TransplantaionPlantsLocation,
@LatitudePlant,
@LongitudePlant,
@NoofPlantstransported,
@ModeoftransportcurrentId,
@Nooftransportationscurrent,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update ProjectLeakage Set ProjectId=@ProjectId,OrgId=@OrgId,EquipmentdeviceId=@EquipmentdeviceId,NoofEquipments=@NoofEquipments,
@IsActive=@IsActive where Id=@Id


end
end


GO

-- %% [markdown]
-- # [dbo].[SP_AddProjects]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjects]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddProjects]
(@Id int,
@OrgId Int,
@Name varchar(100),
@Location varchar(255),
@Type Int,
@GPS varchar(255),
@Latitude Varchar(100),
@Longitude Varchar(100),

--@ProjectProponent varchar(100),

@Areaofplantation Decimal (18,3),

@StartDate datetime,
@EndDate datetime,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@UserId Int,
@ProjectOUT int OUTPUT
)
as
begin
If isnull(@Id,0)=0
begin
insert into Project(
OrgId,
Name,
Location,
Type,
GPS,
Latitude,
Longitude,

--ProjectProponent,

Areaofplantation,

StartDate,
EndDate,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate,
UserId
)
values(
@OrgId,
@Name,
@Location,
@Type,
@GPS,
@Latitude,
@Longitude,

--@ProjectProponent,

@Areaofplantation,

@StartDate,
@EndDate,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate,
@UserId
)
set @ProjectOUT = @@IDENTITY
update GeoBoundaries set ProjectId = @ProjectOUT where ProjectId = 10000000
--update Projectusers set ProjectOUTId =@ProjectOUT where ProjectOUTId = 10000000

end
else
begin
update Project Set OrgId=@OrgId,UserId=@UserId, Name=@Name,Location=@Location,Type=@Type,Latitude=@Latitude,Longitude = @Longitude,GPS=@GPS,
Areaofplantation=@Areaofplantation,StartDate=@StartDate,EndDate=@EndDate, 
@IsActive=@IsActive where Id=@Id
set @ProjectOUT = @Id

end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectsAddInfo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectsAddInfo]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddProjectsAddInfo]
(@Id int,
@ProjectId int,
@OrgId Int,
@waterbodyLocation varchar(100),
@Latitude Decimal (11,9),
@Longitude Decimal (11,9),
@waterbodyArea Decimal (8,3),
@waterbodyCapacity Decimal (8,3),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into ProjectAdditionalInfo(
ProjectId,
OrgId,
waterbodyLocation,
Latitude,
Longitude,
waterbodyArea,
waterbodyCapacity,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProjectId,
@OrgId,
@waterbodyLocation,
@Latitude,
@Longitude,
@waterbodyArea,
@waterbodyCapacity,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
 
end
else
begin
update ProjectAdditionalInfo Set ProjectId=@ProjectId,OrgId=@OrgId, waterbodyLocation=@waterbodyLocation,Latitude=@Latitude,
waterbodyArea=@waterbodyArea,
waterbodyCapacity=@waterbodyCapacity,
IsActive=@IsActive where Id=@Id
 

end
end




 
GO

-- %% [markdown]
-- # [dbo].[SP_AddProjectUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProjectUsers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddProjectUsers]
(@Id int,
@ProjectOUTId int,
@OrgId Int,
@UserId Int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ProjectdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
		insert into Projectusers(
                 ProjectOUTId,
                 OrgId,
                 UserId,
				 [IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@ProjectOUTId,
                @OrgId,
                @UserId,
				 ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @ProjectdtlOUT = @@IDENTITY
				--update Projectusers set ProjectOUTId = @ProjectdtlOUT where ProjectOUTId = 10000000

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE Projectusers
			SET  ProjectOUTId = @ProjectOUTId
			 ,OrgId=@OrgId,UserId=@UserId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @ProjectdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Code]
				,[Name]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Code] = @Code
				,[Name] = @Name
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStates]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStates]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_AddStates] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[States] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[States]
			SET  [Code] = @Code
				,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddUsers] 
(  
 @Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber bigint
,@JobTitle VarChar(100)
--,@DeviceNumber VarChar(255)
,@RoleId int
,@OrgId int
,@Flag int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Users] (
				 [UserName]
				,[Password]
				,[FirstName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,JobTitle
				--,DeviceNumber
				,[RoleId]
				,OrgId
				,Flag
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@UserName
				,@Password
				,@FirstName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@JobTitle
			--	,@DeviceNumber
				,@RoleId
				,@OrgId
				,@Flag
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Users]
			SET  
				[UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName	 
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[MobileNumber] = @MobileNumber
				,JobTitle=@JobTitle
				--,DeviceNumber=@DeviceNumber
				,OrgId=@OrgId
				,Flag=@Flag
				,[RoleId] = @RoleId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddwaterbodyGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddwaterbodyGeoBoundaries]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddwaterbodyGeoBoundaries]
(@Id int,
@PolygonId Int,
@Latitude FLOAT,
@Longitude FLOAT,
@seqorder int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime


)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into waterbodyBoundaries(
 PolygonId,
Latitude,
Longitude,
seqorder,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@PolygonId,
 @Latitude,
@Longitude,
@seqorder,
  @IsActive,
  @CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate

)
 
end
else
begin
update waterbodyBoundaries Set PolygonId=@PolygonId, Latitude=@Latitude,Longitude=@Longitude,
IsActive=@IsActive,seqorder=@seqorder,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_CheckExcelFile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckExcelFile]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_CheckExcelFile](@FileName varchar(100))
as
begin
select count (*) as filecount
from ExcelFileHDR where FileName = @FileName
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckOrgmailId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckOrgmailId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_CheckOrgmailId](@mailId varchar(255))
as
begin
   select count(*) Cnt from Organization where Email = @mailId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCityDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCityDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[SP_GetCityDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[City] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCountryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCountryDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[SP_GetCountryDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
	  	,c.Name AS CreatedByUser
		,t.[UpdatedDate]
	 ,u.Name AS UpdatedByUser
	FROM [dbo].[Country] t
	 INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	 INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelBackDetailsByExcelHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelBackDetailsByExcelHDRId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetExcelBackDetailsByExcelHDRId] (@HDRId INT)
AS
BEGIN
	 

	select * from ExcelPLOT where ExcelSheetType='Back'and FileId=@HDRId 
 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExceldata]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExceldata]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetExceldata] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		  ProjectId,
          orgId, 
		[FileName] 
		,PlantName
		,Diameter
		,Height
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].Exceldata
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1  
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelDetailsByExcelHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelDetailsByExcelHDRId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetExcelDetailsByExcelHDRId] (@HDRId INT)
AS
BEGIN
	 

	select * from ExcelPLOT where ExcelSheetType='Front' and  FileId=@HDRId 
 select * from ExcelPLOT where ExcelSheetType='Back' and FileId=@HDRId 

 END
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelDTLbyExcelProjandPlotId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelDTLbyExcelProjandPlotId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetExcelDTLbyExcelProjandPlotId] (@ProjectId INT,@PlotId Int)
AS
BEGIN
	  
	select e.* from ExcelPLOT e inner join ExcelFileHdr h on h.Id=e.FileId  where e.ExcelSheetType='Front' and  h.ProjectId=@ProjectId and h.PlotId=@PlotId 
 select p.SNO as SN,p.BOTANICAL_NAME as BN,p.COMMON_NAME as CN,p.DIAMETER_INCHES as DN,p.HEIGHT_FEETS as HF,
 p.ExcelSheetType as EST,p.PLANT_NAME as PN from ExcelPLOT p inner join ExcelFileHdr f on f.Id=p.FileId where p.ExcelSheetType='Back' and f.ProjectId=@ProjectId and f.PlotId=@PlotId

 END
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelDtlDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetExcelDtlDetails] (@P_Id int)
as
begin
select * from ExcelDetails where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelDtlDetailsById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelDtlDetailsById]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create Procedure [dbo].[SP_GetExcelDtlDetailsById] (@P_Id int)
as
begin
select * from ExcelDetails where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelFilebyprojpltHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelFilebyprojpltHDRId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetExcelFilebyprojpltHDRId] (@ProjectId Int,@plotId Int)
AS
BEGIN
	SELECT 
		 [Id]
		 ,ProjectId
		 ,PlotId
		,FileId
		,FileName
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].ExcelFileHdr
	WHERE ProjectId=ISNULL(@ProjectId, ProjectId)
	and PlotId=ISNULL(@plotId,PlotId)
		AND IsActive = 1 order by CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelFileHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelFileHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetExcelFileHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		 ,ProjectId
		 ,PlotId
		,FileId
		,FileName
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].ExcelFileHdr
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1 order by CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelFileHdrbyprojectId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelFileHdrbyprojectId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetExcelFileHdrbyprojectId] (@P_Id INT,@ProjectId Int,@plotId Int)
AS
BEGIN
	SELECT 
		 [Id]
		 ,ProjectId
		 ,PlotId
		,FileId
		,FileName
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].ExcelFileHdr
	WHERE Id = ISNULL(@P_Id, Id) and ProjectId=ISNULL(@ProjectId, ProjectId)
	and PlotId=ISNULL(@plotId,PlotId)	AND IsActive = 1  order by CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelFrontDetailsByExcelHDRId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelFrontDetailsByExcelHDRId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetExcelFrontDetailsByExcelHDRId] (@HDRId INT)
AS
BEGIN
	 

	select * from ExcelPLOT where ExcelSheetType='Front'and FileId=@HDRId 
 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGeoBoundaryAddinfoDetails_test]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGeoBoundaryAddinfoDetails_test]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetGeoBoundaryAddinfoDetails_test] (@P_PolygonId Int)    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.PolygonId    
  ,t.[Latitude]    
  ,t.[Longitude]  
  ,'['+CAST(t.[Latitude] as varchar(255))+','+CAST(t.[Longitude] as varchar(255))+']' GridLatLng
  ,t.[CreatedByUserId]
  ,t.[CreatedDate]    
  ,t.[UpdatedByUserId]
  ,t.[UpdatedDate]    
  ,t.seqorder
 FROM [dbo].[waterbodyBoundaries] t    
  
 WHERE t.PolygonId = ISNULL(@P_PolygonId, t.PolygonId)    
  AND t.IsActive = 1  ORDER BY t.seqorder ASC;
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGeoBoundaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGeoBoundaryDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE   PROCEDURE [dbo].[SP_GetGeoBoundaryDetails] (@P_ProjectId Int)    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.[ProjectId]    
  ,t.[Latitude]    
  ,t.[Longitude]  
  ,t.seqorder
  ,t.[CreatedByUserId]
  ,t.[CreatedDate]    
  ,t.[UpdatedByUserId]
  ,t.[UpdatedDate]    

 FROM [dbo].[GeoBoundaries] t    
  
 WHERE t.ProjectId = ISNULL(@P_ProjectId, t.ProjectId)    
  AND t.IsActive = 1 ORDER BY t.seqorder Asc
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetGeoBoundaryDetails_Test]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGeoBoundaryDetails_Test]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetGeoBoundaryDetails_Test] (@P_ProjectId Int)    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.[ProjectId]    
  ,t.[Latitude]    
  ,t.[Longitude]  
  ,'['+CAST(t.[Latitude] as varchar(255))+','+CAST(t.[Longitude] as varchar(255))+']' LatLng
  ,t.seqorder
  ,t.[CreatedByUserId]
  ,t.[CreatedDate]    
  ,t.[UpdatedByUserId]
  ,t.[UpdatedDate]    
 FROM [dbo].[GeoBoundaries] t     
 WHERE t.ProjectId = ISNULL(@P_ProjectId, t.ProjectId)    
  AND t.IsActive = 1  ORDER BY t.seqorder Asc 
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridBoundaryDtlByProjectId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridBoundaryDtlByProjectId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE   PROCEDURE [dbo].[SP_GetGridBoundaryDtlByProjectId] (@ProjectId Int)    
AS    
BEGIN    
select t.Latitude,t.Longitude,t.seqorder,t.GridId ,

  '['+CAST(t.[Latitude] as varchar(255))+','+CAST(t.[Longitude] as varchar(255))+']' GridLatLng
from GridGeoBoundaries t

inner join grid g on g.Id = t.GridId  
where g.ProjectId = ISNULL( @ProjectId, g.ProjectId)
 AND t.IsActive = 1 ORDER BY t.seqorder Asc
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGridDetails](@P_Id int)
as
begin 
select  
g.Id,g.Area,g.ProjectId,
g.Name as GridName,
g.Description,
g.GPS,
g.Latitude,
g.Longitude,
--g.Size,
p.Name as ProjectName
from grid g
inner join Project p on p.Id=g.ProjectId
where g.Id=isnull(@P_Id,g.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridDetailsbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridDetailsbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGridDetailsbyOrgId](@P_OrgId int)
as
begin 
select  
g.Id,g.Area,g.ProjectId,
g.Name as GridName,
g.Description,
g.GPS,
--g.Size,
p.Name as ProjectName,
p.Latitude,
p.Longitude
from grid g
inner join Project p on p.Id=g.ProjectId
where p.OrgId=isnull(@P_OrgId,p.OrgId)  
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridDetailsbyprojectId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridDetailsbyprojectId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGridDetailsbyprojectId](@P_ProjectId int)
as
begin 
select  
g.Id,g.Area,g.ProjectId,
g.Name as GridName,
g.Description,
g.GPS,
--g.Size,
p.Name as ProjectName,
p.Latitude,
p.Longitude
from grid g
inner join Project p on p.Id=g.ProjectId
where g.ProjectId=isnull(@P_ProjectId,g.ProjectId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridGeoBoundaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridGeoBoundaryDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create   PROCEDURE [dbo].[SP_GetGridGeoBoundaryDetails] (@P_GridId Int)    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.[GridId]    
  ,t.[Latitude]    
  ,t.[Longitude]  
  
  ,t.[CreatedByUserId]
  ,t.[CreatedDate]    
  ,t.[UpdatedByUserId]
  ,t.[UpdatedDate]    

 FROM [dbo].[GridGeoBoundaries] t    
  
 WHERE t.GridId = ISNULL(@P_GridId, t.GridId)    
  AND t.IsActive = 1 
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridGeoBoundaryDetails_test]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridGeoBoundaryDetails_test]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetGridGeoBoundaryDetails_test] (@P_GridId Int)    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.[GridId]    
  ,t.[Latitude]    
  ,t.[Longitude]  
  ,'['+CAST(t.[Latitude] as varchar(255))+','+CAST(t.[Longitude] as varchar(255))+']' GridLatLng
  ,t.[CreatedByUserId]
  ,t.[CreatedDate]    
  ,t.[UpdatedByUserId]
  ,t.[UpdatedDate]    
  ,t.seqorder
 FROM [dbo].[GridGeoBoundaries] t    
  
 WHERE t.GridId = ISNULL(@P_GridId, t.GridId)    
  AND t.IsActive = 1  ORDER BY t.seqorder ASC;
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridPolygonBoundaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridPolygonBoundaryDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create   PROCEDURE [dbo].[SP_GetGridPolygonBoundaryDetails] (@P_ProjectId Int)    
AS    
BEGIN    
 SELECT * FROM [dbo].GeoBoundaries g   
  
 WHERE g.ProjectId = ISNULL(@P_ProjectId, g.ProjectId)    
  AND g.IsActive = 1 
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetGridPolygonDetailsbyprojectId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGridPolygonDetailsbyprojectId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetGridPolygonDetailsbyprojectId](@P_ProjectId int,@P_Name varchar(100))
as
begin 
select  
g.Id,g.Area,g.ProjectId,
g.Name as GridName,
g.Description,
g.GPS,
--g.Size,
p.Name as ProjectName,
p.Latitude,
p.Longitude,
gb.Latitude as LatitudeBoundaries,
gb.Longitude as LongitudeBoundaries
from grid g
inner join Project p on p.Id=g.ProjectId
inner join GeoBoundaries gb on gb.ProjectId=g.ProjectId
where g.ProjectId=isnull(@P_ProjectId,g.ProjectId) and  g.[Name]=@P_Name
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogbookHdrbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogbookHdrbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE PROCEDURE [dbo].[SP_GetLogbookHdrbyOrgId] (@P_OrgId INT)
AS
BEGIN
	SELECT 
	L.Id,
	L.OrgId,
		 L.ProjectId,
		 P.Name as ProjectName,
		 L.forestdistance,
		 L.CreatedDate,
		 L.SoilComposition
	FROM LogbookHdr L
	INNER JOIN  Project P on P.Id=L.ProjectId
	--Inner Join grid g on g.ProjectId=L.ProjectId
	WHERE P.OrgId=isnull(@P_OrgId,p.OrgId)   
		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogbookHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogbookHdrDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE PROCEDURE [dbo].[SP_GetLogbookHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
	L.Id,
		 L.ProjectId,
		 P.Name as ProjectName,
		 L.forestdistance,
		 L.faunaevidence,
		 L.faunaphoto
		 ,L.SoilComposition,
		 L.CreatedDate
	FROM LogbookHdr L
	INNER JOIN  Project P on P.Id=L.ProjectId
	--Inner Join grid g on g.ProjectId=L.ProjectId
	WHERE L.Id = ISNULL(@P_Id, L.Id)  
		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogGridPolygonBoundaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogGridPolygonBoundaryDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 

CREATE   PROCEDURE [dbo].[SP_GetLogGridPolygonBoundaryDetails] (@P_ProjectId Int,@P_Name Varchar(100))    
AS    
BEGIN    
 SELECT
 P.Name as ProjectName,
 gb.Latitude as ExternalLatitude,
 gb.Longitude as ExternalLongitude,
 d.GPS,
 ggb.Latitude as gridLatitude
,ggb.Longitude as gridLongitude,
 d.Name as gridname,
 p.Latitude as gpsLatitude,
 p.Longitude as gpsLongitude 
 FROM [dbo].grid d
  inner join GeoBoundaries gb on gb.ProjectId=d.ProjectId
  inner join GridGeoBoundaries ggb on ggb.GridId=d.ProjectId
  inner join Project P on P.Id=d.ProjectId
 WHERE d.ProjectId = ISNULL(@P_ProjectId, d.ProjectId)    
  AND d.Name=@P_Name and d.IsActive = 1 
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtl]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetLookupDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[LookupHdrId]
		,[Code]
		,[Name]
		,[Remarks]
		,[Ord]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrCode]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetLookupDtlByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Code = ISNULL(@P_Code, t.Code) 
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetLookupDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.LookupHdrId = ISNULL(@P_Id, t.LookupHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId] as LookupMstId
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
	,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdr]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetLookupHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		  [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdrDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetLookupHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		  t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id) and  m.ViewYN = 1
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@P_UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMobileUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMobileUsers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetMobileUsers](@P_Id int)
as
begin
select M.Id,OrganizationId,u.FirstName,M.[Name],M.JobTitle,M.Email,M.DeviceNumber,M.IsActive,M.CreatedByUserId,M.CreatedDate,M.UpdatedDate from MobileUsers M
Inner Join Users u on u.OrgId=M.OrganizationId
where M.Id=isnull(@P_Id,M.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrganizationbyBusinessName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrganizationbyBusinessName]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetOrganizationbyBusinessName] (@P_BusinessName varchar(255))
AS
BEGIN
	SELECT 
		count(*) cnt	
	FROM [dbo].[Organization] o
	WHERE o.BusinessName = ISNULL(@P_BusinessName, o.BusinessName)
		AND o.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrganizationDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrganizationDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetOrganizationDetails](@P_Id int)
as
begin
select 
o.[Id]
		,o.[BusinessName]
		,o.[GST]
		,o.[FirstName]
		,o.[LastName]
		,o.[ContactNumber]
		,o.[Email]
		,o.[Typeofbusiness]
		,o.[StreetName]
		,o.[CountryId]
	   ,c.Name as CountryName
		,o.[StateId]
	    ,s.Name as StateName
		,o.[CityId]
	    ,ci.Name as CityName
		,o.[Pin]
		,o.[BuildingName]
		,o.[IsActive]
		,o.[CreatedDate]
		,o.[CreatedByUserId]
		,o.[UpdatedDate]
		,o.[UpdatedByUserId]
	FROM [dbo].[Organization] o
	INNER JOIN dbo.Country c ON c.Id = o.CountryId	
	INNER JOIN dbo.States s ON s.Id = o.StateId
	INNER JOIN dbo.City ci ON ci.Id = o.StateId
where o.Id=isnull(@P_Id,o.Id)
and o.IsActive=1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT1BACKDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT1BACKDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetPLOT1BACKDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT1BACK  
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
    
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT1FRONTDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT1FRONTDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetPLOT1FRONTDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT1FRONT
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT2BACKDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT2BACKDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPLOT2BACKDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT2BACK  
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
     
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT2FRONTDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT2FRONTDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPLOT2FRONTDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT2FRONT
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT3BACKDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT3BACKDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetPLOT3BACKDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT3BACK  
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT3FRONTDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT3FRONTDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPLOT3FRONTDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT3FRONT
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT4FRONTDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT4FRONTDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPLOT4FRONTDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT4FRONT
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetPLOT5FRONTDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPLOT5FRONTDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPLOT5FRONTDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PLOT5FRONT
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotAminitiesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotAminitiesDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPlotAminitiesDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PlotAminities
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
   
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotExcelDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotExcelDtl]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetPlotExcelDtl] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PlotExcelDtl
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotExcelSummaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotExcelSummaryDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetPlotExcelSummaryDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT *  FROM PlotExcelSummary  
	where Id = ISNULL(@P_Id,Id)
		AND  IsActive = 1
END
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectaddinfodetailsbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectaddinfodetailsbyId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE PROCEDURE [dbo].[SP_GetProjectaddinfodetailsbyId] (@P_Id INT)
as
begin
select P.Id,
P.OrgId,
P.ProjectId,
P.Presence,
P.GPS,
P.Latitude,
P.Longitude,
P.Area,
P.capacity,
P.IsActive,
j.Name AS projectname,
P.CreatedByUserId,
P.CreatedDate,
P.UpdatedByUserId,
P.UpdatedDate  from
addinfo P  
  inner join Project j on j.Id =P.ProjectId
  where P.Id =isnull(@P_Id,P.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectaddinfodetailsbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectaddinfodetailsbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetProjectaddinfodetailsbyOrgId] (@P_OrgId INT)
as
begin
select P.Id,
P.OrgId,
P.ProjectId,
P.Presence,
P.GPS,
P.Latitude,
P.Longitude,
P.Area,
P.capacity,
P.IsActive,
j.Name AS projectname,
O.FirstName AS orgname,
P.CreatedByUserId,
P.CreatedDate,
P.UpdatedByUserId,
P.UpdatedDate  from
addinfo P  
 Inner Join Organization O on O.Id = P.OrgId
  inner join Project j on j.Id =P.ProjectId
  where P.OrgId =isnull(@P_OrgId,P.OrgId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectAdditionalInfobyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectAdditionalInfobyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetProjectAdditionalInfobyOrgId](@P_OrgId int)
as
begin 
select  
 *
from ProjectAdditionalInfo g
inner join Project p on p.Id=g.ProjectId
where p.OrgId=isnull(@P_OrgId,p.OrgId)  
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectCurrentDTLByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectCurrentDTLByHdrId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetProjectCurrentDTLByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		t.[Id]
		,t.ProjectCurrentHDRId
		,t.MachineryCurrentlyId
		,t.FuelUsageCurrent
		,ld.[Name] as MachineryName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[ProjectCurrentDTL] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join LookupDtl ld on ld.Id=t.MachineryCurrentlyId
	WHERE t.ProjectCurrentHDRId = ISNULL(@P_Id, t.ProjectCurrentHDRId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectCurrentHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectCurrentHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetProjectCurrentHDR] (@P_OrgId Int,@P_Id INT)
AS
BEGIN
	SELECT 
	p.Id,
	p.ProjectId,
    p.NoofMachinery,
	p.TransplantaionPlantsLocation,
	p.NoofTransportationsforsoil,
	p.LatitudePlant,
	p.LongitudePlant,
	p.NoofPlantstransported,
	p.ModeTransportDevelpmentId,
	p.IsActive,
	p.OrgId,
	  t.[Name] as TransportModeName
	FROM [dbo].[ProjectCurrentHDR] p
	inner join LookupDtl t on t.Id=p.ModeTransportDevelpmentId
	WHERE p.Id = ISNULL(@P_Id, p.Id) and p.OrgId=ISNULL(@P_OrgId,OrgId)
		AND p.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProjectDetails](@P_Id int)
as
begin
select P.Id,
P.Name,
P.OrgId,
P.Location,
P.GPS,
P.Type,
P.Latitude,
P.Longitude,
--P.ProjectProponent,
P.Areaofplantation,
--u.userId as UserId,
s.UserName,
P.UserId,
P.StartDate,
P.EndDate ,
O.BusinessName,
ld.Name as ProjectType   from
 
Project P  
 --inner join Projectusers u on u.ProjectOUTId=P.Id
inner join Users s on s.Id=P.UserId
 Inner Join Organization O on O.Id = P.OrgId
 inner Join LookupDtl ld on ld.Id = P.Type
where P.Id =isnull(@P_Id,P.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectdetailsbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectdetailsbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetProjectdetailsbyOrgId] (@P_OrgId INT)
as
begin
select P.Id,
P.Name,
P.OrgId,
P.Location,
P.GPS,
P.Type,
P.Latitude,
P.Longitude,
--P.ProjectProponent,
P.Areaofplantation,
--u.userId,
P.UserId,
s.UserName,
--P.userId,
P.StartDate,
P.EndDate ,
O.BusinessName,
ld.Name as ProjectType   from

Project P  
 

 Inner Join Organization O on O.Id = P.OrgId
 inner Join LookupDtl ld on ld.Id = P.Type
--inner join Projectusers u on u.ProjectOUTId=P.Id
inner join Users s on s.Id=P.UserId
where P.OrgId =isnull(@P_OrgId,P.OrgId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectDevDTLByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectDevDTLByHdrId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 

CREATE PROCEDURE [dbo].[SP_GetProjectDevDTLByHdrId] (@P_ProjectDevHDRId INT)
AS
BEGIN
	SELECT 
		t.[Id]
		,t.ProjectDevHDRId
		,t.EquipmentNameId
		,t.EquipmentNo
		,t.Noofhoursusedday
		,t.Fuelusage
		,ld.[Name] as EquipmentName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[ProjectDevDTL] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join LookupDtl ld on ld.Id=t.EquipmentNameId
	WHERE t.ProjectDevHDRId = ISNULL(@P_ProjectDevHDRId, t.ProjectDevHDRId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectDevelopmentHDRdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectDevelopmentHDRdetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetProjectDevelopmentHDRdetails] (@P_OrgId Int)
AS
BEGIN
	SELECT 
	p.NoofEquipments,
	p.NoofTransportationsoil,
	p.ProjectId,
	p.TransportationSoilAmount,

p.TransportationSoillocation,
t.Name
	FROM [dbo].[ProjectDevHDR] p
	inner join LookupDtl t on t.Id=p.ModeTransportDevelpmentId
	WHERE p.OrgId=ISNULL(@P_OrgId,OrgId)
		AND p.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectDevHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectDevHDR]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetProjectDevHDR] (@P_OrgId Int,@P_Id INT)
AS
BEGIN
	SELECT 
	p.Id,
	p.ProjectId,
	p.TransportationSoilAmount,
	p.TransportationSoillocation,
	p.ModeTransportDevelpmentId,
	p.NoofEquipments,
	p.NoofTransportationsoil,
	p.IsActive,
	p.LatitudeSoil,
	p.LongitudeSoil,
	p.OrgId,
	  t.[Name] as TransportModeName
	FROM [dbo].[ProjectDevHDR] p
	inner join LookupDtl t on t.Id=p.ModeTransportDevelpmentId
	WHERE p.Id = ISNULL(@P_Id, p.Id) and p.OrgId=ISNULL(@P_OrgId,OrgId)
		AND p.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectdocumentbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectdocumentbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetProjectdocumentbyOrgId] (@P_OrgId INT)
as
begin
select P.DocumentName,
P.DocURL,P.CreatedDate,O.BusinessName,J.Name
from
ProjectDocument P 
Inner Join Organization O on O.Id = P.OrgId
INNER JOIN Project J ON J.Id=P.ProjectId
 where P.OrgId =isnull(@P_OrgId,P.OrgId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectDocuments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectDocuments]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetProjectDocuments](@ProjectId int)
as
begin
select *  from ProjectDocument
 

where ProjectId =isnull(@ProjectId,ProjectId)
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectLeakage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectLeakage]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetProjectLeakage](@ProjectId int)
as
begin
select *  from ProjectLeakage 
 
 

where ProjectId =isnull(@ProjectId,ProjectId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectLeakagebyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectLeakagebyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetProjectLeakagebyOrgId](@P_OrgId int)
as
begin 
select h.OrgId,p.Name as projectname,h.Id,h.ProjectId,h.NoofEquipments,h.TransportationSoilAmount,
h.TransportationSoillocation,c.NoofMachinery,c.TransplantaionPlantsLocation
,c.NoofPlantstransported,c.NoofTransportationsforsoil,h.CreatedDate  from ProjectDevHDR h
--inner join ProjectDevDTL d on d.ProjectDevHDRId=h.Id d.Fuelusage,d.Noofhoursusedday,,d.EquipmentNameId
 inner join ProjectCurrentHDR c on c.ProjectId=h.ProjectId
 inner join Project p on p.OrgId=h.OrgId
where p.OrgId=isnull(@P_OrgId,p.OrgId)  
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectLeakageDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectLeakageDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 create procedure [dbo].[SP_GetProjectLeakageDetails](@P_Id int)
as
begin
select *  from  ProjectdevHDR Ph 
 Inner Join ProjectdevDTL pd on pd.ProjectDevHDRId=ph.Id

-- Inner Join Organization O on O.Id = P.OrgId
-- inner Join LookupDtl ld on ld.Id = Ph.Type
where Ph.Id =isnull(@P_Id,Ph.Id)
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetProjectuserdetailsbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjectuserdetailsbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetProjectuserdetailsbyOrgId] (@P_OrgId Int,@P_ProjectOUTId INT)
as
begin
select P.Id,
P.ProjectOUTId,
P.OrgId,
P.UserId,
  '['+CAST(P.[UserId] as varchar(255))+']' UserIdd,

s.UserName
from
Projectusers P  
 Inner Join Organization O on O.Id = P.OrgId
 inner join Users s on s.Id=P.UserId
WHERE P.ProjectOUTId = ISNULL(@P_ProjectOUTId, P.ProjectOUTId) and P.OrgId=ISNULL(@P_OrgId,P.OrgId)
		AND p.IsActive = 1
 end
GO

-- %% [markdown]
-- # [dbo].[SP_GetProjLeakHDRDTLCurrentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjLeakHDRDTLCurrentDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 create procedure [dbo].[SP_GetProjLeakHDRDTLCurrentDetails](@ProjectId int)
as
begin
        select 
                  Ph.ProjectId
				 ,Ph.OrgId
				 ,Ph.NoofMachinery
				 ,Ph.TransplantaionPlantsLocation
				 ,Ph.LatitudePlant
				,Ph.LongitudePlant
                ,Ph.NoofPlantstransported,
                Ph.ModeTransportDevelpmentId,
                Ph.NoofTransportationsforsoil
				,Ph.[IsActive]
				,Ph.[CreatedDate]
				,Ph.[CreatedByUserId]
				,Ph.[UpdatedDate]
				,Ph.[UpdatedByUserId]  
				,pd.ProjectCurrentHDRId,
                 pd.MachineryCurrentlyId,
                 pd.FuelUsageCurrent
				 
from  ProjectCurrentHDR Ph 
 Inner Join ProjectCurrentDTL pd on pd.ProjectCurrentHDRId=ph.Id

-- Inner Join Organization O on O.Id = P.OrgId
-- inner Join LookupDtl ld on ld.Id = Ph.Type
where Ph.ProjectId =isnull(@ProjectId,Ph.Id)
end
 

GO

-- %% [markdown]
-- # [dbo].[SP_GetProjLeakHDRDTLDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProjLeakHDRDTLDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 CREATE procedure [dbo].[SP_GetProjLeakHDRDTLDetails](@ProjectId int)
as
begin
        select 
                  Ph.ProjectId
				 ,Ph.OrgId
				 ,Ph.NoofEquipments
				 ,Ph.TransportationSoilAmount
				 ,Ph.TransportationSoillocation
				 ,Ph.LatitudeSoil
				 ,Ph.LongitudeSoil
				 ,Ph.ModeTransportDevelpmentId
				 ,Ph.NoofTransportationsoil
				,Ph.[IsActive]
				,Ph.[CreatedDate]
				,Ph.[CreatedByUserId]
				,Ph.[UpdatedDate]
				,Ph.[UpdatedByUserId]  
				,pd. ProjectDevHDRId,
				 pd.EquipmentNameId,
                 pd.EquipmentNo,
                 pd.Noofhoursusedday,
                 pd.Fuelusage
				 
from  ProjectdevHDR Ph 
 Inner Join ProjectdevDTL pd on pd.ProjectDevHDRId=ph.Id

-- Inner Join Organization O on O.Id = P.OrgId
-- inner Join LookupDtl ld on ld.Id = Ph.Type
where Ph.ProjectId =isnull(@ProjectId,Ph.Id)
end
 

GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.ViewYN = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRolesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Roles] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStatesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStatesDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[SP_GetStatesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[States] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTransactionDetailsByDeviceNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTransactionDetailsByDeviceNo]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetTransactionDetailsByDeviceNo](@OrgId Int,@Id int)
as
begin

select * from Organization where Id = @OrgId and IsActive=1

select P.* from Project P
inner join ProjectUsers PU on PU.ProjectId = P.Id
where P.IsActive=1 and P.OrgId=@OrgId and PU.UserId = @Id


select PD.* from ProjectDocument PD
inner join ProjectUsers PU on PU.ProjectId = PD.ProjectId
where PD.IsActive=1 and PD.OrgId=@OrgId and PU.UserId = @Id


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserByDeviceNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserByDeviceNo]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetUserByDeviceNo](@P_DeviceNumber varchar(100))
as
begin
select * from Users where DeviceNumber=@P_DeviceNumber
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsers] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[UserName]
		,[Password]
		,[FirstName]
		,[LastName]
		,[EmailId]
		,[MobileNumber]
		,[OrgId]
		,[RoleId]
		,JobTitle
		,Flag
		--,DeviceNumber
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Users]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END

 
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsersDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,t.OrgId
		,t.JobTitle
		,L.Name as JobName
		--,t.DeviceNumber
		,c.RoleName
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Users] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	Left Join LookupDtl L on L.Id=t.JobTitle
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
 
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersdetailsbyOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersdetailsbyOrgId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsersdetailsbyOrgId] (@P_OrgId INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,t.OrgId
		,t.Flag
		,x.[Name] as Flagname
		,O.BusinessName as OrganizationName
		,t.JobTitle
		,L.Name as JobName
		--,t.DeviceNumber
		,c.RoleName
		,R.Name as RoleN
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Users] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	LEFT join Roles R on R.Id=t.RoleId
	Left Join LookupDtl L on L.Id=t.JobTitle
	left Join Organization O on O.Id=t.OrgId
	left join Flag x on x.NameId=t.Flag
	--inner join LookupDtl z on z.Remarks=t.Flag
	WHERE t.OrgId = ISNULL(@P_OrgId, t.OrgId)
		AND t.ViewYN = 1
END 
 
GO

-- %% [markdown]
-- # [dbo].[SP_InActiveAddinfoDetailsbypolygonId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_InActiveAddinfoDetailsbypolygonId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[SP_InActiveAddinfoDetailsbypolygonId](@P_PolygonId int)
as
begin
update waterbodyBoundaries set IsActive=0 where PolygonId=@P_PolygonId
end
GO

-- %% [markdown]
-- # [dbo].[SP_InActiveGeoBoundariesByprojectId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_InActiveGeoBoundariesByprojectId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_InActiveGeoBoundariesByprojectId](@P_ProjectId int)
as
begin
update GeoBoundaries set IsActive=0 where ProjectId=@P_ProjectId
end
GO

-- %% [markdown]
-- # [dbo].[SP_InActiveGridGeoBoundariesByprojectId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_InActiveGridGeoBoundariesByprojectId]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_InActiveGridGeoBoundariesByprojectId](@P_GridId int)
as
begin
update gridgeoboundaries set IsActive=0 where GridId=@P_GridId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateExcelDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateExcelDetails]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Procedure [dbo].[SP_UpdateExcelDetails]
(@Id int,
@ExcelFileHDRId [int],
@PlantName varchar(100),
@Diameter decimal(4, 2),
@Height [decimal](4, 2),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
update ExcelDetails Set PlantName=@PlantName,Diameter=@Diameter,Height=@Height,
@IsActive=@IsActive where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:09:25 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)   
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNumber,
			u.Password,
			u.OrgId
		FROM Users u 
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END
GO
