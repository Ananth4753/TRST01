-- %% [markdown]
-- # [dbo].[Category]

-- %%
USE [samastafoods]
GO

-- %%
/****** Object:  Table [dbo].[Category]    Script Date: 27-10-2023 15:02:47 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Category](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](100) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
 CONSTRAINT [UQ_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DeliveryPreparationDtl]

-- %%
/****** Object:  Table [dbo].[DeliveryPreparationDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DeliveryPreparationDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UOM] [int] NULL,
	[DeliveryHdrId] [int] NULL,
	[ProductName] [int] NULL,
	[Qty] [int] NULL,
	[TotalAmount] [decimal](18, 3) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DeliveryPreparationHdr]

-- %%
/****** Object:  Table [dbo].[DeliveryPreparationHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DeliveryPreparationHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrderNo] [varchar](20) NULL,
	[PONo] [int] NULL,
	[PartnerName] [int] NOT NULL,
	[PartnerGSTINNo] [varchar](20) NULL,
	[ShippingAddress] [varchar](100) NULL,
	[DeliveryDate] [datetime] NULL,
	[PaymentTerms] [int] NULL,
	[Modeofpayment] [int] NULL,
	[ModeofDelivery] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Dispatch]

-- %%
/****** Object:  Table [dbo].[Dispatch]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dispatch](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[DispatchNumber] [varchar](100) NULL,
	[InvoiceNumber] [int] NULL,
	[OrderNo] [int] NULL,
	[DispatchDate] [date] NULL,
	[DispatchedThrough] [int] NULL,
	[VehicleNumber] [varchar](50) NULL,
	[Qty] [int] NULL,
	[DriverName] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[NoOfCartons] [int] NULL,
	[NoOfBags] [int] NULL,
	[GrossWeight] [decimal](10, 3) NULL,
	[NetWeight] [decimal](10, 3) NULL,
	[CartonSize] [varchar](255) NULL,
	[EwaybillImg] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExeclFileHDR]

-- %%
/****** Object:  Table [dbo].[ExeclFileHDR]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExeclFileHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FileId] [varchar](255) NOT NULL,
	[FileName] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GnrDtl]

-- %%
/****** Object:  Table [dbo].[GnrDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GnrDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[GnrHdrId] [int] NOT NULL,
	[PONumber] [int] NULL,
	[InvoiceNumber] [int] NULL,
	[InvoiceDate] [date] NULL,
	[GRNDate] [date] NULL,
	[ProductId] [int] NULL,
	[ExpectedQuantity] [int] NULL,
	[SupplierReceivedQuantity] [int] NULL,
	[PriceValue] [int] NULL,
	[Pending] [int] NULL,
	[Remarks] [varchar](200) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SKU] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GnrHdr]

-- %%
/****** Object:  Table [dbo].[GnrHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GnrHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PONumber] [int] NULL,
	[InvoiceDate] [date] NULL,
	[GRNDate] [date] NULL,
	[InvoiceNumber] [int] NULL,
	[GRNNumber] [varchar](100) NULL,
	[SupplierName] [varchar](100) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[IndentDtl]

-- %%
/****** Object:  Table [dbo].[IndentDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IndentDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IndentHdrId] [int] NOT NULL,
	[ProductName] [int] NOT NULL,
	[UOM] [int] NULL,
	[RequiredQty] [int] NULL,
	[IndentQty] [int] NULL,
	[PriceRate] [decimal](18, 3) NULL,
	[PriceValue] [decimal](18, 3) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[IndentGeneration]

-- %%
/****** Object:  Table [dbo].[IndentGeneration]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IndentGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [int] NOT NULL,
	[UOM] [int] NULL,
	[RequiredQty] [int] NULL,
	[IndentQty] [int] NULL,
	[IndentStatus] [int] NULL,
	[RequireDate] [datetime] NULL,
	[BillingAddress] [varchar](100) NULL,
	[ShippingAddress] [varchar](100) NULL,
	[PriceRate] [decimal](18, 3) NULL,
	[PriceValue] [decimal](18, 3) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[IndentNo] [varchar](20) NULL,
 CONSTRAINT [PK_IndentGeneration_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[IndentHdr]

-- %%
/****** Object:  Table [dbo].[IndentHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IndentHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IndentNo] [varchar](20) NULL,
	[BusinessName] [int] NOT NULL,
	[IndentStatus] [int] NOT NULL,
	[RequireDate] [datetime] NULL,
	[BillingAddress] [varchar](100) NULL,
	[ShippingAddress] [varchar](100) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InvoiceDtl]

-- %%
/****** Object:  Table [dbo].[InvoiceDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InvoiceDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[InvoiceHdrId] [int] NOT NULL,
	[ProductId] [varchar](100) NULL,
	[RequiredQty] [int] NULL,
	[Uom] [varchar](100) NULL,
	[Price] [int] NULL,
	[Amount] [decimal](18, 3) NULL,
	[TaxableValue] [int] NULL,
	[SGST] [int] NULL,
	[CGST] [int] NULL,
	[IGST] [int] NULL,
	[TotalAmount] [decimal](18, 3) NULL,
	[OtherCharges] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[HsnCode] [varchar](20) NULL,
	[EanCode] [varchar](20) NULL,
	[SKUId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InvoiceHdr]

-- %%
/****** Object:  Table [dbo].[InvoiceHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InvoiceHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BuyersName] [int] NULL,
	[PONumber] [int] NULL,
	[InvoiceNumber] [varchar](100) NULL,
	[Date] [date] NULL,
	[BuyersAddress] [varchar](255) NULL,
	[GSTNumber] [varchar](100) NULL,
	[PaymentTerms] [int] NULL,
	[PaymentMode] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[Freight] [decimal](18, 3) NULL,
	[PackingandForwarding] [decimal](18, 3) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[InwardandQuality]

-- %%
/****** Object:  Table [dbo].[InwardandQuality]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[InwardandQuality](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [int] NULL,
	[RawMaterial] [varchar](50) NULL,
	[Material] [varchar](50) NULL,
	[Texture] [varchar](50) NULL,
	[Colour] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ExcelHdrId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupDtl]

-- %%
/****** Object:  Table [dbo].[LookupDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LookupHdrId] [int] NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Remarks] [varchar](100) NULL,
	[Ord] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupHdr]

-- %%
/****** Object:  Table [dbo].[LookupHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OnBoardPartner]

-- %%
/****** Object:  Table [dbo].[OnBoardPartner]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OnBoardPartner](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BusinessName] [varchar](100) NOT NULL,
	[NatureofBusiness] [varchar](100) NULL,
	[GSTNumber] [varchar](50) NULL,
	[Address] [varchar](100) NULL,
	[Location] [varchar](100) NULL,
	[Pincode] [int] NULL,
	[ContactPersonName] [varchar](50) NULL,
	[Designation] [varchar](50) NULL,
	[PhoneNo] [varchar](20) NULL,
	[EmailId] [varchar](50) NULL,
	[ContactPersonName1] [varchar](50) NULL,
	[Designation1] [varchar](50) NULL,
	[PhoneNo1] [varchar](20) NULL,
	[EmailId1] [varchar](50) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[state] [varchar](50) NULL,
 CONSTRAINT [PK_OnBoardPartner_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OnBoardSuppliers]

-- %%
/****** Object:  Table [dbo].[OnBoardSuppliers]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OnBoardSuppliers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SupplierName] [varchar](100) NOT NULL,
	[UniqueId] [varchar](20) NULL,
	[UniqueIdNo] [varchar](20) NULL,
	[Address] [varchar](100) NULL,
	[Location] [varchar](100) NULL,
	[PinCode] [int] NULL,
	[ContactPersonName] [varchar](50) NULL,
	[Designation] [varchar](50) NULL,
	[PhoneNo] [varchar](20) NULL,
	[EmailId] [varchar](50) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_OnBoardSuppliers_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PackingandQuality]

-- %%
/****** Object:  Table [dbo].[PackingandQuality]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PackingandQuality](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [int] NULL,
	[Parameters] [varchar](255) NULL,
	[Result] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ExcelHdrId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PaymentConfirmation]

-- %%
/****** Object:  Table [dbo].[PaymentConfirmation]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PaymentConfirmation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[InvoiceNo] [int] NULL,
	[PONumber] [int] NULL,
	[PaymentMode] [int] NULL,
	[PaymentTerms] [int] NULL,
	[TransactionID] [varchar](50) NULL,
	[TransactionAmount] [decimal](18, 3) NULL,
	[TransactionDate] [datetime] NULL,
	[TransactionImg] [varchar](255) NULL,
	[Remark] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[AmountDue] [int] NULL,
	[AmountPaid] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PODtl]

-- %%
/****** Object:  Table [dbo].[PODtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PODtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[POHdrId] [int] NOT NULL,
	[ProductName] [int] NOT NULL,
	[UOM] [int] NULL,
	[RequiredQty] [int] NULL,
	[Price] [decimal](18, 3) NULL,
	[Amount] [decimal](18, 3) NULL,
	[TaxableValue] [decimal](18, 3) NULL,
	[SGST] [decimal](18, 3) NULL,
	[CGST] [decimal](18, 3) NULL,
	[IGST] [decimal](18, 3) NULL,
	[TotalAmount] [decimal](18, 3) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[HSN] [varchar](20) NULL,
	[EAN] [varchar](20) NULL,
	[SKUId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[POHdr]

-- %%
/****** Object:  Table [dbo].[POHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[POHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PONo] [varchar](20) NULL,
	[BusinessName] [int] NOT NULL,
	[POStatus] [int] NULL,
	[PartnerGSTINNo] [varchar](20) NULL,
	[ShippingAddress] [varchar](100) NULL,
	[BillingAddress] [varchar](100) NULL,
	[RequireDate] [datetime] NULL,
	[PaymentTerms] [int] NULL,
	[Modeofpayment] [int] NULL,
	[ModeofDelivery] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Remark] [int] NULL,
	[POComments] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PriceList]

-- %%
/****** Object:  Table [dbo].[PriceList]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PriceList](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NULL,
	[ProductPrice] [decimal](18, 0) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProcessandQualityMachine]

-- %%
/****** Object:  Table [dbo].[ProcessandQualityMachine]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProcessandQualityMachine](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [int] NULL,
	[MachineCleaning] [varchar](255) NULL,
	[Date] [datetime] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ExcelHdrId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProcessandQualityManual]

-- %%
/****** Object:  Table [dbo].[ProcessandQualityManual]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProcessandQualityManual](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [int] NULL,
	[ManualCleaning] [varchar](255) NULL,
	[Date] [datetime] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ExcelHdrId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [varchar](255) NULL,
	[Code] [varchar](50) NULL,
	[Category] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[HSN] [varchar](20) NULL,
	[EAN] [varchar](20) NULL,
	[SGST] [decimal](18, 3) NULL,
	[IGST] [decimal](18, 3) NULL,
	[CGST] [decimal](18, 3) NULL,
	[Description] [varchar](1000) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ_ProductName] UNIQUE NONCLUSTERED 
(
	[ProductName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[QRGeneration]

-- %%
/****** Object:  Table [dbo].[QRGeneration]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[QRGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SKU] [int] NOT NULL,
	[ProductName] [int] NULL,
	[ProductCode] [varchar](20) NULL,
	[QRQuantity] [int] NULL,
	[ManufacturingDate] [datetime] NULL,
	[QualityProcessDateStart] [datetime] NULL,
	[QualityProcessDateEnd] [datetime] NULL,
	[RecipeBlendDate] [datetime] NULL,
	[BestBefore] [int] NULL,
	[Source] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UniqueId] [varchar](255) NULL,
	[ReferenceId] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[QualityCheck]

-- %%
/****** Object:  Table [dbo].[QualityCheck]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[QualityCheck](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductName] [int] NULL,
	[Methods] [varchar](50) NULL,
	[Purpose] [varchar](50) NULL,
	[Result] [varchar](100) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ExcelHdrId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RegistrationGenesis]

-- %%
/****** Object:  Table [dbo].[RegistrationGenesis]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RegistrationGenesis](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BusinessName] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[BuildingName] [varchar](100) NOT NULL,
	[City] [varchar](50) NOT NULL,
	[State] [varchar](50) NOT NULL,
	[Pincode] [varchar](50) NOT NULL,
	[Contact] [varchar](100) NOT NULL,
	[Email] [varchar](100) NOT NULL,
	[Captcha] [varchar](50) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SKU]

-- %%
/****** Object:  Table [dbo].[SKU]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SKU](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](15) NULL,
	[SKU] [varchar](50) NULL,
	[Description] [varchar](max) NULL,
	[UOM] [int] NULL,
	[Product] [int] NULL,
	[Size] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[Price] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_SKU] UNIQUE NONCLUSTERED 
(
	[SKU] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[State]

-- %%
/****** Object:  Table [dbo].[State]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[State](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](50) NULL,
	[CGST] [varchar](50) NULL,
	[SGST] [varchar](50) NULL,
	[IGST] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Stock]

-- %%
/****** Object:  Table [dbo].[Stock]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Stock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NOT NULL,
	[AvailableStocks] [int] NULL,
	[TotalStocks] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SKU] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StockTransaction]

-- %%
/****** Object:  Table [dbo].[StockTransaction]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StockTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductId] [int] NOT NULL,
	[TotalStocks] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[status] [int] NULL,
	[SKU] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaxInvoiceDocuments]

-- %%
/****** Object:  Table [dbo].[TaxInvoiceDocuments]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaxInvoiceDocuments](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[InvoiceId] [int] NULL,
	[ImageUrl] [varchar](255) NULL,
	[SNo] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaxInvoiceDtl]

-- %%
/****** Object:  Table [dbo].[TaxInvoiceDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaxInvoiceDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[InvoiceHdrId] [int] NOT NULL,
	[ProductId] [varchar](100) NULL,
	[HsnCode] [varchar](20) NULL,
	[EanCode] [varchar](20) NULL,
	[RequiredQty] [int] NULL,
	[Uom] [varchar](100) NULL,
	[Price] [int] NULL,
	[Amount] [decimal](18, 3) NULL,
	[TaxableValue] [int] NULL,
	[SGST] [int] NULL,
	[CGST] [int] NULL,
	[IGST] [int] NULL,
	[TotalAmount] [decimal](18, 3) NULL,
	[Freight] [decimal](18, 3) NULL,
	[PackingandForwarding] [decimal](18, 3) NULL,
	[OtherCharges] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaxInvoiceHdr]

-- %%
/****** Object:  Table [dbo].[TaxInvoiceHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaxInvoiceHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BuyersName] [int] NULL,
	[PONumber] [int] NULL,
	[InvoiceNumber] [varchar](100) NULL,
	[Date] [date] NULL,
	[BuyersAddress] [varchar](255) NULL,
	[GSTNumber] [varchar](100) NULL,
	[PaymentTerms] [int] NULL,
	[PaymentMode] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UOM]

-- %%
/****** Object:  Table [dbo].[UOM]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UOM](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](10) NULL,
	[Description ] [varchar](50) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_Description] UNIQUE NONCLUSTERED 
(
	[Description ] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UserOfPartner]

-- %%
/****** Object:  Table [dbo].[UserOfPartner]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UserOfPartner](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BusinessName] [int] NOT NULL,
	[UserName ] [varchar](50) NULL,
	[Role] [int] NULL,
	[EmailId] [varchar](50) NULL,
	[MobileNo] [varchar](20) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_UserOfPartner_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](30) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[MiddileName] [varchar](50) NULL,
	[LastName] [varchar](50) NOT NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[RoleId] [int] NULL,
	[OnboardPartnerId] [int] NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__DeliveryP__IsAct__2FEF161B]

-- %%
ALTER TABLE [dbo].[DeliveryPreparationDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__DeliveryP__Creat__30E33A54]

-- %%
ALTER TABLE [dbo].[DeliveryPreparationDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__DeliveryP__IsAct__2B2A60FE]

-- %%
ALTER TABLE [dbo].[DeliveryPreparationHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__DeliveryP__Creat__2C1E8537]

-- %%
ALTER TABLE [dbo].[DeliveryPreparationHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__DeliveryP__Updat__2D12A970]

-- %%
ALTER TABLE [dbo].[DeliveryPreparationHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Dispatch__IsActi__74994623]

-- %%
ALTER TABLE [dbo].[Dispatch] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Dispatch__Create__758D6A5C]

-- %%
ALTER TABLE [dbo].[Dispatch] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Dispatch__Update__76818E95]

-- %%
ALTER TABLE [dbo].[Dispatch] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__GnrDtl__IsActive__7B4643B2]

-- %%
ALTER TABLE [dbo].[GnrDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__GnrDtl__CreatedD__7C3A67EB]

-- %%
ALTER TABLE [dbo].[GnrDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__GnrDtl__UpdatedD__7D2E8C24]

-- %%
ALTER TABLE [dbo].[GnrDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__GnrHdr__IsActive__627A95E8]

-- %%
ALTER TABLE [dbo].[GnrHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__GnrHdr__CreatedD__636EBA21]

-- %%
ALTER TABLE [dbo].[GnrHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__GnrHdr__UpdatedD__6462DE5A]

-- %%
ALTER TABLE [dbo].[GnrHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__IndentDtl__IsAct__6BAEFA67]

-- %%
ALTER TABLE [dbo].[IndentDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__IndentDtl__Creat__6CA31EA0]

-- %%
ALTER TABLE [dbo].[IndentDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__IndentDtl__Updat__6D9742D9]

-- %%
ALTER TABLE [dbo].[IndentDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__IndentGen__IsAct__51EF2864]

-- %%
ALTER TABLE [dbo].[IndentGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__IndentGen__Creat__52E34C9D]

-- %%
ALTER TABLE [dbo].[IndentGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__IndentGen__Updat__53D770D6]

-- %%
ALTER TABLE [dbo].[IndentGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__IndentHdr__IsAct__1881A0DE]

-- %%
ALTER TABLE [dbo].[IndentHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__IndentHdr__Creat__1975C517]

-- %%
ALTER TABLE [dbo].[IndentHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__IndentHdr__Updat__1A69E950]

-- %%
ALTER TABLE [dbo].[IndentHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__InvoiceDt__IsAct__4B973090]

-- %%
ALTER TABLE [dbo].[InvoiceDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__InvoiceDt__Creat__4C8B54C9]

-- %%
ALTER TABLE [dbo].[InvoiceDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__InvoiceDt__Updat__4D7F7902]

-- %%
ALTER TABLE [dbo].[InvoiceDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__InvoiceHd__IsAct__5BCD9859]

-- %%
ALTER TABLE [dbo].[InvoiceHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__InvoiceHd__Creat__5CC1BC92]

-- %%
ALTER TABLE [dbo].[InvoiceHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__InvoiceHd__Updat__5DB5E0CB]

-- %%
ALTER TABLE [dbo].[InvoiceHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Inwardand__IsAct__511AFFBC]

-- %%
ALTER TABLE [dbo].[InwardandQuality] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Inwardand__Creat__520F23F5]

-- %%
ALTER TABLE [dbo].[InwardandQuality] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Inwardand__Updat__5303482E]

-- %%
ALTER TABLE [dbo].[InwardandQuality] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__IsAct__7B264821]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Creat__7C1A6C5A]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Updat__7D0E9093]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__IsAct__70A8B9AE]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Creat__719CDDE7]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Updat__72910220]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__1DB06A4F]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__1EA48E88]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__1F98B2C1]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__208CD6FA]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__2180FB33]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__22751F6C]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__OnBoardPa__IsAct__373B3228]

-- %%
ALTER TABLE [dbo].[OnBoardPartner] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__OnBoardPa__Creat__382F5661]

-- %%
ALTER TABLE [dbo].[OnBoardPartner] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__OnBoardPa__Updat__39237A9A]

-- %%
ALTER TABLE [dbo].[OnBoardPartner] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__OnBoardSu__IsAct__09946309]

-- %%
ALTER TABLE [dbo].[OnBoardSuppliers] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__OnBoardSu__Creat__0A888742]

-- %%
ALTER TABLE [dbo].[OnBoardSuppliers] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__OnBoardSu__Updat__0B7CAB7B]

-- %%
ALTER TABLE [dbo].[OnBoardSuppliers] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Packingan__IsAct__670A40DB]

-- %%
ALTER TABLE [dbo].[PackingandQuality] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Packingan__Creat__67FE6514]

-- %%
ALTER TABLE [dbo].[PackingandQuality] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Packingan__Updat__68F2894D]

-- %%
ALTER TABLE [dbo].[PackingandQuality] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PaymentCo__IsAct__6DEC4894]

-- %%
ALTER TABLE [dbo].[PaymentConfirmation] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PaymentCo__Creat__6EE06CCD]

-- %%
ALTER TABLE [dbo].[PaymentConfirmation] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PaymentCo__Updat__6FD49106]

-- %%
ALTER TABLE [dbo].[PaymentConfirmation] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PODtl__IsActive__3429BB53]

-- %%
ALTER TABLE [dbo].[PODtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PODtl__CreatedDa__351DDF8C]

-- %%
ALTER TABLE [dbo].[PODtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PODtl__UpdatedDa__370627FE]

-- %%
ALTER TABLE [dbo].[PODtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__POHdr__IsActive__6D6238AF]

-- %%
ALTER TABLE [dbo].[POHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__POHdr__CreatedDa__6E565CE8]

-- %%
ALTER TABLE [dbo].[POHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__POHdr__UpdatedDa__6F4A8121]

-- %%
ALTER TABLE [dbo].[POHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__PriceList__IsAct__05A3D694]

-- %%
ALTER TABLE [dbo].[PriceList] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__PriceList__Creat__0697FACD]

-- %%
ALTER TABLE [dbo].[PriceList] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__PriceList__Updat__078C1F06]

-- %%
ALTER TABLE [dbo].[PriceList] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Processan__IsAct__59B045BD]

-- %%
ALTER TABLE [dbo].[ProcessandQualityMachine] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Processan__Creat__5AA469F6]

-- %%
ALTER TABLE [dbo].[ProcessandQualityMachine] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Processan__Updat__5B988E2F]

-- %%
ALTER TABLE [dbo].[ProcessandQualityMachine] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Processan__IsAct__6EAB62A3]

-- %%
ALTER TABLE [dbo].[ProcessandQualityManual] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Processan__Creat__6F9F86DC]

-- %%
ALTER TABLE [dbo].[ProcessandQualityManual] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Processan__Updat__7093AB15]

-- %%
ALTER TABLE [dbo].[ProcessandQualityManual] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Product__IsActiv__00DF2177]

-- %%
ALTER TABLE [dbo].[Product] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Product__Created__01D345B0]

-- %%
ALTER TABLE [dbo].[Product] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Product__Updated__02C769E9]

-- %%
ALTER TABLE [dbo].[Product] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__QRGenerat__IsAct__36670980]

-- %%
ALTER TABLE [dbo].[QRGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__QRGenerat__Creat__375B2DB9]

-- %%
ALTER TABLE [dbo].[QRGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__QRGenerat__Updat__384F51F2]

-- %%
ALTER TABLE [dbo].[QRGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__QualityCh__IsAct__4885B9BB]

-- %%
ALTER TABLE [dbo].[QualityCheck] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__QualityCh__Creat__4979DDF4]

-- %%
ALTER TABLE [dbo].[QualityCheck] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__QualityCh__Updat__4A6E022D]

-- %%
ALTER TABLE [dbo].[QualityCheck] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Registrat__IsAct__12C8C788]

-- %%
ALTER TABLE [dbo].[RegistrationGenesis] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Registrat__Creat__13BCEBC1]

-- %%
ALTER TABLE [dbo].[RegistrationGenesis] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Registrat__Updat__14B10FFA]

-- %%
ALTER TABLE [dbo].[RegistrationGenesis] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__2B0A656D]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__2BFE89A6]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__2CF2ADDF]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__2DE6D218]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__2EDAF651]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__2FCF1A8A]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__123EB7A3]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__1332DBDC]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__14270015]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SKU__IsActive__671F4F74]

-- %%
ALTER TABLE [dbo].[SKU] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SKU__CreatedDate__681373AD]

-- %%
ALTER TABLE [dbo].[SKU] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SKU__UpdatedDate__690797E6]

-- %%
ALTER TABLE [dbo].[SKU] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Stock__IsActive__6BE40491]

-- %%
ALTER TABLE [dbo].[Stock] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Stock__CreatedDa__6CD828CA]

-- %%
ALTER TABLE [dbo].[Stock] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Stock__UpdatedDa__6DCC4D03]

-- %%
ALTER TABLE [dbo].[Stock] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__StockTran__IsAct__756D6ECB]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__StockTran__Creat__76619304]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__StockTran__Updat__7755B73D]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__StockTran__statu__18A19C6F]

-- %%
ALTER TABLE [dbo].[StockTransaction] ADD  DEFAULT ((0)) FOR [status]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__IsAct__1D66518C]

-- %%
ALTER TABLE [dbo].[TaxInvoiceDocuments] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__Creat__2042BE37]

-- %%
ALTER TABLE [dbo].[TaxInvoiceDocuments] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__Updat__1E5A75C5]

-- %%
ALTER TABLE [dbo].[TaxInvoiceDocuments] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__IsAct__0D2FE9C3]

-- %%
ALTER TABLE [dbo].[TaxInvoiceDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__Creat__0E240DFC]

-- %%
ALTER TABLE [dbo].[TaxInvoiceDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__Updat__0F183235]

-- %%
ALTER TABLE [dbo].[TaxInvoiceDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__IsAct__01BE3717]

-- %%
ALTER TABLE [dbo].[TaxInvoiceHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__Creat__02B25B50]

-- %%
ALTER TABLE [dbo].[TaxInvoiceHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__TaxInvoic__Updat__03A67F89]

-- %%
ALTER TABLE [dbo].[TaxInvoiceHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__UOM__IsActive__625A9A57]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__UOM__CreatedDate__634EBE90]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__UOM__UpdatedDate__6442E2C9]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__UserOfPar__IsAct__4959E263]

-- %%
ALTER TABLE [dbo].[UserOfPartner] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__UserOfPar__Creat__4A4E069C]

-- %%
ALTER TABLE [dbo].[UserOfPartner] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__UserOfPar__Updat__4B422AD5]

-- %%
ALTER TABLE [dbo].[UserOfPartner] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__60A75C0F]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__619B8048]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__628FA481]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [dbo].[SP_AddCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCategory]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddCategory]
(@Id int,
@Code varchar(50),
@Name varchar(100),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
IF ISNULL (@Id,0)=0
begin
Insert into Category(
Code,
Name,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@Name,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
End
ELSE
Update Category Set Code=@Code,Name=@Name,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' where Id=@Id
END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END




GO

-- %% [markdown]
-- # [dbo].[SP_AddDeliveryDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDeliveryDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddDeliveryDtl] 
(
 @Id int
,@DeliveryHdrId int
,@ProductName Int
,@UOM Int
,@Qty Int
,@TotalAmount Decimal(18,3)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int


)
AS
BEGIN
	

	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[DeliveryPreparationDtl] (
 [DeliveryHdrId] 
,[ProductName] 
,[UOM] 
,[Qty]
,[TotalAmount]
,[IsActive]
,[CreatedDate]
,[CreatedByUserId]

				)
			VALUES (
				 @DeliveryHdrId
				,@ProductName
				,@UOM
				,@Qty
				,@TotalAmount
				
				
                ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				
				
				)
				

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		
	

	END

GO

-- %% [markdown]
-- # [dbo].[SP_AddDeliveryHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDeliveryHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddDeliveryHdr] 
(
 @Id Int,
 @PONo Int,
 @PartnerName Int,
 @PartnerGSTINNo [varchar](20),
 @ShippingAddress [varchar](100),
 @DeliveryDate [datetime],
 @PaymentTerms Int,
 @Modeofpayment Int,
 @ModeofDelivery Int,
 @IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int
,@DeliveryhdrOUT Int OUTPUT

)
AS
BEGIN
	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[DeliveryPreparationHdr] (
			
				[PONo],
				[PartnerName],
	            [PartnerGSTINNo],
	            [ShippingAddress],
	            [DeliveryDate],
	            [PaymentTerms],
	            [Modeofpayment],
	            [ModeofDelivery] 
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			   @PONo,
			    @PartnerName,
	            @PartnerGSTINNo,
	            @ShippingAddress,
	            @DeliveryDate,
	            @PaymentTerms,
	            @Modeofpayment,
	            @ModeofDelivery
			    ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @DeliveryhdrOUT = @@IDENTITY
				declare @DeliverId int
                set @DeliverId  = @@IDENTITY
				declare @GID varchar(255)
                set @GID =('OD'+RIGHT('0000'+CAST(@DeliverId AS VARCHAR(7)),7))
                update [DeliveryPreparationHdr] set OrderNo = @GID where Id=@DeliverId
				END
				
				END
	
GO

-- %% [markdown]
-- # [dbo].[SP_AddDispatch]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDispatch]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddDispatch] 
(
 @Id int
,@InvoiceNumber int
,@OrderNo int
,@DispatchDate date
,@DispatchedThrough int
,@VehicleNumber varchar(50)
,@Qty int
,@NoOfCartons int,
 @NoOfBags int,
@GrossWeight Decimal(10,3),
@NetWeight Decimal(10,3),
@EwaybillImg Varchar(255),
@CartonSize Varchar(255)
,@DriverName  varchar(50)
,@IsActive bit 
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			BEGIN
			INSERT INTO [dbo].[Dispatch] (
				    
				InvoiceNumber
				,OrderNo
				,[DispatchDate]
				,[DispatchedThrough]
				,[VehicleNumber]
				,[Qty]
				,[NoOfCartons]
                 ,NoOfBags
                 ,GrossWeight
                 ,NetWeight
				 ,EwaybillImg
                 ,CartonSize
				,[DriverName]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
 
				 @InvoiceNumber
				,@OrderNo
				,@DispatchDate
				,@DispatchedThrough
				,@VehicleNumber
				,@Qty
				,@NoOfCartons
                 ,@NoOfBags
                 ,@GrossWeight
                 ,@NetWeight
				 ,@EwaybillImg
                 ,@CartonSize
				,@DriverName
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @POId int
                set @POId  = @@IDENTITY
                declare @GID varchar(255)
                set @GID =('DNO'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
                update [Dispatch] set DispatchNumber = @GID where Id=@POId

				declare @ProductId Int 
				--set @ProductId = (select ProductName from PODtl where POHdrId = @OrderNo)
				--update Stock set AvailableStocks = AvailableStocks - @Qty , TotalStocks = TotalStocks - @Qty where ProductId = @ProductId

				END
		ELSE
		begin
			UPDATE [dbo].[Dispatch]
			SET  
				OrderNo = @OrderNo
				,InvoiceNumber = @InvoiceNumber
				,DispatchDate = @DispatchDate
				,DispatchedThrough = @DispatchedThrough
				,VehicleNumber = @VehicleNumber
				,Qty = @Qty
				,EwaybillImg=@EwaybillImg
				,NoOfCartons = @NoOfCartons
				,NoOfBags=@NoOfBags
				,GrossWeight=@GrossWeight
				,NetWeight=@NetWeight
				,CartonSize=@CartonSize
				,DriverName=@DriverName
				,IsActive = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


 

GO

-- %% [markdown]
-- # [dbo].[SP_AddExcelFileHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddExcelFileHDR]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddExcelFileHDR] 
(
 @Id int = NULL
,@FileId varchar(255)
,@FileName varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ExcelFileHDRId int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin

			INSERT INTO [dbo].[ExeclFileHDR] (
				 FileId
				 ,FileName
				,IsActive
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @FileId
				 ,@FileName
				,ISNULL(@IsActive, 1)
				,GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CreatedByUserId
				,GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				)
				set @ExcelFileHDRId=@@IDENTITY
				end
		ELSE
		begin
			UPDATE [dbo].[ExeclFileHDR]
			SET  [FileId] = @FileId
				,[FileName]=@FileName
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @ExcelFileHDRId=@Id
			End
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddGnrDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGnrDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE PROCEDURE [dbo].[SP_AddGnrDtl] 
(
 @Id int
,@GnrHdrId int
,@PONumber int
,@InvoiceNumber int
,@InvoiceDate date
,@GRNDate date
,@ProductId Int
,@SKU Int
,@ExpectedQuantity int
,@SupplierReceivedQuantity int
,@PriceValue int
,@Pending int
,@Remarks varchar(200)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@GnrdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN 
 
			INSERT INTO [dbo].[GnrDtl](
				 [GnrHdrId]
				 ,PONumber
				 ,InvoiceNumber
				 ,InvoiceDate
				 ,GRNDate
				 ,ProductId
				 ,SKU
				,[ExpectedQuantity]
				,[SupplierReceivedQuantity]
				,[PriceValue]
				,[Pending]
				,[Remarks]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (

				 @GnrHdrId
				 ,@PONumber
				 ,@InvoiceNumber
				 ,@InvoiceDate
				 ,@GRNDate
				 ,@ProductId
				 ,@SKU
				,@ExpectedQuantity
				,@SupplierReceivedQuantity
				,@PriceValue
				,@Pending
				,@Remarks
				,ISNULL(@IsActive, 1)
				,@CreatedDate
				,@CreatedByUserId
				,@UpdatedDate
				,@UpdatedByUserId
				)
				set @GnrdtlOUT = @@IDENTITY
			
				update [Stock] set AvailableStocks = AvailableStocks - @SupplierReceivedQuantity where ProductId = @ProductId And SKU = @SKU


				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[GnrDtl]
			SET  [GnrHdrId] =  @GnrHdrId
			     ,PONumber =@PONumber
				 ,InvoiceNumber=@InvoiceNumber 
				 ,InvoiceDate=@InvoiceDate
				 ,GRNDate=@GRNDate
			    ,[ProductId] = @ProductId
				,[SKU] = @SKU
				,[ExpectedQuantity] = @ExpectedQuantity
				,[SupplierReceivedQuantity] = @SupplierReceivedQuantity
				,[PriceValue] = @PriceValue
				,[Pending]=@Pending
				,[Remarks]=@Remarks
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @GnrdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


GO

-- %% [markdown]
-- # [dbo].[SP_AddGnrHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGnrHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddGnrHdr] 
(
 @Id int,
 @PONumber Int
 ,@InvoiceDate date
,@GRNDate date
,@InvoiceNumber Int
,@SupplierName varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@gnrhdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[GnrHdr] (
				 [PONumber]
				 ,InvoiceDate
				  ,GRNDate
				,[InvoiceNumber]
				,SupplierName
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @PONumber
				 ,@InvoiceDate
				,@GRNDate
				,@InvoiceNumber
				,@SupplierName
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @gnrhdrOUT = @@IDENTITY
				declare @POId int
                set @POId  = @@IDENTITY
                declare @GID varchar(255)
                set @GID =('GRN'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
                update [GnrHdr] set GRNNumber = @GID where Id=@POId
			 
				END
		ELSE
		begin
			UPDATE [dbo].[GnrHdr]
			SET  PONumber=@PONumber ,
				InvoiceNumber =@InvoiceNumber
				,SupplierName=@SupplierName
				,InvoiceDate=@InvoiceDate
				,GRNDate=@GRNDate
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @gnrhdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddGRNDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGRNDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE Procedure [dbo].[SP_AddGRNDetails]
(@Id int,
@IndentNumber Varchar(100),
@InvoiceNumber Varchar(100),
@Product Varchar(100),
@QtyIndent Decimal(8,3),
@Supplied Decimal(8,3),
@PriceValue Decimal(12,2),
@Pending Decimal(8,3),
@IsActive [bit],
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage VARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
 insert into [dbo].[GRN](
IndentNumber,
InvoiceNumber,
Product,
QtyIndent,
Supplied,
PriceValue,
Pending ,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId
)
values(
 @IndentNumber, 
  @InvoiceNumber,
  @Product,
  @QtyIndent,
  @Supplied,
  @PriceValue,
  @Pending,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
else
 
update [dbo].[GRN] Set IndentNumber=@IndentNumber,InvoiceNumber=@InvoiceNumber,Product=@Product,QtyIndent=@QtyIndent,Supplied=@Supplied,
  PriceValue=@PriceValue,Pending=@Pending,IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddHdrInvoice]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddHdrInvoice]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
CREATE PROCEDURE [dbo].[SP_AddHdrInvoice] 
(
 @Id int,
 @BuyersName varchar(100) NULL,
 @OrderNumber varchar(100) NULL,
 @Date date,
 @BuyersAddress varchar(255) NULL,
 @GSTNumber varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@InvoicehdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[InvoiceHdr] (
				 BuyersName
				 ,OrderNumber
				  ,[Date]
				,[BuyersAddress]
				,GSTNumber
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @BuyersName
				,@OrderNumber
				,@Date
				,@BuyersAddress
				,@GSTNumber
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @InvoicehdrOUT = @@IDENTITY
				declare @POId int
                set @POId  = @@IDENTITY
                declare @GID varchar(255)
                set @GID =('INO'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
                update [InvoicehdrOUT] set InvoiceNumber = @GID where Id=@POId
			 
				END
		ELSE
		begin
			UPDATE [dbo].[InvoiceHdr]
			SET  BuyersName=@BuyersName ,
				[Date] =@Date
				,BuyersAddress=@BuyersAddress
				,GSTNumber=@GSTNumber
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @InvoicehdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddIndent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddIndent]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddIndent] (
   @Id INT,
  
@ProductName Int,
@UOM Int,
@RequiredQty Int,
@IndentQty Int,
@IndentStatus Int,
@RequireDate Datetime,
@BillingAddress varchar(100),
@ShippingAddress Varchar(100),
@PriceRate Decimal(18,3),
@PriceValue Decimal(18,3),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
 
  )
AS
BEGIN

		IF ISNULL(@Id,0)=0
		begin
      INSERT INTO [dbo].IndentGeneration (
	   
        ProductName,
UOM,
RequiredQty,
IndentQty,
IndentStatus,
RequireDate,
BillingAddress,
ShippingAddress,
PriceRate,
PriceValue,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
        )
      VALUES (
	
        @ProductName,
@UOM,
@RequiredQty,
@IndentQty,
@IndentStatus,
@RequireDate,
@BillingAddress,
@ShippingAddress,
@PriceRate,
@PriceValue,
ISNULL(@IsActive, 1)
,@CreatedByUserId
        ,ISNULL(@CreatedDate, GETDATE())
         ,@UpdatedByUserId
        ,ISNULL(@UpdatedDate, GETDATE())
       
        )
		declare @IndentId varchar(20)

	set @IndentId  = @@IDENTITY
				declare @GID varchar(255)
                set @GID =('I'+RIGHT('0000000'+CAST(@IndentId AS VARCHAR(7)),7))
                update IndentGeneration set IndentNo=@GID where Id=@IndentId
				END
END
		

--




GO

-- %% [markdown]
-- # [dbo].[SP_AddIndentDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddIndentDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddIndentDtl] 
(
 @Id int
,@IndentHdrId int
,@ProductName Int
,@UOM Int
,@RequiredQty Int
,@IndentQty Int
,@PriceRate Decimal(18,3)
,@PriceValue Decimal(18,3)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int

)
AS
BEGIN
	

	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[IndentDtl] (
 [IndentHdrId] 
,[ProductName] 
,[UOM] 
,[RequiredQty]
,[IndentQty]
,[PriceRate]
,[PriceValue]
,[IsActive]
,[CreatedDate]
,[CreatedByUserId]
,[UpdatedDate]
,[UpdatedByUserId]
				)
			VALUES (
				 @IndentHdrId
				 ,@ProductName
				,@UOM
				,@RequiredQty
				,@IndentQty
				,@PriceRate
				,@PriceValue
                ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[IndentDtl]
			SET  [IndentHdrId] = @IndentHdrId
			,[ProductName] = @ProductName
			,[UOM] = @UOM
				,[RequiredQty] = @RequiredQty
				,[IndentQty] = @IndentQty
				,[PriceRate] = @PriceRate
				,[PriceValue] = @PriceValue 
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			
	

	END

GO

-- %% [markdown]
-- # [dbo].[SP_AddIndentHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddIndentHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddIndentHdr] 
(
 @Id int,

 @BusinessName Int,
 @IndentStatus Int,
 @RequireDate Datetime,
 @BillingAddress varchar(100),
 @ShippingAddress Varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@IndenthdrOUT int OUTPUT

)
AS
BEGIN
	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[IndentHdr] (
			
				 [BusinessName]
				,[IndentStatus]
				,[RequireDate]
				,[BillingAddress]
				,[ShippingAddress]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			   
				 @BusinessName
				,@IndentStatus
				,@RequireDate
				,@BillingAddress
				,@ShippingAddress
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @IndenthdrOUT = @@IDENTITY
				declare @IndentId int

	set @IndentId  = @@IDENTITY
				declare @GID varchar(255)
                set @GID =('I'+RIGHT('0000000'+CAST(@IndentId AS VARCHAR(7)),7))
                update [IndentHdr] set IndentNo = @GID where Id=@IndentId
				END
				
				END
	
GO

-- %% [markdown]
-- # [dbo].[SP_AddInvoiceDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddInvoiceDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddInvoiceDtl] 
(
 @Id int
,@InvoiceHdrId int
,@ProductId varchar(100)
,@SKUId Int
,@HsnCode varchar(20)
,@EanCode varchar(20)

,@RequiredQty Int
,@Uom varchar(100)
,@Price int
,@Amount Decimal(18,3)

,@TaxableValue int
,@SGST int
,@CGST int
,@IGST int
,@TotalAmount Decimal(18,3)
,@OtherCharges int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)
AS
BEGIN
	

	
		IF ISNULL(@Id,0)=0
		BEGIN
INSERT INTO [dbo].[InvoiceDtl] (
 [InvoiceHdrId] 
,[ProductId] 
,[SKUId]
,[HsnCode] 
,[EanCode]
,[RequiredQty]
,[Uom]
,[Price]
,[Amount]

,[TaxableValue]
,[SGST]
,[CGST]
,[IGST]
,[TotalAmount]

,[OtherCharges]
,[IsActive]
,[CreatedDate]
,[CreatedByUserId]

				)
			VALUES (
				 @InvoiceHdrId
				,@ProductId
				,@SKUId
				,@HsnCode
				,@EanCode
				,@RequiredQty
				,@UOM
				,@Price
				,@Amount
				
				,@TaxableValue
				,@SGST
				,@CGST
				,@IGST
				,@TotalAmount
				
				,@OtherCharges

                ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				
				
				)
				

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		
	

	END

GO

-- %% [markdown]
-- # [dbo].[SP_AddInvoiceHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddInvoiceHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddInvoiceHdr] 
(
 @Id Int,
 @BuyersName int,
 @PONumber int,
 @InvoiceNumber Varchar(100),
 @Date Datetime,
 @BuyersAddress Varchar(100),
 @GSTNumber Varchar(100),
 @PaymentTerms int NULL,
@PaymentMode int NULL,
 @Freight [decimal](18,3),
 @PackingandForwarding [decimal](18,3),
 @IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int
,@InvoicehdrOUT Int OUTPUT

)
AS
BEGIN
	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[InvoiceHdr] (
				[BuyersName]
				,[PONumber]
				,[InvoiceNumber]
				,[Date]
				,[BuyersAddress]
				,[GSTNumber]
				,[PaymentTerms]
				,[PaymentMode]
				,[Freight]
				,[PackingandForwarding]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @BuyersName
				 ,@PONumber
				,@InvoiceNumber
				,@Date
				,@BuyersAddress
				,@GSTNumber
				,@PaymentTerms
				,@PaymentMode
				,@Freight,
				@PackingandForwarding
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @InvoicehdrOUT = @@IDENTITY
			declare @GID varchar(255)
                set @GID =('I'+RIGHT('0000000'+CAST(@InvoicehdrOUT AS VARCHAR(7)),7))
                update InvoiceHdr set InvoiceNumber=@GID where Id=@InvoicehdrOUT
			 
				END
		ELSE
		begin
			UPDATE [dbo].[InvoiceHdr]
			SET  BuyersName=@BuyersName ,
				PONumber =@PONumber
				,InvoiceNumber=@InvoiceNumber
				,Date=@Date
				,BuyersAddress=@BuyersAddress
				,GSTNumber=@GSTNumber
				,PaymentTerms=@PaymentTerms
				,PaymentMode=@PaymentMode
				,Freight = @Freight,PackingandForwarding=@PackingandForwarding
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @InvoicehdrOUT = @Id
			end
	END 
GO

-- %% [markdown]
-- # [dbo].[SP_AddInwardandQuality]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddInwardandQuality]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddInwardandQuality] 
(
 @Id int = NULL
,@ProductName varchar(255)
,@RawMaterial varchar(50)
,@Material varchar(50)
,@Texture varchar(50)
,@Colour varchar(50)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		declare @PId int
		set @PId = (select Id from Product where ProductName=@ProductName)
			INSERT INTO [dbo].[InwardandQuality] (
				 [ProductName]
				,[RawMaterial]
				,[Material]
				,[Texture]
				,[Colour]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				 @PId
				,@RawMaterial
				,@Material
				,@Texture
				,@Colour
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		begin
			UPDATE [dbo].[InwardandQuality]
			SET  [ProductName] = @ProductName
				,[RawMaterial] = @RawMaterial
				,[Material] = @Material
				,[Texture] = @Texture
				
				,[Colour] = @Colour
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO







create PROCEDURE [dbo].[SP_AddLookupDtl] 
(
 @Id int
,@LookupHdrId int
,@Code varchar(50)
,@Name varchar(100)
,@Remarks varchar(100)
,@Ord int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookupdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupDtl] (
				 [LookupHdrId]
				,[Code]
				,[Name]
				,[Remarks]
				,[Ord]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @LookupHdrId
				,@Code
				,@Name
				,@Remarks
				,@Ord
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookupdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[LookupDtl]
			SET  [LookupHdrId] = @LookupHdrId
			,[Code] = @Code
				,[Name] = @Name
				,[Remarks] = @Remarks
				,[Ord] = @Ord
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookupdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddLookupHdr] 
(
 @Id int,
 @Code Varchar(50)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookuphdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupHdr] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookuphdrOUT = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[LookupHdr]
			SET  Code=@Code,
				[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookuphdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddOnBoardPartner]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOnBoardPartner]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddOnBoardPartner] 
(
 @Id int
,@BusinessName varchar(100)
,@NatureofBusiness varchar(100)
,@GSTNumber varchar(50)
,@Address varchar(100)
,@Location varchar(100)
,@Pincode Int
,@state varchar(50)
,@ContactPersonName varchar (50)
,@Designation varchar (50)
,@PhoneNo varchar (20)
,@EmailId varchar (50)
,@ContactPersonName1 varchar (50)
,@Designation1 varchar (50)
,@PhoneNo1 varchar (20)
,@EmailId1 varchar (50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[OnBoardPartner] (
			
	[BusinessName],
	[NatureofBusiness],
	[GSTNumber],
	[Address],
	[Location],
	[Pincode],
	[state],
	[ContactPersonName],
	[Designation],
	[PhoneNo],
	[EmailId],
	[ContactPersonName1],
	[Designation1],
	[PhoneNo1],
	[EmailId1],
	[IsActive],
	[CreatedDate],
	[CreatedByUserId],
	[UpdatedDate],
	[UpdatedByUserId]
				)
			VALUES (
 @BusinessName
,@NatureofBusiness
,@GSTNumber
,@Address
,@Location
,@Pincode
,@state
,@ContactPersonName
,@Designation
,@PhoneNo
,@EmailId 
,@ContactPersonName1
,@Designation1
,@PhoneNo1
,@EmailId1
,ISNULL(@IsActive, 1)
,ISNULL(@CreatedDate, GETDATE())
,@CreatedByUserId
,ISNULL(@UpdatedDate, GETDATE())
,@UpdatedByUserId
				)
				
				
				End
		ELSE
			UPDATE [dbo].[OnBoardPartner]
			SET   
				[BusinessName] = @BusinessName,
	[NatureofBusiness] = @NatureofBusiness,
	[GSTNumber] = @GSTNumber,
	[Address] = @Address,
	[Location] = @Location,
	[Pincode] = @Pincode,
	[state]=@state,
	[ContactPersonName] = @ContactPersonName,
	[Designation] = @Designation,
	[PhoneNo] = @PhoneNo,
	[EmailId] = @EmailId,
	[ContactPersonName1] = @ContactPersonName1,
	[Designation1] = @Designation1,
	[PhoneNo1] = @PhoneNo1,
	[EmailId1] = @EmailId1,
				 [IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id 
		IF	@IsActive = 0
		Update Users set ViewYN = 0 where OnboardPartnerId = @Id 
		ELSE  Update Users set ViewYN = 1 where OnboardPartnerId = @Id 
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
  select * from Users
GO

-- %% [markdown]
-- # [dbo].[SP_AddOnBoardSupplier]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOnBoardSupplier]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_AddOnBoardSupplier] 
(
 @Id int
,@SupplierName varchar(100)
,@UniqueId varchar(20)
,@UniqueIdNo varchar(20)
,@Address varchar(100)
,@Location varchar(100)
,@Pincode Int
,@ContactPersonName varchar (50)
,@Designation varchar (50)
,@PhoneNo varchar (20)
,@EmailId varchar (50)

,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[OnBoardSuppliers] (
			
	[SupplierName],
	[UniqueId],
	[UniqueIdNo],
	[Address],
	[Location],
	[Pincode],
	[ContactPersonName],
	[Designation],
	[PhoneNo],
	[EmailId],
	[IsActive],
	[CreatedDate],
	[CreatedByUserId],
	[UpdatedDate],
	[UpdatedByUserId]
				)
			VALUES (
 @SupplierName
,@UniqueId
,@UniqueIdNo
,@Address
,@Location
,@Pincode
,@ContactPersonName
,@Designation
,@PhoneNo
,@EmailId 

,ISNULL(@IsActive, 1)
,ISNULL(@CreatedDate, GETDATE())
,@CreatedByUserId
,ISNULL(@UpdatedDate, GETDATE())
,@UpdatedByUserId
				)
				
				
				End
		ELSE
			UPDATE [dbo].[OnBoardSuppliers]
			SET   
				[SupplierName] = @SupplierName,
	[UniqueId] = @UniqueId,
	[UniqueIdNo] = @UniqueIdNo,
	[Address] = @Address,
	[Location] = @Location,
	[Pincode] = @Pincode,
	[ContactPersonName] = @ContactPersonName,
	[Designation] = @Designation,
	[PhoneNo] = @PhoneNo,
	[EmailId] = @EmailId,
	
				 [IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPackingandQuality]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPackingandQuality]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPackingandQuality] 
(
 @Id int = NULL
,@ProductName Int
,@Parameters varchar(255)
,@Result varchar(255)
,@ExcelHdrId Int

,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0

		begin
		declare @PId int
		set @PId = (select Id from Product where ProductName=@ProductName)
			INSERT INTO [dbo].[PackingandQuality] (
				 [ProductName]
				,[Parameters]
				,[Result]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				 @PId
				,@Parameters
				,@Result
				
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
			UPDATE [dbo].[PackingandQuality]
			SET  [ProductName] = @ProductName
				,[Parameters] = @Parameters
				,[Result] = @Result
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END



GO

-- %% [markdown]
-- # [dbo].[SP_AddPayment]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPayment]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPayment] 
(
 @Id int,
 @InvoiceNo Int,
 @PONumber Int
 ,@PaymentMode Int
 ,@PaymentTerms Int
,@TransactionID varchar(50)
,@TransactionAmount Decimal(18,3)
,@TransactionDate Datetime
,@TransactionImg Varchar(255)
,@Remark Varchar(255)
,@AmountDue int
,@AmountPaid int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[PaymentConfirmation] (
				 [InvoiceNo]
				,[PONumber]
				,[PaymentMode]
				,[PaymentTerms]
				,[TransactionID]
				,[TransactionAmount]
				,[TransactionDate]
				,[TransactionImg]
				,AmountDue
                ,AmountPaid 
				,[Remark]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				 @InvoiceNo
				,@PONumber
				,@PaymentMode
				,@PaymentTerms
				,@TransactionID
				,@TransactionAmount
				,@TransactionDate
				,@TransactionImg
				,@AmountDue - @AmountPaid 
                ,@AmountPaid 
				,@Remark
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
		ELSE
			UPDATE [dbo].[PaymentConfirmation]
			SET  [InvoiceNo] = @InvoiceNo
				,[PONumber] =  @PONumber
				,[PaymentMode] = @PaymentMode
				,[PaymentTerms] = @PaymentTerms
				,[TransactionID] = @TransactionID
                ,[TransactionAmount] = @TransactionAmount
				,[TransactionDate] = @TransactionDate
				,[TransactionImg] = @TransactionImg
				,[AmountPaid]=@AmountPaid
				,[AmountDue]=AmountDue-@AmountPaid	
				
				,[Remark] = @Remark
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPODtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPODtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPODtl] 
(
 @Id int
,@POHdrId int
,@ProductName Int
,@UOM Int
,@RequiredQty Int
,@Price Decimal(18,3)
,@Amount Decimal(18,3)
,@HSN varchar(20)
,@EAN varchar(20)
,@SKUId Int
,@TaxableValue Decimal(18,3)
,@SGST Decimal(18,3)
,@CGST Decimal(18,3)
,@IGST Decimal(18,3)
,@TotalAmount Decimal(18,3)

,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int

)
AS
BEGIN
	

	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[PODtl] (
 [POHdrId] 
,[ProductName] 
,[UOM] 
,[RequiredQty]
,[Price]
,[Amount]
,[HSN]
,[EAN]
,[SKUId]
,[TaxableValue]
,[SGST]
,[CGST]
,[IGST]
,[TotalAmount]

,[IsActive]
,[CreatedDate]
,[CreatedByUserId]
,[UpdatedDate]
,[UpdatedByUserId]
				)
			VALUES (
				 @POHdrId
				,@ProductName
				,@UOM
				,@RequiredQty
				,@Price
				,@Amount
			,@HSN,@EAN,@SKUId
				,@TaxableValue
				,@SGST
				,@CGST
				,@IGST
				,@TotalAmount
				
                ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[PODtl]
			SET  [POHdrId] = @POHdrId
			,[ProductName] = @ProductName
			,[UOM] = @UOM
				,[RequiredQty] = @RequiredQty
				,[Price] = @Price
                ,[Amount] = @Amount
				,[HSN] = @HSN,[EAN] = @EAN ,[SKUId] = @SKUId
				,[TaxableValue] = @TaxableValue
				,[SGST] = @SGST
                ,[CGST] = @CGST
				,[IGST] = @IGST
                ,[TotalAmount] = @TotalAmount
                
                ,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			
	

	END




GO

-- %% [markdown]
-- # [dbo].[SP_AddPOHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPOHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPOHdr] 
(
 @Id Int,
 @BusinessName Int,
 @PartnerGSTINNo Varchar(20),
 @ShippingAddress Varchar(100),
 @BillingAddress Varchar(100),
 @RequireDate Datetime,
 @POStatus Int,
 @PaymentTerms Int,
 @Modeofpayment Int,
 @ModeofDelivery Int,
 @Remark Int,
 @POComments Varchar(255),
 @IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int
,@POhdrOUT Int OUTPUT

)
AS
BEGIN
	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[POHdr] (
			     [BusinessName]
				,[PartnerGSTINNo]
				,[ShippingAddress]
				,[BillingAddress]
				,[RequireDate]
				,[POStatus]
				,[PaymentTerms]
				,[Modeofpayment]
				,[ModeofDelivery]
			,[Remark]
			,[POComments]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			     @BusinessName
				,@PartnerGSTINNo
				,@ShippingAddress
				,@BillingAddress
				,@RequireDate
				,@POStatus
				,@PaymentTerms
				,@Modeofpayment
				,@ModeofDelivery
		,@Remark
		,@POComments
                ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @POhdrOUT = @@IDENTITY
				declare @POId int
                set @POId  = @@IDENTITY
				declare @GID varchar(255)
                set @GID =('PO'+RIGHT('00000'+CAST(@POId AS VARCHAR(7)),7))
                update [POHdr] set PONo = @GID,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 
				
				where Id=@POId 


				END

					ELSE
		begin
			UPDATE [dbo].[POHdr]
			SET  [BusinessName]=@BusinessName,
				[PartnerGSTINNo] = @PartnerGSTINNo,
				ShippingAddress=@ShippingAddress,
				BillingAddress=@BillingAddress,
				RequireDate=@RequireDate,
				POStatus = @POStatus,
				PaymentTerms=@PaymentTerms,
				Modeofpayment = @Modeofpayment,
				ModeofDelivery = @ModeofDelivery,
				Remark = @Remark,
				POComments = @POComments,
				[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @POhdrOUT = @Id
			end
			    END




	


	

GO

-- %% [markdown]
-- # [dbo].[SP_AddPriceList]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPriceList]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE Procedure [dbo].[SP_AddPriceList]
(@Id int,
@ProductId Int,
@ProductPrice Decimal,
@StartDate datetime,
@EndDate datetime,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime

)
as
begin
If isnull(@Id,0)=0
begin
insert into PriceList(
ProductId ,
ProductPrice ,
StartDate,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProductId ,
@ProductPrice ,
@StartDate,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
    begin
    --update PriceList Set ProductId=@ProductId,ProductPrice=@ProductPrice,
    --PriceCategory='Regular',StartDate=@StartDate,EndDate=@EndDate,@IsActive=@IsActive 
    --where Id=@Id

    update PriceList Set EndDate=@EndDate
    where Id=@Id
    insert into PriceList(
ProductId ,
ProductPrice ,
StartDate,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ProductId ,
@ProductPrice ,
@StartDate,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
    end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddProcessandQualityMachine]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProcessandQualityMachine]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddProcessandQualityMachine] 
(
 @Id int = NULL
,@ProductName varchar(255)
,@MachineCleaning varchar(255)
,@Date Datetime
,@ExcelHdrId Int

,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		declare @PId int
		set @PId = (select Id from Product where ProductName=@ProductName)
			INSERT INTO [dbo].[ProcessandQualityMachine] (
				 [ProductName]
				,[MachineCleaning]
				,[Date]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				@PId
				,@MachineCleaning
				,@Date
				,@ExcelHdrId
				
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
			UPDATE [dbo].[ProcessandQualityMachine]
			SET  [ProductName] = @ProductName
				,[MachineCleaning] = @MachineCleaning
				,[Date] = @Date
				,[ExcelHdrId] = @ExcelHdrId
				
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END



GO

-- %% [markdown]
-- # [dbo].[SP_AddProcessandQualityManual]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProcessandQualityManual]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddProcessandQualityManual] 
(
 @Id int = NULL
,@ProductName varchar(255)
,@ManualCleaning varchar(255)
,@Date Datetime
,@ExcelHdrId Int

,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		declare @PId int
		set @PId = (select Id from Product where ProductName=@ProductName)
			INSERT INTO [dbo].[ProcessandQualityManual] (
				 [ProductName]
				,[ManualCleaning]
				,[Date]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				 @PId
				,@ManualCleaning
				,@Date
				,@ExcelHdrId
				
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
			UPDATE [dbo].[ProcessandQualityManual]
			SET  [ProductName] = @ProductName
				,[ManualCleaning] = @ManualCleaning
				,[Date] = @Date
				,[ExcelHdrId] = @ExcelHdrId
				
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END



GO

-- %% [markdown]
-- # [dbo].[SP_AddProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProduct]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddProduct] 
(
 @Id int
,@Code  varchar(50)
,@ProductName varchar(50)
,@Category int
,@HSN varchar(20)
,@EAN varchar(20)
,@CGST Decimal(18,3)
,@IGST Decimal(18,3)
,@SGST Decimal(18,3)
,@Description Varchar(1000)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[Product] (
				 [Code]
				,[ProductName]
				,[Category]
				,[HSN]
				,[EAN]
				,[CGST]
				,[IGST]
				,[SGST]
				,[Description]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@ProductName
				,@Category
				,@HSN
				,@EAN
				,@CGST
				,@IGST
				,@SGST
				,@Description
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				
				End
		ELSE
			UPDATE [dbo].[Product]
			SET  
					[Code] = @Code
				 ,[ProductName] = @ProductName
				 ,[Category]=@Category
				 ,[HSN] = @HSN
				 ,[EAN] = @EAN
				  ,[CGST] = @CGST
				 ,[IGST] = @IGST
				  ,[SGST] = @SGST
				  ,[Description]=@Description
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddQRGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddQRGeneration]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddQRGeneration] 
(
 @Id int
,@SKU Int
,@ProductName Int
,@ProductCode Varchar(20)
,@QRQuantity Int
,@ManufacturingDate Datetime
,@QualityProcessDateStart datetime
,@QualityProcessDateEnd datetime
,@RecipeBlendDate Datetime
,@BestBefore  Int
,@Source Varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@QROutId Int output
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[QRGeneration] (
				 [SKU]
				,[ProductName]
				,[ProductCode]
				,[QRQuantity]
				,[ManufacturingDate]
				,[QualityProcessDateStart]
				,[QualityProcessDateEnd]
				,[RecipeBlendDate]
				,[BestBefore]
				,[Source]
				,[IsActive]
                ,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@SKU
				,@ProductName
				,@ProductCode
				,@QRQuantity
				,@ManufacturingDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@QualityProcessDateStart AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@QualityProcessDateEnd AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@RecipeBlendDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@BestBefore
				,@Source
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
			set @QROutId = @@Identity
			 --declare @RID varchar(255)
            --set @RID =('QR'+RIGHT('00000'+CAST(@QROutId AS VARCHAR(7)),7))
			 DECLARE @guid uniqueidentifier = NEWID();	
             update [QRGeneration] set ReferenceId = @guid where Id=@QROutId

		   		End
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


GO

-- %% [markdown]
-- # [dbo].[SP_AddQualityCheck]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddQualityCheck]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddQualityCheck] 
(
 @Id int = NULL
,@ProductName varchar(255)
,@Methods varchar(50)
,@Purpose varchar(50)
,@Result varchar(100)
,@ExcelHdrId Int
,@IsActive Bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
		declare @PId int
		set @PId = (select Id from Product where ProductName=@ProductName)
			INSERT INTO [dbo].[QualityCheck] (
				 [ProductName]
				,[Methods]
				,[Purpose]
				,[Result]
				,[ExcelHdrId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				
				)
			VALUES (
				 @PId
				,@Methods
				,@Purpose
				,@Result
				,@ExcelHdrId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				
				)
				end
		ELSE
		
			UPDATE [dbo].[QualityCheck]
			SET  [ProductName] = @ProductName
				,[Methods] = @Methods
				,[Purpose] = @Purpose
				,[Result] = @Result
				,[ExcelHdrId] = @ExcelHdrId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END



GO

-- %% [markdown]
-- # [dbo].[SP_AddRegistrationGenesis]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRegistrationGenesis]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddRegistrationGenesis] 
(
 @Id int
,@BusinessName varchar(50)
,@Name varchar(100)
,@BuildingName varchar(100)
,@City varchar(50)
,@State varchar(50)
,@Pincode varchar(50)
,@Contact varchar(100)
,@Email varchar(100)
,@Captcha varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int

)
AS
BEGIN
	
	
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[RegistrationGenesis] (
				 [BusinessName]
				,[Name]
				,[BuildingName]
				,[City]
				,[State]
				,[Pincode]
				,[Contact]
				,[Email]
				,[Captcha]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@BusinessName
				,@Name
				,@BuildingName
				,@City
				,@State
				,@Pincode
				,@Contact
				,@Email
				,@Captcha
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
			
				End
		ELSE
			UPDATE [dbo].[RegistrationGenesis]
			SET  [BusinessName]=@BusinessName
				 ,[Name] = @Name
				 ,[BuildingName] = @BuildingName
				 ,[City] = @City
				 ,[State] = @State
				 ,[Pincode] = @Pincode
				 ,[Contact] = @Contact
				 ,[Email] = @Email
				 ,[Captcha] = @Captcha
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END 

	
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Code]
				,[Name]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Code] = @Code
				,[Name] = @Name
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSKU]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSKU]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddSKU] 
(
 @Id int
,@SKU varchar(50)
,@Code varchar(15)
,@Description varchar(max)
,@UOM int
,@Product int
,@Size int
,@Price int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[SKU] (
			      [SKU]
				 ,[Code]
				 ,[Description]
				 ,[UOM]
				 ,[Product]
			     ,[Size]
				,[Price]
				 ,[IsActive]
				 ,[CreatedDate]
				 ,[CreatedByUserId]
				 ,[UpdatedDate]
				 ,[UpdatedByUserId]
				)
			VALUES (
			     @SKU
				,''
				,@Description
				,@UOM
				,@Product
				,@Size
				,@Price
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @Out int
				set @Out = @@IDENTITY
				update [dbo].[SKU] set Code = UPPER(SUBSTRING(@SKU,1,4))+cast(@Out as varchar(max)) where Id = @Out
				End
		ELSE
			UPDATE [dbo].[SKU]
			SET   [SKU] = @SKU
				 ,[Code] = @Code
				 ,[Description] =@Description
				 ,[UOM] = @UOM
				 ,[Product] =@Product
			     ,[Size] = @Size
				 ,[Price] = @Price
				
				 ,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
				
			WHERE Id = @Id
			set @Out = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddState]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddState]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddState]
(
@Id int
,@Name varchar(50)
,@CGST varchar(50)
,@SGST varchar(50)
,@IGST varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int

)
as begin
	If isnull(@Id,0)=0
	begin
	insert into State(
	              [Name]
				 ,[CGST]
				 ,[SGST]
				 ,[IGST]
				 ,[IsActive]
				 ,[CreatedDate]
				 ,[CreatedByUserId]
				 ,[UpdatedDate]
				 ,[UpdatedByUserId]
	)
	values(
	 @Name
				,@CGST
				,@SGST
				,@IGST
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
	)
	end

else
begin
update [State] Set Name=@Name,SGST= @SGST,CGST=@CGST,IGST=@IGST,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId  WHERE Id = @Id
 
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStock]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddStock]
(@Id int,
 @ProductId int,
 @SKU Int,
 @TotalStocks int,
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as begin
	If isnull(@Id,0)=0
	begin
	insert into Stock(
	SKU,
	ProductId,
	AvailableStocks,
	TotalStocks,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	values(
	@SKU,
	@ProductId,
	@TotalStocks,
	@TotalStocks,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId
	)
	end

else
begin
update Stock Set TotalStocks= TotalStocks+@TotalStocks,AvailableStocks= AvailableStocks+@TotalStocks,
IsActive=@IsActive,
[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',UpdatedByUserId=@UpdatedByUserId where ProductId=@ProductId and SKU = @SKU

insert into StockTransaction (ProductId,SKU,TotalStocks,IsActive,CreatedByUserId,CreatedDate,
UpdatedByUserId,UpdatedDate) 
values(@ProductId,@SKU,@TotalStocks,@IsActive,@CreatedByUserId,@CreatedDate,@UpdatedByUserId,@UpdatedDate)
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddStockTranaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStockTranaction]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddStockTranaction]
(@Id int,
@ProductId int,
 @SKU Int,
 @TotalStocks int,
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as begin
	If isnull(@Id,0)=0
	begin
	insert into StockTransaction(
	ProductId,
	SKU,
	TotalStocks,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	values(
	@ProductId,
	@SKU,
	@TotalStocks,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId
	)
	end

end
GO

-- %% [markdown]
-- # [dbo].[SP_AddTaxInvoiceDocs]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTaxInvoiceDocs]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddTaxInvoiceDocs]
(@Id int,
@InvoiceId Int,
@ImageUrl varchar(255),
@SNo Int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into TaxInvoiceDocuments(
InvoiceId,
ImageUrl,
SNo,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@InvoiceId,
@ImageUrl,
@SNo,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update TaxInvoiceDocuments Set ImageUrl=@ImageUrl,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddTaxInvoiceDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTaxInvoiceDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddTaxInvoiceDtl] 
(
 @Id int
,@InvoiceHdrId int
,@ProductId varchar(100)
,@HsnCode varchar(20)
,@EanCode varchar(20)

,@RequiredQty Int
,@Uom varchar(100)
,@Price int
,@Amount Decimal(18,3)

,@TaxableValue int
,@SGST int
,@CGST int
,@IGST int
,@TotalAmount Decimal(18,3)
,@Freight Decimal(18,3)
,@PackingandForwarding Decimal(18,3)
,@OtherCharges int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
)
AS
BEGIN
	

	
		IF ISNULL(@Id,0)=0
		BEGIN
INSERT INTO [dbo].[TaxInvoiceDtl] (
 [InvoiceHdrId] 
,[ProductId] 
,[HsnCode] 
,[EanCode]
,[RequiredQty]
,[Uom]
,[Price]
,[Amount]

,[TaxableValue]
,[SGST]
,[CGST]
,[IGST]
,[TotalAmount]
,[Freight]
,[PackingandForwarding]
,[OtherCharges]
,[IsActive]
,[CreatedDate]
,[CreatedByUserId]

				)
			VALUES (
				 @InvoiceHdrId
				,@ProductId
				,@HsnCode
				,@EanCode
				,@RequiredQty
				,@UOM
				,@Price
				,@Amount
				
				,@TaxableValue
				,@SGST
				,@CGST
				,@IGST
				,@TotalAmount
				,@Freight
				,@PackingandForwarding
				,@OtherCharges

                ,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				
				
				)
				

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		
	

	END

GO

-- %% [markdown]
-- # [dbo].[SP_AddTaxInvoiceHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTaxInvoiceHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_AddTaxInvoiceHdr] 
(
 @Id Int,
 @BuyersName int,
 @PONumber int,
 @InvoiceNumber Varchar(100),
 @Date Datetime,
 @BuyersAddress Varchar(100),
 @GSTNumber Varchar(100),
 @PaymentTerms int NULL,
 @PaymentMode int NULL,
 @IsActive bit
,@CreatedDate datetime
,@CreatedByUserId Int
,@UpdatedDate datetime
,@UpdatedByUserId Int
,@TaxInvoicehdrOUT Int OUTPUT

)
AS
BEGIN
	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[TaxInvoiceHdr] (
				[BuyersName]
				,[PONumber]
				,[InvoiceNumber]
				,[Date]
				,[BuyersAddress]
				,[GSTNumber]
				,[PaymentTerms]
				,[PaymentMode]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @BuyersName
				 ,@PONumber
				,@InvoiceNumber
				,@Date
				,@BuyersAddress
				,@GSTNumber
				,@PaymentTerms
				,@PaymentMode
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @TaxInvoicehdrOUT = @@IDENTITY
			declare @GID varchar(255)
                set @GID =('I'+RIGHT('0000000'+CAST(@TaxInvoicehdrOUT AS VARCHAR(7)),7))
                update InvoiceHdr set InvoiceNumber=@GID where Id=@TaxInvoicehdrOUT
			 
				END
		ELSE
		begin
			UPDATE [dbo].[TaxInvoiceHdr]
			SET  BuyersName=@BuyersName ,
				PONumber =@PONumber
				,InvoiceNumber=@InvoiceNumber
				,Date=@Date
				,BuyersAddress=@BuyersAddress
				,GSTNumber=@GSTNumber
				,PaymentTerms=@PaymentTerms
				,PaymentMode=@PaymentMode
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @TaxInvoicehdrOUT = @Id
			end
	END 
GO

-- %% [markdown]
-- # [dbo].[SP_AddUOM]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUOM]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddUOM] 
(
 @Id int
,@Code varchar(10)
,@Description varchar(50)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[UOM] (
				 [Code]
				,[Description]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@Code
				,@Description
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
			
				End
		ELSE
			UPDATE [dbo].[UOM]
			SET  [Code]=@Code
				,[Description] = @Description
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUserofPartner]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUserofPartner]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_AddUserofPartner] 
(
 @Id int
,@BusinessName Int
,@UserName varchar(50)
,@Role Int
,@EmailId varchar(50)
,@MobileNo varchar(20)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[UserOfPartner] (
			
	[BusinessName],
	[UserName],
	[Role],
	[EmailId],
	[MobileNo],
	[IsActive],
	[CreatedDate],
	[CreatedByUserId],
	[UpdatedDate],
	[UpdatedByUserId]
				)
			VALUES (
	@BusinessName,
	@UserName,
	@Role,
	@EmailId,
	@MobileNo,
	
ISNULL(@IsActive, 1)
,ISNULL(@CreatedDate, GETDATE())
,@CreatedByUserId
,ISNULL(@UpdatedDate, GETDATE())
,@UpdatedByUserId
				)
				
				
				End
		ELSE
			UPDATE [dbo].[UserOfPartner]
			SET 
			[BusinessName] = @BusinessName,
	[UserName] = @UserName,
	[Role] = @Role,
	[EmailId] = @EmailId,
	[MobileNo] = @MobileNo,
	[IsActive] = ISNULL(@IsActive, 1),
	[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE()),
	[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
 @Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@MiddileName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber bigint
,@RoleId int
,@ViewYN bit
,@OnboardPartnerId Int
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Users] (
				 [UserName]
				,[Password]
				,[FirstName]
				,[MiddileName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,[RoleId]
				,[ViewYN]
				,[OnboardPartnerId]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@UserName
				,@Password
				,@FirstName
				,@MiddileName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@RoleId
				,ISNULL(@ViewYN, 1)
				,@OnboardPartnerId
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Users]
			SET  
				[UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName
				,[MiddileName] = @MiddileName
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[MobileNumber] = @MobileNumber
				,[RoleId] = @RoleId
				,[ViewYN] = @ViewYN
				,[OnboardPartnerId] = @OnboardPartnerId
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_ApprovalPOHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ApprovalPOHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_ApprovalPOHdrDetails]
as begin
SELECT 
		 t.[Id]
		,t.[PONo]
		,u.[BusinessName]
		,t.[BusinessName] as partnerId
		,c.[Name] as POStatus
		,t.[POStatus] as statusId
		,t.[PartnerGSTINNo]
		,t.[ShippingAddress]
		,t.[BillingAddress]
		,t.[RequireDate]
		,k.Name As PaymentTerms
		,t.PaymentTerms as PaymentTermsId
		,l.Name as ModeofDelivery
		,t.ModeofDelivery as ModeofDeliveryId
		,w.Name as Modeofpayment
		,t.Modeofpayment as ModeofpaymentId
        ,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
		,pod.GrandTotal
		
	FROM [dbo].[POHdr] t 
	INNER JOIN LookupDtl c ON c.Id=t.POStatus
	INNER JOIN LookupDtl k ON k.Id=t.PaymentTerms
	INNER JOIN LookupDtl l ON l.Id=t.ModeofDelivery
	INNER JOIN LookupDtl w ON w.Id=t.Modeofpayment
	INNER JOIN OnBoardPartner u ON u.Id=t.BusinessName
	inner Join (SELECT POHdrId, SUM(TaxableValue) as GrandTotal FROM PODtl Group By POHdrId) pod On  pod.POHdrId= t.Id
	AND t.IsActive = 1 and t.POStatus=3
	union
		select 0 [Id]
		,'SPO00001' [PONo]
		,'' [BusinessName]
		,0 partnerId
		,'Accepted' POStatus
		,3 as statusId
		,null [PartnerGSTINNo]
		,null [ShippingAddress]
		,null [BillingAddress]
		,getdate() [RequireDate]
		,'90 Days' As PaymentTerms
		,28 as PaymentTermsId
		,'Transport' as ModeofDelivery
		,6 as ModeofDeliveryId
		,'Online' as Modeofpayment
		,29 as ModeofpaymentId
        ,1 IsActive
		,getdate() [CreatedDate]
		,1 [CreatedByUserId]
		,getdate() [UpdatedDate]
		,1 [UpdatedByUserId]
		,0 GrandTotal
end
GO

-- %% [markdown]
-- # [dbo].[SP_ApprovalPOHdrStatus]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ApprovalPOHdrStatus]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Procedure [dbo].[SP_ApprovalPOHdrStatus](@Id Int,@Status Int )
as begin  
update POHDr set POStatus = @Status where Id = @Id

end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckExcelFile]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckExcelFile]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_CheckExcelFile](@FileName varchar(100))
as
begin
select count (*) as filecount
from [ExeclFileHDR] where FileName = @FileName
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckProductAvailStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckProductAvailStock]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_CheckProductAvailStock](@ProductId int ,@SKU Int) as 
begin
select Id from Stock where ProductId=@ProductId  and SKU = @SKU
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeliveryInvoiceNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeliveryInvoiceNo]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_DeliveryInvoiceNo] (@P_Id INT)
as begin
select t.* from InvoiceHdr t 
left join Dispatch D on D.InvoiceNumber = t.Id  
where t.Id = ISNULL(@P_Id, t.Id)  and D.Id is null
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeliveryNoDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeliveryNoDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_DeliveryNoDetails] (@P_Id INT)
as begin
 
select  *
from DeliveryPreparationHdr t 

where t.Id =ISNULL(@P_Id, t.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeliveryPreparationPO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeliveryPreparationPO]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_DeliveryPreparationPO] (@P_Id INT)
as begin
select t.* from Dispatch t 
left join DeliveryPreparationDtl gh on gh.DeliveryHdrId = t.Id  
where t.Id = ISNULL(@P_Id, t.Id) AND  gh.Id is null
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCategoryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCategoryDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetCategoryDetails](@P_Id int) 
as
begin
select Id,Code,Name,IsActive,CreatedByUserId,CreatedDate ,UpdatedDate from Category where Id=isnull(@P_Id,Id) 
order By   UpdatedDate 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryDtlByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetDeliveryDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT *
		 
	FROM [dbo].[DeliveryPreparationDtl] 
	
	WHERE DeliveryHdrId = ISNULL(@P_Id, DeliveryHdrId)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetDeliveryDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT * FROM [dbo].[DeliveryPreparationDtl] 
	
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetDeliveryHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT d.Id,
	p.PONo,
	d.[OrderNo],
	d.PONo as POId,
	d.[PartnerName] as PartnerId,
	op.BusinessName,
	d.[PartnerGSTINNo],
	d.[ShippingAddress],
	d.[DeliveryDate],
	d.[PaymentTerms],
	ld.Name as PaymentTerm,
	d.ModeofDelivery,
	l.Name as ModeofDeliver,
	lt.Name as Modeofpaymen,
	d.Modeofpayment,
	d.CreatedByUserId,
	d.CreatedDate
    FROM [dbo].[DeliveryPreparationHdr]  d
	Inner Join POHdr p on p.Id = d.PONo
	Inner Join OnBoardPartner op on op.Id = d.PartnerName

	Inner Join LookupDtl ld on ld.Id = d.PaymentTerms
	Inner Join LookupDtl l on l.Id = d.ModeofDelivery
	Inner Join LookupDtl lt on lt.Id = d.Modeofpayment
	WHERE d.Id = ISNULL(@P_Id, d.Id)
		AND d.IsActive = 1
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryInvoice]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryInvoice]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
  
CREATE procedure [dbo].[SP_GetDeliveryInvoice] (@P_Id INT)
as begin
select t.* from InvoiceHdr t
left join Dispatch gh on gh.Id = t.Id

where t.Id = ISNULL(@P_Id, t.Id)   and gh.Id is null
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDeliveryInvoiceNO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDeliveryInvoiceNO]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
  
CREATE procedure [dbo].[SP_GetDeliveryInvoiceNO] (@P_Id INT)
as begin
select t.* from InvoiceHdr t
left join Dispatch d on d.InvoiceNumber=t.Id
where d.Id IS NULL   
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDispatchdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDispatchdetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDispatchdetails] (@P_Id INT)
AS
BEGIN  
	SELECT D.Id,D.NoOfCartons,D.NoOfBags,D.EwaybillImg,D.GrossWeight,D.NetWeight,D.CartonSize,D.IsActive,D.UpdatedDate,D.Qty,ph.PONo,D.OrderNo,D.DispatchDate,ob.BusinessName,ob.Address,
	D.DispatchedThrough,D.VehicleNumber,D.DriverName,D.DispatchNumber,D.CreatedDate,
	D.UpdatedByUserId,D.CreatedByUserId,D.InvoiceNumber as InvoiceId,I.InvoiceNumber,ld.Name as  modeoftransport
	FROM [dbo].[Dispatch] D
	inner join InvoiceHdr I on I.Id=D.InvoiceNumber
    inner join LookupDtl ld on ld.Id=D.DispatchedThrough
	inner join POHdr ph on Ph.Id=D.OrderNo
	inner join OnBoardPartner ob on ob.Id = I.BuyersName 

	WHERE D.Id = ISNULL(@P_Id, D.Id)  
		AND D.IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetDispatchInvoice]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDispatchInvoice]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 

CREATE PROCEDURE [dbo].[SP_GetDispatchInvoice] (@P_Id INT)
AS
BEGIN    
	SELECT t.Id,t.ModeofDelivery as DispatchedThrough  ,t.OrderNo,
	
	k.TotalQty ,ld.Name as deliverymode
	FROM DeliveryPreparationHdr t  
Inner Join LookupDtl ld on ld.Id=t.ModeofDelivery
	Inner Join (select DeliveryHdrId, Sum (Qty) as TotalQty from  DeliveryPreparationDtl group by  DeliveryHdrId) k on k.DeliveryHdrId = t.Id
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetExcelFileHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetExcelFileHDR]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetExcelFileHDR] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,FileId
		,FileName
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].ExeclFileHDR
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1 order by CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGnrDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGnrDtlByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetGnrDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.Id,
		 t.GnrHdrId,
		 t.PONumber,
		 t.InvoiceNumber,
		 cast(t.InvoiceDate as varchar(50)) as InvoiceDate,
		cast(t.GRNDate as varchar(50)) as GRNDate,t.ProductId,
		t.ExpectedQuantity as RequiredQty,
		 t.SupplierReceivedQuantity,
		 t.PriceValue as Price,
		 t.Pending,
		 t.Remarks
		 ,t.IsActive,
		 t.CreatedDate,
		 t.CreatedByUserId,
		 t.UpdatedByUserId,
		 t.UpdatedDate
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[GnrDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.GnrhdrId = ISNULL(@P_Id, t.GnrHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGnrDtlByHdrIndenetNumber]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGnrDtlByHdrIndenetNumber]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
CREATE PROCEDURE [dbo].[SP_GetGnrDtlByHdrIndenetNumber] (@P_PONumber varchar(100))
AS
BEGIN
	SELECT 
		 t.*
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
      FROM [dbo].[GnrDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.PONumber = ISNULL(@P_PONumber, t.PONumber)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGnrDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGnrDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


 
  
CREATE PROCEDURE [dbo].[SP_GetGnrDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT t.Id,
		 t.GnrHdrId,t.PONumber,t.InvoiceNumber,t.ProductId,t.ExpectedQuantity,
		 t.SupplierReceivedQuantity,t.PriceValue,t.Pending,cast(t.GRNDate as varchar(50)) as GRNDate,
		 t.IsActive,t.Remarks,cast(t.InvoiceDate as varchar(50)) as InvoiceDate,
		 t.CreatedDate,t.CreatedByUserId,t.UpdatedByUserId,t.UpdatedDate
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[GnrDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1  
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetgnrHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetgnrHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

  
 
CREATE PROCEDURE [dbo].[SP_GetgnrHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.Id,t.PONumber,t.InvoiceNumber,t.GRNNumber,p.PONo,cast(t.GRNDate as varchar(50)) as GRNDate,t.SupplierName,cast(t.InvoiceDate as varchar(50)) as InvoiceDate,t.IsActive,t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId,iv.InvoiceNumber as InVoiceNo,
		c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[GnrHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join POHdr p on p.Id=t.PONumber
	inner Join InvoiceHdr iv on iv.Id = t.InvoiceNumber
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetgnrHdrDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetgnrHdrDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetgnrHdrDtl] (@UserId INT)
AS
BEGIN

declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
SELECT 
t.Id,t.PONumber,t.InvoiceNumber,t.GRNNumber,p.PONo,cast(t.GRNDate as varchar(50)) as GRNDate,t.SupplierName,cast(t.InvoiceDate as varchar(50)) as InvoiceDate,t.IsActive,t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId,iv.InvoiceNumber as InVoiceNo,
		c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[GnrHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join POHdr p on p.Id=t.PONumber
	inner Join InvoiceHdr iv on iv.Id = t.InvoiceNumber
	WHERE  t.IsActive = 1  AND t.CreatedByUserId =(case when @Role=1 then t.CreatedByUserId else @UserId end)
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGnrIndentDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGnrIndentDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetGnrIndentDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[IndentHdrId] 
		,h.IndentNo
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[IndentQty]
		,t.[PriceRate]
		,t.[PriceValue]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[IndentDtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	 Inner Join IndentHdr h on h.Id=t.IndentHdrId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGNRPOGNRHdrDetail]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGNRPOGNRHdrDetail]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
create PROCEDURE [dbo].[SP_GetGNRPOGNRHdrDetail] (@P_Id INT)
AS
BEGIN
	SELECT  * from POHdr t
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGrnDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGrnDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE procedure [dbo].[SP_GetGrnDtl](@P_Id int)
as 
begin
select G.* from GnrDtl G 
where Id=isnull(@P_Id,Id) AND IsActive = 1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGRNHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGRNHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetGRNHdr] (@P_Id INT)
AS
BEGIN
	SELECT t.Id,t.PONumber as PoId,p.PONo as PONumber ,t.InvoiceNumber,t.GRNNumber,t.GRNDate,t.InvoiceDate,
	t.IsActive,t.CreatedDate,t.CreatedByUserId,t.UpdatedDate,t.UpdatedByUserId FROM GnrHdr t
	inner join POHdr p on p.Id=t.PONumber
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetId] (@P_ProductName varchar(50))
AS
BEGIN
	SELECT 
		count(*) cnt  
	FROM [dbo].[Product] P
	WHERE P.ProductName = ISNULL(@P_ProductName,P.ProductName)
		AND P.IsActive = 1 
END  
GO

-- %% [markdown]
-- # [dbo].[SP_GetIndentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetIndentDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetIndentDetails] (@P_Id INT)
AS
BEGIN
	SELECT IG.Id,
	IG.ProductName as ProductId,
	P.ProductName,
	IG.IndentNo,
	IG.RequiredQty,
	IG.IndentQty,
	IG.RequireDate,
	IG.IndentStatus as IndentStatusId,
	L.Name as IndentStatus,
	IG.BillingAddress,
	IG.UOM as UOMId,
	U.Code as UOM,
	IG.ShippingAddress,
	IG.PriceRate,
	IG.PriceValue,
	IG.IsActive,
	IG.CreatedByUserId,
	IG.CreatedDate,
	IG.UpdatedByUserId,
	IG.UpdatedDate

		
	FROM dbo.IndentGeneration IG
	INNER JOIN Product P On P.Id = IG.ProductName
	INNER JOIN UOM U On U.Id = IG.UOM
	INNER JOIN LookupDtl L On L.Id = IG.IndentStatus
	WHERE IG.Id = ISNULL(@P_Id, IG.Id)
		AND IG.IsActive = 1 order by IG.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetIndentDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetIndentDtlByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetIndentDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[IndentHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[IndentQty]
		,t.[PriceRate]
		,t.[PriceValue]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[IndentDtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	WHERE t.IndentHdrId = ISNULL(@P_Id, t.IndentHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetIndentDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetIndentDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetIndentDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[IndentHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[IndentQty]
		,t.[PriceRate]
		,t.[PriceValue]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[IndentDtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetIndentHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetIndentHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetIndentHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[IndentNo]
		,u.GSTNumber
		,t.[RequireDate]
		,t.[BillingAddress]
		,t.[ShippingAddress]
		,c.[Name] as IndentStatus
		, t.[IndentStatus] as statusId
		,u.[BusinessName]
		,t.[BusinessName] as partnerId
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
	FROM [dbo].[IndentHdr] t
	INNER JOIN LookupDtl c ON c.Id=t.IndentStatus
	INNER JOIN OnBoardPartner u ON u.Id=t.BusinessName
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetIndentNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetIndentNo]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
CREATE PROCEDURE [dbo].[SP_GetIndentNo] (@P_Id INT)
AS
BEGIN
	select * from IndentHdr
	WHERE Id = ISNULL(@P_Id, Id)
		AND  IsActive = 1 order by Id asc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetIndentNumber]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetIndentNumber]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetIndentNumber]  
AS
BEGIN
	SELECT  * from IndentHdr
	WHERE  IsActive = 1 order by IndentNo desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDetailsByOrderNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDetailsByOrderNo]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetInvoiceDetailsByOrderNo] (@P_PONo int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[POHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[Price]
		,t.[Amount]
		,t.[Discount]
		,t.[TaxableValue]
		,t.[SGST]
		,t.[CGST]
		,t.[IGST]
		,t.[TotalAmount]
		,t.[Freight]
		,t.[PackingandForwarding]
		
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[PODtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	inner JOIN DeliveryPreparationHdr d on d.Id=@P_PONo
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDropDownForDispatch]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDropDownForDispatch]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetInvoiceDropDownForDispatch] (@UserId INT)
AS
begin
declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
select IV.* from InvoiceHdr  IV
left Join Dispatch GH On GH.InvoiceNumber = IV.Id

where GH.Id Is null   And IV.CreatedByUserId =(case when @Role=1 then IV.CreatedByUserId else @UserId end)
End

GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDropDownForPayment]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDropDownForPayment]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create PROCEDURE [dbo].[SP_GetInvoiceDropDownForPayment] (@UserId INT)
AS
begin
declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
select IV.* from InvoiceHdr  IV
left Join PaymentConfirmation GH On GH.InvoiceNo = IV.Id

where GH.Id Is null   And IV.CreatedByUserId =(case when @Role=1 then IV.CreatedByUserId else @UserId end)
End

GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetInvoiceDtl] (@P_Id INT)
AS
BEGIN
	SELECT *
	FROM [dbo].[InvoiceDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDtlByHdrCode]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetInvoiceDtlByHdrCode] (@P_Description varchar(100))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[InvoiceHdrId]
		,t.[Description]
		,t.[HSNSAC]
		,t.[RequiredQty]
		,t.[Uom]
		,t.[Price]
		,t.[Amount]
		,t.[Discount]
		,t.[TaxableValue]
		,t.[SGST]
		,t.[CGST]
		,t.[IGST]
		,t.[TotalAmount]
		,t.[Freight]
		,t.[PackingandForwarding]
		,t.[OtherCharges]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[InvoiceDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Description = ISNULL(@P_Description, t.Description) 
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDtlByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetInvoiceDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		*
	FROM [dbo].[InvoiceDtl] 
	
	WHERE InvoiceHdrId = ISNULL(@P_Id, InvoiceHdrId)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetInvoiceDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		  *
	FROM [dbo].[InvoiceDtl] 
	
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


--exec SP_GetInvoiceHdr null
CREATE PROCEDURE [dbo].[SP_GetInvoiceHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
	t.Id,t.BuyersName,
	o.BusinessName,
	t.PONumber,
	po.PONo,
	po.ModeofDelivery,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.Freight,
	 t.PackingandForwarding,
	 t.IsActive,
	 t.Freight,
	 t.PackingandForwarding,
	 t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId
		
	FROM [dbo].[InvoiceHdr] t 
	
	inner join OnBoardPartner o on o.Id=t.BuyersName

	inner join POHdr po on po.Id=t.PONumber
	
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
   
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceHdrByPO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceHdrByPO]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetInvoiceHdrByPO] (@P_PONumber INT)
AS
BEGIN
SELECT 
 t.Id,t.BuyersName,
   o.BusinessName,
	t.PONumber,
	po.PONo,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.IsActive,
	 t.Freight,
	 t.PackingandForwarding,
	 t.CreatedDate,t.CreatedByUserId,
	 t.UpdatedDate,t.UpdatedByUserId
	,c.Name AS CreatedByUser
    ,u.Name AS UpdatedByUser
	FROM [dbo].[InvoiceHdr] t 
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join OnBoardPartner o on o.Id=t.BuyersName
	inner join POHdr po on po.Id=t.PONumber
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE t.PONumber = ISNULL(@P_PONumber, t.PONumber)
AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetInvoiceHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
	 *
	FROM [dbo].[InvoiceHdr] 
	
	WHERE Id = ISNULL(@P_Id,Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceHDRDetailsByPo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceHDRDetailsByPo]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetInvoiceHDRDetailsByPo](@PoId int)
as
begin
	SELECT 
	t.Id,t.BuyersName,
	o.BusinessName,
	t.PONumber,
	po.PONo,
	po.ModeofDelivery,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[InvoiceHdr] t 
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join OnBoardPartner o on o.Id=t.BuyersName

	inner join POHdr po on po.Id=t.PONumber
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE  t.IsActive = 1  AND t.PONumber =@PoId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetInvoiceHdrDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInvoiceHdrDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetInvoiceHdrDtl] (@UserId INT)
AS
BEGIN
declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
	SELECT 
	t.Id,t.BuyersName,
	o.BusinessName,
	t.PONumber,
	po.PONo,
	po.ModeofDelivery,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[InvoiceHdr] t 
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join OnBoardPartner o on o.Id=t.BuyersName

	inner join POHdr po on po.Id=t.PONumber
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE  t.IsActive = 1  AND t.CreatedByUserId =(case when @Role=1 then t.CreatedByUserId else @UserId end)
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetInwardQualityDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetInwardQualityDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetInwardQualityDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT iq.*,p.ProductName ProdName FROM [dbo].[InwardandQuality] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.Id = ISNULL(@P_Id, iq.Id)
		AND iq.IsActive = 1
END
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetLookupDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[LookupHdrId]
		,[Code]
		,[Name]
		,[Remarks]
		,[Ord]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrCode]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrCode] (@P_Code varchar(50))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Code = ISNULL(@P_Code, t.Code)
		AND t.IsActive = 1 
		order By Ord asc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetLookupDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.LookupHdrId = ISNULL(@P_Id, t.LookupHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




create PROCEDURE [dbo].[SP_GetLookupDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId] as LookupMstId
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetLookupHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetLookupHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id) and  m.ViewYN = 1
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@P_UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetNotifications]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetNotifications]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetNotifications]
as
begin
  select 'UOM'+cast(u.Id as varchar(255)) id,null icon,null image,'UOM' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from UOM u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
  union
   select 'Category'+cast(u.Id as varchar(255)) id,null icon,null image,'Category' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from Category u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
  union
     select 'Product'+cast(u.Id as varchar(255)) id,null icon,null image,'Product' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from Product u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
    union
     select 'SKU'+cast(u.Id as varchar(255)) id,null icon,null image,'SKU' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from SKU u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
    union
     select 'OnBoard Partner'+cast(u.Id as varchar(255)) id,null icon,null image,'OnBoardPartner' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from OnBoardPartner u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
    union
     select 'Payment Confirmation'+cast(u.Id as varchar(255)) id,null icon,null image,'Payment Confirmation' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from PaymentConfirmation u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
    union
     select 'GRN'+cast(u.Id as varchar(255)) id,null icon,null image,'GRN' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from GnrHdr u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
    union
     select 'Stock Entry'+cast(u.Id as varchar(255)) id,null icon,null image,'Stock Entry' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from Stock u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
    union
     select 'Invoice Generation'+cast(u.Id as varchar(255)) id,null icon,null image,'Invoice Generation' title,us.FirstName+SPACE(2)+ us.LastName description,
  u.UpdatedDate time,null link,null useRouter,null [read]
  from InvoiceHdr u 
  inner join Users us on us.Id = u.CreatedByUserId
  where cast(u.UpdatedDate as date) = cast(getdate() as date)
  union
  select 'PO Generation'+cast(h.Id as varchar(255)) id,null icon,null image,'PO Generation' title,us.FirstName+SPACE(2)+ us.LastName description,
  h.UpdatedDate time,null link,null useRouter,null [read]
  from POHdr h
  inner join Users us on us.Id = h.CreatedByUserId
  where cast(h.UpdatedDate as date) = cast(getdate() as date)
   union
    select 'Dispatch Details'+cast(d.Id as varchar(255)) id,null icon,null image,'Dispatch Details' title,us.FirstName+SPACE(2)+ us.LastName description,
  d.UpdatedDate time,null link,null useRouter,null [read]
  from Dispatch d
  inner join Users us on us.Id = d.CreatedByUserId
  where cast(d.UpdatedDate as date) = cast(getdate() as date)

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetOnBoardPartner]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOnBoardPartner]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetOnBoardPartner] (@UserId Int)
AS
BEGIN
declare @Idd Int 
 set @Idd = (Select OnboardPartnerId from Users where Id  = @UserId)
 if  Isnull (@Idd,0) = 0
 begin 
	SELECT * FROM [OnBoardPartner]
	order by BusinessName
	
		end

		else 
		begin 
		SELECT * FROM [OnBoardPartner]
	
	WHERE Id = ISNULL(@Idd,Id)
	 
		end
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOnBoardPartnerById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOnBoardPartnerById]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetOnBoardPartnerById] (@P_Id INT)
AS
BEGIN
	SELECT * From OnBoardPartner
	WHERE Id = ISNULL(@P_Id, Id)
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOnBoardSupplier]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOnBoardSupplier]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetOnBoardSupplier] (@P_Id Int)
AS
BEGIN
SELECT * FROM [OnBoardSuppliers]
	
	WHERE Id = ISNULL(@P_Id, Id)
		
		end

		




 
GO

-- %% [markdown]
-- # [dbo].[SP_GetOnPartnerbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOnPartnerbyId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetOnPartnerbyId] (@P_Id INT)
AS
BEGIN
	SELECT 
*
	FROM OnBoardPartner t
	 
	WHERE t.Id = ISNULL(@P_Id,t.Id)
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPackingQualityDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPackingQualityDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetPackingQualityDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT iq.*,p.ProductName ProdName FROM [dbo].[PackingandQuality] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.Id = ISNULL(@P_Id, iq.Id)
		AND iq.IsActive = 1
END
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetPartnerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPartnerDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetPartnerDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
 
		 t.[Id]
		,t.[ProductCodeId]
		,t.[ProductId]
		,t.[SKUId]
		,t.[PartnerName]
		,t.ContactNo
		,t.Location
		,t.Price
		,t.NoofPackets
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Partner] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPartnerPODropDown]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPartnerPODropDown]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPartnerPODropDown] (@UserId INT)
AS
begin

select PO.* from POHdr  PO 
left Join GnrHdr GH On GH.PONumber = PO.Id
Inner Join InvoiceHdr IH on  IH.PONumber = PO.Id
where GH.Id Is null And PO.CreatedByUserId = @UserId

End

GO

-- %% [markdown]
-- # [dbo].[SP_GetPartnerPODropDownForInvoice]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPartnerPODropDownForInvoice]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetPartnerPODropDownForInvoice] (@UserId INT)
AS
begin
declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
select PO.* from POHdr  PO 
left Join InvoiceHdr GH On GH.PONumber = PO.Id

where GH.Id Is null  and  PO.POStatus = 3 And PO.CreatedByUserId =(case when @Role=1 then PO.CreatedByUserId else @UserId end)
End

GO

-- %% [markdown]
-- # [dbo].[SP_GetPaymentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPaymentDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPaymentDetails] (@UserId INT)
AS
BEGIN
	SELECT 
	t.Id,
	t.InvoiceNo,
	IH.InvoiceNumber,
	t.PONumber,
	P.PONo,
	t.PaymentMode,
	ld.Name as modeofpayment,
	t.PaymentTerms,
	l.Name as paymentterm,
	t.AmountDue,
	t.AmountPaid,
	t.TransactionID,
	t.TransactionAmount,
	t.TransactionDate,
	t.TransactionImg,
	t.Remark,
	
	 t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
	t.UpdatedDate,t.UpdatedByUserId
	,t.UpdatedByUserId 	
	FROM [dbo].[PaymentConfirmation] t 
	inner Join InvoiceHDr IH On IH.Id = t.InvoiceNo
	inner Join POHDr P On P.Id = t.PONumber
	inner join LookupDtl l on l.Id = t.PaymentTerms
	inner join LookupDtl ld on ld.Id = t.PaymentMode
	WHERE t.Id = ISNULL(@UserId, t.Id)
		AND t.IsActive = 1
END
select * from PaymentConfirmation



GO

-- %% [markdown]
-- # [dbo].[SP_GetPaymentDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPaymentDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPaymentDtl] (@UserId INT)
AS
BEGIN

declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)

 
	SELECT 
	t.Id,
	t.InvoiceNo,
	IH.InvoiceNumber,
	t.PONumber,
	P.PONo,
	t.PaymentMode,
	ld.Name as modeofpayment,
	t.PaymentTerms,
	l.Name as paymentterm,
	t.AmountDue,
	t.AmountPaid,
	t.TransactionID,
	t.TransactionAmount,
	t.TransactionDate,
	t.TransactionImg,
	t.Remark,
	t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
	t.UpdatedDate,t.UpdatedByUserId
	,t.UpdatedByUserId 	
	FROM [dbo].[PaymentConfirmation] t 
	inner Join InvoiceHDr IH On IH.Id = t.InvoiceNo
	inner Join POHDr P On P.Id = t.PONumber
	inner join LookupDtl l on l.Id = t.PaymentTerms
	inner join LookupDtl ld on ld.Id = t.PaymentMode
	WHERE  t.IsActive = 1  AND t.CreatedByUserId =(case when @Role=1 then t.CreatedByUserId else @UserId end)



	
END




GO

-- %% [markdown]
-- # [dbo].[SP_GetPODetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPODetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
CREATE PROCEDURE [dbo].[SP_GetPODetails] (@P_POHdrId int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[POHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName
		,t.[RequiredQty]
		,t.[Price]
		,t.[Amount]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[PODtl] t
	INNER JOIN Product u ON u.Id=t.ProductName
	WHERE t.POHdrId = ISNULL(@P_POHdrId, t.POHdrId)
		AND t.IsActive = 1
END

 
GO

-- %% [markdown]
-- # [dbo].[SP_GetPODetailsByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPODetailsByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPODetailsByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[POHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[Price]
		,t.[Amount]
	,t.[HSN]
	,t.[EAN]
		,t.[TaxableValue]
		,t.[SGST]
		,t.[CGST]
		,t.[IGST]
		,t.Amount * t.CGST/100 as CGSTAmout
		,t.Amount * t.SGST/100 as SGSTAmout
		,t.Amount * t.IGST/100 as IGSTAmout,
		t.[TotalAmount]
		
		,t.Amount + ( t.Amount * t.CGST/100 + t.Amount * t.SGST/100  + t.Amount * t.IGST/100 )  as amountwithtax
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
		,t.SKUId as skuId,
		s.SKU
	FROM [dbo].[PODtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	inner join SKU s on s.Id = t.SKUId
	 
	WHERE t.POHdrId = ISNULL(@P_Id, t.POHdrId)
		AND t.IsActive = 1
END



 



GO

-- %% [markdown]
-- # [dbo].[SP_GetPODtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPODtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPODtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
	
		 t.[Id]
		,t.[POHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,d.ModeofDelivery
		,d.Modeofpayment
		,d.PaymentTerms
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[Price]
		,t.[Amount]
	
		,t.[TaxableValue]
		,t.[SGST]
		,t.[CGST]
		,t.[IGST]
		,t.[TotalAmount]
		,t.[Freight]
		,t.[PackingandForwarding]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[PODtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	inner JOIN POHdr d ON d.Id=t.POHdrId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1

		 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPOHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPOHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPOHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[PONo]
		,u.[BusinessName]
		,t.[BusinessName] as partnerId
		,c.[Name] as POStatus
		,t.[POStatus] as statusId
		,t.[PartnerGSTINNo]
		,t.[ShippingAddress]
		,t.[BillingAddress]
		,t.[RequireDate],
		t.Remark
		,k.Name As PaymentTerms
		,t.PaymentTerms as PaymentTermsId
		,l.Name as ModeofDelivery
		,t.ModeofDelivery as ModeofDeliveryId
		,w.Name as Modeofpayment
		,t.Modeofpayment as ModeofpaymentId
        ,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
		,pod.GrandTotal
		
	FROM [dbo].[POHdr] t
	INNER JOIN LookupDtl c ON c.Id=t.POStatus
	INNER JOIN LookupDtl k ON k.Id=t.PaymentTerms
	INNER JOIN LookupDtl l ON l.Id=t.ModeofDelivery
	INNER JOIN LookupDtl w ON w.Id=t.Modeofpayment
	INNER JOIN OnBoardPartner u ON u.Id=t.BusinessName
	inner Join (SELECT POHdrId, SUM(TaxableValue) as GrandTotal FROM PODtl Group By POHdrId) pod On  pod.POHdrId= t.Id
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPOHdrDetailsByPONo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPOHdrDetailsByPONo]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPOHdrDetailsByPONo] (@P_PONo varchar(20))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[PONo]
		,u.[BusinessName]
		,u.state
		,e.CGST as ActualCGST
		,e.SGST as ActualSGST
		,e.IGST as ActualIGST
		,t.[BusinessName] as partnerId
		,c.[Name] as POStatus
		,t.[POStatus] as statusId
		,t.[PartnerGSTINNo]
		,t.[ShippingAddress]
		,t.[BillingAddress]
		,t.[RequireDate]
		,IV.Freight
		,IV.PackingandForwarding
		,k.Name As PaymentTerms
		,t.PaymentTerms as PaymentTermsId
		,l.Name as ModeofDelivery
		,t.ModeofDelivery as ModeofDeliveryId
		,w.Name as Modeofpayment
		,t.Modeofpayment as ModeofpaymentId
        ,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
		
	FROM [dbo].[POHdr] t
	inner join PODtl d on d.POHdrId=t.Id
	INNER JOIN LookupDtl c ON c.Id=t.POStatus
	INNER JOIN LookupDtl k ON k.Id=t.PaymentTerms
	INNER JOIN LookupDtl l ON l.Id=t.ModeofDelivery
	INNER JOIN LookupDtl w ON w.Id=t.Modeofpayment
	INNER JOIN OnBoardPartner u ON u.Id=t.BusinessName
left join state e on e.Name=u.state
left Join InvoiceHdr IV On IV.PONumber = t.Id
	WHERE t.PONo = ISNULL(@P_PONo, t.PONo)
		AND t.IsActive = 1
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetPOHdrDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPOHdrDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPOHdrDtl] (@UserId INT)
AS
BEGIN

declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
	SELECT 
		 t.[Id]
		,t.[PONo]
		,u.[BusinessName]
		,t.[BusinessName] as partnerId
		,c.[Name] as POStatus
		,t.[POStatus] as statusId
		,t.[PartnerGSTINNo]
		,t.[ShippingAddress]
		,t.[BillingAddress]
		,t.[RequireDate]
		,k.Name As PaymentTerms
		,t.PaymentTerms as PaymentTermsId
		,l.Name as ModeofDelivery
		,t.ModeofDelivery as ModeofDeliveryId
		,w.Name as Modeofpayment
		,t.Modeofpayment as ModeofpaymentId
		,i.Name as Remarks
		,t.Remark 
        ,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
		,pod.GrandTotal
		
	FROM [dbo].[POHdr] t
	INNER JOIN LookupDtl c ON c.Id=t.POStatus
	INNER JOIN LookupDtl k ON k.Id=t.PaymentTerms
	INNER JOIN LookupDtl l ON l.Id=t.ModeofDelivery
	INNER JOIN LookupDtl w ON w.Id=t.Modeofpayment
	INNER JOIN LookupDtl i ON i.Id=t.Remark
	INNER JOIN OnBoardPartner u ON u.Id=t.BusinessName
	inner Join (SELECT POHdrId, SUM(TaxableValue) as GrandTotal FROM PODtl Group By POHdrId) pod On  pod.POHdrId= t.Id


	WHERE  t.IsActive = 1  AND t.CreatedByUserId =(case when @Role=1 then t.CreatedByUserId else @UserId end)

	
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetPriceListByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPriceListByProductId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetPriceListByProductId](@P_ProductId Int)
as
begin
select * from PriceList where ProductId=@P_ProductId and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPriceListDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPriceListDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[SP_GetPriceListDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 pl.[Id]
		,pl.[ProductId]
		,p.ProductName as ProductName
		,pl.[ProductPrice]
		,pl.[StartDate]
		,pl.[EndDate]
		,pl.[IsActive]
		,pl.[CreatedDate]
		,pl.[CreatedByUserId]
		,pl.[UpdatedDate]
		,pl.[UpdatedByUserId]
		,case when pl.EndDate is null then 'false' else 'true' end Status
	FROM [dbo].[PriceList] pl
	
	INNER JOIN dbo.Product p ON p.Id = pl.ProductId
	WHERE pl.Id = ISNULL(@P_Id, pl.Id)
		AND pl.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPriceListDetailsByDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPriceListDetailsByDate]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[SP_GetPriceListDetailsByDate] (@StartDate date,@EndDate date)
AS
BEGIN
	SELECT 
		 pl.[Id]
		,pl.[ProductId]
		,p.ProductName as ProductName
		,pl.[ProductPrice]
		
		,pl.[StartDate]
		,pl.[EndDate]
		,pl.[IsActive]
		,pl.[CreatedDate]
		,pl.[CreatedByUserId]
		,pl.[UpdatedDate]
		,pl.[UpdatedByUserId]
		,case when pl.EndDate is null then 'false' else 'true' end Status
	FROM [dbo].[PriceList] pl
	INNER JOIN dbo.Product p ON p.Id = pl.ProductId
	WHERE cast(pl.StartDate as Date)>=@StartDate
and cast(pl.StartDate as Date)<=@EndDate
and pl.IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetProcessandQualityMachine]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProcessandQualityMachine]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetProcessandQualityMachine] (@P_Id INT)
AS
BEGIN
	
	SELECT iq.*,p.ProductName ProdName FROM [dbo].[ProcessandQualityMachine] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.Id = ISNULL(@P_Id, iq.Id)
		AND iq.IsActive = 1
END
     

	

GO

-- %% [markdown]
-- # [dbo].[SP_GetProcessandQualityManual]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProcessandQualityManual]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetProcessandQualityManual] (@P_Id INT)
AS
BEGIN
	
	SELECT iq.*,p.ProductName ProdName FROM [dbo].[ProcessandQualityManual] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.Id = ISNULL(@P_Id, iq.Id)
		AND iq.IsActive = 1
END
     

	

GO

-- %% [markdown]
-- # [dbo].[SP_GetProductCheck]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductCheck]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetProductCheck] (@P_ProductName varchar(50))
AS
BEGIN
	SELECT 
		count(*) cnt	
	FROM [dbo].[Product] P
	WHERE P.ProductName = ISNULL(@P_ProductName, P.ProductName)
		AND P.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetProductDetails] (@P_Id INT)
AS
BEGIN
	SELECT cr.Id
		,cr.Code
		,cr.ProductName
		,ld.Name as Category
		,cr.IsActive
		,cr.HSN
		,cr.EAN
		,cr.IGST
		,cr.SGST
		,cr.CGST
		,cr.Description
		,cr.CreatedDate
		,u.Name as 'CreatedByUserId'
		,cr.UpdatedDate
		,um.Name as 'UpdatedByUserId'
		,cr.Id as ProductId
	FROM dbo.Product cr
	inner join UserInfo u on cr.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=cr.UpdatedByUserId
	inner join Category ld on ld.Id = cr.Category
	WHERE cr.Id = ISNULL(@P_Id, cr.Id)
		 order by cr.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductPriceListDropdownDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductPriceListDropdownDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




create  PROCEDURE [dbo].[SP_GetProductPriceListDropdownDetails] (@P_Id INT)
AS
BEGIN
	select p.Id,p.ProductName from Product p where Id not
	in(select distinct ProductId from PriceList) 
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetProducts]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProducts]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetProducts] (@P_Id INT)
AS
BEGIN
	SELECT 
	* from [dbo].[Product]
	WHERE Id = ISNULL(@P_Id, Id)
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetQRDataforBlockchain]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQRDataforBlockchain]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetQRDataforBlockchain](@Id int)
as
begin

select ReferenceId as UId,'exxiBA3LwlJLrNo0x76gcRm73nuMOdcWVEx8QvRBq9IeV6QhNCGAUHolyUTy974B' payload,
(select * from (select q.[Source],ProdName,q.QualityProcessDateStart,q.QualityProcessDateEnd,q.RecipeBlendDate,
q.ManufacturingDate,q.BestBefore as BestBeforeId,q.Id,lud.Name BestBefore from QRGeneration q
inner join LookupDtl lud on lud.Id = q.BestBefore
where q.Id=@Id)Y For JSON PATH) JsonObject 
from
(select Qr.*,p.ProductName ProdName from QRGeneration qr
inner join Product p on p.Id=qr.ProductName
where qr.Id=@Id)X

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetQRGenerationDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQRGenerationDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetQRGenerationDtl] (@P_Id INT)
AS
BEGIN        
	SELECT 
		t.Id,t.SKU, sk.SKU as SKUName,
		t.ProductName ,p.ProductName as Productdtl ,t.ProductCode,t.QRQuantity,ST.TotalStocks,t.ManufacturingDate,t.QualityProcessDateStart,t.QualityProcessDateEnd,t.RecipeBlendDate,t.BestBefore,t.Source,t.UniqueId,t.ReferenceId, ld.Name as bestbeforeduration,t.IsActive,t.CreatedByUserId 
	FROM [dbo].[QRGeneration] t

	inner Join  SKU sk On sk.Id = t.SKU

	inner join Product p on p.Id = t.ProductName
	inner Join LookupDtl ld on ld.Id = t.BestBefore
	inner Join  StockTransaction ST on ST.Id = t.QRQuantity
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetQualityCheckDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQualityCheckDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetQualityCheckDetails] (@P_Id INT)
AS
BEGIN
	
	SELECT iq.*,p.ProductName ProdName FROM [dbo].[QualityCheck] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.Id = ISNULL(@P_Id, iq.Id)
		AND iq.IsActive = 1
END
     
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.ViewYN = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRolesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Roles] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSKUByProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSKUByProduct]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetSKUByProduct] (@ProductId INT)
AS
BEGIN
	SELECT sku.Id
		,sku.SKU
		,sku.Code
		,sku.Description
		,p.ProductName
		,p.Code as ProductCode
		,p.CGST
		,P.IGST
		,P.SGST
		,sku.Product
		,sku.Size
		,sku.Price
		,uom.Code AS UOMCode

		,sku.UOM
		,sku.IsActive
		,sku.CreatedDate
		,u.Name as 'CreatedByUserId'
		,sku.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.SKU sku
	inner join UserInfo u on sku.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=sku.UpdatedByUserId
	inner join UOM uom on uom.Id =sku.UOM
	inner join Product p on p.Id =sku.Product
	WHERE sku.Product = ISNULL(@ProductId, sku.Product)
		AND sku.IsActive = 1 order by sku.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSKUDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSKUDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetSKUDetails] (@P_Id INT)
AS
BEGIN
	SELECT sku.Id
		,sku.SKU
		,sku.Code
		,sku.Description
		,p.ProductName
		,p.Code as ProductCode
		,sku.Product
		,sku.Size
		,sku.Price
		,uom.Code AS UOMCode
		,p.HSN
		,p.EAN
		,p.IGST,p.SGST,p.CGST


,sku.UOM
		,sku.IsActive
		,sku.CreatedDate
		,u.Name as 'CreatedByUserId'
		,sku.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.SKU sku
	inner join UserInfo u on sku.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=sku.UpdatedByUserId
	inner join UOM uom on uom.Id =sku.UOM
	inner join Product p on p.Id =sku.Product
	WHERE sku.Id = ISNULL(@P_Id, sku.Id)
		 order by sku.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetState]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetState]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetState] (@P_Id int)
as
begin
select * from state
where Id = isnull(@P_Id,Id) and IsActive=1 order by Name asc
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStock]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetStock] (@P_Id int)
as
begin
select s.*,p.ProductName,s.AvailableStocks as AvailableStock ,c.Name as CategoryName  from Stock s 
inner join Product p on p.Id=s.ProductId
inner join LookupDtl c on p.Category = c.Id
where s.Id = isnull(@P_Id,s.Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockByCurrentDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockByCurrentDate]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetStockByCurrentDate]
as
begin
select s.*,p.ProductName,Z.SKU as SKUName,s.AvailableStocks as AvailableStock from Stock s 
inner join Product p on p.Id=s.ProductId
inner join SKU Z on Z.Id=s.SKU
where s.IsActive = 1
--where cast (s.UpdatedDate as date) = cast(getdate() as date)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetailsByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetailsByProductId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetStockDetailsByProductId] (@ProductId varchar(200))
as
begin
--select s.*,p.ProductName,s.AvailableStocks as AvailableStock from Stock s 
--right join Product p on p.Id=s.ProductId
--where p.IsActive = 1
select isnull(s.TotalStocks,0) as TotalStocks,p.ProductName ,sk.SKU as SKUName,isnull(s.AvailableStocks,0) as AvailableStock from Product p 
left join Stock s on p.Id=s.ProductId
left join SKU sk on sk.Id=s.SKU
where p.IsActive = 1
--where s.ProductId in (select * from dbo.splitstring(@ProductId))
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDtlByProductId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDtlByProductId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetStockDtlByProductId] (@ProductId INT)
AS
BEGIN   SELECT * FROM Stock 
	
	WHERE IsActive = 1  and ProductId = ISNULL(@ProductId, ProductId)



	
END




GO

-- %% [markdown]
-- # [dbo].[SP_GetStockmovementByDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockmovementByDate]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE  PROCEDURE [dbo].[SP_GetStockmovementByDate] (@StartDate date,@EndDate date)
AS
BEGIN
select IH.Date as InvoiceDate, IH.InvoiceNumber, pd.Qty,p.SKU ,op.BusinessName from Dispatch d
inner join POHdr ph on ph.Id = d.OrderNo
inner join InvoiceHdr IH on IH.Id = d.InvoiceNumber
inner join(select sum(RequiredQty) Qty,PoHdrId,SKUId from PODtl group by POHdrId,SKUId) pd on pd.PoHdrId = ph.Id
inner join OnBoardPartner op on op.Id = ph.BusinessName
inner join SKU p on p.Id = pd.SKUId
where cast(d.CreatedDate as date)>= cast(@StartDate as date) and cast(d.CreatedDate as date)<=cast(@EndDate as date)
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockTransaction]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetStockTransaction] (@ProductId INT)
AS
BEGIN
	SELECT 
		
		*
	FROM [dbo].StockTransaction 
	
	WHERE ProductId = ISNULL(@ProductId,ProductId)
		AND IsActive = 1 and status = 0
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceDetailsByOrderNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceDetailsByOrderNo]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetTaxInvoiceDetailsByOrderNo] (@P_PONo int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[POHdrId] 
		,t.[ProductName] AS ProductId
		,u.ProductName 
		,t.[UOM]
		,c.Code As UOMName
		,t.[RequiredQty]
		,t.[Price]
		,t.[Amount]
	
		,t.[TaxableValue]
		,t.[SGST]
		,t.[CGST]
		,t.[IGST]
		,t.[TotalAmount]
		,t.[Freight]
		,t.[PackingandForwarding]
		
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[PODtl] t
	INNER JOIN UOM c ON c.Id=t.UOM
	INNER JOIN Product u ON u.Id=t.ProductName
	inner JOIN DeliveryPreparationHdr d on d.Id=@P_PONo
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceDocuments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceDocuments]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetTaxInvoiceDocuments] (@InvoiceNo Int)
AS
BEGIN
	SELECT 
		 t.[Id],
	     t.[InvoiceId],
		 t.SNo,
		 t.[ImageUrl]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM TaxInvoiceDocuments t  WHERE t.InvoiceId = ISNULL(@InvoiceNo, t.InvoiceId)
		AND t.IsActive = 1
	
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetTaxInvoiceDtl] (@P_Id INT)
AS
BEGIN
	SELECT *
	FROM [dbo].[TaxInvoiceDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceDtlByHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetTaxInvoiceDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		*
	FROM [dbo].[TaxInvoiceDtl] 
	
	WHERE InvoiceHdrId = ISNULL(@P_Id, InvoiceHdrId)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceDtlDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetTaxInvoiceDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		  *
	FROM [dbo].[TaxInvoiceDtl] 
	
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceHdr]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetTaxInvoiceHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
	t.Id,t.BuyersName,
	o.BusinessName,
	t.PONumber,
	po.PONo,
	po.ModeofDelivery,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[TaxInvoiceHdr] t 
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join OnBoardPartner o on o.Id=t.BuyersName

	inner join POHdr po on po.Id=t.PONumber
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceHdrByPO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceHdrByPO]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetTaxInvoiceHdrByPO] (@P_PONumber INT)
AS
BEGIN
	SELECT 
	t.Id,t.BuyersName,
	o.BusinessName,
	t.PONumber,
	po.PONo,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[TaxInvoiceHdr] t 
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join OnBoardPartner o on o.Id=t.BuyersName

	inner join POHdr po on po.Id=t.PONumber
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE t.PONumber = ISNULL(@P_PONumber, t.PONumber)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create PROCEDURE [dbo].[SP_GetTaxInvoiceHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
	 *
	FROM [dbo].[TaxInvoiceHdr] 
	
	WHERE Id = ISNULL(@P_Id,Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTaxInvoiceHdrDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTaxInvoiceHdrDtl]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetTaxInvoiceHdrDtl] (@UserId INT)
AS
BEGIN
declare @Role int
set @Role = (select RoleId from Users where Id=@UserId)
	SELECT 
	t.Id,t.BuyersName,
	o.BusinessName,
	t.PONumber,
	po.PONo,
	po.ModeofDelivery,
	t.InvoiceNumber,
	 cast(t.Date as varchar(50)) as Date,t.BuyersAddress,t.GSTNumber,
	 l.Name as PaymentTerms,
	 t.PaymentTerms as PaymentTermsId,
	 lt.Name as PaymentMode,
	 t.PaymentMode as PaymentModeId,
	 t.IsActive,
	 t.CreatedDate,t.CreatedByUserId,
		 t.UpdatedDate,t.UpdatedByUserId
		,c.Name AS CreatedByUser
		,u.Name AS UpdatedByUser
	FROM [dbo].[TaxInvoiceHdr] t 
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join OnBoardPartner o on o.Id=t.BuyersName

	inner join POHdr po on po.Id=t.PONumber
	inner join LookupDtl l on l.Id=t.PaymentTerms
	inner join LookupDtl lt on lt.Id=t.PaymentMode
	WHERE  t.IsActive = 1  AND po.CreatedByUserId =(case when @Role=1 then t.CreatedByUserId else @UserId end)
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetUOM]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUOM]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUOM] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Description]
		,IsActive
	FROM [dbo].[UOM]
	WHERE Id = ISNULL(@P_Id, Id)
		 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUOMDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUOMDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE PROCEDURE [dbo].[SP_GetUOMDetails] (@P_Id INT)
AS
BEGIN
	SELECT uom.Id
		,uom.Code
		,uom.Description
		,uom.IsActive
		,uom.CreatedDate
		,u.Name as 'CreatedByUserId'
		,uom.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.UOM uom
	inner join UserInfo u on uom.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=uom.UpdatedByUserId
	WHERE uom.Id = ISNULL(@P_Id, uom.Id)
		 order by uom.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUploadExcelByExcelHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUploadExcelByExcelHdrId]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetUploadExcelByExcelHdrId] (@ExcelHdrId Int)
AS
BEGIN  


	SELECT iq.*,p.ProductName ProdName FROM [dbo].[InwardandQuality] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.ExcelHdrId = @ExcelHdrId  AND p.IsActive = 1

	SELECT pq.*,p.ProductName ProdName FROM [dbo].[PackingandQuality] pq
	inner join Product p on p.Id = pq.ProductName
	where pq.ExcelHdrId =@ExcelHdrId AND p.IsActive = 1
	
	SELECT pqm.*,p.ProductName ProdName FROM [dbo].[ProcessandQualityMachine] pqm
	inner join Product p on p.Id = pqm.ProductName
	where pqm.ExcelHdrId =@ExcelHdrId AND p.IsActive = 1

	SELECT pqma.*,p.ProductName ProdName FROM [dbo].[ProcessandQualityManual] pqma
	inner join Product p on p.Id = pqma.ProductName
	where pqma.ExcelHdrId =@ExcelHdrId AND p.IsActive = 1

	SELECT qc.*,p.ProductName ProdName FROM [dbo].[QualityCheck] qc
	inner join Product p on p.Id = qc.ProductName
	where qc.ExcelHdrId =@ExcelHdrId and p.IsActive = 1
	
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetUploadExcelFiulesByProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUploadExcelFiulesByProduct]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUploadExcelFiulesByProduct] (@ProductName varchar(255))
AS
BEGIN  
declare @ProductId int
--set @ProductId =(select Id from Product where ProductName =@ProductName and IsActive=1)
set @ProductId =280

	SELECT iq.*,p.ProductName ProdName FROM [dbo].[InwardandQuality] iq
	inner join Product p on p.Id = iq.ProductName
	where iq.ProductName =@ProductId AND p.IsActive = 1

	SELECT pq.*,p.ProductName ProdName FROM [dbo].[PackingandQuality] pq
	inner join Product p on p.Id = pq.ProductName
	where pq.ProductName =@ProductId AND p.IsActive = 1
	
	SELECT pqm.*,p.ProductName ProdName FROM [dbo].[ProcessandQualityMachine] pqm
	inner join Product p on p.Id = pqm.ProductName
	where pqm.ProductName =@ProductId AND p.IsActive = 1

	SELECT pqma.*,p.ProductName ProdName FROM [dbo].[ProcessandQualityManual] pqma
	inner join Product p on p.Id = pqma.ProductName
	where pqma.ProductName =@ProductId AND p.IsActive = 1

	SELECT qc.*,p.ProductName ProdName FROM [dbo].[QualityCheck] qc
	inner join Product p on p.Id = qc.ProductName
	where qc.ProductName =@ProductId and p.IsActive = 1
	
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserOfPartner]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserOfPartner]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUserOfPartner] (@P_Id INT)
AS
BEGIN
	SELECT 
		UP.[Id],
		u.[BusinessName] as Business,
		UP.BusinessName,
		UP.[UserName],
		R.Name as RoleName,
		UP.Role,
		UP.[EmailId],
		UP.[MobileNo],
		UP.[IsActive],
		UP.[CreatedDate],
		UP.[CreatedByUserId],
		UP.[UpdatedDate],
		UP.[UpdatedByUserId]

FROM [dbo].[UserOfPartner]  UP
inner join OnBoardPartner  u on UP.BusinessName = u.Id 
inner join Roles R ON R.Id = UP.Role

	WHERE UP.Id = ISNULL(@P_Id, UP.Id)
		AND UP.IsActive = 1
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsers] (@P_Id INT)
AS
BEGIN
	SELECT 
		t.*,bp.BusinessName
	FROM [dbo].[Users] t
	inner join OnBoardPartner bp on bp.Id=t.OnboardPartnerId
	WHERE t.Id = ISNULL(@P_Id,t.Id)
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersbyLoginName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersbyLoginName]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetUsersbyLoginName] (@P_UserName varchar(30))
AS
BEGIN
	SELECT 
		count(*) cnt	
	FROM [dbo].[users] o
	WHERE o.UserName = ISNULL(@P_UserName, o.UserName)
		AND o.ViewYN = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsersDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[MiddileName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,c.Name as RoleName
		,t.[ViewYN]
		,bp.BusinessName as OrgsnizationName
		,t.[CreatedDate]
		,t.OnboardPartnerId
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Users] t
	inner join OnBoardPartner bp on bp.Id=t.OnboardPartnerId
	INNER JOIN Roles c ON c.Id=t.RoleId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GNRApprovalPO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GNRApprovalPO]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GNRApprovalPO] (@P_Id INT)
as begin
select t.* from POHDr t 
left join GnrHdr gh on gh.PONumber = t.Id  
where t.Id = ISNULL(@P_Id, t.Id) AND POStatus = 2 and gh.Id is null
end
GO

-- %% [markdown]
-- # [dbo].[SP_RejectPOForRemarks]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_RejectPOForRemarks]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_RejectPOForRemarks](@Id Int,@Status Int,@Remark Varchar(255) )
as begin  
update POHDr set Remark = @Remark,POStatus= @Status  where Id = @Id
end

GO

-- %% [markdown]
-- # [dbo].[SP_RequestedPOHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_RequestedPOHdrDetails]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_RequestedPOHdrDetails]
as begin
SELECT 
		 t.[Id]
		,t.[PONo]
		,u.[BusinessName]
		,t.[BusinessName] as partnerId
		,c.[Name] as POStatus
		,t.[POStatus] as statusId
		,t.[PartnerGSTINNo]
		,t.[ShippingAddress]
		,t.[BillingAddress]
		,t.[RequireDate]
		,k.Name As PaymentTerms
		,t.PaymentTerms as PaymentTermsId
		,l.Name as ModeofDelivery
		,t.ModeofDelivery as ModeofDeliveryId
		,w.Name as Modeofpayment
		,t.Modeofpayment as ModeofpaymentId
        ,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,t.[UpdatedDate]
		,t.[UpdatedByUserId]
		,pod.GrandTotal
		
	FROM [dbo].[POHdr] t 
	INNER JOIN LookupDtl c ON c.Id=t.POStatus
	INNER JOIN LookupDtl k ON k.Id=t.PaymentTerms
	INNER JOIN LookupDtl l ON l.Id=t.ModeofDelivery
	INNER JOIN LookupDtl w ON w.Id=t.Modeofpayment
	INNER JOIN OnBoardPartner u ON u.Id=t.BusinessName
	inner Join (SELECT POHdrId, SUM(TaxableValue) as GrandTotal FROM PODtl Group By POHdrId) pod On  pod.POHdrId= t.Id
	
		AND t.IsActive = 1 and POStatus=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdatePriceListEndDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdatePriceListEndDate]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdatePriceListEndDate](@PricelistId int,@StartDate datetime)
as
begin 
select 1
--update PriceList set EndDate= @StartDate where Id =@PricelistId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateQRGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateQRGeneration]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_UpdateQRGeneration](@Id int,@UniqueId varchar(255))
as
begin
  update QRGeneration set UniqueId=@UniqueId where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateStockTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateStockTransaction]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_UpdateStockTransaction](@Id int)
as
begin  
  update  StockTransaction  set status = 1 where Id = @Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:02:48 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNumber,
			u.Password,
			u.RoleId
		FROM Users u 
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END

GO
