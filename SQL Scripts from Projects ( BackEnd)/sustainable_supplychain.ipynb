-- %% [markdown]
-- # [dbo].[Dealer]

-- %%
USE [sustainable_supplychain]
GO

-- %%
/****** Object:  Table [dbo].[Dealer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Dealer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[PrimaryContactNo] [bigint] NULL,
	[Address] [varchar](500) NULL,
	[Village] [int] NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitute] [decimal](12, 9) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DealerProcurement]

-- %%
/****** Object:  Table [dbo].[DealerProcurement]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DealerProcurement](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[DealerId] [int] NOT NULL,
	[FarmerId] [int] NOT NULL,
	[ReceivedTons] [decimal](18, 3) NULL,
	[ReceivedDate] [datetime] NOT NULL,
	[SupplyInTons] [decimal](18, 3) NULL,
	[SupplyDate] [datetime] NULL,
	[DealerBatchCode] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Farmer]

-- %%
/****** Object:  Table [dbo].[Farmer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Farmer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[FirstName] [varchar](255) NOT NULL,
	[LastName] [varchar](255) NULL,
	[FatherName] [varchar](255) NULL,
	[Gender] [varchar](10) NULL,
	[Age] [int] NULL,
	[PrimaryContactNo] [bigint] NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[NationalIdentityCode] [varchar](255) NULL,
	[NationalIdentityCodeDocument] [varchar](255) NULL,
	[NoOfPlots] [int] NULL,
	[Image] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[FarmerCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Manfacturer]

-- %%
/****** Object:  Table [dbo].[Manfacturer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Manfacturer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[EntityName] [varchar](255) NOT NULL,
	[PrimaryContactName] [varchar](255) NOT NULL,
	[PrimaryContactNo] [bigint] NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitude] [decimal](12, 9) NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ManfacturerProcurement]

-- %%
/****** Object:  Table [dbo].[ManfacturerProcurement]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ManfacturerProcurement](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ManfacturerId] [int] NOT NULL,
	[DealerBatchCode] [varchar](255) NULL,
	[DealerId] [int] NULL,
	[FarmerId] [int] NULL,
	[ReceivedTons] [decimal](18, 3) NULL,
	[ReceivedDate] [datetime] NOT NULL,
	[ManfacturerBatchCode] [varchar](255) NULL,
	[ManfacturerBatchDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ManfacturerProduction]

-- %%
/****** Object:  Table [dbo].[ManfacturerProduction]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ManfacturerProduction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ManfacturerId] [int] NOT NULL,
	[ManfacturerBatchCode] [varchar](255) NULL,
	[URL] [varchar](255) NULL,
	[ProductionTons] [decimal](18, 3) NULL,
	[ProductionDate] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](255) NOT NULL,
	[Icon] [varchar](255) NOT NULL,
	[Order] [int] NULL,
	[IconType] [varchar](255) NULL,
	[ClassName] [varchar](255) NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Plantation]

-- %%
/****** Object:  Table [dbo].[Plantation]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Plantation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotCode] [varchar](255) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[TypeOfOwnership] [varchar](10) NULL,
	[AreaInHectors] [decimal](8, 3) NULL,
	[Latitude] [decimal](12, 9) NULL,
	[Longitude] [decimal](12, 9) NULL,
	[Address] [varchar](500) NULL,
	[VillageId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[PlotCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationDocuments]

-- %%
/****** Object:  Table [dbo].[PlantationDocuments]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationDocuments](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerId] [int] NOT NULL,
	[PlotId] [int] NOT NULL,
	[DocURL] [varchar](255) NOT NULL,
	[DocType] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationGeoBoundaries]

-- %%
/****** Object:  Table [dbo].[PlantationGeoBoundaries]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationGeoBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerId] [int] NOT NULL,
	[PlotId] [int] NOT NULL,
	[Latitude] [decimal](12, 8) NULL,
	[Longitude] [decimal](12, 8) NULL,
	[SeqNo] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlantationYeild]

-- %%
/****** Object:  Table [dbo].[PlantationYeild]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlantationYeild](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotId] [int] NOT NULL,
	[FarmerId] [int] NOT NULL,
	[YeildInTons] [decimal](10, 3) NOT NULL,
	[DateOfHarvest] [datetime] NULL,
	[SupplyInTons] [decimal](10, 3) NOT NULL,
	[SupplyDate] [datetime] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](255) NOT NULL,
	[Password] [nvarchar](255) NOT NULL,
	[FirstName] [varchar](255) NOT NULL,
	[LastName] [varchar](255) NULL,
	[EmailId] [varchar](255) NULL,
	[MobileNumber] [varchar](20) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[RoleId] [int] NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__4222D4EF]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__4316F928]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__440B1D61]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__44FF419A]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__45F365D3]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__46E78A0C]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__49C3F6B7]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__4AB81AF0]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__4BAC3F29]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__ViewYN__4CA06362]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__4D94879B]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__4E88ABD4]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__4F7CD00D]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__3C69FB99]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__3E52440B]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__36B12243]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__37A5467C]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__38996AB5]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [dbo].[SP_AddDealer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDealer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddDealer](
@Id int,
@Name varchar(255),
@PrimaryContactNo bigint,
@Address varchar(500),
@Village int,
@Latitude decimal(12,9),
@Longitute decimal(12,9),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

    BEGIN TRANSACTION

	BEGIN TRY
	   IF ISNULL(@Id,0) = 0
	   INSERT INTO Dealer(
	   Name,
	   PrimaryContactNo,
	   Address,
	   Village,
	   Latitude,
	   Longitute,
	   IsActive,
	   CreatedDate,
	   CreatedByUserId,
	   UpdatedDate,
	   UpdatedByUserId
	   )
	   VALUES(
	    @Name,
	   @PrimaryContactNo,
	   @Address,
	   @Village,
	   @Latitude,
	   @Longitute,
	   @IsActive,
	   @CreatedDate,
	   @CreatedByUserId,
	   @UpdatedDate,
	   @UpdatedByUserId
	   )
      ELSE 
	      UPDATE Dealer 
   SET  Name = @Name,
		PrimaryContactNo = @PrimaryContactNo,
		Address = @Address,
		Village = @Village,
		Latitude = @Latitude,
		Longitute = @Longitute,
		IsActive = @IsActive,
		UpdatedDate = @UpdatedDate,
		UpdatedByUserId = @UpdatedByUserId
		WHERE Id = @Id
	END TRY
	    BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDealerProcurement]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDealerProcurement]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddDealerProcurement](
@Id int,
@DealerId int,
@FarmerId int,
@ReceivedTons decimal(18,3),
@ReceivedDate datetime,
@SupplyInTons decimal(18,3),
@SupplyDate datetime,
@DealerBatchCode varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

    BEGIN TRANSACTION

	BEGIN TRY
	   IF ISNULL(@Id,0) = 0
	   INSERT INTO DealerProcurement(
	   DealerId,
	   FarmerId,
	   ReceivedTons,
	   ReceivedDate,
	   SupplyInTons,
	   SupplyDate,
	   DealerBatchCode,
	   IsActive,
	   CreatedDate,
	   CreatedByUserId,
	   UpdatedDate,
	   UpdatedByUserId
	   )
	   VALUES(
	   @DealerId,
	   @FarmerId,
	   @ReceivedTons,
	   @ReceivedDate,
	   @SupplyInTons,
	   @SupplyDate,
	   @DealerBatchCode,
	   @IsActive,
	   @CreatedDate,
	   @CreatedByUserId,
	   @UpdatedDate,
	   @UpdatedByUserId
	   )
      ELSE 
	      UPDATE DealerProcurement
   SET  DealerId = @DealerId,
	    FarmerId = @FarmerId,
	    ReceivedTons = @ReceivedTons,
	    ReceivedDate = @ReceivedDate,
	    SupplyInTons = @SupplyInTons,
	    SupplyDate = @SupplyDate,
	    DealerBatchCode = @DealerBatchCode,
		IsActive = @IsActive,
		UpdatedDate = @UpdatedDate,
		UpdatedByUserId = @UpdatedByUserId
		WHERE Id = @Id
	END TRY
	    BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddFarmer](
@Id int,
@FarmerCode varchar(255),
@FirstName varchar(255),
@LastName varchar(255),
@FatherName varchar(255),
@Gender varchar(10),
@Age int,
@PrimaryContactNo bigint,
@Address varchar(500),
@VillageId int,
@NationalIdentityCode varchar(255),
@NationalIdentityCodeDocument varchar(255),
@NoOfPlots int,
@Image varchar(500),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

BEGIN TRY
  IF ISNULL(@Id,0) = 0
  INSERT INTO Farmer(
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  Address,
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  Image,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
  )
  VALUES(
  @FarmerCode,
  @FirstName,
  @LastName,
  @FatherName,
  @Gender,
  @Age,
  @PrimaryContactNo,
  @Address,
  @VillageId,
  @NationalIdentityCode,
  @NationalIdentityCodeDocument,
  @NoOfPlots,
  @Image,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
  )
  ELSE
   UPDATE Farmer
   SET FarmerCode = @FarmerCode,
  FirstName = @FirstName,
  LastName = @LastName,
  FatherName = @FatherName,
  Gender = @Gender,
  Age = @Age,
  PrimaryContactNo = @PrimaryContactNo,
  Address = @Address,
  VillageId = @VillageId,
  NationalIdentityCode = @NationalIdentityCode,
  NationalIdentityCodeDocument = @NationalIdentityCodeDocument,
  NoOfPlots = @NoOfPlots,
  Image = @Image,
  IsActive = @IsActive,
  UpdatedDate = @UpdatedDate,
  UpdatedByUserId = @UpdatedByUserId
  WHERE Id = @Id
END TRY
BEGIN CATCH
		 SELECT @ErrorNumber = ERROR_NUMBER(),
		        @ErrorMessage = ERROR_MESSAGE()

				IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
				RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 

		END CATCH
		IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddManfacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManfacturer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddManfacturer](
@Id int,
@EntityName varchar(255),
@PrimaryContactName varchar(255),
@PrimaryContactNo bigint,
@Latitude decimal(12,9),
@Longitude decimal(12,9),
@Address varchar(500),
@VillageId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

  BEGIN TRY
  IF ISNULL(@Id,0) = 0
    INSERT INTO Manfacturer(
	EntityName,
	PrimaryContactName,
	PrimaryContactNo,
	Latitude,
	Longitude,
	Address,
	VillageId,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@EntityName,
	@PrimaryContactName,
	@PrimaryContactNo,
	@Latitude,
	@Longitude,
	@Address,
	@VillageId,
	@IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	ELSE
	UPDATE Manfacturer
	SET  EntityName = @EntityName,
	PrimaryContactName = @PrimaryContactName,
	PrimaryContactNo = @PrimaryContactNo,
	Latitude = @Latitude,
	Longitude = @Longitude,
	Address = @Address,
	VillageId = @VillageId,
	IsActive = @IsActive,
    UpdatedDate = @UpdatedDate,
    UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY
  BEGIN CATCH
   SELECT ErrorMessage = ERROR_MESSAGE(),
          ErrorNumber = ERROR_NUMBER()

		  IF @@TRANCOUNT >0
		  ROLLBACK TRANSACTION;
	      RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
 
  END CATCH
     IF @@TRANCOUNT >0
	 COMMIT TRANSACTION;

	 SET @ErrorNumber = 0
	 SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddManfacturerProcurement]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManfacturerProcurement]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddManfacturerProcurement](
@Id int,
@ManfacturerId int,
@DealerBatchCode varchar(255),
@DealerId int,
@FarmerId int,
@ReceivedTons decimal(18,3),
@ReceivedDate datetime,
@ManfacturerBatchCode varchar(255),
@ManfacturerBatchDate datetime,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

  BEGIN TRY
  IF ISNULL(@Id,0) = 0
    INSERT INTO ManfacturerProcurement(
	ManfacturerId,
	DealerBatchCode,
	DealerId,
	FarmerId,
	ReceivedTons,
	ReceivedDate,
	ManfacturerBatchCode,
	ManfacturerBatchDate,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@ManfacturerId,
	@DealerBatchCode,
	@DealerId,
	@FarmerId,
	@ReceivedTons,
	@ReceivedDate,
	@ManfacturerBatchCode,
	@ManfacturerBatchDate,
	@IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	ELSE
	UPDATE ManfacturerProcurement
	SET  ManfacturerId = @ManfacturerId,
	DealerBatchCode = @DealerBatchCode,
	DealerId = @DealerId,
	FarmerId = @FarmerId,
	ReceivedTons = @ReceivedTons,
	ReceivedDate = @ReceivedDate,
	ManfacturerBatchCode = @ManfacturerBatchCode,
	ManfacturerBatchDate = @ManfacturerBatchDate,
	IsActive = @IsActive,
    UpdatedDate = @UpdatedDate,
    UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY
  BEGIN CATCH
   SELECT ErrorMessage = ERROR_MESSAGE(),
          ErrorNumber = ERROR_NUMBER()

		  IF @@TRANCOUNT >0
		  ROLLBACK TRANSACTION;
	      RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
 
  END CATCH
     IF @@TRANCOUNT >0
	 COMMIT TRANSACTION;

	 SET @ErrorNumber = 0
	 SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddManfacturerProduction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManfacturerProduction]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_AddManfacturerProduction](
@Id int,
@ManfacturerId int,
@ManfacturerBatchCode varchar(255),
@URL varchar(255),
@ProductionTons decimal(18,3),
@ProductionDate datetime,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN

BEGIN TRANSACTION

  BEGIN TRY
  IF ISNULL(@Id,0) = 0
    INSERT INTO ManfacturerProduction(
	ManfacturerId,
	ManfacturerBatchCode,
	URL,
	ProductionTons,
	ProductionDate,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	)
	VALUES(
	@ManfacturerId,
	@ManfacturerBatchCode,
	@URL,
	@ProductionTons,
	@ProductionDate,
	@IsActive,
    @CreatedDate,
    @CreatedByUserId,
    @UpdatedDate,
    @UpdatedByUserId
	)
	ELSE
	UPDATE ManfacturerProduction
	SET  ManfacturerId = @ManfacturerId,
	ManfacturerBatchCode =@ManfacturerBatchCode,
	URL = @URL,
	ProductionTons = @ProductionTons,
	ProductionDate = @ProductionDate,
	IsActive = @IsActive,
    UpdatedDate = @UpdatedDate,
    UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY
  BEGIN CATCH
   SELECT ErrorMessage = ERROR_MESSAGE(),
          ErrorNumber = ERROR_NUMBER()

		  IF @@TRANCOUNT >0
		  ROLLBACK TRANSACTION;
	      RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
 
  END CATCH
     IF @@TRANCOUNT >0
	 COMMIT TRANSACTION;

	 SET @ErrorNumber = 0
	 SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(255)
,@Icon varchar(255)
,@Order int
,@IconType varchar(255)
,@ClassName varchar(255)
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Name]
				,[MenuType]
				,[ParentMenuId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				,IconType
				,ClassName
				)
			VALUES (
				 @Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				,@IconType
				,@ClassName
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
				,IconType=@IconType
				,ClassName=@ClassName
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantation]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantation]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddPlantation](
@Id int,
@PlotCode varchar(255),
@FarmerCode varchar(255),
@TypeOfOwnership varchar(10),
@AreaInHectors decimal(8,3),
@Latitude decimal(12,9),
@Longitude decimal(12,9),
@Address varchar(500),
@VillageId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
  BEGIN TRANSACTION

  BEGIN TRY
    IF ISNULL(@Id,0) = 0
	INSERT INTO Plantation(
	PlotCode,
	FarmerCode,
	TypeOfOwnership,
	AreaInHectors,
	Latitude,
	Longitude,
	Address,
	VillageId,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	VALUES(
	@PlotCode,
	@FarmerCode,
	@TypeOfOwnership,
	@AreaInHectors,
	@Latitude,
	@Longitude,
	@Address,
	@VillageId,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId

	)
	ELSE
	UPDATE Plantation
	SET PlotCode = @PlotCode,
	FarmerCode = @FarmerCode,
	TypeOfOwnership = @TypeOfOwnership,
	AreaInHectors = @AreaInHectors,
	Latitude = @Latitude,
	Longitude = @Longitude,
	Address = @Address,
	VillageId = @VillageId,
	IsActive = @IsActive,
	UpdatedDate = @UpdatedDate,
	UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY

  BEGIN CATCH
     SELECT @ErrorNumber = ERROR_NUMBER(),
	        @ErrorMessage = ERROR_MESSAGE();
			
			IF @@TRANCOUNT>0
            ROLLBACK TRANSACTION;
            RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
  END CATCH
      IF @@TRANCOUNT>0
	   COMMIT TRANSACTION;

	   SET @ErrorNumber = 0
	   SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationDocuments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationDocuments]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPlantationDocuments](
@Id int,
@FarmerId int,
@PlotId int,
@DocURL varchar(255),
@DocType varchar(255),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id, 0) = 0
	  INSERT INTO PlantationDocuments(
	  FarmerId,
	  PlotId,
	  DocURL,
	  DocType,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
	  @FarmerId,
	  @PlotId,
	  @DocURL,
	  @DocType,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	  ELSE
	  UPDATE PlantationDocuments
	  SET FarmerId = @FarmerId,
	  PlotId = @PlotId,
	  DocURL = @DocURL,
	  DocType = @DocType,
	  IsActive = @IsActive,
	  UpdatedDate = @UpdatedDate,
	  UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationGeoBoundaries]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddPlantationGeoBoundaries](
@Id int,
@FarmerId int,
@PlotId int,
@Latitude decimal(12,8),
@Longitude decimal(12,8),
@SeqNo int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS 
BEGIN
BEGIN TRANSACTION

BEGIN TRY
    IF ISNULL(@Id, 0) = 0
	  INSERT INTO PlantationGeoBoundaries(
	  FarmerId,
	  PlotId,
	  Latitude,
	  Longitude,
	  SeqNo,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
	  )
	  VALUES(
	  @FarmerId,
	  @PlotId,
	  @Latitude,
	  @Longitude,
	  @SeqNo,
	  @IsActive,
	  @CreatedDate,
	  @CreatedByUserId,
	  @UpdatedDate,
	  @UpdatedByUserId
	  )
	  ELSE
	  UPDATE PlantationGeoBoundaries
	  SET FarmerId = @FarmerId,
	  PlotId = @PlotId,
	  Latitude = @Latitude,
	  Longitude = @Longitude,
	  SeqNo = @SeqNo,
	  IsActive = @IsActive,
	  UpdatedDate = @UpdatedDate,
	  UpdatedByUserId = @UpdatedByUserId
	  WHERE Id = @Id
END TRY
BEGIN CATCH
   SELECT @ErrorNumber = ERROR_NUMBER(),
          @ErrorMessage = ERROR_MESSAGE();
		   
		   IF @@TRANCOUNT > 0
		   ROLLBACK TRANSACTION;
	    	RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
END CATCH
   IF @@TRANCOUNT > 0
      COMMIT TRANSACTION;

	SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'

END
GO

-- %% [markdown]
-- # [dbo].[SP_AddPlantationYeild]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPlantationYeild]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_AddPlantationYeild](
@Id int,
@PlotId int,
@FarmerId int,
@YeildInTons decimal(10,3),
@DateOfHarvest Datetime,
@SupplyInTons decimal(10,3),
@SupplyDate datetime,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
  BEGIN TRANSACTION

  BEGIN TRY
    IF ISNULL(@Id,0) = 0
	INSERT INTO PlantationYeild(
	PlotId,
	FarmerId,
	YeildInTons,
	DateOfHarvest,
	SupplyInTons,
	SupplyDate,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
	)
	VALUES(
	@PlotId,
	@FarmerId,
	@YeildInTons,
	@DateOfHarvest,
	@SupplyInTons,
	@SupplyDate,
	@IsActive,
	@CreatedDate,
	@CreatedByUserId,
	@UpdatedDate,
	@UpdatedByUserId

	)
	ELSE
	UPDATE PlantationYeild
	SET PlotId = @PlotId,
	FarmerId = @FarmerId,
	YeildInTons = @YeildInTons,
	DateOfHarvest = @DateOfHarvest,
	SupplyInTons = @SupplyInTons,
	SupplyDate = @SupplyDate,
	IsActive = @IsActive,
	UpdatedDate = @UpdatedDate,
	UpdatedByUserId = @UpdatedByUserId
	WHERE Id = @Id
  END TRY

  BEGIN CATCH
     SELECT @ErrorNumber = ERROR_NUMBER(),
	        @ErrorMessage = ERROR_MESSAGE();
			
			IF @@TRANCOUNT>0
            ROLLBACK TRANSACTION;
            RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
  END CATCH
      IF @@TRANCOUNT>0
	   COMMIT TRANSACTION;

	   SET @ErrorNumber = 0
	   SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRole]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRole]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRole] 
(
 @Id int
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Name]
				,[IsActive]
				,[CreatedDate]
				,[UpdatedDate]
				)
			VALUES (
				 @Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,ISNULL(@UpdatedDate, GETDATE())
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Name]
				,[IsActive]
				,[CreatedDate]
				,[UpdatedDate]
				)
			VALUES (
				 @Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,ISNULL(@UpdatedDate, GETDATE())
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
 @Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber varchar(20)
,@RoleId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Users] (
				 [UserName]
				,[Password]
				,[FirstName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,[RoleId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @UserName
				,@Password
				,@FirstName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@RoleId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Users]
			SET  
				 [UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[MobileNumber] = @MobileNumber
				,[RoleId] = @RoleId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckEmailId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckEmailId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckEmailId](@EmailId varchar(255))
as
begin
select EmailId from Users where EmailId=IsNull(@EmailId,EmailId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckFirstName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckFirstName]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_CheckFirstName](@FirstName varchar(100))
as
begin
select FirstName from Users where FirstName=IsNull(@FirstName,FirstName)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckMenuName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckMenuName]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
create PROCEDURE [dbo].[SP_CheckMenuName] (@Name Varchar(100))
AS
BEGIN
	SELECT Name from Menu
	WHERE Name = ISNULL(@Name, Name)  
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckRoleName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckRoleName]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
create PROCEDURE [dbo].[SP_CheckRoleName] (@Name Varchar(100))
AS
BEGIN
	SELECT Name from Roles
	WHERE Name = ISNULL(@Name, Name)  
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckUserName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckUserName]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_CheckUserName](@UserName varchar(100))
as
begin
select UserName from Users where UserName = IsNull (@UserName,UserName)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetDealer](@P_Id int)
AS
BEGIN
    SELECT
	     Id,
	     Name,
		 PrimaryContactNo,
		 Address,
		 Village,
		 Latitude,
		 Longitute,
		 IsActive,
		 CreatedDate,
		 CreatedByUserId,
		 UpdatedDate,
		 UpdatedByUserId
		 FROM Dealer
		 WHERE Id = ISNULL(@P_Id, Id)
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDealerProcurement]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDealerProcurement]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetDealerProcurement](@P_Id int)
AS
BEGIN
    SELECT
	     Id,
	     DealerId,
		 FarmerId,
		 ReceivedTons,
		 ReceivedDate,
		 SupplyInTons,
		 SupplyDate,
		 DealerBatchCode,
		 IsActive,
		 CreatedDate,
		 CreatedByUserId,
		 UpdatedDate,
		 UpdatedByUserId
		 FROM DealerProcurement
		 WHERE Id = ISNULL(@P_Id, Id)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsByFarmerCode]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetFarmerDetailsByFarmerCode](@P_FarmerCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  Address,
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  Image,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE FarmerCode = ISNULL(@P_FarmerCode, FarmerCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsByUserId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetFarmerDetailsByUserId](@P_CreatedByUserId int)
AS
BEGIN
    SELECT
  Id,
  FarmerCode,
  FirstName,
  LastName,
  FatherName,
  Gender,
  Age,
  PrimaryContactNo,
  Address,
  VillageId,
  NationalIdentityCode,
  NationalIdentityCodeDocument,
  NoOfPlots,
  Image,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Farmer
		 WHERE CreatedByUserId = ISNULL(@P_CreatedByUserId, CreatedByUserId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturer]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetManfacturer](@P_Id int)
AS
BEGIN
    SELECT
    Id,
    EntityName,
	PrimaryContactName,
	PrimaryContactNo,
	Latitude,
	Longitude,
	Address,
	VillageId,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId		
	FROM Manfacturer
		 WHERE Id = ISNULL(@P_Id, Id)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturerProcurement]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturerProcurement]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetManfacturerProcurement](@P_Id int)
AS
BEGIN
    SELECT
    Id,
    ManfacturerId,
	DealerBatchCode,
	DealerId,
	FarmerId,
	ReceivedTons,
	ReceivedDate,
	ManfacturerBatchCode,
	ManfacturerBatchDate,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId	
	FROM ManfacturerProcurement
		 WHERE Id = ISNULL(@P_Id, Id)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetManfacturerProduction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManfacturerProduction]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetManfacturerProduction](@P_Id int)
AS
BEGIN
    SELECT
    Id,
   ManfacturerId,
	ManfacturerBatchCode,
	URL,
	ProductionTons,
	ProductionDate,
	IsActive,
    CreatedDate,
    CreatedByUserId,
    UpdatedDate,
    UpdatedByUserId
	FROM ManfacturerProduction
		 WHERE Id = ISNULL(@P_Id, Id)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM [dbo].[VW_UserRoleMenus] M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@UserId
FOR XML PATH,TYPE)))children
FROM [dbo].[VW_UserRoleMenus] M WHERE MenuType='M' AND UserId=@UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Name
		,m.MenuType
		,m.IconType
		,m.ClassName
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuTypes
		--,mm.Name as ParentMenu
		,m.ParentMenuId
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.IsActive
		,m.CreatedDate
		--,u.Name as CreatedByUser
		,m.CreatedByUserId
		,m.UpdatedDate
		--,um.Name as UpdatedByUser
		,m.UpdatedByUserId
	FROM dbo.Menu m 
	inner join VW_UserInfo u on m.CreatedByUserId=u.Id 
	inner join VW_UserInfo Um ON Um.id=m.UpdatedByUserId
	left join menu mm on mm.Id=m.ParentMenuId
	WHERE m.Id = ISNULL(@Id, m.Id)  order by CreatedDate desc 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@UserId INT)
AS
BEGIN
	SELECT RM.Id,
	    RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDetailsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDetailsByFarmerCode]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationDetailsByFarmerCode](@P_FarmerCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  PlotCode,
  FarmerCode,
  TypeOfOwnership,
  AreaInHectors,
  Latitude,
  Longitude,
  Address,
  VillageId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Plantation
		 WHERE FarmerCode = ISNULL(@P_FarmerCode, FarmerCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDetailsByPlotCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDetailsByPlotCode]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationDetailsByPlotCode](@P_PlotCode varchar(255))
AS
BEGIN
    SELECT
  Id,
  PlotCode,
  FarmerCode,
  TypeOfOwnership,
  AreaInHectors,
  Latitude,
  Longitude,
  Address,
  VillageId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Plantation
		 WHERE PlotCode = ISNULL(@P_PlotCode, PlotCode)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDetailsByUserId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationDetailsByUserId](@P_CreatedByUserId int)
AS
BEGIN
    SELECT
  Id,
  PlotCode,
  FarmerCode,
  TypeOfOwnership,
  AreaInHectors,
  Latitude,
  Longitude,
  Address,
  VillageId,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
		 FROM Plantation
		 WHERE CreatedByUserId = ISNULL(@P_CreatedByUserId, CreatedByUserId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationDocumentsByPlotId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationDocumentsByPlotId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationDocumentsByPlotId](@P_PlotId int)
AS
BEGIN
    SELECT
      Id,
      FarmerId,
	  PlotId,
	  DocURL,
	  DocType,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
		 FROM PlantationDocuments
		 WHERE PlotId = ISNULL(@P_PlotId, PlotId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationGeoBoundariesByPlotId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationGeoBoundariesByPlotId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationGeoBoundariesByPlotId](@P_PlotId int)
AS
BEGIN
    SELECT
      Id,
      FarmerId,
	  PlotId,
	  Latitude,
	  Longitude,
	  SeqNo,
	  IsActive,
	  CreatedDate,
	  CreatedByUserId,
	  UpdatedDate,
	  UpdatedByUserId
		 FROM PlantationGeoBoundaries
		 WHERE PlotId = ISNULL(@P_PlotId, PlotId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlantationYeildDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlantationYeildDetailsByUserId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetPlantationYeildDetailsByUserId](@P_CreatedByUserId int)
AS
BEGIN
    SELECT
    Id,
    PlotId,
	FarmerId,
	YeildInTons,
	DateOfHarvest,
	SupplyInTons,
	SupplyDate,
	IsActive,
	CreatedDate,
	CreatedByUserId,
	UpdatedDate,
	UpdatedByUserId
		 FROM PlantationYeild
		 WHERE CreatedByUserId = ISNULL(@P_CreatedByUserId, CreatedByUserId)
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleDetails]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetRoleDetails null
CREATE PROCEDURE [dbo].[SP_GetRoleDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[UpdatedDate]
	FROM [dbo].[Roles] t
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
END

--- End Procedure : SP_GetRoleDetails

--- Start Procedure : SP_AddMenu
SET ANSI_NULLS ON
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.IsActive
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as CreatedByUser
		,Um.Name as UpdatedByUser
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN VW_UserInfo U ON U.Id=RM.CreatedByUserId
	inner join VW_UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@Id, RM.RoleId)
		  
	ORDER By r.name, PM.[Order]  ,m.[Order],UpdatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSideMenuByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSideMenuByUserId]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetSideMenuByUserId 1
CREATE proc [dbo].[SP_GetSideMenuByUserId](@UserId int)
as
begin
select m.Path as path,m.MenuName as title,isnull(m.IconType,'') as iconType,m.Icon as icon,
isnull(m.ClassName,'') as class,'false' as groupTitle,'' as badge,'' as badgeClass,'All' role,m.[Order] as orderPosition,
dbo.FN_JsonArrayToString(m.MenuId,@UserId) AS submenu
from VW_UserRoleMenus m where m.UserId = @UserId and m.MenuType = 'M' 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserDetails]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUserDetails] (@Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,r.Name AS RoleName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
		,t.UpdatedByUserId
	FROM [dbo].[Users] t
	INNER JOIN VW_UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN VW_UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Roles r on r.Id = t.RoleId
	WHERE t.Id = ISNULL(@Id, t.Id) order by CreatedDate desc
		--AND t.IsActive = 1

END
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:11:24 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_ValidateUser 'DeveloperUser','b56e0b4ea4962283bee762525c2d490f'
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(255),
	@Password VARCHAR(255)    
AS

BEGIN
	
		SELECT 
		 t.[Id]
		,[UserName]
		,[Password]
		,[FirstName]
		,[LastName]
		,[EmailId]
		,[MobileNumber]
		,[RoleId]
		,t.[IsActive]
		,t.[CreatedDate]
		,[CreatedByUserId]
		,t.[UpdatedDate]
		,[UpdatedByUserId]
		,r.Name as RoleName
	FROM [dbo].[Users] t
	inner join [dbo].[Roles] r on r.Id = t.RoleId
	WHERE t.UserName=@UserName AND t.Password=@Password AND t.IsActive=1
END
GO
