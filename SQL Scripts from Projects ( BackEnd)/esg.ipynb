-- %% [markdown]
-- # [dbo].[Answers]

-- %%
USE [esg]
GO

-- %%
/****** Object:  Table [dbo].[Answers]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Answers](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[QuestionId] [int] NULL,
	[TemplateSubMenuId] [int] NULL,
	[Value] [varchar](500) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[AssessmentBaseValue]

-- %%
/****** Object:  Table [dbo].[AssessmentBaseValue]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AssessmentBaseValue](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TypeName] [varchar](10) NOT NULL,
	[CO2] [decimal](18, 2) NOT NULL,
	[CH4] [decimal](18, 2) NOT NULL,
	[N2O] [decimal](18, 2) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BackGroupImages]

-- %%
/****** Object:  Table [dbo].[BackGroupImages]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BackGroupImages](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NULL,
	[Base64] [varchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BlockChainTransaction]

-- %%
/****** Object:  Table [dbo].[BlockChainTransaction]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BlockChainTransaction](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NOT NULL,
	[S3URL] [varchar](500) NOT NULL,
	[IPFSHash] [varchar](255) NOT NULL,
	[PinSize] [int] NOT NULL,
	[IPFSTimestamp] [datetime] NOT NULL,
	[IsDuplicate] [bit] NOT NULL,
	[BlockChainTransactionAddress] [varchar](500) NOT NULL,
	[WalletAddress] [varchar](500) NOT NULL,
	[TransactionGasFee] [int] NOT NULL,
	[CreatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_FinalReportGeneration]

-- %%
/****** Object:  Table [dbo].[BRSR_FinalReportGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_FinalReportGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportName] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[CoverPageImage] [varchar](max) NULL,
	[CoverPageLayout] [varchar](max) NULL,
	[DesignTemplate] [varchar](max) NULL,
	[Logo] [varchar](max) NULL,
	[Introduction] [nvarchar](max) NULL,
	[FinalDraftGuidance] [varchar](max) NULL,
	[Settings] [bit] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Reportpicbase] [varchar](max) NULL,
	[ReportId] [varchar](255) NULL,
	[isPublished] [bit] NULL,
	[Messagefromceo] [nvarchar](max) NULL,
	[aboutthisreport] [nvarchar](max) NULL,
	[keyhighlights] [nvarchar](max) NULL,
	[vision] [nvarchar](max) NULL,
	[IsSignoff] [varchar](255) NULL,
	[IsValidate] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_ReportEvidence]

-- %%
/****** Object:  Table [dbo].[BRSR_ReportEvidence]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_ReportEvidence](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NOT NULL,
	[GuidanceNumber] [varchar](255) NULL,
	[QuestionCode] [nvarchar](max) NULL,
	[FileName] [varchar](255) NULL,
	[UploadedObj] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_ReportGeneration]

-- %%
/****** Object:  Table [dbo].[BRSR_ReportGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_ReportGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportName] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[InitialDraftReport] [nvarchar](max) NULL,
	[FinalDraftReport] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[Stage] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_ReportTemplateMenuId]

-- %%
/****** Object:  Table [dbo].[BRSR_ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_ReportTemplateMenuId](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[UserId] [int] NULL,
	[TemplateMenuId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Checked] [bit] NULL,
	[Status] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_TemplateMenu]

-- %%
/****** Object:  Table [dbo].[BRSR_TemplateMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_TemplateMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[FrameworkId] [int] NULL,
	[TemplateMenuName] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_TemplateMenuCategory]

-- %%
/****** Object:  Table [dbo].[BRSR_TemplateMenuCategory]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_TemplateMenuCategory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateMenuId] [int] NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_TemplateSubMenu]

-- %%
/****** Object:  Table [dbo].[BRSR_TemplateSubMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_TemplateSubMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[TemplateMenuCategoryId] [int] NULL,
	[TemplateMenuId] [int] NULL,
	[TemplateSubMenuName] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_TemplateSubMenuItem]

-- %%
/****** Object:  Table [dbo].[BRSR_TemplateSubMenuItem]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_TemplateSubMenuItem](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[TemplateSubMenuId] [int] NULL,
	[Guidance] [varchar](max) NULL,
	[Description] [varchar](max) NULL,
	[ScreenName] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BRSR_ValidatingFinalReport]

-- %%
/****** Object:  Table [dbo].[BRSR_ValidatingFinalReport]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BRSR_ValidatingFinalReport](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[UserId] [varchar](255) NULL,
	[IsValidate] [varchar](55) NULL,
	[Remarks] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CA_Scope1CompanyFacilities]

-- %%
/****** Object:  Table [dbo].[CA_Scope1CompanyFacilities]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CA_Scope1CompanyFacilities](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FuelType] [nvarchar](255) NOT NULL,
	[Noofunits] [int] NULL,
	[Units] [varchar](255) NOT NULL,
	[GWPFactor] [varchar](255) NOT NULL,
	[MetricCO2e] [nvarchar](255) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[OrgId] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CA_Scope1CompanyVehicles]

-- %%
/****** Object:  Table [dbo].[CA_Scope1CompanyVehicles]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CA_Scope1CompanyVehicles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Vehicle] [varchar](255) NOT NULL,
	[Type] [varchar](255) NOT NULL,
	[Fuel] [varchar](255) NOT NULL,
	[EmissionFactor] [decimal](18, 5) NOT NULL,
	[Distance] [varchar](255) NOT NULL,
	[tCO2e] [nvarchar](255) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[OrgId] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CA_Scope1Fugitives]

-- %%
/****** Object:  Table [dbo].[CA_Scope1Fugitives]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CA_Scope1Fugitives](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Emission] [varchar](255) NOT NULL,
	[Factorperkg] [int] NULL,
	[Amount] [nvarchar](255) NOT NULL,
	[tCO2e] [nvarchar](255) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[OrgId] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CityState]

-- %%
/****** Object:  Table [dbo].[CityState]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CityState](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[City] [varchar](55) NOT NULL,
	[State] [varchar](55) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Countries]

-- %%
/****** Object:  Table [dbo].[Countries]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Countries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[CountryName] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
 CONSTRAINT [PK_Countries_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CurrencytypeforExchangerate]

-- %%
/****** Object:  Table [dbo].[CurrencytypeforExchangerate]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CurrencytypeforExchangerate](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Currency] [varchar](55) NULL,
	[Exchangerate] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
 CONSTRAINT [PK_CurrencytypeforExchangerate_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DistrictDtl]

-- %%
/****** Object:  Table [dbo].[DistrictDtl]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DistrictDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Princ8essId] [int] NOT NULL,
	[Princ8leadId] [int] NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DynamicHTMLTableHeaders]

-- %%
/****** Object:  Table [dbo].[DynamicHTMLTableHeaders]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DynamicHTMLTableHeaders](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[QuestionKey] [varchar](max) NOT NULL,
	[HeaderName] [varchar](max) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[DynamicQuestions]

-- %%
/****** Object:  Table [dbo].[DynamicQuestions]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[DynamicQuestions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateSubMenuId] [int] NOT NULL,
	[Questions] [varchar](500) NOT NULL,
	[Type] [varchar](50) NOT NULL,
	[KeyValue] [varchar](500) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ElectricCountries]

-- %%
/****** Object:  Table [dbo].[ElectricCountries]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ElectricCountries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Country] [varchar](255) NULL,
	[Productionfuel] [decimal](18, 6) NULL,
 CONSTRAINT [PK_ElectricCountries_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FinalReportGeneration]

-- %%
/****** Object:  Table [dbo].[FinalReportGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FinalReportGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportName] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[CoverPageImage] [varchar](max) NULL,
	[CoverPageLayout] [varchar](max) NULL,
	[DesignTemplate] [varchar](max) NULL,
	[Logo] [varchar](max) NULL,
	[Introduction] [nvarchar](max) NULL,
	[FinalDraftGuidance] [varchar](max) NULL,
	[Settings] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Reportpicbase] [varchar](max) NULL,
	[ReportId] [varchar](255) NULL,
	[isPublished] [bit] NULL,
	[Messagefromceo] [nvarchar](max) NULL,
	[aboutthisreport] [nvarchar](max) NULL,
	[keyhighlights] [nvarchar](max) NULL,
	[vision] [nvarchar](max) NULL,
	[IsSignoff] [varchar](255) NULL,
	[IsValidate] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Framework]

-- %%
/****** Object:  Table [dbo].[Framework]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Framework](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[FrameworkName] [varchar](255) NULL,
	[Logo] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
 CONSTRAINT [PK_Framework_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FuelConvertionType]

-- %%
/****** Object:  Table [dbo].[FuelConvertionType]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FuelConvertionType](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TypeId] [int] NOT NULL,
	[ConvertFrom] [varchar](50) NOT NULL,
	[ConvertTo] [varchar](50) NOT NULL,
	[MultiplyBy] [decimal](18, 10) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FuelType]

-- %%
/****** Object:  Table [dbo].[FuelType]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FuelType](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Type] [varchar](10) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FuelTypeBaseValue]

-- %%
/****** Object:  Table [dbo].[FuelTypeBaseValue]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FuelTypeBaseValue](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TypeId] [int] NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[CO2] [decimal](18, 15) NULL,
	[CH4] [decimal](18, 15) NULL,
	[N2O] [decimal](18, 15) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupDtl]

-- %%
/****** Object:  Table [dbo].[LookupDtl]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LookupHdrId] [int] NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Remarks] [varchar](100) NULL,
	[Ord] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupHdr]

-- %%
/****** Object:  Table [dbo].[LookupHdr]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NICList]

-- %%
/****** Object:  Table [dbo].[NICList]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NICList](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NICCode] [int] NULL,
	[Description] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NICList1]

-- %%
/****** Object:  Table [dbo].[NICList1]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NICList1](
	[NICCode] [varchar](50) NULL,
	[Description] [nvarchar](100) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NICList2]

-- %%
/****** Object:  Table [dbo].[NICList2]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NICList2](
	[NICCode] [varchar](50) NULL,
	[Description] [nvarchar](300) NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NICList3]

-- %%
/****** Object:  Table [dbo].[NICList3]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NICList3](
	[NICCode] [varchar](50) NULL,
	[Description] [varchar](max) NULL,
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[QuesDtl]

-- %%
/****** Object:  Table [dbo].[QuesDtl]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[QuesDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[QuesHdrId] [int] NOT NULL,
	[QuesCode] [varchar](255) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[Ord] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[ReportId] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[QuesHdr]

-- %%
/****** Object:  Table [dbo].[QuesHdr]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[QuesHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[QuesCode] [varchar](255) NULL,
	[Name] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Questions]

-- %%
/****** Object:  Table [dbo].[Questions]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Questions](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[TemplateSubMenuId] [int] NULL,
	[Label] [varchar](500) NULL,
	[ControlType] [varchar](255) NULL,
	[Key] [varchar](255) NULL,
	[Options] [varchar](4000) NULL,
	[Order] [int] NULL,
	[Required] [bit] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Registration]

-- %%
/****** Object:  Table [dbo].[Registration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Registration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[OrganizationName] [varchar](255) NULL,
	[OrganizationType] [varchar](255) NULL,
	[HeadOffice] [varchar](255) NULL,
	[Country] [varchar](255) NULL,
	[Pincode] [bigint] NULL,
	[ContactName] [varchar](255) NULL,
	[EmailId] [varchar](255) NULL,
	[ContactNumber] [bigint] NULL,
	[Designation] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[OrgId] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[OrganizationName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportCollaborators]

-- %%
/****** Object:  Table [dbo].[ReportCollaborators]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReportCollaborators](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[CollaboratorId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportEvidence]

-- %%
/****** Object:  Table [dbo].[ReportEvidence]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReportEvidence](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NOT NULL,
	[GuidanceNumber] [varchar](255) NULL,
	[QuestionCode] [varchar](255) NULL,
	[FileName] [varchar](255) NULL,
	[UploadedObj] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportGeneration]

-- %%
/****** Object:  Table [dbo].[ReportGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReportGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportName] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[InitialDraftReport] [nvarchar](max) NULL,
	[FinalDraftReport] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[Stage] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportPictures]

-- %%
/****** Object:  Table [dbo].[ReportPictures]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReportPictures](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NULL,
	[Picture] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportTemplateMenuId]

-- %%
/****** Object:  Table [dbo].[ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReportTemplateMenuId](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[UserId] [int] NULL,
	[TemplateMenuId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Checked] [bit] NULL,
	[Status] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ReportTemplateMenuIdforTemplate]

-- %%
/****** Object:  Table [dbo].[ReportTemplateMenuIdforTemplate]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ReportTemplateMenuIdforTemplate](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[UserId] [int] NULL,
	[TemplateMenuId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Checked] [bit] NULL,
	[Status] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RequestData]

-- %%
/****** Object:  Table [dbo].[RequestData]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RequestData](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[GuidanceNumber] [varchar](255) NULL,
	[RequestedBy] [varchar](255) NULL,
	[RequestedTo] [varchar](255) NULL,
	[RequestedMessage] [varchar](255) NULL,
	[Response] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope1CompanyVehicles]

-- %%
/****** Object:  Table [dbo].[Scope1CompanyVehicles]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope1CompanyVehicles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Vehicle] [varchar](255) NOT NULL,
	[Type] [varchar](255) NOT NULL,
	[Fuel] [varchar](255) NOT NULL,
	[Emissionfactor] [decimal](18, 5) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope1Fugutives]

-- %%
/****** Object:  Table [dbo].[Scope1Fugutives]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope1Fugutives](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Emission] [varchar](255) NOT NULL,
	[factor] [decimal](18, 5) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope2Marketbased]

-- %%
/****** Object:  Table [dbo].[Scope2Marketbased]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope2Marketbased](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Country] [varchar](255) NOT NULL,
	[Emissionfactor] [decimal](18, 5) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope2SteamHeat]

-- %%
/****** Object:  Table [dbo].[Scope2SteamHeat]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope2SteamHeat](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[GWP] [varchar](55) NOT NULL,
	[Emissionfactor] [decimal](18, 5) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3avgpiecebased]

-- %%
/****** Object:  Table [dbo].[Scope3avgpiecebased]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3avgpiecebased](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductType] [varchar](55) NOT NULL,
	[Emissionfactor] [decimal](18, 2) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Categ1SupplierSpec]

-- %%
/****** Object:  Table [dbo].[Scope3Categ1SupplierSpec]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Categ1SupplierSpec](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Purchasedgoods] [varchar](55) NOT NULL,
	[Emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category2shift]

-- %%
/****** Object:  Table [dbo].[Scope3Category2shift]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category2shift](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[MachineryType] [varchar](255) NOT NULL,
	[Gasoline] [decimal](18, 2) NOT NULL,
	[DieselFuel] [decimal](18, 2) NOT NULL,
	[Electricity] [decimal](18, 2) NOT NULL,
	[emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category2spend]

-- %%
/****** Object:  Table [dbo].[Scope3Category2spend]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category2spend](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CommodityCodeName] [varchar](255) NULL,
	[emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category3elec]

-- %%
/****** Object:  Table [dbo].[Scope3Category3elec]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category3elec](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Country] [varchar](255) NOT NULL,
	[oversgen] [decimal](18, 5) NULL,
	[oversetd] [decimal](18, 5) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category3Fuel]

-- %%
/****** Object:  Table [dbo].[Scope3Category3Fuel]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category3Fuel](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FuelType] [varchar](255) NOT NULL,
	[Unit] [varchar](255) NOT NULL,
	[emissionfactor] [decimal](18, 5) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category4]

-- %%
/****** Object:  Table [dbo].[Scope3Category4]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category4](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[VehicleType] [varchar](255) NOT NULL,
	[Units] [varchar](55) NOT NULL,
	[Emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category5Waste]

-- %%
/****** Object:  Table [dbo].[Scope3Category5Waste]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category5Waste](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Material] [varchar](255) NOT NULL,
	[DisposalMethod] [varchar](255) NOT NULL,
	[Standardef] [decimal](18, 2) NULL,
	[IsActive] [bit] NULL,
	[TypeId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category5WasteMaterialNames]

-- %%
/****** Object:  Table [dbo].[Scope3Category5WasteMaterialNames]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category5WasteMaterialNames](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Material] [varchar](255) NOT NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category6BusinessTravel]

-- %%
/****** Object:  Table [dbo].[Scope3Category6BusinessTravel]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category6BusinessTravel](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TravelType] [varchar](55) NOT NULL,
	[Standard] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category6hotel]

-- %%
/****** Object:  Table [dbo].[Scope3Category6hotel]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category6hotel](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[HotelCountry] [varchar](55) NOT NULL,
	[emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category6RentalCars]

-- %%
/****** Object:  Table [dbo].[Scope3Category6RentalCars]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category6RentalCars](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Fuel] [varchar](55) NOT NULL,
	[Standard] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3Category7]

-- %%
/****** Object:  Table [dbo].[Scope3Category7]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3Category7](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[VehicleType] [varchar](255) NOT NULL,
	[emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3scope1calc]

-- %%
/****** Object:  Table [dbo].[Scope3scope1calc]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3scope1calc](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FuelType] [varchar](255) NOT NULL,
	[Units] [varchar](55) NOT NULL,
	[Emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3scope2calc]

-- %%
/****** Object:  Table [dbo].[Scope3scope2calc]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3scope2calc](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Country] [varchar](255) NOT NULL,
	[Productionfuel] [decimal](18, 10) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Scope3spendbased]

-- %%
/****** Object:  Table [dbo].[Scope3spendbased]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Scope3spendbased](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CommodityCodeName] [varchar](255) NOT NULL,
	[Emissionfactor] [decimal](18, 10) NULL,
	[IsActive] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_FinalReportGeneration]

-- %%
/****** Object:  Table [dbo].[SGX_FinalReportGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_FinalReportGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportName] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[CoverPageImage] [varchar](max) NULL,
	[CoverPageLayout] [varchar](max) NULL,
	[DesignTemplate] [varchar](max) NULL,
	[Logo] [varchar](max) NULL,
	[Introduction] [nvarchar](max) NULL,
	[FinalDraftGuidance] [varchar](max) NULL,
	[Settings] [bit] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Reportpicbase] [varchar](max) NULL,
	[ReportId] [varchar](255) NULL,
	[isPublished] [bit] NULL,
	[Messagefromceo] [nvarchar](max) NULL,
	[aboutthisreport] [nvarchar](max) NULL,
	[keyhighlights] [nvarchar](max) NULL,
	[vision] [nvarchar](max) NULL,
	[IsSignoff] [varchar](255) NULL,
	[IsValidate] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_ReportEvidence]

-- %%
/****** Object:  Table [dbo].[SGX_ReportEvidence]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_ReportEvidence](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NOT NULL,
	[GuidanceNumber] [varchar](255) NULL,
	[QuestionCode] [varchar](255) NULL,
	[FileName] [varchar](255) NULL,
	[UploadedObj] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_ReportGeneration]

-- %%
/****** Object:  Table [dbo].[SGX_ReportGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_ReportGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportName] [varchar](255) NULL,
	[StartDate] [datetime] NULL,
	[EndDate] [datetime] NULL,
	[InitialDraftReport] [nvarchar](max) NULL,
	[FinalDraftReport] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[Stage] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_ReportTemplateMenuId]

-- %%
/****** Object:  Table [dbo].[SGX_ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_ReportTemplateMenuId](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[UserId] [int] NULL,
	[TemplateMenuId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Checked] [bit] NULL,
	[Status] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_TemplateMenu]

-- %%
/****** Object:  Table [dbo].[SGX_TemplateMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_TemplateMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[FrameworkId] [int] NULL,
	[TemplateMenuName] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_TemplateMenuCategory]

-- %%
/****** Object:  Table [dbo].[SGX_TemplateMenuCategory]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_TemplateMenuCategory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateMenuId] [int] NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_TemplateSubMenu]

-- %%
/****** Object:  Table [dbo].[SGX_TemplateSubMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_TemplateSubMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[TemplateMenuCategoryId] [int] NULL,
	[TemplateMenuId] [int] NULL,
	[TemplateSubMenuName] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_TemplateSubMenuItem]

-- %%
/****** Object:  Table [dbo].[SGX_TemplateSubMenuItem]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_TemplateSubMenuItem](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[TemplateSubMenuId] [int] NULL,
	[Guidance] [varchar](max) NULL,
	[Description] [varchar](max) NULL,
	[ScreenName] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SGX_ValidatingFinalReport]

-- %%
/****** Object:  Table [dbo].[SGX_ValidatingFinalReport]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SGX_ValidatingFinalReport](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[UserId] [varchar](255) NULL,
	[IsValidate] [varchar](55) NULL,
	[Remarks] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Sheet1$]

-- %%
/****** Object:  Table [dbo].[Sheet1$]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Sheet1$](
	[NICCode] [float] NULL,
	[Description] [nvarchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SigningoffFinalReport]

-- %%
/****** Object:  Table [dbo].[SigningoffFinalReport]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SigningoffFinalReport](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[UserId] [varchar](255) NULL,
	[IsSignoff] [varchar](55) NULL,
	[Remarks] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StateHdr]

-- %%
/****** Object:  Table [dbo].[StateHdr]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StateHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateCheckboxMenuId]

-- %%
/****** Object:  Table [dbo].[TemplateCheckboxMenuId]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateCheckboxMenuId](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateId] [varchar](255) NULL,
	[UserId] [int] NULL,
	[TemplateSubMenuId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Checked] [bit] NULL,
	[Status] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateDesignbyScreen]

-- %%
/****** Object:  Table [dbo].[TemplateDesignbyScreen]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateDesignbyScreen](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateSubMenuId] [int] NOT NULL,
	[ScreenName] [varchar](255) NOT NULL,
	[ReqData] [varchar](255) NOT NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[Code] [varchar](255) NULL,
	[Answers] [varchar](max) NULL,
 CONSTRAINT [PK_TemplateDesignbyScreen_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateGeneration]

-- %%
/****** Object:  Table [dbo].[TemplateGeneration]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateGeneration](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateName] [varchar](255) NULL,
	[ReportId] [varchar](max) NULL,
	[TemplateId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateMenu]

-- %%
/****** Object:  Table [dbo].[TemplateMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[FrameworkId] [int] NULL,
	[TemplateMenuName] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateMenuCategory]

-- %%
/****** Object:  Table [dbo].[TemplateMenuCategory]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateMenuCategory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[TemplateMenuId] [int] NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateSubMenu]

-- %%
/****** Object:  Table [dbo].[TemplateSubMenu]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateSubMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[TemplateMenuId] [int] NULL,
	[TemplateSubMenuName] [varchar](255) NULL,
	[Description] [varchar](3000) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[TemplateMenuCategoryId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TemplateSubMenuItem]

-- %%
/****** Object:  Table [dbo].[TemplateSubMenuItem]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TemplateSubMenuItem](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[TemplateSubMenuId] [int] NULL,
	[Guidance] [varchar](max) NULL,
	[Description] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[ScreenName] [varchar](255) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](255) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[LastName] [varchar](50) NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[RoleId] [int] NULL,
	[RegistrationId] [int] NULL,
	[VerificationCode] [bigint] NULL,
	[OrgId] [varchar](255) NULL,
	[Designation] [varchar](255) NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[UserName] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ValidatingFinalReport]

-- %%
/****** Object:  Table [dbo].[ValidatingFinalReport]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ValidatingFinalReport](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ReportId] [varchar](255) NULL,
	[OrgId] [varchar](255) NULL,
	[UserId] [varchar](255) NULL,
	[IsValidate] [varchar](55) NULL,
	[Remarks] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedByUserId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Answers__IsActiv__6CA31EA0]

-- %%
ALTER TABLE [dbo].[Answers] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Assessmen__IsAct__0539C240]

-- %%
ALTER TABLE [dbo].[AssessmentBaseValue] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BlockChai__Creat__789EE131]

-- %%
ALTER TABLE [dbo].[BlockChainTransaction] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Fina__IsAct__38EE7070]

-- %%
ALTER TABLE [dbo].[BRSR_FinalReportGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BRSR_Fina__Creat__39E294A9]

-- %%
ALTER TABLE [dbo].[BRSR_FinalReportGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Fina__Updat__3AD6B8E2]

-- %%
ALTER TABLE [dbo].[BRSR_FinalReportGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__IsAct__05C3D225]

-- %%
ALTER TABLE [dbo].[BRSR_ReportEvidence] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__Creat__06B7F65E]

-- %%
ALTER TABLE [dbo].[BRSR_ReportEvidence] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__Updat__07AC1A97]

-- %%
ALTER TABLE [dbo].[BRSR_ReportEvidence] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__IsAct__3429BB53]

-- %%
ALTER TABLE [dbo].[BRSR_ReportGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__Creat__351DDF8C]

-- %%
ALTER TABLE [dbo].[BRSR_ReportGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__Updat__361203C5]

-- %%
ALTER TABLE [dbo].[BRSR_ReportGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__IsAct__436BFEE3]

-- %%
ALTER TABLE [dbo].[BRSR_ReportTemplateMenuId] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__Creat__4460231C]

-- %%
ALTER TABLE [dbo].[BRSR_ReportTemplateMenuId] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Repo__Updat__45544755]

-- %%
ALTER TABLE [dbo].[BRSR_ReportTemplateMenuId] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Temp__IsAct__29AC2CE0]

-- %%
ALTER TABLE [dbo].[BRSR_TemplateMenuCategory] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BRSR_Temp__Creat__2AA05119]

-- %%
ALTER TABLE [dbo].[BRSR_TemplateMenuCategory] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Temp__Updat__2B947552]

-- %%
ALTER TABLE [dbo].[BRSR_TemplateMenuCategory] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Vali__IsAct__17E28260]

-- %%
ALTER TABLE [dbo].[BRSR_ValidatingFinalReport] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__BRSR_Vali__Creat__18D6A699]

-- %%
ALTER TABLE [dbo].[BRSR_ValidatingFinalReport] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BRSR_Vali__Updat__19CACAD2]

-- %%
ALTER TABLE [dbo].[BRSR_ValidatingFinalReport] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__DynamicHT__IsAct__297722B6]

-- %%
ALTER TABLE [dbo].[DynamicHTMLTableHeaders] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__DynamicQu__IsAct__1758727B]

-- %%
ALTER TABLE [dbo].[DynamicQuestions] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__FinalRepo__IsAct__51EF2864]

-- %%
ALTER TABLE [dbo].[FinalReportGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__FinalRepo__Creat__52E34C9D]

-- %%
ALTER TABLE [dbo].[FinalReportGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__FinalRepo__Updat__53D770D6]

-- %%
ALTER TABLE [dbo].[FinalReportGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__FuelConve__IsAct__7E8CC4B1]

-- %%
ALTER TABLE [dbo].[FuelConvertionType] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__FuelType__IsActi__7BB05806]

-- %%
ALTER TABLE [dbo].[FuelType] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__FuelTypeB__IsAct__0BE6BFCF]

-- %%
ALTER TABLE [dbo].[FuelTypeBaseValue] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupDtl__IsAct__4589517F]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Creat__467D75B8]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Updat__477199F1]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__IsAct__40C49C62]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Creat__41B8C09B]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Updat__42ACE4D4]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__1DB06A4F]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__1EA48E88]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__1F98B2C1]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__208CD6FA]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__2180FB33]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__22751F6C]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__NICList__IsActiv__50C5FA01]

-- %%
ALTER TABLE [dbo].[NICList] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__NICList__Created__51BA1E3A]

-- %%
ALTER TABLE [dbo].[NICList] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__NICList__Updated__52AE4273]

-- %%
ALTER TABLE [dbo].[NICList] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__QuesDtl__IsActiv__731B1205]

-- %%
ALTER TABLE [dbo].[QuesDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__QuesDtl__Created__740F363E]

-- %%
ALTER TABLE [dbo].[QuesDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__QuesDtl__Updated__75035A77]

-- %%
ALTER TABLE [dbo].[QuesDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__QuesHdr__IsActiv__689D8392]

-- %%
ALTER TABLE [dbo].[QuesHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__QuesHdr__Created__6991A7CB]

-- %%
ALTER TABLE [dbo].[QuesHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__QuesHdr__Updated__6A85CC04]

-- %%
ALTER TABLE [dbo].[QuesHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Questions__IsAct__69C6B1F5]

-- %%
ALTER TABLE [dbo].[Questions] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Registrat__IsAct__634EBE90]

-- %%
ALTER TABLE [dbo].[Registration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Registrat__Creat__6442E2C9]

-- %%
ALTER TABLE [dbo].[Registration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Registrat__Updat__65370702]

-- %%
ALTER TABLE [dbo].[Registration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ReportCol__IsAct__075714DC]

-- %%
ALTER TABLE [dbo].[ReportCollaborators] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ReportCol__Creat__084B3915]

-- %%
ALTER TABLE [dbo].[ReportCollaborators] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ReportCol__Updat__093F5D4E]

-- %%
ALTER TABLE [dbo].[ReportCollaborators] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ReportEvi__IsAct__1DD065E0]

-- %%
ALTER TABLE [dbo].[ReportEvidence] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ReportEvi__Creat__1EC48A19]

-- %%
ALTER TABLE [dbo].[ReportEvidence] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ReportEvi__Updat__1FB8AE52]

-- %%
ALTER TABLE [dbo].[ReportEvidence] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ReportGen__IsAct__12FDD1B2]

-- %%
ALTER TABLE [dbo].[ReportGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ReportGen__Creat__13F1F5EB]

-- %%
ALTER TABLE [dbo].[ReportGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ReportGen__Updat__14E61A24]

-- %%
ALTER TABLE [dbo].[ReportGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ReportTem__IsAct__0880433F]

-- %%
ALTER TABLE [dbo].[ReportTemplateMenuId] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ReportTem__Creat__09746778]

-- %%
ALTER TABLE [dbo].[ReportTemplateMenuId] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ReportTem__Updat__0A688BB1]

-- %%
ALTER TABLE [dbo].[ReportTemplateMenuId] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ReportTem__IsAct__35A7EF71]

-- %%
ALTER TABLE [dbo].[ReportTemplateMenuIdforTemplate] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ReportTem__Creat__369C13AA]

-- %%
ALTER TABLE [dbo].[ReportTemplateMenuIdforTemplate] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ReportTem__Updat__379037E3]

-- %%
ALTER TABLE [dbo].[ReportTemplateMenuIdforTemplate] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RequestDa__IsAct__2334397B]

-- %%
ALTER TABLE [dbo].[RequestData] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__RequestDa__Creat__24285DB4]

-- %%
ALTER TABLE [dbo].[RequestData] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RequestDa__Updat__251C81ED]

-- %%
ALTER TABLE [dbo].[RequestData] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__2B0A656D]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__2BFE89A6]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__2CF2ADDF]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__2DE6D218]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__2EDAF651]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__2FCF1A8A]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__123EB7A3]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__1332DBDC]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__14270015]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Scope2Ste__IsAct__08D548FA]

-- %%
ALTER TABLE [dbo].[Scope2SteamHeat] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3avg__IsAct__3C89F72A]

-- %%
ALTER TABLE [dbo].[Scope3avgpiecebased] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__39AD8A7F]

-- %%
ALTER TABLE [dbo].[Scope3Categ1SupplierSpec] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__52793849]

-- %%
ALTER TABLE [dbo].[Scope3Category2shift] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__451F3D2B]

-- %%
ALTER TABLE [dbo].[Scope3Category2spend] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__668030F6]

-- %%
ALTER TABLE [dbo].[Scope3Category3elec] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__62AFA012]

-- %%
ALTER TABLE [dbo].[Scope3Category3Fuel] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__573DED66]

-- %%
ALTER TABLE [dbo].[Scope3Category4] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__6A50C1DA]

-- %%
ALTER TABLE [dbo].[Scope3Category5Waste] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__6F1576F7]

-- %%
ALTER TABLE [dbo].[Scope3Category5WasteMaterialNames] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__47FBA9D6]

-- %%
ALTER TABLE [dbo].[Scope3Category6hotel] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3Cat__IsAct__72E607DB]

-- %%
ALTER TABLE [dbo].[Scope3Category7] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3sco__IsAct__7C6F7215]

-- %%
ALTER TABLE [dbo].[Scope3scope1calc] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Scope3spe__IsAct__3F6663D5]

-- %%
ALTER TABLE [dbo].[Scope3spendbased] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Final__IsAct__76818E95]

-- %%
ALTER TABLE [dbo].[SGX_FinalReportGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Final__Creat__7775B2CE]

-- %%
ALTER TABLE [dbo].[SGX_FinalReportGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Final__Updat__7869D707]

-- %%
ALTER TABLE [dbo].[SGX_FinalReportGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__IsAct__0F4D3C5F]

-- %%
ALTER TABLE [dbo].[SGX_ReportEvidence] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__Creat__10416098]

-- %%
ALTER TABLE [dbo].[SGX_ReportEvidence] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__Updat__113584D1]

-- %%
ALTER TABLE [dbo].[SGX_ReportEvidence] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__IsAct__7B4643B2]

-- %%
ALTER TABLE [dbo].[SGX_ReportGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__Creat__7C3A67EB]

-- %%
ALTER TABLE [dbo].[SGX_ReportGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__Updat__7D2E8C24]

-- %%
ALTER TABLE [dbo].[SGX_ReportGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__IsAct__4C8B54C9]

-- %%
ALTER TABLE [dbo].[SGX_ReportTemplateMenuId] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__Creat__4D7F7902]

-- %%
ALTER TABLE [dbo].[SGX_ReportTemplateMenuId] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Repor__Updat__4E739D3B]

-- %%
ALTER TABLE [dbo].[SGX_ReportTemplateMenuId] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Templ__IsAct__45DE573A]

-- %%
ALTER TABLE [dbo].[SGX_TemplateMenuCategory] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Templ__Creat__46D27B73]

-- %%
ALTER TABLE [dbo].[SGX_TemplateMenuCategory] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Templ__Updat__47C69FAC]

-- %%
ALTER TABLE [dbo].[SGX_TemplateMenuCategory] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Valid__IsAct__216BEC9A]

-- %%
ALTER TABLE [dbo].[SGX_ValidatingFinalReport] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SGX_Valid__Creat__226010D3]

-- %%
ALTER TABLE [dbo].[SGX_ValidatingFinalReport] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SGX_Valid__Updat__2354350C]

-- %%
ALTER TABLE [dbo].[SGX_ValidatingFinalReport] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Signingof__IsAct__2C1E8537]

-- %%
ALTER TABLE [dbo].[SigningoffFinalReport] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Signingof__Creat__2D12A970]

-- %%
ALTER TABLE [dbo].[SigningoffFinalReport] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Signingof__Updat__2E06CDA9]

-- %%
ALTER TABLE [dbo].[SigningoffFinalReport] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__TemplateC__IsAct__7EC1CEDB]

-- %%
ALTER TABLE [dbo].[TemplateCheckboxMenuId] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__TemplateC__Creat__7FB5F314]

-- %%
ALTER TABLE [dbo].[TemplateCheckboxMenuId] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__TemplateC__Updat__00AA174D]

-- %%
ALTER TABLE [dbo].[TemplateCheckboxMenuId] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__TemplateG__IsAct__3E3D3572]

-- %%
ALTER TABLE [dbo].[TemplateGeneration] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__TemplateG__Creat__3F3159AB]

-- %%
ALTER TABLE [dbo].[TemplateGeneration] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__TemplateG__Updat__40257DE4]

-- %%
ALTER TABLE [dbo].[TemplateGeneration] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__TemplateM__IsAct__1C5231C2]

-- %%
ALTER TABLE [dbo].[TemplateMenuCategory] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__TemplateM__Creat__1D4655FB]

-- %%
ALTER TABLE [dbo].[TemplateMenuCategory] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__TemplateM__Updat__1E3A7A34]

-- %%
ALTER TABLE [dbo].[TemplateMenuCategory] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__60A75C0F]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__619B8048]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__628FA481]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Validatin__IsAct__22951AFD]

-- %%
ALTER TABLE [dbo].[ValidatingFinalReport] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Validatin__Creat__23893F36]

-- %%
ALTER TABLE [dbo].[ValidatingFinalReport] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Validatin__Updat__247D636F]

-- %%
ALTER TABLE [dbo].[ValidatingFinalReport] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK__BRSR_Temp__Frame__26CFC035]

-- %%
ALTER TABLE [dbo].[BRSR_TemplateMenu]  WITH CHECK ADD FOREIGN KEY([FrameworkId])
REFERENCES [dbo].[Framework] ([Id])
GO

-- %% [markdown]
-- # [FK__FuelConve__TypeI__7F80E8EA]

-- %%
ALTER TABLE [dbo].[FuelConvertionType]  WITH CHECK ADD FOREIGN KEY([TypeId])
REFERENCES [dbo].[FuelType] ([Id])
GO

-- %% [markdown]
-- # [FK__FuelTypeB__TypeI__0DCF0841]

-- %%
ALTER TABLE [dbo].[FuelTypeBaseValue]  WITH CHECK ADD FOREIGN KEY([TypeId])
REFERENCES [dbo].[FuelType] ([Id])
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK__SGX_Templ__Frame__4301EA8F]

-- %%
ALTER TABLE [dbo].[SGX_TemplateMenu]  WITH CHECK ADD FOREIGN KEY([FrameworkId])
REFERENCES [dbo].[Framework] ([Id])
GO

-- %% [markdown]
-- # [FK__TemplateM__Frame__04AFB25B]

-- %%
ALTER TABLE [dbo].[TemplateMenu]  WITH CHECK ADD FOREIGN KEY([FrameworkId])
REFERENCES [dbo].[Framework] ([Id])
GO

-- %% [markdown]
-- # [dbo].[GetScope1VehicleEmissionFactor]

-- %%
/****** Object:  StoredProcedure [dbo].[GetScope1VehicleEmissionFactor]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

-- Create the procedure
CREATE PROCEDURE [dbo].[GetScope1VehicleEmissionFactor]
    @Vehicle VARCHAR(255),
    @Type VARCHAR(255),
    @Fuel VARCHAR(255)
AS
BEGIN
    SET NOCOUNT ON;

    DECLARE @EmissionFactor DECIMAL(18, 5);

    -- Retrieve the Emissionfactor from the table based on parameters
    SELECT @EmissionFactor = Emissionfactor
    FROM [dbo].[Scope1CompanyVehicles]
    WHERE [Vehicle] = @Vehicle
    AND [Type] = @Type
    AND [Fuel] = @Fuel;

    -- Return the Emissionfactor as the result
    SELECT @EmissionFactor AS EmissionFactor;
END
GO

-- %% [markdown]
-- # [dbo].[ShowReportByonlyReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[ShowReportByonlyReportId]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[ShowReportByonlyReportId] (@ReportId varchar(255))
as
begin
select r.*,u.FirstName as Name,ui.FirstName as UpdatedName from ReportGeneration r
inner join Users u on u.Id=r.CreatedByUserId
inner join Users ui on ui.Id=r.UpdatedByUserId
 where r.ReportId=@ReportId ORDER BY UpdatedDate Desc;
end
GO

-- %% [markdown]
-- # [dbo].[ShowReportByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[ShowReportByReportId]    Script Date: 27-10-2023 14:37:38 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[ShowReportByReportId] (@OrgId varchar(255))
as
begin
    select r.*, u.FirstName as Name, ui.FirstName as UpdatedName,'GRI' as ReportType
    from ReportGeneration r
    inner join Users u on u.Id = r.CreatedByUserId
    inner join Users ui on ui.Id = r.UpdatedByUserId
    where r.OrgId = @OrgId 

    UNION ALL

    select br.*, u.FirstName as Name, ui.FirstName as UpdatedName,'BRSR' as ReportType
    from BRSR_ReportGeneration br
    inner join Users u on u.Id = br.CreatedByUserId
    inner join Users ui on ui.Id = br.UpdatedByUserId
    where br.OrgId = @OrgId 
    --ORDER BY UpdatedDate Desc;
	 UNION ALL

    select br.*, u.FirstName as Name, ui.FirstName as UpdatedName,'SGX' as ReportType
    from SGX_ReportGeneration br
    inner join Users u on u.Id = br.CreatedByUserId
    inner join Users ui on ui.Id = br.UpdatedByUserId
    where br.OrgId = @OrgId 
    ORDER BY UpdatedDate Desc;
end
GO

-- %% [markdown]
-- # [dbo].[ShowReportByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[ShowReportByUserId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[ShowReportByUserId] (@P_Id int)
as
begin
select * from ReportGeneration where CreatedByUserId=@P_Id
end
GO

-- %% [markdown]
-- # [dbo].[ShowSGX_ReportByonlyReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[ShowSGX_ReportByonlyReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[ShowSGX_ReportByonlyReportId] (@ReportId varchar(255))
as
begin
select r.*,u.FirstName as Name,ui.FirstName as UpdatedName from SGX_ReportGeneration r
inner join Users u on u.Id=r.CreatedByUserId
inner join Users ui on ui.Id=r.UpdatedByUserId
 where r.ReportId=@ReportId ORDER BY UpdatedDate Desc;
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddBlockChainTransaction]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBlockChainTransaction]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_AddBlockChainTransaction]
(
 @ReportId varchar(255),
 @S3URL varchar(500),
 @IPFSHash varchar(500),
 @PinSize int,
 @IPFSTimestamp datetime,
 @IsDuplicate bit,
 @BlockChainTransactionAddress varchar(500),
 @WalletAddress varchar(500),
 @TransactionGasFee int
)
as
begin

 insert into BlockChainTransaction(ReportId,S3URL,IPFSHash,PinSize,IPFSTimestamp,IsDuplicate,
 BlockChainTransactionAddress,WalletAddress,TransactionGasFee)
 values(@ReportId,@S3URL,@IPFSHash,@PinSize,@IPFSTimestamp,@IsDuplicate,@BlockChainTransactionAddress,
 @WalletAddress,@TransactionGasFee)

end
GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_FinalReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_FinalReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddBRSR_FinalReportGeneration]
(
	  @Id INT
	 ,@ReportName varchar(255)
	 ,@ReportId varchar(255)
	,@StartDate datetime
	,@EndDate datetime
    ,@CoverPageImage varchar(max)
	,@CoverPageLayout varchar(max)
	,@DesignTemplate varchar(max)
	,@Logo varchar(max)
	,@Introduction nvarchar(max)
	,@FinalDraftGuidance varchar(max)
	,@Reportpicbase varchar(max)
	,@Settings BIT =0
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@reportoutId int output 
	,@isPublished bit =0
	,@Messagefromceo nvarchar(max)
	,@aboutthisreport nvarchar(max)
	,@keyhighlights nvarchar(max)
	,@vision nvarchar(max)
	,@IsValidate nvarchar(max)
	,@IsSignoff nvarchar(max)
)
as
begin
If isnull(@Id,0)=0
begin
INSERT INTO [dbo].[BRSR_FinalReportGeneration] (
			     [ReportName]
				 ,ReportId
				,[StartDate]
				,[EndDate]
				,CoverPageImage
				,CoverPageLayout
				,DesignTemplate
				,Logo
				,Introduction
				,FinalDraftGuidance
				,Settings
				,Reportpicbase
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,isPublished
				,Messagefromceo
				,aboutthisreport
				,keyhighlights
				,vision
				,IsValidate
				,IsSignoff
				)
VALUES (
				 @ReportName
				 ,@ReportId
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CoverPageImage
				,@CoverPageLayout
				,@DesignTemplate
				,@Logo
				,@Introduction
				,@FinalDraftGuidance
				,@Reportpicbase
				,ISNULL(@Settings,0)
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@isPublished
				,@Messagefromceo
				,@aboutthisreport
				,@keyhighlights
				,@vision
				,@IsValidate
				,@IsSignoff
				)
				set @reportoutId=@@IDENTITY
end
else
begin
update BRSR_FinalReportGeneration Set ReportName=@ReportName,StartDate=@StartDate,EndDate=@EndDate,ReportId=@ReportId
,CoverPageImage=@CoverPageImage,CoverPageLayout=@CoverPageLayout,DesignTemplate=@DesignTemplate
,Logo=@Logo,Introduction=@Introduction,FinalDraftGuidance=@FinalDraftGuidance,Settings=@Settings,Reportpicbase=@Reportpicbase
,IsActive=@IsActive,CreatedDate=@CreatedDate,CreatedByUserId=@CreatedByUserId,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId,isPublished=@isPublished,
Messagefromceo=@Messagefromceo,aboutthisreport=@aboutthisreport,keyhighlights=@keyhighlights,vision=@vision,IsValidate=@IsValidate,IsSignoff=@IsSignoff
where ID=@ID
set @reportoutId=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_ReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_ReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_AddBRSR_ReportGeneration] (
	  @Id INT
	 ,@ReportName varchar(255)
	,@StartDate datetime
	,@EndDate datetime
	,@InitialDraftReport varchar(max)
	,@FinalDraftReport varchar(max)
	,@OrgId varchar(255)
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@reportoutId int output 
	,@ReportId varchar(255) output
	)
AS
BEGIN
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[BRSR_ReportGeneration] (
			     [ReportName]
				,[StartDate]
				,[EndDate]
				,InitialDraftReport
				,FinalDraftReport
				,OrgId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportName
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@InitialDraftReport
				,@FinalDraftReport
				,@OrgId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @reportoutId=@@IDENTITY
				declare @rId varchar(255)
				set @rId = NEWID()
				update BRSR_ReportGeneration set ReportId=@rId where Id = @reportoutId
				set @ReportId = @rId

				insert into BRSR_FinalReportGeneration(  
				[ReportName]
				,[StartDate]
				,[EndDate]
				,ReportId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
				values(
				 @ReportName
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@ReportId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)

end

else
begin
update BRSR_ReportGeneration Set ReportName=@ReportName,StartDate=@StartDate,EndDate=@EndDate,InitialDraftReport=@InitialDraftReport,FinalDraftReport=@FinalDraftReport,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
set @reportoutId=@Id
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_ReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddBRSR_ReportTemplateMenuId] (
	 @Id INT = NULL
	 ,@ReportId varchar(255)
	 ,@UserId int
	 ,@TemplateMenuId int
	 ,@Checked bit
	 ,@Status bit
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	)
AS
BEGIN
  declare @IId int
	     set @IId =(select count(*) from BRSR_ReportTemplateMenuId where
		 ReportId=@ReportId and TemplateMenuId=@TemplateMenuId and Checked=1)

			IF @IId = 0
			begin
			INSERT INTO [dbo].[BRSR_ReportTemplateMenuId] (
			     [ReportId]
				,[UserId]
				,[TemplateMenuId]
				,[Checked]
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportId
				,@UserId
				,@TemplateMenuId
				,@Checked
				,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
           end

else
begin
update BRSR_ReportTemplateMenuId Set ReportId=@ReportId,UserId=@UserId,TemplateMenuId=@TemplateMenuId,
Checked=@Checked,Status=@Status,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ReportId=@ReportId and TemplateMenuId=@TemplateMenuId
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_TemplateMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_TemplateMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddBRSR_TemplateMenu]
(@Id int,
@Code varchar(50),
@FrameworkId int,
@TemplateMenuName varchar(255),
@Description varchar(3000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into BRSR_TemplateMenu(
Code,
FrameworkId,
TemplateMenuName,
Description,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@FrameworkId,
@TemplateMenuName,
@Description,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update BRSR_TemplateMenu Set 
Code=@Code,FrameworkId=@FrameworkId,
TemplateMenuName=@TemplateMenuName,Description=@Description,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_TemplateMenuCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_TemplateMenuCategory]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddBRSR_TemplateMenuCategory]
(@Id int,
@TemplateMenuId int,
@Name varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into BRSR_TemplateMenuCategory(
TemplateMenuId,
Name,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@TemplateMenuId,
@Name,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update BRSR_TemplateMenuCategory Set 
TemplateMenuId=@TemplateMenuId,Name=@Name,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_TemplateSubMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_TemplateSubMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddBRSR_TemplateSubMenu]
(@Id int,
@Code varchar(50),
@TemplateMenuCategoryId int,
@TemplateMenuId int,
@TemplateSubMenuName varchar(255),
@Description varchar(3000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into BRSR_TemplateSubMenu(
Code,
TemplateMenuCategoryId,
TemplateMenuId,
TemplateSubMenuName,
Description,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@TemplateMenuCategoryId,
@TemplateMenuId,
@TemplateSubMenuName,
@Description,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update BRSR_TemplateSubMenu Set 
Code=@Code,TemplateMenuCategoryId=@TemplateMenuCategoryId,
TemplateMenuId=@TemplateMenuId,TemplateSubMenuName=@TemplateSubMenuName,Description=@Description,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_TemplateSubMenuItem]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_TemplateSubMenuItem]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddBRSR_TemplateSubMenuItem]
(@Id int,
@Code varchar(50),
@TemplateSubMenuId int,
@Guidance varchar(max),
@Description varchar(max),
@ScreenName varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into BRSR_TemplateSubMenuItem(
Code,
TemplateSubMenuId,
Guidance,
Description,
ScreenName,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@TemplateSubMenuId,
@Guidance,
@Description,
@ScreenName,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update BRSR_TemplateSubMenuItem Set 
Code=@Code,TemplateSubMenuId=@TemplateSubMenuId,
Guidance=@Guidance,ScreenName=@ScreenName,Description=@Description,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSR_ValidatingFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSR_ValidatingFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddBRSR_ValidatingFinalReport]
(
	@Id INT = NULL,
	@ReportId varchar(255),
	@OrgId varchar(255),
	@UserId varchar(255),
	@IsValidate varchar(55),
	@Remarks varchar(max),
	@IsActive BIT = 1,
	@CreatedDate DATETIME = NULL,
	@CreatedByUserId INT = NULL,
	@UpdatedDate DATETIME = NULL,
	@UpdatedByUserId INT = NULL
)
AS
BEGIN
	SET NOCOUNT ON;

	IF @Id IS NULL
	BEGIN
		IF EXISTS (SELECT 1 FROM [dbo].[BRSR_ValidatingFinalReport] WHERE UserId = @UserId AND ReportId = @ReportId)
		BEGIN
			UPDATE [dbo].[BRSR_ValidatingFinalReport]
			SET
				IsValidate = @IsValidate,
				Remarks = @Remarks,
				IsActive = ISNULL(@IsActive, 1),
				CreatedDate = ISNULL(@CreatedDate, GETDATE()),
				CreatedByUserId = @CreatedByUserId,
				UpdatedDate = ISNULL(@UpdatedDate, GETDATE()),
				UpdatedByUserId = @UpdatedByUserId
			WHERE
				UserId = @UserId
				AND ReportId = @ReportId;
		END
		ELSE
		BEGIN
			INSERT INTO [dbo].[BRSR_ValidatingFinalReport]
			(
				ReportId,
				OrgId,
				UserId,
				IsValidate,
				Remarks,
				[IsActive],
				[CreatedDate],
				[CreatedByUserId],
				[UpdatedDate],
				[UpdatedByUserId]
			)
			VALUES
			(
				@ReportId,
				@OrgId,
				@UserId,
				@IsValidate,
				@Remarks,
				ISNULL(@IsActive, 1),
				ISNULL(@CreatedDate, GETDATE()),
				@CreatedByUserId,
				ISNULL(@UpdatedDate, GETDATE()),
				@UpdatedByUserId
			);
		END
	END
	ELSE
	BEGIN
		UPDATE [dbo].[BRSR_ValidatingFinalReport]
		SET
			ReportId = @ReportId,
			OrgId = @OrgId,
			IsValidate = @IsValidate,
			Remarks = @Remarks,
			IsActive = @IsActive,
			CreatedDate = @CreatedDate,
			CreatedByUserId = @CreatedByUserId,
			UpdatedDate = @UpdatedDate,
			UpdatedByUserId = @UpdatedByUserId
		WHERE
			ID = @ID;
	END
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddBRSRReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBRSRReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddBRSRReportEvidence]
(@Id int,
@ReportId varchar(255),
@OrgId varchar(255),
@GuidanceNumber varchar(255),
@QuestionCode nvarchar(max),
@FileName varchar(255),
@UploadedObj varchar(max),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
if ISNULL(@Id,0) = 0
begin
insert into BRSR_ReportEvidence(
ReportId,
OrgId,
GuidanceNumber,
QuestionCode,
FileName,
UploadedObj,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ReportId,
@OrgId,
@GuidanceNumber,
@QuestionCode,
@FileName,
@UploadedObj,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update BRSR_ReportEvidence Set ReportId=@ReportId,
OrgId=@OrgId,GuidanceNumber=@GuidanceNumber,QuestionCode=@QuestionCode,FileName=@FileName,
UploadedObj=@UploadedObj,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate  where Id=@Id
end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddCA_Scope1CompanyFacilities]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCA_Scope1CompanyFacilities]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddCA_Scope1CompanyFacilities] 
(
 @Id int
,@FuelType nVarchar(255)
,@Noofunits int
,@Units Varchar(255)
,@GWPFactor Varchar(255)
,@MetricCO2e nVarchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@OrgId varchar(255)
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION
  BEGIN TRY
        IF ISNULL(@Id,0)=0
		BEGIN
            INSERT INTO [dbo].[CA_Scope1CompanyFacilities] (
                 [FuelType]
                ,[Noofunits]
                ,[Units]
                ,[GWPFactor]
                ,[MetricCO2e]
				,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
				,OrgId
                )
            VALUES (
                @FuelType
                ,@Noofunits
                ,@Units
                ,@GWPFactor
                ,@MetricCO2e
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
				,@OrgId
                )
		END
        ELSE
BEGIN
            UPDATE [dbo].[CA_Scope1CompanyFacilities]
            SET  
                [FuelType] = @FuelType
                ,[Noofunits] = @Noofunits
                ,[Units] = @Units
                ,[GWPFactor] = @GWPFactor
                ,[MetricCO2e] = @MetricCO2e
                ,[IsActive] = ISNULL(@IsActive, 1)
                 ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
				,OrgId=@OrgId
            WHERE Id = @Id
END
    END TRY
    BEGIN CATCH
        SELECT @ErrorNumber = ERROR_NUMBER()
            ,@ErrorMessage = ERROR_MESSAGE()
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
    END CATCH;
    IF @@TRANCOUNT > 0
        COMMIT TRANSACTION;
    SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCA_Scope1CompanyVehicles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCA_Scope1CompanyVehicles]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_AddCA_Scope1CompanyVehicles] 
(
 @Id int
,@Vehicle Varchar(255)
,@Type Varchar(255)
,@Fuel Varchar(255)
,@EmissionFactor decimal(18,5)
,@Distance Varchar(255)
,@tCO2e nVarchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@OrgId varchar(255)
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION
  BEGIN TRY
        IF ISNULL(@Id,0)=0
		BEGIN
            INSERT INTO [dbo].[CA_Scope1CompanyVehicles] (
                 [Vehicle]
                ,[Type]
                ,[Fuel]
                ,[EmissionFactor]
                ,[Distance]
				,tCO2e
				,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
				,OrgId
                )
            VALUES (
                @Vehicle
                ,@Type
                ,@Fuel
                ,@EmissionFactor
                ,@Distance
				,@tCO2e
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
				,@OrgId
                )
		END
        ELSE
BEGIN
            UPDATE [dbo].[CA_Scope1CompanyVehicles]
            SET  
                [Vehicle] = @Vehicle
                ,[Type] = @Type
                ,[Fuel] = @Fuel
                ,[EmissionFactor] = @EmissionFactor
                ,[Distance] = @Distance
				,tCO2e=@tCO2e
                ,[IsActive] = ISNULL(@IsActive, 1)
                 ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
				,OrgId=@OrgId
            WHERE Id = @Id
END
    END TRY
    BEGIN CATCH
        SELECT @ErrorNumber = ERROR_NUMBER()
            ,@ErrorMessage = ERROR_MESSAGE()
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
    END CATCH;
    IF @@TRANCOUNT > 0
        COMMIT TRANSACTION;
    SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCA_Scope1Fugitives]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCA_Scope1Fugitives]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_AddCA_Scope1Fugitives] 
(
 @Id int
,@Emission Varchar(255)
,@Factorperkg int
,@Amount NVarchar(255)
,@tCO2e NVarchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@OrgId varchar(255)
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION
  BEGIN TRY
        IF ISNULL(@Id,0)=0
		BEGIN
            INSERT INTO [dbo].[CA_Scope1Fugitives] (
                 [Emission]
                ,[Factorperkg]
                ,[Amount]
                ,[tCO2e]
				,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
				,OrgId
                )
            VALUES (
                @Emission
                ,@Factorperkg
                ,@Amount
                ,@tCO2e
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
				,@OrgId
                )
		END
        ELSE
BEGIN
            UPDATE [dbo].[CA_Scope1Fugitives]
            SET  
                Emission = @Emission
                ,Factorperkg = @Factorperkg
                ,Amount = @Amount
                ,tCO2e = @tCO2e
                ,[IsActive] = ISNULL(@IsActive, 1)
                 ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
				,OrgId=@OrgId
            WHERE Id = @Id
END
    END TRY
    BEGIN CATCH
        SELECT @ErrorNumber = ERROR_NUMBER()
            ,@ErrorMessage = ERROR_MESSAGE()
        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
    END CATCH;
    IF @@TRANCOUNT > 0
        COMMIT TRANSACTION;
    SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddCountries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCountries]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddCountries]
(@Id int,
@Code varchar(50),
@CountryName varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into Countries(
Code,
CountryName,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@CountryName,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update Countries Set Code=@Code,CountryName=@CountryName,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddFinalReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFinalReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddFinalReportGeneration]
(
	  @Id INT
	 ,@ReportName varchar(255)
	 ,@ReportId varchar(255)
	,@StartDate datetime
	,@EndDate datetime
    ,@CoverPageImage varchar(max)
	,@CoverPageLayout varchar(max)
	,@DesignTemplate varchar(max)
	,@Logo varchar(max)
	,@Introduction nvarchar(max)
	,@FinalDraftGuidance varchar(max)
	,@Reportpicbase varchar(max)
	,@Messagefromceo nvarchar(max)
	,@aboutthisreport nvarchar(max)
	,@keyhighlights nvarchar(max)
	,@vision nvarchar(max)
	,@IsValidate varchar(255)
	,@IsSignoff varchar(255)
	,@Settings INT
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@reportoutId int output 
	,@isPublished bit =0
)
as
begin
If isnull(@Id,0)=0
begin
INSERT INTO [dbo].[FinalReportGeneration] (
			     [ReportName]
				 ,ReportId
				,[StartDate]
				,[EndDate]
				,CoverPageImage
				,CoverPageLayout
				,DesignTemplate
				,Logo
				,Introduction
				,FinalDraftGuidance
				,Settings
				,Reportpicbase
				,Messagefromceo
				,aboutthisreport
				,keyhighlights
				,vision
				,IsSignoff
				,IsValidate
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,isPublished
				)
VALUES (
				 @ReportName
				 ,@ReportId
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CoverPageImage
				,@CoverPageLayout
				,@DesignTemplate
				,@Logo
				,@Introduction
				,@FinalDraftGuidance
				,@Reportpicbase
				,@Messagefromceo
				,@aboutthisreport
				,@keyhighlights
				,@vision
				,@IsSignoff
				,@IsValidate
				,ISNULL(@Settings,0)
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@isPublished
				)
				set @reportoutId=@@IDENTITY
end
else
begin
update FinalReportGeneration Set ReportName=@ReportName,StartDate=@StartDate,EndDate=@EndDate,ReportId=@ReportId
,CoverPageImage=@CoverPageImage,CoverPageLayout=@CoverPageLayout,DesignTemplate=@DesignTemplate
,Logo=@Logo,Introduction=@Introduction,FinalDraftGuidance=@FinalDraftGuidance,Settings=@Settings,Reportpicbase=@Reportpicbase
,Messagefromceo=@Messagefromceo,aboutthisreport=@aboutthisreport,keyhighlights=@keyhighlights,vision=@vision,IsValidate=@IsValidate,IsSignoff=@IsSignoff
,IsActive=@IsActive,CreatedDate=@CreatedDate,CreatedByUserId=@CreatedByUserId,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId,isPublished=@isPublished
where ID=@ID
set @reportoutId=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupDtl]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddLookupDtl] 
(
 @Id int
,@LookupHdrId int
,@Code varchar(255)
,@Name varchar(100)
,@Remarks varchar(100)
,@Ord int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookupdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupDtl] (
				  [LookupHdrId]
				,[Code]
				,[Name]
				,[Remarks]
				,[Ord]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @LookupHdrId
				,@Code
				,@Name
				,@Remarks
				,@Ord
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookupdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[LookupDtl]
			SET  [LookupHdrId] = @LookupHdrId
			,[Code] = @Code
				,[Name] = @Name
				,[Remarks] = @Remarks
				,[Ord] = @Ord
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookupdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupHdr]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddLookupHdr] 
(
 @Id int,
 @Code Varchar(255)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookuphdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupHdr] (
					 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 	 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookuphdrOUT = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[LookupHdr]
			SET  
				[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookuphdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRegistration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRegistration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRegistration] 
(
 @Id int
,@OrganizationName varchar(255)
,@OrganizationType varchar(255)
,@HeadOffice varchar(255)
,@Country varchar(255)
,@Pincode bigint
,@ContactName varchar(255)
,@EmailId varchar(255)
,@ContactNumber bigint
,@Designation varchar(255)
,@EncryptedPassword varchar(255)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
,@registrationOUT int OUTPUT
,@OrgId varchar(255) output
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].Registration(
				 [OrganizationName]
				,[OrganizationType]
				,[HeadOffice]
				,[Country]
				,[Pincode]
				,[ContactName]
				,[EmailId]
				,[ContactNumber]
				,[Designation]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@OrganizationName
				,@OrganizationType
				,@HeadOffice
				,@Country
				,@Pincode
				,@ContactName
				,@EmailId
				,@ContactNumber
				,@Designation
					,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				--,@CreatedByUserId
				,1
				,ISNULL(@UpdatedDate, GETDATE())
				--,@UpdatedByUserId
				,1
				)
				set @registrationOUT = @@IDENTITY
				declare @OutId int
				set @OutId = @@IDENTITY
				declare @OrgIId varchar(255)
				set @OrgIId = NEWID()
				update Registration set OrgId=@OrgIId where Id=@registrationOUT
				set @OrgId = @OrgIId
				--insert into Users(UserName,Password,FirstName,LastName,EmailId,MobileNumber,
				--ViewYN,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,RoleId,RegistrationId)
				--values(@EmailId,@EncryptedPassword,@ContactName,@ContactName,@EmailId,@ContactNumber,1,1,getdate(),1,getdate(),1,@OutId)
				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
		begin
			UPDATE [dbo].Registration
				SET  
				[OrganizationName] = @OrganizationName
				,[OrganizationType] = @OrganizationType
				,[HeadOffice] = @HeadOffice
				,[Country] = @Country
				,[Pincode] = @Pincode
				,[ContactName] = @ContactName
				,[EmailId] = @EmailId
				,[ContactNumber] = @ContactNumber
				,[Designation] = @Designation
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				--,[UpdatedByUserId] = @UpdatedByUserId
				,[UpdatedByUserId] =1
			WHERE Id = @Id
			set @registrationOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddReportCollaborators]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddReportCollaborators]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddReportCollaborators]
(@Id int,
@ReportId varchar(255),
@OrgId varchar(255),
@CollaboratorId int,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into ReportCollaborators(
ReportId,
OrgId,
CollaboratorId,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ReportId,
@OrgId,
@CollaboratorId,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update ReportCollaborators Set ReportId=@ReportId,OrgId=@OrgId,CollaboratorId=@CollaboratorId,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddReportEvidence]
(@Id int,
@ReportId varchar(255),
@OrgId varchar(255),
@GuidanceNumber varchar(255),
@QuestionCode varchar(255),
@FileName varchar(255),
@UploadedObj varchar(max),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
if ISNULL(@Id,0) = 0
begin
insert into ReportEvidence(
ReportId,
OrgId,
GuidanceNumber,
QuestionCode,
FileName,
UploadedObj,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ReportId,
@OrgId,
@GuidanceNumber,
@QuestionCode,
@FileName,
@UploadedObj,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update ReportEvidence Set ReportId=@ReportId,
OrgId=@OrgId,GuidanceNumber=@GuidanceNumber,QuestionCode=@QuestionCode,FileName=@FileName,
UploadedObj=@UploadedObj,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate  where Id=@Id
end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddReportGeneration] (
	  @Id INT
	 ,@ReportName varchar(255)
	,@StartDate datetime
	,@EndDate datetime
	,@InitialDraftReport nvarchar(max)
	,@FinalDraftReport varchar(max)
	,@OrgId varchar(255)
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@reportoutId int output 
	,@ReportId varchar(255) output
	)
AS
BEGIN
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[ReportGeneration] (
			     [ReportName]
				,[StartDate]
				,[EndDate]
				,InitialDraftReport
				,FinalDraftReport
				,OrgId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportName
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@InitialDraftReport
				,@FinalDraftReport
				,@OrgId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @reportoutId=@@IDENTITY
				declare @rId varchar(255)
				set @rId = NEWID()
				update ReportGeneration set ReportId=@rId where Id = @reportoutId
				set @ReportId = @rId

				insert into FinalReportGeneration(  
				[ReportName]
				,[StartDate]
				,[EndDate]
				,ReportId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
				values(
				 @ReportName
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@ReportId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)

end

else
begin
update ReportGeneration Set ReportName=@ReportName,StartDate=@StartDate,EndDate=@EndDate,InitialDraftReport=@InitialDraftReport,FinalDraftReport=@FinalDraftReport,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
set @reportoutId=@Id
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddReportPictures]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddReportPictures]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddReportPictures]
(@Id int,
@Name varchar(255),
@Picture varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into ReportPictures(
Name,
Picture,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Name,
@Picture,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update ReportPictures Set Name=@Name,Picture=@Picture,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddReportTemplateMenuId] (
	 @Id INT = NULL
	 ,@ReportId varchar(255)
	 ,@UserId int
	 ,@TemplateMenuId int
	 ,@Checked bit
	 ,@Status bit
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	)
AS
BEGIN
  declare @IId int
	     set @IId =(select count(*) from ReportTemplateMenuId where
		 ReportId=@ReportId and TemplateMenuId=@TemplateMenuId and Checked=1)

			IF @IId = 0
			begin
			INSERT INTO [dbo].[ReportTemplateMenuId] (
			     [ReportId]
				,[UserId]
				,[TemplateMenuId]
				,[Checked]
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportId
				,@UserId
				,@TemplateMenuId
				,@Checked
				,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
           end

else
begin
update ReportTemplateMenuId Set ReportId=@ReportId,UserId=@UserId,TemplateMenuId=@TemplateMenuId,
Checked=@Checked,Status=@Status,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ReportId=@ReportId and TemplateMenuId=@TemplateMenuId
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddReportTemplateMenuIdforTemplate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddReportTemplateMenuIdforTemplate]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddReportTemplateMenuIdforTemplate] (
	 @Id INT = NULL
	 ,@ReportId varchar(255)
	 ,@UserId int
	 ,@TemplateMenuId int
	 ,@Checked bit
	 ,@Status bit
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	)
AS
BEGIN
  declare @IId int
	     set @IId =(select count(*) from ReportTemplateMenuIdforTemplate where
		 ReportId=@ReportId and TemplateMenuId=@TemplateMenuId and Checked=1)

			IF @IId = 0
			begin
			INSERT INTO [dbo].[ReportTemplateMenuIdforTemplate] (
			     [ReportId]
				,[UserId]
				,[TemplateMenuId]
				,[Checked]
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportId
				,@UserId
				,@TemplateMenuId
				,@Checked
				,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
           end

else
begin
update ReportTemplateMenuIdforTemplate Set ReportId=@ReportId,UserId=@UserId,TemplateMenuId=@TemplateMenuId,
Checked=@Checked,Status=@Status,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ReportId=@ReportId and TemplateMenuId=@TemplateMenuId
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddRequestData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRequestData]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddRequestData]
(@Id int,
@ReportId varchar(255),
@GuidanceNumber varchar(255),
@RequestedBy varchar(255),
@RequestedTo varchar(255),
@RequestedMessage varchar(255),
@Response varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into RequestData(
ReportId,
GuidanceNumber,
RequestedBy,
RequestedTo,
RequestedMessage,
Response,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ReportId,
@GuidanceNumber,
@RequestedBy,
@RequestedTo,
@RequestedMessage,
@Response,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update RequestData Set ReportId=@ReportId,GuidanceNumber=@GuidanceNumber,
RequestedBy=@RequestedBy,RequestedTo=@RequestedTo,
RequestedMessage=@RequestedMessage,Response=@Response,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Code]
				,[Name]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Code] = @Code
				,[Name] = @Name
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_FinalReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_FinalReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddSGX_FinalReportGeneration]
(
	  @Id INT
	 ,@ReportName varchar(255)
	 ,@ReportId varchar(255)
	,@StartDate datetime
	,@EndDate datetime
    ,@CoverPageImage varchar(max)
	,@CoverPageLayout varchar(max)
	,@DesignTemplate varchar(max)
	,@Logo varchar(max)
	,@Introduction nvarchar(max)
	,@FinalDraftGuidance varchar(max)
	,@Reportpicbase varchar(max)
	,@Settings BIT =0
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@reportoutId int output 
	,@isPublished bit =0
	,@Messagefromceo nvarchar(max)
	,@aboutthisreport nvarchar(max)
	,@keyhighlights nvarchar(max)
	,@vision nvarchar(max)
	,@IsValidate nvarchar(max)
	,@IsSignoff nvarchar(max)
)
as
begin
If isnull(@Id,0)=0
begin
INSERT INTO [dbo].[SGX_FinalReportGeneration] (
			     [ReportName]
				 ,ReportId
				,[StartDate]
				,[EndDate]
				,CoverPageImage
				,CoverPageLayout
				,DesignTemplate
				,Logo
				,Introduction
				,FinalDraftGuidance
				,Settings
				,Reportpicbase
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,isPublished
				,Messagefromceo
				,aboutthisreport
				,keyhighlights
				,vision
				,IsValidate
				,IsSignoff
				)
VALUES (
				 @ReportName
				 ,@ReportId
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CoverPageImage
				,@CoverPageLayout
				,@DesignTemplate
				,@Logo
				,@Introduction
				,@FinalDraftGuidance
				,@Reportpicbase
				,ISNULL(@Settings,0)
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@isPublished
				,@Messagefromceo
				,@aboutthisreport
				,@keyhighlights
				,@vision
				,@IsValidate
				,@IsSignoff
				)
				set @reportoutId=@@IDENTITY
end
else
begin
update SGX_FinalReportGeneration Set ReportName=@ReportName,StartDate=@StartDate,EndDate=@EndDate,ReportId=@ReportId
,CoverPageImage=@CoverPageImage,CoverPageLayout=@CoverPageLayout,DesignTemplate=@DesignTemplate
,Logo=@Logo,Introduction=@Introduction,FinalDraftGuidance=@FinalDraftGuidance,Settings=@Settings,Reportpicbase=@Reportpicbase
,IsActive=@IsActive,CreatedDate=@CreatedDate,CreatedByUserId=@CreatedByUserId,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId,isPublished=@isPublished,
Messagefromceo=@Messagefromceo,aboutthisreport=@aboutthisreport,keyhighlights=@keyhighlights,vision=@vision,IsValidate=@IsValidate,IsSignoff=@IsSignoff
where ID=@ID
set @reportoutId=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_ReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_ReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddSGX_ReportGeneration] (
	  @Id INT
	 ,@ReportName varchar(255)
	,@StartDate datetime
	,@EndDate datetime
	,@InitialDraftReport varchar(max)
	,@FinalDraftReport varchar(max)
	,@OrgId varchar(255)
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@reportoutId int output 
	,@ReportId varchar(255) output
	)
AS
BEGIN
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[SGX_ReportGeneration] (
			     [ReportName]
				,[StartDate]
				,[EndDate]
				,InitialDraftReport
				,FinalDraftReport
				,OrgId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportName
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@InitialDraftReport
				,@FinalDraftReport
				,@OrgId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @reportoutId=@@IDENTITY
				declare @rId varchar(255)
				set @rId = NEWID()
				update SGX_ReportGeneration set ReportId=@rId where Id = @reportoutId
				set @ReportId = @rId

				insert into SGX_FinalReportGeneration(  
				[ReportName]
				,[StartDate]
				,[EndDate]
				,ReportId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
				values(
				 @ReportName
				,@StartDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@EndDate AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@ReportId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)

end

else
begin
update SGX_ReportGeneration Set ReportName=@ReportName,StartDate=@StartDate,EndDate=@EndDate,InitialDraftReport=@InitialDraftReport,FinalDraftReport=@FinalDraftReport,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
set @reportoutId=@Id
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_ReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddSGX_ReportTemplateMenuId] (
	 @Id INT = NULL
	 ,@ReportId varchar(255)
	 ,@UserId int
	 ,@TemplateMenuId int
	 ,@Checked bit
	 ,@Status bit
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	)
AS
BEGIN
  declare @IId int
	     set @IId =(select count(*) from SGX_ReportTemplateMenuId where
		 ReportId=@ReportId and TemplateMenuId=@TemplateMenuId and Checked=1)

			IF @IId = 0
			begin
			INSERT INTO [dbo].[SGX_ReportTemplateMenuId] (
			     [ReportId]
				,[UserId]
				,[TemplateMenuId]
				,[Checked]
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @ReportId
				,@UserId
				,@TemplateMenuId
				,@Checked
				,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
           end

else
begin
update SGX_ReportTemplateMenuId Set ReportId=@ReportId,UserId=@UserId,TemplateMenuId=@TemplateMenuId,
Checked=@Checked,Status=@Status,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ReportId=@ReportId and TemplateMenuId=@TemplateMenuId
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_TemplateMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_TemplateMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddSGX_TemplateMenu]
(@Id int,
@Code varchar(50),
@FrameworkId int,
@TemplateMenuName varchar(255),
@Description varchar(3000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into SGX_TemplateMenu(
Code,
FrameworkId,
TemplateMenuName,
Description,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@FrameworkId,
@TemplateMenuName,
@Description,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update SGX_TemplateMenu Set 
Code=@Code,FrameworkId=@FrameworkId,
TemplateMenuName=@TemplateMenuName,Description=@Description,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_TemplateMenuCategory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_TemplateMenuCategory]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddSGX_TemplateMenuCategory]
(@Id int,
@TemplateMenuId int,
@Name varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into SGX_TemplateMenuCategory(
TemplateMenuId,
Name,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@TemplateMenuId,
@Name,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update SGX_TemplateMenuCategory Set 
TemplateMenuId=@TemplateMenuId,Name=@Name,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_TemplateSubMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_TemplateSubMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddSGX_TemplateSubMenu]
(@Id int,
@Code varchar(50),
@TemplateMenuCategoryId int,
@TemplateMenuId int,
@TemplateSubMenuName varchar(255),
@Description varchar(3000),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into SGX_TemplateSubMenu(
Code,
TemplateMenuCategoryId,
TemplateMenuId,
TemplateSubMenuName,
Description,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@TemplateMenuCategoryId,
@TemplateMenuId,
@TemplateSubMenuName,
@Description,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update SGX_TemplateSubMenu Set 
Code=@Code,TemplateMenuCategoryId=@TemplateMenuCategoryId,
TemplateMenuId=@TemplateMenuId,TemplateSubMenuName=@TemplateSubMenuName,Description=@Description,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_TemplateSubMenuItem]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_TemplateSubMenuItem]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddSGX_TemplateSubMenuItem]
(@Id int,
@Code varchar(50),
@TemplateSubMenuId int,
@Guidance varchar(max),
@Description varchar(max),
@ScreenName varchar(255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
If isnull(@Id,0)=0
begin
insert into SGX_TemplateSubMenuItem(
Code,
TemplateSubMenuId,
Guidance,
Description,
ScreenName,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@Code,
@TemplateSubMenuId,
@Guidance,
@Description,
@ScreenName,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update SGX_TemplateSubMenuItem Set 
Code=@Code,TemplateSubMenuId=@TemplateSubMenuId,
Guidance=@Guidance,ScreenName=@ScreenName,Description=@Description,@IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate where Id=@Id
end
end








GO

-- %% [markdown]
-- # [dbo].[SP_AddSGX_ValidatingFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGX_ValidatingFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddSGX_ValidatingFinalReport]
(
	@Id INT = NULL,
	@ReportId varchar(255),
	@OrgId varchar(255),
	@UserId varchar(255),
	@IsValidate varchar(55),
	@Remarks varchar(max),
	@IsActive BIT = 1,
	@CreatedDate DATETIME = NULL,
	@CreatedByUserId INT = NULL,
	@UpdatedDate DATETIME = NULL,
	@UpdatedByUserId INT = NULL
)
AS
BEGIN
	SET NOCOUNT ON;

	IF @Id IS NULL
	BEGIN
		IF EXISTS (SELECT 1 FROM [dbo].[SGX_ValidatingFinalReport] WHERE UserId = @UserId AND ReportId = @ReportId)
		BEGIN
			UPDATE [dbo].[SGX_ValidatingFinalReport]
			SET
				IsValidate = @IsValidate,
				Remarks = @Remarks,
				IsActive = ISNULL(@IsActive, 1),
				CreatedDate = ISNULL(@CreatedDate, GETDATE()),
				CreatedByUserId = @CreatedByUserId,
				UpdatedDate = ISNULL(@UpdatedDate, GETDATE()),
				UpdatedByUserId = @UpdatedByUserId
			WHERE
				UserId = @UserId
				AND ReportId = @ReportId;
		END
		ELSE
		BEGIN
			INSERT INTO [dbo].[SGX_ValidatingFinalReport]
			(
				ReportId,
				OrgId,
				UserId,
				IsValidate,
				Remarks,
				[IsActive],
				[CreatedDate],
				[CreatedByUserId],
				[UpdatedDate],
				[UpdatedByUserId]
			)
			VALUES
			(
				@ReportId,
				@OrgId,
				@UserId,
				@IsValidate,
				@Remarks,
				ISNULL(@IsActive, 1),
				ISNULL(@CreatedDate, GETDATE()),
				@CreatedByUserId,
				ISNULL(@UpdatedDate, GETDATE()),
				@UpdatedByUserId
			);
		END
	END
	ELSE
	BEGIN
		UPDATE [dbo].[SGX_ValidatingFinalReport]
		SET
			ReportId = @ReportId,
			OrgId = @OrgId,
			IsValidate = @IsValidate,
			Remarks = @Remarks,
			IsActive = @IsActive,
			CreatedDate = @CreatedDate,
			CreatedByUserId = @CreatedByUserId,
			UpdatedDate = @UpdatedDate,
			UpdatedByUserId = @UpdatedByUserId
		WHERE
			ID = @ID;
	END
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSGXReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSGXReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Procedure [dbo].[SP_AddSGXReportEvidence]
(@Id int,
@ReportId varchar(255),
@OrgId varchar(255),
@GuidanceNumber varchar(255),
@QuestionCode varchar(255),
@FileName varchar(255),
@UploadedObj varchar(max),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as
begin
if ISNULL(@Id,0) = 0
begin
insert into SGX_ReportEvidence(
ReportId,
OrgId,
GuidanceNumber,
QuestionCode,
FileName,
UploadedObj,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@ReportId,
@OrgId,
@GuidanceNumber,
@QuestionCode,
@FileName,
@UploadedObj,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
end
else
begin
update SGX_ReportEvidence Set ReportId=@ReportId,
OrgId=@OrgId,GuidanceNumber=@GuidanceNumber,QuestionCode=@QuestionCode,FileName=@FileName,
UploadedObj=@UploadedObj,IsActive=@IsActive,
UpdatedByUserId=@UpdatedByUserId,UpdatedDate=@UpdatedDate  where Id=@Id
end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddSigningoffFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSigningoffFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddSigningoffFinalReport]
(
	@Id INT = NULL,
	@ReportId varchar(255),
	@OrgId varchar(255),
	@UserId varchar(255),
	@IsSignoff varchar(55),
	@Remarks varchar(max),
	@IsActive BIT = 1,
	@CreatedDate DATETIME = NULL,
	@CreatedByUserId INT = NULL,
	@UpdatedDate DATETIME = NULL,
	@UpdatedByUserId INT = NULL
)
AS
BEGIN
	SET NOCOUNT ON;

	IF @Id IS NULL
	BEGIN
		IF EXISTS (SELECT 1 FROM [dbo].[SigningoffFinalReport] WHERE UserId = @UserId AND ReportId = @ReportId)
		BEGIN
			UPDATE [dbo].[SigningoffFinalReport]
			SET
				IsSignoff = @IsSignoff,
				Remarks = @Remarks,
				IsActive = ISNULL(@IsActive, 1),
				CreatedDate = ISNULL(@CreatedDate, GETDATE()),
				CreatedByUserId = @CreatedByUserId,
				UpdatedDate = ISNULL(@UpdatedDate, GETDATE()),
				UpdatedByUserId = @UpdatedByUserId
			WHERE
				UserId = @UserId
				AND ReportId = @ReportId;
		END
		ELSE
		BEGIN
			INSERT INTO [dbo].[SigningoffFinalReport]
			(
				ReportId,
				OrgId,
				UserId,
				IsSignoff,
				Remarks,
				[IsActive],
				[CreatedDate],
				[CreatedByUserId],
				[UpdatedDate],
				[UpdatedByUserId]
			)
			VALUES
			(
				@ReportId,
				@OrgId,
				@UserId,
				@IsSignoff,
				@Remarks,
				ISNULL(@IsActive, 1),
				ISNULL(@CreatedDate, GETDATE()),
				@CreatedByUserId,
				ISNULL(@UpdatedDate, GETDATE()),
				@UpdatedByUserId
			);
		END
	END
	ELSE
	BEGIN
		UPDATE [dbo].[SigningoffFinalReport]
		SET
			ReportId = @ReportId,
			OrgId = @OrgId,
			IsSignoff = @IsSignoff,
			Remarks = @Remarks,
			IsActive = @IsActive,
			CreatedDate = @CreatedDate,
			CreatedByUserId = @CreatedByUserId,
			UpdatedDate = @UpdatedDate,
			UpdatedByUserId = @UpdatedByUserId
		WHERE
			ID = @ID;
	END
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddTemplateCheckboxMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTemplateCheckboxMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddTemplateCheckboxMenuId] (
	 @Id INT = NULL
	 ,@TemplateId varchar(255)
	 ,@UserId int
	 ,@TemplateSubMenuId int
	 ,@Checked bit
	 ,@Status bit
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	)
AS
BEGIN
  declare @IId int
	     set @IId =(select count(*) from TemplateCheckboxMenuId where
		 TemplateId=@TemplateId and TemplateSubMenuId=@TemplateSubMenuId)

			IF @IId = 0
			begin
			INSERT INTO [dbo].[TemplateCheckboxMenuId] (
			     [TemplateId]
				,[UserId]
				,[TemplateSubMenuId]
				,[Checked]
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @TemplateId
				,@UserId
				,@TemplateSubMenuId
				,@Checked
				,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
           end

else
begin
update TemplateCheckboxMenuId Set TemplateId=@TemplateId,UserId=@UserId,TemplateSubMenuId=@TemplateSubMenuId,
Checked=@Checked,Status=@Status,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where TemplateId=@TemplateId and TemplateSubMenuId=@TemplateSubMenuId
 
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddTemplateDesignbyScreen]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTemplateDesignbyScreen]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_AddTemplateDesignbyScreen] (
	  @Id INT
	 ,@TemplateSubMenuId int
	,@ScreenName varchar(255)
	,@ReqData varchar(255)
	,@Code varchar(255)
	,@Answers varchar(max)
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT 
	)
AS
BEGIN
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[TemplateDesignbyScreen] (
			     [TemplateSubMenuId]
				,[ScreenName]
				,[ReqData]
				,Code
				,Answers
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @TemplateSubMenuId
				,@ScreenName
				,@ReqData
				,@Code
				,@Answers
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
end

else
begin
update TemplateDesignbyScreen Set TemplateSubMenuId=@TemplateSubMenuId,ScreenName=@ScreenName,ReqData=@ReqData,Code=@Code,Answers=@Answers,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddTemplateGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTemplateGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddTemplateGeneration] (
	  @Id INT
	 ,@TemplateName varchar(255)
	,@ReportId varchar(max)
	,@OrgId varchar(255)
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	,@templateoutId int output 
	,@TemplateId varchar(255) output
	)
AS
BEGIN
	       
			IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[TemplateGeneration] (
			     [TemplateName]
				 ,ReportId
				,OrgId
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @TemplateName
				,@ReportId
				,@OrgId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @templateoutId=@@IDENTITY
				declare @tId varchar(255)
				set @tId = NEWID()
				update TemplateGeneration set TemplateId=@tId where Id = @templateoutId
				set @TemplateId = @tId

end

else
begin
update TemplateGeneration Set TemplateName=@TemplateName,ReportId=@ReportId,
IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
set @templateoutId=@Id
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
	@Id int
	,@UserName varchar(255)
	,@Password nvarchar(1024)
	,@FirstName varchar(50)
	,@LastName varchar(50)
	,@EmailId varchar(100)
	,@MobileNumber bigint
	,@RegistrationId Int
	,@RoleId int
	,@Designation varchar(255)
	,@ViewYN bit
	,@CreatedDate datetime
	,@CreatedByUserId int
	,@UpdatedDate datetime
	,@UpdatedByUserId int
	,@ErrorNumber INT OUTPUT
	,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id, 0) = 0
		BEGIN
			INSERT INTO [dbo].[Users] (
				[UserName]
				,[Password]
				,[FirstName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,[RegistrationId]
				,[RoleId]
				,[Designation]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
			)
			VALUES (
				@UserName
				,@Password
				,@FirstName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@RegistrationId
				,@RoleId
				,@Designation
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
			)

			DECLARE @OrgId varchar(255)
			SET @OrgId = (SELECT OrgId FROM Registration WHERE Id = @RegistrationId)
			UPDATE Users SET OrgId = @OrgId WHERE RegistrationId = @RegistrationId
		END
		ELSE
		BEGIN
			UPDATE [dbo].[Users]
			SET  
				[UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[MobileNumber] = @MobileNumber
				,[RoleId] = @RoleId
				,[Designation] = @Designation
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;

		RAISERROR('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddValidatingFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddValidatingFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddValidatingFinalReport]
(
	@Id INT = NULL,
	@ReportId varchar(255),
	@OrgId varchar(255),
	@UserId varchar(255),
	@IsValidate varchar(55),
	@Remarks varchar(max),
	@IsActive BIT = 1,
	@CreatedDate DATETIME = NULL,
	@CreatedByUserId INT = NULL,
	@UpdatedDate DATETIME = NULL,
	@UpdatedByUserId INT = NULL
)
AS
BEGIN
	SET NOCOUNT ON;

	IF @Id IS NULL
	BEGIN
		IF EXISTS (SELECT 1 FROM [dbo].[ValidatingFinalReport] WHERE UserId = @UserId AND ReportId = @ReportId)
		BEGIN
			UPDATE [dbo].[ValidatingFinalReport]
			SET
				IsValidate = @IsValidate,
				Remarks = @Remarks,
				IsActive = ISNULL(@IsActive, 1),
				CreatedDate = ISNULL(@CreatedDate, GETDATE()),
				CreatedByUserId = @CreatedByUserId,
				UpdatedDate = ISNULL(@UpdatedDate, GETDATE()),
				UpdatedByUserId = @UpdatedByUserId
			WHERE
				UserId = @UserId
				AND ReportId = @ReportId;
		END
		ELSE
		BEGIN
			INSERT INTO [dbo].[ValidatingFinalReport]
			(
				ReportId,
				OrgId,
				UserId,
				IsValidate,
				Remarks,
				[IsActive],
				[CreatedDate],
				[CreatedByUserId],
				[UpdatedDate],
				[UpdatedByUserId]
			)
			VALUES
			(
				@ReportId,
				@OrgId,
				@UserId,
				@IsValidate,
				@Remarks,
				ISNULL(@IsActive, 1),
				ISNULL(@CreatedDate, GETDATE()),
				@CreatedByUserId,
				ISNULL(@UpdatedDate, GETDATE()),
				@UpdatedByUserId
			);
		END
	END
	ELSE
	BEGIN
		UPDATE [dbo].[ValidatingFinalReport]
		SET
			ReportId = @ReportId,
			OrgId = @OrgId,
			IsValidate = @IsValidate,
			Remarks = @Remarks,
			IsActive = @IsActive,
			CreatedDate = @CreatedDate,
			CreatedByUserId = @CreatedByUserId,
			UpdatedDate = @UpdatedDate,
			UpdatedByUserId = @UpdatedByUserId
		WHERE
			ID = @ID;
	END
END
GO

-- %% [markdown]
-- # [dbo].[SP_BRSR_SelectedTemplateMenuCategoryTreeView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_BRSR_SelectedTemplateMenuCategoryTreeView]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_SelectedTemplateMenuCategoryTreeView 'EC28ED01-8EB6-4114-B973-68950E96B82E'
Create proc [dbo].[SP_BRSR_SelectedTemplateMenuCategoryTreeView](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #BRSR_TemplateSubMenu from BRSR_TemplateSubMenu tsm
inner join BRSR_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId and rtsm.Checked=1

select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select Code+' '+TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #BRSR_TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
from BRSR_TemplateMenuCategory tmc where tmc.Id in (select TemplateMenuCategoryId from #BRSR_TemplateSubMenu)

--select * from
--(select tm.TemplateMenuName,tm.Id,case when tm.Id !=1 then
--(select text,value,collapsed,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm)x where x.Sub is not null
 select * from
(select *,case when Id =1 then 1 
when Id= 8 then 2 
when Id=2 then 3
when Id=3 then 4
when Id=6 then 5 end SNo
from 
 (select * from
(select tm.TemplateMenuName,tm.Id,case when tm.Id !=8 then
(select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #BRSR_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) 
end Sub from BRSR_TemplateMenu tm)x where x.Sub is not null)X)Y Order by Y.SNo

drop table #BRSR_TemplateSubMenu
drop table #inner

end

GO

-- %% [markdown]
-- # [dbo].[SP_BRSR_TemplateMenuCategoryTreeView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_BRSR_TemplateMenuCategoryTreeView]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_BRSR_TemplateMenuCategoryTreeView 'EC28ED01-8EB6-4114-B973-68950E96B82E'
CREATE proc [dbo].[SP_BRSR_TemplateMenuCategoryTreeView](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #BRSR_TemplateSubMenu from BRSR_TemplateSubMenu tsm
left join BRSR_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId


select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value
from BRSR_TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
from BRSR_TemplateMenuCategory tmc


select tm.TemplateMenuName,tm.Id,case when tm.Id = 3 then (select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id order by Id For Json Path) else
(select TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #BRSR_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub from BRSR_TemplateMenu tm

drop table #BRSR_TemplateSubMenu
drop table #inner
end


GO

-- %% [markdown]
-- # [dbo].[SP_BRSR_TestPurpose]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_BRSR_TestPurpose]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TestPurpose '1A40EE55-BD42-43F0-B92A-5C9EF19289B7'
Create proc [dbo].[SP_BRSR_TestPurpose](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #BRSR_TemplateSubMenu from BRSR_TemplateSubMenu tsm
left join BRSR_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId

select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #BRSR_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from BRSR_TemplateMenu tm
drop table #BRSR_TemplateSubMenu


------ Latest Changes with TemplateMenu Category ------

--select tsm.*,case when rtsm.Id is null then 'false'
--when rtsm.checked = 0 then 'false'
--when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
--left join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
--rtsm.ReportId = @ReportId


--select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,
--(select Code+' '+TemplateSubMenuName as text,cast(tmc.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
--from TemplateMenuCategory tmc


--select tm.Id,tm.TemplateMenuName,case when tm.Id !=1 then
--(select text,value,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm

--drop table #TemplateSubMenu
--drop table #inner

end

GO

-- %% [markdown]
-- # [dbo].[SP_BRSR_TestPurpose2]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_BRSR_TestPurpose2]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TestPurpose2 'hhh'
Create proc [dbo].[SP_BRSR_TestPurpose2](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false' else 'true' end checked into #BRSR_TemplateSubMenu 
from BRSR_TemplateSubMenu tsm
Inner join BRSR_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId and rtsm.Checked=1


select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #BRSR_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from BRSR_TemplateMenu tm where tm.Id in (select TemplateMenuId from #BRSR_TemplateSubMenu)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CreateDynamicHTMLTable]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CreateDynamicHTMLTable]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



--exec SP_CreateDynamicHTMLTable
CREATE proc [dbo].[SP_CreateDynamicHTMLTable](@QuestionKey varchar(255),@Question varchar(255),@Value varchar(max),@outValue varchar(max) output)
as
begin

create table #keyWithAnswers([KeyValue] varchar(500),[Value] varchar(500),[Type] varchar(500))
DECLARE @json NVARCHAR(MAX)
SET @json=@Value;
insert into #keyWithAnswers
SELECT * FROM OPENJSON(@json);

select *,ROW_NUMBER() over(order by [KeyValue]) Id into #outerkeyWithAnswers  from #keyWithAnswers

--select * from #outerkeyWithAnswers


declare @C_Id int
declare @C_KeyValue int
declare @G_Min int
set @G_Min= (select MIN(Id) from #outerkeyWithAnswers)
declare @G_Max int
set @G_Max= (select MAX(Id) from #outerkeyWithAnswers)

declare @C_Value varchar(max)
declare @G_MultiRows varchar(max)
select '<th>'+HeaderName+'</th>' as Header,1 DId into #HeaderTemp from DynamicHTMLTableHeaders where QuestionKey = @QuestionKey
set @G_MultiRows = (SELECT '<tr>'+STRING_AGG(Header, '')+'<tr>' AS SingleHeaderRow FROM #HeaderTemp GROUP BY DId)

DECLARE db_cursor1 CURSOR FOR 
select Id,KeyValue,Value from #outerkeyWithAnswers order by KeyValue

OPEN db_cursor1  
FETCH NEXT FROM db_cursor1 INTO @C_Id,@C_KeyValue, @C_Value

WHILE @@FETCH_STATUS = 0  
BEGIN  
	  create table #InnerkeyWithAnswers([KeyValue] varchar(500),[Value] varchar(500),[Type] varchar(500))
      DECLARE @json2 NVARCHAR(MAX)
	  SET @json2=@C_Value;

	  insert into #InnerkeyWithAnswers
      SELECT * FROM OPENJSON(@json2);

	  --select * from #InnerkeyWithAnswers
      select *,'<td>'+Value+'</td>' Tag,1 DId into #Temp  from #InnerkeyWithAnswers

	  --select * from #Temp

	  set @G_MultiRows = @G_MultiRows + (SELECT '<tr>'+STRING_AGG(Tag, '')+'<tr>' AS SingleRow FROM #Temp GROUP BY DId)

	  if(@G_Max = @C_Id)
	  begin
	     declare @code varchar(max)
		 set @code = [dbo].[DynamicTable](@Question, @G_MultiRows)
	    --select @code
		set @outValue = @code
	  end

	  drop table #InnerkeyWithAnswers
	  drop table #Temp
	  FETCH NEXT FROM db_cursor1 INTO @C_Id,@C_KeyValue, @C_Value
END 

CLOSE db_cursor1  
DEALLOCATE db_cursor1 

drop table #keyWithAnswers
drop table #outerkeyWithAnswers
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteBRSRReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteBRSRReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_DeleteBRSRReportEvidence]
    @OrgId varchar(255),
    @ReportId varchar(255),
    @QuestionCode varchar(255)
AS
BEGIN
    DELETE FROM BRSR_ReportEvidence
    WHERE OrgId = @OrgId
      AND ReportId = @ReportId
      AND QuestionCode = @QuestionCode;
END
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteFinalReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteFinalReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_DeleteFinalReportId] (@P_Id int)
as
begin
delete FinalReportGeneration where ReportHdrId=@P_Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_DeleteReportEvidence]
    @OrgId varchar(255),
    @ReportId varchar(255),
    @QuestionCode varchar(255)
AS
BEGIN
    DELETE FROM ReportEvidence
    WHERE OrgId = @OrgId
      AND ReportId = @ReportId
      AND QuestionCode = @QuestionCode;
END
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_DeleteReportId] (@P_Id int)
as
begin
delete ReportGeneration where Id=@P_Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteSGXReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteSGXReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_DeleteSGXReportEvidence]
    @OrgId varchar(255),
    @ReportId varchar(255),
    @QuestionCode varchar(255)
AS
BEGIN
    DELETE FROM SGX_ReportEvidence
    WHERE OrgId = @OrgId
      AND ReportId = @ReportId
      AND QuestionCode = @QuestionCode;
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetARList]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetARList]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Proc [dbo].[SP_GetARList]
as
begin
select * from AssessmentBaseValue where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_FinalReportByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_FinalReportByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetFinalReportByReportId] 1 select * from FinalReportGeneration
Create PROCEDURE [dbo].[SP_GetBRSR_FinalReportByReportId] (@ReportId varchar(255))
AS
BEGIN
select 
 FR.Id
		,FR.ReportId
		,FR.ReportName
		,FR.StartDate
		,FR.EndDate
		,FR.CoverPageImage
		,FR.CoverPageLayout
		,FR.DesignTemplate
		,FR.Logo
		,FR.Introduction
		,FR.FinalDraftGuidance
		,FR.Reportpicbase
		,FR.Settings
		,FR.aboutthisreport
		,FR.Messagefromceo
		,FR.keyhighlights
		,FR.vision
		,FR.IsActive
		,FR.CreatedDate
		,FR.CreatedByUserId
		,FR.UpdatedDate
		,FR.UpdatedByUserId
		,FR.IsValidate
		,FR.IsSignoff
from BRSR_FinalReportGeneration FR
INNER JOIN BRSR_ReportGeneration RG ON RG.ReportId = FR.ReportId
	WHERE FR.ReportId = ISNULL(@ReportId, FR.ReportId)
	AND FR.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_FinalReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_FinalReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetBRSR_FinalReportGeneration] (@ReportId varchar(255))
as
begin
select f.*
from BRSR_FinalReportGeneration f

where f.ReportId=isnull(@ReportId,f.ReportId) and f.IsActive=1 and f.IsActive=1 
end
--select * from FinalReportGeneration
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_ReportGenerationByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_ReportGenerationByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetBRSR_ReportGenerationByReportId] (@ReportId varchar(255))
as
begin
select r.*
from BRSR_ReportGeneration r

where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_ReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetBRSR_ReportTemplateMenuId] (@P_ReportId Varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.ReportId
		,TM.UserId
		,TM.TemplateMenuId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,TM.Checked
		,TM.Status
	FROM BRSR_ReportTemplateMenuId  TM
	WHERE TM.ReportId = ISNULL(@P_ReportId, TM.ReportId)
		AND TM.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_TemplateMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_TemplateMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetBRSR_TemplateMenu] (@P_Id Int)
AS
BEGIN
	SELECT 
		*
	FROM BRSR_TemplateMenu 
	WHERE Id = ISNULL(@P_Id,Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_TemplateSubMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_TemplateSubMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetBRSR_TemplateSubMenu] (@P_Id Int)
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM BRSR_TemplateSubMenu TM
	INNER JOIN BRSR_TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.Id = ISNULL(@P_Id, TM.Id)
		AND TM.IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_TemplateSubMenubyScreenclick]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_TemplateSubMenubyScreenclick]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetBRSR_TemplateSubMenubyScreenclick] (@TemplateMenuName varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM BRSR_TemplateSubMenu TM
	INNER JOIN BRSR_TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.Id = ISNULL(@TemplateMenuName, TM.Id)
		AND TM.IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_TemplateSubMenubyTemplateSubMenuName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_TemplateSubMenubyTemplateSubMenuName]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetBRSR_TemplateSubMenubyTemplateSubMenuName 'PRINCIPLE WISE PERFORMANCE DISCLOSURE (Essential Indicators)'
CREATE PROCEDURE [dbo].[SP_GetBRSR_TemplateSubMenubyTemplateSubMenuName] (@TemplateSubMenuName varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.TemplateMenuCategoryId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM BRSR_TemplateSubMenu TM
	INNER JOIN BRSR_TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.TemplateSubMenuName = ISNULL(@TemplateSubMenuName, TM.TemplateSubMenuName)
		AND TM.IsActive = 1 order by Id
END

--select * from  BRSR_TemplateSubMenu
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSR_ValidatingFinalReportonlybyReportid]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSR_ValidatingFinalReportonlybyReportid]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetBRSR_ValidatingFinalReportonlybyReportid] (@ReportId varchar(255))
as
begin
select f.*
from BRSR_ValidatingFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSRReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSRReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetBRSRReportEvidence](@ReportId varchar(255),@QuestionCode VARCHAR(255)) 
as
begin
select * from BRSR_ReportEvidence where ReportId=@ReportId AND QuestionCode = @QuestionCode and IsActive=1
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSRReportEvidencebyReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSRReportEvidencebyReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetBRSRReportEvidencebyReportId](@ReportId varchar(255), @OrgId VARCHAR(255)) 
AS
BEGIN
    SELECT GuidanceNumber, QuestionCode, UploadedObj
    FROM BRSR_ReportEvidence
    WHERE ReportId = @ReportId AND OrgId = @OrgId AND IsActive = 1
    ORDER BY GuidanceNumber, QuestionCode;
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetBRSRValidatingFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBRSRValidatingFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetBRSRValidatingFinalReport] (@ReportId varchar(255),@UserId INT)
as
begin
select f.*
from BRSR_ValidatingFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 AND f.UserId = @UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCA_Scope1CompanyFacilities]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCA_Scope1CompanyFacilities]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetCA_Scope1CompanyFacilities](@P_Id INT)
as
begin
select * from CA_Scope1CompanyFacilities WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCA_Scope1CompanyVehicles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCA_Scope1CompanyVehicles]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetCA_Scope1CompanyVehicles](@P_Id INT)
as
begin
select * from CA_Scope1CompanyVehicles WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCA_Scope1Fugitives]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCA_Scope1Fugitives]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetCA_Scope1Fugitives](@P_Id INT)
as
begin
select * from CA_Scope1Fugitives WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCalculateARValues]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCalculateARValues]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetCalculateARValues 1,1
CREATE proc [dbo].[SP_GetCalculateARValues](@FuelTypeId int,@ARId int)
as
begin
select 1 as SNo,* into #AssessmentBaseValue from AssessmentBaseValue where Id=@ARId
select 1 as SNo,* into #FuelTypeBaseValue from FuelTypeBaseValue  where Id=@FuelTypeId

select *,(X.CO2+X.CH4+X.N2O) TotalValue from
(select abv.TypeName,fbv.Name,(abv.CO2 * fbv.CO2) CO2,(abv.CH4 * fbv.CH4) CH4, (abv.N2O * fbv.N2O) N2O from #AssessmentBaseValue abv
inner join #FuelTypeBaseValue fbv on fbv.SNo = abv.SNo)X

drop table #AssessmentBaseValue
drop table #FuelTypeBaseValue
end




GO

-- %% [markdown]
-- # [dbo].[SP_GetCityState]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCityState]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetCityState] 
AS
BEGIN
	SELECT 
		 *
	FROM CityState
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetCollaboratorsByReportName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCollaboratorsByReportName]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetCollaboratorsByReportName] (@ReportId varchar(255))
AS
begin
select r.*,rg.ReportName,u.FirstName from ReportCollaborators r
inner join ReportGeneration rg on rg.ReportId=r.ReportId
inner join Users u on u.Id=r.CollaboratorId
WHERE r.ReportId = ISNULL(@ReportId, r.ReportId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCollaboratorsinOrganization]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCollaboratorsinOrganization]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetCollaboratorsinOrganization 'AD9C98C9-DCEC-4FE7-97DD-A6DEC08743E6' , 'BF31E633-05E7-405B-AD96-3693B10A37D4'
CREATE PROCEDURE [dbo].[SP_GetCollaboratorsinOrganization] (@OrgId varchar(255),@ReportId varchar(255))
AS
BEGIN
    select * into #Users from Users where OrgId = @OrgId  and RoleId=11
   select * into #ReportCollaborators from ReportCollaborators where OrgId =@OrgId and
   ReportId= @ReportId    select * from #Users u
   left join #ReportCollaborators rc on u.Id = rc.CollaboratorId where rc.Id is null    drop table #Users
    drop table #ReportCollaborators
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCountry]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCountry]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetCountry] (@P_Id Int)
AS
BEGIN
	SELECT 
		 *
	FROM Countries
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetCurrencytypeforExchangerate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCurrencytypeforExchangerate]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetCurrencytypeforExchangerate]
as
begin
select * from CurrencytypeforExchangerate where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDescriptionByScreenName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDescriptionByScreenName]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--select * from TemplateSubMenu 
--select * from TemplateSubMenuItem
--exec SP_GetDescriptionByScreenName 'Remuneration policies'
CREATE proc [dbo].[SP_GetDescriptionByScreenName] (@TemplateSubMenuName varchar(255))
as
begin

select tsmi.*,(select Code from TemplateSubMenu where Id = tsmi.TemplateSubMenuId)+' '+ScreenName as CodeScreenName into #TemplateSubMenuItem from TemplateSubMenuItem  tsmi

select 
		p.[Id]
		,p.[Code]
		,ts.Guidance
		,ts.Description
		,p.TemplateSubMenuName
		,p.TemplateMenuId
		,p.IsActive
		,p.CreatedByUserId
		,p.CreatedDate
		,p.UpdatedByUserId
		,p.[UpdatedDate]
from TemplateSubMenu p
left join #TemplateSubMenuItem ts on ts.ScreenName=p.TemplateSubMenuName
where ts.CodeScreenName=@TemplateSubMenuName order by Guidance ASC

drop table #TemplateSubMenuItem

--select  t1.*,t2.Id as t1Id,t2.Guidance,t2.Description from TemplateDesignbyScreen t1
--left join TemplateSubMenuItem t2 on t2.ScreenName = @ScreenName
--and t2.Code = t1.Code
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDesignTemplatesByOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDesignTemplatesByOrgId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDesignTemplatesByOrgId] (@OrgId varchar(255))
AS
BEGIN
	SELECT 
		 t.*,u.FirstName as Name,ui.FirstName as UpdatedName
	FROM [dbo].TemplateGeneration t
	inner join Users u on u.Id=t.CreatedByUserId
inner join Users ui on ui.Id=t.UpdatedByUserId
	WHERE t.OrgId = ISNULL(@OrgId, t.OrgId)
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistinctIdByTemplateSubMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistinctIdByTemplateSubMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetDistinctIdByTemplateSubMenuId] (@TemplateSubMenuId int)
as
begin
select ReqData from TemplateSubMenuItem where TemplateSubMenuId=@TemplateSubMenuId group by ReqData 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistinctScreenNameByTemplateSubMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistinctScreenNameByTemplateSubMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetDistinctScreenNameByTemplateSubMenuId] (@TemplateSubMenuId int)
as
begin
select ScreenName from TemplateSubMenuItem where TemplateSubMenuId=@TemplateSubMenuId group by ScreenName 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictDtlbyessential]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictDtlbyessential]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetDistrictDtlbyessential] (@Princ8essId Int)
AS
BEGIN
SELECT 
        dl.Name
    FROM StateHdr sh
    INNER JOIN DistrictDtl dl ON sh.Id = dl.Princ8essId
    WHERE sh.Id = @Princ8essId;
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictDtlbyleadership]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictDtlbyleadership]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetDistrictDtlbyleadership] (@Princ8leadId Int)
AS
BEGIN
SELECT 
        dl.Name
    FROM StateHdr sh
    INNER JOIN DistrictDtl dl ON sh.Id = dl.Princ8leadId
    WHERE sh.Id = @Princ8leadId;
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDynamicQuestionandAnswers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDynamicQuestionandAnswers]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetDynamicQuestionandAnswers '95E6B902-F375-43FC-BC84-696C5C0643CD'
CREATE proc [dbo].[SP_GetDynamicQuestionandAnswers](@ReportId varchar(255))
as
begin

create table #keyWithAnswers([KeyValue] varchar(500),[Value] varchar(500),[Type] varchar(500))
DECLARE @json NVARCHAR(MAX)
SET @json= (select InitialDraftReport from ReportGeneration where ReportId=@ReportId)

insert into #keyWithAnswers
SELECT * FROM OPENJSON(@json);

--select * from #keyWithAnswers

select x.*,isnull(kwa.[Value],'NA') Value into #multidiv from 
(select dq.* from DynamicQuestions dq
left join ReportTemplateMenuId rtm on rtm.TemplateMenuId = dq.TemplateSubMenuId
where rtm.ReportId=@ReportId)X
left join #keyWithAnswers kwa on kwa.[KeyValue] = x.KeyValue

--select * from #multidiv

select *, row_number() over (partition by TemplateSubMenuId order by TemplateSubMenuId) as RowId into #multiheading from #multidiv


--select * from #multiheading

select *,row_number() over(order by TemplateSubMenuId,RowId) SqNo into #multiheading1 from #multiheading order by TemplateSubMenuId,RowId



update #multiheading1 set Value='NA' where Value =''

--select * from #multiheading1


declare @C_TempSubMenuId int
declare @C_Question varchar(500)
declare @C_Type varchar(50)
declare @C_KeyValue varchar(500)
declare @C_Value varchar(500)
declare @C_RowId int
declare @G_Min int
set @G_Min = (select MIN(SqNo) from #multiheading1)
declare @G_Max int
set @G_Max = (select MAX(SqNo) from #multiheading1)
declare @C_SqNo int
declare @HtmlCode varchar(max)

DECLARE db_cursor CURSOR FOR 
SELECT TemplateSubMenuId,Questions,Type,KeyValue,Value,RowId,SqNo  from #multiheading1  order by SqNo
 
OPEN db_cursor  
FETCH NEXT FROM db_cursor INTO @C_TempSubMenuId,@C_Question,@C_Type,@C_KeyValue,@C_Value,@C_RowId,@C_SqNo

WHILE @@FETCH_STATUS = 0  
BEGIN  
       declare @Max int

	   if @G_Min = @C_SqNo
	   begin
	    set @HtmlCode = ''
	    declare @stylecode varchar(max)
	   set @stylecode= dbo.DynamicStyleTag()
	   set @HtmlCode = @HtmlCode + @stylecode
	   declare @base64 varchar(max)
	   set @base64 = (select Reportpicbase from FinalReportGeneration where ReportId=@ReportId)
	   declare @covercode varchar(max)
	   set @covercode = dbo.DynamicCoverandIntro(@base64)
	   set @HtmlCode = @HtmlCode + @covercode
	   end
	  
	   if @C_RowId = 1
	   begin
	      set @Max = 0
	      declare @L_ReportName varchar(500)
		  declare @L_Name varchar(500)
		  declare @L_base64 varchar(max)
		  set @Max = (select MAX(RowId) from #multiheading where TemplateSubMenuId = @C_TempSubMenuId)
	      set @L_ReportName = (select ReportName from FinalReportGeneration where ReportId = @ReportId)
		  set @L_Name = (select TemplateSubMenuName from TemplateSubMenu where Id = @C_TempSubMenuId)
		  set @L_base64 = (select Base64 from BackGroupImages where Id=1)
		  declare @code varchar(max)
		  set @code = [dbo].[DynamicHeading](@L_Name,@L_ReportName,@L_base64)
		  set @HtmlCode = @HtmlCode + @code
	   end
	   
	   
	      declare @subcode varchar(max)
		  if(@C_Type = 'Multi')
		  begin
		     if (@C_Value != 'NA')
			 begin
			     set @C_Value = (REPLACE(REPLACE(REPLACE(@C_Value,'[',''),']',''),'"',''))
				 set @subcode = [dbo].[DynamicDiv](@C_Question,@C_Value)
		         set @HtmlCode = @HtmlCode + @subcode
			 end
		  end
		  if(@C_Type = 'String' or @C_Type = 'Number')
		  begin
		    set @subcode = [dbo].[DynamicDiv](@C_Question,@C_Value)
		    set @HtmlCode = @HtmlCode + @subcode
		  end
		   if(@C_Type = 'Table' )
		  begin
		  if (@C_Value != 'NA')
		  begin
		  declare @localtable varchar(max)
		  exec SP_CreateDynamicHTMLTable @C_KeyValue,@C_Question,@C_Value, @localtable output
		  if(@localtable != null or @localtable != '')
		  begin
		  set @HtmlCode = @HtmlCode + @localtable
		  end
		  end
		  end
		  else
		  begin
		   set @subcode = [dbo].[DynamicDiv](@C_Question,@C_Value)
		    set @HtmlCode = @HtmlCode + @subcode
		  end
		 

	   if @Max = @C_RowId
	   begin
	    declare @footercode varchar(max)
		set @footercode = [dbo].[DynamicFooter]()
		set @HtmlCode = @HtmlCode + @footercode
	   end
	   if @G_Max = @C_SqNo
	   begin
	   select @HtmlCode as HtmlCode
	   end
      FETCH NEXT FROM db_cursor INTO @C_TempSubMenuId,@C_Question,@C_Type,@C_KeyValue,@C_Value,@C_RowId,@C_SqNo 
END 

CLOSE db_cursor
DEALLOCATE db_cursor

drop table #keyWithAnswers
drop table #multidiv
drop table #multiheading
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetElectricCountry]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetElectricCountry]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetElectricCountry] (@P_Id Int)
AS
BEGIN
	SELECT 
		 *
	FROM ElectricCountries
	WHERE Id = ISNULL(@P_Id, Id)
		
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetFinalReportByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFinalReportByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetFinalReportByReportId] 1 select * from FinalReportGeneration
CREATE PROCEDURE [dbo].[SP_GetFinalReportByReportId] (@ReportId varchar(255))
AS
BEGIN
select 
 FR.Id
		,FR.ReportId
		,FR.ReportName
		,FR.StartDate
		,FR.EndDate
		,FR.CoverPageImage
		,FR.CoverPageLayout
		,FR.DesignTemplate
		,FR.Logo
		,FR.Introduction
		,FR.FinalDraftGuidance
		,FR.Reportpicbase
		,FR.Settings
		,FR.aboutthisreport
		,FR.Messagefromceo
		,FR.keyhighlights
		,FR.vision
		,FR.IsActive
		,FR.CreatedDate
		,FR.CreatedByUserId
		,FR.UpdatedDate
		,FR.UpdatedByUserId
		,FR.IsValidate
		,FR.IsSignoff
from FinalReportGeneration FR
INNER JOIN ReportGeneration RG ON RG.ReportId = FR.ReportId
	WHERE FR.ReportId = ISNULL(@ReportId, FR.ReportId)
	AND FR.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFinalReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFinalReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetFinalReportGeneration] (@ReportId varchar(255))
as
begin
select f.*
from FinalReportGeneration f

where f.ReportId=isnull(@ReportId,f.ReportId) and f.IsActive=1 and f.IsActive=1 
end
--select * from FinalReportGeneration
GO

-- %% [markdown]
-- # [dbo].[SP_GetFramework]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFramework]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetFramework] (@P_Id Int)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[FrameworkName]
		,[Logo]
		,[Description]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM Framework
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetFuelConvertionTypeById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFuelConvertionTypeById]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFuelConvertionTypeById 1
CREATE Proc [dbo].[SP_GetFuelConvertionTypeById](@Id int)
as
begin

select fct.* from FuelConvertionType fct
left join FuelTypeBaseValue fbv on fbv.TypeId = fct.TypeId
where fbv.Id =@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFuelTypeBaseValue]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFuelTypeBaseValue]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetFuelTypeBaseValue]
as
begin
select * from FuelTypeBaseValue where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtl]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[LookupHdrId]
		,[Code]
		,[Name]
		,[Remarks]
		,[Ord]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrCode]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Code = ISNULL(@P_Code, t.Code) 
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.LookupHdrId = ISNULL(@P_Id, t.LookupHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetails]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





CREATE PROCEDURE [dbo].[SP_GetLookupDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId] as LookupMstId
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdr]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		  [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdrDetails]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetLookupHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		  t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id) and  m.ViewYN = 1
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@P_UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetNICCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetNICCode]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetNICCode] 
AS
BEGIN
	SELECT * FROM NICList3
	WHERE  IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetNICCodefilter]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetNICCodefilter]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetNICCodefilter] (@P_NICCode Varchar(50))
AS
BEGIN
	SELECT * FROM NICList3
	WHERE  NICCode = ISNULL(@P_NICCode, NICCode)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPreviewByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPreviewByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetPreviewByReportId '618ADA43-C1BE-47C4-BCCC-1AA53F86E5D9'
CREATE PROCEDURE [dbo].[SP_GetPreviewByReportId] (@ReportId varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.ReportId
		,ts.Code
		,ts.TemplateSubMenuName
		,TM.UserId
		,TM.TemplateMenuId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,TM.Checked
		,TM.Status
		,ts.TemplateMenuId MenuId
	--	,tds.ReqData
	 into #Temp
	FROM ReportTemplateMenuId  TM
	inner join TemplateSubMenu ts on ts.Id=TM.TemplateMenuId
	--inner join TemplateDesignbyScreen tds on tds.Id=TM.TemplateMenuId
	WHERE TM.ReportId = ISNULL(@ReportId, TM.ReportId)
		AND TM.IsActive = 1 order by TemplateMenuId
		 
		 SELECT *,ROW_NUMBER() OVER(PARTITION BY MenuId ORDER BY TemplateMenuId) as RowNo,case when ROW_NUMBER() OVER(PARTITION BY MenuId ORDER BY TemplateMenuId) = 1 then (select TemplateMenuName from TemplateMenu where Id=MenuId) else 'no' end MTemplateName from #Temp

		drop table #Temp
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPublishedReportsByOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPublishedReportsByOrgId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetPublishedReportsByOrgId] (@OrgId varchar(255))
AS
BEGIN
	SELECT 
		 r.*,u.FirstName as Name,ui.FirstName as UpdatedName
	FROM [dbo].ReportGeneration r
	inner join FinalReportGeneration fr on fr.ReportId=r.ReportId
inner join Users u on u.Id=r.CreatedByUserId
inner join Users ui on ui.Id=r.UpdatedByUserId
	WHERE r.OrgId = ISNULL(@OrgId, r.OrgId)
		AND fr.isPublished=1  ORDER BY UpdatedDate Desc;
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetQuesDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQuesDtl]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



--exec [SP_GetQuesDtl] 2
--select * from QuesDtl
CREATE PROCEDURE [dbo].[SP_GetQuesDtl] (@P_QuesHdrId int)
AS
BEGIN
	SELECT 
		 [Id]
		,[QuesHdrId]
		,[QuesCode]
		,[Name]
		,[Ord]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[QuesDtl]
	WHERE QuesHdrId = ISNULL(@P_QuesHdrId, QuesHdrId)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetQuesHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQuesHdr]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetQuesHdr] (@P_QuesCode varchar(255))
AS
BEGIN
	SELECT 
		  [Id]
		,[QuesCode]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[QuesHdr]
	WHERE QuesCode = ISNULL(@P_QuesCode, QuesCode)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetQuestions]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQuestions]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetQuestions] (@Code varchar(255))
AS
BEGIN
	SELECT 
		 *
	FROM Questions
	WHERE Code = ISNULL(@Code, Code)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegistration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegistration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetRegistration] (@P_Id INT)
AS
BEGIN
	SELECT 
		 *
	FROM [dbo].[Registration]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegistrationbyEmailId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegistrationbyEmailId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetRegistrationbyEmailId] (@P_EmailId varchar(255))
AS
BEGIN
	SELECT 
		count(*) cnt	
	FROM [dbo].[Registration] r
	WHERE r.EmailId = ISNULL(@P_EmailId, r.EmailId)
		AND r.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegistrationbyRegName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegistrationbyRegName]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetRegistrationbyRegName] (@P_OrganizationName varchar(255))
AS
BEGIN
	SELECT 
		count(*) cnt	
	FROM [dbo].[Registration] r
	WHERE r.OrganizationName = ISNULL(@P_OrganizationName, r.OrganizationName)
		AND r.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegistrationDetailsByOrgId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegistrationDetailsByOrgId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetRegistrationDetailsByOrgId] (@OrgId varchar(255))
AS
BEGIN
	SELECT 
		 *
	FROM [dbo].[Registration]
	WHERE OrgId = ISNULL(@OrgId, OrgId)
		AND IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportCollaborators]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportCollaborators]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetReportCollaborators] (@CollaboratorId int)
as
begin
select r.*,rg.ReportName,u.FirstName from ReportCollaborators r
inner join ReportGeneration rg on rg.ReportId=r.ReportId
inner join Users u on u.Id=r.CollaboratorId
WHERE r.CollaboratorId = ISNULL(@CollaboratorId, r.CollaboratorId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetReportEvidence](@ReportId varchar(255),@QuestionCode VARCHAR(255)) 
as
begin
select * from ReportEvidence where ReportId=@ReportId AND QuestionCode = @QuestionCode and IsActive=1
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportEvidencebyReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportEvidencebyReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetReportEvidencebyReportId](@ReportId varchar(255), @OrgId VARCHAR(255)) 
AS
BEGIN
    SELECT GuidanceNumber, QuestionCode, UploadedObj
    FROM ReportEvidence
    WHERE ReportId = @ReportId AND OrgId = @OrgId AND IsActive = 1
    ORDER BY GuidanceNumber, QuestionCode;
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetReportGeneration] (@ReportId varchar(255))
as
begin
select r.*
from ReportGeneration r

where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1 and r.IsActive=1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportGenerationByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportGenerationByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetReportGenerationByReportId] (@ReportId varchar(255))
as
begin
select r.*
from ReportGeneration r

where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportGenerationByReportIdReportType]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportGenerationByReportIdReportType]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetReportGenerationByReportIdReportType] (@ReportId varchar(255),@ReportType varchar(255))
as
begin
 if @ReportType = 'GRI'
 begin
select r.*
from ReportGeneration r
where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1 and r.IsActive=1 
end
else  if @ReportType = 'BRSR'
begin
select r.*
from BRSR_ReportGeneration r
where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1 and r.IsActive=1
end
else  if @ReportType = 'SGX'
begin
select r.*
from SGX_ReportGeneration r
where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1 and r.IsActive=1
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportJsonByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportJsonByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetReportJsonByReportId 'CC53429C-8ED6-4DA2-AAC4-8D87F5595704'
CREATE proc [dbo].[SP_GetReportJsonByReportId](@ReportId varchar(255))
as
begin
select rg.ReportId,rg.ReportName,rg.StartDate,rg.EndDate,rg.InitialDraftReport as ReportJson,
rg.OrgId,isnull(r.OrganizationName,'trst01') as OrgName,Year(rg.StartDate) as ReportYear,u.EmailId as Author
from ReportGeneration rg 
left join Registration r on r.OrgId = rg.OrgId
left join Users u on u.Id = rg.CreatedByUserId
where rg.ReportId = @ReportId
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetReportPictures]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportPictures]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetReportPictures](@P_Id int) 
as
begin
select * from ReportPictures where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetReportTemplateMenuId] (@P_ReportId Varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.ReportId
		,TM.UserId
		,TM.TemplateMenuId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,TM.Checked
		,TM.Status
	FROM ReportTemplateMenuId  TM
	WHERE TM.ReportId = ISNULL(@P_ReportId, TM.ReportId)
		AND TM.IsActive = 1 ORder by TM.TemplateMenuId
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportTemplateMenuIdforTemplate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportTemplateMenuIdforTemplate]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetReportTemplateMenuIdforTemplate] (@P_ReportId Varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.ReportId
		,TM.UserId
		,TM.TemplateMenuId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,TM.Checked
		,TM.Status
	FROM ReportTemplateMenuIdforTemplate  TM
	WHERE TM.ReportId = ISNULL(@P_ReportId, TM.ReportId)
		AND TM.IsActive = 1 ORder by TM.TemplateMenuId
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetReportTemplateMenuSubIdByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReportTemplateMenuSubIdByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetReportTemplateMenuSubIdByReportId](@ReportId varchar(255))
as
begin

select * from ReportTemplateMenuId where ReportId = @ReportId and Checked = 1 order by TemplateMenuId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRequestData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRequestData]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetRequestData](@P_Id int) 
as
begin
select * from RequestData where Id=isnull(@P_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.ViewYN = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetRolesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Roles] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope1Fugutives]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope1Fugutives]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope1Fugutives]
as
begin
select * from Scope1Fugutives 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope2Marketbased]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope2Marketbased]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope2Marketbased]
as
begin
select * from Scope2Marketbased 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope2SteamHeat]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope2SteamHeat]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetScope2SteamHeat]
as
begin
select * from Scope2SteamHeat where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3AvgPiece]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3AvgPiece]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3AvgPiece]
as
begin
select * from Scope3avgpiecebased where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Categ1SupplierSpec]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Categ1SupplierSpec]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Categ1SupplierSpec]
as
begin
select * from Scope3Categ1SupplierSpec where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category2shift]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category2shift]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category2shift]
as
begin
select * from Scope3Category2shift where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category2spend]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category2spend]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category2spend]
as
begin
select * from Scope3Category2spend where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category3elec]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category3elec]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category3elec]
as
begin
select * from Scope3Category3elec where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category3Fuel]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category3Fuel]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category3Fuel]
as
begin
select * from Scope3Category3Fuel where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category4]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category4]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category4]
as
begin
select * from Scope3Category4 where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category5Waste]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category5Waste]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category5Waste]
as
begin
select * from Scope3Category5Waste where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category5WasteById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category5WasteById]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetScope3Category5WasteById] (@Material VARCHAR(255))
AS
BEGIN
    SELECT fct.*
    FROM Scope3Category5Waste fct
    WHERE fct.Material = @Material
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category5WasteMaterialNames]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category5WasteMaterialNames]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category5WasteMaterialNames]
as
begin
select * from Scope3Category5WasteMaterialNames where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category6BusinessTravel]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category6BusinessTravel]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category6BusinessTravel]
as
begin
select * from Scope3Category6BusinessTravel where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category6hotel]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category6hotel]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category6hotel]
as
begin
select * from Scope3Category6hotel where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category6RentalCars]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category6RentalCars]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category6RentalCars]
as
begin
select * from Scope3Category6RentalCars where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3Category7]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3Category7]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3Category7]
as
begin
select * from Scope3Category7 where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3scope1calc]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3scope1calc]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3scope1calc]
as
begin
select * from Scope3scope1calc where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3scope2calc]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3scope2calc]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetScope3scope2calc]
as
begin
select * from Scope3scope2calc 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetScope3spendbased]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetScope3spendbased]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetScope3spendbased]
as
begin
select * from Scope3spendbased where IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_FinalReportByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_FinalReportByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetFinalReportByReportId] 1 select * from FinalReportGeneration
Create PROCEDURE [dbo].[SP_GetSGX_FinalReportByReportId] (@ReportId varchar(255))
AS
BEGIN
select 
 FR.Id
		,FR.ReportId
		,FR.ReportName
		,FR.StartDate
		,FR.EndDate
		,FR.CoverPageImage
		,FR.CoverPageLayout
		,FR.DesignTemplate
		,FR.Logo
		,FR.Introduction
		,FR.FinalDraftGuidance
		,FR.Reportpicbase
		,FR.Settings
		,FR.aboutthisreport
		,FR.Messagefromceo
		,FR.keyhighlights
		,FR.vision
		,FR.IsActive
		,FR.CreatedDate
		,FR.CreatedByUserId
		,FR.UpdatedDate
		,FR.UpdatedByUserId
		,FR.IsValidate
		,FR.IsSignoff
from SGX_FinalReportGeneration FR
INNER JOIN SGX_ReportGeneration RG ON RG.ReportId = FR.ReportId
	WHERE FR.ReportId = ISNULL(@ReportId, FR.ReportId)
	AND FR.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_FinalReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_FinalReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSGX_FinalReportGeneration] (@ReportId varchar(255))
as
begin
select f.*
from SGX_FinalReportGeneration f

where f.ReportId=isnull(@ReportId,f.ReportId) and f.IsActive=1 and f.IsActive=1 
end
--select * from FinalReportGeneration
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_ReportGenerationByReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_ReportGenerationByReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSGX_ReportGenerationByReportId] (@ReportId varchar(255))
as
begin
select r.*
from SGX_ReportGeneration r

where r.ReportId=isnull(@ReportId,r.ReportId) and r.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_ReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_ReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetSGX_ReportTemplateMenuId] (@P_ReportId Varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.ReportId
		,TM.UserId
		,TM.TemplateMenuId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,TM.Checked
		,TM.Status
	FROM SGX_ReportTemplateMenuId  TM
	WHERE TM.ReportId = ISNULL(@P_ReportId, TM.ReportId)
		AND TM.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_TemplateMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_TemplateMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetSGX_TemplateMenu] (@P_Id Int)
AS
BEGIN
	SELECT 
		*
	FROM SGX_TemplateMenu 
	WHERE Id = ISNULL(@P_Id,Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_TemplateSubMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_TemplateSubMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetSGX_TemplateSubMenu] (@P_Id Int)
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM SGX_TemplateSubMenu TM
	INNER JOIN SGX_TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.Id = ISNULL(@P_Id, TM.Id)
		AND TM.IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_TemplateSubMenubyScreenclick]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_TemplateSubMenubyScreenclick]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetSGX_TemplateSubMenubyScreenclick] (@TemplateMenuName varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM SGX_TemplateSubMenu TM
	INNER JOIN SGX_TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.Id = ISNULL(@TemplateMenuName, TM.Id)
		AND TM.IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_TemplateSubMenubyTemplateSubMenuName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_TemplateSubMenubyTemplateSubMenuName]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetBRSR_TemplateSubMenubyTemplateSubMenuName 'PRINCIPLE WISE PERFORMANCE DISCLOSURE (Essential Indicators)'
Create PROCEDURE [dbo].[SP_GetSGX_TemplateSubMenubyTemplateSubMenuName] (@TemplateSubMenuName varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.TemplateMenuCategoryId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM SGX_TemplateSubMenu TM
	INNER JOIN SGX_TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.TemplateSubMenuName = ISNULL(@TemplateSubMenuName, TM.TemplateSubMenuName)
		AND TM.IsActive = 1 order by Id
END

--select * from  BRSR_TemplateSubMenu
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGX_ValidatingFinalReportonlybyReportid]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGX_ValidatingFinalReportonlybyReportid]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSGX_ValidatingFinalReportonlybyReportid] (@ReportId varchar(255))
as
begin
select f.*
from SGX_ValidatingFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGXReportEvidence]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGXReportEvidence]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSGXReportEvidence](@ReportId varchar(255),@QuestionCode VARCHAR(255)) 
as
begin
select * from SGX_ReportEvidence where ReportId=@ReportId AND QuestionCode = @QuestionCode and IsActive=1
end 
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGXReportEvidencebyReportId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGXReportEvidencebyReportId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetSGXReportEvidencebyReportId](@ReportId varchar(255), @OrgId VARCHAR(255)) 
AS
BEGIN
    SELECT GuidanceNumber, QuestionCode, UploadedObj
    FROM SGX_ReportEvidence
    WHERE ReportId = @ReportId AND OrgId = @OrgId AND IsActive = 1
    ORDER BY GuidanceNumber, QuestionCode;
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetSGXValidatingFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSGXValidatingFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSGXValidatingFinalReport] (@ReportId varchar(255),@UserId INT)
as
begin
select f.*
from SGX_ValidatingFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 AND f.UserId = @UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSigningoffFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSigningoffFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSigningoffFinalReport] (@ReportId varchar(255),@UserId INT)
as
begin
select f.*
from SigningoffFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 AND f.UserId = @UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetSigningoffFinalReportonlybyReportid]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSigningoffFinalReportonlybyReportid]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_GetSigningoffFinalReportonlybyReportid] (@ReportId varchar(255))
as
begin
select f.*
from SigningoffFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetStateHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStateHdr]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetStateHdr] (@P_Id Int)
AS
BEGIN
	SELECT 
		 *
	FROM StateHdr
	WHERE Id = ISNULL(@P_Id, Id)
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateCheckboxMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateCheckboxMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetTemplateCheckboxMenuId] (@P_TemplateId Varchar(255))
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.TemplateId
		,TM.UserId
		,TM.TemplateSubMenuId
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,TM.Checked
		,TM.Status
	FROM TemplateCheckboxMenuId  TM
	WHERE TM.TemplateId = ISNULL(@P_TemplateId, TM.TemplateId)
		AND TM.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateCheckboxMenuSubIdByTemplateId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateCheckboxMenuSubIdByTemplateId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_GetTemplateCheckboxMenuSubIdByTemplateId](@TemplateId varchar(255))
as
begin

select * from TemplateCheckboxMenuId where TemplateId = @TemplateId and Checked = 1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateDesignbyScreen]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateDesignbyScreen]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetTemplateDesignbyScreen] (@P_Id Int)
AS
BEGIN
	SELECT 
		*
	FROM TemplateDesignbyScreen 
	WHERE Id = ISNULL(@P_Id,Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetTemplateGeneration] (@TemplateId varchar(255))
as
begin
select r.*
from TemplateGeneration r

where r.TemplateId=isnull(@TemplateId,r.TemplateId) and r.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateGenerationbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateGenerationbyId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetTemplateGenerationbyId] (@Id int)
as
begin
select r.*
from TemplateGeneration r

where Id=isnull(@Id,Id) and r.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetTemplateMenu] (@P_Id Int)
AS
BEGIN
	SELECT 
		*
	FROM TemplateMenu 
	WHERE Id = ISNULL(@P_Id,Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateSubMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateSubMenu]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetTemplateSubMenu] (@P_Id Int)
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM TemplateSubMenu TM
	INNER JOIN TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	WHERE TM.Id = ISNULL(@P_Id, TM.Id)
		AND TM.IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateSubMenuDetailsByTemplateId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateSubMenuDetailsByTemplateId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetTemplateSubMenuDetailsByTemplateId 1,3
CREATE PROCEDURE [dbo].[SP_GetTemplateSubMenuDetailsByTemplateId] (@P_Id Int,@ReportId int)
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,case when rt.Id is null then 'false' else 'true' end checked
		
	FROM TemplateSubMenu TM
	INNER JOIN TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	left join(select * from ReportTemplateMenuId where ReportId =@ReportId and Checked=1 and Status=1) rt 
	on rt.TemplateMenuId=TM.Id
	WHERE TM.TemplateMenuId = ISNULL(@P_Id, TM.TemplateMenuId)
		AND TM.IsActive = 1 order by Id
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateSubMenuItem]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateSubMenuItem]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetTemplateSubMenuItem] (@P_Id Int)
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateSubMenuId
		,TM.Guidance
		,TM.Description
		,TM.ScreenName
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
	FROM TemplateSubMenuItem  TM
	INNER JOIN [dbo].[TemplateSubMenu] TS ON TS.Id = TM.TemplateSubMenuId
	WHERE TM.TemplateSubMenuId = ISNULL(@P_Id, TM.TemplateSubMenuId)
		AND TM.IsActive = 1
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateSubMenuItemDetailsByTemplateId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateSubMenuItemDetailsByTemplateId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [SP_GetTemplateSubMenuItemDetailsByTemplateId] 1,1
CREATE PROCEDURE [dbo].[SP_GetTemplateSubMenuItemDetailsByTemplateId] (@P_Id Int,@ReportId int)
AS
BEGIN
	SELECT 
		 TM.Id
		,TM.Code
		,TM.TemplateMenuId
		,FW.TemplateMenuName
		,TM.TemplateSubMenuName
		,TM.Id TemplateSubMenuId
		,TM.Description
		,TM.IsActive
		,TM.CreatedDate
		,TM.CreatedByUserId
		,TM.UpdatedDate
		,TM.UpdatedByUserId
		,case when rt.Id is null then 'false' else 'true' end checked
	FROM TemplateSubMenu TM
	INNER JOIN TemplateMenu FW ON FW.Id = TM.TemplateMenuId
	inner join(select * from ReportTemplateMenuId where ReportId =@ReportId and Checked=1 and Status=1)
	rt on rt.TemplateMenuId=TM.Id
	WHERE TM.TemplateMenuId = ISNULL(@P_Id, TM.TemplateMenuId)
		AND TM.IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTemplateSubMenuItemsByTemplateSubmenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTemplateSubMenuItemsByTemplateSubmenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetTemplateSubMenuItemsByTemplateSubmenuId] (@P_Id Int)
AS
BEGIN
	SELECT 
		*
	FROM TemplateSubMenuItem 

	WHERE TemplateSubMenuId = ISNULL(@P_Id,TemplateSubMenuId)
		AND IsActive = 1
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserDetailbyEmailId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserDetailbyEmailId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetUserDetailbyEmailId] (@P_EmailId varchar(255))
AS
BEGIN
	SELECT 
		count(*) cnt	
	FROM [dbo].[Users] r
	WHERE r.EmailId = ISNULL(@P_EmailId, r.EmailId)
		AND r.ViewYN = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUsers] (@P_Id INT)
AS
BEGIN
	SELECT 
		 u.[Id]
		 ,r.OrganizationName
		,u.[UserName]
		,u.[Password]
		,u.[FirstName]
		,u.[LastName]
		,u.[EmailId]
		,u.[MobileNumber]
		,u.[RoleId]
		,u.[ViewYN]
		,u.[CreatedDate]
		,u.[CreatedByUserId]
		,u.[UpdatedDate]
		,u.[UpdatedByUserId]
	FROM [dbo].[Users] u
	inner join Registration r on r.Id=u.Id
	WHERE u.Id = ISNULL(@P_Id, u.Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers1]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers1]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUsers1] (@P_Id INT)
AS
BEGIN
	select * from [Users]
		WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetUsersDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,r.Name as RoleName
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Users] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	inner join Roles r on r.Id =t.RoleId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersinOrganization]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersinOrganization]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetUsersinOrganization 'AD9C98C9-DCEC-4FE7-97DD-A6DEC08743E6'
CREATE PROCEDURE [dbo].[SP_GetUsersinOrganization] (@OrgId varchar(255))
AS
BEGIN
 select *,r.Name as RoleName from Users
	inner join Roles r on r.Id =RoleId
where OrgId=@OrgId
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetValidatingFinalReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetValidatingFinalReport]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetValidatingFinalReport] (@ReportId varchar(255),@UserId INT)
as
begin
select f.*
from ValidatingFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 AND f.UserId = @UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetValidatingFinalReportonlybyReportid]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetValidatingFinalReportonlybyReportid]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetValidatingFinalReportonlybyReportid] (@ReportId varchar(255))
as
begin
select f.*
from ValidatingFinalReport f

 WHERE f.ReportId = ISNULL(@ReportId, f.ReportId) AND f.IsActive = 1 
end
GO

-- %% [markdown]
-- # [dbo].[SP_ResetUserPassword]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ResetUserPassword]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_ResetUserPassword] (@Password varchar(255),@Id int)
as
begin
update Users set Password  = @Password where Id = @Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_SelectedTemplateMenuCategoryTreeView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SelectedTemplateMenuCategoryTreeView]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_SelectedTemplateMenuCategoryTreeView 'E4340632-9816-451A-80FD-FB2DE6407E9F'
CREATE proc [dbo].[SP_SelectedTemplateMenuCategoryTreeView](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
inner join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId and rtsm.Checked=1


select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select Code+' '+TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by TemplateMenuId, Id For Json Path ) children into #inner
from TemplateMenuCategory tmc where tmc.IsActive = 1 and tmc.Id in (select TemplateMenuCategoryId from #TemplateSubMenu)
 


--select * from
--(select tm.TemplateMenuName,tm.Id,case when tm.Id !=1 then
--(select text,value,collapsed,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm)x where x.Sub is not null
 select * from
(select *,case when Id =1 then 1 
when Id= 8 then 2 
when Id=2 then 3
when Id=3 then 4
when Id=6 then 5 end SNo
from 
 (select * from
(select tm.TemplateMenuName,tm.Id,case when tm.Id !=8 then
(select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id order by value For Json Path ) else
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuId=tm.Id order by value ASC For Json Path ) 
end Sub from TemplateMenu tm)x where x.Sub is not null)X)Y Order by Y.SNo

drop table #TemplateSubMenu
drop table #inner

end


GO

-- %% [markdown]
-- # [dbo].[SP_SelectedTemplateMenuCategoryTreeViewforTemplate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SelectedTemplateMenuCategoryTreeViewforTemplate]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_SelectedTemplateMenuCategoryTreeView 'E4340632-9816-451A-80FD-FB2DE6407E9F'
Create proc [dbo].[SP_SelectedTemplateMenuCategoryTreeViewforTemplate](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
inner join ReportTemplateMenuIdforTemplate rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId and rtsm.Checked=1


select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select Code+' '+TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by TemplateMenuId, Id For Json Path ) children into #inner
from TemplateMenuCategory tmc where tmc.IsActive = 1 and tmc.Id in (select TemplateMenuCategoryId from #TemplateSubMenu)
 


--select * from
--(select tm.TemplateMenuName,tm.Id,case when tm.Id !=1 then
--(select text,value,collapsed,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm)x where x.Sub is not null
 select * from
(select *,case when Id =1 then 1 
when Id= 8 then 2 
when Id=2 then 3
when Id=3 then 4
when Id=6 then 5 end SNo
from 
 (select * from
(select tm.TemplateMenuName,tm.Id,case when tm.Id !=8 then
(select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id order by value For Json Path ) else
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuId=tm.Id order by value ASC For Json Path ) 
end Sub from TemplateMenu tm)x where x.Sub is not null)X)Y Order by Y.SNo

drop table #TemplateSubMenu
drop table #inner

end


GO

-- %% [markdown]
-- # [dbo].[SP_SGX_GuidanceScreen]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SGX_GuidanceScreen]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_SGX_GuidanceScreen] (@ScreenName varchar(255))
AS
BEGIN
    SELECT *
    FROM SGX_TemplateSubMenuItem
    WHERE ScreenName = COALESCE(@ScreenName, ScreenName);
END
GO

-- %% [markdown]
-- # [dbo].[SP_SGX_SelectedTemplateMenuCategoryTreeView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SGX_SelectedTemplateMenuCategoryTreeView]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_SelectedTemplateMenuCategoryTreeView 'EC28ED01-8EB6-4114-B973-68950E96B82E'
Create proc [dbo].[SP_SGX_SelectedTemplateMenuCategoryTreeView](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #SGX_TemplateSubMenu from SGX_TemplateSubMenu tsm
inner join SGX_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId and rtsm.Checked=1

select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select Code+' '+TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #SGX_TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
from SGX_TemplateMenuCategory tmc where tmc.Id in (select TemplateMenuCategoryId from #SGX_TemplateSubMenu)

--select * from
--(select tm.TemplateMenuName,tm.Id,case when tm.Id !=1 then
--(select text,value,collapsed,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm)x where x.Sub is not null
 select * from
(select *,case when Id =1 then 1 
when Id= 8 then 2 
when Id=2 then 3
when Id=3 then 4
when Id=6 then 5 end SNo
from 
 (select * from
(select tm.TemplateMenuName,tm.Id,case when tm.Id !=8 then
(select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #SGX_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) 
end Sub from SGX_TemplateMenu tm)x where x.Sub is not null)X)Y Order by Y.SNo

drop table #SGX_TemplateSubMenu
drop table #inner

end

GO

-- %% [markdown]
-- # [dbo].[SP_SGX_TemplateMenuCategoryTreeView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SGX_TemplateMenuCategoryTreeView]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_SGX_TemplateMenuCategoryTreeView '9B0180AB-3D12-4848-A618-1E0CC1C97CEF'
CREATE proc [dbo].[SP_SGX_TemplateMenuCategoryTreeView](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #SGX_TemplateSubMenu from SGX_TemplateSubMenu tsm
left join SGX_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId


select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value
from SGX_TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
from SGX_TemplateMenuCategory tmc


select tm.TemplateMenuName,tm.Id,case when tm.Id in (1,2,3) then (select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id order by Id For Json Path) else
(select TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #SGX_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub from SGX_TemplateMenu tm

drop table #SGX_TemplateSubMenu
drop table #inner
end


GO

-- %% [markdown]
-- # [dbo].[SP_SGX_TestPurpose]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SGX_TestPurpose]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TestPurpose '1A40EE55-BD42-43F0-B92A-5C9EF19289B7'
Create proc [dbo].[SP_SGX_TestPurpose](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #SGX_TemplateSubMenu from SGX_TemplateSubMenu tsm
left join SGX_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId

select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #SGX_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from SGX_TemplateMenu tm
drop table #SGX_TemplateSubMenu


------ Latest Changes with TemplateMenu Category ------

--select tsm.*,case when rtsm.Id is null then 'false'
--when rtsm.checked = 0 then 'false'
--when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
--left join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
--rtsm.ReportId = @ReportId


--select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,
--(select Code+' '+TemplateSubMenuName as text,cast(tmc.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
--from TemplateMenuCategory tmc


--select tm.Id,tm.TemplateMenuName,case when tm.Id !=1 then
--(select text,value,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm

--drop table #TemplateSubMenu
--drop table #inner

end

GO

-- %% [markdown]
-- # [dbo].[SP_SGX_TestPurpose2]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SGX_TestPurpose2]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TestPurpose2 'hhh'
Create proc [dbo].[SP_SGX_TestPurpose2](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false' else 'true' end checked into #SGX_TemplateSubMenu 
from SGX_TemplateSubMenu tsm
Inner join SGX_ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId and rtsm.Checked=1


select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #SGX_TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from SGX_TemplateMenu tm where tm.Id in (select TemplateMenuId from #SGX_TemplateSubMenu)
end
GO

-- %% [markdown]
-- # [dbo].[SP_TemplateMenuCategoryTreeView]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TemplateMenuCategoryTreeView]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TemplateMenuCategoryTreeView '8C0D9385-5FEF-48EF-B884-76F7F065859E'
CREATE proc [dbo].[SP_TemplateMenuCategoryTreeView](@ReportId varchar(255))
as
begin

------ Latest Changes with TemplateMenu Category ------

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked 
into #TemplateSubMenu 
from TemplateSubMenu tsm
left join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
rtsm.ReportId = @ReportId
where tsm.IsActive = 1 -- add this line to filter by IsActive=1

select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,'true'  as collapsed,
(select Code+' '+TemplateSubMenuName as text,cast(tmc.TemplateMenuId as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where IsActive = 1 and TemplateMenuCategoryId=tmc.Id and IsActive=1 order by Id For Json Path ) children into #inner
from TemplateMenuCategory tmc
where tmc.IsActive = 1 -- add this line to filter by IsActive=1

select * from
(select *,case when Id =1 then 1 
when Id= 8 then 2 
when Id=2 then 3
when Id=3 then 4
when Id=6 then 5 end SNo
from 
(select tm.TemplateMenuName,tm.Id,case when tm.Id != 8 then
(select text,value,collapsed,JSON_QUERY(children) children
from #inner where TemplateMenuId=tm.Id and IsActive=1 order by Id For Json Path ) else
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuId=tm.Id and IsActive=1 order by Id For Json Path ) 
end Sub from TemplateMenu tm where IsActive = 1)X)Y order by Y.SNo

drop table #TemplateSubMenu
drop table #inner

end
GO

-- %% [markdown]
-- # [dbo].[SP_TestPurpose]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TestPurpose]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TestPurpose '1A40EE55-BD42-43F0-B92A-5C9EF19289B7'
CREATE proc [dbo].[SP_TestPurpose](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
left join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId

select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from TemplateMenu tm
drop table #TemplateSubMenu


------ Latest Changes with TemplateMenu Category ------

--select tsm.*,case when rtsm.Id is null then 'false'
--when rtsm.checked = 0 then 'false'
--when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
--left join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and 
--rtsm.ReportId = @ReportId


--select tmc.TemplateMenuId,tmc.Name as text,tmc.Id as value,
--(select Code+' '+TemplateSubMenuName as text,cast(tmc.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuCategoryId=tmc.Id order by Id For Json Path ) children into #inner
--from TemplateMenuCategory tmc


--select tm.Id,tm.TemplateMenuName,case when tm.Id !=1 then
--(select text,value,JSON_QUERY(children) children
--from #inner where TemplateMenuId=tm.Id order by Id For Json Path ) else
--(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
--from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) end Sub
--from TemplateMenu tm

--drop table #TemplateSubMenu
--drop table #inner

end

GO

-- %% [markdown]
-- # [dbo].[SP_TestPurpose_categorywise]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TestPurpose_categorywise]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--

CREATE proc [dbo].[SP_TestPurpose_categorywise](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false'
when rtsm.checked = 0 then 'false'
when rtsm.checked = 1 then 'true' end checked into #TemplateSubMenu from TemplateSubMenu tsm
left join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId

select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from TemplateMenu tm

drop table #TemplateSubMenu
end

GO

-- %% [markdown]
-- # [dbo].[SP_TestPurpose2]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TestPurpose2]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TestPurpose2 20
CREATE proc [dbo].[SP_TestPurpose2](@ReportId varchar(255))
as
begin

select tsm.*,case when rtsm.Id is null then 'false' else 'true' end checked into #TemplateSubMenu 
from TemplateSubMenu tsm
Inner join ReportTemplateMenuId rtsm on rtsm.TemplateMenuId = tsm.Id and rtsm.ReportId = @ReportId and rtsm.Checked=1


select tm.Id,tm.TemplateMenuName,
(select Code+' '+TemplateSubMenuName as text,cast(tm.Id as varchar(255)) +':'+ cast(Id as varchar(255)) as value,checked
from #TemplateSubMenu where TemplateMenuId=tm.Id order by Id For Json Path ) Sub from TemplateMenu tm where tm.Id in (select TemplateMenuId from #TemplateSubMenu)
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateBRSR_ReportGenerationForStage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateBRSR_ReportGenerationForStage]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_UpdateBRSR_ReportGenerationForStage](@ReportId varchar(255),@Stage varchar(255))
as
begin

update BRSR_ReportGeneration set Stage =@Stage where ReportId = @ReportId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateRegistrationStatus]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateRegistrationStatus]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_UpdateRegistrationStatus] 
(
 @Id int
,@OrganizationName varchar(255)
,@OrganizationType varchar(255)
,@HeadOffice varchar(255)
,@Country varchar(255)
,@Pincode bigint
,@ContactName varchar(255)
,@EmailId varchar(255)
,@ContactNumber bigint
,@Designation varchar(255)
,@EncryptedPassword varchar(255)
,@registrationOUT int OUTPUT
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
	BEGIN 
			UPDATE [dbo].Registration
				SET  
				[OrganizationName] = @OrganizationName
				,[OrganizationType] = @OrganizationType
				,[HeadOffice] = @HeadOffice
				,[Country] = @Country
				,[Pincode] = @Pincode
				,[ContactName] = @ContactName
				,[EmailId] = @EmailId
				,[ContactNumber] = @ContactNumber
				,[Designation] = @Designation
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				--,[UpdatedByUserId] = @UpdatedByUserId
				,[UpdatedByUserId] =1
			WHERE Id = @Id	
	END 

	
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportGeneration]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportGeneration]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdateReportGeneration](@ReportId varchar(255),@ReportName varchar(255),@UserId int)
as
begin
update ReportGeneration Set ReportName=@ReportName,
UpdatedDate=getdate(),UpdatedByUserId=@UserId
where ReportId = @ReportId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportGenerationForStage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportGenerationForStage]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_UpdateReportGenerationForStage](@ReportId varchar(255),@Stage varchar(255))
as
begin

update ReportGeneration set Stage =@Stage where ReportId = @ReportId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportInitialDraftById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportInitialDraftById]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_UpdateReportInitialDraftById] 
  @Id INT,
@InitialDraftReport varchar(max)
	,@reportoutId int output
as
begin
update ReportGeneration Set InitialDraftReport=@InitialDraftReport
where ID=@ID
set @reportoutId=@@IDENTITY
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportTemplateMenuId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportTemplateMenuId]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_UpdateReportTemplateMenuId] (@ReportId int)
as
begin
update ReportTemplateMenuId set Status=1 where ReportId=@ReportId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportTemplateMenuIdback]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportTemplateMenuIdback]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_UpdateReportTemplateMenuIdback '1A40EE55-BD42-43F0-B92A-5C9EF19289B7'
CREATE Proc [dbo].[SP_UpdateReportTemplateMenuIdback] (@ReportId Varchar(255))
as
begin
delete from ReportTemplateMenuId where ReportId=@ReportId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportTemplateMenuIdCheck]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportTemplateMenuIdCheck]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_UpdateReportTemplateMenuIdCheck] (@ReportId int)
as
begin
update ReportTemplateMenuId set Checked=1 where ReportId=@ReportId
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateReportTemplateMenuIdfromTemplate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateReportTemplateMenuIdfromTemplate]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_UpdateReportTemplateMenuIdfromTemplate] (
	 @Id INT = NULL
	,@ReportId varchar(255) output
	,@reportoutId int output 
	 ,@UserId int
	 ,@TemplateMenuId int
	 ,@Checked bit
	 ,@Status bit
	,@IsActive BIT = 1
	,@CreatedDate DATETIME
	,@CreatedByUserId INT
	,@UpdatedDate DATETIME
	,@UpdatedByUserId INT
	)
AS
BEGIN
  IF ISNULL(@Id,0)=0
			begin
			INSERT INTO [dbo].[ReportTemplateMenuId] (
				[UserId]
				,[TemplateMenuId]
				,[Checked]
				,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@UserId
				,@TemplateMenuId
				,@Checked
				,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @reportoutId=@@IDENTITY
				declare @rId varchar(255)
				set @rId = NEWID()
				update ReportGeneration set ReportId=@rId where Id = @reportoutId
				set @ReportId = @rId
           end

else
begin
update ReportTemplateMenuId Set ReportId=@ReportId,UserId=@UserId,TemplateMenuId=@TemplateMenuId,
Checked=@Checked,Status=@Status,IsActive=@IsActive,
UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ReportId=@ReportId and TemplateMenuId=@TemplateMenuId
 set @reportoutId=@Id
end 
end

GO

-- %% [markdown]
-- # [dbo].[SP_UpdateUserPassword]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateUserPassword]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_UpdateUserPassword] (@EmailId varchar(255),@Password varchar(255))
AS
BEGIN
	update Users set Password=@Password  where EmailId  =@EmailId 
END
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateVerificationCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateVerificationCode]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create procedure [dbo].[SP_UpdateVerificationCode](@EmailId varchar(255),@VerificationCode bigint)
as
begin
update Users set VerificationCode=@VerificationCode where EmailId=@EmailId
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(255),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
		u.*
		,r.Name as RoleName
		FROM Users u 
		inner join Roles r on r.Id=u.RoleId
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateVerificationCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateVerificationCode]    Script Date: 27-10-2023 14:37:39 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_ValidateVerificationCode] (@VerificationCode bigint)
as
begin
select  OrgId  from Users  where VerificationCode=@VerificationCode
end
GO
