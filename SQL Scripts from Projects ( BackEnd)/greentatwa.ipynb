-- %% [markdown]
-- # [dbo].[Category]

-- %%
USE [greentatwa]
GO

-- %%
/****** Object:  Table [dbo].[Category]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Category](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Crop]

-- %%
/****** Object:  Table [dbo].[Crop]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Crop](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](255) NULL,
	[Category] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Product]

-- %%
/****** Object:  Table [dbo].[Product]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Product](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[QRCounter]

-- %%
/****** Object:  Table [dbo].[QRCounter]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[QRCounter](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[QRId] [varchar](255) NULL,
	[IPAddress] [varchar](256) NULL,
	[latitude] [varchar](100) NULL,
	[longitude] [varchar](100) NULL,
	[City] [varchar](255) NULL,
	[RigionName] [varchar](255) NULL,
	[PinCode] [varchar](256) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SKU]

-- %%
/****** Object:  Table [dbo].[SKU]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SKU](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](255) NULL,
	[Description] [varchar](max) NULL,
	[CropId] [int] NULL,
	[Category] [varchar](255) NULL,
	[UOMId] [int] NULL,
	[Size] [int] NULL,
	[Price] [decimal](18, 2) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[ProductCode] [varchar](255) NULL,
	[ProductName] [varchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StockDetails]

-- %%
/****** Object:  Table [dbo].[StockDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StockDetails](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[BatchID] [varchar](255) NULL,
	[BatchCode] [varchar](255) NULL,
	[Crop] [varchar](50) NULL,
	[FarmID] [varchar](50) NULL,
	[FarmLocation] [varchar](255) NULL,
	[Year] [int] NULL,
	[Farmer] [varchar](50) NULL,
	[GPS] [varchar](255) NULL,
	[FarmerName] [varchar](50) NULL,
	[Season] [varchar](50) NULL,
	[HarvestedDate] [datetime] NULL,
	[SKU] [varchar](50) NULL,
	[ProductCode] [varchar](50) NULL,
	[ProductName] [varchar](50) NULL,
	[MFD] [datetime] NULL,
	[Quantity] [varchar](50) NULL,
	[BestBefore] [datetime] NULL,
	[ProcessedDate] [datetime] NULL,
	[ProcessedAt] [varchar](255) NULL,
	[GFCDate] [datetime] NULL,
	[QRCode] [varchar](255) NULL,
	[UniqueId] [varchar](255) NULL,
	[Status] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[StockDetailsHDR]

-- %%
/****** Object:  Table [dbo].[StockDetailsHDR]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[StockDetailsHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](max) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[UOM]

-- %%
/****** Object:  Table [dbo].[UOM]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[UOM](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NULL,
	[Name] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](30) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[MiddleName] [varchar](50) NULL,
	[LastName] [varchar](50) NOT NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[RoleId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Category__IsActi__3D2915A8]

-- %%
ALTER TABLE [dbo].[Category] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Category__Create__3E1D39E1]

-- %%
ALTER TABLE [dbo].[Category] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Category__Update__3F115E1A]

-- %%
ALTER TABLE [dbo].[Category] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Crop__IsActive__49C3F6B7]

-- %%
ALTER TABLE [dbo].[Crop] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Crop__CreatedDat__4AB81AF0]

-- %%
ALTER TABLE [dbo].[Crop] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Crop__UpdatedDat__4BAC3F29]

-- %%
ALTER TABLE [dbo].[Crop] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__70DDC3D8]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__IsActive__71D1E811]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__72C60C4A]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__73BA3083]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__74AE54BC]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__75A278F5]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__Product__IsActiv__2FCF1A8A]

-- %%
ALTER TABLE [dbo].[Product] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Product__Created__30C33EC3]

-- %%
ALTER TABLE [dbo].[Product] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Product__Updated__31B762FC]

-- %%
ALTER TABLE [dbo].[Product] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__QRCounter__Creat__4F47C5E3]

-- %%
ALTER TABLE [dbo].[QRCounter] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__7A672E12]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__7B5B524B]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__7C4F7684]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__IsActi__7D439ABD]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__7E37BEF6]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__7F2BE32F]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__IsActive__5DCAEF64]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__5EBF139D]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__5FB337D6]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__SKU__IsActive__534D60F1]

-- %%
ALTER TABLE [dbo].[SKU] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__SKU__CreatedDate__5441852A]

-- %%
ALTER TABLE [dbo].[SKU] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__SKU__UpdatedDate__5535A963]

-- %%
ALTER TABLE [dbo].[SKU] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__StockDeta__IsAct__282DF8C2]

-- %%
ALTER TABLE [dbo].[StockDetailsHDR] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__StockDeta__Creat__29221CFB]

-- %%
ALTER TABLE [dbo].[StockDetailsHDR] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__StockDeta__Updat__2A164134]

-- %%
ALTER TABLE [dbo].[StockDetailsHDR] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__UOM__IsActive__4E88ABD4]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__UOM__CreatedDate__4F7CD00D]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__UOM__UpdatedDate__5070F446]

-- %%
ALTER TABLE [dbo].[UOM] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__IsActive__6A30C649]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__6B24EA82]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__6C190EBB]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK_Menu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Menu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [dbo].[SP_AddCrop]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCrop]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddCrop] 
(
 @Id int
,@Name varchar(100)
,@Category varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[Crop] (
				 [Code]
				,[Name]
				,[Category]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 ''
				,@Name
				,@Category
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @Out int
				set @Out = @@IDENTITY
				update [dbo].[Crop] set Code = UPPER(SUBSTRING(@Name,1,3))+cast(@Out as varchar(max)) where Id = @Out
				End
		ELSE
			UPDATE [dbo].[Crop]
			SET  
				 [Name] = @Name
				 ,[Category] = @Category
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddProduct]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddProduct]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddProduct] 
(
 @Id int
,@Code  varchar(100)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[Product] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				
				End
		ELSE
			UPDATE [dbo].[Product]
			SET  
					[Code] = @Code
				 ,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddQRCounter]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddQRCounter]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddQRCounter] (
@Id int,
@QRId varchar(255),
@IPAddress varchar(255) ,
@latitude varchar(100),
@longitude varchar(100),
@City varchar(255),
@RigionName  varchar(255),
@PinCode varchar(255),
@IsActive bit



)
as
begin
If  isnull(@Id,0) = 0
begin
insert into QRCounter(
QRId ,
IPAddress,
latitude,
longitude,
City ,
RigionName,
PinCode,
IsActive


)
values(
@QRId ,
@IPAddress,
@latitude,
@longitude,
@City ,
@RigionName,
@PinCode,
@IsActive


)

end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





CREATE PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[Roles] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 ''
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @Out int
				set @Out = @@IDENTITY
				update [dbo].[Roles] set Code = UPPER(SUBSTRING(@Name,1,3))+cast(@Out as varchar(max)) where Id = @Out
				End
		ELSE
			UPDATE [dbo].[Roles]
			SET  
				 [Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSKU]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSKU]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddSKU] 
(
 @Id int
,@Name varchar(100)
,@ProductCode varchar(255)
,@ProductName varchar(255)
,@CropId int
,@Category varchar(255)
,@UOMId int
,@Size int
,@Price decimal(18,2)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[SKU] (
				 [Code]
				,[Name]
				,[ProductCode]
				,[ProductName]
				,[CropId]
				,[Category]
				,[UOMId]
				,[Size]
				,[Price]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				''
				,@Name
				,@ProductCode
				,@ProductName
				,@CropId
				,@Category
				,@UOMId
				,@Size
				,@Price
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @Out int
				set @Out = @@IDENTITY
				update [dbo].[SKU] set Code = UPPER(SUBSTRING(@Name,1,3))+cast(@Out as varchar(max)) where Id = @Out
				End
		ELSE
			UPDATE [dbo].[SKU]
			SET  
				 [Name] = @Name
				 ,[ProductCode] = @ProductCode
				 ,[ProductName] = @ProductName
				 ,[CropId] = @CropId
				 ,[Category] = @Category
				 ,[UOMId] = @UOMId
				 ,[Size] = @Size
				 ,[Price] = @Price
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStock]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





CREATE PROCEDURE [dbo].[SP_AddStock] 
(
 @Id int
,@BatchCode varchar(100)
,@Crop varchar(100)
,@FarmID varchar(100)
,@FarmLocation varchar(100)
,@Year int
,@Farmer varchar(100)
,@GPS varchar(max)
,@FarmerName varchar(255)
,@Season varchar(255)
,@HarvestedDate datetime
,@SKU varchar(100)
,@ProductCode varchar(100)
,@ProductName varchar(100)
,@MFD datetime
,@Quantity varchar(100)
,@BestBefore datetime
,@ProcessedDate datetime
,@ProcessedAt varchar(255)
,@GFCDate datetime
,@Status varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[StockDetails] (
			      BatchID
				 ,BatchCode
				 ,Crop
				 ,FarmID
				 ,FarmLocation
				 ,[Year]
				 ,Farmer
				 ,GPS
				 ,FarmerName
				 ,Season
				 ,[Status]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			'0'
				  ,@BatchCode
				 ,@Crop
				 ,@FarmID
				 ,@FarmLocation
				 ,@Year
				 ,@Farmer
				 ,@GPS
				 ,@FarmerName
				 ,@Season
				 ,@Status
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @Out int
				set @Out = @@IDENTITY
				update [dbo].[StockDetails] set BatchID= 'GT'+cast(@out as varchar(max)) where Id = @out
				End
		ELSE
			UPDATE [dbo].[StockDetails]
			SET  
				 SKU = @SKU
				 ,ProductCode = @ProductCode
				 ,ProductName = @ProductName
				 ,MFD = @MFD
				 ,Quantity = @Quantity
				 ,BestBefore = @BestBefore
				 ,ProcessedDate =@ProcessedDate
				 ,ProcessedAt =@ProcessedAt
				 ,HarvestedDate = @HarvestedDate
				 ,GFCDate = @GFCDate
				 ,[Status] = @Status
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddStockDetailsHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStockDetailsHDR]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddStockDetailsHDR] 
(
 @Id int
,@Code varchar(max)
,@IsActive bit
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@BatchCode NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[StockDetailsHDR] (
				 [Code]
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @Code
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
				declare @Out int
				SET @Out=@@IDENTITY
				update StockDetailsHDR set Code= 'GT'+@Code +cast(format(@Out,'000') as varchar(max)) where Id=@Out
				set @BatchCode = 'GT'+@Code +cast(format(@Out,'000') as varchar(max))
				
		END
		
END
	

GO

-- %% [markdown]
-- # [dbo].[SP_AddUOM]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUOM]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_AddUOM] 
(
 @Id int
,@Code varchar(100)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		Begin
			INSERT INTO [dbo].[UOM] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
			
				End
		ELSE
			UPDATE [dbo].[UOM]
			SET  [Code]=@Code
				 ,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
 @Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@MiddleName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber bigint
,@RoleId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Users] (
				 [UserName]
				,[Password]
				,[FirstName]
				,[MiddleName]
				,[LastName]
				,[EmailId]
				,[MobileNumber]
				,[RoleId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				@UserName
				,@Password
				,@FirstName
				,@MiddleName
				,@LastName
				,@EmailId
				,@MobileNumber
				,@RoleId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Users]
			SET  
				[UserName] = @UserName
				,[Password] = @Password
				,[FirstName] = @FirstName
				,[MiddleName] = @MiddleName
				,[LastName] = @LastName
				,[EmailId] = @EmailId
				,[MobileNumber] = @MobileNumber
				,[RoleId] = @RoleId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_Get_StockDetailsQuantityByBatchCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Get_StockDetailsQuantityByBatchCode]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE Proc [dbo].[SP_Get_StockDetailsQuantityByBatchCode](@StartDate date,@EndDate date)
as
begin
select (sum(cast(Quantity as int))) Quantity from StockDetails where  cast(UpdatedDate as Date)>=@StartDate and
cast(UpdatedDate as Date)<= @EndDate and
Quantity is not null and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_Get_StockDetailsQuantityByBatchId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Get_StockDetailsQuantityByBatchId]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE Proc [dbo].[SP_Get_StockDetailsQuantityByBatchId](@StartDate date,@EndDate date)
as
begin
select cast(UpdatedDate as Date) Date,sum(cast(Quantity as int))Quantity from StockDetails where cast(UpdatedDate as Date)>=@StartDate and
cast(UpdatedDate as Date)<= @EndDate and Quantity is not null and IsActive=1
group by cast(UpdatedDate as Date)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBatchCodeofStock]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBatchCodeofStock]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetBatchCodeofStock]
as
begin
 select distinct BatchCode from StockDetails where IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCategoryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCategoryDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetCategoryDetails] (@P_Id INT)
AS
BEGIN
	SELECT cr.Id
		,cr.Name
		,cr.IsActive
		,cr.CreatedDate
		,u.Name as 'CreatedByUserId'
		,cr.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.Category cr
	inner join UserInfo u on cr.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=cr.UpdatedByUserId
	WHERE cr.Id = ISNULL(@P_Id, cr.Id)
		AND cr.IsActive = 1 order by cr.Id 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCrop]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCrop]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetCrop] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[Category]
	FROM [dbo].[Crop]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCropDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCropDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetCropDetails] (@P_Id INT)
AS
BEGIN
	SELECT cr.Id
		,cr.Code
		,cr.Name
		,cr.Category
		,cr.IsActive
		,cr.CreatedDate
		,u.Name as 'CreatedByUserId'
		,cr.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.Crop cr
	inner join UserInfo u on cr.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=cr.UpdatedByUserId
	WHERE cr.Id = ISNULL(@P_Id, cr.Id)
		AND cr.IsActive = 1 order by cr.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuTypeName type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuTypeName type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.IsActive
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id)
		--AND m.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



Create PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@P_UserId, u.Id)
	AND RM.IsActive = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetProductDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetProductDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetProductDetails] (@P_Id INT)
AS
BEGIN
	SELECT cr.Id
		,cr.Code
		,cr.Name
		,cr.IsActive
		,cr.CreatedDate
		,u.Name as 'CreatedByUserId'
		,cr.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.Product cr
	inner join UserInfo u on cr.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=cr.UpdatedByUserId
	WHERE cr.Id = ISNULL(@P_Id, cr.Id)
		AND cr.IsActive = 1 order by cr.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetQRCounterDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetQRCounterDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_GetQRCounterDetails](@p_Id int)
as
begin 
select Id,QRId,IPAddress,latitude,longitude,City,RigionName,PinCode ,IsActive,CreatedDate from QRCounter where  Id=isnull (@p_Id,Id)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[IsActive]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.IsActive = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRolesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUserId
	FROM [dbo].[Roles] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSKUDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSKUDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetSKUDetails] (@P_Id INT)
AS
BEGIN
	SELECT sku.Id
		,sku.Code
		,sku.Name
		,sku.ProductCode
		,sku.ProductName
		,sku.Category
		,sku.Price
		,sku.Size
		,sku.CropId
		,cr.Name CropName
		,sku.UOMId
		,uom.Name UOMName
		,sku.IsActive
		,sku.CreatedDate
		,u.Name as 'CreatedByUserId'
		,sku.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.SKU sku
	inner join UserInfo u on sku.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=sku.UpdatedByUserId
	inner join Crop cr on cr.Id = sku.CropId
	inner join UOM uom on uom.Id =sku.UOMId
	WHERE sku.Id = ISNULL(@P_Id, sku.Id)
		AND sku.IsActive = 1 order by sku.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetStockDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,'GT'+cast(t.Id as varchar(max)) as BatchID
		,t.BatchCode
		,t.[Crop]
		,t.FarmID
		,t.FarmLocation
		,t.Year
		,t.Farmer
		,t.GPS
		,t.FarmerName
		,t.Season
		,t.Status
		,t.SKU
		,t.ProductCode
		,t.ProductName
		,t.MFD
		,t.Quantity
		,t.BestBefore
		,t.HarvestedDate
		,t.ProcessedDate
		,t.ProcessedAt
		,t.GFCDate
		,t.QRCode
		,t.UniqueId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUserId
		,isnull(qc.QRcount,0) QRcount
	FROM [dbo].[StockDetails]  t WITH (NOLOCK)
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	left join (select count(*) QRcount, QRId from QRCounter group by QRId) qc on qc.QRId = t.UniqueId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1  order by Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetailsByBatchCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetailsByBatchCode]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO








CREATE PROCEDURE [dbo].[SP_GetStockDetailsByBatchCode] (@P_Id varchar(max))
AS
BEGIN
	SELECT 
		 t.[Id]
		,'GT'+cast(t.Id as varchar(max)) as BatchID
		,t.BatchCode
		,t.[Crop]
		,t.FarmID
		,t.FarmLocation
		,t.Year
		,t.Farmer
		,t.GPS
		,t.FarmerName
		,t.Season
		,t.Status
		,t.SKU
		,t.ProductCode
		,t.ProductName
		,t.MFD
		,t.Quantity
		,t.BestBefore
		,t.HarvestedDate
		,t.ProcessedDate
		,t.ProcessedAt
		,t.GFCDate
		,t.QRCode
		,t.UniqueId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUserId
	FROM [dbo].[StockDetails] t WITH (NOLOCK)
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	--left join Product p on p.Id = ProductCode
	WHERE t.BatchCode = ISNULL(@P_Id, t.BatchCode)
		AND t.IsActive = 1 order by Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStockDetailsForBlockchain]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStockDetailsForBlockchain]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO








CREATE PROCEDURE [dbo].[SP_GetStockDetailsForBlockchain] (@P_Id varchar(max))
AS
BEGIN
	SELECT 
		'jNE7WI8dkAaBoDtpj73zTidQHdGqz55OllZ10gBfc4dDfDbXVk60qoezz4vPAVjP' payload
		,'GT Form' Form
		,'GT'+cast(t.Id as varchar(max)) as BatchID
		 ,t.[Id]
		,t.BatchCode
		,t.[Crop]
		,t.FarmID
		,t.FarmLocation
		,t.Year
		,t.Farmer
		,t.GPS
		,t.FarmerName
		,t.Season
		,t.Status
		,t.SKU
		,t.ProductCode
		,t.ProductName
		,t.MFD
		,t.Quantity
		,t.BestBefore
		,t.HarvestedDate
		,t.ProcessedDate
		,t.ProcessedAt
		,t.GFCDate
		,t.QRCode
		,t.UniqueId
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUserId
	FROM [dbo].[StockDetails] t WITH (NOLOCK)
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	--left join Product p on p.Id = t.ProductCode
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1 order by Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUOM]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUOM]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUOM] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
	FROM [dbo].[UOM]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1 order by Id
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUOMDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUOMDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUOMDetails] (@P_Id INT)
AS
BEGIN
	SELECT uom.Id
		,uom.Code
		,uom.Name
		,uom.IsActive
		,uom.CreatedDate
		,u.Name as 'CreatedByUserId'
		,uom.UpdatedDate
		,um.Name as 'UpdatedByUserId'
	FROM dbo.UOM uom
	inner join UserInfo u on uom.CreatedByUserId=u.Id 
	inner join UserInfo Um ON Um.id=uom.UpdatedByUserId
	WHERE uom.Id = ISNULL(@P_Id, uom.Id)
		AND uom.IsActive = 1 order by uom.Id desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetUsers] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[UserName]
		,[Password]
		,[FirstName]
		,[MiddleName]
		,[LastName]
		,[EmailId]
		,[MobileNumber]
		,[RoleId]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Users]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetUsersDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[UserName]
		,t.[Password]
		,t.[FirstName]
		,t.[MiddleName]
		,t.[LastName]
		,t.[EmailId]
		,t.[MobileNumber]
		,t.[RoleId]
		,c.RoleName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Users] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateStockDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateStockDetails]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdateStockDetails](@Id int,@QRCode varchar(max),@UniqueId varchar(max))
as
begin
update StockDetails set QRCode=@QRCode,UniqueId=@UniqueId where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 14:58:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNumber,
			u.Password
		FROM Users u 
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.IsActive=1
END
GO
