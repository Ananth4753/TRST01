-- %% [markdown]
-- # [dbo].[AgentTargets]

-- %%
USE [sowandreap_live]
GO

-- %%
/****** Object:  Table [dbo].[AgentTargets]    Script Date: 27-10-2023 15:05:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[AgentTargets](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[WeekId] [int] NULL,
	[TargetRegistration] [int] NULL,
	[TargetArea] [float] NULL,
	[AgentId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BorewellPumpOperations]

-- %%
/****** Object:  Table [dbo].[BorewellPumpOperations]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BorewellPumpOperations](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Date] [date] NULL,
	[HoursDay] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[PumpCapacity] [decimal](18, 2) NULL,
	[DepthOfBorewll] [decimal](18, 2) NULL,
	[TypeOfIrrigation] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ClusterDTL]

-- %%
/****** Object:  Table [dbo].[ClusterDTL]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ClusterDTL](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ClusterHDRId] [int] NULL,
	[VillageId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ClusterHDR]

-- %%
/****** Object:  Table [dbo].[ClusterHDR]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ClusterHDR](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NULL,
	[Name] [varchar](255) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ComplaintRepository]

-- %%
/****** Object:  Table [dbo].[ComplaintRepository]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ComplaintRepository](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ComplaintCode] [varchar](60) NOT NULL,
	[ModuleTypeId] [int] NOT NULL,
	[FileName] [varchar](100) NOT NULL,
	[FileLocation] [varchar](250) NOT NULL,
	[FileExtension] [varchar](25) NOT NULL,
	[IsVideoRecording] [bit] NOT NULL,
	[IsResult] [bit] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[ServerUpdatedStatus] [bit] NOT NULL,
	[LogBookNo] [varchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Complaints]

-- %%
/****** Object:  Table [dbo].[Complaints]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Complaints](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](60) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[ComplaintStatus] [int] NOT NULL,
	[ComplaintType] [int] NOT NULL,
	[solution] [varchar](255) NOT NULL,
	[LogBookNo] [varchar](255) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ComplaintStatusHistory]

-- %%
/****** Object:  Table [dbo].[ComplaintStatusHistory]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ComplaintStatusHistory](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ComplaintCode] [varchar](60) NOT NULL,
	[ComplaintTypeById] [int] NULL,
	[StatusTypeId] [int] NOT NULL,
	[AssigntoUserId] [int] NOT NULL,
	[Comments] [varchar](150) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Crop]

-- %%
/****** Object:  Table [dbo].[Crop]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Crop](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[Season] [varchar](10) NULL,
 CONSTRAINT [PK__Crop__3214EC07110B5746] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UQ__Crop__737584F6BB7CB968] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CropVariety]

-- %%
/****** Object:  Table [dbo].[CropVariety]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CropVariety](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[CropId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[District]

-- %%
/****** Object:  Table [dbo].[District]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[District](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[StateId] [int] NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_District_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_District_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Documents]

-- %%
/****** Object:  Table [dbo].[Documents]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Documents](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[PlotNo] [varchar](255) NULL,
	[IdentityCode] [varchar](max) NULL,
	[DocUrl] [varchar](500) NULL,
	[DocType] [varchar](255) NULL,
	[DocExtension] [varchar](255) NULL,
	[DocOldNum] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[DocLocal] [varchar](max) NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Farmer]

-- %%
/****** Object:  Table [dbo].[Farmer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Farmer](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[FarmerTitle] [varchar](255) NULL,
	[FirstName] [varchar](255) NULL,
	[MiddleName] [varchar](255) NULL,
	[LastName] [varchar](255) NULL,
	[FatherName] [varchar](255) NULL,
	[Gender] [varchar](255) NULL,
	[Age] [int] NULL,
	[PrimaryContactNum] [varchar](255) NULL,
	[SecondaryContactNum] [varchar](255) NULL,
	[Address] [varchar](4000) NULL,
	[DistrictId] [int] NULL,
	[MandalId] [int] NULL,
	[StateId] [int] NULL,
	[VillageId] [int] NULL,
	[PinCode] [varchar](255) NULL,
	[Sync] [bit] NULL,
	[IsPlot] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[TotalPlotArea] [float] NULL,
	[PlotsCount] [int] NULL,
	[LocalImage] [varchar](max) NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[IdentityCode] [varchar](500) NULL,
 CONSTRAINT [PK_Farmer_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_FarmerCode] UNIQUE NONCLUSTERED 
(
	[FarmerCode] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FarmerBank]

-- %%
/****** Object:  Table [dbo].[FarmerBank]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FarmerBank](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[IdentityCode] [varchar](255) NULL,
	[AccountHolderName] [varchar](255) NULL,
	[AccountNumber] [varchar](255) NULL,
	[BranchName] [varchar](255) NULL,
	[IFSCCode] [varchar](250) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[LocalDocUrl] [varchar](max) NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FarmerConsent]

-- %%
/****** Object:  Table [dbo].[FarmerConsent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FarmerConsent](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[Name] [varchar](255) NOT NULL,
	[AgreementDate] [datetime] NULL,
	[DigitalSign] [varchar](max) NULL,
	[1_1_a] [bit] NULL,
	[1_1_b] [bit] NULL,
	[1_1_c] [bit] NULL,
	[1_1_d] [bit] NULL,
	[1_1_e] [bit] NULL,
	[1_2_a] [bit] NULL,
	[1_2_b] [bit] NULL,
	[1_2_c] [bit] NULL,
	[1_2_d] [bit] NULL,
	[IsActive] [bit] NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[UpdatedDate] [datetime] NULL,
	[Base64] [varchar](max) NULL,
	[DataEntryUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fertilizer]

-- %%
/****** Object:  Table [dbo].[Fertilizer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fertilizer](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Fertilizer] [int] NULL,
	[FertilizerType] [int] NULL,
	[Date] [date] NULL,
	[Qty] [decimal](18, 2) NULL,
	[UOM] [int] NULL,
	[CropProtection] [varchar](255) NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GeoBoundaries]

-- %%
/****** Object:  Table [dbo].[GeoBoundaries]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GeoBoundaries](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotNo] [varchar](255) NULL,
	[Latitude] [varchar](100) NULL,
	[Longitude] [varchar](100) NULL,
	[GeoCategoryTypeId] [int] NULL,
	[Sync] [bit] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SeqNo] [int] NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
 CONSTRAINT [PK_GeoBoundaries_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[GHGEmissionCollection]

-- %%
/****** Object:  Table [dbo].[GHGEmissionCollection]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[GHGEmissionCollection](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Date] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[S1C1] [decimal](18, 3) NULL,
	[S1C2] [decimal](18, 3) NULL,
	[S1C3] [decimal](18, 3) NULL,
	[S2C1] [decimal](18, 3) NULL,
	[S2C2] [decimal](18, 3) NULL,
	[S2C3] [decimal](18, 3) NULL,
	[S3C1] [decimal](18, 3) NULL,
	[S3C2] [decimal](18, 3) NULL,
	[S3C3] [decimal](18, 3) NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[S1TimeStamp] [datetime] NULL,
	[S2TimeStamp] [datetime] NULL,
	[S3TimeStamp] [datetime] NULL,
	[LogBookNo] [varchar](50) NULL,
	[SoilTemperature] [float] NULL,
	[SoilMoisture] [decimal](18, 3) NULL,
	[PlotAreaLatitude] [varchar](50) NULL,
	[PlotAreaLongitude] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HarvestDetails]

-- %%
/****** Object:  Table [dbo].[HarvestDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HarvestDetails](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Date] [date] NULL,
	[YeildQty] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Land]

-- %%
/****** Object:  Table [dbo].[Land]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Land](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PlotNo] [varchar](255) NOT NULL,
	[Size] [varchar](255) NULL,
	[CropId] [int] NULL,
	[FarmerCode] [varchar](255) NULL,
	[Latitude] [varchar](100) NULL,
	[Longitude] [varchar](100) NULL,
	[Address] [varchar](255) NULL,
	[Plotownership] [varchar](255) NULL,
	[LandMark] [varchar](255) NULL,
	[DistrictId] [int] NULL,
	[MandalId] [int] NULL,
	[VillageId] [int] NULL,
	[StateId] [int] NULL,
	[PinCode] [varchar](255) NULL,
	[SurveyNo] [varchar](100) NULL,
	[PattadarBookNo] [varchar](255) NULL,
	[GPS] [varchar](255) NULL,
	[Sync] [bit] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[GPSPlotArea] [decimal](18, 6) NULL,
	[Cluster] [varchar](255) NULL,
	[LandImage] [varchar](max) NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[PlotArea1] [decimal](18, 6) NULL,
	[PlotArea2] [decimal](18, 6) NULL,
	[PlotArea3] [decimal](18, 6) NULL,
	[PlotArea4] [decimal](18, 6) NULL,
	[PlotArea5] [decimal](18, 6) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC,
	[PlotNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_PlotNo] UNIQUE NONCLUSTERED 
(
	[PlotNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LogBook]

-- %%
/****** Object:  Table [dbo].[LogBook]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LogBook](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](50) NOT NULL,
	[PlotNo] [varchar](50) NULL,
	[Crop] [int] NULL,
	[CropVariety] [int] NULL,
	[SeedVariety] [int] NULL,
	[SeedDistributor] [int] NULL,
	[Season] [int] NULL,
	[CultivationPractice] [int] NULL,
	[DateOfSowing] [datetime] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[isClosed] [bit] NULL,
	[IsProgressive] [bit] NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[FarmerCode] [varchar](255) NULL,
	[CurrYear] [int] NULL,
	[PreviousYeild] [decimal](18, 6) NULL,
	[PrevSeason] [int] NULL,
	[PrevCropVariety] [int] NULL,
	[DateOfTransplanting] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC,
	[LogBookNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_LogBookNo] UNIQUE NONCLUSTERED 
(
	[LogBookNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LogBook_Season]

-- %%
/****** Object:  Table [dbo].[LogBook_Season]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LogBook_Season](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[PlotNo] [varchar](255) NOT NULL,
	[CurrYear] [int] NULL,
	[CropId] [int] NULL,
	[SeasonId] [int] NULL,
	[CropVarietyId] [int] NULL,
	[CultivationPractiseId] [int] NULL,
	[PreviousYeildWithoutAWD] [decimal](18, 3) NULL,
	[YieldInCurrentSeason] [decimal](18, 3) NULL,
	[DateOfSowing] [datetime] NULL,
	[DateOfTransplanting] [datetime] NULL,
	[DateOfPipeInstallation] [datetime] NULL,
	[DateOfFirstDrying] [datetime] NULL,
	[DateOfSecondDrying] [datetime] NULL,
	[DateOfHarvest] [datetime] NULL,
	[UREAQty_1] [decimal](18, 3) NULL,
	[DAPQty_1] [decimal](18, 3) NULL,
	[PotashQty_1] [decimal](18, 3) NULL,
	[OtherFertilizerQty_1] [decimal](18, 3) NULL,
	[UREAQty_2] [decimal](18, 3) NULL,
	[DAPQty_2] [decimal](18, 3) NULL,
	[PotashQty_2] [decimal](18, 3) NULL,
	[OtherFertilizerQty_2] [decimal](18, 3) NULL,
	[UREAQty_3] [decimal](18, 3) NULL,
	[DAPQty_3] [decimal](18, 3) NULL,
	[PotashQty_3] [decimal](18, 3) NULL,
	[OtherFertilizerQty_3] [decimal](18, 3) NULL,
	[IsClosed] [bit] NULL,
	[IsProgressive] [bit] NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[DataEntryUserId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC,
	[LogBookNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [const_LogBook_Season] UNIQUE NONCLUSTERED 
(
	[LogBookNo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LogBookBeforeAWD]

-- %%
/****** Object:  Table [dbo].[LogBookBeforeAWD]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LogBookBeforeAWD](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[PlotNo] [varchar](255) NOT NULL,
	[RabiCropVarietyId] [int] NULL,
	[KharifCropVarietyId] [int] NULL,
	[RabiYeild] [decimal](18, 3) NULL,
	[KharifYeild] [decimal](18, 3) NULL,
	[RabiFertilizerUREAQty_1] [decimal](18, 3) NULL,
	[RabiFertilizerDAPQty_1] [decimal](18, 3) NULL,
	[RabiFertilizerPotashQty_1] [decimal](18, 3) NULL,
	[RabiFertilizerOtherQty_1] [decimal](18, 3) NULL,
	[KharifFertilizerUREAQty_1] [decimal](18, 3) NULL,
	[KharifFertilizerDAPQty_1] [decimal](18, 3) NULL,
	[KharifFertilizerPotashQty_1] [decimal](18, 3) NULL,
	[KharifFertilizerOtherQty_1] [decimal](18, 3) NULL,
	[RabiFertilizerUREAQty_2] [decimal](18, 3) NULL,
	[RabiFertilizerDAPQty_2] [decimal](18, 3) NULL,
	[RabiFertilizerPotashQty_2] [decimal](18, 3) NULL,
	[RabiFertilizerOtherQty_2] [decimal](18, 3) NULL,
	[KharifFertilizerUREAQty_2] [decimal](18, 3) NULL,
	[KharifFertilizerDAPQty_2] [decimal](18, 3) NULL,
	[KharifFertilizerPotashQty_2] [decimal](18, 3) NULL,
	[KharifFertilizerOtherQty_2] [decimal](18, 3) NULL,
	[RabiFertilizerUREAQty_3] [decimal](18, 3) NULL,
	[RabiFertilizerDAPQty_3] [decimal](18, 3) NULL,
	[RabiFertilizerPotashQty_3] [decimal](18, 3) NULL,
	[RabiFertilizerOtherQty_3] [decimal](18, 3) NULL,
	[KharifFertilizerUREAQty_3] [decimal](18, 3) NULL,
	[KharifFertilizerDAPQty_3] [decimal](18, 3) NULL,
	[KharifFertilizerPotashQty_3] [decimal](18, 3) NULL,
	[KharifFertilizerOtherQty_3] [decimal](18, 3) NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[DataEntryUserId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupDtl]

-- %%
/****** Object:  Table [dbo].[LookupDtl]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupDtl](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[LookupHdrId] [int] NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[Remarks] [varchar](100) NULL,
	[Ord] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LookupHdr]

-- %%
/****** Object:  Table [dbo].[LookupHdr]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LookupHdr](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Mandal]

-- %%
/****** Object:  Table [dbo].[Mandal]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Mandal](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[DistrictId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Mandal_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Menu]

-- %%
/****** Object:  Table [dbo].[Menu]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Menu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](50) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MenuType] [varchar](1) NOT NULL,
	[ParentMenuId] [int] NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[Path] [varchar](1024) NOT NULL,
	[Icon] [varchar](1024) NOT NULL,
	[Order] [int] NULL,
 CONSTRAINT [PK_Menu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Menu_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[OrganicAmendments]

-- %%
/****** Object:  Table [dbo].[OrganicAmendments]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[OrganicAmendments](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Value] [int] NULL,
	[Date] [date] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PipeInstallation]

-- %%
/****** Object:  Table [dbo].[PipeInstallation]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PipeInstallation](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NOT NULL,
	[CurrYear] [int] NOT NULL,
	[SeasonId] [int] NOT NULL,
	[DateOfPipeInstallation] [datetime] NULL,
	[Latitude] [float] NULL,
	[Longitude] [float] NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PlacesInCurrentCity]

-- %%
/****** Object:  Table [dbo].[PlacesInCurrentCity]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PlacesInCurrentCity](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Location] [geography] NULL,
	[Name] [varchar](100) NULL
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Raajitable]

-- %%
/****** Object:  Table [dbo].[Raajitable]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Raajitable](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](500) NULL,
	[DocURL] [varchar](1000) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RaajiTable1]

-- %%
/****** Object:  Table [dbo].[RaajiTable1]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RaajiTable1](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](500) NULL,
	[DocURL] [varchar](1000) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RaajiTable2]

-- %%
/****** Object:  Table [dbo].[RaajiTable2]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RaajiTable2](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[FarmerCode] [varchar](255) NULL,
	[PipeInstalled] [date] NULL,
	[FirstDry] [date] NULL,
	[FirstFlood] [date] NULL,
	[SecondDry] [date] NULL,
	[SecondFlood] [date] NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RoleMenu]

-- %%
/****** Object:  Table [dbo].[RoleMenu]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RoleMenu](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[RoleId] [int] NOT NULL,
	[MenuId] [int] NOT NULL,
	[AddYN] [bit] NOT NULL,
	[EditYN] [bit] NOT NULL,
	[DeleteYN] [bit] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_RoleMenu_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Roles_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Roles_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Season]

-- %%
/****** Object:  Table [dbo].[Season]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Season](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](10) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[PlantFrom] [datetime] NOT NULL,
	[PlantTo] [datetime] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_Season_Code] UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Code] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SeedDistributor]

-- %%
/****** Object:  Table [dbo].[SeedDistributor]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SeedDistributor](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](50) NOT NULL,
	[RegistrationNo] [varchar](50) NULL,
	[Location] [varchar](255) NULL,
	[Address] [varchar](4000) NULL,
	[Pincode] [varchar](20) NULL,
	[PhoneNo] [varchar](20) NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SoilHealthCard]

-- %%
/****** Object:  Table [dbo].[SoilHealthCard]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SoilHealthCard](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SampleNo] [varchar](50) NOT NULL,
	[SampleCollectionDate] [datetime] NOT NULL,
	[SoilColour] [int] NOT NULL,
	[SoilNature] [int] NOT NULL,
	[PH] [decimal](18, 2) NOT NULL,
	[OrganicCarbon] [decimal](18, 2) NOT NULL,
	[Nitrogen] [decimal](18, 2) NOT NULL,
	[Phosphorous] [decimal](18, 2) NOT NULL,
	[Potassium] [decimal](18, 2) NOT NULL,
	[Sulphur] [decimal](18, 2) NOT NULL,
	[Zinc] [decimal](18, 2) NOT NULL,
	[Iron] [decimal](18, 2) NOT NULL,
	[Manganese] [decimal](18, 2) NOT NULL,
	[Copper] [decimal](18, 2) NOT NULL,
	[Boron] [decimal](18, 2) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[PlotNo] [varchar](255) NULL,
	[ElectricalConductivity] [decimal](18, 2) NULL,
	[DocUrl] [varchar](500) NULL,
	[DocType] [varchar](255) NULL,
	[DocExtension] [varchar](255) NULL,
	[Type] [varchar](20) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[States]

-- %%
/****** Object:  Table [dbo].[States]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[States](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Code] [varchar](6) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_State_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UK_State_Name] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TabDatabase]

-- %%
/****** Object:  Table [dbo].[TabDatabase]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TabDatabase](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Name] [varchar](max) NULL,
	[UserId] [int] NULL,
	[FileSize] [varchar](max) NULL,
	[FileType] [varchar](max) NULL,
	[FilePath] [varchar](max) NULL,
	[CreatedDate] [datetime] NULL,
	[AgentId] [int] NULL,
	[VoluntaryId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblCalendar]

-- %%
/****** Object:  Table [dbo].[tblCalendar]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCalendar](
	[Date] [date] NOT NULL,
	[Day] [char](10) NOT NULL,
	[DayOfWeek] [tinyint] NOT NULL,
	[DayOfMonth] [tinyint] NOT NULL,
	[DayOfYear] [smallint] NOT NULL,
	[PreviousDay] [date] NOT NULL,
	[NextDay] [date] NOT NULL,
	[WeekOfYear] [tinyint] NOT NULL,
	[Month] [char](10) NOT NULL,
	[MonthOfYear] [tinyint] NOT NULL,
	[QuarterOfYear] [tinyint] NOT NULL,
	[Year] [int] NOT NULL,
	[IsWeekend] [bit] NOT NULL,
 CONSTRAINT [PK_CalendarDate] PRIMARY KEY CLUSTERED 
(
	[Date] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Users]

-- %%
/****** Object:  Table [dbo].[Users]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Users](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](30) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[MiddileName] [varchar](50) NULL,
	[LastName] [varchar](50) NOT NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[RoleId] [int] NOT NULL,
	[ViewYN] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[IMEINo] [varchar](50) NULL,
	[DOB] [date] NULL,
	[Education] [varchar](100) NULL,
	[Address] [varchar](500) NULL,
	[photo] [varchar](max) NULL,
 CONSTRAINT [PK_Users_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Village]

-- %%
/****** Object:  Table [dbo].[Village]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Village](
	[Id] [int] NOT NULL,
	[Code] [varchar](255) NOT NULL,
	[Name] [varchar](100) NOT NULL,
	[MandalId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
	[PinCode] [varchar](255) NULL,
 CONSTRAINT [PK_Village_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Voluntary]

-- %%
/****** Object:  Table [dbo].[Voluntary]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Voluntary](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[UserName] [varchar](30) NOT NULL,
	[Password] [nvarchar](1024) NOT NULL,
	[FirstName] [varchar](50) NOT NULL,
	[LastName] [varchar](50) NOT NULL,
	[EmailId] [varchar](100) NULL,
	[MobileNumber] [bigint] NULL,
	[DOB] [date] NULL,
	[Education] [varchar](100) NULL,
	[Address] [varchar](500) NULL,
	[Photo] [varchar](max) NULL,
	[IMEINo] [varchar](50) NULL,
	[AgentId] [int] NOT NULL,
	[RoleId] [int] NOT NULL,
	[IsActive] [bit] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[CreatedByUserId] [int] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
	[UpdatedByUserId] [int] NOT NULL,
 CONSTRAINT [PK_Voluntary_Id] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WaterReasonPreSeason]

-- %%
/****** Object:  Table [dbo].[WaterReasonPreSeason]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WaterReasonPreSeason](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Field] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WaterRegimeonSeason]

-- %%
/****** Object:  Table [dbo].[WaterRegimeonSeason]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WaterRegimeonSeason](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Field] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WaterRegimeOnthefield]

-- %%
/****** Object:  Table [dbo].[WaterRegimeOnthefield]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WaterRegimeOnthefield](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[LogBookNo] [varchar](255) NULL,
	[Field] [int] NULL,
	[IsActive] [bit] NULL,
	[CreatedDate] [datetime] NULL,
	[CreatedByUserId] [int] NULL,
	[UpdatedDate] [datetime] NULL,
	[UpdatedByUserId] [int] NULL,
	[SQNo] [varchar](15) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[WeeklyCalendar]

-- %%
/****** Object:  Table [dbo].[WeeklyCalendar]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[WeeklyCalendar](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Year] [int] NOT NULL,
	[WeekOfYear] [int] NOT NULL,
	[WeekStart] [date] NOT NULL,
	[WeekEnd] [date] NOT NULL,
	[CreatedDate] [datetime] NOT NULL,
	[UpdatedDate] [datetime] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__AgentTarg__IsAct__2724C5F0]

-- %%
ALTER TABLE [dbo].[AgentTargets] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__AgentTarg__Creat__2818EA29]

-- %%
ALTER TABLE [dbo].[AgentTargets] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__AgentTarg__Updat__290D0E62]

-- %%
ALTER TABLE [dbo].[AgentTargets] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__BorewellP__Creat__6E565CE8]

-- %%
ALTER TABLE [dbo].[BorewellPumpOperations] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__BorewellP__Updat__6F4A8121]

-- %%
ALTER TABLE [dbo].[BorewellPumpOperations] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ClusterDT__IsAct__2F9A1060]

-- %%
ALTER TABLE [dbo].[ClusterDTL] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ClusterDT__Creat__308E3499]

-- %%
ALTER TABLE [dbo].[ClusterDTL] ADD  DEFAULT ((1)) FOR [CreatedByUserId]
GO

-- %% [markdown]
-- # [DF__ClusterDT__Creat__318258D2]

-- %%
ALTER TABLE [dbo].[ClusterDTL] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ClusterDT__Updat__32767D0B]

-- %%
ALTER TABLE [dbo].[ClusterDTL] ADD  DEFAULT ((1)) FOR [UpdatedByUserId]
GO

-- %% [markdown]
-- # [DF__ClusterDT__Updat__336AA144]

-- %%
ALTER TABLE [dbo].[ClusterDTL] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__ClusterHD__IsAct__28ED12D1]

-- %%
ALTER TABLE [dbo].[ClusterHDR] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__ClusterHD__Creat__29E1370A]

-- %%
ALTER TABLE [dbo].[ClusterHDR] ADD  DEFAULT ((1)) FOR [CreatedByUserId]
GO

-- %% [markdown]
-- # [DF__ClusterHD__Creat__2AD55B43]

-- %%
ALTER TABLE [dbo].[ClusterHDR] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__ClusterHD__Updat__2BC97F7C]

-- %%
ALTER TABLE [dbo].[ClusterHDR] ADD  DEFAULT ((1)) FOR [UpdatedByUserId]
GO

-- %% [markdown]
-- # [DF__ClusterHD__Updat__2CBDA3B5]

-- %%
ALTER TABLE [dbo].[ClusterHDR] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Crop__IsActive__047AA831]

-- %%
ALTER TABLE [dbo].[Crop] ADD  CONSTRAINT [DF__Crop__IsActive__047AA831]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Crop__CreatedDat__0662F0A3]

-- %%
ALTER TABLE [dbo].[Crop] ADD  CONSTRAINT [DF__Crop__CreatedDat__0662F0A3]  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Crop__UpdatedDat__084B3915]

-- %%
ALTER TABLE [dbo].[Crop] ADD  CONSTRAINT [DF__Crop__UpdatedDat__084B3915]  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__District__IsActi__6C190EBB]

-- %%
ALTER TABLE [dbo].[District] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__District__Create__6D0D32F4]

-- %%
ALTER TABLE [dbo].[District] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__District__Update__6E01572D]

-- %%
ALTER TABLE [dbo].[District] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Farmer__IsActive__40058253]

-- %%
ALTER TABLE [dbo].[Farmer] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Farmer__CreatedD__40F9A68C]

-- %%
ALTER TABLE [dbo].[Farmer] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Farmer__UpdatedD__41EDCAC5]

-- %%
ALTER TABLE [dbo].[Farmer] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_1_a__04CFADEC]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_1_a]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_1_b__05C3D225]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_1_b]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_1_c__06B7F65E]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_1_c]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_1_d__07AC1A97]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_1_d]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_2_a__08A03ED0]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_2_a]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_2_b__09946309]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_2_b]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_2_c__0A888742]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_2_c]
GO

-- %% [markdown]
-- # [DF__FarmerCon__1_2_d__0B7CAB7B]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((0)) FOR [1_2_d]
GO

-- %% [markdown]
-- # [DF__FarmerCon__IsAct__0C70CFB4]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__FarmerCon__Creat__0D64F3ED]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__FarmerCon__Updat__0E591826]

-- %%
ALTER TABLE [dbo].[FarmerConsent] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Fertilize__Creat__75F77EB0]

-- %%
ALTER TABLE [dbo].[Fertilizer] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Fertilize__Updat__76EBA2E9]

-- %%
ALTER TABLE [dbo].[Fertilizer] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__GeoBounda__IsAct__40C49C62]

-- %%
ALTER TABLE [dbo].[GeoBoundaries] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__GeoBounda__Creat__41B8C09B]

-- %%
ALTER TABLE [dbo].[GeoBoundaries] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__GeoBounda__Updat__42ACE4D4]

-- %%
ALTER TABLE [dbo].[GeoBoundaries] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__HarvestDe__IsAct__4FD1D5C8]

-- %%
ALTER TABLE [dbo].[HarvestDetails] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__HarvestDe__Creat__50C5FA01]

-- %%
ALTER TABLE [dbo].[HarvestDetails] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__HarvestDe__Updat__51BA1E3A]

-- %%
ALTER TABLE [dbo].[HarvestDetails] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Land__IsActive__44CA3770]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Land__CreatedDat__45BE5BA9]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Land__UpdatedDat__46B27FE2]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Land__PlotArea1__01BE3717]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT ((0)) FOR [PlotArea1]
GO

-- %% [markdown]
-- # [DF__Land__PlotArea2__02B25B50]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT ((0)) FOR [PlotArea2]
GO

-- %% [markdown]
-- # [DF__Land__PlotArea3__03A67F89]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT ((0)) FOR [PlotArea3]
GO

-- %% [markdown]
-- # [DF__Land__PlotArea4__049AA3C2]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT ((0)) FOR [PlotArea4]
GO

-- %% [markdown]
-- # [DF__Land__PlotArea5__058EC7FB]

-- %%
ALTER TABLE [dbo].[Land] ADD  DEFAULT ((0)) FOR [PlotArea5]
GO

-- %% [markdown]
-- # [DF__LogBook__Created__02284B6B]

-- %%
ALTER TABLE [dbo].[LogBook] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LogBook__Updated__031C6FA4]

-- %%
ALTER TABLE [dbo].[LogBook] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LogBook_S__Creat__737017C0]

-- %%
ALTER TABLE [dbo].[LogBook_Season] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LogBook_S__Updat__74643BF9]

-- %%
ALTER TABLE [dbo].[LogBook_Season] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__IsAct__7E8CC4B1]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Creat__7F80E8EA]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupDtl__Updat__00750D23]

-- %%
ALTER TABLE [dbo].[LookupDtl] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__IsAct__79C80F94]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Creat__7ABC33CD]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__LookupHdr__Updat__7BB05806]

-- %%
ALTER TABLE [dbo].[LookupHdr] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Mandal__IsActive__75A278F5]

-- %%
ALTER TABLE [dbo].[Mandal] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Mandal__CreatedD__76969D2E]

-- %%
ALTER TABLE [dbo].[Mandal] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Mandal__UpdatedD__778AC167]

-- %%
ALTER TABLE [dbo].[Mandal] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__MenuType__58D1301D]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('I') FOR [MenuType]
GO

-- %% [markdown]
-- # [DF__Menu__ViewYN__59C55456]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Menu__CreatedDat__5AB9788F]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__UpdatedDat__5BAD9CC8]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Menu__Path__5CA1C101]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Path]
GO

-- %% [markdown]
-- # [DF__Menu__Icon__5D95E53A]

-- %%
ALTER TABLE [dbo].[Menu] ADD  DEFAULT ('') FOR [Icon]
GO

-- %% [markdown]
-- # [DF__OrganicAm__IsAct__54968AE5]

-- %%
ALTER TABLE [dbo].[OrganicAmendments] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__OrganicAm__Creat__558AAF1E]

-- %%
ALTER TABLE [dbo].[OrganicAmendments] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__OrganicAm__Updat__567ED357]

-- %%
ALTER TABLE [dbo].[OrganicAmendments] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__AddYN__0B5CAFEA]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [AddYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__EditYN__0C50D423]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [EditYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Delete__0D44F85C]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [DeleteYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__ViewYN__0E391C95]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Create__0F2D40CE]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__RoleMenu__Update__10216507]

-- %%
ALTER TABLE [dbo].[RoleMenu] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__ViewYN__03BB8E22]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Roles__CreatedDa__04AFB25B]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Roles__UpdatedDa__05A3D694]

-- %%
ALTER TABLE [dbo].[Roles] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Season__IsActive__047AA831]

-- %%
ALTER TABLE [dbo].[Season] ADD  CONSTRAINT [DF__Season__IsActive__047AA831]  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Season__CreatedDat__0662F0A3]

-- %%
ALTER TABLE [dbo].[Season] ADD  CONSTRAINT [DF__Season__CreatedDat__0662F0A3]  DEFAULT (NULL) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Season__UpdatedDat__084B3915]

-- %%
ALTER TABLE [dbo].[Season] ADD  CONSTRAINT [DF__Season__UpdatedDat__084B3915]  DEFAULT (NULL) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__States__IsActive__66603565]

-- %%
ALTER TABLE [dbo].[States] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__States__CreatedD__6754599E]

-- %%
ALTER TABLE [dbo].[States] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__States__UpdatedD__68487DD7]

-- %%
ALTER TABLE [dbo].[States] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Users__ViewYN__59FA5E80]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT ((1)) FOR [ViewYN]
GO

-- %% [markdown]
-- # [DF__Users__CreatedDa__5AEE82B9]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Users__UpdatedDa__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[Users] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Village__IsActiv__347EC10E]

-- %%
ALTER TABLE [dbo].[Village] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Village__Created__3572E547]

-- %%
ALTER TABLE [dbo].[Village] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Village__Updated__36670980]

-- %%
ALTER TABLE [dbo].[Village] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__Voluntary__IsAct__5EAA0504]

-- %%
ALTER TABLE [dbo].[Voluntary] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__Voluntary__Creat__5F9E293D]

-- %%
ALTER TABLE [dbo].[Voluntary] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__Voluntary__Updat__60924D76]

-- %%
ALTER TABLE [dbo].[Voluntary] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WaterReas__IsAct__5A4F643B]

-- %%
ALTER TABLE [dbo].[WaterReasonPreSeason] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WaterReas__Creat__5B438874]

-- %%
ALTER TABLE [dbo].[WaterReasonPreSeason] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WaterReas__Updat__5C37ACAD]

-- %%
ALTER TABLE [dbo].[WaterReasonPreSeason] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WaterRegi__IsAct__5F141958]

-- %%
ALTER TABLE [dbo].[WaterRegimeonSeason] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WaterRegi__Creat__60083D91]

-- %%
ALTER TABLE [dbo].[WaterRegimeonSeason] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WaterRegi__Updat__60FC61CA]

-- %%
ALTER TABLE [dbo].[WaterRegimeonSeason] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [DF__WaterRegi__IsAct__63D8CE75]

-- %%
ALTER TABLE [dbo].[WaterRegimeOnthefield] ADD  DEFAULT ((1)) FOR [IsActive]
GO

-- %% [markdown]
-- # [DF__WaterRegi__Creat__64CCF2AE]

-- %%
ALTER TABLE [dbo].[WaterRegimeOnthefield] ADD  DEFAULT (getdate()) FOR [CreatedDate]
GO

-- %% [markdown]
-- # [DF__WaterRegi__Updat__65C116E7]

-- %%
ALTER TABLE [dbo].[WaterRegimeOnthefield] ADD  DEFAULT (getdate()) FOR [UpdatedDate]
GO

-- %% [markdown]
-- # [FK__CropVarie__CropI__7993056A]

-- %%
ALTER TABLE [dbo].[CropVariety]  WITH CHECK ADD FOREIGN KEY([CropId])
REFERENCES [dbo].[Crop] ([Id])
GO

-- %% [markdown]
-- # [FK_Menu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Menu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Menu]  WITH CHECK ADD  CONSTRAINT [FK_Menu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Menu] CHECK CONSTRAINT [FK_Menu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_MenuId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_MenuId] FOREIGN KEY([MenuId])
REFERENCES [dbo].[Menu] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_MenuId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_RoleId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_RoleId] FOREIGN KEY([RoleId])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_RoleId]
GO

-- %% [markdown]
-- # [FK_RoleMenu_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[RoleMenu]  WITH CHECK ADD  CONSTRAINT [FK_RoleMenu_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[RoleMenu] CHECK CONSTRAINT [FK_RoleMenu_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK__Roles__CreatedBy__0697FACD]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO

-- %% [markdown]
-- # [FK_Roles_CreatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_CreatedByUserId] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_CreatedByUserId]
GO

-- %% [markdown]
-- # [FK_Roles_UpdatedByUserId]

-- %%
ALTER TABLE [dbo].[Roles]  WITH CHECK ADD  CONSTRAINT [FK_Roles_UpdatedByUserId] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Roles] CHECK CONSTRAINT [FK_Roles_UpdatedByUserId]
GO

-- %% [markdown]
-- # [FK__Season__CreatedByUser__056ECC6A]

-- %%
ALTER TABLE [dbo].[Season]  WITH CHECK ADD  CONSTRAINT [FK__Season__CreatedByUser__056ECC6A] FOREIGN KEY([CreatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Season] CHECK CONSTRAINT [FK__Season__CreatedByUser__056ECC6A]
GO

-- %% [markdown]
-- # [FK__Season__UpdatedByUser__075714DC]

-- %%
ALTER TABLE [dbo].[Season]  WITH CHECK ADD  CONSTRAINT [FK__Season__UpdatedByUser__075714DC] FOREIGN KEY([UpdatedByUserId])
REFERENCES [dbo].[Users] ([Id])
GO
ALTER TABLE [dbo].[Season] CHECK CONSTRAINT [FK__Season__UpdatedByUser__075714DC]
GO

-- %% [markdown]
-- # [dbo].[LookupDtlByCode]

-- %%
/****** Object:  StoredProcedure [dbo].[LookupDtlByCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[LookupDtlByCode](@Code varchar(255))
as
begin
select * from LookupDtl where Code = @Code
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddAgentTargets]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddAgentTargets]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_AddAgentTargets]
(
 @Id int,
 @WeekId int,
 @TargetRegistration int,
 @TargetArea float,
 @AgentId int,
 @IsActive bit,
 @CreatedDate datetime,
 @CreatedByUserId int,
 @UpdatedDate datetime,
 @UpdatedByUserId int
)
as
begin
 
     if isnull(@Id,0) = 0
	 begin
	   insert into AgentTargets(WeekId,TargetRegistration,TargetArea,AgentId,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId)
	   values(@WeekId,@TargetRegistration,@TargetArea,@AgentId,@IsActive,@CreatedDate,@CreatedByUserId,@UpdatedDate,@UpdatedByUserId)
	 end
	 else
	 begin
	    update AgentTargets set WeekId= @WeekId,TargetRegistration = @TargetRegistration,
		TargetArea = @TargetArea,AgentId = @AgentId,IsActive = @IsActive,UpdatedDate = @UpdatedDate,UpdatedByUserId = @UpdatedByUserId
		where Id = @Id
	 end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddBorewellPumpOperations]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddBorewellPumpOperations]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddBorewellPumpOperations]
(@ID int,
@LogBookNo varchar(255),
@Date date,
@HoursDay int,
@PumpCapacity decimal(18,2),
@DepthOfBorewll decimal(18,2),
@TypeOfIrrigation int,
@SQNo varchar(15),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
/*declare @LogId int
  set @LogId= (select count(*) from BorewellPumpOperations  where LogBookNo=@LogBookNo)*/
 If isnull(@Id,0) = 0
 begin
 insert into BorewellPumpOperations(
LogBookNo,
Date,
HoursDay,
PumpCapacity,
DepthOfBorewll,
TypeOfIrrigation,
SQNo,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

)
values(
  @LogBookNo,
  @Date,
  @HoursDay,
  @PumpCapacity ,
@DepthOfBorewll ,
@TypeOfIrrigation,
@SQNo,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
  
end
else
begin
update BorewellPumpOperations Set LogBookNo=@LogBookNo,Date=@Date,HoursDay=@HoursDay,PumpCapacity=@PumpCapacity,
DepthOfBorewll=@DepthOfBorewll,TypeOfIrrigation=@TypeOfIrrigation,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where LogBookNo=@LogBookNo
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddClusterDTL]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddClusterDTL]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddClusterDTL] 
(
 @Id int
,@ClusterHDRId int
,@VillageId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[ClusterDTL] (
				 [ClusterHDRId]
				,[VillageId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			    @ClusterHDRId
				,@VillageId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[ClusterDTL]
			SET  
				 [ClusterHDRId] = @ClusterHDRId
				,[VillageId] = @VillageId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddClusterHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddClusterHDR]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_AddClusterHDR] 
(
 @Id int
,@Code varchar(50)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ClusterHDRId INT OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].[ClusterHDR] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			    @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @ClusterHDRId = @@IDENTITY
				end
		ELSE
		begin
			UPDATE [dbo].[ClusterHDR]
			SET  
					[Code] = @Code
					,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @ClusterHDRId = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddComplaintRepository]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddComplaintRepository]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddComplaintRepository]
(@Id int,
@ComplaintCode varchar(60),
@LogBookNo varchar(255),
@ModuleTypeId int,
@FileName varchar (100),
@FileLocation varchar(250),
@FileExtension varchar(25),
@IsVideoRecording bit,
@IsResult bit,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@ServerUpdatedStatus bit
 
 )
as begin
 If isnull(@Id,0) = 0
 begin
 insert into ComplaintRepository(
ComplaintCode ,
LogBookNo,
ModuleTypeId,
FileName,
FileLocation,
FileExtension,
IsVideoRecording,
IsResult,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate,
ServerUpdatedStatus
 

)
values(
  @ComplaintCode ,
  @LogBookNo,
@ModuleTypeId,
@FileName,
@FileLocation,
@FileExtension,
@IsVideoRecording,
@IsResult,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate,
@ServerUpdatedStatus
 
)
  
end
else
begin
update ComplaintRepository Set   ComplaintCode=@ComplaintCode ,LogBookNo = @LogBookNo,ModuleTypeId=@ModuleTypeId,FileName=@FileName,FileLocation=@FileLocation,
FileExtension=@FileExtension,IsVideoRecording=@IsVideoRecording,IsResult=@IsResult,IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId,ServerUpdatedStatus=@ServerUpdatedStatus
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddComplaints]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddComplaints]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddComplaints]
(@Id int,
@Code varchar(60),
@LogBookNo varchar (255),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,
@ComplaintStatus int,
@ComplaintType int,
@solution varchar(255)
 )
as begin
 If isnull(@Id,0) = 0
 begin
 insert into Complaints(
Code ,
LogBookNo,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate,
ComplaintStatus,
ComplaintType,
solution

)
values(
  @Code ,
  @LogBookNo,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate,
@ComplaintStatus,
@ComplaintType,
@solution
)
  
end
else
begin
update Complaints Set Code=@Code, LogBookNo =@LogBookNo,ComplaintStatus=@ComplaintStatus,ComplaintType=@ComplaintType,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId,solution=@solution
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddComplaintStatusHistory]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddComplaintStatusHistory]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddComplaintStatusHistory]
(@Id int,
 @ComplaintCode varchar(60) ,
	@ComplaintTypeById int,
	@StatusTypeId int,
	@AssigntoUserId int  ,
	@Comments varchar(150) ,
	@IsActive bit ,
	@CreatedByUserId int ,
	@CreatedDate datetime,
	@UpdatedByUserId int,
	@UpdatedDate  datetime 
	
 )
as begin
 If isnull(@Id,0) = 0
 begin
 insert into ComplaintStatusHistory(
ComplaintCode ,
ComplaintTypeById,
StatusTypeId,
AssigntoUserId,
Comments,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

 

)
values(
  @ComplaintCode ,
@ComplaintTypeById,
@StatusTypeId,
@AssigntoUserId,
@Comments,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId

)
  
end
else
begin
update ComplaintStatusHistory Set ComplaintTypeById=@ComplaintTypeById,StatusTypeId=@StatusTypeId,
AssigntoUserId=@AssigntoUserId,Comments=@Comments,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddCrops]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCrops]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddCrops]
(@Id int = null,
@Code varchar(255),
@Name varchar(50),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime,

@Season varchar(10),

@CropOUT int OUTPUT
 
)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into Crop(
Code,
 Name,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate,
Season

)
values(
  @Code,
  @Name,
  @IsActive,
  @CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate,
  @Season


)
 set @CropOUT = @@IDENTITY
end
else
begin
update Crop Set Code=@Code,Name=@Name,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId,Season=@Season
where Id=@Id
 set @CropOUT = @Id
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddCropVariety]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddCropVariety]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddCropVariety] 
(
 @Id int
,@CropId int
,@Code varchar(255)
,@Name varchar(100)

,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@VarietyOut int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[CropVariety] (
				 [CropId]
				,[Code]
				,[Name]
				
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @CropId
				,@Code
				,@Name
				
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @VarietyOut = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[CropVariety]
			SET  [CropId] = @CropId
			,[Code] = @Code
				,[Name] = @Name
				
				
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @VarietyOut = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDistrict]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDistrict]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddDistrict] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@StateId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[District] (
				 [Code]
				,[Name]
				
				,[StateId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				
				,@StateId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[District]
			SET  [Code] = @Code
				,[Name] = @Name
				
				,[StateId] =@StateId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddDocument]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddDocument]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE   PROCEDURE [dbo].[SP_AddDocument] 
(
 @FarmerCode varchar(255)
,@PlotNo varchar(255)
,@IdentityCode varchar(Max)
,@DocUrl varchar(500)
,@DocType varchar(255)
,@DocExtension varchar(255)
,@DocOldNum varchar(255)
,@DocLocal varchar(max)
,@IsActive bit
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		  declare @cnt int
 if @FarmerCode != '' and @PlotNo = ''
begin
set @cnt =(select count(*) from Documents where FarmerCode=@FarmerCode and DocType=@DocType and IsActive=1)
end
else
begin  if @FarmerCode = '' and @PlotNo != ''
if @DocType = 'Water Regime'
begin
set @cnt =0
end
else
begin
set @cnt =(select count(*) from Documents where PlotNo=@PlotNo and DocType=@DocType and IsActive=1)
end
end
--else
--begin  if @FarmerCode = '' and @PlotNo != ''
--set @cnt =(select count(*) from Documents where PlotNo=@PlotNo and DocType=@DocType)
--end
if @cnt =0
begin
			INSERT INTO [dbo].[Documents] (
				 [FarmerCode]
				 ,[PlotNo]
				 ,IdentityCode
				,[DocUrl]
				,[DocType]
				,[DocExtension]
				,[DocOldNum]
				,DocLocal
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@PlotNo
				,@IdentityCode
				,@DocUrl
				,@DocType
				,@DocExtension
				,@DocOldNum 
				,@DocLocal
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
	end
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


 
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE   PROCEDURE [dbo].[SP_AddFarmer] 
(
 @FarmerCode varchar(255)
,@FarmerTitle varchar(255)
,@FirstName varchar(255)
,@MiddleName varchar(255)
,@LastName varchar(255)
,@FatherName varchar(255)
,@Gender varchar(50)
,@Age int
,@PrimaryContactNum varchar(255)
,@SecondaryContactNum varchar(255)
,@Address varchar(255)
,@DistrictId int
,@MandalId int
,@StateId int
,@VillageId int
,@PinCode varchar(255)
,@Sync bit
,@IsPlot varchar(255)
,@TotalPlotArea float
,@PlotsCount int
,@LocalImage varchar(max)
,@IsActive bit
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN

			INSERT INTO [dbo].[Farmer] (
				 [FarmerCode]
				 ,[FarmerTitle]
				,[FirstName]
				,[MiddleName]
				,[LastName]
				,[FatherName]
				,[Gender]
				,[Age]
				,[PrimaryContactNum]
				,[SecondaryContactNum]
				,[Address]
				,DistrictId
				,MandalId
				,[StateId]
				,[VillageId]
				,[PinCode]
				,[Sync]
				,IsPlot
				,TotalPlotArea
				,PlotsCount
				,LocalImage
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@FarmerTitle
				,@FirstName
				,@MiddleName
				,@LastName
				,@FatherName
				,@Gender
				,@Age
				,@PrimaryContactNum
				,@SecondaryContactNum
				,@Address
				,@DistrictId
				,@MandalId
				,@StateId
				,@VillageId
				,@PinCode
				,@Sync
				,@IsPlot
				,@TotalPlotArea
				,@PlotsCount
				,@LocalImage
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
	
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmerBank]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmerBank]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE   PROCEDURE [dbo].[SP_AddFarmerBank] 
(
 @FarmerCode varchar(255)
,@IdentityCode varchar(255)
,@AccountHolderName varchar(255)
,@AccountNumber varchar(255)
,@BranchName varchar(255)
,@IFSCCode varchar(255)
,@LocalDocUrl varchar(max)
,@IsActive bit
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN

			INSERT INTO [dbo].[FarmerBank] (
				 [FarmerCode]
				 ,IdentityCode
				,AccountHolderName
				,AccountNumber
				,BranchName
				,IFSCCode
				,LocalDocUrl
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@IdentityCode
				,@AccountHolderName
				,@AccountNumber
				,@BranchName
				,@IFSCCode
				,@LocalDocUrl
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
	
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddFarmerConsent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFarmerConsent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE   PROCEDURE [dbo].[SP_AddFarmerConsent] 
(
 @FarmerCode varchar(255)
,@Name varchar(255)
,@AgreementDate date
,@DigitalSign varchar(255)
,@1_1_a bit
,@1_1_b bit
,@1_1_c bit
,@1_1_d bit
,@1_1_e bit
,@1_2_a bit
,@1_2_b bit
,@1_2_c bit
,@1_2_d bit
,@AgentId int
,@VoluntaryId int
,@Base64 varchar(max)
,@IsActive bit
,@CreatedDate datetime
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		    declare @cnt int
			set @cnt = (select count(*) from FarmerConsent where FarmerCode = @FarmerCode and IsActive = 1)
			IF @cnt = 0
			begin
			INSERT INTO [dbo].[FarmerConsent] (
				  [FarmerCode]
      ,[Name]
      ,[AgreementDate]
      ,[DigitalSign]
      ,[1_1_a]
      ,[1_1_b]
      ,[1_1_c]
      ,[1_1_d]
	  ,[1_1_e]
      ,[1_2_a]
      ,[1_2_b]
      ,[1_2_c]
      ,[1_2_d]
	   ,[AgentId]
      ,[VoluntaryId]
	  ,[Base64]
      ,[IsActive]
      ,[CreatedDate]
      ,[UpdatedDate]
				)
			VALUES (
				@FarmerCode
				,@Name
				,@AgreementDate
				,@DigitalSign
				,@1_1_a
				,@1_1_b
				,@1_1_c
				,@1_1_d
				,@1_1_e
				,@1_2_a
				,@1_2_b
				,@1_2_c
				,@1_2_d
				,@AgentId
				,@VoluntaryId
				,@Base64
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,ISNULL(@UpdatedDate, GETDATE())
				)
			end
			else
			begin
			 update FarmerConsent set 
			   Name = @Name 
			   ,AgreementDate = @AgreementDate
			   ,DigitalSign = @DigitalSign
			   ,[1_1_a] = @1_1_a
			   ,[1_1_b] = @1_1_b
			   ,[1_1_c] = @1_1_c
			   ,[1_1_d] = @1_1_d
			   ,[1_1_e] = @1_1_e
			   ,[1_2_a] = @1_2_a
			   ,[1_2_b] = @1_2_b
			   ,[1_2_c] = @1_2_c
			   ,[1_2_d] = @1_2_d
			   ,AgentId = @AgentId
			   ,VoluntaryId = @VoluntaryId
			   ,[Base64] = @Base64
 			 where FarmerCode = @FarmerCode
			end
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_Addfarmerdocumnet]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Addfarmerdocumnet]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_Addfarmerdocumnet]
(@Id int,
@FarmerCode [varchar](255) NULL,
@PlotNo [varchar](255) NULL,
@IdentityCode [varchar](255) NULL,
@DocUrl [varchar](500) NULL,
@DocType [varchar](255) NULL,
@DocExtension [varchar](255) NULL,
@DocOldNum [varchar](255) NULL,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
 )
as begin
 If isnull(@Id,0) = 0
 begin
 insert into Documents(
FarmerCode ,
PlotNo,
IdentityCode,
DocUrl,
DocType,
DocExtension,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate
)
values(
@FarmerCode,
@PlotNo,
@IdentityCode,
@DocUrl,
@DocType,
@DocExtension,
@IsActive,
@CreatedByUserId,
@CreatedDate,
@UpdatedByUserId,
@UpdatedDate
)
  
end
else
begin
update Documents Set FarmerCode=@FarmerCode,IdentityCode=@IdentityCode,DocUrl=@DocUrl,
DocType=@DocType,DocExtension=@DocExtension,IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId 
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddFertilizer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddFertilizer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddFertilizer]
(@ID int,
@LogBookNo varchar(255),
@Fertilizer int,
@FertilizerType int,
@Date date,
@Qty decimal(18,2),
@UOM int,
@CropProtection varchar(255),
@SQNo varchar(15),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin

/*declare @LogId int
  set @LogId= (select count(*) from Fertilizer  where LogBookNo=@LogBookNo)*/
 If isnull(@Id,0) = 0
 begin
 insert into Fertilizer(
  LogBookNo,
  Fertilizer,
  FertilizerType,
  Date,
  Qty,
  UOM,
  CropProtection,
  SQNo,
  IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
)
values(
@LogBookNo,
 @Fertilizer,
  @FertilizerType,
  @Date,
  @Qty,
  @UOM,
  @CropProtection,
  @SQNo,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
  
end
else
begin
update Fertilizer Set LogBookNo=@LogBookNo,Fertilizer=@Fertilizer,FertilizerType=@FertilizerType,
Date=@Date,Qty=@Qty,UOM=@UOM,CropProtection=@CropProtection,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where LogBookNo=@LogBookNo
  
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGeoBoundaries]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE   PROCEDURE [dbo].[SP_AddGeoBoundaries] 
(
 @PlotNo varchar(255)
,@Latitude varchar(255)
,@Longitude varchar(255)
,@GeoCategoryTypeId int
,@SeqNo Int
,@Sync bit
,@IsActive bit
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		
		BEGIN

			INSERT INTO [dbo].[GeoBoundaries] (
				 [PlotNo]
				,[Latitude]
				,[Longitude]
				,GeoCategoryTypeId
				,SeqNo
				,[Sync]
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @PlotNo
				,@Latitude
				,@Longitude
				,@GeoCategoryTypeId
				,@SeqNo
				,@Sync
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
		END
		
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddGHGEmission]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddGHGEmission]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddGHGEmission]
(@Id int = null,
@Date  datetime,
@PlotAreaLatitude varchar(50),
@PlotAreaLongitude varchar(50),
@SoilTemperature Float,
@SoilMoisture decimal(18, 3),
@LogBookNo varchar(50),
@S1C1 decimal(18, 3) ,
@S1C2 decimal(18, 3) ,
@S1C3 decimal(18, 3) ,
@S2C1 decimal(18, 3) ,
@S2C2 decimal(18, 3) ,
@S2C3 decimal(18, 3) ,
@S3C1 decimal(18, 3) ,
@S3C2 decimal(18, 3) ,
@S3C3 decimal(18, 3) ,
@S1TimeStamp datetime,
@S2TimeStamp datetime,
@S3TimeStamp datetime,
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime
)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into GHGEmissionCollection(
Date,
PlotAreaLatitude,
PlotAreaLongitude,
SoilTemperature,
SoilMoisture,
LogBookNo,
S1C1,
S1C2,
S1C3,
S2C1,
S2C2,
S2C3,
S3C1,
S3C2,
S3C3,
S1TimeStamp,
S2TimeStamp,
S3TimeStamp,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate

)
values(
  @Date,
@PlotAreaLatitude,
@PlotAreaLongitude,
@SoilTemperature,
@SoilMoisture,
@LogBookNo,
@S1C1,
@S1C2,
@S1C3,
@S2C1,
@S2C2,
@S2C3,
@S3C1,
@S3C2,
@S3C3,
@S1TimeStamp,
@S2TimeStamp,
@S3TimeStamp,
@IsActive,
@CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate
 )
 
end
else
begin
update GHGEmissionCollection Set Date = @Date,
PlotAreaLatitude=@PlotAreaLatitude,
PlotAreaLongitude=@PlotAreaLongitude,
SoilTemperature=@SoilTemperature,
SoilMoisture=@SoilMoisture,
LogBookNo=@LogBookNo,
S1C1=@S1C1,
S1C2=@S1C2,
S1C3=@S1C3,
S2C1=@S2C1,
S2C2=@S2C2,
S2C3=@S2C3,
S3C1=@S3C1,
S3C2=@S3C2,
S3C3=@S3C3,
S1TimeStamp = @S1TimeStamp,S2TimeStamp = @S2TimeStamp,S3TimeStamp = @S3TimeStamp,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id

end 
end
 

 
GO

-- %% [markdown]
-- # [dbo].[SP_AddHarvestDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddHarvestDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddHarvestDetails]
(@ID int,
@LogBookNo varchar(255),
@Date date,
@YeildQty int,
@SQNo varchar(15),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
/*declare @LogId int
  set @LogId= (select count(*) from HarvestDetails  where LogBookNo=@LogBookNo)*/
 If isnull(@Id,0) = 0
 begin
 insert into HarvestDetails(
LogBookNo,
Date,
YeildQty,
SQNo,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

)
values(
  @LogBookNo,
  @Date,
  @YeildQty,
  @SQNo,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
 
end
else
begin
update HarvestDetails Set LogBookNo=@LogBookNo,Date=@Date,YeildQty=@YeildQty,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where LogBookNo=@LogBookNo
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddLand]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLand]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE   PROCEDURE [dbo].[SP_AddLand] 
(
@PlotNo varchar(255)
,@Size varchar(255)
,@CropId int
,@FarmerCode varchar(255)
,@Latitude varchar(255)
,@Longitude varchar(255)
,@Address varchar(255)
,@Plotownership varchar(255)
,@Cluster varchar(255)
,@LandMark varchar(255)
,@DistrictId int
,@MandalId int
,@VillageId int
,@StateId int
,@PinCode varchar(255)
,@SurveyNo varchar(100)
,@PattadarBookNo varchar(100)
,@GPS varchar(100)
,@GPSPlotArea decimal(18,6)
,@Sync bit
,@LandImage varchar(max)
,@IsActive bit
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		
		BEGIN


		IF LEN(ISNULL(@GPSPlotArea, '')) = 0
     	Begin
			set @GPSPlotArea = 0
		end
    declare @cnt INT
    set @cnt = (select count(1) from land where FarmerCode = @FarmerCode and [PlotNo] = @PlotNo and IsActive =1 )
		IF @cnt=0
			INSERT INTO [dbo].[Land] (
				 [PlotNo]
				,[Size]
				,[CropId]
				,[FarmerCode]
				,[Latitude]
				,[Longitude]
				,[Address]
				,[Plotownership]
				,[Cluster]
				,[LandMark]
				,LandImage
				,[IsActive]
				,[DistrictId]
				,[MandalId]
				,[VillageId]
				,[StateId]
				,[PinCode]
				,[SurveyNo]
				,[PattadarBookNo]
				,[Sync]
				,[GPS]
				,[GPSPlotArea]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @PlotNo
				,@Size
				,@CropId
				,@FarmerCode
				,@Latitude
				,@Longitude
				,@Address
				,@Plotownership
				,@Cluster
				,@LandMark
				,@LandImage
				,ISNULL(@IsActive, 1)
				,@DistrictId
				,@MandalId
				,@VillageId
				,@StateId
				,@PinCode
				,@SurveyNo
				,@PattadarBookNo
				,@Sync
				,@GPS
				,@GPSPlotArea
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
            ELSE
                UPDATE [dbo].[Land] 
                SET
                [Latitude] = @Latitude
                ,[Longitude] = @Longitude
                ,LandImage = @LandImage
                ,GPSPlotArea = @GPSPlotArea
                ,UpdatedByUserId = @UpdatedByUserId
                ,UpdatedDate = ISNULL(@UpdatedDate, GETDATE())
                where FarmerCode = @FarmerCode and PlotNo = @PlotNo
		END
		
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLogBook]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLogBook]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddLogBook]
(@Id Int ,
@LogBookNo varchar(50),
@PlotNo varchar(50),
@Season Int,
@DateOfSowing datetime,
@DateOfTransplanting datetime,
@Crop Int,
@CropVariety Int,
@SeedVariety Int,
@SeedDistributor Int,
@CultivationPractice int,
@IsActive bit,
@AgentId int,
@VoluntaryId int,
@IsProgressive bit,
@isClosed bit,
@FarmerCode varchar(255),
@CurrYear int,
@PreviousYeild decimal(18,6),
@PrevSeason int,
@PrevCropVariety int,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as begin
  
  BEGIN TRANSACTION
	BEGIN TRY
		BEGIN

  declare @cnt int
  set @cnt = (select count(*) from LogBook where FarmerCode = @FarmerCode and Season=@Season and CurrYear=@CurrYear
  and IsActive=1)

 If @cnt = 0
 begin
 insert into LogBook(
  LogBookNo,
  PlotNo,
  Season,
  DateOfSowing,
  DateOfTransplanting,
  Crop,
  CropVariety,
  SeedVariety,
  SeedDistributor,
  CultivationPractice,
  IsActive,
  AgentId,
  VoluntaryId,
  IsProgressive,
  isClosed,
  FarmerCode,
  CurrYear,
  PreviousYeild,
  PrevSeason,
  PrevCropVariety,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
)
values(
@LogBookNo,
@PlotNo,
@Season,
ISNULL(@DateOfSowing, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
ISNULL(@DateOfTransplanting, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
@Crop,
@CropVariety,
@SeedVariety,
@SeedDistributor,
@CultivationPractice,
@IsActive,
@AgentId,
@VoluntaryId,
@IsProgressive,
0,
@FarmerCode,
@CurrYear,
@PreviousYeild,
@PrevSeason,
@PrevCropVariety,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
end
else
begin
update LogBook Set 
DateOfSowing=@DateOfSowing,DateOfTransplanting=@DateOfTransplanting,
Crop=@Crop,CropVariety=@CropVariety,SeedVariety=@SeedVariety,
CultivationPractice=@CultivationPractice,SeedDistributor=@SeedDistributor,
IsActive=@IsActive,PreviousYeild = @PreviousYeild,PrevSeason=@PrevSeason,
PrevCropVariety =@PrevCropVariety,
UpdatedDate=@UpdatedDate,
UpdatedByUserId=@UpdatedByUserId,AgentId = @AgentId,VoluntaryId = @VoluntaryId
where FarmerCode=@FarmerCode and Season=@Season and CurrYear = @CurrYear
end
END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddLogBook_Season]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLogBook_Season]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE Procedure [dbo].[SP_AddLogBook_Season]
(
@Id Int ,
@LogBookNo varchar(255),
@FarmerCode varchar(255),
@PlotNo varchar(255),
@CurrYear int,
@CropId Int,
@SeasonId Int,
@CropVarietyId int,
@CultivationPractiseId int,
@PreviousYeildWithoutAWD decimal(18,3),
@YieldInCurrentSeason decimal(18,3),
@DateOfSowing datetime,
@DateOfTransplanting datetime,
@DateOfPipeInstallation datetime,
@DateOfFirstDrying datetime,
@DateOfSecondDrying datetime,
@DateOfHarvest datetime,
@UREAQty_1 decimal(18,3),
@DAPQty_1 decimal(18,3),
@PotashQty_1 decimal(18,3),
@OtherFertilizerQty_1 decimal(18,3),
@UREAQty_2 decimal(18,3),
@DAPQty_2 decimal(18,3),
@PotashQty_2 decimal(18,3),
@OtherFertilizerQty_2 decimal(18,3),
@UREAQty_3 decimal(18,3),
@DAPQty_3 decimal(18,3),
@PotashQty_3 decimal(18,3),
@OtherFertilizerQty_3 decimal(18,3),
@IsClosed bit,
@IsProgressive bit,
@AgentId int,
@VoluntaryId int,
@DataEntryUserId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 ,@ErrorNumber INT OUTPUT
 ,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as begin

BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
  
  declare @cnt int
  set @cnt = (select count(*) from LogBook_Season where LogBookNo = @LogBookNo and IsActive=1)

 If @cnt = 0
 begin
 insert into LogBook_Season(
       [LogBookNo]
      ,[FarmerCode]
      ,[PlotNo]
      ,[CurrYear]
      ,[CropId]
      ,[SeasonId]
	  ,[CropVarietyId]
      ,[CultivationPractiseId]
      ,[PreviousYeildWithoutAWD]
      ,[YieldInCurrentSeason]
      ,[DateOfSowing]
      ,[DateOfTransplanting]
      ,[DateOfPipeInstallation]
      ,[DateOfFirstDrying]
      ,[DateOfSecondDrying]
      ,[DateOfHarvest]
	  ,[UREAQty_1]
	  ,[DAPQty_1]
	  ,[PotashQty_1]
	  ,[OtherFertilizerQty_1]
	  ,[UREAQty_2]
	  ,[DAPQty_2]
	  ,[PotashQty_2]
	  ,[OtherFertilizerQty_2]
	  ,[UREAQty_3]
	  ,[DAPQty_3]
	  ,[PotashQty_3]
	  ,[OtherFertilizerQty_3]
      ,[IsClosed]
      ,[IsProgressive]
      ,[AgentId]
      ,[VoluntaryId]
      ,[DataEntryUserId]
      ,[IsActive]
      ,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId]
)
values(
 @LogBookNo,
 @FarmerCode,
 @PlotNo,
 @CurrYear,
 @CropId,
 @SeasonId,
 @CropVarietyId,
 @CultivationPractiseId,
 @PreviousYeildWithoutAWD,
 @YieldInCurrentSeason,
 ISNULL(@DateOfSowing, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
 case when @DateOfTransplanting is not null 
 then @DateOfTransplanting AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' else null end,
 case when @DateOfPipeInstallation is not null 
 then @DateOfPipeInstallation AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' else null end,
 case when @DateOfFirstDrying is not null 
 then @DateOfFirstDrying AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' else null end,
 case when @DateOfSecondDrying is not null 
 then @DateOfSecondDrying AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' else null end,
 case when @DateOfHarvest is not null 
 then @DateOfHarvest AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' else null end,
 @UREAQty_1,
 @DAPQty_1,
 @PotashQty_1,
 @OtherFertilizerQty_1,
  @UREAQty_2,
 @DAPQty_2,
 @PotashQty_2,
 @OtherFertilizerQty_2,
  @UREAQty_3,
 @DAPQty_3,
 @PotashQty_3,
 @OtherFertilizerQty_3,
 @IsClosed,
 @IsProgressive,
 @AgentId,
 @VoluntaryId,
 @DataEntryUserId,
 ISNULL(@IsActive, 1),
 ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
 @CreatedByUserId,
 ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
 @UpdatedByUserId
)
 end
 else
 begin
   update LogBook_Season 
    set CropVarietyId = @CropVarietyId
	,DateOfSowing = ISNULL(@DateOfSowing, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,DateOfTransplanting = ISNULL(@DateOfTransplanting, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	,UREAQty_1 = @UREAQty_1
	,DAPQty_1 = @DAPQty_1
	,PotashQty_1 = @PotashQty_1
	,OtherFertilizerQty_1 = @OtherFertilizerQty_1
	,UREAQty_2 = @UREAQty_2
	,DAPQty_2 = @DAPQty_2
	,PotashQty_2 = @PotashQty_2
	,OtherFertilizerQty_2 = @OtherFertilizerQty_2
	,UREAQty_3 = @UREAQty_3
	,DAPQty_3 = @DAPQty_3
	,PotashQty_3 = @PotashQty_3
	,OtherFertilizerQty_3 = @OtherFertilizerQty_3
   where LogBookNo = @LogBookNo
 end
 END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

end
GO

-- %% [markdown]
-- # [dbo].[SP_AddLogBookBeforeAWD]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLogBookBeforeAWD]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_AddLogBookBeforeAWD]
(
  @Id int,
  @FarmerCode varchar(255),
  @PlotNo varchar(255),
  @RabiCropVarietyId int,
  @KharifCropVarietyId int,
  @RabiYeild decimal(18,3),
  @KharifYeild decimal(18,3),

  @RabiFertilizerUREAQty_1 decimal(18,3),
  @RabiFertilizerDAPQty_1 decimal(18,3),
  @RabiFertilizerPotashQty_1 decimal(18,3), 
  @RabiFertilizerOtherQty_1 decimal(18,3),

  @KharifFertilizerUREAQty_1 decimal(18,3),
  @KharifFertilizerDAPQty_1 decimal(18,3),
  @KharifFertilizerPotashQty_1 decimal(18,3),
  @KharifFertilizerOtherQty_1 decimal(18,3),

  @RabiFertilizerUREAQty_2 decimal(18,3),
  @RabiFertilizerDAPQty_2  decimal(18,3),
  @RabiFertilizerPotashQty_2 decimal(18,3),
  @RabiFertilizerOtherQty_2 decimal(18,3),

  @KharifFertilizerUREAQty_2 decimal(18,3),
  @KharifFertilizerDAPQty_2 decimal(18,3),
  @KharifFertilizerPotashQty_2 decimal(18,3),
  @KharifFertilizerOtherQty_2 decimal(18,3),

  @RabiFertilizerUREAQty_3 decimal(18,3),
  @RabiFertilizerDAPQty_3 decimal(18,3),
  @RabiFertilizerPotashQty_3 decimal(18,3),
  @RabiFertilizerOtherQty_3 decimal(18,3),

  @KharifFertilizerUREAQty_3 decimal(18,3),
  @KharifFertilizerDAPQty_3 decimal(18,3),
  @KharifFertilizerPotashQty_3 decimal(18,3),
  @KharifFertilizerOtherQty_3 decimal(18,3),
  @AgentId int,
  @VoluntaryId int,
  @DataEntryUserId int,
  @IsActive bit,
  @CreatedDate datetime,
  @CreatedByUserId int,
  @UpdatedDate datetime,
  @UpdatedByUserId int
 ,@ErrorNumber INT OUTPUT
 ,@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
	BEGIN TRY
		BEGIN

		 declare @cnt int
  set @cnt = (select count(*) from LogBookBeforeAWD where FarmerCode = @FarmerCode and IsActive=1)
   If @cnt = 0
 begin
     insert into LogBookBeforeAWD(
	  [FarmerCode]
      ,[PlotNo]
      ,[RabiCropVarietyId]
      ,[KharifCropVarietyId]
      ,[RabiYeild]
      ,[KharifYeild]
      ,[RabiFertilizerUREAQty_1]
      ,[RabiFertilizerDAPQty_1]
      ,[RabiFertilizerPotashQty_1]
      ,[RabiFertilizerOtherQty_1]

      ,[KharifFertilizerUREAQty_1]
      ,[KharifFertilizerDAPQty_1]
      ,[KharifFertilizerPotashQty_1]
      ,[KharifFertilizerOtherQty_1]

      ,[RabiFertilizerUREAQty_2]
      ,[RabiFertilizerDAPQty_2]
      ,[RabiFertilizerPotashQty_2]
      ,[RabiFertilizerOtherQty_2]

      ,[KharifFertilizerUREAQty_2]
      ,[KharifFertilizerDAPQty_2]
      ,[KharifFertilizerPotashQty_2]
      ,[KharifFertilizerOtherQty_2]

      ,[RabiFertilizerUREAQty_3]
      ,[RabiFertilizerDAPQty_3]
      ,[RabiFertilizerPotashQty_3]
      ,[RabiFertilizerOtherQty_3]

      ,[KharifFertilizerUREAQty_3]
      ,[KharifFertilizerDAPQty_3]
      ,[KharifFertilizerPotashQty_3]
      ,[KharifFertilizerOtherQty_3]
      ,[AgentId]
      ,[VoluntaryId]
      ,[DataEntryUserId]
      ,[IsActive]
      ,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId])
	 values(
	  @FarmerCode
	  ,@PlotNo
	  ,@RabiCropVarietyId
	  ,@KharifCropVarietyId
	  ,@RabiYeild
	  ,@KharifYeild
	   ,@RabiFertilizerUREAQty_1
  ,@RabiFertilizerDAPQty_1
  ,@RabiFertilizerPotashQty_1
  ,@RabiFertilizerOtherQty_1

  ,@KharifFertilizerUREAQty_1
  ,@KharifFertilizerDAPQty_1
  ,@KharifFertilizerPotashQty_1
  ,@KharifFertilizerOtherQty_1

  ,@RabiFertilizerUREAQty_2
  ,@RabiFertilizerDAPQty_2
  ,@RabiFertilizerPotashQty_2
  ,@RabiFertilizerOtherQty_2

  ,@KharifFertilizerUREAQty_2
  ,@KharifFertilizerDAPQty_2
  ,@KharifFertilizerPotashQty_2
  ,@KharifFertilizerOtherQty_2

  ,@RabiFertilizerUREAQty_3
  ,@RabiFertilizerDAPQty_3
  ,@RabiFertilizerPotashQty_3
  ,@RabiFertilizerOtherQty_3

  ,@KharifFertilizerUREAQty_3
  ,@KharifFertilizerDAPQty_3
  ,@KharifFertilizerPotashQty_3
  ,@KharifFertilizerOtherQty_3
  ,@AgentId
  ,@VoluntaryId
  ,@DataEntryUserId
   ,ISNULL(@IsActive, 1),
 ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
 @CreatedByUserId,
 ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
 @UpdatedByUserId
	 )
end
	 else
	 begin
	    update LogBookBeforeAWD
		set RabiCropVarietyId =@RabiCropVarietyId
		,KharifCropVarietyId = @KharifCropVarietyId
		,RabiYeild = @RabiYeild
		,KharifYeild = @KharifYeild
		,RabiFertilizerUREAQty_1 = @RabiFertilizerUREAQty_1
		,RabiFertilizerDAPQty_1 = @RabiFertilizerDAPQty_1
		,RabiFertilizerPotashQty_1 =@RabiFertilizerPotashQty_1
		,RabiFertilizerOtherQty_1 = @RabiFertilizerOtherQty_1
		,KharifFertilizerUREAQty_1 = @KharifFertilizerUREAQty_1
		,KharifFertilizerDAPQty_1 = @KharifFertilizerDAPQty_1
		,KharifFertilizerPotashQty_1 = @KharifFertilizerPotashQty_1
		,KharifFertilizerOtherQty_1 = @KharifFertilizerOtherQty_1

		 ,RabiFertilizerUREAQty_2 = @RabiFertilizerUREAQty_2
          ,RabiFertilizerDAPQty_2 = @RabiFertilizerDAPQty_2
          ,RabiFertilizerPotashQty_2 =@RabiFertilizerPotashQty_2
          ,RabiFertilizerOtherQty_2 = @RabiFertilizerOtherQty_2
          ,KharifFertilizerUREAQty_2 = @KharifFertilizerUREAQty_2
          ,KharifFertilizerDAPQty_2 = @KharifFertilizerDAPQty_2
          ,KharifFertilizerPotashQty_2 = @KharifFertilizerPotashQty_2
          ,KharifFertilizerOtherQty_2 = @KharifFertilizerOtherQty_2

		   ,RabiFertilizerUREAQty_3 = @RabiFertilizerUREAQty_3
          ,RabiFertilizerDAPQty_3 = @RabiFertilizerDAPQty_3
          ,RabiFertilizerPotashQty_3 =@RabiFertilizerPotashQty_3
          ,RabiFertilizerOtherQty_3 = @RabiFertilizerOtherQty_3
          ,KharifFertilizerUREAQty_3 = @KharifFertilizerUREAQty_3
          ,KharifFertilizerDAPQty_3 = @KharifFertilizerDAPQty_3
          ,KharifFertilizerPotashQty_3 = @KharifFertilizerPotashQty_3
          ,KharifFertilizerOtherQty_3 = @KharifFertilizerOtherQty_3

		where FarmerCode = @FarmerCode
	 end
	 END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupDtl]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO







CREATE PROCEDURE [dbo].[SP_AddLookupDtl] 
(
 @Id int
,@LookupHdrId int
,@Code varchar(255)
,@Name varchar(100)
,@Remarks varchar(100)
,@Ord int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookupdtlOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupDtl] (
				 [LookupHdrId]
				,[Code]
				,[Name]
				,[Remarks]
				,[Ord]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @LookupHdrId
				,@Code
				,@Name
				,@Remarks
				,@Ord
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookupdtlOUT = @@IDENTITY

				--update [dbo].[LookupDtl] set Code='0'+cast(@lookupdtlOUT as varchar(max)) where Id =@lookupdtlOUT
				END
		ELSE
			UPDATE [dbo].[LookupDtl]
			SET  [LookupHdrId] = @LookupHdrId
			,[Code] = @Code
				,[Name] = @Name
				,[Remarks] = @Remarks
				,[Ord] = @Ord
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookupdtlOUT = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddLookupHdr]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO








CREATE PROCEDURE [dbo].[SP_AddLookupHdr] 
(
 @Id int,
 @Code Varchar(255)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@lookuphdrOUT int OUTPUT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		BEGIN
			INSERT INTO [dbo].[LookupHdr] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				set @lookuphdrOUT = @@IDENTITY

			--update [dbo].[LookupHdr] set Code='0'+cast(@lookuphdrOUT as varchar(max)) where Id =@lookuphdrOUT
				END
		ELSE
		begin
			UPDATE [dbo].[LookupHdr]
			SET  Code=@Code,
				[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
			set @lookuphdrOUT = @Id
			end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddMandal]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMandal]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddMandal] 
(
 @Id int = NULL
,@Code varchar(6)
,@Name varchar(100)
,@DistrictId int 
,@IsActive bit 
,@CreatedDate datetime 
,@CreatedByUserId int 
,@UpdatedDate datetime 
,@UpdatedByUserId int 
,@ErrorNumber INT OUTPUT 
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Mandal] (
				 [Code]
				,[Name]
				,[DistrictId]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,@DistrictId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Mandal]
			SET  [Code] = @Code
				,[Name] = @Name
				,[DistrictId] = @DistrictId
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddManualData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManualData]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_AddManualData]
(
 @FarmerCode varchar(500),
 @PlotNo varchar(500),
 @FarmerTitle varchar(10),
 @FirstName varchar(255),
 @LastName varchar(255),
 @FatherName varchar(255),
 @Gender varchar(10),
 @Age int,
 @MobileNo varchar(10),
 @Address varchar(500),
 @StateId int,
 @DistrictId int,
 @MandalId int,
 @VillageId int,
 @PinCode varchar(10),
 @TotalPlotArea float,
 @AccountNumber varchar(255),
 @IFSCCode varchar(250),
 @PattadarBookNo varchar(255),
 @SurveyNo varchar(100),
 @AadhaarNo varchar(255),
 @AgreementDate datetime,
 @one_1_a bit,
 @one_1_b bit,
 @one_1_c bit,
 @one_1_d bit,
 @one_1_e bit,
 @one_2_a bit,
 @one_2_b bit,
 @one_2_c bit,
 @IsActive bit,
 @CreatedByUserId int,
 @CreatedDate datetime,
 @UpdatedByUserId int,
 @UpdatedDate datetime,
 @DataEntryUserId int,
 @ErrorNumber INT OUTPUT,
 @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN 
              DECLARE @CheckFarmerCodeInFarmerTable INT
			  SET @CheckFarmerCodeInFarmerTable = (select count(FarmerCode) from Farmer where IsActive = 1 and FarmerCode = @FarmerCode and CreatedByUserId = @CreatedByUserId)

			  DECLARE @CheckFarmerCodeInFarmerBankTable INT
			  SET @CheckFarmerCodeInFarmerBankTable = (select count(FarmerCode) from FarmerBank where IsActive = 1 and FarmerCode = @FarmerCode and CreatedByUserId = @CreatedByUserId)

			  DECLARE @CheckFarmerCodeInFarmerConsentTable INT
			  SET @CheckFarmerCodeInFarmerConsentTable = (select count(FarmerCode) from FarmerConsent where IsActive = 1 and FarmerCode = @FarmerCode and AgentId = @CreatedByUserId)

			  DECLARE @CheckFarmerCodeInPlotTable INT
			  SET @CheckFarmerCodeInPlotTable = (select count(PlotNo) from Land where IsActive = 1 and PlotNo = @PlotNo and CreatedByUserId = @CreatedByUserId)

			  

			  --- INSERT data to FARMER Table ----
			 IF @CheckFarmerCodeInFarmerTable = 0
			 BEGIN
			     INSERT INTO [dbo].[Farmer](
				 [FarmerCode]
				,[FarmerTitle]
				,[FirstName]
				,[LastName]
				,[FatherName]
				,[Gender]
				,[Age]
				,[PrimaryContactNum]
				,[Address]
				,[DistrictId]
				,[MandalId]
				,[StateId]
				,[VillageId]
				,[PinCode]
				,[Sync]
				,IsPlot
				,TotalPlotArea
				,PlotsCount
				,[IdentityCode]
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				,[AgentId]
				)
			VALUES (
				 @FarmerCode
				,@FarmerTitle
				,@FirstName
				,@LastName
				,@FatherName
				,@Gender
				,@Age
				,@MobileNo
				,@Address
				,@DistrictId
				,@MandalId
				,@StateId
				,@VillageId
				,@PinCode
				,1
				,1
				,@TotalPlotArea
				,1
				,@AadhaarNo
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId 
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@CreatedByUserId
				)
			 END 
			 -- UPDATE data to FARMER Table
 			 ELSE IF @CheckFarmerCodeInFarmerTable != 0
			 BEGIN
			     UPDATE Farmer 
				 set FirstName = @FirstName,
				 LastName = @LastName,
				 FatherName = @FatherName,
				 Gender = @Gender,
				 Age = @Age,
				 PrimaryContactNum = @MobileNo,
				 Address = @Address,
				 StateId = @StateId,
				 DistrictId = @DistrictId,
				 MandalId = @MandalId,
				 VillageId = @VillageId,
				 TotalPlotArea = @TotalPlotArea,
				 IdentityCode = @AadhaarNo,
				 IsActive = @IsActive,
				 UpdatedByUserId = @UpdatedByUserId,
				 UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				 where FarmerCode = @FarmerCode

			 END



			 --- INSERT data to FARMERBANK Table ---
			 IF @CheckFarmerCodeInFarmerBankTable = 0
			 BEGIN
			 INSERT INTO [FarmerBank] (
				 [FarmerCode]
				,AccountHolderName
				,AccountNumber
				,IFSCCode
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@FirstName + ' ' + @LastName
				,@AccountNumber
				,@IFSCCode
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				)
			 END
			 ELSE IF @CheckFarmerCodeInFarmerBankTable != 0
			 BEGIN
					UPDATE FarmerBank 
					set  AccountHolderName = @FirstName + ' '+@LastName,
					AccountNumber =  @AccountNumber,
					IFSCCode = @IFSCCode,
					IsActive = @IsActive,
					UpdatedByUserId = @UpdatedByUserId,
				    UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
					where FarmerCode = @FarmerCode
			 END


			 --- INSERT data to PLOT Table ---
			 IF @CheckFarmerCodeInPlotTable = 0
			 BEGIN
			 INSERT INTO [dbo].[Land] (
				 [PlotNo]
				,[Size]
				,[CropId]
				,[FarmerCode]
				,[Address]
				,[Plotownership]
				,[IsActive]
				,[DistrictId]
				,[MandalId]
				,[VillageId]
				,[StateId]
				,[PinCode]
				,[SurveyNo]
				,[PattadarBookNo]
				,[Sync]
				,[GPSPlotArea]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @PlotNo
				,@TotalPlotArea
				,2
				,@FarmerCode
				,@Address
				,'O'
				,ISNULL(@IsActive, 1)
				,@DistrictId
				,@MandalId
				,@VillageId
				,@StateId
				,@PinCode
				,@SurveyNo
				,@PattadarBookNo
				,1
				,0
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				)
			 END
			 ELSE IF @CheckFarmerCodeInPlotTable != 0
			 BEGIN
			    UPDATE [dbo].[Land] 
                SET
                [Size] = @TotalPlotArea,
                Address = @Address,
                DistrictId = @DistrictId,
				MandalId = @MandalId,
				VillageId = @VillageId,
				StateId = @StateId,
				PinCode = @PinCode,
				SurveyNo = @SurveyNo,
				PattadarBookNo = @PattadarBookNo,
                UpdatedByUserId = @UpdatedByUserId,
                UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
                where FarmerCode = @FarmerCode and PlotNo = @PlotNo
			 END


			 --- INSERT data to FARMERCONSENT Table ---
			 IF @CheckFarmerCodeInFarmerConsentTable = 0
			 BEGIN
			 INSERT INTO [dbo].[FarmerConsent] (
	   [FarmerCode]
      ,[Name]
      ,[AgreementDate]
      ,[1_1_a]
      ,[1_1_b]
      ,[1_1_c]
      ,[1_1_d]
	  ,[1_1_e]
      ,[1_2_a]
      ,[1_2_b]
      ,[1_2_c]
	  ,[AgentId]
      ,[IsActive]
      ,[CreatedDate]
      ,[UpdatedDate]
	  ,[DataEntryUserId]
				)
			VALUES (
				@FarmerCode
				,@FirstName +' ' + @LastName
				,isnull(@AgreementDate,Getdate()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@one_1_a
				,@one_1_b
				,@one_1_c
				,@one_1_d
				,@one_1_e
				,@one_2_a
				,@one_2_b
				,@one_2_c
				,@CreatedByUserId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@DataEntryUserId
				)
			 END
			 ELSE IF @CheckFarmerCodeInFarmerConsentTable !=0
			 BEGIN
			     UPDATE FarmerConsent
				 set Name = @FirstName +' ' + @LastName,
				 AgreementDate = @AgreementDate,
				 [1_1_a] = @one_1_a,
				 [1_1_b] = @one_1_b,
				 [1_1_c] = @one_1_c,
				 [1_1_d] = @one_1_d,
				 [1_1_e] = @one_1_e,
				 [1_2_a] = @one_2_a,
				 [1_2_b] = @one_2_b,
				 [1_2_c] = @one_2_c,
				 UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
				 DataEntryUserId = @DataEntryUserId
				 where FarmerCode = @FarmerCode
			 END

	    END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
	COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END






	
	
GO

-- %% [markdown]
-- # [dbo].[SP_AddManualData_Test]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddManualData_Test]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_AddManualData_Test]
(
 @FarmerCode varchar(500),
 @PlotNo varchar(500),
 @FarmerTitle varchar(10),
 @FirstName varchar(255),
 @LastName varchar(255),
 @FatherName varchar(255),
 @Gender varchar(10),
 @Age int,
 @MobileNo varchar(10),
 @Address varchar(500),
 @StateId int,
 @DistrictId int,
 @MandalId int,
 @VillageId int,
 @PinCode varchar(10),
 @TotalPlotArea float,
 @AccountNumber varchar(255),
 @IFSCCode varchar(250),
 @PattadarBookNo varchar(255),
 @SurveyNo varchar(100),
 @AadhaarNo varchar(255),
 @AgreementDate datetime,
 @one_1_a bit,
 @one_1_b bit,
 @one_1_c bit,
 @one_1_d bit,
 @one_1_e bit,
 @one_2_a bit,
 @one_2_b bit,
 @one_2_c bit,
 @IsActive bit,
 @CreatedByUserId int,
 @CreatedDate datetime,
 @UpdatedByUserId int,
 @UpdatedDate datetime,
 @DataEntryUserId int,
 @ErrorNumber INT OUTPUT,
 @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN 
              DECLARE @CheckFarmerCodeInFarmerTable INT
			  SET @CheckFarmerCodeInFarmerTable = (select count(FarmerCode) from Farmer where IsActive = 1 and FarmerCode = @FarmerCode and CreatedByUserId = @CreatedByUserId)

			  DECLARE @CheckFarmerCodeInFarmerBankTable INT
			  SET @CheckFarmerCodeInFarmerBankTable = (select count(FarmerCode) from FarmerBank where IsActive = 1 and FarmerCode = @FarmerCode and CreatedByUserId = @CreatedByUserId)

			  DECLARE @CheckFarmerCodeInFarmerConsentTable INT
			  SET @CheckFarmerCodeInFarmerConsentTable = (select count(FarmerCode) from FarmerConsent where IsActive = 1 and FarmerCode = @FarmerCode and AgentId = @CreatedByUserId)

			  DECLARE @CheckFarmerCodeInPlotTable INT
			  SET @CheckFarmerCodeInPlotTable = (select count(PlotNo) from Land where IsActive = 1 and PlotNo = @PlotNo and CreatedByUserId = @CreatedByUserId)

			  

			  --- INSERT data to FARMER Table ----
			 IF @CheckFarmerCodeInFarmerTable = 0
			 BEGIN
			     INSERT INTO [dbo].[Farmer](
				 [FarmerCode]
				,[FarmerTitle]
				,[FirstName]
				,[LastName]
				,[FatherName]
				,[Gender]
				,[Age]
				,[PrimaryContactNum]
				,[Address]
				,[DistrictId]
				,[MandalId]
				,[StateId]
				,[VillageId]
				,[PinCode]
				,[Sync]
				,IsPlot
				,TotalPlotArea
				,PlotsCount
				,[IdentityCode]
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@FarmerTitle
				,@FirstName
				,@LastName
				,@FatherName
				,@Gender
				,@Age
				,@MobileNo
				,@Address
				,@DistrictId
				,@MandalId
				,@StateId
				,@VillageId
				,@PinCode
				,1
				,1
				,@TotalPlotArea
				,1
				,@AadhaarNo
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId 
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				)
			 END 
			 -- UPDATE data to FARMER Table
 			 ELSE IF @CheckFarmerCodeInFarmerTable != 0
			 BEGIN
			     UPDATE Farmer 
				 set FirstName = @FirstName,
				 LastName = @LastName,
				 FatherName = @FatherName,
				 Gender = @Gender,
				 Age = @Age,
				 PrimaryContactNum = @MobileNo,
				 Address = @Address,
				 StateId = @StateId,
				 DistrictId = @DistrictId,
				 MandalId = @MandalId,
				 VillageId = @VillageId,
				 TotalPlotArea = @TotalPlotArea,
				 IdentityCode = @AadhaarNo,
				 IsActive = @IsActive,
				 UpdatedByUserId = @UpdatedByUserId,
				 UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				 where FarmerCode = @FarmerCode

			 END



			 --- INSERT data to FARMERBANK Table ---
			 IF @CheckFarmerCodeInFarmerBankTable = 0
			 BEGIN
			 INSERT INTO [FarmerBank] (
				 [FarmerCode]
				,AccountHolderName
				,AccountNumber
				,IFSCCode
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@FirstName + ' ' + @LastName
				,@AccountNumber
				,@IFSCCode
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				)
			 END
			 ELSE IF @CheckFarmerCodeInFarmerBankTable != 0
			 BEGIN
					UPDATE FarmerBank 
					set  AccountHolderName = @FirstName + ' '+@LastName,
					AccountNumber =  @AccountNumber,
					IFSCCode = @IFSCCode,
					IsActive = @IsActive,
					UpdatedByUserId = @UpdatedByUserId,
				    UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
					where FarmerCode = @FarmerCode
			 END


			 --- INSERT data to PLOT Table ---
			 IF @CheckFarmerCodeInPlotTable = 0
			 BEGIN
			 INSERT INTO [dbo].[Land] (
				 [PlotNo]
				,[Size]
				,[CropId]
				,[FarmerCode]
				,[Address]
				,[Plotownership]
				,[IsActive]
				,[DistrictId]
				,[MandalId]
				,[VillageId]
				,[StateId]
				,[PinCode]
				,[SurveyNo]
				,[PattadarBookNo]
				,[Sync]
				,[GPSPlotArea]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @PlotNo
				,@TotalPlotArea
				,2
				,@FarmerCode
				,@Address
				,'O'
				,ISNULL(@IsActive, 1)
				,@DistrictId
				,@MandalId
				,@VillageId
				,@StateId
				,@PinCode
				,@SurveyNo
				,@PattadarBookNo
				,1
				,0
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				)
			 END
			 ELSE IF @CheckFarmerCodeInPlotTable != 0
			 BEGIN
			    UPDATE [dbo].[Land] 
                SET
                [Size] = @TotalPlotArea,
                Address = @Address,
                DistrictId = @DistrictId,
				MandalId = @MandalId,
				VillageId = @VillageId,
				StateId = @StateId,
				PinCode = @PinCode,
				SurveyNo = @SurveyNo,
				PattadarBookNo = @PattadarBookNo,
                UpdatedByUserId = @UpdatedByUserId,
                UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
                where FarmerCode = @FarmerCode and PlotNo = @PlotNo
			 END


			 --- INSERT data to FARMERCONSENT Table ---
			 IF @CheckFarmerCodeInFarmerConsentTable = 0
			 BEGIN
			 INSERT INTO [dbo].[FarmerConsent] (
	   [FarmerCode]
      ,[Name]
      ,[AgreementDate]
      ,[1_1_a]
      ,[1_1_b]
      ,[1_1_c]
      ,[1_1_d]
	  ,[1_1_e]
      ,[1_2_a]
      ,[1_2_b]
      ,[1_2_c]
	  ,[AgentId]
      ,[IsActive]
      ,[CreatedDate]
      ,[UpdatedDate]
	  ,[DataEntryUserId]
				)
			VALUES (
				@FarmerCode
				,@FirstName +' ' + @LastName
				,isnull(@AgreementDate,Getdate()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@one_1_a
				,@one_1_b
				,@one_1_c
				,@one_1_d
				,@one_1_e
				,@one_2_a
				,@one_2_b
				,@one_2_c
				,@CreatedByUserId
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@DataEntryUserId
				)
			 END
			 ELSE IF @CheckFarmerCodeInFarmerConsentTable !=0
			 BEGIN
			     UPDATE FarmerConsent
				 set Name = @FirstName +' ' + @LastName,
				 AgreementDate = @AgreementDate,
				 [1_1_a] = @one_1_a,
				 [1_1_b] = @one_1_b,
				 [1_1_c] = @one_1_c,
				 [1_1_d] = @one_1_d,
				 [1_1_e] = @one_1_e,
				 [1_2_a] = @one_2_a,
				 [1_2_b] = @one_2_b,
				 [1_2_c] = @one_2_c,
				 UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
				 DataEntryUserId = @DataEntryUserId
				 where FarmerCode = @FarmerCode
			 END

	    END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
	COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END






	
	
GO

-- %% [markdown]
-- # [dbo].[SP_AddMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddMenu]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddMenu] 
(
 @Id int = NULL
,@Code varchar(50)
,@Name varchar(100)
,@MenuType varchar(1)
,@ParentMenuId int
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@Path varchar(1024)
,@Icon varchar(1024)
,@Order int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Menu] (
				 [Code]
				,[Name]
				,[MenuType]
				,[ParentMenuId]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				,[Path]
				,[Icon]
				,[Order]
				)
			VALUES (
				 @Code
				,@Name
				,@MenuType
				,@ParentMenuId
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				,@Path
				,@Icon
				,@Order
				)
		ELSE
			UPDATE [dbo].[Menu]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MenuType] = @MenuType
				,[ParentMenuId] = @ParentMenuId
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
				,[Path] = @Path
				,[Icon] = @Icon
				,[Order] = @Order
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddOrganicAmendments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddOrganicAmendments]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddOrganicAmendments]
(@ID int,
@LogBookNo varchar(255),
@Value int,
@Date date,
@SQNo varchar(15),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
/*declare @LogId int
  set @LogId= (select count(*) from  OrganicAmendments where LogBookNo=@LogBookNo) */
 If isnull(@Id,0) = 0
 begin
 insert into OrganicAmendments(
LogBookNo,
Value,
Date,
SQNo,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

)
values(
  @LogBookNo,
  @Value,
  @Date,
  @SQNo,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
 
end
else
begin
update OrganicAmendments Set LogBookNo=@LogBookNo,Value= @Value,Date=@Date,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where LogBookNo=@LogBookNo
 
end 
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddPipeInstallation]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddPipeInstallation]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create proc [dbo].[SP_AddPipeInstallation]
(
@FarmerCode varchar(255),
@CurrYear int,
@SeasonId int,
@DateOfPipeInstallation datetime,
@Latitude float,
@Longitude float,
@AgentId int,
@VoluntaryId int,
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int,
@ErrorNumber INT OUTPUT,
@ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		   
		    insert into PipeInstallation(
	   [FarmerCode]
      ,[CurrYear]
      ,[SeasonId]
      ,[DateOfPipeInstallation]
      ,[Latitude]
      ,[Longitude]
      ,[AgentId]
      ,[VoluntaryId]
      ,[IsActive]
      ,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId]
			)
			values(@FarmerCode
			,@CurrYear
			,@SeasonId
			,ISNULL(@DateOfPipeInstallation, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@Latitude
			,@Longitude
			,@AgentId
			,@VoluntaryId
			,ISNULL(@IsActive, 1)
			,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@CreatedByUserId
			,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			)
		END
		END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'

end
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoleMenu]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRoleMenu] 
(
 @Id int
,@RoleId int
,@MenuId int
,@AddYN bit
,@EditYN bit
,@DeleteYN bit
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[RoleMenu] (
				 [RoleId]
				,[MenuId]
				,[AddYN]
				,[EditYN]
				,[DeleteYN]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @RoleId
				,@MenuId
				,@AddYN
				,@EditYN
				,@DeleteYN
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[RoleMenu]
			SET  [RoleId] = @RoleId
				,[MenuId] = @MenuId
				,[AddYN] = @AddYN
				,[EditYN] = @EditYN
				,[DeleteYN] = @DeleteYN
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddRoles]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddRoles] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@ViewYN bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[Roles] (
				 [Code]
				,[Name]
				,[ViewYN]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@ViewYN, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[Roles]
			SET  [Code] = @Code
				,[Name] = @Name
				,[ViewYN] = ISNULL(@ViewYN, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSeason]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSeason]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





CREATE PROCEDURE [dbo].[SP_AddSeason] 
(
 @Id int
,@Name varchar(50)
,@PlantFrom datetime
,@PlantTo datetime
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].[Season] (
				 [Code]
				,[Name]
				,[PlantFrom]
				,[PlantTo]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 ''
				,@Name
				,@PlantFrom
				,@PlantTo
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
				declare @Out int
				Set @Out = @@IDENTITY
				UPDATE [dbo].[Season] set Code='0'+cast(@Out as varchar(max)) where Id=@Out
				end
		ELSE
			UPDATE [dbo].[Season]
			SET  
				[Name] = @Name
				,[PlantFrom] = @PlantFrom
				,[PlantTo] = @PlantTo
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddSeedDistributor]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSeedDistributor]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddSeedDistributor]
(@Id int = null,

@Name varchar(50),
@RegistrationNo varchar (50),
@Location varchar (255),
@Address varchar (4000),
@Pincode varchar (20),
@PhoneNo varchar (20),
@IsActive bit,
@CreatedByUserId int,
@CreatedDate datetime,
@UpdatedByUserId int,
@UpdatedDate datetime

 
)
as begin
 If isnull(@Id,0) = 0
 begin
 insert into SeedDistributor(

 Name,
 RegistrationNo,
 Location,
 Address,
 Pincode,
 PhoneNo,
IsActive,
CreatedByUserId,
CreatedDate,
UpdatedByUserId,
UpdatedDate


)
values(
  
  @Name,@RegistrationNo,@Location,@Address,@Pincode
,@PhoneNo,
  @IsActive,
  @CreatedByUserId,
  @CreatedDate,
  @UpdatedByUserId,
  @UpdatedDate
 


)

end
else
begin
update SeedDistributor Set Name=@Name,RegistrationNo=@RegistrationNo,Location=@Location,Address=@Address,Pincode=@Pincode,
PhoneNo=@PhoneNo,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where Id=@Id
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddSoilHealthCard]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSoilHealthCard]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddSoilHealthCard]
(@ID int,
@PlotNo varchar (255),
@SampleNo varchar(50),
@SampleCollectionDate datetime,
@SoilColour int,
@SoilNature int,
@DocUrl varchar(500)
,@DocType varchar(255)
,@DocExtension varchar(255),
@PH Decimal (18,2),
@ElectricalConductivity Decimal (18,2),
@OrganicCarbon Decimal (18,2),
@Nitrogen Decimal (18,2),
@Phosphorous Decimal (18,2),
@Potassium Decimal (18,2),
@Sulphur Decimal (18,2),
@Zinc Decimal (18,2),
@Iron Decimal (18,2),
@Manganese Decimal (18,2),
@Copper Decimal (18,2),
@Boron Decimal (18,2),
@Type varchar(20),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
 If isnull(@ID,0) = 0
 begin
 insert into SoilHealthCard(
 PlotNo,
 SampleNo,
 SampleCollectionDate,
 SoilColour,
 SoilNature,
 PH,
 ElectricalConductivity,
 OrganicCarbon,
 Nitrogen,
 Phosphorous,
 Potassium,
 Sulphur,
 Zinc,
 Iron,
 Manganese,
 Copper,
 Boron,
 Type,
 DocUrl,
DocType,
DocExtension,
 IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
)
values(
@PlotNo,
@SampleNo,
@SampleCollectionDate,
@SoilColour,
@SoilNature,
@PH,
@ElectricalConductivity,
@OrganicCarbon,
@Nitrogen,
@Phosphorous ,
@Potassium ,
@Sulphur ,
@Zinc ,
@Iron ,
@Manganese ,
@Copper ,
@Boron,
@Type,
@DocUrl,
@DocType,
@DocExtension,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
 
end
else
begin
update SoilHealthCard Set
PlotNo = @PlotNo,
SampleNo=@SampleNo ,
SampleCollectionDate=@SampleCollectionDate,
SoilColour=@SoilColour ,
SoilNature =@SoilNature ,
PH=@PH ,
ElectricalConductivity=@ElectricalConductivity ,
OrganicCarbon=@OrganicCarbon ,
Nitrogen=@Nitrogen ,
Phosphorous=@Phosphorous ,
Potassium=@Potassium ,
Sulphur=@Sulphur ,
Zinc =@Zinc ,
Iron=@Iron ,
Manganese =@Manganese ,
Copper=@Copper ,
Boron =@Boron ,
Type = @Type,
DocUrl = @DocUrl,
DocType = @DocType,
DocExtension=@DocExtension,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
 
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddSoilHealthCardDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddSoilHealthCardDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddSoilHealthCardDetails]
(
--@ID int,
@PlotNo varchar (255),
@SampleNo varchar(50),
@SampleCollectionDate datetime,
@SoilColour int,
@SoilNature int,
@DocUrl varchar(500)
,@DocType varchar(255)
,@DocExtension varchar(255),
@PH Decimal (18,2),
@ElectricalConductivity Decimal (18,2),
@OrganicCarbon Decimal (18,2),
@Nitrogen Decimal (18,2),
@Phosphorous Decimal (18,2),
@Potassium Decimal (18,2),
@Sulphur Decimal (18,2),
@Zinc Decimal (18,2),
@Iron Decimal (18,2),
@Manganese Decimal (18,2),
@Copper Decimal (18,2),
@Boron Decimal (18,2),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
 begin
 insert into SoilHealthCard(
 PlotNo,
 SampleNo,
 SampleCollectionDate,
 SoilColour,
 SoilNature,
 PH,
 ElectricalConductivity,
 OrganicCarbon,
 Nitrogen,
 Phosphorous,
 Potassium,
 Sulphur,
 Zinc,
 Iron,
 Manganese,
 Copper,
 Boron,
 DocUrl,
DocType,
DocExtension,
 IsActive,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
)
values(
@PlotNo,
@SampleNo ,
@SampleCollectionDate,
@SoilColour ,
@SoilNature ,
@PH ,
@ElectricalConductivity ,
@OrganicCarbon ,
@Nitrogen ,
@Phosphorous ,
@Potassium ,
@Sulphur ,
@Zinc ,
@Iron ,
@Manganese ,
@Copper ,
@Boron ,
@DocUrl,
@DocType,
@DocExtension,
@IsActive,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
  
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddStates]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddStates]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddStates] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
			INSERT INTO [dbo].[States] (
				 [Code]
				,[Name]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
				 @Code
				,@Name
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		ELSE
			UPDATE [dbo].[States]
			SET  [Code] = @Code
				,[Name] = @Name
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddTabDatabase]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTabDatabase]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_AddTabDatabase]
(
 @Id int,
 @Name varchar(max),
 @UserId int,
 @FileSize varchar(max),
 @FileType varchar(max),
 @FilePath varchar(max)
)
as
begin
   if ISNULL(@Id,0) = 0
    begin
	     Insert into TabDatabase(
		    [Name]
			,UserId
			,FileSize
			,FileType
			,FilePath
			,CreatedDate
		 )
		 values
		 (
		 @Name
		 ,@UserId
		 ,@FileSize
		 ,@FileType
		 ,@FilePath
		 ,GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
		 )
	end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddTabDatabaseByVoluntaryId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddTabDatabaseByVoluntaryId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create procedure [dbo].[SP_AddTabDatabaseByVoluntaryId]
(
 @Id int,
 @Name varchar(max),
 @AgentId int,
 @VoluntaryId int,
 @FileSize varchar(max),
 @FileType varchar(max),
 @FilePath varchar(max)
)
as
begin
   if ISNULL(@Id,0) = 0
    begin
	     Insert into TabDatabase(
		    [Name]
			,AgentId
			,VoluntaryId
			,FileSize
			,FileType
			,FilePath
			,CreatedDate
		 )
		 values
		 (
		 @Name
		 ,@AgentId
		 ,@VoluntaryId
		 ,@FileSize
		 ,@FileType
		 ,@FilePath
		 ,GETDATE() AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
		 )
	end
end
GO

-- %% [markdown]
-- # [dbo].[SP_AddUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddUsers]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 


CREATE PROCEDURE [dbo].[SP_AddUsers] 
(
@Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@MiddileName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber bigint
,@RoleId int
,@IMEINo varchar(50)
,@ViewYN bit
,@DOB date
,@Education varchar(100)
,@Address varchar(500)
,@photo varchar(max)
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION

 

    BEGIN TRY
        IF ISNULL(@Id,0)=0
            INSERT INTO [dbo].[Users] (
                 [UserName]
                ,[Password]
                ,[FirstName]
                ,[MiddileName]
                ,[LastName]
                ,[EmailId]
                ,[MobileNumber]
                ,[RoleId]
                ,[IMEINo]
                ,[ViewYN]
                ,[DOB]
                ,[Education]
                ,[Address]
                ,[photo]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                @UserName
                ,@Password
                ,@FirstName
                ,@MiddileName
                ,@LastName
                ,@EmailId
                ,@MobileNumber
                ,@RoleId
                ,@IMEINo
                ,ISNULL(@ViewYN, 1)
                ,@DOB
                ,@Education
                ,@Address
                ,@photo
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
        ELSE
            UPDATE [dbo].[Users]
            SET  
                [UserName] = @UserName
                ,[Password] = @Password
                ,[FirstName] = @FirstName
                ,[MiddileName] = @MiddileName
                ,[LastName] = @LastName
                ,[EmailId] = @EmailId
                ,[MobileNumber] = @MobileNumber
                ,[RoleId] = @RoleId
                ,[IMEINo] = @IMEINo
                ,[ViewYN] = ISNULL(@ViewYN, 1)
                ,[DOB] = @DOB
                ,[Education] = @Education
                ,[Address] = @Address
                ,[photo] = @photo
                 ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
    END TRY

 

    BEGIN CATCH
        SELECT @ErrorNumber = ERROR_NUMBER()
            ,@ErrorMessage = ERROR_MESSAGE()

 

        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
    END CATCH;

 

    IF @@TRANCOUNT > 0
        COMMIT TRANSACTION;

 

    SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'
END

GO

-- %% [markdown]
-- # [dbo].[SP_AddVillage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVillage]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_AddVillage] 
(
 @Id int
,@Code varchar(6)
,@Name varchar(100)
,@MandalId int
,@PinCode varchar(6)
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION

	BEGIN TRY
		IF ISNULL(@Id,0)=0
		begin
			INSERT INTO [dbo].[Village] (
			     Id
				 ,[Code]
				,[Name]
				,[MandalId]
				,[PinCode]
				,[IsActive]
				,[CreatedDate]
				,[CreatedByUserId]
				,[UpdatedDate]
				,[UpdatedByUserId]
				)
			VALUES (
			    (select Max(Id)+1 from Village)
				,@Code
				,@Name
				,@MandalId
				,@PinCode
				,ISNULL(@IsActive, 1)
				,ISNULL(@CreatedDate, GETDATE())
				,@CreatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@UpdatedByUserId
				)
		  end
		ELSE
		begin
			UPDATE [dbo].[Village]
			SET  [Code] = @Code
				,[Name] = @Name
				,[MandalId] = @MandalId
				,[PinCode] = @PinCode
				,[IsActive] = ISNULL(@IsActive, 1)
				,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
				,[UpdatedByUserId] = @UpdatedByUserId
			WHERE Id = @Id
		end
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntary]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntary]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_AddVoluntary] 
(
@Id int
,@UserName varchar(30)
,@Password nvarchar(1024)
,@FirstName varchar(50)
,@LastName varchar(50)
,@EmailId varchar(100)
,@MobileNumber bigint
,@DOB date
,@Education varchar(100)
,@Address varchar(500)
,@Photo varchar(max)
,@IMEINo varchar(50)
,@AgentId int
,@RoleId int
,@IsActive bit
,@CreatedDate datetime
,@CreatedByUserId int
,@UpdatedDate datetime
,@UpdatedByUserId int
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
    BEGIN TRANSACTION
  BEGIN TRY
        IF ISNULL(@Id,0)=0
            INSERT INTO [dbo].[Voluntary] (
                 [UserName]
                ,[Password]
                ,[FirstName]
                ,[LastName]
                ,[EmailId]
                ,[MobileNumber]
                ,[DOB]
                ,[Education]
                ,[Address]
                ,[Photo]
                ,[IMEINo]
                ,AgentId
                ,[RoleId]
                ,[IsActive]
                ,[CreatedDate]
                ,[CreatedByUserId]
                ,[UpdatedDate]
                ,[UpdatedByUserId]
                )
            VALUES (
                @UserName
                ,@Password
                ,@FirstName
                ,@LastName
                ,@EmailId
                ,@MobileNumber
                ,@DOB
                ,@Education
                ,@Address
                ,@Photo
                ,@IMEINo
                ,@AgentId
                ,@RoleId
                ,ISNULL(@IsActive, 1)
                ,ISNULL(@CreatedDate, GETDATE())
                ,@CreatedByUserId
                ,ISNULL(@UpdatedDate, GETDATE())
                ,@UpdatedByUserId
                )
        ELSE
            UPDATE [dbo].[Voluntary]
            SET  
                [UserName] = @UserName
                ,[Password] = @Password
                ,[FirstName] = @FirstName
                ,[LastName] = @LastName
                ,[EmailId] = @EmailId
                ,[MobileNumber] = @MobileNumber
                ,[RoleId] = @RoleId
                ,[IMEINo] = @IMEINo
                ,[IsActive] = ISNULL(@IsActive, 1)
                ,[DOB] = @DOB
                ,[Education] = @Education
                ,[Address] = @Address
                ,[Photo] = @Photo
                 ,AgentId=@AgentId
                 ,[UpdatedDate] = ISNULL(@UpdatedDate, GETDATE())
                ,[UpdatedByUserId] = @UpdatedByUserId
            WHERE Id = @Id
    END TRY

 

    BEGIN CATCH
        SELECT @ErrorNumber = ERROR_NUMBER()
            ,@ErrorMessage = ERROR_MESSAGE()

 

        IF @@TRANCOUNT > 0
            ROLLBACK TRANSACTION;
        RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
    END CATCH;

 

    IF @@TRANCOUNT > 0
        COMMIT TRANSACTION;

 

    SET @ErrorNumber = 0
    SET @ErrorMessage = 'Success'
END

GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntaryDocument]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntaryDocument]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddVoluntaryDocument] 
(
 @FarmerCode varchar(255)
,@PlotNo varchar(255)
,@IdentityCode varchar(Max)
,@DocUrl varchar(500)
,@DocType varchar(255)
,@DocExtension varchar(255)
,@DocOldNum varchar(255)
,@DocLocal varchar(max)
,@IsActive bit
,@AgentId int
,@VoluntaryId int
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		  declare @cnt int
 if @FarmerCode != '' and @PlotNo = ''
begin
set @cnt =(select count(*) from Documents where FarmerCode=@FarmerCode and DocType=@DocType)
end
else
begin  if @FarmerCode = '' and @PlotNo != ''
if @DocType = 'Water Regime'
begin
set @cnt =0
end
else
begin
set @cnt =(select count(*) from Documents where PlotNo=@PlotNo and DocType=@DocType)
end
end
if @cnt =0
begin
			INSERT INTO [dbo].[Documents] (
				 [FarmerCode]
				 ,[PlotNo]
				 ,IdentityCode
				,[DocUrl]
				,[DocType]
				,[DocExtension]
				,[DocOldNum]
				,DocLocal
				,[IsActive]
				,[AgentId]
				,[VoluntaryId]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@PlotNo
				,@IdentityCode
				,@DocUrl
				,@DocType
				,@DocExtension
				,@DocOldNum 
				,@DocLocal
				,ISNULL(@IsActive, 1)
				,@AgentId
				,@VoluntaryId
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
	end
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END


 
GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntaryFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntaryFarmer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddVoluntaryFarmer] 
(
 @FarmerCode varchar(255)
,@FarmerTitle varchar(255)
,@FirstName varchar(255)
,@MiddleName varchar(255)
,@LastName varchar(255)
,@FatherName varchar(255)
,@Gender varchar(50)
,@Age int
,@PrimaryContactNum varchar(255)
,@SecondaryContactNum varchar(255)
,@Address varchar(255)
,@DistrictId int
,@MandalId int
,@StateId int
,@VillageId int
,@PinCode varchar(255)
,@Sync bit
,@IsPlot varchar(255)
,@TotalPlotArea float
,@PlotsCount int
,@LocalImage varchar(max)
,@IsActive bit
,@AgentId int
,@VoluntaryId int
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN

			INSERT INTO [dbo].[Farmer] (
				 [FarmerCode]
				 ,[FarmerTitle]
				,[FirstName]
				,[MiddleName]
				,[LastName]
				,[FatherName]
				,[Gender]
				,[Age]
				,[PrimaryContactNum]
				,[SecondaryContactNum]
				,[Address]
				,DistrictId
				,MandalId
				,[StateId]
				,[VillageId]
				,[PinCode]
				,[Sync]
				,IsPlot
				,TotalPlotArea
				,PlotsCount
				,LocalImage
				,[IsActive]
				,[AgentId]
				,[VoluntaryId]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@FarmerTitle
				,@FirstName
				,@MiddleName
				,@LastName
				,@FatherName
				,@Gender
				,@Age
				,@PrimaryContactNum
				,@SecondaryContactNum
				,@Address
				,@DistrictId
				,@MandalId
				,@StateId
				,@VillageId
				,@PinCode
				,@Sync
				,@IsPlot
				,@TotalPlotArea
				,@PlotsCount
				,@LocalImage
				,ISNULL(@IsActive, 1)
				,@AgentId
				,@VoluntaryId
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
	
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntaryFarmerBank]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntaryFarmerBank]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


Create PROCEDURE [dbo].[SP_AddVoluntaryFarmerBank] 
(
 @FarmerCode varchar(255)
,@IdentityCode varchar(255)
,@AccountHolderName varchar(255)
,@AccountNumber varchar(255)
,@BranchName varchar(255)
,@IFSCCode varchar(255)
,@LocalDocUrl varchar(max)
,@IsActive bit
,@AgentId int
,@VoluntaryId int
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		BEGIN

			INSERT INTO [dbo].[FarmerBank] (
				 [FarmerCode]
				 ,IdentityCode
				,AccountHolderName
				,AccountNumber
				,BranchName
				,IFSCCode
				,LocalDocUrl
				,[IsActive]
				,[AgentId]
				,[VoluntaryId]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@IdentityCode
				,@AccountHolderName
				,@AccountNumber
				,@BranchName
				,@IFSCCode
				,@LocalDocUrl
				,ISNULL(@IsActive, 1)
				,@AgentId
				,@VoluntaryId
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				)
	
		END
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntaryGeoBoundaries]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntaryGeoBoundaries]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddVoluntaryGeoBoundaries] 
(
 @PlotNo varchar(255)
,@Latitude varchar(255)
,@Longitude varchar(255)
,@GeoCategoryTypeId int
,@SeqNo Int
,@Sync bit
,@IsActive bit
,@AgentId int
,@VoluntaryId int
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		
		BEGIN
		  
			INSERT INTO [dbo].[GeoBoundaries] (
				 [PlotNo]
				,[Latitude]
				,[Longitude]
				,GeoCategoryTypeId
				,SeqNo
				,[Sync]
				,[IsActive]
				,AgentId
				,VoluntaryId
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				
				)
			VALUES (
				 @PlotNo
				,@Latitude
				,@Longitude
				,@GeoCategoryTypeId
				,@SeqNo
				,@Sync
				,ISNULL(@IsActive, 1)
				,@AgentId
				,@VoluntaryId
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				
				)
		
		END
		
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntaryLand]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntaryLand]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_AddVoluntaryLand] 
(
 @PlotNo varchar(255)
,@Size varchar(255)
,@CropId int
,@FarmerCode varchar(255)
,@Latitude varchar(255)
,@Longitude varchar(255)
,@Address varchar(255)
,@Plotownership varchar(255)
,@Cluster varchar(255)
,@LandMark varchar(255)
,@DistrictId int
,@MandalId int
,@VillageId int
,@StateId int
,@PinCode varchar(255)
,@SurveyNo varchar(100)
,@PattadarBookNo varchar(100)
,@GPS varchar(100)
,@GPSPlotArea decimal(18,6)
,@PlotArea1 decimal(18,6)
,@PlotArea2 decimal(18,6)
,@PlotArea3 decimal(18,6)
,@PlotArea4 decimal(18,6)
,@PlotArea5 decimal(18,6)
,@Sync bit
,@LandImage varchar(max)
,@IsActive bit
,@AgentId int
,@VoluntaryId int
,@CreatedByUserId int
,@CreatedDate datetime
,@UpdatedByUserId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		
		BEGIN


		IF LEN(ISNULL(@GPSPlotArea, '')) = 0
     	Begin
			set @GPSPlotArea = 0
		end
    declare @cnt INT
    set @cnt = (select count(1) from land where FarmerCode = @FarmerCode and [PlotNo] = @PlotNo and IsActive =1 )
		IF @cnt=0
			INSERT INTO [dbo].[Land] (
				 [PlotNo]
				,[Size]
				,[CropId]
				,[FarmerCode]
				,[Latitude]
				,[Longitude]
				,[Address]
				,[Plotownership]
				,[Cluster]
				,[LandMark]
				,LandImage
				,[IsActive]
				,[DistrictId]
				,[MandalId]
				,[VillageId]
				,[StateId]
				,[PinCode]
				,[SurveyNo]
				,[PattadarBookNo]
				,[Sync]
				,[GPS]
				,[GPSPlotArea]
				,[PlotArea1]
				,[PlotArea2]
				,[PlotArea3]
				,[PlotArea4]
				,[PlotArea5]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				,[AgentId]
				,[VoluntaryId]
				)
			VALUES (
				 @PlotNo
				,@Size
				,@CropId
				,@FarmerCode
				,@Latitude
				,@Longitude
				,@Address
				,@Plotownership
				,@Cluster
				,@LandMark
				,@LandImage
				,ISNULL(@IsActive, 1)
				,@DistrictId
				,@MandalId
				,@VillageId
				,@StateId
				,@PinCode
				,@SurveyNo
				,@PattadarBookNo
				,@Sync
				,@GPS
				,@GPSPlotArea
				,@PlotArea1
				,@PlotArea2
				,@PlotArea3
				,@PlotArea4
				,@PlotArea5
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE())
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE())
				,@AgentId
				,@VoluntaryId
				)
            ELSE
                UPDATE [dbo].[Land] 
                SET
                [Latitude] = @Latitude
                ,[Longitude] = @Longitude
                ,LandImage = @LandImage
                ,GPSPlotArea = @GPSPlotArea
				,PlotArea1 = @PlotArea1
				,PlotArea2 = @PlotArea2
				,PlotArea3 = @PlotArea3
				,PlotArea4 = @PlotArea4
				,PlotArea5 = @PlotArea5
                ,UpdatedByUserId = @UpdatedByUserId
                ,UpdatedDate = ISNULL(@UpdatedDate, GETDATE())
                where FarmerCode = @FarmerCode and PlotNo = @PlotNo
		END
		
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_AddVoluntaryLogBook]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddVoluntaryLogBook]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Procedure [dbo].[SP_AddVoluntaryLogBook]
(@ID Int ,
@LogBookNo varchar(50),
@PlotNo varchar(50),
@Season Int,
@DateOfSowing datetime,
@DateOfTransplanting datetime,
@Crop Int,
@CropVariety Int,
@SeedVariety Int,
@SeedDistributor Int,
@CultivationPractice int,
@IsActive bit,
@AgentId int,
@VoluntaryId int,
@IsProgressive bit,
@isClosed bit,
@FarmerCode varchar(255),
@CurrYear int,
@PreviousYeild decimal(18,6),
@PrevSeason int,
@PrevCropVariety int,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
  
  declare @cnt int
  set @cnt = (select count(*) from LogBook where FarmerCode = @FarmerCode and Season=@Season and CurrYear=@CurrYear
  and IsActive=1)

 If @cnt = 0
 begin
 insert into LogBook(
  LogBookNo,
  PlotNo,
  Season,
  DateOfSowing,
  DateOfTransplanting,
  Crop,
  CropVariety,
  SeedVariety,
  SeedDistributor,
  CultivationPractice,
  IsActive,
  AgentId,
  VoluntaryId,
  IsProgressive,
  isClosed,
  FarmerCode,
  CurrYear,
  PreviousYeild,
  PrevSeason,
  PrevCropVariety,
  CreatedDate,
  CreatedByUserId,
  UpdatedDate,
  UpdatedByUserId
)
values(
@LogBookNo,
@PlotNo,
@Season,
ISNULL(@DateOfSowing, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
ISNULL(@DateOfTransplanting, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time',
@Crop,
@CropVariety,
@SeedVariety,
@SeedDistributor,
@CultivationPractice,
@IsActive,
@AgentId,
@VoluntaryId,
@IsProgressive,
0,
@FarmerCode,
@CurrYear,
@PreviousYeild,
@PrevSeason,
@PrevCropVariety,
@CreatedDate,
@CreatedByUserId,
@UpdatedDate,
@UpdatedByUserId
)
 
end
else
begin
update LogBook Set 
DateOfSowing=@DateOfSowing,DateOfTransplanting=@DateOfTransplanting,
Crop=@Crop,CropVariety=@CropVariety,SeedVariety=@SeedVariety,
CultivationPractice=@CultivationPractice,SeedDistributor=@SeedDistributor,
IsActive=@IsActive,PreviousYeild = @PreviousYeild,PrevSeason=@PrevSeason,
PrevCropVariety =@PrevCropVariety,
UpdatedDate=@UpdatedDate,
UpdatedByUserId=@UpdatedByUserId,AgentId = @AgentId,VoluntaryId = @VoluntaryId
where FarmerCode=@FarmerCode and Season=@Season and CurrYear = @CurrYear
end
end

GO

-- %% [markdown]
-- # [dbo].[SP_AddWaterReasonPreSeason]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWaterReasonPreSeason]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddWaterReasonPreSeason]
(@ID int,
@LogBookNo varchar(255),
@Field int,
@SQNo varchar(15),
@IsActive bit,
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
/*
declare @LogId int
  set @LogId= (select count(*) from  WaterReasonPreSeason where LogBookNo=@LogBookNo) */
 If isnull(@Id,0) = 0
 begin
 insert into WaterReasonPreSeason(
LogBookNo,
 Field,
 SQNo,
IsActive,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

)
values(
  @LogBookNo,
  @Field,
  @SQNo,
  @IsActive,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
 
end
else
begin
update WaterReasonPreSeason Set LogBookNo=@LogBookNo,Field=@Field,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where LogBookNo=@LogBookNo
 
end 
end
 

GO

-- %% [markdown]
-- # [dbo].[SP_AddWaterRegimeonSeason]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWaterRegimeonSeason]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Procedure [dbo].[SP_AddWaterRegimeonSeason]
(@ID int,
@LogBookNo varchar(255),
@Field int,
@IsActive bit,
@SQNo varchar(15),
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
 If isnull(@ID,0) = 0
 begin
 insert into WaterRegimeonSeason(
LogBookNo,
 Field,
IsActive,
SQNo,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

)
values(
  @LogBookNo,
  @Field,
  @IsActive,
  @SQNo,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
 
end
else
begin
update WaterRegimeonSeason Set LogBookNo=@LogBookNo,Field=@Field,SQNo=@SQNo ,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_AddWaterRegimeOnthefield]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_AddWaterRegimeOnthefield]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 CREATE Procedure [dbo].[SP_AddWaterRegimeOnthefield]
(@ID int,
@LogBookNo varchar(255),
@Field int,
@IsActive bit,
@SQNo varchar (15),
@CreatedDate datetime,
@CreatedByUserId int,
@UpdatedDate datetime,
@UpdatedByUserId int
 
)
as begin
 If isnull(@ID,0) = 0
 begin
 insert into  WaterRegimeOnthefield(
LogBookNo,
Field,
IsActive,
SQNo,
CreatedDate,
CreatedByUserId,
UpdatedDate,
UpdatedByUserId

)
values(
  @LogBookNo,
  @Field,
  @IsActive,
  @SQNo,
  @CreatedDate,
  @CreatedByUserId,
  @UpdatedDate,
  @UpdatedByUserId
)
  
end
else
begin
update  WaterRegimeOnthefield Set LogBookNo=@LogBookNo,Field=@Field,SQNo=@SQNo,
IsActive=@IsActive,UpdatedDate=@UpdatedDate,UpdatedByUserId=@UpdatedByUserId
where ID=@ID
 
end 
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_CheckAgentbyIdWeekId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckAgentbyIdWeekId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_CheckAgentbyIdWeekId] (@Id Int,@WeekId Int,@AgentId Int)
AS
BEGIN
	SELECT at.Id,
	at.WeekId
		,at.TargetRegistration
		,at.TargetArea
		,at.AgentId
		,at.IsActive
		,at.CreatedDate
		,at.CreatedByUserId
		,at.UpdatedDate
		,at.UpdatedByUserId
		,u.UserName
		,wc.Id as weeklycalendarId
		,wc.weekOfYear
		,wc.WeekStart
		,wc.WeekEnd
	FROM dbo.agenttargets at
	inner join users u on u.Id=at.AgentId
	inner join weeklycalendar wc on wc.Id = at.WeekId
	INNER JOIN UserInfo Ui ON Ui.Id=at.CreatedByUserId
	inner join UserInfo Um ON Um.Id=at.UpdatedByUserId
	WHERE at.Id = ISNULL(@Id, at.Id) and at.WeekId= ISNULL(@WeekId,at.WeekId)
	and at.AgentId=ISNULL(@AgentId,at.AgentId)
		    
		  order by at.AgentId
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_CheckClusterName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckClusterName]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE Proc [dbo].[SP_CheckClusterName](@P_Name varchar(255))
as
begin
select count(*) Count from ClusterHDR where LOWER(Name) =LOWER(@P_Name)
end
GO

-- %% [markdown]
-- # [dbo].[SP_CheckLogbookByLogBook]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_CheckLogbookByLogBook]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_CheckLogbookByLogBook 'TSNKLTP030_017012'
CREATE proc [dbo].[SP_CheckLogbookByLogBook](@LogBookNo varchar(255))
as
begin

select lb.LogBookNo,case when f.LogBookNo is null then 0 else 1 end as Fertilizer,
case when oa.LogBookNo is null then 0 else 1 end as OrganicAmendments,
case when wros.LogBookNo is null then 0 else 1 end as WaterRegimeonSeason,
case when wrps.LogBookNo is null then 0 else 1 end as WaterReasonPreSeason,
case when bpo.LogBookNo is null then 0 else 1 end as BorewellPumpOperations,
case when wrof.LogBookNo is null then 0 else 1 end as WaterRegimeOnthefield,
case when hd.LogBookNo is null then 0 else 1 end as HarvestDetails,
case when gc.LogBookNo is null then 0 else 1 end as GHGEmissionCollection
from LogBook lb
left join Fertilizer f on f.LogBookNo = lb.LogBookNo
left join OrganicAmendments oa on oa.LogBookNo = lb.LogBookNo
left join WaterRegimeonSeason wros on wros.LogBookNo = lb.LogBookNo
left join WaterReasonPreSeason wrps on wrps.LogBookNo = lb.LogBookNo
left join BorewellPumpOperations bpo on bpo.LogBookNo = lb.LogBookNo
left join WaterRegimeOnthefield wrof on wrof.LogBookNo = lb.LogBookNo
left join HarvestDetails hd on hd.LogBookNo = lb.LogBookNo
left join GHGEmissionCollection gc on gc.LogBookNo = lb.LogBookNo
where lb.LogBookNo =@LogBookNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_DailyFarmerCount]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DailyFarmerCount]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_DailyFarmerCount]
as
begin
select top 3 * from 
(select * from
(select FieldExecutive,count(*) FarmerCount,SUM(TotalPlotArea) ApproxArea ,sum(GPSPlotArea) GPSPlotArea from
(select f.FarmerCode,f.FarmerTitle,f.FirstName,f.MiddleName,f.TotalPlotArea,f.LastName,f.CreatedByUserId,u.FirstName FieldExecutive,cast(f.CreatedDate as date) CreatedDate,
l.GPSPlotArea
from Farmer f
full outer join (select FarmerCode,sum(GPSPlotArea) GPSPlotArea from Land where IsActive=1 group by FarmerCode) l on l.FarmerCode = f.FarmerCode
inner join Users u on u.Id = f.CreatedByUserId
where cast(f.CreatedDate as date) = cast(getdate()   as date))X group by FieldExecutive)X
union
select 'F E 1','0',0,'0'
union
select 'F E 2','0',0,'0'
union
select 'F E 3','0',0,'0'
union
select 'F E 4','0',0,'0'
union
select 'F E 5','0',0,'0'
)y
order by FarmerCount desc
end
GO

-- %% [markdown]
-- # [dbo].[SP_DailyFarmerCountbyUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DailyFarmerCountbyUser]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_DailyFarmerCountbyUser] (@P_UserName Varchar(30))
as
begin
select  * from 
(select * from
(select FieldExecutive,count(*) FarmerCount,SUM(TotalPlotArea) ApproxArea ,sum(GPSPlotArea) GPSPlotArea from
(select f.FarmerCode,f.FarmerTitle,f.FirstName,f.MiddleName,f.TotalPlotArea,f.LastName,f.CreatedByUserId,u.FirstName FieldExecutive,cast(f.CreatedDate as date) CreatedDate,
l.GPSPlotArea
from Farmer f
full outer join (select FarmerCode,sum(GPSPlotArea) GPSPlotArea from Land where IsActive=1 group by FarmerCode) l on l.FarmerCode = f.FarmerCode
inner join Users u on u.Id = f.CreatedByUserId
where cast(f.CreatedDate as date) = cast(getdate() as date) AND UserName=@P_UserName)X group by FieldExecutive)X

)y
order by FarmerCount desc
end
GO

-- %% [markdown]
-- # [dbo].[SP_DailyFullReport]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DailyFullReport]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_DailyFullReport]
as
begin
select ROW_NUMBER() over(order by f.FarmerCode) SNo,f.FarmerCode,f.FirstName+' '+f.LastName as FarmerName,f.FatherName,f.PrimaryContactNum,
f.IdentityCode AadharNo,l.PlotNo,l.Latitude,l.Longitude,l.PattadarBookNo,l.SurveyNo,
S.Name StateName,D.Name DistrictName,M.Name MandalName,V.Name VillageName,u.UserName as Agent,
cast(doc.CreatedDate as Date) as PipeInstalledDate , doc.DocUrl as PipeInstallationTaken,
f.TotalPlotArea,l.Size,l.GPSPlotArea,l.PlotArea1,l.PlotArea2,l.PlotArea3,l.PlotArea4,l.PlotArea5,
vol.UserName VolunteerName
,docW1_1.DocUrl as WaterCycle1_1,cast(docW1_1.CreatedDate as date) as WaterCycle1_1Date
,docW1_2.DocUrl as WaterCycle1_2,cast(docW1_2.CreatedDate as date) as WaterCycle1_2Date

 

,docW2_1.DocUrl as WaterCycle2_1,cast(docW2_1.CreatedDate as date) as WaterCycle2_1Date
,docW2_2.DocUrl as WaterCycle2_2,cast(docW2_2.CreatedDate as date) as WaterCycle2_2Date

 

,docW3_1.DocUrl as WaterCycle3_1,cast(docW3_1.CreatedDate as date) as WaterCycle3_1Date
,docW3_2.DocUrl as WaterCycle3_2,cast(docW3_2.CreatedDate as date) as WaterCycle3_2Date

 

from Farmer f 
left join Land l on l.FarmerCode = f.FarmerCode
left join States S on S.Id = f.StateId
left join District D on D.Id = f.DistrictId
left join Mandal M on M.Id = f.MandalId
left join Village V on V.Id = f.VillageId
left join Users u on u.Id = f.AgentId
left join Documents doc on doc.FarmerCode = f.FarmerCode and doc.DocType='pipe installation' and doc.IsActive=1
left join Documents docW1_1 on docW1_1.FarmerCode = f.FarmerCode and docW1_1.DocType='water cycle 1_1' and docW1_1.IsActive=1
left join Documents docW1_2 on docW1_2.FarmerCode = f.FarmerCode and docW1_2.DocType='water cycle 1_2' and docW1_2.IsActive=1
left join Documents docW2_1 on docW2_1.FarmerCode = f.FarmerCode and docW2_1.DocType='water cycle 2_1' and docW2_1.IsActive=1
left join Documents docW2_2 on docW2_2.FarmerCode = f.FarmerCode and docW2_2.DocType='water cycle 2_2' and docW2_2.IsActive=1
left join Documents docW3_1 on docW3_1.FarmerCode = f.FarmerCode and docW3_1.DocType='water cycle 3_1' and docW3_1.IsActive=1
left join Documents docW3_2 on docW3_2.FarmerCode = f.FarmerCode and docW3_2.DocType='water cycle 3_2' and docW3_2.IsActive=1
left join Voluntary vol on vol.Id=doc.VoluntaryId
where f.AgentId in (select Id from Users where RoleId = 3 and ViewYN = 1 and Id not in (48,55))
and f.FarmerCode like 'F_%' and f.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_DailyFullReportWithProof]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DailyFullReportWithProof]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_DailyFullReportWithProof]
as
begin
IF OBJECT_ID('tempdb..#TempFarmer') IS NOT NULL DROP TABLE #TempFarmer
select * into #TempFarmer from Farmer where  IsActive =1 and FarmerCode like 'F_%' and
AgentId in (select Id from Users where RoleId = 3 and ViewYN = 1 and Id not in (48,55))

select f.FarmerCode,f.FirstName+' '+f.LastName as FarmerName,f.FatherName,f.Gender,f.Age,f.PrimaryContactNum
,f.TotalPlotArea,S.Name StateName,D.Name DistrictName,M.Name MandalName,V.Name VillageName,c.UserName as AgentName
,f.IdentityCode as AadharNo,l.PattadarBookNo,l.SurveyNo,
case when docphoto.DocUrl is not null then docphoto.DocUrl else 'No' end as FarmerPhoto,
case when docaadhar.DocUrl is not null  then docaadhar.DocUrl else 'No' end as FarmerAadhar,
case when docpattadar.DocUrl is not null  then docpattadar.DocUrl else 'No' end as FarmerPattadarBook,
case when docbank.DocUrl is not null  then docbank.DocUrl else 'No' end as FarmerBankPassbook,
case when docfarmerconsent.DocUrl is not null  then docfarmerconsent.DocUrl else 'No' end as  FarmerConsent
,fc.AgreementDate
,lb.LogBookNo,cast(lb.DateOfSowing as date) DateOfSowing ,
cast(lb.DateOfTransplanting as date) DateOfTransplanting
from #TempFarmer f 
left JOIN UserInfo c ON c.Id=f.CreatedByUserId
left join States S on S.Id = f.StateId 
left join District D on D.Id = f.DistrictId
left join Mandal M on M.Id = f.MandalId
left join Village V on V.Id = f.VillageId
left join LogBook lb on lb.FarmerCode = f.FarmerCode
left join FarmerBank fb on fb.FarmerCode = f.FarmerCode  and fb.IsActive = 1
left join (select FarmerCode,string_agg(PattadarBookNo,'$') AS PattadarBookNo,string_agg(SurveyNo,'$') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='photo' ) docphoto on docphoto.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='aadhar card' ) docaadhar on docaadhar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Pattadar Book' ) docpattadar on docpattadar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='bank passbook' ) docbank on docbank.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Agreement' ) docfarmerconsent on docfarmerconsent.FarmerCode = f.FarmerCode
left join FarmerConsent fc on fc.FarmerCode = f.FarmerCode and fc.IsActive =1
drop table #TempFarmer
end
GO

-- %% [markdown]
-- # [dbo].[SP_DashboardAllPlots]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DashboardAllPlots]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_DashboardAllPlots]
as
begin
select l.PlotNo,l.FarmerCode,f.FirstName +' '+f.LastName FarmerName,
u.UserName as Agent,case when lb.LogBookNo is null then 'No'
when lb.LogBookNo is not null then (case when (select count(LogBookNo) from WaterRegimeOnthefield where LogBookNo = lb.LogBookNo)>0 then 'Yes' else 'No' end)
end WaterRegimeInstalled,case when l.Latitude is not null and l.Longitude is not null then 'Yes' else 'No' end GPSTakenYN,case when lb.LogBookNo is null then 'No'
when lb.LogBookNo is not null then (case when (select count(*) from Documents where DocType='Water Regime' and PlotNo = l.PlotNo)>0 then 'Yes' else 'No' end)
end WaterRegimeImageTaken
from Land l
left join(select * from LogBook where isClosed=0) lb on l.PlotNo = lb.PlotNo
left join Farmer f on f.FarmerCode = l.FarmerCode
left join Users u on u.Id = l.CreatedByUserId
where l.IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_DashboardDailyPlotRelatedInfo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DashboardDailyPlotRelatedInfo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Proc [dbo].[SP_DashboardDailyPlotRelatedInfo](@P_UserName Varchar(30))
as
begin

declare @NoofPlots int,@NoofGPSPointsTaken int,@NoofWaterRegimeInstalled int 
set @NoofPlots =(select count(PlotNo) NoofPlots from Land L
left join Users u on u.Id=L.CreatedByUserId
where u.UserName=@P_UserName and L.IsActive =1 AND cast(L.CreatedDate as date) = cast(getdate() as date))

set @NoofGPSPointsTaken =(select count(GPSPlotArea) NoofGPSPointsTaken 
from Land L left join Users u on u.Id=L.CreatedByUserId 
where u.UserName=@P_UserName and L.IsActive =1 and L.Latitude is not null and L.Longitude is  not null
and cast(L.CreatedDate as date) = cast(getdate() as date))

set @NoofWaterRegimeInstalled = (select count(distinct LogBookNo) NoofWaterRegimeInstalled
from WaterRegimeOnthefield w
left join Users u on u.Id=w.CreatedByUserId
where u.UserName=@P_UserName and w.IsActive =1 
and cast(w.CreatedDate as date) = cast(getdate() as date))

select @NoofPlots as NoofPlots,@NoofGPSPointsTaken as NoofGPSPointsTaken,@NoofWaterRegimeInstalled as NoofWaterRegimeInstalled
end
GO

-- %% [markdown]
-- # [dbo].[SP_DashboardPlotRelatedInfo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DashboardPlotRelatedInfo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_DashboardPlotRelatedInfo]
as
begin

--declare @NoofPlots int,@NoofGPSPointsTaken int,@NoofWaterRegimeInstalled int 
--set @NoofPlots =(select count(PlotNo) NoofPlots from Land where IsActive =1)

--set @NoofGPSPointsTaken =(select count(GPSPlotArea) NoofGPSPointsTaken 
--from Land where IsActive =1 and Latitude is not null and Longitude is not null)

--set @NoofWaterRegimeInstalled = (select count(distinct LogBookNo) NoofWaterRegimeInstalled
--from WaterRegimeOnthefield where IsActive=1)

--select @NoofPlots as NoofPlots,@NoofGPSPointsTaken as NoofGPSPointsTaken,@NoofWaterRegimeInstalled as NoofWaterRegimeInstalled

declare @totalplot int
declare @gpspointtaken int
declare @pipeinstalled int

set @totalplot = (select count(PlotNo) from vw_plot)
set @gpspointtaken = (select count(Id) 
from vw_plot where Latitude!='' and Longitude!='')
set @pipeinstalled = (select count(PlotNo)
from [dbo].[vw_pipeinstalled])

select @totalplot as NoofPlots,
@gpspointtaken as NoofGPSPointsTaken,
@pipeinstalled as NoofWaterRegimeInstalled
end
GO

-- %% [markdown]
-- # [dbo].[SP_DashboardTotalPlotRelatedInfo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DashboardTotalPlotRelatedInfo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create Proc [dbo].[SP_DashboardTotalPlotRelatedInfo](@P_UserName Varchar(30))
as
begin

declare @NoofPlots int,@NoofGPSPointsTaken int,@NoofWaterRegimeInstalled int 
set @NoofPlots =(select count(PlotNo) NoofPlots from Land L
left join Users u on u.Id=L.CreatedByUserId
where u.UserName=@P_UserName and L.IsActive =1 )

set @NoofGPSPointsTaken =(select count(GPSPlotArea) NoofGPSPointsTaken 
from Land L left join Users u on u.Id=L.CreatedByUserId 
where u.UserName=@P_UserName and L.IsActive =1 and L.Latitude is not null and L.Longitude is  not null
)

set @NoofWaterRegimeInstalled = (select count(distinct LogBookNo) NoofWaterRegimeInstalled
from WaterRegimeOnthefield w
left join Users u on u.Id=w.CreatedByUserId
where u.UserName=@P_UserName and w.IsActive =1 
)

select @NoofPlots as NoofPlots,@NoofGPSPointsTaken as NoofGPSPointsTaken,@NoofWaterRegimeInstalled as NoofWaterRegimeInstalled
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteAgentTargetById]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteAgentTargetById]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_DeleteAgentTargetById]
(
  @Id int
 ,@IsActive bit
)
as
begin
  update agenttargets set 
   IsActive = @IsActive
  where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_DeleteClusterVillageDTL]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_DeleteClusterVillageDTL]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_DeleteClusterVillageDTL]
(
 @Id INT
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(255) OUTPUT
)
AS 
BEGIN
	BEGIN TRANSACTION
		BEGIN TRY
			DELETE FROM [dbo].[ClusterDTL] WHERE Id = ISNULL(@Id, Id) AND IsActive = 1
		END TRY

		BEGIN CATCH
			SELECT @ErrorNumber = ERROR_NUMBER()
				,@ErrorMessage = ERROR_MESSAGE()
	
			IF @@TRANCOUNT > 0
				ROLLBACK TRANSACTION;
			RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
		END CATCH;
	
		IF @@TRANCOUNT > 0
			COMMIT TRANSACTION;
	
		SET @ErrorNumber = 0
		SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_FarmerKYCByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_FarmerKYCByFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_FarmerKYCByFarmerCode '037223481398'
CREATE Proc [dbo].[SP_FarmerKYCByFarmerCode](@FarmerCode varchar(255))
as
begin
select DocUrl,DocType from Documents where FarmerCode=@FarmerCode 
and DocType in ('photo','bank passbook','voter id','pan card','aadhar card')
union
select DocUrl,'plot photo' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('photo') 
union
select DocUrl,'pipe installed' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('Water Regime') and DocOldNum='Pipe Installation'
end

GO

-- %% [markdown]
-- # [dbo].[SP_GenerateKMLFileByPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GenerateKMLFileByPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GenerateKMLFileByPlotNo 'P_1688209537000_15'
Create Proc [dbo].[SP_GenerateKMLFileByPlotNo](@PlotNo varchar(255))
as
begin
declare @kml varchar(max);
declare @coordinates varchar(max);
set @coordinates =(select
   distinct  
    stuff((
        select ' ' + u.Longitude+','+u.Latitude+','+'0'
        from GeoBoundaries u where u.PlotNo = @PlotNo order by SeqNo asc
        for xml path('')
    ),1,1,'') as userlist
from GeoBoundaries
group by PlotNo )
set @kml = '<?xml version="1.0" encoding="UTF-8"?>
<kml xmlns="http://www.opengis.net/kml/2.2">
  <Placemark>
    <name>'+@PlotNo+'</name>
    <Polygon>
      <outerBoundaryIs>
        <LinearRing>
          <coordinates>
            '+@coordinates+'
          </coordinates>
        </LinearRing>
      </outerBoundaryIs>
    </Polygon>
  </Placemark>
</kml>
'
select @kml as KML,@PlotNo as PlotNo 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetAgentData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAgentData]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetAgentData null
CREATE proc [dbo].[SP_GetAgentData](@AgentId int)
as
begin
DECLARE @weekid INT

DECLARE @weekstart DATE

DECLARE @weekend DATE


select @weekid = WeekofYear, @weekstart = weekstart, @weekend = weekend from 
weeklycalendar where Datediff(day,getdate(), weekstart) between 0 and 6  



select
fc.AgentId, 
sum(f.TotalPlotArea) as area,
sum(1) as actualregistrations
into #actuals
from FarmerConsent fc
left join Farmer f on fc.FarmerCode = f.FarmerCode
where 1=1
and fc.AgentId = isnull(@AgentId,fc.AgentId)
and f.CreatedDate <= isnull(@weekend,f.CreatedDate)
and fc.FarmerCode like 'F_%' and fc.IsActive = 1

group by fc.AgentId



select agentId, sum(targetregistration) targetregistration,sum(targetarea) targetarea 
into #targets
from agenttargets
where 1=1
and AgentId = isnull(@AgentId,AgentId)
and weekid <= isnull(@weekid,weekid)
group by AgentId







select X.*,cast(((cast(X.actualregistrations as float)/x.targetregistrations)*100) as decimal(18,3)) RegPer,
cast(((cast(X.actualarea as float)/x.targetarea)*100) as decimal(18,3)) AreaPer,
u.UserName AgentName from
(select t.AgentId,
sum(t.targetregistration) as targetregistrations,sum(t.targetarea) targetarea,
isnull(sum(actualregistrations),0) as actualregistrations, cast(isnull(sum(area),0) as decimal(18,3)) as actualarea
from #targets t
left join #actuals a on a.AgentId = t.AgentId
group by t.AgentId)X 
left join Users u on u.Id = x.AgentId
order by actualregistrations desc


drop table #actuals

drop table #targets
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetAgentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAgentDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_GetAgentDetails]
as
begin
select * from Users where RoleId=3 and ViewYN=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetAgentTargetByAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAgentTargetByAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetAgentTargetByAgentId null
CREATE proc [dbo].[SP_GetAgentTargetByAgentId](@AgentId int)
as
begin
  
  select a.*,u.UserName,wc.Year,wc.WeekStart,wc.WeekEnd,cast(WeekStart as varchar(255))+ ' to ' + cast(WeekEnd as varchar(255)) as Weekly
  from AgentTargets a 
  left join WeeklyCalendar wc on wc.Id = a.WeekId
  left join Users u on u.Id = a.AgentId
  where a.AgentId = ISNULL(@AgentId,a.AgentId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetAgenttargetdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAgenttargetdetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetAgenttargetdetails] (@Id Int)
AS
BEGIN
	SELECT at.Id,
	at.WeekId
		,at.TargetRegistration
		,at.TargetArea
		,at.AgentId
		,at.IsActive
		,at.CreatedDate
		,at.CreatedByUserId
		,at.UpdatedDate
		,at.UpdatedByUserId
		,u.UserName
		,wc.Id as weeklycalendarId
		,wc.weekOfYear
		,wc.WeekStart
		,wc.WeekEnd
	FROM dbo.agenttargets at
	inner join users u on u.Id=at.AgentId
	inner join weeklycalendar wc on wc.Id = at.WeekId
	INNER JOIN UserInfo Ui ON Ui.Id=at.CreatedByUserId
	inner join UserInfo Um ON Um.Id=at.UpdatedByUserId
	WHERE at.WeekId = ISNULL(@Id, at.WeekId)   and at.IsActive=1
		    
		  order by WeekId
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetAgenttargetdetailsbyIdWeekId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAgenttargetdetailsbyIdWeekId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetAgenttargetdetailsbyIdWeekId] (@Id Int,@WeekId Int)
AS
BEGIN
	SELECT at.Id,
	at.WeekId
		,at.TargetRegistration
		,at.TargetArea
		,at.AgentId
		,at.IsActive
		,at.CreatedDate
		,at.CreatedByUserId
		,at.UpdatedDate
		,at.UpdatedByUserId
		,u.UserName
		,wc.Id as weeklycalendarId
		,wc.weekOfYear
		,wc.WeekStart
		,wc.WeekEnd
	FROM dbo.agenttargets at
	inner join users u on u.Id=at.AgentId
	inner join weeklycalendar wc on wc.Id = at.WeekId
	INNER JOIN UserInfo Ui ON Ui.Id=at.CreatedByUserId
	inner join UserInfo Um ON Um.Id=at.UpdatedByUserId
	WHERE at.Id = ISNULL(@Id, at.Id) and at.WeekId= ISNULL(@WeekId,at.WeekId)
		    and at.IsActive=1
		  order by WeekId
	
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetAllFiltersData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetAllFiltersData]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 --exec SP_GetAllFiltersData null,30,null,null
 CREATE proc [dbo].[SP_GetAllFiltersData]
 (@AgentId int,@DistrictId int,@MandalId int,@VillageId int) 
 as begin DECLARE @weekid INT
 DECLARE @weekstart DATE 
 DECLARE @weekend DATE  
 select @weekid = WeekofYear, @weekstart = weekstart, @weekend = weekend from  weeklycalendar where Datediff(day,getdate(), weekstart) between 0 and 6 
 
 
 select  fc.farmercode,fc.AgentId, ag.UserName as agentName, fc.dataentryuserid, deu.UserName as dataentryusername,   
 f.VillageId, v.name as villagename, f.mandalid, m.Name as mandalname, f.DistrictId, d.Name as districtname,  
 f.TotalPlotArea as area  into #actuals  from FarmerConsent fc  left join Farmer f on fc.FarmerCode = f.FarmerCode
 left join village v on f.VillageId = v.id  left join mandal m on v.MandalId = m.Id 
 left join District d on m.DistrictId = d.id  left join Users ag on fc.AgentId = ag.Id  
 left join Users deu on fc.dataentryuserid = deu.Id  where 1=1  and
 fc.AgentId = isnull(@AgentId,fc.AgentId)  and f.VillageId= isnull(@VillageId,f.VillageId)  
 and v.MandalId= isnull(@MandalId,v.MandalId)  and m.DistrictId= isnull(@DistrictId,m.DistrictId) 
 and f.CreatedDate <= isnull(@weekend,f.CreatedDate)  
 and fc.FarmerCode like 'F_%' and fc.IsActive = 1  and fc.AgentId in (select Id from Users where RoleId = 3 and ViewYN = 1) 

select agentId, weekid, targetregistration,targetarea    into #targets  
from agenttargets  where 1=1  and AgentId = isnull(@AgentId,AgentId)  and weekid <= isnull(@weekid,weekid)  

declare @actualregistrations int
declare @actualarea decimal(18,3)
declare @targetregistrations int
declare @targetarea decimal(18,3)

select    @actualregistrations =isnull(count(1),0), @actualarea =isnull(sum(area),0)  from #actuals  
 
 select  @targetregistrations = sum(targetregistration),@targetarea = sum(targetarea)  from #targets     
 

 select @actualregistrations as actualregistrations,
 @actualarea as actualarea,@targetregistrations as targetregistrations,@targetarea as targetarea
  

 drop table #actuals 
 drop table #targets end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBorewellDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBorewellDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetBorewellDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin

select 
bwp.ID,
bwp.LogBookNo,
bwp.Date,
bwp.HoursDay,
bwp.PumpCapacity,
bwp.DepthOfBorewll ,

ld.Name as TypeOfIrrigationName,
bwp.IsActive,
bwp.CreatedDate,
bwp.CreatedByUserId,
bwp.UpdatedDate,
bwp.UpdatedByUserId from 
  BorewellPumpOperations bwp
  

  inner Join LookupDtl ld On ld.Id = bwp.TypeOfIrrigation
  
  where LogBookNo = @P_LogBookNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetBorewellPumpOperationsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetBorewellPumpOperationsDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetBorewellPumpOperationsDetails](@P_ID int)
as 
begin

select ID,LogBookNo,Date,HoursDay,PumpCapacity,
DepthOfBorewll ,
TypeOfIrrigation ,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
  BorewellPumpOperations where ID = isnull(@P_ID,ID)
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetClusterDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetClusterDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetClusterDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		cd.Id,
		cd.ClusterHDRId,
		ch.Code,
		ch.Name ClusterName,
		cd.VillageId,
		v.Name VillageName,
		v.MandalId,
		m.Name MandalName,
		m.DistrictId,
		d.Name DistrictName,
		d.StateId,
		s.Name StateName
	FROM ClusterDTL cd
	INNER JOIN  ClusterHDR ch on ch.Id = cd.ClusterHDRId
	INNER JOIN Village v on v.Id = cd.VillageId
	INNER JOIN Mandal m on m.Id = v.MandalId
	INNER JOIN District d on d.Id = m.DistrictId
	INNER JOIN States s on s.Id = d.StateId
	WHERE cd.ClusterHDRId = ISNULL(@P_Id, cd.ClusterHDRId)
			AND cd.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetClusterHDR]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetClusterHDR]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetClusterHDR] (@P_Id INT)
AS 
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[ClusterHDR]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetClusterHDRDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetClusterHDRDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetClusterHDRDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[ClusterHDR] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1 order By t.Name asc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetClusterNameByVillageId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetClusterNameByVillageId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create Proc [dbo].[SP_GetClusterNameByVillageId](@P_VillageId int)
as
begin
select Id,Code,Name from ClusterHDR where Id in
(select ClusterHDRId from ClusterDTL where VillageId=@P_VillageId)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintMasterDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintMasterDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



 CREATE PROCEDURE [dbo].[SP_GetComplaintMasterDetails]
as
begin

select * from Complaints where IsActive=1

select * from ComplaintStatusHistory where IsActive=1

select * from ComplaintRepository where IsActive=1


end
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintRepositoryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintRepositoryDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetComplaintRepositoryDetails](@P_Id int)
as 
begin

select Id,ComplaintCode,LogBookNo,ModuleTypeId,FileName,FileLocation,FileExtension,IsVideoRecording,IsResult,IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,ServerUpdatedStatus
  from 
  ComplaintRepository where Id = isnull(@P_Id,Id)
end
 
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintRepositoryDetailsByCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintRepositoryDetailsByCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetComplaintRepositoryDetailsByCode](@P_ComplaintCode varchar(60))
as 
begin

select Id,ComplaintCode,ModuleTypeId,FileName,FileLocation,FileExtension,IsVideoRecording,IsResult,IsActive,CreatedByUserId,CreatedDate,UpdatedByUserId,UpdatedDate,ServerUpdatedStatus
  from 
  [dbo].[ComplaintRepository] where ComplaintCode = @P_ComplaintCode and IsActive=1 
end
 
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintsDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetComplaintsDetails](@P_Id int)
as 
begin


SELECT 
		 c.[Id]
		, c.[Code]
		,c.LogBookNo
		,c.[ComplaintStatus] 
		,(select Name from dbo.LookupDtl where Id =c.ComplaintStatus) StatusName
		,c.[ComplaintType]
		,(select Name from dbo.LookupDtl where Id =c.ComplaintType) ComplaintName
		,c.[solution]
	    ,c.[IsActive]
		,c.[CreatedDate]
		,c.[CreatedByUserId]
		,c.[UpdatedDate]
		,c.[UpdatedByUserId]
	FROM [dbo].Complaints c
where  c.IsActive=1 and c.Id = isnull(@P_Id,c.Id) order By c.UpdatedDate desc
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintStatusHistoryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintStatusHistoryDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetComplaintStatusHistoryDetails](@P_Id int)
as 
begin

select 
ch.[Id]
,ch.[ComplaintCode]
,ch.[ComplaintTypeById]
,(select Name from dbo.LookupDtl where Id =ch.ComplaintTypeById) ComplainType
,ch.[StatusTypeId]
,(select Name from dbo.LookupDtl where Id =ch.StatusTypeId) ComplaintStatusName
,ch.[AssigntoUserId]
,(select UserName from dbo.[UserInfo] where Id =ch.AssigntoUserId) AssigntoUser
,ch.[Comments]
,ch.[IsActive]
,ch.[CreatedDate]
,ch.[CreatedByUserId]
,ch.[UpdatedDate]
,ch.[UpdatedByUserId]
  from [dbo].ComplaintStatusHistory ch where Id = isnull(@P_Id,Id)
end
 
  
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintStatusHistoryDetailsByCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintStatusHistoryDetailsByCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetComplaintStatusHistoryDetailsByCode](@P_Code varchar(60))
as 
begin

select 
ch.[Id]
,ch.[ComplaintCode]
,ch.[ComplaintTypeById]
,(select Name from dbo.LookupDtl where Id =ch.ComplaintTypeById) ComplainType
,ch.[StatusTypeId]
,(select Name from dbo.LookupDtl where Id =ch.StatusTypeId) ComplaintStatusName
,ch.[AssigntoUserId]
,(select FirstName  + LastName    from dbo.[Users] where Id =ch.AssigntoUserId) AssigntoUser
,ch.[Comments]
,ch.[IsActive]
,ch.[CreatedDate]
,ch.[CreatedByUserId]
,ch.[UpdatedDate]
,ch.[UpdatedByUserId]
  from [dbo].ComplaintStatusHistory ch where ch.ComplaintCode = isnull(@P_Code,ch.ComplaintCode)
end
 
  
GO

-- %% [markdown]
-- # [dbo].[SP_GetComplaintTransactionDetailsByIMEINO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetComplaintTransactionDetailsByIMEINO]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




create PROCEDURE [dbo].[SP_GetComplaintTransactionDetailsByIMEINO](@IMEINO varchar(255))
as
begin

select * from Complaints where IsActive=1 

select * from ComplaintStatusHistory where IsActive=1

select * from ComplaintRepository where IsActive=1

 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetCropDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCropDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[SP_GetCropDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[Season]
		
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
	FROM [dbo].[Crop] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCrops]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCrops]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetCrops] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[Season]

		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Crop]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCropVariety]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCropVariety]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetCropVariety] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[CropId]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[CropVariety]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCropVarietyDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCropVarietyDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetCropVarietyDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,p.Name as CropName
		,t.[Name] as CropVariety
		
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name as CreatedUser
		,t.[UpdatedDate]
		,u.Name as UpdatedUser
	FROM [dbo].[CropVariety] t
	
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Crop p ON p.Id=t.CropId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetCropVarietyDetailsByCropId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetCropVarietyDetailsByCropId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetCropVarietyDetailsByCropId] (@P_CropId INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.Name
		,t.CropId
		
		,t.[IsActive]
		,t.[CreatedDate]
		,t.CreatedByUserId
		,t.[UpdatedDate]
		,t.UpdatedByUserId
	FROM [dbo].[CropVariety] t
	
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN Crop p ON p.Id=t.CropId
WHERE t.CropId = ISNULL(@P_CropId, t.CropId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDashboardLogBookByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDashboardLogBookByFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetDashboardLogBookByFarmerCode '037223481398'
CREATE proc [dbo].[SP_GetDashboardLogBookByFarmerCode](@FarmerCode varchar(255))
as
begin
SELECT 
		pl.LogBookNo,
		pl.PlotNo,
		f.FarmerCode,
		f.FirstName+' '+f.MiddleName+' '+f.LastName FarmerName,
	    c.Name as CropName,
	    cv.Name as CropVariety,
	 	d.Name as SeedVariety,
	    sd.Name as SeedDistributor,
	    s.Name as Season,
	    ld.Name as CultivationPractice,
        pl.DateOfSowing,
		pl.IsActive,
		u.FirstName  as FieldExecutive,
		pl.UpdatedDate
	FROM [dbo].[LogBook] pl
	inner join Land l on l.PlotNo = pl.PlotNo
    inner join Farmer f on f.FarmerCode = l.FarmerCode
    left join Crop c on c.Id = pl.Crop
    left Join Season s on s.Id = pl.Season
    left Join LookupDtl ld on ld.Id = pl.CultivationPractice
    left Join CropVariety cv on cv.Id = pl.CropVariety
    left Join LookupDtl d on d.Id = pl.SeedVariety
    left Join SeedDistributor sd on sd.Id = pl.SeedDistributor
    inner join Users  u on u.Id = pl.CreatedByUserId
    WHERE  f.FarmerCode = @FarmerCode
and f.IsActive = 1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDataEntryUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDataEntryUsers]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetDataEntryUsers null
CREATE proc [dbo].[SP_GetDataEntryUsers](@date date)
as
begin

if @date is null
begin
select X.*,u.UserName from
(select count(fc.FarmerCode) cnt,fc.DataEntryUserId,cast(fc.CreatedDate as date) Date
from FarmerConsent fc
where fc.DataEntryUserId is not null and cast(fc.CreatedDate as date)>= cast(dateadd(DD,-7,getdate()) as date)
group by fc.DataEntryUserId,cast(fc.CreatedDate as date))X
left join Users u on u.Id = x.DataEntryUserId
order by Date desc
end
else
begin
select X.*,u.UserName from
(select count(fc.FarmerCode) cnt,fc.DataEntryUserId,cast(fc.CreatedDate as date) Date
from FarmerConsent fc
where fc.DataEntryUserId is not null and cast(fc.CreatedDate as date) = cast(@date as date)
group by fc.DataEntryUserId,cast(fc.CreatedDate as date))X
left join Users u on u.Id = x.DataEntryUserId
order by Date desc
end
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDataEntryUsersByDates]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDataEntryUsersByDates]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetDataEntryUsersByDates null,null
CREATE proc [dbo].[SP_GetDataEntryUsersByDates](@FromDate date,@ToDate date)
as

begin

select fc.DataEntryUserId,u.UserName, count(fc.FarmerCode) cnt
from FarmerConsent fc left join Users u on u.Id = fc.DataEntryUserId
where 1=1 
and fc.DataEntryUserId is not null 
and cast(fc.CreatedDate as date) between cast(isnull(@FromDate,fc.CreatedDate) as date) and cast(isnull(@ToDate,fc.CreatedDate) as date)
group by fc.DataEntryUserId,u.UserName

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetDataToBlockchain]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDataToBlockchain]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDataToBlockchain 'TSVBAD183018_005'
CREATE Proc [dbo].[SP_GetDataToBlockchain](@PlotNo varchar(50))
as
begin
--select f.FarmerCode,f.FirstName+' '+f.LastName FarmerName,f.Gender,f.Age,f.PrimaryContactNum,d.Name DistrictName,
--s.Name StateName,m.Name MandalName,v.Name VillageName into #Farmer
--from Farmer f
--inner join States s on s.Id = f.StateId
--inner join District d on d.Id = f.DistrictId
--inner join Mandal m on m.Id = f.MandalId
--inner join Village v on v.Id = f.VillageId
--where f.FarmerCode=@FarmerCode 
--and f.IsActive=1

--select lb.PlotNo,lb.DateOfSowing,c.Name CropName,cv.Name CropVarietyName,sd.Name SeedDistributorName,
--ludsv.Name SeedVarietyName,ludcp.Name CultivationPracticeName
--from LogBook lb 
--inner join Crop c on c.Id = lb.Crop
--inner join CropVariety cv on cv.Id = lb.CropVariety
--inner join SeedDistributor sd on sd.Id = lb.SeedDistributor
--inner join LookupDtl ludsv on ludsv.Id = lb.SeedVariety
--inner join LookupDtl ludcp on ludcp.Id = lb.CultivationPractice
--where lb.PlotNo in (select PlotNo from Land where FarmerCode=@FarmerCode and IsActive=1)

--select 
--(select l.PlotNo,c.Name CropName,l.Size,l.PattadarBookNo,l.GPSPlotArea,l.Cluster,
--l.Latitude,l.Longitude,l.Plotownership,l.SurveyNo,d.Name DistrictName,
--s.Name StateName,m.Name MandalName,v.Name VillageName  from Land l
--inner join Crop c on c.Id = l.CropId
--inner join States s on s.Id = l.StateId
--inner join District d on d.Id = l.DistrictId
--inner join Mandal m on m.Id = l.MandalId
--inner join Village v on v.Id = l.VillageId
--where l.FarmerCode=@FarmerCode and l.IsActive=1 FOR JSON PATH) as Plots,@FarmerCode FarmerCode into #Plots

--select f.*,p.Plots from #Farmer f
--inner join #Plots p on f.FarmerCode = p.FarmerCode

--drop table #Farmer
--drop table #Plots


select f.FarmerCode,f.FirstName+' '+f.LastName FarmerName,f.Gender,f.Age,f.PrimaryContactNum,l.PlotNo,c.Name CropName,l.Size,l.PattadarBookNo,l.GPSPlotArea,l.Cluster,
l.Latitude,l.Longitude,l.Plotownership,l.SurveyNo,d.Name DistrictName,
s.Name StateName,m.Name MandalName,v.Name VillageName into #Plot  from Land l
inner join Crop c on c.Id = l.CropId
inner join States s on s.Id = l.StateId
inner join District d on d.Id = l.DistrictId
inner join Mandal m on m.Id = l.MandalId
inner join Village v on v.Id = l.VillageId
inner join Farmer f on f.FarmerCode = l.FarmerCode
where l.PlotNo=@PlotNo and l.IsActive=1 

declare @logbookno varchar(100)
set @logbookno =(select LogBookNo from LogBook where PlotNo=@PlotNo)

 select 
(select f.Fertilizer,lud.Name FertilizerType,f.Date,f.Qty,f.CropProtection,luduom.Name UOM from Fertilizer f 
inner join  LookupDtl lud on lud.Id = f.FertilizerType
inner join  LookupDtl luduom on luduom.Id = f.UOM
where f.LogBookNo=@logbookno  FOR JSON PATH) as Fertilizer,@PlotNo PlotNo into #Fertilizer

 select
(select oa.Value,oa.Date from OrganicAmendments oa 
where oa.LogBookNo=@logbookno  FOR JSON PATH) as OrganicAmendments,@PlotNo PlotNo into #OrganicAmendments

select
(select wrs.Field,wrs.CreatedDate from WaterRegimeonSeason wrs 
where wrs.LogBookNo=@logbookno  FOR JSON PATH) as WaterRegimeonSeason,@PlotNo PlotNo into #WaterRegimeonSeason

select
(select wrps.Field,wrps.CreatedDate from WaterReasonPreSeason wrps
where wrps.LogBookNo=@logbookno FOR JSON PATH) as WaterReasonPreSeason,@PlotNo PlotNo into #WaterReasonPreSeason

select
(select wrf.Field,wrf.CreatedDate from WaterRegimeOnthefield  wrf
where wrf.LogBookNo=@logbookno FOR JSON PATH) as WaterRegimeOnthefield,@PlotNo PlotNo into #WaterRegimeOnthefield

select
(select bpo.DepthOfBorewll,bpo.Date,bpo.HoursDay,bpo.PumpCapacity,lud.Name TypeOfIrrigation
from BorewellPumpOperations bpo
inner join LookupDtl lud on lud.Id =bpo.TypeOfIrrigation
where bpo.LogBookNo=@logbookno FOR JSON PATH) as BorewellPumpOperations,@PlotNo PlotNo into #BorewellPumpOperations

select
(select h.Date,h.YeildQty from HarvestDetails h 
where h.LogBookNo=@logbookno FOR JSON PATH) as HarvestDetails,@PlotNo PlotNo into #HarvestDetails

select
(select lb.PlotNo,lb.LogBookNo,lb.DateOfSowing,c.Name CropName,cv.Name CropVarietyName,sd.Name SeedDistributorName,
ludsv.Name SeedVarietyName,ludcp.Name CultivationPracticeName,
f.Fertilizer,oa.OrganicAmendments,wrs.WaterRegimeonSeason,wrps.WaterReasonPreSeason,bpo.BorewellPumpOperations
,h.HarvestDetails from LogBook lb
inner join #Fertilizer f on f.PlotNo = lb.PlotNo
inner join #OrganicAmendments oa on oa.PlotNo =lb.PlotNo
inner join #WaterRegimeonSeason wrs on wrs.PlotNo = lb.PlotNo
inner join #WaterReasonPreSeason wrps on wrps.PlotNo =lb.PlotNo
inner join #BorewellPumpOperations bpo on bpo.PlotNo = lb.PlotNo
inner join #HarvestDetails h on h.PlotNo =lb.PlotNo
inner join Crop c on c.Id = lb.Crop
inner join CropVariety cv on cv.Id = lb.CropVariety
inner join SeedDistributor sd on sd.Id = lb.SeedDistributor
inner join LookupDtl ludsv on ludsv.Id = lb.SeedVariety
inner join LookupDtl ludcp on ludcp.Id = lb.CultivationPractice
where lb.PlotNo in (select PlotNo from Land where PlotNo=@PlotNo and IsActive=1) FOR JSON PATH) as LogBook,@PlotNo PlotNo into #LogBook

select p.*,lb.LogBook from #Plot p 
inner join #LogBook lb on lb.PlotNo = p.PlotNo

drop table #Fertilizer
drop table #OrganicAmendments
drop table #WaterRegimeonSeason
drop table #WaterReasonPreSeason
drop table #WaterRegimeOnthefield
drop table #BorewellPumpOperations
drop table #HarvestDetails
drop table #LogBook
drop table #Plot
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDetailsByLogbookPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDetailsByLogbookPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 create procedure [dbo].[SP_GetDetailsByLogbookPlotNo](
 @P_PlotNo varchar(255)
 
 )
 as
 begin
 select * from Land where PlotNo=@P_PlotNo
select * from Farmer where FarmerCode in (select FarmerCode from Land where PlotNo=@P_PlotNo)

 end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDetailsByPincode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDetailsByPincode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetDetailsByPincode] (@P_PinCode Varchar(255))
as
begin
select V.Name VillageName,V.Id VillageId,V.MandalId,M.Name MandalName,M.DistrictId,D.Name DistrictName
,D.StateId,S.Name StateName
from Village V
left join
Mandal M on M.Id = V.MandalId
left join
District D on D.Id = M.DistrictId
left join 
States S on S.Id = D.StateId
where V.PinCode=@P_PinCode
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistictClusterdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistictClusterdetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create PROCEDURE [dbo].[SP_GetDistictClusterdetails] (@P_Cluster varchar(50))
AS 
BEGIN
    
	select DISTINCT Cluster from land 
	
	WHERE Cluster = ISNULL(@P_Cluster, Cluster)
		AND IsActive = 1  
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictByAgent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictByAgent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetDistrictByAgent null
CREATE proc [dbo].[SP_GetDistrictByAgent](@AgentId int)
as
begin

if @AgentId is not null
begin
select Id,Name,1 as cnt from District where Id in(
select distinct(DistrictId) from Farmer where CreatedByUserId = @AgentId and DistrictId !=0)
end
else
begin
select * from
(select d.Id,d.Name,case when fd.DistrictId is null then 0 else 1 end cnt from District d
left join 
(select distinct(DistrictId) from Farmer where DistrictId !=0 and IsActive =1) fd on fd.DistrictId = d.Id
where d.IsActive=1)x order by x.cnt desc
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictByStateId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictByStateId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetDistrictByStateId] (@P_Id INT)
AS
BEGIN
		SELECT d.Id
		,d.[Code]
		,d.[Name]
		,d.[StateId]
		,z.Name As StateName
		,d.[IsActive]
		,d.[CreatedDate]
		,c.Name AS CreatedByUser
		,d.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM dbo.District d 
		INNER JOIN UserInfo c ON c.Id=d.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=d.UpdatedByUserId
	INNER JOIN States z ON z.Id=d.StateId
	WHERE d.[StateId] = ISNULL(@P_Id, d.Id)
		AND d.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE   PROCEDURE [dbo].[SP_GetDistrictDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[StateId]
		,s.name as StateName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[District] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	INNER JOIN dbo.States s ON s.Id = t.StateId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1 order by t.Name asc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetDistrictWiseTreeViewData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDistrictWiseTreeViewData]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetDistrictWiseTreeViewData]
as
begin
select * from (

select

d.name as districtname, count(fc.FarmerCode) over (partition by d.name) actualDistrictRegs, sum(f.TotalPlotArea) over (partition by d.name) as totalDistrictPlotArea

,m.name as mandalname, count(fc.FarmerCode) over (partition by d.name,m.name) actualMandalRegs, sum(f.TotalPlotArea) over (partition by d.name,m.name) as totalMandalPlotArea

, v.name as villagename, count(fc.FarmerCode) over (partition by d.name,m.name,v.name) actualVillageRegs,sum(f.TotalPlotArea) over (partition by d.name,m.name,v.name) as totalVillagePlotArea

, u.username as agentname ,count(fc.FarmerCode) over (partition by d.name,m.name,v.name,u.username) actualRegs,sum(f.TotalPlotArea) over (partition by d.name,m.name,v.name,u.username) as totalPlotArea

from FarmerConsent fc

left join Farmer f on fc.FarmerCode = f.FarmerCode

left join village v on f.villageid = v.id

left join mandal m on v.MandalId = m.id

left join District d on m.DistrictId = d.id

left join Users u on fc.AgentId =u.id and u.ViewYN = 1 and RoleId = 3

where 1=1

and v.name is not null

and u.id not in (55,59,48)

and fc.FarmerCode like 'F_%'

--and v.name in ('Golagudem','Alair')

)a

group by a.districtname,a.actualDistrictRegs,a.mandalname,a.actualMandalRegs,a.villagename,a.actualVillageRegs,a.agentname,a.actualRegs,a.totalDistrictPlotArea,a.totalMandalPlotArea,a.totalVillagePlotArea,a.totalPlotArea

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDocumentsByCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDocumentsByCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE Proc [dbo].[SP_GetDocumentsByCode](@P_Type varchar(255),@P_Code varchar(255))
as 
begin

 if @P_Type = 'Farmer'
 begin
   select * from Documents where FarmerCode=@P_Code and IsActive=1
 end
 else if @P_Type = 'Land'
 begin
 select * from Documents where PlotNo=@P_Code and IsActive=1
 end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetDocumentsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetDocumentsByFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE Proc [dbo].[SP_GetDocumentsByFarmerCode](@P_Code varchar(255))
as 
begin

 
   select * from Documents where FarmerCode=@P_Code and IsActive=1 and DocType='photo'
 
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerBankDetailsByCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerBankDetailsByCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_GetFarmerBankDetailsByCode](@P_Code varchar(255))
as
begin
select * from FarmerBank where FarmerCode=@P_Code and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerCheckListByAgent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerCheckListByAgent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec  [SP_GetFarmerCheckListByAgent] null,null
CREATE proc [dbo].[SP_GetFarmerCheckListByAgent](@AgentId int,@DistrictId int)
as
begin
-- 1 means images are taken
-- 0 means images are not taken
select  *  into #Temp from
(select f.FarmerCode,f.FirstName +' '+f.LastName as FirstName,isnull(p.cnt,0) NoOfPlots,case when fclb.cnt>0 then 1 else 0 end FarmerLogBook,
case when fp.FarmerCode is not null then 1 else 0 end FarmerPhotoTaken,
case when fip.FarmerCode is not null then 1 else 0 end FarmerIdentityProofTaken,
case when fbp.FarmerCode is not null then 1 else 0 end FarmerBankPassbookTaken,
case when p.FarmerCode is not null then 1 else 0 end PlotTaken,
case when pp.FarmerCode is not null then 1 else 0 end PlotPhotoTaken,
case when pin.FarmerCode is not null then 1 else 0 end PipeInstallationTaken,
u.FirstName  as Agent 
from [dbo].[vw_farmer] f
left join [dbo].[Users] u on u.Id = f.CreatedByUserId
left join [dbo].[vw_farmerphoto] fp on fp.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmeridentityproof] fip on fip.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmerbankpassbook] fbp on fbp.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmerlogbook] fclb on fclb.FarmerCode = f.FarmerCode
left join (select FarmerCode,count(FarmerCode) cnt from [dbo].[vw_plot] group by FarmerCode)p on p.FarmerCode = f.FarmerCode
left join (select FarmerCode,count(FarmerCode) cnt from [dbo].[vw_plotphoto] group by FarmerCode) pp on pp.FarmerCode = f.FarmerCode
left join [dbo].[vw_pipeinstalled] pin on pin.FarmerCode = f.FarmerCode
where f.CreatedByUserId = isnull(@AgentId,f.CreatedByUserId)
and f.DistrictId = ISNULL(@DistrictId,f.DistrictId)
) X

select ROW_NUMBER() over(Order by FarmerCOde) RowId,* into #fullkyc from #Temp where NoOfPlots>0 and FarmerPhotoTaken=1 and FarmerIdentityProofTaken =1 and
FarmerBankPassbookTaken = 1 and PlotPhotoTaken=1 and PipeInstallationTaken =1 and FarmerLogBook =1

select (select count(FarmerCode) from #fullkyc)+ROW_NUMBER() over(Order by FarmerCOde) RowId,* into #notkyc from #Temp where FarmerCode not in (select FarmerCode from #fullkyc)

select top 110 * from
(select * from #fullkyc
union
select * from #notkyc)X order by X.RowId

drop table #Temp
drop table #fullkyc
drop table #notkyc
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerConsentDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerConsentDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--- exec SP_GetFarmerConsentDetails null
CREATE   PROCEDURE [dbo].[SP_GetFarmerConsentDetails] (@P_Id varchar(255))
AS
BEGIN

IF OBJECT_ID('tempdb..#TempFarmer') IS NOT NULL DROP TABLE #TempFarmer
select * into #TempFarmer from Farmer where FarmerCode = isnull(@P_Id,FarmerCode) and IsActive =1

select f.Id,f.FarmerCode,f.FarmerTitle,f.FirstName,f.LastName,f.FatherName,f.Gender,f.Age,f.PrimaryContactNum
,f.StateId,f.DistrictId,f.MandalId,f.VillageId,f.PinCode,f.TotalPlotArea,f.CreatedByUserId,f.CreatedDate,
S.Name StateName,D.Name DistrictName,M.Name MandalName,V.Name VillageName,c.UserName as AgentName
,fb.AccountNumber,fb.IFSCCode,l.PattadarBookNo,l.SurveyNo,docaadhar.DocOldNum as AadhaarNo,
docphoto.DocUrl as FarmerPhoto,docaadhar.DocUrl as FarmerAadhar,docpattadar.DocUrl as FarmerPattadarBook
,docbank.DocUrl as FarmerBankPassbook,docfarmerconsent.DocUrl as FarmerConsent
,fc.AgreementDate,
case when (fc.[1_1_a] =  0 or fc.[1_1_a] is null) then 'No' else 'Yes' end  one_1_a
,case when (fc.[1_1_b] = 0 or fc.[1_1_b] is null) then 'No' else 'Yes' end one_1_b
,case when (fc.[1_1_c] = 0 or fc.[1_1_c] is null) then 'No' else 'Yes' end one_1_c
,case when (fc.[1_1_d] = 0 or fc.[1_1_d] is null) then 'No' else 'Yes' end one_1_d
,case when (fc.[1_1_e] = 0 or fc.[1_1_e] is null) then 'No' else 'Yes' end one_1_e
,case when (fc.[1_2_a] = 0 or fc.[1_2_a] is null) then 'No' else 'Yes' end one_2_a
,case when (fc.[1_2_b] = 0 or fc.[1_2_b] is null) then 'No' else 'Yes' end one_2_b
,case when (fc.[1_2_c] = 0 or fc.[1_2_c] is null) then 'No' else 'Yes' end one_2_c
from #TempFarmer f 
left JOIN UserInfo c ON c.Id=f.CreatedByUserId
left join States S on S.Id = f.StateId 
left join District D on D.Id = f.DistrictId
left join Mandal M on M.Id = f.MandalId
left join Village V on V.Id = f.VillageId
left join FarmerBank fb on fb.FarmerCode = f.FarmerCode  and fb.IsActive = 1
left join (select FarmerCode,string_agg(PattadarBookNo,'$') AS PattadarBookNo,string_agg(SurveyNo,'$') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='photo' ) docphoto on docphoto.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='aadhar card' ) docaadhar on docaadhar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Pattadar Book' ) docpattadar on docpattadar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='bank passbook' ) docbank on docbank.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Agreement' ) docfarmerconsent on docfarmerconsent.FarmerCode = f.FarmerCode
left join FarmerConsent fc on fc.FarmerCode = f.FarmerCode and fc.IsActive =1

drop table #TempFarmer


	--SELECT 
	--	 t.[Id]
	--	,t.FarmerCode
	--	,t.FarmerTitle
	--	,t.[FirstName]
	--	,t.MiddleName
	--	,t.[LastName]
	--	,t.[FatherName]
	--	,t.Gender
	--	,t.Age
	--	,t.[PrimaryContactNum]
	--	,t.SecondaryContactNum
	--	,t.[Address]
	--	,t.Sync
	--	,t.IsPlot
	--	,t.DistrictId
	--	,D.Name DistrictName
	--	,t.MandalId
	--	,M.Name MandalName
	--	,t.[StateId]
	--	,S.Name StateName
	--	,t.[VillageId]
	--	,V.Name VillageName
	--	,t.[PinCode]
	--	,t.[IsActive]
	--	,c.Name AS CreatedByUser
	--	,t.[CreatedDate]
	--	,u.Name AS UpdatedByUser
	--	,t.[UpdatedDate]
	--	,t.TotalPlotArea
	--	,t.PlotsCount 
	--	,fc.AgreementDate
	--	,fc.Base64 as FingerprintImg
	--	,case when fc.[1_1_a] = 0 then 'No' else 'Yes' end  one_1_a
	--	,case when fc.[1_1_b] = 0 then 'No' else 'Yes' end one_1_b
	--	,case when fc.[1_1_c] = 0 then 'No' else 'Yes' end one_1_c
	--	,case when fc.[1_1_d] = 0 then 'No' else 'Yes' end one_1_d
	--	,case when fc.[1_1_e] = 0 then 'No' else 'Yes' end one_1_e
	--	,case when fc.[1_2_a] = 0 then 'No' else 'Yes' end one_2_a
	--	,case when fc.[1_2_b] = 0 then 'No' else 'Yes' end one_2_b
	--	,case when fc.[1_2_c] = 0 then 'No' else 'Yes' end one_2_c
	--	,docphoto.DocUrl as FarmerPhoto
	--	,docaadhar.DocUrl as FarmerAadhar
	--	,docpattadar.DocUrl as FarmerPassbook
	--	,docaadhar.DocOldNum as AadhaarNo
	--	,docbank.DocUrl as FarmerBankpassbook
	--	,ld.PattadarBookNo
	--	,fb.AccountNumber as KathaNo
	--	,ld.SurveyNo
	--FROM [dbo].[Farmer] t
	--left JOIN UserInfo c ON c.Id=t.CreatedByUserId
	--left JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	--left join District D on D.Id = t.DistrictId
	--left join Mandal M on M.Id = t.MandalId
	--left join Village V on V.Id = t.VillageId
	--left join States S on S.Id = t.StateId  
	--left join Land ld on ld.FarmerCode = t.FarmerCode
	--left join FarmerBank fb on fb.FarmerCode = t.FarmerCode
	--left join(select * from Documents where DocType='photo' ) docphoto on docphoto.FarmerCode = t.FarmerCode
	--left join(select * from Documents where DocType='aadhar card' ) docaadhar on docaadhar.FarmerCode = t.FarmerCode
	--left join(select * from Documents where DocType='Pattadar Book' ) docpattadar on docpattadar.FarmerCode = t.FarmerCode
 --   left join(select * from Documents where DocType='bank passbook' ) docbank on docbank.FarmerCode = t.FarmerCode
 --   inner join FarmerConsent fc on fc.FarmerCode = t. FarmerCode
	--WHERE t.FarmerCode = ISNULL(@P_Id, t.FarmerCode)
	--	AND t.IsActive = 1 and fc.IsActive =1 order By t.CreatedDate desc

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerData]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
 --exec SP_GetFarmerData '03722265049'
CREATE proc [dbo].[SP_GetFarmerData](@P_Code varchar(255))
as
begin

select top 1  t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate],isnull(t.DocUrl,'https://etgdocstorage.s3.ap-south-1.amazonaws.com/sowandreap_images/sowandreap.png') DocUrl from
(select X.*,Y.DocUrl,Y.DocType from 
(select * from Farmer) X
left join
(select * from Documents where DocType='photo' and IsActive=1)Y on X.FarmerCode = Y.FarmerCode
where X.FarmerCode=@P_Code) t
INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
where t.FarmerCode=@P_Code and t.IsActive =1

--select top 1  t.[Id]
--		,t.FarmerCode
--		,t.FarmerTitle
--		,t.[FirstName]
--		,t.MiddleName
--		,t.[LastName]
--		,t.[FatherName]
--		,t.Gender
--		,t.Age
--		,t.[PrimaryContactNum]
--		,t.SecondaryContactNum
--		,t.[Address]
--		,t.Sync
--		,t.IsPlot
--		,t.DistrictId
--		,D.Name DistrictName
--		,t.MandalId
--		,M.Name MandalName
--		,t.[StateId]
--		,S.Name StateName
--		,t.[VillageId]
--		,V.Name VillageName
--		,t.[PinCode]
--		,t.[IsActive]
--		,c.Name AS CreatedByUser
--		,t.[CreatedDate]
--		,u.Name AS UpdatedByUser
--		,t.[UpdatedDate],ds.DocUrl
--		from Farmer t
--left join Documents ds on ds.FarmerCode=t.FarmerCode
--INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
--	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
--	inner join District D on D.Id = t.DistrictId
--	inner join Mandal M on M.Id = t.MandalId
--	inner join Village V on V.Id = t.VillageId
--	inner join States S on S.Id = t.StateId 
--where t.FarmerCode=@P_Code and ds.DocType='photo'

select top 1 * from Documents where FarmerCode=@P_Code  and 
DocType in ('aadhar card','voter id','driving licence','pan card') and IsActive=1

select top 1 fb.*,d.DocUrl,d.DocExtension from FarmerBank fb
left join Documents d on d.FarmerCode=fb.FarmerCode
where fb.FarmerCode=@P_Code  and d.DocType='bank passbook' and d.IsActive=1
--and d.IdentityCode=fb.IdentityCode


select   
  t.[Id] 
  ,t.[PlotNo]    
  ,t.[Size]  
  ,t.Plotownership
  ,t.LandMark
  ,t.[CropId]    
  ,cr.Name    
  ,t.[FarmerCode]    
  ,f.FirstName   
  ,f.MiddleName
  ,f.LastName    
  ,f.Address as FarmerAddress    
  ,f.PrimaryContactNum
  ,f.SecondaryContactNum
  ,f.FarmerTitle
  ,f.Gender
  ,f.Age 
  ,f.FatherName         
  ,t.[Latitude]    
  ,t.[Longitude]    
  ,t.[Address]    
  ,t.[IsActive]    
  ,t.Cluster
  ,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.StateId
		,S.Name StateName
		,t.VillageId
		,V.Name VillageName
		,t.PinCode
  ,t.SurveyNo
  ,t.PattadarBookNo
  ,t.Sync
  ,t.GPS
  ,t.GPSPlotArea
    ,dt.DocUrl
	,t.LandImage
 -- ,t.[CreatedDate]    
  --,c.Name AS CreatedByUserId    
  --,t.[UpdatedDate]    
  --,u.Name AS UpdatedByUserId
from Land t
LEFT JOIN UserInfo c ON c.Id=t.CreatedByUserId    
 LEFT JOIN UserInfo u ON u.Id=t.UpdatedByUserId    
 LEFT JOIN Crop cr on cr.Id =t.CropId    
 LEFT JOIN Farmer f on f.FarmerCode = t.FarmerCode  
 LEFT join District D on D.Id = t.DistrictId
	LEFT join Mandal M on M.Id = t.MandalId
	LEFT join Village V on V.Id = t.VillageId
	LEFT join States S on S.Id = t.StateId 
		left join Documents dt on dt.PlotNo=t.PlotNo and dt.DocType='photo'
where t.FarmerCode = @P_Code and t.IsActive=1


SELECT 
		sh.[ID]
		,L.PlotNo as PlotNo
		,sh.[SampleNo]
		,sh.[SampleCollectionDate]
		,c.Name as SoilColour
		,u.Name as SoilNature
		,sh.[PH]
		,sh.[ElectricalConductivity]
		,sh.[OrganicCarbon]
		,sh.[Nitrogen]
		,sh.[Phosphorous]
		,sh.[Potassium ]
		,sh.[Sulphur]
		,sh.[Zinc]
		,sh.[Iron]
		,sh.[Manganese]
		,sh.[Copper]
		,sh.[Boron]
        ,sh.[IsActive]
		,sh.[CreatedDate]
		,sh.[CreatedByUserId]
		,sh.[UpdatedDate]
		,sh.[UpdatedByUserId]
		
	FROM [dbo].[SoilHealthCard] sh
	 Inner JOIN LookupDtl c ON c.Id=sh.SoilColour   
 INNER JOIN LookupDtl u ON u.Id=sh.SoilNature
 Inner Join Land L On L.PlotNo = sh.PlotNo
	
	where L.FarmerCode = @P_Code and sh.IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDataByAgent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDataByAgent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetFarmerDataByAgent 53             
CREATE Proc [dbo].[SP_GetFarmerDataByAgent](@AgentId int)
as
begin
IF OBJECT_ID('tempdb..#TempFarmer') IS NOT NULL DROP TABLE #TempFarmer
IF OBJECT_ID('tempdb..#TempPlot') IS NOT NULL DROP TABLE #TempPlot
select * into #TempFarmer from Farmer where CreatedByUserId = @AgentId and IsActive =1

select ROW_NUMBER() over(partition by FarmerCode order by FarmerCode) SNo,* into #TempPlot from Land where IsActive =1 and FarmerCode in (
select FarmerCode from #TempFarmer)

select f.Id,f.FarmerCode,tp.PlotNo,f.FarmerTitle,f.FirstName,f.LastName,f.FatherName,f.Gender,f.Age,f.PrimaryContactNum
,f.StateId,f.DistrictId,f.MandalId,f.VillageId,f.PinCode,f.Address,f.TotalPlotArea,f.CreatedByUserId,f.CreatedDate,
S.Name StateName,D.Name DistrictName,M.Name MandalName,V.Name VillageName,c.UserName as AgentName
,fb.AccountNumber,fb.IFSCCode,l.PattadarBookNo,l.SurveyNo,f.IdentityCode as AadhaarNo,
docphoto.DocUrl as FarmerPhoto,docaadhar.DocUrl as FarmerAadhar,docpattadar.DocUrl as FarmerPattadarBook
,docbank.DocUrl as FarmerBankPassbook,docfarmerconsent.DocUrl as FarmerConsent
,fc.AgreementDate,
 case when (fc.[1_1_a] =  0 or fc.[1_1_a] is null) then 0 else 1 end  one_1_a
,case when (fc.[1_1_b] = 0 or fc.[1_1_b] is null) then 0 else 1 end one_1_b
,case when (fc.[1_1_c] = 0 or fc.[1_1_c] is null) then 0 else 1 end one_1_c
,case when (fc.[1_1_d] = 0 or fc.[1_1_d] is null) then 0 else 1 end one_1_d
,case when (fc.[1_1_e] = 0 or fc.[1_1_e] is null) then 0 else 1 end one_1_e
,case when (fc.[1_2_a] = 0 or fc.[1_2_a] is null) then 0 else 1 end one_2_a
,case when (fc.[1_2_b] = 0 or fc.[1_2_b] is null) then 0 else 1 end one_2_b
,case when (fc.[1_2_c] = 0 or fc.[1_2_c] is null) then 0 else 1 end one_2_c
from #TempFarmer f 
left JOIN UserInfo c ON c.Id=f.CreatedByUserId
left join States S on S.Id = f.StateId 
left join District D on D.Id = f.DistrictId
left join Mandal M on M.Id = f.MandalId
left join Village V on V.Id = f.VillageId
left join #TempPlot tp on tp.FarmerCode = f.FarmerCode and tp.SNo = 1
left join FarmerBank fb on fb.FarmerCode = f.FarmerCode  and fb.IsActive = 1
left join (select FarmerCode,string_agg(PattadarBookNo,'$') AS PattadarBookNo,string_agg(SurveyNo,'$') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='photo' ) docphoto on docphoto.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='aadhar card' ) docaadhar on docaadhar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Pattadar Book' ) docpattadar on docpattadar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='bank passbook' ) docbank on docbank.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Agreement' ) docfarmerconsent on docfarmerconsent.FarmerCode = f.FarmerCode
left join FarmerConsent fc on fc.FarmerCode = f.FarmerCode and fc.IsActive =1 order by f.CreatedDate desc

drop table #TempFarmer
drop table #TempPlot
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE   PROCEDURE [dbo].[SP_GetFarmerDetails] (@P_Id varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
	WHERE t.FarmerCode = ISNULL(@P_Id, t.FarmerCode)
		AND t.IsActive = 1 order By t.CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsbyclusterName]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsbyclusterName]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerDetailsbyclusterName 'Adilabad (Rural)'

CREATE   PROCEDURE [dbo].[SP_GetFarmerDetailsbyclusterName] (@P_cluster VarChar(100))
AS
BEGIN
	
	if @P_cluster !=0
	begin

	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
		,l.Cluster
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
	left join Land l on l.FarmerCode=t.FarmerCode
	WHERE l.Cluster = isnull(@P_cluster,l.cluster)
		AND t.IsActive = 1 order By t.CreatedDate desc
	
		select COUNT(f.FarmerCode) as NoOFfarmer,cast(SUM(TotalPlotArea) as decimal(18,3))
		TotalPlotArea from Farmer f
		left join Land l on l.FarmerCode = f.FarmerCode
		where l.Cluster=@P_Cluster and f.IsActive=1 group by f.MandalId
	 
	end
	else
	begin

	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId
	where t.IsActive = 1 order By t.CreatedDate desc
	
	select COUNT(FarmerCode) as NoOFfarmer,cast(SUM(TotalPlotArea) as decimal(18,3))
	TotalPlotArea from Farmer where IsActive=1
	end

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsByDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsByDate]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetFarmerDetailsByDate] (@FromDate date,@ToDate date)
AS
BEGIN
		SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
	

	WHERE cast(t.CreatedDate as Date)>=@FromDate
and cast(t.CreatedDate as Date)<=@ToDate
and t.IsActive = 1 order by CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsbydistrict]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsbydistrict]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerDetailsbydistrict 0
CREATE   PROCEDURE [dbo].[SP_GetFarmerDetailsbydistrict] (@P_districtId int)
AS
BEGIN
	
	if @P_districtId !=0
	begin

	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
	WHERE t.DistrictId = isnull(@P_districtId,t.DistrictId)
		AND t.IsActive = 1 order By t.CreatedDate desc
	
		select COUNT(FarmerCode) as NoOFfarmer,cast(SUM(TotalPlotArea) as decimal(18,3))
		TotalPlotArea from Farmer where DistrictId=@P_districtId and IsActive=1 group by DistrictId
	end
	else
	begin

	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId
	where t.IsActive = 1 order By t.CreatedDate desc
	
	select COUNT(FarmerCode) as NoOFfarmer,cast(SUM(TotalPlotArea) as decimal(18,3))
	TotalPlotArea from Farmer where IsActive=1
	end

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerDetailsbyUserID]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerDetailsbyUserID]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerDetailsbyUserID 29

CREATE   PROCEDURE [dbo].[SP_GetFarmerDetailsbyUserID] (@P_userId int)
AS
BEGIN
	
	if @P_userId !=0
	begin

	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
		
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
	
	WHERE t.CreatedByUserId = isnull(@P_userId,t.CreatedByUserId)
		AND t.IsActive = 1 order By t.CreatedDate desc
	
		select COUNT(f.FarmerCode) as NoOFfarmer,cast(SUM(TotalPlotArea) as decimal(18,3))
		TotalPlotArea from Farmer f
		
		where f.CreatedByUserId= @P_userId and f.IsActive=1 group by f.CreatedByUserId
	
	end
	else
	begin

	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
		,t.LocalImage
		,t.Sync
		,t.IsPlot
		,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.[StateId]
		,S.Name StateName
		,t.[VillageId]
		,V.Name VillageName
		,t.[PinCode]
		,t.[IsActive]
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId
	where t.IsActive = 1 order By t.CreatedDate desc
	
	select COUNT(FarmerCode) as NoOFfarmer,cast(SUM(TotalPlotArea) as decimal(18,3))
	TotalPlotArea from Farmer where IsActive=1
	end

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerFullDetailsByAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerFullDetailsByAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerFullDetailsByAgentId 37
CREATE proc [dbo].[SP_GetFarmerFullDetailsByAgentId](@AgentId int)
as
begin

   select l.PlotNo,l.Size,l.Latitude,l.Longitude,l.PattadarBookNo,l.SurveyNo,f.FarmerCode,f.FirstName +' '+f.LastName FarmerName
   ,d.Name as DistrictName,m.Name as MandalName,v.Name as VillageName,u.UserName as AgentName
   ,case when doc.DocUrl is not null then doc.DocUrl else 'No' end PipeInstallationTaken
   ,case when gb.cntPlotNo is not null then gb.cntPlotNo else 0 end GeoBoundariesTaken
   ,case when gb.cntPlotNo is not null then dbo.FN_GenerateKMLFileByPlotNo(l.PlotNo) else 'No' end KMLFile
   ,case when l.Latitude is not null and l.Longitude is not null then 'Yes' else 'No' end as GPSPointTaken
   ,doc.CreatedDate docCreatedDate,f.AgentId,f.TotalPlotArea,
   l.GPSPlotArea,l.PlotArea1,l.PlotArea2,l.PlotArea3,l.PlotArea4,l.PlotArea5,doc.CreatedDate as PipeInstalledDate,
   isnull(w1.cntw1,0) cntw1,isnull(w2.cntw2,0) cntw2,isnull(w3.cntw3,0) cntw3,w1.W1Date,w2.W2Date,w3.W3Date
   from Land l 
   left join Farmer f on f.FarmerCode = l.FarmerCode
   left join District d on d.Id = l.DistrictId
   left join Mandal m on m.Id = l.MandalId
   left join Village v on v.Id = l.VillageId
   left join Users u on u.Id = l.CreatedByUserId
   left join Documents doc on doc.FarmerCode = f.FarmerCode and doc.DocType='pipe installation' and doc.IsActive=1
   left join (select count(PlotNo) cntPlotNo,PlotNo from GeoBoundaries group by PlotNo) gb on gb.PlotNo = l.PlotNo

   left join (select count(FarmerCode) cntw1,FarmerCode,cast(CreatedDate as Date) as W1Date from
(select FarmerCode,
       CreatedDate 
from (select FarmerCode,
             CreatedDate,
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn
      from Documents where DocType like 'water cycle 1%' and IsActive=1) as T
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w1 on w1.FarmerCode = f.FarmerCode

left join (select count(FarmerCode) cntw2,FarmerCode,cast(CreatedDate as Date) as W2Date from
(select FarmerCode,
       CreatedDate 
from (select FarmerCode,
             CreatedDate,
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn
      from Documents where DocType like 'water cycle 2%' and IsActive=1) as T
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w2 on w2.FarmerCode = f.FarmerCode

left join (select count(FarmerCode) cntw3,FarmerCode,cast(CreatedDate as Date) as W3Date from
(select FarmerCode,
       CreatedDate 
from (select FarmerCode,
             CreatedDate,
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn
      from Documents where DocType like 'water cycle 3%' and IsActive=1) as T
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w3 on w3.FarmerCode = f.FarmerCode

   where f.FarmerCode like 'F_%' and f.IsActive=1 --and f.AgentId = @AgentId
   and F.FarmerCode in (
  'F_109314197_47'	,
'F_243125933_47'	,
'F_422498365_47'	,
'F_460068877_47'	,
'F_479129970_47'	,
'F_503472755_47'	,
'F_519972226_47'	,
'F_126633644_47'	,
'F_170330516_47'	,
'F_179452631_47'	,
'F_355631872_47'	,
'F_396071040_47'	,
'F_152568014_47'	,
'F_163318090_47'	,
'F_180266463_47'	,
'F_239233849_47'	,
'F_276948021_47'	,
'F_284434911_47'	,
'F_310112995_47'	,
'F_321036247_47'	,
'F_398705503_47'	,
'F_454897131_47'	,
'F_172000747_47'	,
'F_445565799_44'	,
'F_246875816_44'	,
'F_121382942_74'	,
'F_146666744_53'	,
'F_873697958_53'	,
'F_617850574_44'	,
'F_675120794_66'	,
'F_720683819_66'	,
'F_822981877_44'	,
'F_931760963_44'	,
'F_993915566_71'	,
'F_525221797_70'	,
'F_524791043_44'	,
'F_361290355_66'	,
'F_693473525_50'	,
'F_717260349_66'	,
'F_750697440_44'	,
'F_792222434_44'	,
'F_916977839_53'	,
'F_252349332_44'	,
'F_831427044_53'	,
'F_865487407_53'	,
'F_127055604_66'	,
'F_178297841_44'	,
'F_586307189_44'	,
'F_783774363_44'	,
'F_285342251_66'	,
'F_667586892_53'	,
'F_248653242_66'	,
'F_231190237_66'	,
'F_840731034_53'	,
'F_306007242_44'	,
'F_781555048_53'	,
'F_638122900_44'	,
'F_228229158_44'	,
'F_155182176_44'	,
'F_149115664_74'	,
'F_291369109_70'	,
'F_166508319_74'	,
'F_460607988_44'	,
'F_365570417_44'	,
'F_226469618_44'	,
'F_222463064_44'	,
'F_256648172_44'	,
'F_292392616_44'	,
'F_355841699_44'	,
'F_491789381_44'	,
'F_179976197_74'	,
'F_237685455_44'	,
'F_477631128_44'	,
'F_508114568_44'	,
'F_522609636_44'	,
'F_644267273_44'	,
'F_776970483_44'	,
'F_950086189_44'	,
'F_958673868_44'	,
'F_765981559'	,
'F_317191414_69'	,
'F_610877773'	,
'F_538084747'	,
'F_940431828_53'	,
'F_869786833_44'	,
'F_528926347_44'	,
'F_523067413_44'	,
'F_322570125_44'	,
'F_213395112_44'	,
'F_109320612_44'	,
'F_534445277_44'	,
'F_127515200_44'	,
'F_425336639_44'	,
'F_843826623_44'	,
'F_819717218_44'	,
'F_125144868'	,
'F_794897616_44'	,
'F_498873311_44'	,
'F_686788301_44'	,
'F_693600324_44'	,
'F_683002122_44'	,
'F_741570267_44'	,
'F_535595092_44'	,
'F_814350099_44'	,
'F_137217021_70'	,
'F_519654446_70'	,
'F_553068083_44'	,
'F_384445397_70'	,
'F_376909086_70'	,
'F_250165947_70'	,
'F_211610898_70'	,
'F_182712065_70'	,
'F_140931279_74'	,
'F_402067107_44'	,
'F_423089071_44'	,
'F_425870059_44'	,
'F_440810598_44'	,
'F_461556189_44'	,
'F_472582235_44'	,
'F_478955141_44'	,
'F_484780576_44'	,
'F_536665492_44'	,
'F_650573410_44'	,
'F_754918438_44'	,
'F_773364788_44'	,
'F_806280152_44'	,
'F_813705576_44'	,
'F_975861332_44'	,
'F_991892341_44'	,
'F_737622162_53'	,
'F_372836328_44'	,
'F_829496294_44'	,
'F_162393297_44'	,
'F_242150873_44'	,
'F_231282930_37'	,
'F_651858009'	,
'F_103405480_69'	,
'F_627266902_53'	,
'F_510469668_69'	,
'F_517599121_69'	,
'F_989373637_67'	,
'F_181426883_47'	,
'F_250338372_33'	,
'F_317495124_66'	,
'F_451020614_66'	,
'F_489651549_47'	,
'F_586414488_44'	,
'F_958898597_44'	,
'F_960227010_66'	,
'F_479908545_47'	,
'F_163056645_66'	,
'F_961183699_44'	,
'F_834582891_44'	,
'F_534222137_44'	,
'F_446531438_66'	,
'F_248034832_44'	,
'F_168378084_66'	,
'F_313052141_47'	,
'F_723432844_44'	,
'F_498951214_44'	,
'F_139344023_44'	,
'F_453327424_70'	,
'F_187270028_44'	,
'F_194893154_44'	,
'F_485834529_44'	,
'F_599623315_44'	,
'F_696139242_44'	,
'F_763108239_66'	,
'F_780330945_66'	,
'F_830020666_44'	,
'F_894135906_44'	,
'F_695464529_44'	,
'F_453681731_44'	,
'F_102000012_44'	,
'F_149679257_44'	,
'F_929854091_44'	,
'F_500393236_44'	,
'F_338397139_44'	,
'F_322073287_44'	,
'F_640777582_44'	,
'F_211429796_44'	,
'F_132096260_44'	,
'F_922397079_44'	,
'F_524551532_44'	,
'F_482188400_44'	,
'F_541559623_44'	,
'F_351239663_37'	,
'F_439845103_69'	,
'F_366619429_69'	,
'F_349146655_69'	,
'F_587294901'	,
'F_141217473_44'	,
'F_157140931_44'	,
'F_168612435_44'	,
'F_181002783_44'	,
'F_186482404_66'	,
'F_225352630_44'	,
'F_233942676_70'	,
'F_238469691_44'	,
'F_317503310_70'	,
'F_368187089_44'	,
'F_430564553_44'	,
'F_441695633_44'	,
'F_459362575_44'	,
'F_466253659_44'	,
'F_490770598_44'	,
'F_515230885_70'	,
'F_679756794_44'	,
'F_988096232_44'	,
'F_995541568_44'	,
'F_965924139_44'	,
'F_925742371_44'	,
'F_903933354_44'	,
'F_817258985_44'	,
'F_718746961_44'	,
'F_695722225_44'	,
'F_626344909_44'	,
'F_436997650_44'	,
'F_341246593_44'	,
'F_338050089_44'	,
'F_328159733_44'	,
'F_173957789_44'	,
'F_172719315_44'	,
'F_120488271_44'	,
'F_271002415_70'	,
'F_127681355_50'	,
'F_103866375_50'	,
'F_305189252_50'	,
'F_311518621_44'	,
'F_449176550_44'	,
'F_497125056_44'	,
'F_529066693_44'	,
'F_537932297_44'	,
'F_541420441_44'	,
'F_544743696_44'	,
'F_565274056_44'	,
'F_569269218_44'	,
'F_584523314_44'	,
'F_604692162_44'	,
'F_628272097_44'	,
'F_668992976_44'	,
'F_677059971_44'	,
'F_738489871_44'	,
'F_815517690_44'	,
'F_821913490_44'	,
'F_858894035_44'	,
'F_890437933_44'	,
'F_915074184_44'	,
'F_934664586_44'	,
'F_945065531_44'	,
'F_948240538_44'	,
'F_953547934_44'	,
'F_955169114_44'	,
'F_207955987_69'	,
'F_311578951_72'	,
'F_231467488_70'	,
'F_191634767_70'	,
'F_768050788_44'	,
'F_636035644_44'	,
'F_688170243_44'	,
'F_101505317_53'	,
'F_578309234_44'	,
'F_307151958_37'	,
'F_958773266_66'	,
'F_919426504_44'	,
'F_855602853_66'	,
'F_811899388_44'	,
'F_791673490_66'	,
'F_765526029_44'	,
'F_424488528_70'	,
'F_442091431_70'	,
'F_496471991_70'	,
'F_223583942_70'	,
'F_149743097_70'	,
'F_304061969_70'	,
'F_330832884_66'	,
'F_343953750_66'	,
'F_504275746_44'	,
'F_620542044_44'	,
'F_120637463_44'	,
'F_126972058_44'	,
'F_135125674_66'	,
'F_157978876_66'	,
'F_165061106_66'	,
'F_175132671_66'	,
'F_180144248_66'	,
'F_231047913_44'	,
'F_246319510_44'	,
'F_248404297_66'	,
'F_281702672_66'	,
'F_345556434_44'	,
'F_414322356_44'	,
'F_446621384_66'	,
'F_453316392_44'	,
'F_464996831_66'	,
'F_486847832_44'	,
'F_509949748_44'	,
'F_531636133_44'	,
'F_545632099_66'	,
'F_692616773_66'	,
'F_108981643_44'	,
'F_132662912_44'	,
'F_144420201_44'	,
'F_169290367_44'	,
'F_214307435_44'	,
'F_228354504_44'	,
'F_239371481_44'	,
'F_263283476_44'	,
'F_281725664_44'	,
'F_282258290_44'	,
'F_286138927_44'	,
'F_304636747_44'	,
'F_310049651_44'	,
'F_343568354_44'	,
'F_356563610_44'	,
'F_366457916_44'	,
'F_422314463_44'	,
'F_423780476_44'	,
'F_430509470_66'	,
'F_442099242_44'	,
'F_448799866_44'	,
'F_532525850_44'	,
'F_587678036_44'	,
'F_655369472_44'	,
'F_664395549_44'	,
'F_706560605_44'	,
'F_731587019_44'	,
'F_829742451_44'	,
'F_835969565_44'	,
'F_838756145_44'	,
'F_889177854_44'	,
'F_909976821_44'	,
'F_913190950_44'	,
'F_939839633_44'	,
'F_953068052_44'	,
'F_985557552_44'	,
'F_547373623_66'	,
'F_836197825_44'	,
'F_453083365_50'	,
'F_213795101_50'	,
'F_361661106_50'	,
'F_222351032_74'	,
'F_157901607_74'	,
'F_119888470_74'	,
'F_144309003_74'	,
'F_144451430_74'	,
'F_173857972_74'	,
'F_176519127_74'	,
'F_189512435_74'	,
'F_121841875_74'	,
'F_153355379_74'	,
'F_174531052_74'	,
'F_189661599_74'	,
'F_203131288_74'	,
'F_218238424_74'	,
'F_101234004_29'	,
'F_117841875_29'	,
'F_126698852_29'	,
'F_213365873_74'	,
'F_217737942_29'	,
'F_227743026_29'	,
'F_238737639_29'	,
'F_318948840_29'	,
'F_335557466_29'	,
'F_375831956_29'	,
'F_408598070_29'	,
'F_508337991_29'	,
'F_141287057_47'	,
'F_155671552_47'	,
'F_168770412_47'	,
'F_192997955_47'	,
'F_220206821_47'	,
'F_240442153_47'	,
'F_273831480_47'	,
'F_292303812_47'	,
'F_328761002_47'	,
'F_368344100_47'	,
'F_371002547_47'	,
'F_376540891_47'	,
'F_410792319_47'	,
'F_420238101_47'	,
'F_447398954_47'	,
'F_455080388_47'	,
'F_470775688_47'	,
'F_511834110_47'	,
'F_517882975_47'	,
'F_530138235_47'	,
'F_582373028_53'	,
'F_833058216_74'	,
'F_861741870_74'	,
'F_893092299_47'	
   )
   
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerFullDetailsValidatorByAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerFullDetailsValidatorByAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerFullDetailsValidatorByAgentId 37  
CREATE proc [dbo].[SP_GetFarmerFullDetailsValidatorByAgentId](@AgentId int)  
as  
begin  
  
   select l.PlotNo,l.Size,l.Latitude,l.Longitude,l.PattadarBookNo,l.SurveyNo,f.FarmerCode,f.FirstName +' '+f.LastName FarmerName  
   ,d.Name as DistrictName,m.Name as MandalName,v.Name as VillageName,u.UserName as AgentName  
   ,case when doc.DocUrl is not null then doc.DocUrl else 'No' end PipeInstallationTaken  
   ,case when gb.cntPlotNo is not null then gb.cntPlotNo else 0 end GeoBoundariesTaken  
   ,case when gb.cntPlotNo is not null then dbo.FN_GenerateKMLFileByPlotNo(l.PlotNo) else 'No' end KMLFile  
   ,case when l.Latitude is not null and l.Longitude is not null then 'Yes' else 'No' end as GPSPointTaken  
   ,doc.CreatedDate docCreatedDate,f.AgentId,f.TotalPlotArea,  
   l.GPSPlotArea,l.PlotArea1,l.PlotArea2,l.PlotArea3,l.PlotArea4,l.PlotArea5,doc.CreatedDate as PipeInstalledDate,  
   isnull(w1.cntw1,0) cntw1,isnull(w2.cntw2,0) cntw2,isnull(w3.cntw3,0) cntw3,w1.W1Date,w2.W2Date,w3.W3Date
   ,docphoto.DocUrl as FarmerPhoto,docaadhar.DocUrl as FarmerAadhar,docpattadar.DocUrl as FarmerPattadarBook
 ,docbank.DocUrl as FarmerBankPassbook,docfarmerconsent.DocUrl as FarmerConsent
   from Land l   
   left join Farmer f on f.FarmerCode = l.FarmerCode  
   left join District d on d.Id = l.DistrictId  
   left join Mandal m on m.Id = l.MandalId  
   left join Village v on v.Id = l.VillageId  
   left join Users u on u.Id = l.CreatedByUserId  
   left join Documents doc on doc.FarmerCode = f.FarmerCode and doc.DocType='pipe installation' and doc.IsActive=1  
  left join(select * from Documents where DocType='photo' ) docphoto on docphoto.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='aadhar card' ) docaadhar on docaadhar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Pattadar Book' ) docpattadar on docpattadar.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='bank passbook' ) docbank on docbank.FarmerCode = f.FarmerCode
left join(select * from Documents where DocType='Agreement' ) docfarmerconsent on docfarmerconsent.FarmerCode = f.FarmerCode
  left join (select count(PlotNo) cntPlotNo,PlotNo from GeoBoundaries group by PlotNo) gb on gb.PlotNo = l.PlotNo  
  
   left join (select count(FarmerCode) cntw1,FarmerCode,cast(CreatedDate as Date) as W1Date from  
(select FarmerCode,  
       CreatedDate   
from (select FarmerCode,  
             CreatedDate,  
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn  
      from Documents where DocType like 'water cycle 1%' and IsActive=1) as T  
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w1 on w1.FarmerCode = f.FarmerCode  
  
left join (select count(FarmerCode) cntw2,FarmerCode,cast(CreatedDate as Date) as W2Date from  
(select FarmerCode,  
       CreatedDate   
from (select FarmerCode,  
             CreatedDate,  
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn  
      from Documents where DocType like 'water cycle 2%' and IsActive=1) as T  
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w2 on w2.FarmerCode = f.FarmerCode  
  
left join (select count(FarmerCode) cntw3,FarmerCode,cast(CreatedDate as Date) as W3Date from  
(select FarmerCode,  
       CreatedDate   
from (select FarmerCode,  
             CreatedDate,  
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn  
      from Documents where DocType like 'water cycle 3%' and IsActive=1) as T  
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w3 on w3.FarmerCode = f.FarmerCode  
  
   where f.FarmerCode like 'F_%' and f.IsActive=1 and f.AgentId = @AgentId  
   
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerMapDetailsbyAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerMapDetailsbyAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--  exec SP_GetFarmerMapDetailsbyAgentId null

CREATE PROCEDURE [dbo].[SP_GetFarmerMapDetailsbyAgentId] (@P_AgentId int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.[FirstName] +' ' + t.[LastName] as FarmerName
		,t.[Address]+ ' '+ V.Name as FarmerAddress
		,t.CreatedByUserId as  AgentId
	--	,t.AgentId
		,Vt.UserName as VolunteerName
		,t.VoluntaryId
		,us.UserName as AgentName
		,v.Name as VillageName
	FROM [dbo].[Farmer] t
 	left JOIN Users uv ON uv.Id=t.UpdatedByUserId
	left join Village V on V.Id = t.VillageId
	left join Voluntary Vt on Vt.Id = t.VoluntaryId
	left join Users us on us.Id = t.CreatedByUserId
	--WHERE t.AgentId = ISNULL(@P_AgentId, t.AgentId)
		WHERE t.CreatedByUserId = ISNULL(@P_AgentId, t.CreatedByUserId)

		AND t.IsActive = 1 order By t.CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerMapDetailsbyAgentIdVillageId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerMapDetailsbyAgentIdVillageId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--  exec SP_GetFarmerMapDetailsbyAgentId null

CREATE PROCEDURE [dbo].[SP_GetFarmerMapDetailsbyAgentIdVillageId] (@P_AgentId int,@P_VillageId int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.[FirstName] +' ' + t.[LastName] as FarmerName
		,t.[Address]+ ' '+ V.Name as FarmerAddress
		,t.CreatedByUserId as  AgentId
	--	,t.AgentId
		,Vt.UserName as VolunteerName
		,t.VoluntaryId
		,us.UserName as AgentName
		,v.Name as VillageName
	FROM [dbo].[Farmer] t
 	left JOIN Users uv ON uv.Id=t.UpdatedByUserId
	left join Village V on V.Id = t.VillageId
	left join Voluntary Vt on Vt.Id = t.VoluntaryId
	left join Users us on us.Id = t.CreatedByUserId
	--WHERE t.AgentId = ISNULL(@P_AgentId, t.AgentId)
		WHERE t.CreatedByUserId = ISNULL(@P_AgentId, t.CreatedByUserId)
		and t.VillageId =ISNULL(@P_VillageId,t.VillageId)
		AND t.IsActive = 1 order By t.CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerMapDetailsbyId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerMapDetailsbyId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--  exec SP_GetFarmerMapDetailsbyAgentId null

CREATE PROCEDURE [dbo].[SP_GetFarmerMapDetailsbyId] (@P_Id int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName] as FarmerName
		,t.[Address]+ ' '+ V.Name as FarmerAddress
		,t.AgentId
		,Vt.UserName
		,t.VoluntaryId
		,us.UserName as AgentName
	FROM [dbo].[Farmer] t
 	left JOIN Users uv ON uv.Id=t.UpdatedByUserId
	left join Village V on V.Id = t.VillageId
	left join Voluntary Vt on Vt.Id = t.VoluntaryId
	left join Users us on us.Id = t.AgentId
	--WHERE t.AgentId = ISNULL(@P_AgentId, t.AgentId)
		WHERE t.Id = ISNULL(@P_Id, t.Id)

		AND t.IsActive = 1 order By t.CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerMapDetailsbyVillageId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerMapDetailsbyVillageId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--  exec SP_GetFarmerMapDetailsbyVillageId null
CREATE PROCEDURE [dbo].[SP_GetFarmerMapDetailsbyVillageId] (@P_VillageId int)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.[FirstName] +' ' + t.[LastName] as FarmerName
		,t.[Address]+ ' '+ V.Name as FarmerAddress
		,t.CreatedByUserId as  AgentId
		,Vt.UserName as VolunteerName
		,t.VoluntaryId
		,us.UserName as AgentName
		,v.Name as VillageName
	FROM [dbo].[Farmer] t
 	left JOIN Users uv ON uv.Id=t.UpdatedByUserId
	left join Village V on V.Id = t.VillageId
	left join Voluntary Vt on Vt.Id = t.VoluntaryId
	left join Users us on us.Id = t.CreatedByUserId
	--WHERE t.AgentId = ISNULL(@P_AgentId, t.AgentId)
		WHERE  t.VillageId =ISNULL(@P_VillageId,t.VillageId)
		AND t.IsActive = 1 and t.FarmerCode like 'F_%' order By t.CreatedDate desc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerPlotDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerPlotDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[SP_GetFarmerPlotDetails] (@P_Id varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.FarmerCode
		,t.FarmerTitle
		,t.[FirstName]
		,t.MiddleName
		,t.[LastName]
		,t.[FatherName]
		,t.Gender
		,t.Age
		,t.[PrimaryContactNum]
		,t.SecondaryContactNum
		,t.[Address]
	    ,D.Name DistrictName
	    ,M.Name MandalName
	    ,S.Name StateName
		,V.Name VillageName
		,t.[PinCode]
	    ,c.Name AS FieldExecutive
		,t.[CreatedDate]
		,t.TotalPlotArea
		,t.PlotsCount
	FROM [dbo].[Farmer] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
	WHERE t.FarmerCode = ISNULL(@P_Id, t.FarmerCode)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerVillageList]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerVillageList]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerVillageList
CREATE proc [dbo].[SP_GetFarmerVillageList]
as
begin
select distinct VillageId into #TempVillages
from Farmer where IsActive = 1 and FarmerCode like 'F_%' and VillageId != 0 and VillageId != 9736
select v.Id,v.Name from #TempVillages tv
left join Village v on v.Id = tv.VillageId order by Name

drop table #TempVillages
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerWaterCyclesByAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerWaterCyclesByAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerWaterCyclesByAgentId 48
CREATE proc [dbo].[SP_GetFarmerWaterCyclesByAgentId](@AgentId int)
as
begin

--select distinct FarmerCode into #DistinctFarmerCode
--from Documents where DocType like 'water cycle%' and IsActive=1


select f.FarmerCode,f.FirstName+' '+f.LastName as FarmerName,f.PrimaryContactNum,
m.Name as MandalName,v.Name as VillageName,
isnull(w1.cntw1,0) cntw1,isnull(w2.cntw2,0) cntw2,isnull(w3.cntw3,0) cntw3,
w1.W1Date,w2.W2Date,w3.W3Date,
--volun.UserName as VolunteerName,
f.AgentId
from Farmer f
left join Mandal m on m.Id = f.MandalId
left join Village v on v.Id = f.VillageId
left join (select count(FarmerCode) cntw1,FarmerCode,cast(CreatedDate as Date) as W1Date from
(select FarmerCode,
       CreatedDate 
from (select FarmerCode,
             CreatedDate,
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn
      from Documents where DocType like 'water cycle 1%' and IsActive=1) as T
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w1 on w1.FarmerCode = f.FarmerCode

left join (select count(FarmerCode) cntw2,FarmerCode,cast(CreatedDate as Date) as W2Date from
(select FarmerCode,
       CreatedDate 
from (select FarmerCode,
             CreatedDate,
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn
      from Documents where DocType like 'water cycle 2%' and IsActive=1) as T
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w2 on w2.FarmerCode = f.FarmerCode

left join (select count(FarmerCode) cntw3,FarmerCode,cast(CreatedDate as Date) as W3Date from
(select FarmerCode,
       CreatedDate 
from (select FarmerCode,
             CreatedDate,
             row_number() over(partition by FarmerCode order by CreatedDate desc) as rn
      from Documents where DocType like 'water cycle 3%' and IsActive=1) as T
where rn = 1)X group by FarmerCode,cast(CreatedDate as Date))w3 on w3.FarmerCode = f.FarmerCode


--left join (select count(FarmerCode) cntw1,FarmerCode,max(cast(CreatedDate as Date)) as W1Date from Documents where DocType like 'water cycle 1%' and IsActive=1 group by FarmerCode,cast(CreatedDate as Date))w1 on w1.FarmerCode = f.FarmerCode
--left join (select count(FarmerCode) cntw2,FarmerCode,cast(CreatedDate as Date) as W2Date from Documents where DocType like 'water cycle 2%' and IsActive=1 group by FarmerCode,cast(CreatedDate as Date))w2 on w2.FarmerCode = f.FarmerCode
--left join (select count(FarmerCode) cntw3,FarmerCode,cast(CreatedDate as Date) as W3Date from Documents where DocType like 'water cycle 3%' and IsActive=1 group by FarmerCode,cast(CreatedDate as Date))w3 on w3.FarmerCode = f.FarmerCode
--left join (select count(FarmerCode) cntv, FarmerCode,VoluntaryId from Documents where DocType like 'water cycle%' and IsActive=1 group by FarmerCode,VoluntaryId)vol on vol.FarmerCode = f.FarmerCode
--left join Voluntary volun on volun.Id = vol.VoluntaryId

--where f.FarmerCode in (select FarmerCode from #DistinctFarmerCode) and
where f.AgentId = ISNULL(@AgentId,f.AgentId) and f.IsActive=1 and  f.FarmerCode like 'F_%'

--drop table #DistinctFarmerCode
end



GO

-- %% [markdown]
-- # [dbo].[SP_GetFarmerWaterCyclesByAgentIdVillageId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFarmerWaterCyclesByAgentIdVillageId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetFarmerWaterCyclesByAgentIdVillageId 69
CREATE proc [dbo].[SP_GetFarmerWaterCyclesByAgentIdVillageId](@AgentId int,@VillageId int)
as
begin
select distinct FarmerCode into #DistinctFarmerCode
from Documents where DocType like 'water cycle%' and IsActive=1


select f.FarmerCode,f.FirstName+' '+f.LastName as FarmerName,f.PrimaryContactNum,
m.Name as MandalName,v.Name as VillageName,
isnull(w1.cntw1,0) cntw1,isnull(w2.cntw2,0) cntw2,isnull(w3.cntw3,0) cntw3,
volun.UserName as VolunteerName
from Farmer f
left join Mandal m on m.Id = f.MandalId
left join Village v on v.Id = f.VillageId
left join (select count(FarmerCode) cntw1,FarmerCode from Documents where DocType like 'water cycle 1%' and IsActive=1 group by FarmerCode)w1 on w1.FarmerCode = f.FarmerCode
left join (select count(FarmerCode) cntw2,FarmerCode from Documents where DocType like 'water cycle 2%' and IsActive=1 group by FarmerCode)w2 on w2.FarmerCode = f.FarmerCode
left join (select count(FarmerCode) cntw3,FarmerCode from Documents where DocType like 'water cycle 3%' and IsActive=1 group by FarmerCode)w3 on w3.FarmerCode = f.FarmerCode
left join (select count(FarmerCode) cntv, FarmerCode,VoluntaryId from Documents where DocType like 'water cycle%' and IsActive=1 group by FarmerCode,VoluntaryId)vol on vol.FarmerCode = f.FarmerCode
left join Voluntary volun on volun.Id = vol.VoluntaryId
where f.FarmerCode in (select FarmerCode from #DistinctFarmerCode) and
f.AgentId = ISNULL(@AgentId,f.AgentId) 
and f.VillageId = ISNULL(@VillageId,f.VillageId)

drop table #DistinctFarmerCode
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFertilizerDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFertilizerDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetFertilizerDetails](@P_ID int)
as 
begin

select ID,Fertilizer,FertilizerType,Date,Qty,UOM,CropProtection,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from Fertilizer where ID = isnull(@P_ID,ID)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetFertilizerDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetFertilizerDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetFertilizerDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin
select a.*,b.Name as fertilizer_name, c.Name as fertilizertype_name,d.Name as UOM_name
from Fertilizer a left join (select id,name from LookupDtl) b on a.Fertilizer = b.id
left join (select id,name from LookupDtl) c on a.FertilizerType =c.Id 
left join (select id,name from LookupDtl) d on a.UOM = d.Id where a.IsActive=1 and a.LogBookNo= @P_LogBookNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGeoBoundaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGeoBoundaryDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE   PROCEDURE [dbo].[SP_GetGeoBoundaryDetails] (@P_PlotNo varchar(255))    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.[PlotNo]    
  ,t.[Latitude]    
  ,t.[Longitude]  
  ,t.GeoCategoryTypeId
  ,t.SeqNo
  ,t.Sync
  ,t.[CreatedDate]    
  ,c.Name AS CreatedByUser 
  ,t.[UpdatedDate]    
  ,u.Name AS UpdatedByUser   
 FROM [dbo].[GeoBoundaries] t    
 INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId    
 INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId    
 WHERE t.PlotNo = ISNULL(@P_PlotNo, t.PlotNo)    
  AND t.IsActive = 1 order by SeqNo
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetGeoBoundaryDetailsByPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGeoBoundaryDetailsByPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetGeoBoundaryDetailsByPlotNo 'F_995233355_47'
CREATE PROCEDURE [dbo].[SP_GetGeoBoundaryDetailsByPlotNo] (@PlotNo varchar(255),@No int)    
AS    
BEGIN    
SELECT     
   t.[Id]  
  ,t.[PlotNo]    
  ,t.[Latitude]    
  ,t.[Longitude]  
  ,'['+CAST(t.[Latitude] as varchar(255))+','+CAST(t.[Longitude] as varchar(255))+']' LatLng
  ,t.SeqNo
  ,t.[CreatedByUserId]
  ,t.[CreatedDate]    
  ,t.[UpdatedByUserId]
  ,t.[UpdatedDate]    
FROM [dbo].[GeoBoundaries] t     
WHERE t.PlotNo = ISNULL(@PlotNo, t.PlotNo)  and t.GeoCategoryTypeId = @No   
  AND t.IsActive = 1  ORDER BY t.SeqNo Asc 
  end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGHGEmissionDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGHGEmissionDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[SP_GetGHGEmissionDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		 ,t.[Date]
		  ,t.[PlotAreaLatitude]
		 ,t.[PlotAreaLongitude]
		 ,t.[SoilTemperature]
		 ,t.[SoilMoisture]
		 ,t.[S1C1]
		 ,t.[S1C2]
		 ,t.[S1C3]
		 ,t.[S2C1]
		 ,t.[S2C2]
		 ,t.[S2C3]
		 ,t.[S3C1]
		 ,t.[S3C2]
		 ,t.[S3C3]
		 ,t.S2TimeStamp
		 ,t.S2TimeStamp
		 ,t.S3TimeStamp
         ,t.[IsActive]
	     ,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
	FROM [dbo].[GHGEmissionCollection] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetGHGEmissionDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGHGEmissionDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetGHGEmissionDetailsByLogBookNo](@P_LogBookNo varchar(50))
as 
begin

select t.[Id]
		 ,t.[Date]
		 
		 ,t.[PlotAreaLatitude]
		 ,t.[PlotAreaLongitude]
		 ,t.[SoilTemperature]
		 ,t.[SoilMoisture]
		 ,t.[S1C1]
		 ,t.[S1C2]
		 ,t.[S1C3]
		 ,t.[S2C1]
		 ,t.[S2C2]
		 ,t.[S2C3]
		 ,t.[S3C1]
		 ,t.[S3C2]
		 ,t.[S3C3]
		 ,t.S1TimeStamp
		 ,t.S2TimeStamp
		 ,t.S3TimeStamp
         ,t.[IsActive]
	     ,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
		,lb.PlotNo
		from 
[GHGEmissionCollection] t 
INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
inner join Logbook lb on lb.LogBookNo = t.LogBookNo
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId 
	where t.LogBookNo = @P_LogBookNo

	order By t.Date
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetGPSClusterCountdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGPSClusterCountdetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [dbo].[SP_GetGPSClusterdetails] 'null' UPPER(favorite_car) AS car
Create PROCEDURE [dbo].[SP_GetGPSClusterCountdetails] (@P_Cluster varchar(50))
AS 
BEGIN
    if lower(@P_Cluster) = 'null'
	set @P_Cluster = null
	select  count(l.Id) cnt
	from land l
	left join Farmer F on F.FarmerCode = l.FarmerCode
	WHERE l.Cluster = ISNULL(@P_Cluster, l.Cluster)
	AND l.IsActive = 1  and l.Latitude!='' and l.Longitude!=''

END

GO

-- %% [markdown]
-- # [dbo].[SP_GetGPSClusterdetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetGPSClusterdetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [dbo].[SP_GetGPSClusterdetails] 'null' UPPER(favorite_car) AS car
CREATE PROCEDURE [dbo].[SP_GetGPSClusterdetails] (@P_Cluster varchar(50))
AS 
BEGIN
    if lower(@P_Cluster) = 'null'
	set @P_Cluster = null
	select  l.Latitude,Longitude,Cluster,gps,F.FarmerTitle+'.'+FirstName+' '+LastName as FarmerName from land l
	left join Farmer F on F.FarmerCode = l.FarmerCode
	
	WHERE l.Cluster = ISNULL(@P_Cluster, l.Cluster)
		AND l.IsActive = 1  and l.Latitude!='' and l.Longitude!=''
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetHarvestDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetHarvestDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetHarvestDetails](@P_ID int)
as 
begin

select ID,LogBookNo,Date,YeildQty,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
HarvestDetails where ID = isnull(@P_ID,ID)
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetHarvestDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetHarvestDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetHarvestDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin

select ID,LogBookNo,Date,YeildQty,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
HarvestDetails where LogBookNo = @P_LogBookNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLandDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLandDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE   PROCEDURE [dbo].[SP_GetLandDetails] (@P_Id varchar(255))    
AS    
BEGIN    
 SELECT     
   t.[Id]  
  ,t.[PlotNo]    
  ,t.[Size]  
  ,t.Plotownership
  ,t.LandMark
  ,t.[CropId]    
  ,cr.Name    
  ,t.[FarmerCode]    
  ,f.FirstName   
  ,f.MiddleName
  ,f.LastName    
  ,f.Address as FarmerAddress    
  ,f.PrimaryContactNum
  ,f.SecondaryContactNum
  ,f.FarmerTitle
  ,f.Gender
  ,f.Age    
  ,f.FatherName         
  ,t.[Latitude]    
  ,t.[Longitude]    
  ,t.[Address]    
  ,t.[IsActive]    
  ,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.StateId
		,S.Name StateName
		,t.VillageId
		,V.Name VillageName
		,t.PinCode
  ,t.SurveyNo
  ,t.PattadarBookNo
  ,t.Sync
  ,t.GPS
  ,t.GPSPlotArea
  ,t.[CreatedDate]    
  ,c.Name AS CreatedByUserId    
  ,t.[UpdatedDate]    
  ,u.Name AS UpdatedByUserId    
 FROM [dbo].[Land] t    
 INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId    
 INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId    
 INNER JOIN Crop cr on cr.Id =t.CropId    
 INNER JOIN Farmer f on f.FarmerCode = t.FarmerCode  
 inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
 WHERE t.PlotNo = ISNULL(@P_Id, t.PlotNo)    
  AND t.IsActive = 1  order by t.CreatedDate desc 
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetLandDetailsByFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLandDetailsByFarmer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO







    
CREATE   PROCEDURE [dbo].[SP_GetLandDetailsByFarmer] (@P_Id varchar(255))    
AS    
BEGIN    
 SELECT     
   t.[Id]    
  ,t.[PlotNo]    
  ,t.[Size]   
   ,t.Plotownership
  ,t.LandMark
  ,t.[CropId]    
  ,cr.Name    
  ,t.[FarmerCode]    
  ,f.FirstName    
  ,f.MiddleName
  ,f.LastName    
  ,f.Address as FarmerAddress    
  ,f.PrimaryContactNum
  ,f.SecondaryContactNum
  ,f.FarmerCode
  ,f.Gender
  ,f.Age   
  ,f.FatherName        
  ,t.[Latitude]    
  ,t.[Longitude]    
  ,t.[Address]    
  ,t.[IsActive]    
  ,t.[CreatedDate]    
  ,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.StateId
		,S.Name StateName
		,t.VillageId
		,V.Name VillageName
		,t.PinCode
  ,t.SurveyNo
  ,t.PattadarBookNo
  ,t.GPS
  ,t.GPSPlotArea
  ,t.sync
  ,c.Name AS CreatedByUserId    
  ,t.[UpdatedDate]    
  ,u.Name AS UpdatedByUserId    
 FROM [dbo].[Land] t    
 INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId    
 INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId    
 INNER JOIN Crop cr on cr.Id =t.CropId    
 INNER JOIN Farmer f on f.FarmerCode = t.FarmerCode    
 inner join District D on D.Id = t.DistrictId
	inner join Mandal M on M.Id = t.MandalId
	inner join Village V on V.Id = t.VillageId
	inner join States S on S.Id = t.StateId 
 WHERE t.FarmerCode = ISNULL(@P_Id, t.FarmerCode)    
  AND t.IsActive = 1    
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogBook_SeasonByAgent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogBook_SeasonByAgent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetLogBook_SeasonByAgent 55             
CREATE Proc [dbo].[SP_GetLogBook_SeasonByAgent](@AgentId int)
as
begin
IF OBJECT_ID('tempdb..#TempFarmer') IS NOT NULL DROP TABLE #TempFarmer
IF OBJECT_ID('tempdb..#TempPlot') IS NOT NULL DROP TABLE #TempPlot
select * into #TempFarmer from Farmer where CreatedByUserId = @AgentId and IsActive =1 and FarmerCode like 'F_%'

select ROW_NUMBER() over(partition by FarmerCode order by FarmerCode) SNo,* into #TempPlot from Land where IsActive =1 and FarmerCode in (
select FarmerCode from #TempFarmer)

select f.Id,f.FarmerCode,tp.PlotNo,ls.LogBookNo,ls.DateOfSowing,f.FarmerTitle,f.FirstName,f.LastName,f.FatherName,f.Gender,f.Age,f.PrimaryContactNum
,f.StateId,f.DistrictId,f.MandalId,f.VillageId,f.PinCode,f.Address,f.TotalPlotArea,f.CreatedByUserId,f.CreatedDate,
S.Name StateName,D.Name DistrictName,M.Name MandalName,V.Name VillageName,c.UserName as AgentName
,fb.AccountNumber,fb.IFSCCode,l.PattadarBookNo,l.SurveyNo,f.IdentityCode as AadhaarNo,fc.AgreementDate,
cr.Name as CropName,ss.Name as SeasonName,ld.Name as CultivationPractise
from #TempFarmer f 
left JOIN UserInfo c ON c.Id=f.CreatedByUserId
left join States S on S.Id = f.StateId 
left join District D on D.Id = f.DistrictId
left join Mandal M on M.Id = f.MandalId
left join Village V on V.Id = f.VillageId
left join #TempPlot tp on tp.FarmerCode = f.FarmerCode and tp.SNo = 1
left join FarmerBank fb on fb.FarmerCode = f.FarmerCode  and fb.IsActive = 1
left join (select FarmerCode,string_agg(PattadarBookNo,'$') AS PattadarBookNo,string_agg(SurveyNo,'$') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = f.FarmerCode
left join FarmerConsent fc on fc.FarmerCode = f.FarmerCode and fc.IsActive =1 
left join LogBook_Season ls on ls.FarmerCode = f.FarmerCode
left join Crop cr on cr.Id = ls.CropId
left join Season ss on ss.Id = ls.SeasonId
left join LookupDtl ld on ld.Id = ls.CultivationPractiseId
order by f.CreatedDate desc
drop table #TempFarmer
drop table #TempPlot
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetLogBookByAgent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogBookByAgent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetLogBookByAgent 47             
CREATE Proc [dbo].[SP_GetLogBookByAgent](@AgentId int)
as
begin
IF OBJECT_ID('tempdb..#TempFarmer') IS NOT NULL DROP TABLE #TempFarmer
IF OBJECT_ID('tempdb..#TempPlot') IS NOT NULL DROP TABLE #TempPlot
select * into #TempFarmer from Farmer where CreatedByUserId = @AgentId and IsActive =1 and FarmerCode like 'F_%'

select ROW_NUMBER() over(partition by FarmerCode order by FarmerCode) SNo,* into #TempPlot from Land where IsActive =1 and FarmerCode in (
select FarmerCode from #TempFarmer)

select f.Id,f.FarmerCode,tp.PlotNo,ls.LogBookNo,ls.DateOfSowing,ls.DateOfTransplanting,ls.PreviousYeild,f.FarmerTitle,f.FirstName,f.LastName,f.FirstName+' '+f.LastName as FarmerName,f.FatherName,f.Gender,f.Age,f.PrimaryContactNum
,f.StateId,f.DistrictId,f.MandalId,f.VillageId,f.PinCode,f.Address,f.TotalPlotArea,f.CreatedByUserId,f.CreatedDate,
S.Name StateName,D.Name DistrictName,M.Name MandalName,V.Name VillageName,c.UserName as AgentName
,fb.AccountNumber,fb.IFSCCode,l.PattadarBookNo,l.SurveyNo,f.IdentityCode as AadhaarNo,fc.AgreementDate,
cr.Name as CropName,ss.Name as SeasonName,ld.Name as CultivationPractise
from #TempFarmer f 
left JOIN UserInfo c ON c.Id=f.CreatedByUserId
left join States S on S.Id = f.StateId 
left join District D on D.Id = f.DistrictId
left join Mandal M on M.Id = f.MandalId
left join Village V on V.Id = f.VillageId
left join #TempPlot tp on tp.FarmerCode = f.FarmerCode and tp.SNo = 1
left join FarmerBank fb on fb.FarmerCode = f.FarmerCode  and fb.IsActive = 1
left join (select FarmerCode,string_agg(PattadarBookNo,'$') AS PattadarBookNo,string_agg(SurveyNo,'$') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = f.FarmerCode
left join FarmerConsent fc on fc.FarmerCode = f.FarmerCode and fc.IsActive =1 
left join LogBook ls on ls.FarmerCode = f.FarmerCode
left join Crop cr on cr.Id = ls.PrevCropVariety
left join Season ss on ss.Id = ls.PrevSeason
left join LookupDtl ld on ld.Id = ls.CultivationPractice
order by f.CreatedDate desc
drop table #TempFarmer
drop table #TempPlot
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetLogBookDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogBookDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetLogBookDetails](@P_ID int,@P_Season int,@P_DOS varchar(255))
as 
begin
 
	SELECT 
		pl.LogBookNo,
		pl.PlotNo,
		
		f.FirstName+' '+f.MiddleName+' '+f.LastName FarmerName,
	 c.Name as CropName,
	 cv.Name as CropVariety,
	 	d.Name as SeedVariety,
	 sd.Name as SeedDistributor,
	 s.Name as Season,
	
	 ld.Name as CultivationPractice,


		pl.DateOfSowing,
		pl.IsActive,
		u.FirstName  as FieldExecutive,
	
		pl.UpdatedDate
	FROM [dbo].[LogBook] pl
	
	inner join Land l on l.PlotNo = pl.PlotNo
inner join Farmer f on f.FarmerCode = l.FarmerCode
inner join Crop c on c.Id = pl.Crop


inner Join Season s on s.Id = pl.Season
inner Join LookupDtl ld on ld.Id = pl.CultivationPractice
inner Join CropVariety cv on cv.Id = pl.CropVariety
inner Join LookupDtl d on d.Id = pl.SeedVariety
inner Join SeedDistributor sd on sd.Id = pl.SeedDistributor
inner join Users  u on u.Id = pl.CreatedByUserId
where pl.Season = isnull(@P_Season,pl.Season) and YEAR(pl.DateOfSowing) = isnull(@P_DOS,YEAR(pl.DateOfSowing))
order by pl.ID 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogbookDetailsByDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogbookDetailsByDate]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE PROCEDURE [dbo].[SP_GetLogbookDetailsByDate] (@FromDate date,@ToDate date)
AS
BEGIN
		SELECT 
		pl.LogBookNo,
		pl.PlotNo,
		
		f.FirstName+' '+f.MiddleName+' '+f.LastName FarmerName,
	 c.Name as CropName,
	 cv.Name as CropVariety,
	 	d.Name as SeedVariety,
	 sd.Name as SeedDistributor,
	 s.Name as Season,
	
	 ld.Name as CultivationPractice,


		pl.DateOfSowing,
		pl.IsActive,
		u.FirstName  as FieldExecutive,
	
		pl.UpdatedDate
	FROM [dbo].[LogBook] pl
	
	inner join Land l on l.PlotNo = pl.PlotNo
inner join Farmer f on f.FarmerCode = l.FarmerCode
inner join Crop c on c.Id = pl.Crop


inner Join Season s on s.Id = pl.Season
inner Join LookupDtl ld on ld.Id = pl.CultivationPractice
left Join CropVariety cv on cv.Id = pl.CropVariety
left Join LookupDtl d on d.Id = pl.SeedVariety
left Join SeedDistributor sd on sd.Id = pl.SeedDistributor
inner join Users  u on u.Id = pl.CreatedByUserId

	WHERE cast(pl.CreatedDate as Date)>=@FromDate
and cast(pl.CreatedDate as Date)<=@ToDate
and pl.IsActive = 1
END




GO

-- %% [markdown]
-- # [dbo].[SP_GetLogBookDetailsBySeason]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogBookDetailsBySeason]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetLogBookDetailsBySeason](@P_Season int)
as 
begin
 
--select ID,LogBookNo,PlotNo,Season,DateOfSowing,Harvest,Crop,CultivationPractice,IsActive,CreatedDate,
--CreatedByUserId,UpdatedDate,UpdatedByUserId from LogBook where ID = isnull(@P_ID,ID)
	SELECT 
		pl.LogBookNo,
		pl.PlotNo,
		
		f.FirstName+' '+f.MiddleName+' '+f.LastName FarmerName,
	 c.Name as CropName,
	 cv.Name as CropVariety,
	 	d.Name as SeedVariety,
	 sd.Name as SeedDistributor,
	 s.Name as Season,
	
	 ld.Name as CultivationPractice,


		pl.DateOfSowing,
		pl.IsActive,
		u.FirstName  as FieldExecutive,
	
		pl.UpdatedDate
	FROM [dbo].[LogBook] pl
	
	inner join Land l on l.PlotNo = pl.PlotNo
inner join Farmer f on f.FarmerCode = l.FarmerCode
inner join Crop c on c.Id = pl.Crop


inner Join Season s on s.Id = pl.Season
inner Join LookupDtl ld on ld.Id = pl.CultivationPractice
inner Join CropVariety cv on cv.Id = pl.CropVariety
inner Join LookupDtl d on d.Id = pl.SeedVariety
inner Join SeedDistributor sd on sd.Id = pl.SeedDistributor
inner join Users  u on u.Id = pl.CreatedByUserId
order by pl.ID 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLogBookFullDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogBookFullDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetLogBookFullDetailsByLogBookNo 'L_194647778_55_2_2023'
CREATE proc [dbo].[SP_GetLogBookFullDetailsByLogBookNo](@LogBookNo varchar(255))
as
begin

select lbs.*,lbba.RabiCropVarietyId,lbba.KharifCropVarietyId,lbba.KharifYeild,lbba.RabiYeild,
lbba.[RabiFertilizerUREAQty_1]
      ,lbba.[RabiFertilizerDAPQty_1]
      ,lbba.[RabiFertilizerPotashQty_1]
      ,lbba.[RabiFertilizerOtherQty_1]
      ,lbba.[KharifFertilizerUREAQty_1]
      ,lbba.[KharifFertilizerDAPQty_1]
      ,lbba.[KharifFertilizerPotashQty_1]
      ,lbba.[KharifFertilizerOtherQty_1]
      ,lbba.[RabiFertilizerUREAQty_2]
      ,lbba.[RabiFertilizerDAPQty_2]
      ,lbba.[RabiFertilizerPotashQty_2]
      ,lbba.[RabiFertilizerOtherQty_2]
      ,lbba.[KharifFertilizerUREAQty_2]
      ,lbba.[KharifFertilizerDAPQty_2]
      ,lbba.[KharifFertilizerPotashQty_2]
      ,lbba.[KharifFertilizerOtherQty_2]
      ,lbba.[RabiFertilizerUREAQty_3]
      ,lbba.[RabiFertilizerDAPQty_3]
      ,lbba.[RabiFertilizerPotashQty_3]
      ,lbba.[RabiFertilizerOtherQty_3]
      ,lbba.[KharifFertilizerUREAQty_3]
      ,lbba.[KharifFertilizerDAPQty_3]
      ,lbba.[KharifFertilizerPotashQty_3]
      ,lbba.[KharifFertilizerOtherQty_3]
from LogBook_Season lbs 
left join LogBookBeforeAWD lbba on lbba.FarmerCode = lbs.FarmerCode
where LogBookNo = @LogBookNo
end


GO

-- %% [markdown]
-- # [dbo].[SP_GetLogbookMaster]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLogbookMaster]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE PROCEDURE [dbo].[SP_GetLogbookMaster](@P_LogBookNo Varchar(255))
as
begin --Farmer details--
select a.*,b.Name as Village_name, c.Name as Mandal_name,d.Name as District_name,
e.Name as States_Name,isnull(doc.DocUrl,'https://etgdocstorage.s3.ap-south-1.amazonaws.com/sowandreap_images/sowandreap.png') DocUrl
from Farmer a 
left join (select id,name from Village) b on a.VillageId= b.id
left join (select id,name from Mandal) c on a.MandalId =c.Id 
left join (select id,name from District) d on a.DistrictId = d.Id
left join (select id,name from States) e on a.StateId = e.Id 
left join (select DocUrl,FarmerCode from Documents where DocType='photo' and IsActive=1) doc on doc.FarmerCode= a.FarmerCode
where IsActive=1 and a.FarmerCode in (Select FarmerCode from Land where IsActive=1 
and PlotNo in (select PlotNo from LogBook where IsActive=1 and LogBookNo= @P_LogBookNo ))

-- Land or Plot Details--
select l.*,c.Name Crop_name from  Land l
left join Crop c on c.Id = l.CropId
left join LogBook lb on lb.PlotNo = l.PlotNo
where l.IsActive=1 and lb.LogBookNo = @P_LogBookNo

-- Log Book Deatils--
select * from LogBook where IsActive=1 and LogBookNo= @P_LogBookNo

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtl]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtl]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtl] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[LookupHdrId]
		,[Code]
		,[Name]
		,[Remarks]
		,[Ord]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupDtl]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrCode] (@P_Code varchar(255))
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Code = ISNULL(@P_Code, t.Code)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlByHdrId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlByHdrId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupDtlByHdrId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId]
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.LookupHdrId = ISNULL(@P_Id, t.LookupHdrId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupDtlDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupDtlDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetLookupDtlDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[LookupHdrId] as LookupMstId
		,t.[Code]
		,t.[Name]
		,t.[Remarks]
		,t.[Ord]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupDtl] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdr]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdr]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupHdr] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[LookupHdr]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetLookupHdrDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetLookupHdrDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetLookupHdrDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[LookupHdr] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMandalDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMandalDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO




CREATE PROCEDURE [dbo].[SP_GetMandalDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[DistrictId]
		,d.Name DistrictName
		,s.Id stateId
		,s.Name StateName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Mandal] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner JOIN dbo.District d ON d.Id = t.DistrictId
	inner JOIN dbo.States s ON s.Id = d.StateId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1 order By t.Name
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMandalDistrictId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMandalDistrictId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetMandalDistrictId null


CREATE PROCEDURE [dbo].[SP_GetMandalDistrictId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[DistrictId]
		,d.Name DistrictName
		,s.Id StateId
		,s.Name StateName
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUserId
	FROM [dbo].[Mandal] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	inner JOIN dbo.District d ON d.Id = t.DistrictId
	inner JOIN dbo.States s ON s.Id = d.StateId
	WHERE t.DistrictId = ISNULL(@P_Id, t.DistrictId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetManualLogBookDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetManualLogBookDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetManualLogBookDetails 'L_20230622124930_1'
CREATE procedure [dbo].[SP_GetManualLogBookDetails](@LogBookNo varchar(255))
as 
begin
 
	SELECT 
		pl.*
	FROM [dbo].[LogBook] pl
where pl.LogBookNo = @LogBookNo and IsActive = 1
order by pl.ID 

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetMasterDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMasterDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetMasterDetails]
as
begin

--select * from Farmer where IsActive=1

--select * from Land where IsActive=1

--select * from GeoBoundaries where IsActive=1

--select * from FarmerBank where IsActive=1

--select * from Documents where IsActive=1

select * from ClusterHDR  where IsActive=1

select * from ClusterDTL  where IsActive=1

select * from States where IsActive=1

select * from District  where IsActive=1  and Id in(10,9,29,13,6,18,19,37,26,11,20,33,12,15,24)

select * from Mandal  where IsActive=1
and DistrictId in (10,9,29,13,6,18,19,37,26,11,20,33,12,15,24)

select * from Village  where IsActive=1
and MandalId in 
(select Id from Mandal  where IsActive=1
and DistrictId in (10,9,29,13,6,18,19,37,26,11,20,33,12,15,24))

select * from Season where IsActive=1


select * from LookupHdr where IsActive=1

select * from LookupDtl where IsActive=1
select * from SeedDistributor where IsActive=1
select *from Crop where IsActive=1
select *from CropVariety where IsActive=1

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetMasterDetailsByIMEINO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMasterDetailsByIMEINO]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetMasterDetailsByIMEINO](@IMEINO varchar(255))
as
begin

select f.*,d.DocUrl from
(select * from Farmer 
where IsActive=1 and CreatedByUserId in(select CreatedByUserId from Users where IMEINo=@IMEINO))f
inner join Documents d on d.FarmerCode = f.FarmerCode
where d.IsActive =1 and d.DocType in ('photo')

select l.*,d.DocUrl from
(select * from Land 
where IsActive=1 and CreatedByUserId in(select CreatedByUserId from Users where IMEINo=@IMEINO))l
inner join Documents d on d.PlotNo = l.PlotNo
where d.IsActive =1 and d.DocType in ('photo')

select * from GeoBoundaries 
where IsActive=1 and CreatedByUserId in(select CreatedByUserId from Users where IMEINo=@IMEINO)
ORDER BY SeqNo

select fb.*,d.DocUrl from
(select * from FarmerBank
where IsActive=1 and CreatedByUserId in(select CreatedByUserId from Users where IMEINo=@IMEINO))fb
inner join Documents d on d.FarmerCode = fb.FarmerCode
where d.IsActive =1 and d.DocType in ('bank passbook')

select * from Documents 
where IsActive=1 and CreatedByUserId in(select CreatedByUserId from Users where IMEINo=@IMEINO)

select * from ClusterHDR  where IsActive=1

select * from ClusterDTL  where IsActive=1

select * from States where IsActive=1

select * from District  where IsActive=1 

select * from Mandal  where IsActive=1
and DistrictId in (  11,12,23)

select * from Village  where IsActive=1
and MandalId in 
(select Id from Mandal  where IsActive=1
and DistrictId in (  11,12,23))

select * from Season where IsActive=1



end

GO

-- %% [markdown]
-- # [dbo].[SP_GetMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenu]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[MenuType]
		,[ParentMenuId]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
		,[Path]
		,[Icon]
		,[Order]
	FROM [dbo].[Menu]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuByUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuByUser]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuByUser] (@P_UserId INT)
AS
BEGIN

SELECT dbo.STRING_UNESCAPE(JStr)JStr FROM
(SELECT dbo.XmlToJson((
(SELECT id, title,link,icon,type,dbo.STRING_UNESCAPE(children) children
FROM
(SELECT MenuId id, MenuName title, Icon icon, dbo.STRING_UNESCAPE(Path) link, MenuType type,

dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type,
dbo.XmlToJson(((SELECT MenuId id, MenuName title, Icon icon, Path link, 
MenuType type
FROM UserRoleMenus M10 WHERE M10.ParentMenuId=M9.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M9 WHERE M9.ParentMenuId=M8.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M8 WHERE M8.ParentMenuId=M7.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M7 WHERE M7.ParentMenuId=M6.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M6 WHERE M6.ParentMenuId=M5.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M5 WHERE M5.ParentMenuId=M4.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M4 WHERE M4.ParentMenuId=M3.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M3 WHERE M3.ParentMenuId=M2.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M2 WHERE M2.ParentMenuId=M.MenuId AND UserId=@P_UserId
FOR XML PATH,TYPE)))children
FROM UserRoleMenus M WHERE MenuType='M' AND UserId=@P_UserId) j

FOR XML PATH,TYPE)))
JStr)A

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT m.Id
		,m.Code
		,m.Name
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,mm.Name as ParentMenu
		,m.[Path]
		,m.[Icon]
		,m.[Order]
		,m.ViewYN
		,m.CreatedDate
		,u.Name as 'CreatedByUser'
		,m.UpdatedDate
		,um.Name as 'UpdatedByUser'
	FROM dbo.Menu m 
	inner join UserInfo u on m.CreatedByUserId=u.Id 
	left join menu mm on mm.Id=m.ParentMenuId
	inner join UserInfo Um ON Um.id=m.UpdatedByUserId
	WHERE m.Id = ISNULL(@P_Id, m.Id)
		--AND m.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetMenuDetailsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetMenuDetailsByUserId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetMenuDetailsByUserId] (@P_UserId INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,CASE WHEN m.Path LIKE'http%' THEN 'REPORTS' ELSE  PM.Name END ParentMenu
		,Case when m.MenuType='M' then 'Menu' when m.MenuType='S' then 'Sub Menu' else 'Item' end MenuType
		,M.[Name] [Menu]
		,m.Path
		,m.Icon
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN Users u ON u.RoleId=r.Id
	WHERE u.Id = ISNULL(@P_UserId, u.Id)
	AND RM.ViewYN = 1
	AND ISNULL(m.Path,'')!=''
	AND m.Path not like 'http%'
	ORDER By r.name,CASE WHEN m.Path LIKE'http%' THEN 9999 ELSE  PM.[Order] END ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrganicAmendmentsDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrganicAmendmentsDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetOrganicAmendmentsDetails](@P_ID int)
as 
begin

select ID,LogBookNo,Value,Date,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
 OrganicAmendments  where ID = isnull(@P_ID,ID)
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetOrganicDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetOrganicDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE procedure [dbo].[SP_GetOrganicDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin
select a.*,b.Name as Value_name 
from OrganicAmendments a left join (select id,Name from LookupDtl) b on 
a.Value = b.id where IsActive=1 and LogBookNo= @P_LogBookNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPerformers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPerformers]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
   
-- exec SP_GetPerformers    
CREATE PROCEDURE [dbo].[SP_GetPerformers]      
AS      
BEGIN      

declare @StartDate date,@EndDate date

set @StartDate = (select top 1 WeekStart  from WeeklyCalendar where WeekStart <= cast(getdate() as date) order by Id desc)
 set @EndDate= (select top 1 WeekEnd  from WeeklyCalendar where WeekStart <= cast(getdate() as date) order by Id desc)
      
select u.id as agentId, u.UserName as agentName, sum(TargetRegistration) as TargetRegs, sum(TargetArea) as TargetArea       
into #targets      
from agenttargets a      
left join Users u on a.agentid = u.id      
where 1=1   and a.WeekId in (select Id from WeeklyCalendar where WeekStart >= @StartDate and WeekStart <= @EndDate) 
group by u.Id,u.UserName;  

      
select u.id as agentId, u.UserName as agentName, count(1) as actualRegs, isnull(round(sum(TotalPlotArea),2),0) as actualArea       
into #actuals      
from Farmerconsent fc      
left join Farmer f on fc.FarmerCode=f.FarmerCode      
inner join users u on fc.AgentId = u.id and u.RoleId = 3 and ViewYN = 1      
where 1=1 and fc.CreatedDate>= @StartDate and fc.CreatedDate <= @EndDate      
group by u.Id, u.UserName;   


select t.agentId,t.agentName,t.TargetRegs,t.TargetArea,isnull(a.actualRegs,0) actualRegs,
isnull(a.actualArea,0) actualArea
from #targets t
left join #actuals a on a.agentId = t.agentId
   
      
      
drop table #targets;      
drop table #actuals;      
      
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotDetailsBasedOnFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotDetailsBasedOnFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE  PROCEDURE [dbo].[SP_GetPlotDetailsBasedOnFarmerCode] (@P_FarmerCode varchar(255))
AS
BEGIN
	SELECT 
		 l.[Id]
		,l.PlotNo
		,l.FarmerCode
		,f.FarmerTitle 
		,f.[FirstName]
		,f.MiddleName
		,f.[LastName]
	    ,f.Gender
		,f.Age
		,f.[PrimaryContactNum]
		,f.SecondaryContactNum
		,l.Plotownership
		,l.SurveyNo
		,l.PattadarBookNo
		,l.GPS
		,l.GPSPlotArea
	    ,l.[Address] PlotAddress
	    ,D.Name PlotDistrictName
	    ,M.Name PlotMandalName
	    ,S.Name PlotStateName
		,V.Name PlotVillageName
		,l.[PinCode]
	    ,c.Name AS FieldExecutive
		,l.[CreatedDate]
	
	FROM [dbo].[Land] l
	INNER JOIN UserInfo c ON c.Id=l.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=l.UpdatedByUserId
	inner join District D on D.Id = l.DistrictId
	inner join Mandal M on M.Id = l.MandalId
	inner join Village V on V.Id = l.VillageId
	inner join States S on S.Id = l.StateId 
	left join Farmer f on f.FarmerCode = l.FarmerCode
	WHERE l.FarmerCode = ISNULL(@P_FarmerCode, l.FarmerCode)
		AND l.IsActive = 1   order By l.CreatedDate desc
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotDetailsBasedOnPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotDetailsBasedOnPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create  PROCEDURE [dbo].[SP_GetPlotDetailsBasedOnPlotNo] (@P_PlotNo varchar(255))
AS
BEGIN
	select   
  t.[Id] 
  ,t.[PlotNo]    
  ,t.[Size]  
  ,t.Plotownership
  ,t.LandMark
  ,t.[CropId]    
  ,cr.Name    
  ,t.[FarmerCode]    
  ,f.FirstName   
  ,f.MiddleName
  ,f.LastName    
  ,f.Address as FarmerAddress    
  ,f.PrimaryContactNum
  ,f.SecondaryContactNum
  ,f.FarmerTitle
  ,f.Gender
  ,f.Age 
  ,f.FatherName         
  ,t.[Latitude]    
  ,t.[Longitude]    
  ,t.[Address]    
  ,t.[IsActive]    
  ,t.Cluster
  ,t.DistrictId
		,D.Name DistrictName
		,t.MandalId
		,M.Name MandalName
		,t.StateId
		,S.Name StateName
		,t.VillageId
		,V.Name VillageName
		,t.PinCode
  ,t.SurveyNo
  ,t.PattadarBookNo
  ,t.Sync
  ,t.GPS
  ,t.GPSPlotArea
 -- ,t.[CreatedDate]    
  --,c.Name AS CreatedByUserId    
  --,t.[UpdatedDate]    
  --,u.Name AS UpdatedByUserId
from Land t
LEFT JOIN UserInfo c ON c.Id=t.CreatedByUserId    
 LEFT JOIN UserInfo u ON u.Id=t.UpdatedByUserId    
 LEFT JOIN Crop cr on cr.Id =t.CropId    
 LEFT JOIN Farmer f on f.FarmerCode = t.FarmerCode  
 LEFT join District D on D.Id = t.DistrictId
	LEFT join Mandal M on M.Id = t.MandalId
	LEFT join Village V on V.Id = t.VillageId
	LEFT join States S on S.Id = t.StateId 
where t.PlotNo = @P_PlotNo and t.IsActive=1

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotDetailsByAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotDetailsByAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetPlotDetailsByAgentId 37
CREATE proc [dbo].[SP_GetPlotDetailsByAgentId](@AgentId int)
as
begin
   --select * from
   --(
   select l.PlotNo,l.Size,l.Latitude,l.Longitude,l.PattadarBookNo,l.SurveyNo,f.FarmerCode,f.FirstName +' '+f.LastName FarmerName
   ,d.Name as DistrictName,m.Name as MandalName,v.Name as VillageName,u.UserName as AgentName
   ,case when doc.DocUrl is not null then doc.DocUrl else 'No' end PipeInstallationTaken
   ,case when gb.cntPlotNo is not null then gb.cntPlotNo else 0 end GeoBoundariesTaken
   ,case when gb.cntPlotNo is not null then dbo.FN_GenerateKMLFileByPlotNo(l.PlotNo) else 'No' end KMLFile
   ,case when l.Latitude is not null and l.Longitude is not null then 'Yes' else 'No' end as GPSPointTaken
   ,doc.CreatedDate docCreatedDate,f.AgentId,f.TotalPlotArea,
   l.GPSPlotArea,l.PlotArea1,l.PlotArea2,l.PlotArea3,l.PlotArea4,l.PlotArea5,doc.CreatedDate as PipeInstalledDate
   from Land l 
   left join Farmer f on f.FarmerCode = l.FarmerCode
   left join District d on d.Id = l.DistrictId
   left join Mandal m on m.Id = l.MandalId
   left join Village v on v.Id = l.VillageId
   left join Users u on u.Id = l.CreatedByUserId
   left join Documents doc on doc.FarmerCode = f.FarmerCode and doc.DocType='pipe installation' and doc.IsActive=1
   left join (select count(PlotNo) cntPlotNo,PlotNo from GeoBoundaries group by PlotNo) gb on gb.PlotNo = l.PlotNo
   where f.FarmerCode like 'F_%' and f.IsActive=1 and f.AgentId = @AgentId 
   --and l.PlotArea1>0

   --) X where X.KMLFile != 'No' and
   --cast(X.docCreatedDate as date) = '2023-07-16'
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotNearLocationsByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotNearLocationsByFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create procedure [dbo].[SP_GetPlotNearLocationsByFarmerCode](@lat decimal(18,6),@long decimal(18,6), @range decimal(18,6) ,@FarmerCode varchar(255) )
as 
begin
 select StartLocation.STDistance(EndLocation)/1000 [Distance In KM] ,GPS,PlotNo ,FarmerCode,CreatedByUserId from 
(select (Geography :: Point (@lat,@long,(4326))) StartLocation,(Geography :: Point ([Latitude],[Longitude],(4326))) as EndLocation,GPS,PlotNo,FarmerCode,CreatedByUserId
from Land)X where StartLocation.STDistance(EndLocation)/1000 <= @range and x.FarmerCode = @FarmerCode
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetPlotNearLocationsByUserId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetPlotNearLocationsByUserId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


create procedure [dbo].[SP_GetPlotNearLocationsByUserId](@lat decimal(18,6),@long decimal(18,6), @range decimal(18,6) ,@UserId Int )
as 
begin
 select StartLocation.STDistance(EndLocation)/1000 [Distance In KM] ,GPS,PlotNo ,FarmerCode,CreatedByUserId from 
(select (Geography :: Point (@lat,@long,(4326))) StartLocation,(Geography :: Point ([Latitude],[Longitude],(4326))) as EndLocation,GPS,PlotNo,FarmerCode,CreatedByUserId
from Land)X where StartLocation.STDistance(EndLocation)/1000 <= @range and x.CreatedByUserId = @UserId
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetReaPreSeasonDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetReaPreSeasonDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetReaPreSeasonDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin

select wps.ID,
wps.LogBookNo,
wps.Field,
ld.Name as FieldName,

wps.IsActive,
wps.CreatedDate,
wps.CreatedByUserId,
wps.UpdatedDate,
wps.UpdatedByUserId from 
WaterReasonPreSeason   wps
  inner Join LookupDtl ld On ld.Id = wps.Field
  where LogBookNo = @P_LogBookNo
  ORDER BY UpdatedDate DESC;
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegOnFieldDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegOnFieldDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetRegOnFieldDetailsByLogBookNo 'TSNKLTP037_446'
CREATE procedure [dbo].[SP_GetRegOnFieldDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin

select wps.ID,
wps.LogBookNo,
wps.Field,
d.IdentityCode As  LtLgImage,
ld.Name as FieldName,
d.DocUrl,
d.DocExtension,
wps.IsActive,
wps.CreatedDate,
wps.CreatedByUserId,
wps.UpdatedDate,
wps.UpdatedByUserId
,1 as SQNo
from 
WaterRegimeOnthefield   wps
  inner Join LookupDtl ld On ld.Id = wps.Field
  -- Logbook Number is sending in Docextension
   left join LogBook lb on lb.LogBookNo = wps.LogBookNo
   left join Land l on l.PlotNo = lb.PlotNo
   left join Documents d on d.PlotNo = l.PlotNo and DocType = 'Water Regime'
  where wps.LogBookNo = @P_LogBookNo

  ORDER BY UpdatedDate DESC;
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRegOnSeasonDetailsByLogBookNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRegOnSeasonDetailsByLogBookNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


CREATE procedure [dbo].[SP_GetRegOnSeasonDetailsByLogBookNo](@P_LogBookNo varchar(255))
as 
begin

select wps.ID,
wps.LogBookNo,
wps.Field,
ld.Name as FieldName,

wps.IsActive,
wps.CreatedDate,
wps.CreatedByUserId,
wps.UpdatedDate,
wps.UpdatedByUserId from 
WaterRegimeonSeason   wps
  inner Join LookupDtl ld On ld.Id = wps.Field
  where LogBookNo = @P_LogBookNo
  ORDER BY UpdatedDate DESC;
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenu]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenu]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRoleMenu] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[RoleId]
		,[MenuId]
		,[AddYN]
		,[EditYN]
		,[DeleteYN]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[RoleMenu]
	WHERE Id = ISNULL(@P_Id, Id)
		--AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoleMenuDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoleMenuDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRoleMenuDetails] (@P_Id INT)
AS
BEGIN
	SELECT RM.Id,
	RM.RoleId
		,R.[Name] [Role]
		,RM.MenuId
		,PM.Name ParentMenu
		,M.[Name] [Menu]
		,RM.[AddYN]
		,RM.[EditYN]
		,RM.[DeleteYN]
		,RM.[ViewYN]
		,RM.[CreatedDate]
		,RM.[CreatedByUserId]
		,RM.[UpdatedDate]
		,U.Name as 'CreatedByUser'
		,Um.Name as 'UpdatedByUser'
		,RM.[UpdatedByUserId]
	FROM dbo.RoleMenu RM
	INNER JOIN Roles R ON RM.RoleId = R.Id
	INNER JOIN Menu M ON RM.MenuId = M.Id
	LEFT JOIN Menu PM ON M.ParentMenuId = PM.Id
	INNER JOIN UserInfo U ON U.Id=RM.CreatedByUserId
	inner join UserInfo Um ON Um.Id=RM.UpdatedByUserId
	WHERE RM.RoleId = ISNULL(@P_Id, RM.RoleId)
		--AND RM.ViewYN = 1
	ORDER By r.name, PM.[Order]  ,m.[Order]
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRoles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRoles]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRoles] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		,[Code]
		,[Name]
		,[ViewYN]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[Roles]
	WHERE Id = ISNULL(@P_Id, Id)
		AND ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetRolesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetRolesDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetRolesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[ViewYN]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[Roles] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSeasonDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSeasonDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO





CREATE   PROCEDURE [dbo].[SP_GetSeasonDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[PlantFrom]
		,t.[PlantTo]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUserId
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUserId
	FROM [dbo].[Season] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSeedDestributors]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSeedDestributors]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



create PROCEDURE [dbo].[SP_GetSeedDestributors] (@P_Id INT)
AS
BEGIN
	SELECT 
		 [Id]
		
		,[Name]
		,[RegistrationNo]
		,[Location]
		,[Address]
		,[Pincode]
		,[PhoneNo]
		,[IsActive]
		,[CreatedDate]
		,[CreatedByUserId]
		,[UpdatedDate]
		,[UpdatedByUserId]
	FROM [dbo].[SeedDistributor]
	WHERE Id = ISNULL(@P_Id, Id)
		AND IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSeedDitributorDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSeedDitributorDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create  PROCEDURE [dbo].[SP_GetSeedDitributorDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		
		,t.[Name]
		,t.[RegistrationNo]
		,t.[Location]
		,t.[Address]
		,t.[Pincode]
		,t.[PhoneNo]
		
		,t.[IsActive]
	
		
		,c.Name AS CreatedByUser
		,t.[CreatedDate]
		,u.Name AS UpdatedByUser
		,t.[UpdatedDate]
	FROM [dbo].[SeedDistributor] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetSoilHealthCard]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSoilHealthCard]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetSoilHealthCard] (@P_FarmerCode varchar(255))
AS
BEGIN
	SELECT 
		sh.[ID]
		,L.PlotNo as PlotNo
		,sh.[SampleNo]
		,sh.[SampleCollectionDate]
		,c.Name as SoilColour
		,u.Name as SoilNature
		,sh.[PH]
		,sh.[ElectricalConductivity]
		,sh.[OrganicCarbon]
		,sh.[Nitrogen]
		,sh.[Phosphorous]
		,sh.[Potassium]
		,sh.[Sulphur]
		,sh.[Zinc]
		,sh.[Iron]
		,sh.[Manganese]
		,sh.[Copper]
		,sh.[Boron]
        ,sh.[IsActive]
		,sh.[CreatedDate]
		,sh.[CreatedByUserId]
		,sh.[UpdatedDate]
		,sh.[UpdatedByUserId]
		
	FROM [dbo].[SoilHealthCard] sh
	 Inner JOIN LookupDtl c ON c.Id=sh.SoilColour   
 INNER JOIN LookupDtl u ON u.Id=sh.SoilNature
 Inner Join Land L On L.PlotNo = sh.PlotNo
	
	WHERE L.FarmerCode = @P_FarmerCode and   
		 sh.IsActive = 1 
END


GO

-- %% [markdown]
-- # [dbo].[SP_GetSoilHealthCardByPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetSoilHealthCardByPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetSoilHealthCardByPlotNo] (@P_PlotNo varchar(255))
AS
BEGIN
	SELECT 
		sh.[ID]
		,L.PlotNo as PlotNo
		,sh.[SampleNo]
		,sh.[SampleCollectionDate]
		,c.Name as SoilColour
		,u.Name as SoilNature
		,sh.[PH]
		,sh.[ElectricalConductivity]
		,sh.[OrganicCarbon]
		,sh.[Nitrogen]
		,sh.[Phosphorous]
		,sh.[Potassium]
		,sh.[Sulphur]
		,sh.[Zinc]
		,sh.[Iron]
		,sh.[Manganese]
		,sh.[Copper]
		,sh.[Boron]
		,sh.[DocExtension]
		,sh.[DocUrl]
		,sh.[DocType]
        ,sh.[IsActive]
		,sh.[CreatedDate]
		,sh.[CreatedByUserId]
		,sh.[UpdatedDate]
		,sh.[UpdatedByUserId]
		
	FROM [dbo].[SoilHealthCard] sh
	 Inner JOIN LookupDtl c ON c.Id=sh.SoilColour   
 INNER JOIN LookupDtl u ON u.Id=sh.SoilNature
 Inner Join Land L On L.PlotNo = sh.PlotNo
	
	WHERE L.PlotNo = @P_PlotNo and   
		 sh.IsActive = 1 
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetStatesDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetStatesDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE   PROCEDURE [dbo].[SP_GetStatesDetails] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[IsActive]
		,t.[CreatedDate]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,u.Name AS UpdatedByUser
	FROM [dbo].[States] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTabDatabaseDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTabDatabaseDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[SP_GetTabDatabaseDetails] (@P_Id int)
as
begin
select Id,Name,UserId,FileSize,FileType,FilePath,CreatedDate  from TabDatabase where UserId=isnull(@P_Id,UserId)
ORDER BY CreatedDate ASC
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetTargetvsActuals]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTargetvsActuals]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO


-- exec SP_GetTargetvsActuals null, null
CREATE PROCEDURE [dbo].[SP_GetTargetvsActuals] (@weekId int, @agentId int)
AS
BEGIN

Declare @weekstartdate date
Declare @weekenddate date

if @weekid is not null
Begin
select @weekstartdate = WeekStart, @weekenddate = Weekend from weeklycalendar where weekofyear = @weekid
end
else 
begin
set @weekstartdate = NULL
set @weekenddate = NULL
end



select u.id as agentId, u.UserName as agentName, sum(TargetRegistration) as TargetRegs, sum(TargetArea) as TargetArea 
into #targets
from agenttargets a
left join Users u on a.agentid = u.id
where 1=1
and WeekId = ISNULL(@weekId, weekId)
group by u.Id,u.UserName;

select u.id as agentId, u.UserName as agentName, count(1) as actualRegs, isnull(round(sum(TotalPlotArea),2),0) as actualArea 
into #actuals
from Farmerconsent fc
left join Farmer f on fc.FarmerCode=f.FarmerCode
left join users u on fc.AgentId = u.id
where 1=1 
and fc.CreatedDate >= isnull(null,fc.CreatedDate) 
and fc.CreatedDate <=isnull(null,fc.CreatedDate)
and fc.AgentId in (select Id from Users where RoleId = 3 and ViewYN = 1) and fc.FarmerCode like 'F_%'
group by u.Id, u.UserName;

select * from #actuals

select t.agentId, t.agentName,t.TargetRegs, t.TargetArea, ISNULL(actualRegs,0) actualRegs, ISNULL(actualArea,0) actualArea 
from #targets t
left join #actuals a on t.agentName=a.agentName
where t.agentId  = isnull(@agentId,t.agentId);

drop table #targets;
drop table #actuals;

END
GO

-- %% [markdown]
-- # [dbo].[SP_GetTargetvsActualsOverall]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTargetvsActualsOverall]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
   
-- exec SP_GetTargetvsActualsOverall 'overall'       
CREATE PROCEDURE [dbo].[SP_GetTargetvsActualsOverall](@Type varchar(255))       
AS      
BEGIN      

declare @StartDate date,@EndDate date

if(@Type = 'overall' )
begin
 set @StartDate = '2023-05-01'
 set @EndDate= (select top 1 WeekEnd  from WeeklyCalendar order by Id desc)
end
else if(@Type = 'tilldate')
begin
 set @StartDate = '2023-05-01'
 set @EndDate= (select top 1 WeekEnd  from WeeklyCalendar where WeekStart <= cast(getdate() as date) order by Id desc)
end
else if(@Type = 'currentweek')
begin
 set @StartDate = (select top 1 WeekStart  from WeeklyCalendar where WeekStart <= cast(getdate() as date) order by Id desc)
 set @EndDate= (select top 1 WeekEnd  from WeeklyCalendar where WeekStart <= cast(getdate() as date) order by Id desc)
end
      
select u.id as agentId, u.UserName as agentName, sum(TargetRegistration) as TargetRegs, sum(TargetArea) as TargetArea       
into #targets      
from agenttargets a      
left join Users u on a.agentid = u.id      
where 1=1   and a.isactive = 1 and a.WeekId in 
(select Id from WeeklyCalendar where WeekStart >= @StartDate and WeekStart <= @EndDate) 
group by u.Id,u.UserName;    


      
select u.id as agentId, u.UserName as agentName, count(1) as actualRegs, isnull(round(sum(TotalPlotArea),2),0) as actualArea       
into #actuals      
from Farmerconsent fc      
left join Farmer f on fc.FarmerCode=f.FarmerCode      
left join users u on fc.AgentId = u.id      
where fc.isactive = 1 and 
cast(fc.CreatedDate as date)>= @StartDate and cast(fc.CreatedDate as date) <= @EndDate 
and fc.AgentId in (select Id from Users where RoleId = 3 and ViewYN = 1) and fc.FarmerCode like 'F_%'
group by u.Id, u.UserName;      
   

 select X.*,cast((100 -((cast(X.actualRegs as float)/X.TargetRegs)*100)) as decimal(18,2)) as RemainingRegs,  
 cast((100 -((cast(X.actualArea as float)/X.TagetArea)*100)) as decimal(18,2)) as RemainingArea,
 cast((((cast(X.actualRegs as float)/X.TargetRegs)*100)) as decimal(18,2)) as TillNowRegs, 
 cast((((cast(X.actualArea as float)/X.TagetArea)*100)) as decimal(18,2)) as TillNowArea
 from   
(select       
sum(t.TargetRegs) as TargetRegs,       
sum(t.TargetArea) as TagetArea,       
ISNULL(sum(actualRegs),0) actualRegs, cast(ISNULL(sum(actualArea),0) as decimal(18,3)) actualArea      
from #targets t      
left join #actuals a on t.agentName=a.agentName)X     
      
drop table #targets;      
drop table #actuals;      
      
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetTargetvsActualsProgressOverall]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTargetvsActualsProgressOverall]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--   exec SP_GetTargetvsActualsOverall 'Overall'
-- exec SP_GetTargetvsActualsProgressOverall        
CREATE PROCEDURE [dbo].[SP_GetTargetvsActualsProgressOverall]     
AS      
BEGIN      

declare @StartDate date,@EndDate date, @currentweekstartdate date, @currentweekenddate date, @currentweekid int

begin
 set @StartDate = '2023-05-01'
 set @EndDate= (select top 1 WeekEnd  from WeeklyCalendar order by Id desc)
 select @currentweekid = WeekofYear, @currentweekenddate = weekstart, @currentweekenddate = weekend from weeklycalendar 
 where Datediff(day,getdate(), weekstart) between 0 and 6  

end
      
select u.id as agentId, u.UserName as agentName, sum(TargetRegistration) as TargetRegs, sum(TargetArea) as TargetArea       
into #targets      
from agenttargets a      
left join Users u on a.agentid = u.id      
where 1=1  and a.IsActive = 1 
and a.WeekId in (select Id from WeeklyCalendar where WeekStart >= @StartDate and WeekStart <= @EndDate) 
group by u.Id,u.UserName;    

select u.id as agentId, u.UserName as agentName, sum(TargetRegistration) as tillweekTargetRegs, sum(TargetArea) as tillweekTargetArea       
into #tillweektargets      
from agenttargets a      
left join Users u on a.agentid = u.id      
where 1=1  and a.IsActive = 1 
 and a.WeekId in (select Id from WeeklyCalendar where WeekStart >= @StartDate and WeekStart <= @currentweekEndDate) 
group by u.Id,u.UserName;  
      
select u.id as agentId, u.UserName as agentName, count(1) as actualRegs, isnull(round(sum(TotalPlotArea),2),0) as actualArea       
into #actuals      
from Farmerconsent fc      
left join Farmer f on fc.FarmerCode=f.FarmerCode      
left join users u on fc.AgentId = u.id      
where 1=1  and fc.IsActive = 1 
and cast(fc.CreatedDate as date)>= @StartDate and cast(fc.CreatedDate as date) <= @EndDate      
group by u.Id, u.UserName;      
   
   


 select X.*,cast((100 -((cast(X.actualRegs as float)/X.TargetRegs)*100)) as decimal(18,2)) as RemainingRegs,  
 cast((100 -((cast(X.actualArea as float)/X.TagetArea)*100)) as decimal(18,2)) as RemainingArea,
 cast((((cast(X.actualRegs as float)/X.TargetRegs)*100)) as decimal(18,2)) as TillNowRegs, 
 cast((((cast(X.actualArea as float)/X.TagetArea)*100)) as decimal(18,2)) as TillNowArea,
  cast((((cast(X.tillweekTargetRegs as float)/X.TargetRegs)*100)) as decimal(18,2)) as tillweektargetRegs, 
 cast((((cast(X.tillweekTagetArea as float)/X.TagetArea)*100)) as decimal(18,2)) as tillweektargetArea
 from   
(select       
sum(t.TargetRegs) as TargetRegs,       
sum(t.TargetArea) as TagetArea,
sum(tt.tillweekTargetRegs) as tillweekTargetRegs,       
sum(tt.tillweekTargetArea) as tillweekTagetArea,       
ISNULL(sum(actualRegs),0) actualRegs, cast(ISNULL(sum(actualArea),0) as decimal(18,3)) actualArea      
from #targets t  
left join #tillweektargets tt on t.agentId=tt.agentId    
left join #actuals a on t.agentId=a.agentId
)X     
      
drop table #targets; 
drop table #tillweektargets;      
drop table #actuals;      
      
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetTargetvsActualsTillDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTargetvsActualsTillDate]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
 
-- exec SP_GetTargetvsActualsTillDate     
CREATE PROCEDURE [dbo].[SP_GetTargetvsActualsTillDate]     
AS    
BEGIN    
    
select u.id as agentId, u.UserName as agentName, sum(TargetRegistration) as TargetRegs, sum(TargetArea) as TargetArea     
into #targets    
from agenttargets a    
left join Users u on a.agentid = u.id    
where 1=1   and a.WeekId in (select Id from WeeklyCalendar where WeekStart <= cast(getdate() as date)) 
group by u.Id,u.UserName;    

declare @StartDate date,@EndDate date
set @StartDate = '2023-05-01'
set @EndDate= (select top 1 WeekEnd  from WeeklyCalendar where WeekStart <= cast(getdate() as date) order by Id desc)
    
select u.id as agentId, u.UserName as agentName, count(1) as actualRegs, isnull(round(sum(TotalPlotArea),2),0) as actualArea     
into #actuals    
from Farmerconsent fc    
left join Farmer f on fc.FarmerCode=f.FarmerCode    
left join users u on fc.AgentId = u.id    
where fc.isactive = 1 and 
cast(fc.CreatedDate as date)>= @StartDate and cast(fc.CreatedDate as date) <= @EndDate 
and fc.AgentId in (select Id from Users where RoleId = 3 and ViewYN = 1) and fc.FarmerCode like 'F_%'
group by u.Id, u.UserName;    
 
 
 select X.*,cast((100 -((cast(X.actualRegs as float)/X.TargetRegs)*100)) as decimal(18,2)) as RemainingRegs,
 cast((100 -((cast(X.actualArea as float)/X.TagetArea)*100)) as decimal(18,2)) as RemainingArea from 
(select     
sum(t.TargetRegs) as TargetRegs,     
sum(t.TargetArea) as TagetArea,     
ISNULL(sum(actualRegs),0) actualRegs, cast(ISNULL(sum(actualArea),0) as decimal(18,3)) actualArea    
from #targets t    
left join #actuals a on t.agentName=a.agentName)X   
    
drop table #targets;    
drop table #actuals;    
    
END 
GO

-- %% [markdown]
-- # [dbo].[SP_GetTooltipDetailsByPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTooltipDetailsByPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_GetTooltipDetailsByPlotNo](@P_PlotNo varchar(max))
as
begin
select l.PlotNo,l.Size,l.VillageId,f.FirstName+' '+f.MiddleName+' '+f.LastName as Name,f.FarmerCode,l.GPSPlotArea,v.Name Village
from Land l
inner join Farmer f on f.FarmerCode=l.FarmerCode
inner join Village v on v.Id=l.VillageId
where l.PlotNo=@P_PlotNo
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetTransactionDetailsByIMEINO]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetTransactionDetailsByIMEINO]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetTransactionDetailsByIMEINO 'Agent'
CREATE PROCEDURE [dbo].[SP_GetTransactionDetailsByIMEINO](@IMEINO varchar(255))
as
begin

select f.*,d.DocUrl,doc.DocUrl as AadharCardPhoto from
(select * from Farmer 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO))f
left join Documents d on d.FarmerCode = f.FarmerCode and d.DocType in ('photo')
left join Documents doc on doc.FarmerCode = f.FarmerCode and d.DocType in ('aadhar card')
where f.IsActive =1 

--select l.*,d.DocUrl from
--(select * from Land 
--where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO))l
--inner join Documents d on d.PlotNo = l.PlotNo
--where d.IsActive =1 and d.DocType in ('photo')

select l.*,d.DocUrl,doc.DocUrl as PattadarBookPhoto from
(select * from Land 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO))l
left join Documents d on d.PlotNo = l.PlotNo and d.DocType in ('photo')
left join Documents doc on doc.PlotNo = l.PlotNo and d.DocType in ('Pattadar Book')
where l.IsActive =1 

select * from GeoBoundaries 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)


select fb.*,d.DocUrl from
(select * from FarmerBank
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO))fb
inner join Documents d on d.FarmerCode = fb.FarmerCode
where d.IsActive =1 and d.DocType in ('bank passbook')

select * from Documents 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from LogBook 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from Fertilizer 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from OrganicAmendments 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from WaterRegimeonSeason 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from WaterReasonPreSeason
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from BorewellPumpOperations 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from WaterRegimeOnthefield 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

select * from HarvestDetails 
where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

 select * from SoilHealthCard 
 where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

  select * from Complaints
 where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)


 
  select * from ComplaintRepository
 where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

 
  select * from GHGEmissionCollection
 where IsActive=1 and CreatedByUserId in(select Id from Users where IMEINo=@IMEINO)

  select * into #TempFarmer from Farmer where 
  CreatedByUserId in (select Id from Users where IMEINo=@IMEINO)
  and IsActive =1

   select  tf.FarmerCode
          ,tf.FarmerTitle
		  ,tf.FirstName +' '+ tf.LastName as FarmerName
		  ,tf.TotalPlotArea
		  ,tf.PrimaryContactNum
          ,l.PattadarBookNo
          ,l.SurveyNo
		  ,doc.DocOldNum as DocumentNo
		  ,doc.DocType as DocumentType
         ,S.Name StateName
         ,D.Name DistrictName
		 ,M.Name MandalName
		 ,V.Name VillageName
		 ,fc.Name
		 ,fc.AgreementDate
		 ,fc.DigitalSign
		 ,fc.[1_1_a] as one_1_a
		 ,fc.[1_1_b]  as one_1_b
		 ,fc.[1_1_c]  as one_1_c
		 ,fc.[1_1_d] as one_1_d
		 ,fc.[1_1_e] as one_1_e
		  ,fc.[1_2_a] as one_2_a
		 ,fc.[1_2_b] as one_2_b
		 ,fc.[1_2_c] as one_2_c
		 ,fc.[1_2_d] as one_2_d
		 ,tf.AgentId
		 ,tf.VoluntaryId
		 ,docphoto.DocUrl FarmerPhoto
		 ,fc.Base64
		 from #TempFarmer tf 
   left join (select FarmerCode,string_agg(PattadarBookNo,',') AS PattadarBookNo,string_agg(SurveyNo,',') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = tf.FarmerCode
   left join FarmerConsent fc on fc.FarmerCode = tf.FarmerCode
   left join (select * from Documents  where DocType in ('aadhar card','pan card','voter id')) doc on doc.FarmerCode = tf.FarmerCode
   left join (select * from Documents  where DocType in ('photo')) docphoto on docphoto.FarmerCode = tf.FarmerCode
   inner join States S on S.Id = tf.StateId 
   inner join District D on D.Id = tf.DistrictId
   inner join Mandal M on M.Id = tf.MandalId
   inner join Village V on V.Id = tf.VillageId

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserAccessRights]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserAccessRights]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
Create PROCEDURE [dbo].[SP_GetUserAccessRights](@UserId INT,@Path VARCHAR(128)) AS
BEGIN

SELECT TOP 1 
rm.AddYN,rm.EditYN,rm.DeleteYN,rm.ViewYN
FROM RoleMenu rm 
INNER JOIN Menu m ON rm.MenuId = m.Id
INNER JOIN Users u ON u.RoleId = rm.RoleId
WHERE u.Id=@UserId
AND m.MenuType='I'
AND m.Path = @Path
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetUserByDistrictId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserByDistrictId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetUserByDistrictId null
CREATE proc [dbo].[SP_GetUserByDistrictId](@DistrictId int)
as
begin
   if @DistrictId is not null
   begin
  select Id,UserName from Users where Id in (
   select distinct(CreatedByUserId) from Farmer where DistrictId = @DistrictId and IsActive=1) and
   ViewYN = 1 and Id != 1 and RoleId = 3
   end
   else
   begin
   select Id,UserName from Users where 
   ViewYN = 1 and Id != 1 and RoleId = 3
   end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserByImeiDetailsforTab]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserByImeiDetailsforTab]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[SP_GetUserByImeiDetailsforTab] 
as
begin
select * from Users where IMEINo is not null
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetUserByIMEINo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUserByIMEINo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_GetUserByIMEINo](@P_IMEINo varchar(50))
as
begin
select * from Users where IMEINo=@P_IMEINo
end




GO

-- %% [markdown]
-- # [dbo].[SP_GetUsers]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsers]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetUsers] (@P_Id INT)
AS
BEGIN
    SELECT 
         [Id]
        ,[UserName]
        ,[Password]
        ,[FirstName]
        ,[MiddileName]
        ,[LastName]
        ,[EmailId]
        ,[MobileNumber]
        ,[RoleId]
        ,[IMEINo]
        ,[ViewYN]
        ,[DOB]
                ,[Education]
                ,[Address]
                ,[photo]
        ,[CreatedDate]
        ,[CreatedByUserId]
        ,[UpdatedDate]
        ,[UpdatedByUserId]
    FROM [dbo].[Users]
    WHERE Id = ISNULL(@P_Id, Id) --and RoleId = 3
        AND ViewYN = 1 order by UserName Asc
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetUsersDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetUsersDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 

 

CREATE PROCEDURE [dbo].[SP_GetUsersDetails] (@P_Id INT)
AS
BEGIN
    SELECT 
         t.[Id]
        ,t.[UserName]
        ,t.[Password]
        ,t.[FirstName]
        ,t.[MiddileName]
        ,t.[LastName]
        ,t.[EmailId]
        ,t.[MobileNumber]
        ,t.[RoleId]
        ,t.IMEINo
        ,c.RoleName
        ,t.[ViewYN]
        ,t.DOB
        ,t.Education
        ,t.Address
        ,t.photo
        ,t.[CreatedDate]
        ,c.Name AS CreatedByUser
        ,t.[UpdatedDate]
        ,u.Name AS UpdatedByUser
    FROM [dbo].[Users] t
    INNER JOIN UserInfo c ON c.Id=t.Id
    INNER JOIN UserInfo u ON u.Id=t.Id
    WHERE t.Id = ISNULL(@P_Id, t.Id)
        AND t.ViewYN = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetVillageDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVillageDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_GetVillageDetails] (@P_Id INT)
AS
BEGIN

	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[MandalId]
		,m.Name as MandalName
		,m.[DistrictId]
		,d.Name as DistrictName
		,d.[StateId]
		,s.name as StateName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,t.UpdatedByUserId
		,u.Name AS UpdatedByUser
        ,t.PinCode
	FROM [dbo].[Village] t
	
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	Left JOIN dbo.Mandal m ON m.Id = t.MandalId
	left JOIN dbo.District d ON d.Id = m.DistrictId
	inner JOIN dbo.States s ON s.Id = d.StateId

	WHERE t.Id = ISNULL(@P_Id, t.Id)
		AND t.IsActive = 1

		
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetVillageDetailsByMandalId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVillageDetailsByMandalId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO



CREATE PROCEDURE [dbo].[SP_GetVillageDetailsByMandalId] (@P_Id INT)
AS
BEGIN
	SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[MandalId]
		,m.Name as MandalName
		,m.[DistrictId]
		,d.Name as DistrictName
		,d.[StateId]
		,s.name as StateName
		,t.[IsActive]
		,t.PinCode
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,t.UpdatedByUserId
		,u.Name AS UpdatedByUser
	FROM [dbo].[Village] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	Left JOIN dbo.Mandal m ON m.Id = t.MandalId
	left JOIN dbo.District d ON d.Id = m.DistrictId
	inner JOIN dbo.States s ON s.Id = d.StateId
	WHERE t.MandalId = ISNULL(@P_Id, t.MandalId)
		AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetVillagesByAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVillagesByAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetVillagesByAgentId null
CREATE proc [dbo].[SP_GetVillagesByAgentId](@AgentId int)
as
begin

if @AgentId is not null
begin
select Id,Name,1 as cnt from Village where Id in(
select distinct(VillageId) from Farmer where CreatedByUserId = @AgentId and VillageId !=0)
end
else
begin
select * from
(select d.Id,d.Name,case when fd.VillageId is null then 0 else 1 end cnt from Village d
left join 
(select distinct(VillageId) from Farmer where VillageId !=0 and IsActive =1) fd on fd.VillageId = d.Id
where d.IsActive=1)x order by x.cnt desc
end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetVillagesNotInClusterDTLByMandalId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVillagesNotInClusterDTLByMandalId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create PROCEDURE [dbo].[SP_GetVillagesNotInClusterDTLByMandalId] (@P_Id INT)
AS
BEGIN
select * from
	(SELECT 
		 t.[Id]
		,t.[Code]
		,t.[Name]
		,t.[MandalId]
		,m.Name as MandalName
		,m.[DistrictId]
		,d.Name as DistrictName
		,d.[StateId]
		,s.name as StateName
		,t.[IsActive]
		,t.[CreatedDate]
		,t.[CreatedByUserId]
		,c.Name AS CreatedByUser
		,t.[UpdatedDate]
		,t.UpdatedByUserId
		,u.Name AS UpdatedByUser
	FROM [dbo].[Village] t
	INNER JOIN UserInfo c ON c.Id=t.CreatedByUserId
	INNER JOIN UserInfo u ON u.Id=t.UpdatedByUserId
	Left JOIN dbo.Mandal m ON m.Id = t.MandalId
	left JOIN dbo.District d ON d.Id = m.DistrictId
	inner JOIN dbo.States s ON s.Id = d.StateId
	WHERE t.MandalId = ISNULL(@P_Id, t.MandalId)
	AND t.IsActive = 1)X where X.Id not in (select VillageId from ClusterDTL where IsActive=1)
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetVolunatriesbyAgentId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVolunatriesbyAgentId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--  exec SP_GetVolunatriesbyAgentId null

CREATE PROCEDURE [dbo].[SP_GetVolunatriesbyAgentId] (@P_AgentId int)
AS
BEGIN
	SELECT 
	    t.Id,
		t.UserName as AgentName
	FROM [dbo].[Voluntary] t
WHERE t.AgentId = ISNULL(@P_AgentId, t.AgentId)
		AND t.IsActive = 1 order By t.UserName desc
END



GO

-- %% [markdown]
-- # [dbo].[SP_GetVoluntaryByIMEINo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVoluntaryByIMEINo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

Create proc [dbo].[SP_GetVoluntaryByIMEINo](@P_IMEINo varchar(50))
as
begin
select * from Voluntary where IMEINo=@P_IMEINo and IsActive=1
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetVoluntaryDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVoluntaryDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
--select * from Voluntary
--   exec SP_GetVoluntaryDetails null

CREATE PROCEDURE [dbo].[SP_GetVoluntaryDetails] (@P_Id INT)
AS
BEGIN
    SELECT 
         t.[Id]
        ,t.AgentId
        ,t.[UserName]
        ,t.[Password]
        ,t.[FirstName]
        ,t.[LastName]
        ,t.[EmailId]
        ,t.[MobileNumber]
        ,t.[RoleId]
        ,t.IMEINo
        ,t.IsActive
        ,t.DOB
        ,t.Education
        ,t.Address
        ,t.Photo
        ,t.[CreatedDate]
        ,t.[UpdatedDate]
,t.CreatedByUserId,
t.UpdatedByUserId
    FROM [dbo].[Voluntary] t
   
    WHERE t.Id = ISNULL(@P_Id, t.Id)
        AND t.IsActive = 1
END
GO

-- %% [markdown]
-- # [dbo].[SP_GetVoluntarytableDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVoluntarytableDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

 
--  exec SP_GetVoluntarytableDetails null

CREATE PROCEDURE [dbo].[SP_GetVoluntarytableDetails] (@P_Id INT)
AS
BEGIN
    SELECT 
         t.[Id]
        ,t.[UserName]
        ,v.UserName as AgentName
        ,t.[MobileNumber]
        ,c.Name as RoleName
        ,t.IMEINo
        ,t.RoleId
        ,t.IsActive
        ,t.DOB
        ,t.Education
        ,t.Address
        ,t.Photo
        ,t.[CreatedDate]
        ,t.UpdatedDate
    FROM [dbo].[Voluntary] t
    left JOIN Roles c ON c.Id=t.RoleId
    left JOIN Users u ON u.Id=t.UpdatedByUserId
    left join Users v on v.Id=t.AgentId
	inner join Users o on o.Id = t.CreatedByUserId
    WHERE t.Id = ISNULL(@P_Id, t.Id)
        AND t.IsActive = 1
END

GO

-- %% [markdown]
-- # [dbo].[SP_GetVoluntaryTransactionDetailsByIMEINo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVoluntaryTransactionDetailsByIMEINo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetVoluntaryTransactionDetailsByIMEINo '4c3b2e586efcade7'
CREATE proc [dbo].[SP_GetVoluntaryTransactionDetailsByIMEINo](@IMEINo varchar(255))
as
begin
  
   
--select * into #TempFarmer from Farmer where VoluntaryId in 
--(select Id from Voluntary where IMEINo=@IMEINo and IsActive =1) and IsActive =1

select * into #TempFarmer from Farmer
where 1=1 and (VoluntaryId in (select Id from Voluntary where IMEINo=@IMEINo and IsActive =1)
or AgentId in (select Id from Users where IMEINo=@IMEINo and ViewYN =1)) and IsActive =1;



select f.*,d.DocUrl,doc.DocUrl as AadharCardPhoto from
(select * from Farmer 
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer))f
left join Documents d on d.FarmerCode = f.FarmerCode and d.DocType in ('photo')
left join Documents doc on doc.FarmerCode = f.FarmerCode and d.DocType in ('aadhar card')
where f.IsActive =1 


 select l.*,d.DocUrl,doc.DocUrl as PattadarBookPhoto into #TempPlot from
(select * from Land where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer))l
left join Documents d on d.PlotNo = l.PlotNo and d.DocType in ('photo')
left join Documents doc on doc.PlotNo = l.PlotNo and d.DocType in ('Pattadar Book')
where l.IsActive =1 

select * from #TempPlot


select * from GeoBoundaries 
where IsActive=1 and PlotNo in(select PlotNo from #TempPlot)


select fb.*,d.DocUrl from
(select * from FarmerBank
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer))fb
inner join Documents d on d.FarmerCode = fb.FarmerCode
where d.IsActive =1 and d.DocType in ('bank passbook')

select * from Documents 
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer)

select * into #TempLogBook from LogBook 
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer)

select * from #TempLogBook

select * from Fertilizer 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from OrganicAmendments 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from WaterRegimeonSeason 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from WaterReasonPreSeason
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from BorewellPumpOperations 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from WaterRegimeOnthefield 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from HarvestDetails 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

 select * from SoilHealthCard 
 where IsActive=1 and PlotNo in(select PlotNo from #TempPlot)

  select * from Complaints
 where IsActive=1 and Code in(select LogBookNo from #TempLogBook)


 
  select * from ComplaintRepository
 where IsActive=1 and ComplaintCode in(select LogBookNo from #TempLogBook)

 
  select * from GHGEmissionCollection
 where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

 


select  tf.FarmerCode
          ,tf.FarmerTitle
		  ,tf.FirstName +' '+ tf.LastName as FarmerName
		  ,tf.TotalPlotArea
		  ,tf.PrimaryContactNum
          ,l.PattadarBookNo
          ,l.SurveyNo
		  ,doc.DocOldNum as DocumentNo
		  ,doc.DocType as DocumentType
         ,S.Name StateName
         ,D.Name DistrictName
		 ,M.Name MandalName
		 ,V.Name VillageName
		 ,fc.Name
		 ,fc.AgreementDate
		 ,fc.DigitalSign
		 ,fc.[1_1_a]
		 ,fc.[1_1_b]
		 ,fc.[1_1_c]
		 ,fc.[1_1_d]
		 ,fc.[1_1_e]
		 ,fc.[1_2_a]
		 ,fc.[1_2_b]
		 ,fc.[1_2_c]
		 ,fc.[1_2_d]
		 ,tf.AgentId
		 ,tf.VoluntaryId
		 ,docphoto.DocUrl FarmerPhoto
		 from #TempFarmer tf 
   left join (select FarmerCode,string_agg(PattadarBookNo,',') AS PattadarBookNo,string_agg(SurveyNo,',') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = tf.FarmerCode
   left join FarmerConsent fc on fc.FarmerCode = tf.FarmerCode
   left join (select * from Documents  where DocType in ('aadhar card','pan card','voter id')) doc on doc.FarmerCode = tf.FarmerCode
   left join (select * from Documents  where DocType in ('photo')) docphoto on docphoto.FarmerCode = tf.FarmerCode
   inner join States S on S.Id = tf.StateId 
   inner join District D on D.Id = tf.DistrictId
   inner join Mandal M on M.Id = tf.MandalId
   inner join Village V on V.Id = tf.VillageId

  select * from PipeInstallation where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer)

 drop table #TempFarmer
 drop table #TempPlot
 drop table #TempLogBook

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetVoluntaryTransactionDetailsByIMEINo_1]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetVoluntaryTransactionDetailsByIMEINo_1]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetVoluntaryTransactionDetailsByIMEINo_1 '4c3b2e586efcade7'
Create proc [dbo].[SP_GetVoluntaryTransactionDetailsByIMEINo_1](@IMEINo varchar(255))
as
begin
  
   
select * into #TempFarmer from Farmer where VoluntaryId in (select Id from Voluntary where IMEINo=@IMEINo and IsActive =1) and IsActive =1


select f.*,d.DocUrl,doc.DocUrl as AadharCardPhoto from
(select * from Farmer 
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer))f
left join Documents d on d.FarmerCode = f.FarmerCode and d.DocType in ('photo')
left join Documents doc on doc.FarmerCode = f.FarmerCode and d.DocType in ('aadhar card')
where f.IsActive =1 


 select l.*,d.DocUrl,doc.DocUrl as PattadarBookPhoto into #TempPlot from
(select * from Land where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer))l
left join Documents d on d.PlotNo = l.PlotNo and d.DocType in ('photo')
left join Documents doc on doc.PlotNo = l.PlotNo and d.DocType in ('Pattadar Book')
where l.IsActive =1 

select * from #TempPlot


select * from GeoBoundaries 
where IsActive=1 and PlotNo in(select PlotNo from #TempPlot)


select fb.*,d.DocUrl from
(select * from FarmerBank
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer))fb
inner join Documents d on d.FarmerCode = fb.FarmerCode
where d.IsActive =1 and d.DocType in ('bank passbook')

select * from Documents 
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer)

select * into #TempLogBook from LogBook 
where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer)

select * from #TempLogBook

select * from Fertilizer 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from OrganicAmendments 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from WaterRegimeonSeason 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from WaterReasonPreSeason
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from BorewellPumpOperations 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from WaterRegimeOnthefield 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

select * from HarvestDetails 
where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

 select * from SoilHealthCard 
 where IsActive=1 and PlotNo in(select PlotNo from #TempPlot)

  select * from Complaints
 where IsActive=1 and Code in(select LogBookNo from #TempLogBook)


 
  select * from ComplaintRepository
 where IsActive=1 and ComplaintCode in(select LogBookNo from #TempLogBook)

 
  select * from GHGEmissionCollection
 where IsActive=1 and LogBookNo in(select LogBookNo from #TempLogBook)

 


select  tf.FarmerCode
          ,tf.FarmerTitle
		  ,tf.FirstName +' '+ tf.LastName as FarmerName
		  ,tf.TotalPlotArea
		  ,tf.PrimaryContactNum
          ,l.PattadarBookNo
          ,l.SurveyNo
		  ,doc.DocOldNum as DocumentNo
		  ,doc.DocType as DocumentType
         ,S.Name StateName
         ,D.Name DistrictName
		 ,M.Name MandalName
		 ,V.Name VillageName
		 ,fc.Name
		 ,fc.AgreementDate
		 ,fc.DigitalSign
		 ,fc.[1_1_a]
		 ,fc.[1_1_b]
		 ,fc.[1_1_c]
		 ,fc.[1_1_d]
		 ,fc.[1_1_e]
		 ,fc.[1_2_a]
		 ,fc.[1_2_b]
		 ,fc.[1_2_c]
		 ,fc.[1_2_d]
		 ,tf.AgentId
		 ,tf.VoluntaryId
		 ,docphoto.DocUrl FarmerPhoto
		 from #TempFarmer tf 
   left join (select FarmerCode,string_agg(PattadarBookNo,',') AS PattadarBookNo,string_agg(SurveyNo,',') AS SurveyNo 
from Land group by FarmerCode) l on l.FarmerCode = tf.FarmerCode
   left join FarmerConsent fc on fc.FarmerCode = tf.FarmerCode
   left join (select * from Documents  where DocType in ('aadhar card','pan card','voter id')) doc on doc.FarmerCode = tf.FarmerCode
   left join (select * from Documents  where DocType in ('photo')) docphoto on docphoto.FarmerCode = tf.FarmerCode
   inner join States S on S.Id = tf.StateId 
   inner join District D on D.Id = tf.DistrictId
   inner join Mandal M on M.Id = tf.MandalId
   inner join Village V on V.Id = tf.VillageId

  select * from PipeInstallation where IsActive=1 and FarmerCode in(select FarmerCode from #TempFarmer)

 drop table #TempFarmer
 drop table #TempPlot
 drop table #TempLogBook

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetWaterCyclesByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWaterCyclesByFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetWaterCyclesByFarmerCode 'F_112317147_69',1
CREATE proc [dbo].[SP_GetWaterCyclesByFarmerCode](@FarmerCode varchar(255),@cycleId int)
as
begin
  if @cycleId = 1
  begin
		select * from Documents where DocType like 'water cycle 1%' and FarmerCode=@FarmerCode and IsActive=1
		order by DocType
  end
 else if @cycleId = 2
  begin
		select * from Documents where DocType like 'water cycle 2%' and FarmerCode=@FarmerCode and IsActive=1
		order by DocType
  end
  else if @cycleId = 3
  begin
		select * from Documents where DocType like 'water cycle 3%' and FarmerCode=@FarmerCode and IsActive=1
		order by DocType
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWaterReasonPreSeasonDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWaterReasonPreSeasonDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetWaterReasonPreSeasonDetails](@P_ID int)
as 
begin

select ID,LogBookNo,Field,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
  WaterReasonPreSeason where ID = isnull(@P_ID,ID)
end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWaterRegimeonSeasonDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWaterRegimeonSeasonDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetWaterRegimeonSeasonDetails](@P_ID int)
as 
begin

select ID,LogBookNo,Field,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
  WaterRegimeonSeason  where ID = isnull(@P_ID,ID)
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetWaterRegimeOnthefieldDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWaterRegimeOnthefieldDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create procedure [dbo].[SP_GetWaterRegimeOnthefieldDetails](@P_ID int)
as 
begin

select ID,LogBookNo,Field,IsActive,CreatedDate,CreatedByUserId,UpdatedDate,UpdatedByUserId from 
 WaterRegimeOnthefield where ID = isnull(@P_ID,ID)
end
 
GO

-- %% [markdown]
-- # [dbo].[SP_GetWeeklyCalendar]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWeeklyCalendar]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

--exec SP_GetWeeklyCalendar 2023
CREATE proc [dbo].[SP_GetWeeklyCalendar](@Year int)
as
begin
   select Id,Year,WeekOfYear,WeekStart,WeekEnd, cast(WeekStart as varchar(255))+ ' to ' + cast(WeekEnd as varchar(255)) as Weekly
   from WeeklyCalendar where  [Year] = isnull(@Year,YEAR(GETDATE())) and WeekEnd >= cast(getdate() as date)
end

GO

-- %% [markdown]
-- # [dbo].[SP_GetWeeklyProgress]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWeeklyProgress]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetWeeklyProgress null
CREATE Proc [dbo].[SP_GetWeeklyProgress](@AgentId int)
as
begin
select wc.Id,wc.Year,wc.WeekOfYear,wc.WeekStart,wc.WeekEnd,isnull(t.AgentId,0) AgentId,isnull(t.TargetRegistration,0) TargetRegistration ,isnull(t.TargetArea,0) TargetArea,
cast(wc.WeekStart as varchar(255)) +' to '+cast(wc.WeekEnd as varchar(255)) Weekly into #Temp
from WeeklyCalendar wc 
left join (select * from AgentTargets where AgentId = isnull(@AgentId,AgentId)) t on t.WeekId = wc.Id
where  wc.WeekStart>='2023-05-01' and wc.WeekEnd <= '2023-06-25'


Create table #TempSum(SNo int,WeekStart date,WeekEnd date,TargetRegistration int,TargetArea float,ActualRegistration int,ActualArea float)
insert into #TempSum(SNo,WeekStart,WeekEnd,TargetRegistration,TargetArea)
select ROW_NUMBER() over (order by WeekStart,WeekEnd) SNo,WeekStart,WeekEnd,sum(TargetRegistration) TargetRegistration,sum(TargetArea) TargetArea from #Temp group by WeekStart,WeekEnd


declare @NoOfRecords int
set @NoOfRecords = (select COUNT(SNo) from #TempSum)

declare @Counter int
set @Counter = 1 

while (@Counter <= @NoOfRecords)
begin
   declare @StartDate date,@EndDate date,@ActualRegistartion int,@ActualArea float
   select @StartDate = WeekStart,@EndDate = WeekEnd from #TempSum where SNo = @Counter
   
   select @ActualRegistartion =isnull(count(Id),0),@ActualArea = isnull(sum(TotalPlotArea),0) from Farmer  
   where FarmerCode in (select FarmerCode from FarmerConsent 
   where CreatedDate > = @StartDate and CreatedDate <= @EndDate and 
   AgentId = isnull(@AgentId,AgentId))

   update #TempSum set ActualRegistration = @ActualRegistartion,ActualArea = @ActualArea where WeekStart=@StartDate and WeekEnd = @EndDate
   set @Counter = @Counter + 1

end

select *,case when TargetRegistration != 0 then cast((cast(ActualRegistration as float)/cast(TargetRegistration as float)*100) as varchar(255))+'%' else '0%' end Percentage,'Week ' + 
cast(SNo as varchar(255)) Weekly from #TempSum


drop table #Temp
drop table #TempSum

end
GO

-- %% [markdown]
-- # [dbo].[SP_GetWeeklyProgressData]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWeeklyProgressData]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_GetWeeklyProgressData null,11,null
CREATE proc [dbo].[SP_GetWeeklyProgressData](@AgentId int,@DistrictId int,@WeekId int)
as
begin



select wc.Id,wc.Year,wc.WeekOfYear,wc.WeekStart,wc.WeekEnd,isnull(t.AgentId,0) AgentId,isnull(t.TargetRegistration,0) TargetRegistration ,isnull(t.TargetArea,0) TargetArea,
cast(wc.WeekStart as varchar(255)) +' to '+cast(wc.WeekEnd as varchar(255)) Weekly into #Temp
from WeeklyCalendar wc 
left join (select * from AgentTargets where AgentId = isnull(@AgentId,AgentId) and WeekId = isnull(@WeekId,WeekId)) t on t.WeekId = wc.Id 
where  wc.WeekStart>='2023-05-01' and wc.WeekEnd <= '2023-06-25' 


Create table #TempSum(SNo int,WeekStart date,WeekEnd date,TargetRegistration int,TargetArea float,ActualRegistration int,ActualArea float)
insert into #TempSum(SNo,WeekStart,WeekEnd,TargetRegistration,TargetArea)
select ROW_NUMBER() over (order by WeekStart,WeekEnd) SNo,WeekStart,WeekEnd,sum(TargetRegistration) TargetRegistration,sum(TargetArea) TargetArea from #Temp group by WeekStart,WeekEnd


declare @NoOfRecords int
set @NoOfRecords = (select COUNT(SNo) from #TempSum)

declare @Counter int
set @Counter = 1 

while (@Counter <= @NoOfRecords)
begin
   declare @StartDate date,@EndDate date,@ActualRegistartion int,@ActualArea float
   select @StartDate = WeekStart,@EndDate = WeekEnd from #TempSum where SNo = @Counter
   
   select @ActualRegistartion =isnull(count(Id),0),@ActualArea = isnull(sum(TotalPlotArea),0) from Farmer  
   where FarmerCode in (select FarmerCode from FarmerConsent 
   where CreatedDate > = @StartDate and CreatedDate <= @EndDate and 
   AgentId = isnull(@AgentId,AgentId)) and DistrictId = ISNULL(@DistrictId,DistrictId)

   update #TempSum set ActualRegistration = @ActualRegistartion,ActualArea = @ActualArea where WeekStart=@StartDate and WeekEnd = @EndDate
   set @Counter = @Counter + 1

end

select *,case when TargetRegistration != 0 then cast(cast((cast(ActualRegistration as float)/cast(TargetRegistration as float)*100) as decimal(18,2)) as varchar(255))+'%' else '0%' end Percentage,'Week ' + 
cast(SNo as varchar(255)) Weekly from #TempSum


drop table #Temp
drop table #TempSum

end

GO

-- %% [markdown]
-- # [dbo].[SP_GetWeekWiseFilters]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_GetWeekWiseFilters]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
  
  
--exec SP_GetWeekWiseFilters  
CREATE PROCEDURE [dbo].[SP_GetWeekWiseFilters]   
AS  
BEGIN  
select Id,concat('Week-',ROW_NUMBER()over(order by weekofyear)) as week,   
weekStart,   
Weekend,  
concat('(',weekStart, ':',Weekend,')') as dates from weeklycalendar   
WHERE weekofyear>=18  
  
END  
GO

-- %% [markdown]
-- # [dbo].[SP_InactiveFarmerIdentity]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_InactiveFarmerIdentity]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_InactiveFarmerIdentity](@FarmerCode varchar(255))
as
begin
update Documents set IsActive=0 where FarmerCode=@FarmerCode and
DocType in ('aadhar card','voter id','driving licence','pan card')
end
GO

-- %% [markdown]
-- # [dbo].[SP_InActiveGeoBoundariesByPlotNo]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_InActiveGeoBoundariesByPlotNo]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_InActiveGeoBoundariesByPlotNo](@P_PlotNo varchar(255),@P_Area varchar(255),@No int)
as
begin


 declare @sumof5 decimal(18,6)
 if @No = 1
 begin
    set @sumof5 = (select PlotArea2+PlotArea3+PlotArea4+PlotArea5 from Land where PlotNo=@P_PlotNo)
	set @sumof5 = @sumof5 + cast(@P_Area as decimal(18,6))
	 update Land set GPSPlotArea=@sumof5,PlotArea1=@P_Area where PlotNo=@P_PlotNo 
 end
 else if @No = 2
 begin
    set @sumof5 = (select PlotArea1+PlotArea3+PlotArea4+PlotArea5 from Land where PlotNo=@P_PlotNo)
	set @sumof5 = @sumof5 + cast(@P_Area as decimal(18,6))
	 update Land set GPSPlotArea=@sumof5,PlotArea2=@P_Area where PlotNo=@P_PlotNo 
 end
 else if @No = 3
 begin
    set @sumof5 = (select PlotArea1+PlotArea2+PlotArea4+PlotArea5 from Land where PlotNo=@P_PlotNo)
	set @sumof5 = @sumof5 + cast(@P_Area as decimal(18,6))
	 update Land set GPSPlotArea=@sumof5,PlotArea3=@P_Area where PlotNo=@P_PlotNo 
 end
  else if @No = 4
 begin
    set @sumof5 = (select PlotArea1+PlotArea2+PlotArea3+PlotArea5 from Land where PlotNo=@P_PlotNo)
	set @sumof5 = @sumof5 + cast(@P_Area as decimal(18,6))
	 update Land set GPSPlotArea=@sumof5,PlotArea4=@P_Area where PlotNo=@P_PlotNo 
 end
  else if @No = 5
 begin
    set @sumof5 = (select PlotArea1+PlotArea2+PlotArea3+PlotArea4 from Land where PlotNo=@P_PlotNo)
	set @sumof5 = @sumof5 + cast(@P_Area as decimal(18,6))
	 update Land set GPSPlotArea=@sumof5,PlotArea5=@P_Area where PlotNo=@P_PlotNo 
 end

 update GeoBoundaries set IsActive=0 where PlotNo=@P_PlotNo and GeoCategoryTypeId = @No
end



GO

-- %% [markdown]
-- # [dbo].[SP_ManualDocuments]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ManualDocuments]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE proc [dbo].[SP_ManualDocuments]
(
  @FarmerCode varchar(500),
  @DocUrl varchar(500),
  @DocType varchar(100),
  @IsActive bit,
  @CreatedDate datetime,
  @CreatedByUserId int,
  @UpdatedDate datetime,
  @UpdatedByUserId int,
  @ErrorNumber INT OUTPUT,
  @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
    	BEGIN TRANSACTION
	BEGIN TRY
	      declare @cnt int
		  set @cnt = (select count(Id) from Documents where FarmerCode = @FarmerCode 
		  and DocType = @DocType and IsActive =1)

if @cnt = 0
   begin
			INSERT INTO [dbo].[Documents] (
				 [FarmerCode]
				,[DocUrl]
				,[DocType]
				,[IsActive]
				,[CreatedByUserId]
				,[CreatedDate]
				,[UpdatedByUserId]
				,[UpdatedDate]
				)
			VALUES (
				 @FarmerCode
				,@DocUrl
				,@DocType
				,ISNULL(@IsActive, 1)
				,@CreatedByUserId
				,ISNULL(@CreatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				,@UpdatedByUserId
				,ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
				)
	end
	else
	begin
	     update Documents 
		 set DocUrl = @DocUrl,
		 DocType = @DocType,
		 IsActive = @IsActive,
		 UpdatedByUserId = @UpdatedByUserId,
		 UpdatedDate = ISNULL(@UpdatedDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time' 
		 where FarmerCode = @FarmerCode and DocType = @DocType
	end

	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_ManualPlotImage]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ManualPlotImage]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE Proc [dbo].[SP_ManualPlotImage](@PlotNo varchar(255),@LandImage varchar(max))
as
begin

update Land set LandImage=@LandImage where PlotNo =@PlotNo and IsActive =1
end
GO

-- %% [markdown]
-- # [dbo].[SP_Raaji]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_Raaji]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_Raaji
CREATE proc [dbo].[SP_Raaji]
as
begin
select  FarmerCode,FirstName,CreatedDate into #Temp from
(select f.FarmerCode,f.FirstName +' '+f.LastName as FirstName,isnull(p.cnt,0) NoOfPlots,case when fclb.cnt>0 then 1 else 0 end FarmerLogBook,
case when fp.FarmerCode is not null then 1 else 0 end FarmerPhotoTaken,
case when fip.FarmerCode is not null then 1 else 0 end FarmerIdentityProofTaken,
case when fbp.FarmerCode is not null then 1 else 0 end FarmerBankPassbookTaken,
case when p.FarmerCode is not null then 1 else 0 end PlotTaken,
case when pp.FarmerCode is not null then 1 else 0 end PlotPhotoTaken,
case when pin.FarmerCode is not null then 1 else 0 end PipeInstallationTaken,
u.FirstName as Agent,pin.CreatedDate 
from [dbo].[vw_farmer] f
left join [dbo].[Users] u on u.Id = f.CreatedByUserId
left join [dbo].[vw_farmerphoto] fp on fp.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmeridentityproof] fip on fip.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmerbankpassbook] fbp on fbp.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmerlogbook] fclb on fclb.FarmerCode = f.FarmerCode
left join (select FarmerCode,count(FarmerCode) cnt from [dbo].[vw_plot] group by FarmerCode)p on p.FarmerCode = f.FarmerCode
left join (select FarmerCode,count(FarmerCode) cnt from [dbo].[vw_plotphoto] group by FarmerCode) pp on pp.FarmerCode = f.FarmerCode
left join [dbo].[vw_pipeinstalled] pin on pin.FarmerCode = f.FarmerCode
where f.CreatedByUserId = isnull(null,f.CreatedByUserId)
and f.DistrictId = ISNULL(null,f.DistrictId)
) X where FarmerPhotoTaken = 1 and
FarmerIdentityProofTaken = 1 and
FarmerBankPassbookTaken = 1 and
PlotTaken =1 and
PlotPhotoTaken =1 and
PipeInstallationTaken =1 and
FarmerLogBook = 1


select ROW_NUMBER() over(partition by FarmerCode  order by FarmerCode) SNo,* into #sampleLand from Land 
where FarmerCode in (select FarmerCode from #Temp)

select ROW_NUMBER() over(Order by f.FarmerCode) RowId, f.FarmerCode,f.FirstName +' '+f.LastName as FarmeName,d.Name DistrictName,
m.Name MandalName,v.Name VillageName,l.PlotNo,f.PrimaryContactNum,doc.DocOldNum as DocumentNo,l.PattadarBookNo,
l.Plotownership,f.TotalPlotArea ,u.UserName as Agent--,t.CreatedDate as PipeInstalled
into #Final
from #Temp t
left join Farmer f on f.FarmerCode = t.FarmerCode
left join District d on d.Id = f.DistrictId
left join Mandal m on m.Id = f.MandalId
left join Village v on v.Id = f.VillageId
left join #sampleLand l on l.FarmerCode = f.FarmerCode and SNo =1
left join Documents doc on doc.FarmerCode = f.FarmerCode 
--left join vw_pipeinstalled pp on pp.PlotNo = l.PlotNo
and DocType in ('aadhar card','pan card','voter id')
left join Users u on u.Id = f.CreatedByUserId

--select * from #Final order by RowId


CREATE TABLE #TempImages
(
   Id int,
   FarmerCode varchar(255),
   FarmerName varchar(255),
   photo varchar(255),
   [aadhar card]  varchar(255),
   [bank passbook] varchar(255),
   [plot photo] varchar(255),
   [pipe installed] varchar(255)
)


CREATE TABLE #karmaTemp
(
   Id int,
   FarmerCode varchar(255),
   [cycle1_1] varchar(255),
   [cycle1_2] varchar(255),
   [cycle1_3] varchar(255)
)


DECLARE 
    @FarmerCode VARCHAR(MAX), 
    @FarmeName VARCHAR(MAX),
	@RowId int
DECLARE cursor_product CURSOR
FOR SELECT 
        FarmerCode,
		FarmeName,
		RowId
    FROM 
        #Final order by RowId;

OPEN cursor_product;

FETCH NEXT FROM cursor_product INTO 
    @FarmerCode, 
    @FarmeName,@RowId;

WHILE @@FETCH_STATUS = 0
    BEGIN
	--insert into #TempImages(FarmerCode,[photo],[aadhar card],[bank passbook],[plot photo],[pipe installed])
	--exec SP_SampleFarmerKYCByFarmerCode @FarmerCode = @FarmerCode

	select * into #Temp1 from 
(select  @FarmerCode as FarmerCode, DocUrl,DocType from Documents where FarmerCode=@FarmerCode 
and DocType in ('photo','bank passbook','voter id','pan card','aadhar card')
union
select @FarmerCode as FarmerCode,DocUrl,'plot photo' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('photo') 
union
select @FarmerCode as FarmerCode,DocUrl,'pipe installed' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('Water Regime') and DocOldNum='Pipe Installation')X

declare @cnt int
set @cnt = (select count(*) from #Temp)
if @cnt>1
begin
insert into #TempImages(FarmerCode,[photo],[aadhar card],[bank passbook],[plot photo],[pipe installed])
SELECT @FarmerCode as FarmerCode,*
FROM
(
  SELECT  [DocType], DocUrl
  FROM #Temp1
) src
PIVOT
(
  MAX(DocUrl)
  FOR [DocType] IN ([photo], [aadhar card], [bank passbook], [plot photo], [pipe installed])
) piv;
drop table #Temp1



select d.PlotNo,d.DocUrl,d.DocOldNum,l.FarmerCode,d.CreatedByUserId,l.DistrictId,d.CreatedDate,d.DocExtension into #dummy from
(select * from 
(select ROW_NUMBER() over(Partition by PlotNo order by CreatedDate) RowId,d.PlotNo,d.DocUrl,d.DocOldNum,d.CreatedByUserId,d.CreatedDate,d.DocExtension from Documents d
where d.DocType in ('Water Regime') and d.IsActive =1 and DocExtension in ('1111@2','1111@3','1111@4'))X)d
inner join Land l on l.PlotNo = d.PlotNo and l.FarmerCode = @FarmerCode


insert into #karmaTemp(FarmerCode,[cycle1_1],[cycle1_2],[cycle1_3])
SELECT @FarmerCode as FarmerCode,*
FROM
(
  SELECT  DocExtension, DocUrl
  FROM #dummy
) src
PIVOT
(
  MAX(DocUrl)
  FOR DocExtension IN ([1111@2],[1111@3],[1111@4])
) piv;

drop table #dummy


end

update #TempImages set FarmerName = @FarmeName,Id=@RowId where FarmerCode = @FarmerCode
	  
      FETCH NEXT FROM cursor_product INTO 
      @FarmerCode,@FarmeName,@RowId;
    END;

CLOSE cursor_product;

DEALLOCATE cursor_product;

select f.*,ti.photo,ti.[aadhar card],ti.[bank passbook],ti.[plot photo],ti.[pipe installed] into #withImages from #Final f 
inner join #TempImages ti on ti.FarmerCode = f.FarmerCode

--select * from #withImages order by RowId

select wi.*,kt.cycle1_1 as Dry,kt.cycle1_2 as Flooded,kt.cycle1_3 as SecondDry,rt.DocURL as LogBookImage,rt1.DocURL as Agreements,
r2.PipeInstalled,r2.FirstDry,r2.FirstFlood,r2.SecondDry,r2.SecondFlood
from #withImages wi
left join #karmaTemp kt on kt.FarmerCode = wi.FarmerCode
left join Raajitable rt on rt.FarmerCode = wi.FarmerCode
left join Raajitable1 rt1 on rt1.FarmerCode = wi.FarmerCode
left join Land l on l.PlotNo = wi.PlotNo
left join RaajiTable2 r2 on r2.FarmerCode = wi.FarmerCode
order by wi.RowId


drop table #Temp
drop table #sampleLand
drop table #Final
drop table #withImages
drop table #karmaTemp
drop table #TempImages

end


GO

-- %% [markdown]
-- # [dbo].[SP_RaajiFarmerConsent]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_RaajiFarmerConsent]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_RaajiFarmerConsent
CREATE proc [dbo].[SP_RaajiFarmerConsent]
as
begin

select fc.FarmerCode,f.FirstName+' '+f.LastName as FarmerName,f.IdentityCode as DocumentNo,f.PrimaryContactNum ContactNo,f.TotalPlotArea,
d.Name DistrictName,m.Name MandalName,v.Name VillageName,p.PlotNo,p.PattadarBookNo,p.Plotownership,docphoto.DocUrl as FarmerPhoto,docaadhar.DocUrl as FarmerAadhar,
docpattadar.DocUrl as FarmerPattadarBook
,docbank.DocUrl as FarmerBankPassbook,docfarmerconsent.DocUrl as FarmerConsent
,fc.AgreementDate,u.UserName as Agent from FarmerConsent fc 
left join Farmer f on f.FarmerCode = fc.FarmerCode
left join District d on d.Id = f.DistrictId
left join Mandal m on m.Id = f.MandalId
left join Village v on v.Id = f.VillageId
left join Land p on p.FarmerCode = f.FarmerCode
left join Users u on u.Id = fc.AgentId
left join(select * from Documents where DocType='photo' ) docphoto on docphoto.FarmerCode = f.FarmerCode and docphoto.IsActive = 1
left join(select * from Documents where DocType='aadhar card' ) docaadhar on docaadhar.FarmerCode = f.FarmerCode and docaadhar.IsActive = 1
left join(select * from Documents where DocType='Pattadar Book' ) docpattadar on docpattadar.FarmerCode = f.FarmerCode and docpattadar.IsActive = 1
left join(select * from Documents where DocType='bank passbook' ) docbank on docbank.FarmerCode = f.FarmerCode and docbank.IsActive = 1
left join(select * from Documents where DocType='Agreement' ) docfarmerconsent on docfarmerconsent.FarmerCode = f.FarmerCode and docfarmerconsent.IsActive = 1
where fc.FarmerCode like 'F_%'

end


GO

-- %% [markdown]
-- # [dbo].[SP_RaajiSowingDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_RaajiSowingDate]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_RaajiSowingDate
CREATE proc [dbo].[SP_RaajiSowingDate]
as
begin
select  FarmerCode,FirstName,CreatedDate into #Temp from
(select f.FarmerCode,f.FirstName +' '+f.LastName as FirstName,isnull(p.cnt,0) NoOfPlots,case when fclb.cnt>0 then 1 else 0 end FarmerLogBook,
case when fp.FarmerCode is not null then 1 else 0 end FarmerPhotoTaken,
case when fip.FarmerCode is not null then 1 else 0 end FarmerIdentityProofTaken,
case when fbp.FarmerCode is not null then 1 else 0 end FarmerBankPassbookTaken,
case when p.FarmerCode is not null then 1 else 0 end PlotTaken,
case when pp.FarmerCode is not null then 1 else 0 end PlotPhotoTaken,
case when pin.FarmerCode is not null then 1 else 0 end PipeInstallationTaken,
u.FirstName as Agent,pin.CreatedDate 
from [dbo].[vw_farmer] f
left join [dbo].[Users] u on u.Id = f.CreatedByUserId
left join [dbo].[vw_farmerphoto] fp on fp.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmeridentityproof] fip on fip.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmerbankpassbook] fbp on fbp.FarmerCode = f.FarmerCode
left join [dbo].[vw_farmerlogbook] fclb on fclb.FarmerCode = f.FarmerCode
left join (select FarmerCode,count(FarmerCode) cnt from [dbo].[vw_plot] group by FarmerCode)p on p.FarmerCode = f.FarmerCode
left join (select FarmerCode,count(FarmerCode) cnt from [dbo].[vw_plotphoto] group by FarmerCode) pp on pp.FarmerCode = f.FarmerCode
left join [dbo].[vw_pipeinstalled] pin on pin.FarmerCode = f.FarmerCode
where f.CreatedByUserId = isnull(null,f.CreatedByUserId)
and f.DistrictId = ISNULL(null,f.DistrictId)
) X where FarmerPhotoTaken = 1 and
FarmerIdentityProofTaken = 1 and
FarmerBankPassbookTaken = 1 and
PlotTaken =1 and
PlotPhotoTaken =1 and
PipeInstallationTaken =1 and
FarmerLogBook = 1


select ROW_NUMBER() over(partition by FarmerCode  order by FarmerCode) SNo,* into #sampleLand from Land 
where FarmerCode in (select FarmerCode from #Temp)

select ROW_NUMBER() over(Order by f.FarmerCode) RowId, f.FarmerCode,f.FirstName +' '+f.LastName as FarmeName,d.Name DistrictName,
m.Name MandalName,v.Name VillageName,l.PlotNo,f.PrimaryContactNum,doc.DocOldNum as DocumentNo,
l.Plotownership,f.TotalPlotArea ,u.UserName as Agent,t.CreatedDate as PipeInstalled
into #Final
from #Temp t
left join Farmer f on f.FarmerCode = t.FarmerCode
left join District d on d.Id = f.DistrictId
left join Mandal m on m.Id = f.MandalId
left join Village v on v.Id = f.VillageId
left join #sampleLand l on l.FarmerCode = f.FarmerCode and SNo =1
left join Documents doc on doc.FarmerCode = f.FarmerCode 
--left join vw_pipeinstalled pp on pp.PlotNo = l.PlotNo
and DocType in ('aadhar card','pan card','voter id')
left join Users u on u.Id = f.CreatedByUserId

--select * from #Final order by RowId


CREATE TABLE #TempImages
(
   Id int,
   FarmerCode varchar(255),
   FarmerName varchar(255),
   photo varchar(255),
   [aadhar card]  varchar(255),
   [bank passbook] varchar(255),
   [plot photo] varchar(255),
   [pipe installed] varchar(255)
)


CREATE TABLE #karmaTemp
(
   Id int,
   FarmerCode varchar(255),
   [cycle1_1] varchar(255),
   [cycle1_2] varchar(255)
)


DECLARE 
    @FarmerCode VARCHAR(MAX), 
    @FarmeName VARCHAR(MAX),
	@RowId int
DECLARE cursor_product CURSOR
FOR SELECT 
        FarmerCode,
		FarmeName,
		RowId
    FROM 
        #Final order by RowId;

OPEN cursor_product;

FETCH NEXT FROM cursor_product INTO 
    @FarmerCode, 
    @FarmeName,@RowId;

WHILE @@FETCH_STATUS = 0
    BEGIN
	--insert into #TempImages(FarmerCode,[photo],[aadhar card],[bank passbook],[plot photo],[pipe installed])
	--exec SP_SampleFarmerKYCByFarmerCode @FarmerCode = @FarmerCode

	select * into #Temp1 from 
(select  @FarmerCode as FarmerCode, DocUrl,DocType from Documents where FarmerCode=@FarmerCode 
and DocType in ('photo','bank passbook','voter id','pan card','aadhar card')
union
select @FarmerCode as FarmerCode,DocUrl,'plot photo' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('photo') 
union
select @FarmerCode as FarmerCode,DocUrl,'pipe installed' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('Water Regime') and DocOldNum='Pipe Installation')X

declare @cnt int
set @cnt = (select count(*) from #Temp)
if @cnt>1
begin
insert into #TempImages(FarmerCode,[photo],[aadhar card],[bank passbook],[plot photo],[pipe installed])
SELECT @FarmerCode as FarmerCode,*
FROM
(
  SELECT  [DocType], DocUrl
  FROM #Temp1
) src
PIVOT
(
  MAX(DocUrl)
  FOR [DocType] IN ([photo], [aadhar card], [bank passbook], [plot photo], [pipe installed])
) piv;
drop table #Temp1



select d.PlotNo,d.DocUrl,d.DocOldNum,l.FarmerCode,d.CreatedByUserId,l.DistrictId,d.CreatedDate,d.DocExtension into #dummy from
(select * from 
(select ROW_NUMBER() over(Partition by PlotNo order by CreatedDate) RowId,d.PlotNo,d.DocUrl,d.DocOldNum,d.CreatedByUserId,d.CreatedDate,d.DocExtension from Documents d
where d.DocType in ('Water Regime') and d.IsActive =1 and DocExtension in ('1111@2','1111@3'))X)d
inner join Land l on l.PlotNo = d.PlotNo and l.FarmerCode = @FarmerCode


insert into #karmaTemp(FarmerCode,[cycle1_1],[cycle1_2])
SELECT @FarmerCode as FarmerCode,*
FROM
(
  SELECT  DocExtension, DocUrl
  FROM #dummy
) src
PIVOT
(
  MAX(DocUrl)
  FOR DocExtension IN ([1111@2],[1111@3])
) piv;

drop table #dummy


end

update #TempImages set FarmerName = @FarmeName,Id=@RowId where FarmerCode = @FarmerCode
	  
      FETCH NEXT FROM cursor_product INTO 
      @FarmerCode,@FarmeName,@RowId;
    END;

CLOSE cursor_product;

DEALLOCATE cursor_product;

select f.*,ti.photo,ti.[aadhar card],ti.[bank passbook],ti.[plot photo],ti.[pipe installed] into #withImages from #Final f 
inner join #TempImages ti on ti.FarmerCode = f.FarmerCode

--select * from #withImages order by RowId

select wi.*,kt.cycle1_1 as Dry,kt.cycle1_2 as Flooded into #forlogbook  from #withImages wi
left join #karmaTemp kt on kt.FarmerCode = wi.FarmerCode order by wi.RowId

--select * from #forlogbook order by RowId

select * into #dummyLogbook from
(select ROW_NUMBER() over(partition by PlotNo order by PlotNo) LNo,* from LogBook where IsActive =1)
X where LNo=1

select
 flb.FarmerCode,
 f.FirstName+' '+f.LastName FarmerName,flb.Agent,
flb.PlotNo,lb.LogBookNo,lb.DateOfSowing,
 c.Name as CropName,
 cv.Name as CropVariety,
 d.Name as SeedVariety,
 sd.Name as SeedDistributor,
 s.Name as Season,
 ld.Name as CultivationPractice
 ,fer.Qty as FertilizerQty
 ,la.PattadarBookNo
 ,la.SurveyNo
from #forlogbook flb
left join #dummyLogbook lb on lb.PlotNo = flb.PlotNo
left join Farmer f on f.FarmerCode = flb.FarmerCode
left join Crop c on c.Id = lb.Crop
left Join Season s on s.Id = lb.Season
left Join LookupDtl ld on ld.Id = lb.CultivationPractice
left Join CropVariety cv on cv.Id = lb.CropVariety
left Join LookupDtl d on d.Id = lb.SeedVariety
left Join SeedDistributor sd on sd.Id = lb.SeedDistributor
left join Fertilizer fer on fer.LogBookNo = lb.LogBookNo
left join Land la on la.PlotNo = flb.PlotNo
drop table #Temp
drop table #sampleLand
drop table #Final
drop table #withImages
drop table #karmaTemp
drop table #TempImages

drop table #forlogbook
drop table #dummyLogbook
end


GO

-- %% [markdown]
-- # [dbo].[SP_SampleFarmerKYCByFarmerCode]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_SampleFarmerKYCByFarmerCode]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_SampleFarmerKYCByFarmerCode '037223481398'
CREATE Proc [dbo].[SP_SampleFarmerKYCByFarmerCode](@FarmerCode varchar(255))
as
begin

select * into #Temp from 
(select  @FarmerCode as FarmerCode, DocUrl,DocType from Documents where FarmerCode=@FarmerCode 
and DocType in ('photo','bank passbook','voter id','pan card','aadhar card')
union
select @FarmerCode as FarmerCode,DocUrl,'plot photo' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('photo') 
union
select @FarmerCode as FarmerCode,DocUrl,'pipe installed' DocType from Documents where PlotNo in(select PlotNo from Land where FarmerCode=@FarmerCode) 
and DocType in ('Water Regime') and DocOldNum='Pipe Installation')X

declare @cnt int
set @cnt = (select count(*) from #Temp)
print @cnt
if @cnt>1
begin
SELECT @FarmerCode as FarmerCode,*
FROM
(
  SELECT  [DocType], DocUrl
  FROM #Temp
) src
PIVOT
(
  MAX(DocUrl)
  FOR [DocType] IN ([photo], [aadhar card], [bank passbook], [plot photo], [pipe installed])
) piv;
end
end



GO

-- %% [markdown]
-- # [dbo].[SP_TotalFarmerCount]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TotalFarmerCount]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE Proc [dbo].[SP_TotalFarmerCount]
as
begin
--select count(FarmerCode) FarmerCount,sum(TotalPlotArea) as AprroxArea,sum(GPSPlotArea) GPSPlotArea from
--(select f.FarmerCode,f.FarmerTitle,f.FirstName,f.TotalPlotArea,f.MiddleName,f.LastName,f.CreatedByUserId,
--cast(f.CreatedDate as date) CreatedDate,l.GPSPlotArea from Farmer f
-- full outer join (select FarmerCode,sum(GPSPlotArea) GPSPlotArea from Land where IsActive=1 group by FarmerCode) l 
--on l.FarmerCode = f.FarmerCode where f.IsActive=1)X 

declare @totalfarmer int
declare @totalplotarea decimal(18,3)
declare @gpsplotarea decimal(18,3)

set @totalfarmer =(select count(FarmerCode) from vw_farmer)
set @totalplotarea =(select sum(TotalPlotArea) from vw_farmer)
set @gpsplotarea =(select sum(GPSPlotArea) from vw_plot)

select @totalfarmer as FarmerCount,@totalplotarea as ApproxArea,@gpsplotarea as GPSPlotArea

end
GO

-- %% [markdown]
-- # [dbo].[SP_TotalFarmerCountbyAgentorDistrict]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TotalFarmerCountbyAgentorDistrict]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TotalFarmerCountbyAgentorDistrict 32,null
CREATE Proc [dbo].[SP_TotalFarmerCountbyAgentorDistrict] (@AgentId int,@DistrictId int)
as
begin

declare @totalfarmer int
declare @totalplotarea decimal(18,3)
declare @gpsplotarea decimal(18,3)
declare @UserName varchar(255)

set @UserName = (select UserName from Users where Id= @AgentId)
set @totalfarmer =(select count(FarmerCode) from vw_farmer  
where CreatedByUserId= isnull(@AgentId,CreatedByUserId) and DistrictId = ISNULL(@DistrictId,DistrictId))
set @totalplotarea =(select sum(TotalPlotArea) from vw_farmer 
where CreatedByUserId= isnull(@AgentId,CreatedByUserId) 
and DistrictId = ISNULL(@DistrictId,DistrictId))
set @gpsplotarea =(select sum(GPSPlotArea) from vw_plot
where CreatedByUserId= isnull(@AgentId,CreatedByUserId) 
and DistrictId = ISNULL(@DistrictId,DistrictId))

select isnull(@UserName,'All') as FieldExecutive,
@totalfarmer as FarmerCount,
isnull(@totalplotarea,0) as ApproxArea,
isnull(@gpsplotarea,0) as GPSPlotArea

end
GO

-- %% [markdown]
-- # [dbo].[SP_TotalFarmerCountbyUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TotalFarmerCountbyUser]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TotalFarmerCountbyUser 'Superadmin'
CREATE Proc [dbo].[SP_TotalFarmerCountbyUser] (@P_UserName Varchar(30))
as
begin

--select  * from 
--(select * from
--(select FieldExecutive,count(*) FarmerCount,SUM(TotalPlotArea) ApproxArea ,sum(GPSPlotArea) GPSPlotArea from
--(select f.FarmerCode,f.FarmerTitle,f.FirstName,f.MiddleName,f.TotalPlotArea,f.LastName,f.CreatedByUserId,u.UserName FieldExecutive,cast(f.CreatedDate as date) CreatedDate,
--l.GPSPlotArea
--from Farmer f
--full outer join (select FarmerCode,sum(GPSPlotArea) GPSPlotArea from Land where IsActive=1 group by FarmerCode) l on l.FarmerCode = f.FarmerCode
--inner join Users u on u.Id = f.CreatedByUserId
--where UserName=@P_UserName)X group by FieldExecutive)X)y
--order by FarmerCount desc

declare @totalfarmer int
declare @totalplotarea decimal(18,3)
declare @gpsplotarea decimal(18,3)
declare @UserId int

set @UserId = (select Id from Users where UserName= @P_UserName)
set @totalfarmer =(select count(FarmerCode) from vw_farmer where CreatedByUserId=@UserId)
set @totalplotarea =(select sum(TotalPlotArea) from vw_farmer where CreatedByUserId=@UserId)
set @gpsplotarea =(select sum(GPSPlotArea) from vw_plot where CreatedByUserId=@UserId)

select @P_UserName as FieldExecutive,
@totalfarmer as FarmerCount,
isnull(@totalplotarea,0) as ApproxArea,
isnull(@gpsplotarea,0) as GPSPlotArea

end
GO

-- %% [markdown]
-- # [dbo].[SP_TotalFarmerDetailsForManagedDashboard]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TotalFarmerDetailsForManagedDashboard]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
  
--exec SP_TotalFarmerDetailsForManagedDashboard null,null  
CREATE Proc [dbo].[SP_TotalFarmerDetailsForManagedDashboard](@AgentId int,@DistrictId int)  
as  
begin  
select  
f.CreatedByUserId,f.VillageId,f.MandalId,f.DistrictId,count(f.FarmerCode) TotalRegistartion,cast(sum(f.TotalPlotArea) as decimal(18,3)) TotalPlotArea into #TempFarmer from  
Farmer f  
where f.CreatedByUserId in (26,29,30,31,32,33,36,37,39,43,44,47,49,50,53,56) and f.DistrictId !=0 and CreatedByUserId = isnull(@AgentId, f.CreatedByUserId) and DistrictId = ISNULL(@DistrictId,f.DistrictId)  
group by f.CreatedByUserId,f.VillageId,f.MandalId,f.DistrictId  
  
--select count(*) from #TempFarmer  
  
select  
u.UserName as AgentName,d.Name as DistrictName,m.Name as MandalName,v.Name as VillageName,  
f.TotalRegistartion,f.TotalPlotArea,ch.Name as ClusterName ,at.TargetRegistration, at.TargetPlotArea
--,f.VillageId,f.MandalId,f.DistrictId,f.CreatedByUserId   
from  
#TempFarmer f  
left join Users u on u.Id = f.CreatedByUserId  
left join (select sum(TargetRegistration) TargetRegistration,sum(TargetArea) TargetPlotArea,AgentId
from AgentTargets group by AgentId) at on at.AgentId = f.CreatedByUserId
left join District d on d.Id = f.DistrictId  
left join Mandal m on m.Id = f.MandalId  
left join Village v on v.Id = f.VillageId  
left join ClusterDTL cd on cd.VillageId = f.VillageId  
left join ClusterHDR ch on ch.Id = cd.ClusterHDRId  
drop table #TempFarmer  
end  
  
GO

-- %% [markdown]
-- # [dbo].[SP_TotalGPSCountbyAgentorDistrict]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TotalGPSCountbyAgentorDistrict]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec [dbo].[SP_TotalGPSCountbyAgentorDistrict] null,null
CREATE PROCEDURE [dbo].[SP_TotalGPSCountbyAgentorDistrict] (@AgentId int,@DistrictId int)
AS 
BEGIN
    
	select ROW_NUMBER() over(Order by l.Id) RowId, l.Latitude,Longitude,Cluster,gps,F.FarmerTitle+'.'+FirstName+' '+LastName as FarmerName into #Temp from land l
	left join Farmer F on F.FarmerCode = l.FarmerCode
	WHERE l.CreatedByUserId = ISNULL(@AgentId, l.CreatedByUserId) and l.DistrictId = ISNULL(@DistrictId,l.DistrictId)
    AND l.IsActive = 1  and l.Latitude!='' and l.Longitude!=''

	select * from #Temp

	declare @totalgpsCount int
	set @totalgpsCount = (select count(RowId) from #Temp)

	select @totalgpsCount as totalgpsCount

	drop table #Temp

END

GO

-- %% [markdown]
-- # [dbo].[SP_TotalPlotCountbyAgentorDistrict]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_TotalPlotCountbyAgentorDistrict]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_TotalPlotCountbyAgentorDistrict null,null
CREATE Proc [dbo].[SP_TotalPlotCountbyAgentorDistrict] (@AgentId int,@DistrictId int)
as
begin

declare @totalplot int
declare @gpspointtaken int
declare @pipeinstalled int
declare @UserName varchar(255)

set @UserName = (select UserName from Users where Id= @AgentId)

set @totalplot = (select count(PlotNo) from vw_plot 
where CreatedByUserId= isnull(@AgentId,CreatedByUserId) and DistrictId = ISNULL(@DistrictId,DistrictId)) 

set @gpspointtaken = (select count(Id) 
from vw_plot where Latitude!='' and Longitude!='' and 
CreatedByUserId= isnull(@AgentId,CreatedByUserId) and DistrictId = ISNULL(@DistrictId,DistrictId)) 


set @pipeinstalled = (select count(PlotNo)
from [dbo].[vw_pipeinstalled] where 
CreatedByUserId= isnull(@AgentId,CreatedByUserId) and DistrictId = ISNULL(@DistrictId,DistrictId))

select isnull(@UserName,'All') as FieldExecutive, @totalplot as NoofPlots,
@gpspointtaken as NoofGPSPointsTaken,
@pipeinstalled as NoofWaterRegimeInstalled
end


GO

-- %% [markdown]
-- # [dbo].[SP_UpdateFarmer]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateFarmer]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdateFarmer]
(
 @Id int
,@FarmerTitle varchar(255)
,@FirstName varchar(255)
,@MiddleName varchar(255)
,@LastName varchar(255)
,@FatherName varchar(255)
,@Gender varchar(50)
,@Age int
,@PrimaryContactNum varchar(255)
,@SecondaryContactNum varchar(255)
,@Address varchar(255)
,@DistrictId int
,@MandalId int
,@StateId int
,@VillageId int
,@PinCode varchar(255)
,@UpdatedByUserId int
,@UpdatedDate datetime
)
as
begin
  update Farmer set 
  FarmerTitle = @FarmerTitle
  ,FirstName = @FirstName
  ,MiddleName = @MiddleName
  ,LastName = @LastName
  ,FatherName = @FatherName
  ,Gender = @Gender
  ,Age = @Age
  ,PrimaryContactNum = @PrimaryContactNum
  ,SecondaryContactNum = @SecondaryContactNum
  ,Address = @Address
  ,DistrictId = @DistrictId
  ,MandalId = @MandalId
  ,StateId = @StateId
  ,PinCode = @PinCode
  ,UpdatedByUserId = @UpdatedByUserId
  ,UpdatedDate = @UpdatedDate
  where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateFarmerBank]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateFarmerBank]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_UpdateFarmerBank]
(
 @Id int
 ,@FarmerCode varchar(255)
,@AccountHolderName varchar(255)
,@AccountNumber varchar(255)
,@BranchName varchar(255)
,@IFSCCode varchar(255)
,@IsActive bit
,@UpdatedByUserId int
,@UpdatedDate datetime
)
as
begin
  update FarmerBank set 
	AccountHolderName = @AccountHolderName
   ,AccountNumber = @AccountNumber
   ,BranchName = @BranchName
   ,IFSCCode = @IFSCCode
   ,IsActive = @IsActive
  ,UpdatedByUserId = @UpdatedByUserId
  ,UpdatedDate = @UpdatedDate
  where Id=@Id

  if(@IsActive = 0)
  begin
     
 update Documents set IsActive=0 where FarmerCode=@FarmerCode and 
	DocType='bank passbook'
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateFarmerIdentity]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateFarmerIdentity]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_UpdateFarmerIdentity](@FarmerCode varchar(255),@DocOldNum varchar(255))
as
begin
update Documents set DocOldNum=@DocOldNum where FarmerCode=@FarmerCode and
DocType in ('aadhar card','voter id','driving licence','pan card')
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateFarmerMapping]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateFarmerMapping]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdateFarmerMapping]
(
  @Id int
 ,@AgentId int
 ,@VoluntaryId Int
 ,@UpdatedByUserId int
 ,@UpdatedDate datetime
)
as
begin
  update Farmer set 
   AgentId = @AgentId
  ,VoluntaryId = @VoluntaryId
  ,UpdatedByUserId = @UpdatedByUserId
  ,UpdatedDate = @UpdatedDate
  where Id=@Id
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateFarmerPlotDetails]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateFarmerPlotDetails]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE proc [dbo].[SP_UpdateFarmerPlotDetails]
(
 @Id int
 ,@PlotNo varchar(255)
,@Plotownership varchar(255)
,@CropId int
,@Size varchar(255)
,@SurveyNo varchar(100)
,@PattadarBookNo varchar(255)
,@PinCode varchar(255)
,@VillageId int
,@MandalId int
,@DistrictId int
,@StateId int
,@LandMark varchar(255)
,@Address varchar(255)
,@Cluster varchar(255)
,@IsActive bit
,@UpdatedByUserId int
,@UpdatedDate datetime
)
as
begin
  update Land set 
	Plotownership = @Plotownership
   ,CropId = @CropId
   ,Size = @Size
   ,SurveyNo = @SurveyNo
   ,PattadarBookNo = @PattadarBookNo
   ,PinCode = @PinCode
   ,VillageId = @VillageId
   ,MandalId = @MandalId
   ,DistrictId = @DistrictId
   ,StateId = @StateId
   ,LandMark = @LandMark
   ,Address = @Address
   ,Cluster = @Cluster
   ,IsActive = @IsActive
  ,UpdatedByUserId = @UpdatedByUserId
  ,UpdatedDate = @UpdatedDate
  where Id=@Id

  if(@IsActive = 0)
  begin
     
 update Documents set IsActive=0 where PlotNo=@PlotNo and 
	DocType='photo'
  end
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateFarmerVolunteerId]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateFarmerVolunteerId]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
--exec SP_UpdateFarmerVolunteerId 33,'6618,6721,11078'
CREATE proc [dbo].[SP_UpdateFarmerVolunteerId](@VolunteerId int, @List varchar(max))
as
begin
  --select * from Farmer where Id in (SELECT value FROM STRING_SPLIT(@List, ','))
  update Farmer set VoluntaryId=@VolunteerId where Id in (SELECT value FROM STRING_SPLIT(@List, ','))
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdatePipeInstallationPhoto]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdatePipeInstallationPhoto]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdatePipeInstallationPhoto]
(
 @FarmerCode varchar(255),
 @DocUrl varchar(255),
 @DocType varchar(100),
 @IsActive bit,
 @CreatedByUserId int,
 @UpdatedByUserId int,
 @AgentId int,
 @ErrorNumber INT OUTPUT,
 @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
 
   declare @cnt int
   set @cnt =(select count(*) from Documents where FarmerCode=@FarmerCode and DocType = 'pipe installation' and IsActive=1)
   if @cnt > 0
   begin
     update Documents set IsActive=0 where FarmerCode=@FarmerCode and DocType = 'pipe installation' and IsActive=1
	 update PipeInstallation set IsActive=0  where FarmerCode=@FarmerCode and IsActive=1
   end 

   BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		   
	   insert into Documents(FarmerCode,DocUrl,DocType,DocExtension,
	   IsActive,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId],AgentId)
	  values(@FarmerCode,@DocUrl,@DocType,'.jpg'
	  ,ISNULL(@IsActive, 1)
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@CreatedByUserId
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			,@AgentId
	  )

	   insert into PipeInstallation(
	   [FarmerCode]
      ,[CurrYear]
      ,[SeasonId]
      ,[DateOfPipeInstallation]
      ,[Latitude]
      ,[Longitude]
      ,[AgentId]
      ,[VoluntaryId]
      ,[IsActive]
      ,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId]
			)
			values(@FarmerCode
			,'2023'
			,2
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,null
			,null
			,@AgentId
			,null
			,ISNULL(@IsActive, 1)
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@CreatedByUserId
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			)
		END
		END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdatePipeInstallationPhotoWithDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdatePipeInstallationPhotoWithDate]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[SP_UpdatePipeInstallationPhotoWithDate]
(
 @FarmerCode varchar(255),
 @DocUrl varchar(255),
 @DocType varchar(100),
 @InstallationDate datetime,
 @IsActive bit,
 @CreatedByUserId int,
 @UpdatedByUserId int,
 @AgentId int,
 @ErrorNumber INT OUTPUT,
 @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
 
   declare @cnt int
   set @cnt =(select count(*) from Documents where FarmerCode=@FarmerCode and DocType = 'pipe installation' and IsActive=1)
   if @cnt > 0
   begin
     update Documents set IsActive=0 where FarmerCode=@FarmerCode and DocType = 'pipe installation' and IsActive=1
	 update PipeInstallation set IsActive=0  where FarmerCode=@FarmerCode and IsActive=1
   end 

   BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		   
	   insert into Documents(FarmerCode,DocUrl,DocType,DocExtension,
	   IsActive,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId],AgentId)
	  values(@FarmerCode,@DocUrl,@DocType,'.jpg'
	  ,ISNULL(@IsActive, 1)
	  ,ISNULL(@InstallationDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
	  ,@CreatedByUserId
	  ,ISNULL(@InstallationDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			,@AgentId
	  )

	   insert into PipeInstallation(
	   [FarmerCode]
      ,[CurrYear]
      ,[SeasonId]
      ,[DateOfPipeInstallation]
      ,[Latitude]
      ,[Longitude]
      ,[AgentId]
      ,[VoluntaryId]
      ,[IsActive]
      ,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId]
			)
			values(@FarmerCode
			,'2023'
			,2
			,ISNULL(@InstallationDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,null
			,null
			,@AgentId
			,null
			,ISNULL(@IsActive, 1)
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@CreatedByUserId
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			)
		END
		END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateVoluntaryLand]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateVoluntaryLand]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_UpdateVoluntaryLand] 
(
 @PlotNo varchar(255)
,@FarmerCode varchar(255)
,@Latitude varchar(255)
,@Longitude varchar(255)
,@GPSPlotArea decimal(18,6)
,@VoluntaryId int
,@UpdatedDate datetime
,@ErrorNumber INT OUTPUT
,@ErrorMessage NVARCHAR(4000) OUTPUT
)
AS
BEGIN
	BEGIN TRANSACTION
	BEGIN TRY
		
		BEGIN
		IF LEN(ISNULL(@GPSPlotArea, '')) = 0
     	Begin
			set @GPSPlotArea = 0
		end
		  UPDATE [dbo].[Land] 
                SET
                 [Latitude] = @Latitude
                ,[Longitude] = @Longitude
                ,GPSPlotArea = @GPSPlotArea
                ,VoluntaryId = @VoluntaryId
                ,UpdatedDate = ISNULL(@UpdatedDate, GETDATE())
                where FarmerCode = @FarmerCode and PlotNo = @PlotNo
		END
		
	END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
END
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateWaterCycles]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateWaterCycles]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create proc [dbo].[SP_UpdateWaterCycles]
(
 @FarmerCode varchar(255),
 @DocUrl varchar(255),
 @DocType varchar(100),
 @IsActive bit,
 @CreatedByUserId int,
 @UpdatedByUserId int,
 @AgentId int,
 @ErrorNumber INT OUTPUT,
 @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
 
   declare @cnt int
   set @cnt =(select count(*) from Documents where FarmerCode=@FarmerCode and DocType = @DocType and IsActive=1)
   if @cnt > 0
   begin
     update Documents set IsActive=0 where FarmerCode=@FarmerCode and DocType = @DocType and IsActive=1
   end 

   BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		   
	   insert into Documents(FarmerCode,DocUrl,DocType,DocExtension,
	   IsActive,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId],AgentId)
	  values(
	  @FarmerCode,
	  @DocUrl,
	  @DocType,
	  '.jpg'
	  ,ISNULL(@IsActive, 1)
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@CreatedByUserId
			,(GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			,@AgentId
	  )

		END
		END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_UpdateWaterCyclesWithDate]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_UpdateWaterCyclesWithDate]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

create proc [dbo].[SP_UpdateWaterCyclesWithDate]
(
 @FarmerCode varchar(255),
 @DocUrl varchar(255),
 @DocType varchar(100),
 @InstallationDate datetime,
 @IsActive bit,
 @CreatedByUserId int,
 @UpdatedByUserId int,
 @AgentId int,
 @ErrorNumber INT OUTPUT,
 @ErrorMessage NVARCHAR(4000) OUTPUT
)
as
begin
 
   declare @cnt int
   set @cnt =(select count(*) from Documents where FarmerCode=@FarmerCode and DocType = @DocType and IsActive=1)
   if @cnt > 0
   begin
     update Documents set IsActive=0 where FarmerCode=@FarmerCode and DocType = @DocType and IsActive=1
   end 

   BEGIN TRANSACTION
	BEGIN TRY
		BEGIN
		   
	   insert into Documents(FarmerCode,DocUrl,DocType,DocExtension,
	   IsActive,[CreatedDate]
      ,[CreatedByUserId]
      ,[UpdatedDate]
      ,[UpdatedByUserId],AgentId)
	  values(
	  @FarmerCode,
	  @DocUrl,
	  @DocType,
	  '.jpg'
	  ,ISNULL(@IsActive, 1)
	  ,ISNULL(@InstallationDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@CreatedByUserId
	  ,ISNULL(@InstallationDate, GETDATE()) AT TIME ZONE 'UTC' AT TIME ZONE 'India Standard Time'
			,@UpdatedByUserId
			,@AgentId
	  )

		END
		END TRY

	BEGIN CATCH
		SELECT @ErrorNumber = ERROR_NUMBER()
			,@ErrorMessage = ERROR_MESSAGE()

		IF @@TRANCOUNT > 0
			ROLLBACK TRANSACTION;
		RAISERROR ('Error: %d: %s', 16, 1, @ErrorNumber, @ErrorMessage) 
	END CATCH;

	IF @@TRANCOUNT > 0
		COMMIT TRANSACTION;

	SET @ErrorNumber = 0
	SET @ErrorMessage = 'Success'
end
GO

-- %% [markdown]
-- # [dbo].[SP_ValidateUser]

-- %%
/****** Object:  StoredProcedure [dbo].[SP_ValidateUser]    Script Date: 27-10-2023 15:05:46 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE PROCEDURE [dbo].[SP_ValidateUser]
	@UserName VARCHAR(50),
	@Password VARCHAR(50)    
AS

BEGIN
	SET NOCOUNT ON;
		SELECT 
			u.Id,
			u.FirstName,
			u.LastName,
			u.UserName,
			u.MobileNumber,
			u.Password,
			u.RoleId
		FROM Users u 
		WHERE u.UserName=@UserName AND u.Password=@Password AND u.ViewYN=1
END
GO
